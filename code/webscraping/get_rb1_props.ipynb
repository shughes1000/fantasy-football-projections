# %% [markdown]
# Find relevant runningbacks to webscrape

# %%
import pandas as pd

pd.set_option('display.max_columns', 100)

df_superflex_rankings = pd.read_parquet(r'..\..\data\fantasypros_in_season_rankings\superflex_rankings.parquet')

df_superflex_rankings = df_superflex_rankings.loc[df_superflex_rankings['Player Name'].notna(), :].reset_index(drop=True)

df_superflex_rankings
# Out:
#        Year  Week   RK        Player Name POS  POS RK
# 0      2018     1    1     Todd Gurley II  RB       1
# 1      2018     1    2      David Johnson  RB       2
# 2      2018     1    3       Alvin Kamara  RB       3
# 3      2018     1    4  Melvin Gordon III  RB       4
# 4      2018     1    5    Ezekiel Elliott  RB       5
# ...     ...   ...  ...                ...  ..     ...
# 41050  2023    17  461    Steven Sims Jr.  WR     183
# 41051  2023    17  462     Jashaun Corbin  RB     112
# 41052  2023    17  463       Dee Eskridge  WR     184
# 41053  2023    17  464       Clayton Tune  QB      65
# 41054  2023    17  465      Brady Russell  TE     104
#
# [41055 rows x 6 columns]

# %%
df_rb = df_superflex_rankings.loc[df_superflex_rankings['POS'] == 'RB', :].sort_values(['Year', 'Week', 'POS RK'], ignore_index=True)

df_rb = df_rb.loc[df_rb['Year'] >= 2020, :].reset_index(drop=True)  # for now

df_rb.sort_values(['Year', 'Week', 'POS RK'], ignore_index=True, inplace=True)

df_rb
# Out:
#       Year  Week   RK          Player Name POS  POS RK
# 0     2020     1    3  Christian McCaffrey  RB       1
# 1     2020     1   16      Ezekiel Elliott  RB       2
# 2     2020     1   20          Dalvin Cook  RB       3
# 3     2020     1   22          Josh Jacobs  RB       4
# 4     2020     1   24       Saquon Barkley  RB       5
# ...    ...   ...  ...                  ...  ..     ...
# 7994  2023    17  396        Adam Prentice  RB     108
# 7995  2023    17  412        Jonathan Ward  RB     109
# 7996  2023    17  415          Sean Tucker  RB     110
# 7997  2023    17  416     Ty Montgomery II  RB     111
# 7998  2023    17  462       Jashaun Corbin  RB     112
#
# [7999 rows x 6 columns]

# %%
df_rb.loc[df_rb['Player Name'].str.contains('-'), 'Player Name'].unique()
# Out:
# array(['Clyde Edwards-Helaire', 'Tony Brooks-James', 'Tyrion Davis-Price'],
#       dtype=object)

# %%
df_rb.loc[df_rb['Player Name'].str.contains(r'(Sr\.|Jr\.)$', regex=True), 'Player Name'].unique()
# Out:
# C:\Users\mhugh\AppData\Local\Temp\ipykernel_25380\3306468192.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df_rb.loc[df_rb['Player Name'].str.contains(r'(Sr\.|Jr\.)$', regex=True), 'Player Name'].unique()
# array(['Duke Johnson Jr.', 'Darrell Henderson Jr.', 'Benny Snell Jr.',
#        'Wayne Gallman Jr.', 'Jeff Wilson Jr.', 'Alex Armah Jr.',
#        "De'Angelo Henderson Sr.", 'Anthony McFarland Jr.',
#        'Kerrith Whyte Jr.', 'Patrick Taylor Jr.', 'Tony Jones Jr.',
#        'Adrian Killins Jr.', 'Demetric Felton Jr.', 'Pooka Williams Jr.',
#        'John Kelly Jr.', 'A.J. Rose Jr.', 'Travis Etienne Jr.',
#        'Pierre Strong Jr.', 'Brian Robinson Jr.', 'Chris Rodriguez Jr.',
#        'SaRodorick Thompson Jr.'], dtype=object)

# %%
# make names easier to match
df_rb['Player Name'] = (
    df_rb['Player Name']
    .str.split().str[:2].str.join(' ')  # make names just the first two words
    .str.replace(r'[^a-zA-Z0-9\s]', '', regex=True)  # remove non-alphanumeric characters
    .str.lower()  # lowercase only (helps with matching)
)

df_rb
# Out:
#       Year  Week   RK          Player Name POS  POS RK
# 0     2020     1    3  christian mccaffrey  RB       1
# 1     2020     1   16      ezekiel elliott  RB       2
# 2     2020     1   20          dalvin cook  RB       3
# 3     2020     1   22          josh jacobs  RB       4
# 4     2020     1   24       saquon barkley  RB       5
# ...    ...   ...  ...                  ...  ..     ...
# 7994  2023    17  396        adam prentice  RB     108
# 7995  2023    17  412        jonathan ward  RB     109
# 7996  2023    17  415          sean tucker  RB     110
# 7997  2023    17  416        ty montgomery  RB     111
# 7998  2023    17  462       jashaun corbin  RB     112
#
# [7999 rows x 6 columns]

# %% [markdown]
# Filter to relevant players

# %%
df_teams = pd.read_parquet('../../data/fantasy_points/footballguys_half_ppr.parquet')[['Season', 'Week', 'Name', 'Team', 'Position']]

df_teams['Name'] = (
    df_teams['Name'].str.split().str[:2].str.join(' ')  # make names just the first two words
    .str.replace(r'[^a-zA-Z0-9\s]', '', regex=True)  # remove non-alphanumeric characters
    .str.lower()  # lowercase only (helps with matching)
)

df_teams = df_teams.loc[df_teams['Position'] == 'RB', :].reset_index(drop=True)

df_teams
# Out:
#       Season  Week                   Name Team Position
# 0       2018     1           alvin kamara   NO       RB
# 1       2018     1           james conner  PIT       RB
# 2       2018     1        adrian peterson  WAS       RB
# 3       2018     1              joe mixon  CIN       RB
# 4       2018     1         isaiah crowell  NYJ       RB
# ...      ...   ...                    ...  ...      ...
# 9248    2023    17          hunter luepke  DAL       RB
# 9249    2023    17        latavius murray  BUF       RB
# 9250    2023    17        dare ogunbowale  HOU       RB
# 9251    2023    17  cordarrelle patterson  ATL       RB
# 9252    2023    17         lamical perine   KC       RB
#
# [9253 rows x 5 columns]

# %% [markdown]
# Fix players with difficult names

# %%
df_teams.loc[df_teams['Name'] == 'ken walker', 'Name'] = 'kenneth walker'

# %%
df_rb = df_rb.merge(
    df_teams.rename(columns={'Season': 'Year', 'Name': 'Player Name', 'Position': 'POS'}),
    how='left',
    on=['Year', 'Week', 'Player Name', 'POS'],
)

df_rb.loc[(df_rb['Team'].isna()) & (df_rb['POS RK'] <= 25), :]

# 2022 Week 17 Bills at Bengals was cancelled
# Out:
#       Year  Week  RK           Player Name POS  POS RK Team
# 1488  2020    13  73  clyde edwardshelaire  RB      18  NaN

# %%
df_rb.loc[(df_rb['Team'].isna()) & (df_rb['POS RK'] <= 32*2), :].groupby(['Player Name'])['POS'].count().sort_values(ascending=False).head(10)
# Out:
# Player Name
# ty montgomery        4
# boston scott         3
# jordan mason         3
# leonard fournette    3
# keaontay ingram      3
# royce freeman        2
# zamir white          2
# trey sermon          2
# gary brightwell      2
# benny snell          2
# Name: POS, dtype: int64

# %%
df_rb = df_rb.loc[df_rb['Team'].notna(), :].reset_index(drop=True)

df_rb
# Out:
#       Year  Week   RK          Player Name POS  POS RK Team
# 0     2020     1    3  christian mccaffrey  RB       1  CAR
# 1     2020     1   16      ezekiel elliott  RB       2  DAL
# 2     2020     1   20          dalvin cook  RB       3  MIN
# 3     2020     1   22          josh jacobs  RB       4   LV
# 4     2020     1   24       saquon barkley  RB       5  NYG
# ...    ...   ...  ...                  ...  ..     ...  ...
# 6170  2023    17  369        jakob johnson  RB     102   LV
# 6171  2023    17  377           alex armah  RB     105  WAS
# 6172  2023    17  388          nick bawden  RB     107  NYJ
# 6173  2023    17  396        adam prentice  RB     108   NO
# 6174  2023    17  412        jonathan ward  RB     109  TEN
#
# [6175 rows x 7 columns]

# %%
df_rb = df_rb.groupby(['Year', 'Week', 'Team']).nth(0).reset_index(drop=True)

df_rb
# Out:
#       Year  Week   RK          Player Name POS  POS RK Team
# 0     2020     1    3  christian mccaffrey  RB       1  CAR
# 1     2020     1   16      ezekiel elliott  RB       2  DAL
# 2     2020     1   20          dalvin cook  RB       3  MIN
# 3     2020     1   22          josh jacobs  RB       4   LV
# 4     2020     1   24       saquon barkley  RB       5  NYG
# ...    ...   ...  ...                  ...  ..     ...  ...
# 2011  2023    17   84        jaylen warren  RB      29  PIT
# 2012  2023    17   89          jerome ford  RB      30  CLE
# 2013  2023    17   99          gus edwards  RB      32  BAL
# 2014  2023    17  104       khalil herbert  RB      33  CHI
# 2015  2023    17  116       brian robinson  RB      35  WAS
#
# [2016 rows x 7 columns]

# %%
df_rb['Player Name URL'] = df_rb['Player Name'].str.replace(' ', '-')

# fix players who are known to have issues
df_rb.loc[df_rb['Player Name'] == 'clyde edwardshelaire', 'Player Name URL'] = 'clyde-edwards-helaire'
df_rb.loc[df_rb['Player Name'] == 'benny snell', 'Player Name URL'] = 'benjamin-snell-jr'
df_rb.loc[df_rb['Player Name'] == 'jeff wilson', 'Player Name URL'] = 'jeffery-wilson'
df_rb.loc[df_rb['Player Name'] == 'tony jones', 'Player Name URL'] = 'tony-jones-rb'
df_rb.loc[df_rb['Player Name'] == 'pierre strong', 'Player Name URL'] = 'pierre-strong-jr'
df_rb.loc[df_rb['Player Name'] == 'brian robinson', 'Player Name URL'] = 'brian-robinson-jr'
df_rb.loc[df_rb['Player Name'] == 'chris rodriguez', 'Player Name URL'] = 'chris-rodriguez-jr'
df_rb.loc[df_rb['Player Name'] == 'david johnson', 'Player Name URL'] = 'david-johnson-rb'
df_rb.loc[df_rb['Player Name'] == 'ronald jones', 'Player Name URL'] = 'ronald-jones-ii'
df_rb.loc[df_rb['Player Name'] == 'damien harris', 'Player Name URL'] = 'damien-harris-rb'
df_rb.loc[df_rb['Player Name'] == 'mike davis', 'Player Name URL'] = 'mike-davis-rb'
df_rb.loc[df_rb['Player Name'] == 'adrian peterson', 'Player Name URL'] = 'adrian-peterson-min'
df_rb.loc[df_rb['Player Name'] == 'justin jackson', 'Player Name URL'] = 'justin-jackson-rb'
df_rb.loc[df_rb['Player Name'] == 'rodney smith', 'Player Name URL'] = 'rodney-smith-rb'
df_rb.loc[df_rb['Player Name'] == 'buddy howell', 'Player Name URL'] = 'gregory-howell'
df_rb.loc[df_rb['Player Name'] == 'najee harris', 'Player Name URL'] = 'najee-harris-rb'
df_rb.loc[df_rb['Player Name'] == 'kenneth walker', 'Player Name URL'] = 'kenneth-walker-rb'
df_rb.loc[df_rb['Player Name'] == 'zonovan knight', 'Player Name URL'] = 'zonovan-bam-knight'
df_rb.loc[df_rb['Player Name'] == 'michael carter', 'Player Name URL'] = 'michael-carter-rb'
df_rb.loc[df_rb['Player Name'] == 'tyrion davisprice', 'Player Name URL'] = 'tyrion-davis-price'
df_rb.loc[df_rb['Player Name'] == 'spencer brown', 'Player Name URL'] = 'spencer-brown-rb'


df_rb
# Out:
#       Year  Week   RK          Player Name POS  POS RK Team  \
# 0     2020     1    3  christian mccaffrey  RB       1  CAR
# 1     2020     1   16      ezekiel elliott  RB       2  DAL
# 2     2020     1   20          dalvin cook  RB       3  MIN
# 3     2020     1   22          josh jacobs  RB       4   LV
# 4     2020     1   24       saquon barkley  RB       5  NYG
# ...    ...   ...  ...                  ...  ..     ...  ...
# 2011  2023    17   84        jaylen warren  RB      29  PIT
# 2012  2023    17   89          jerome ford  RB      30  CLE
# 2013  2023    17   99          gus edwards  RB      32  BAL
# 2014  2023    17  104       khalil herbert  RB      33  CHI
# 2015  2023    17  116       brian robinson  RB      35  WAS
#
#           Player Name URL
# 0     christian-mccaffrey
# 1         ezekiel-elliott
# 2             dalvin-cook
# 3             josh-jacobs
# 4          saquon-barkley
# ...                   ...
# 2011        jaylen-warren
# 2012          jerome-ford
# 2013          gus-edwards
# 2014       khalil-herbert
# 2015    brian-robinson-jr
#
# [2016 rows x 8 columns]

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

options = Options()
# options.add_argument('--headless')

driver = webdriver.Chrome(options=options)

# %%
import time
from selenium.webdriver.common.by import By

def scrape_props(player_name, player_name_url, year, week, team):
    driver.get(url=f"https://www.bettingpros.com/nfl/odds/player-props/{player_name_url}/?season={year}&week={week}")
    time.sleep(5)

    # the page uses lazy loading
    # this loop helps all relevant elements load before scraping
    for _ in range(3):
        # find all loaded rows
        rows = driver.find_elements(
            by=By.CLASS_NAME,
            value="grouped-items-with-sticky-footer__content",
        )

        # scroll to the last loaded row, which should load subsequent rows if there are any
        if len(rows) > 0:
            driver.execute_script(f"window.scrollTo(0, {rows[-1].location['y']});")

        time.sleep(3)

    rows = driver.find_elements(
        by=By.CLASS_NAME,
        value="grouped-items-with-sticky-footer__content",
    )

    if len(rows) == 0:
        print(f"Warning: No rows for {player_name} {year} week {week}")
        
    data = {
        'Year': year,
        'Week': week,
        'Player Name': player_name,
        'Team': team,
    }
    for row in rows:
        t = row.text.split('\n')
        if t[0] == 'Rushing Yards Over/Under':
            data['Rushing Yards Projection'] = t[-4]
            data['Rushing Yards Over'] = t[-3]
            data['Rushing Yards Under'] = t[-1]
        elif t[0] == 'Receiving Yards Over/Under':
            data['Receiving Yards Projection'] = t[-4]
            data['Receiving Yards Over'] = t[-3]
            data['Receiving Yards Under'] = t[-1]
        elif t[0] == 'Receptions Over/Under':
            data['Receptions Projection'] = t[-4]
            data['Receptions Over'] = t[-3]
            data['Receptions Under'] = t[-1]
        elif t[0] == 'Anytime Touchdown Scorer':
            data['Anytime Touchdown Line'] = t[-1]

    return data

# %%
from tqdm.autonotebook import tqdm

d = []
for index, row in tqdm(list(df_rb.iterrows())):
    try:
        d.append(scrape_props(row['Player Name'], row['Player Name URL'], row['Year'], row['Week'], row['Team']))
    except Exception as e:
        print(f"Error with {row['Player Name'], row['Player Name URL'], row['Year'], row['Week'], row['Team']}: {e}")
# Out:
# C:\Users\mhugh\AppData\Local\Temp\ipykernel_25380\402797918.py:1: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm
#   0%|          | 0/2016 [00:00<?, ?it/s]
# Warning: No rows for todd gurley 2020 week 1
# Warning: No rows for todd gurley 2020 week 2
# Warning: No rows for frank gore 2020 week 2
# Warning: No rows for todd gurley 2020 week 3
# Warning: No rows for frank gore 2020 week 3
# Warning: No rows for todd gurley 2020 week 4
# Warning: No rows for frank gore 2020 week 4
# Warning: No rows for todd gurley 2020 week 5
# Warning: No rows for todd gurley 2020 week 6
# Warning: No rows for frank gore 2020 week 6
# Warning: No rows for todd gurley 2020 week 7
# Warning: No rows for frank gore 2020 week 7
# Warning: No rows for todd gurley 2020 week 8
# Warning: No rows for todd gurley 2020 week 9
# Warning: No rows for todd gurley 2020 week 11
# Warning: No rows for frank gore 2020 week 12
# Warning: No rows for frank gore 2020 week 13
# Warning: No rows for todd gurley 2020 week 13
# Warning: No rows for todd gurley 2020 week 14
# Warning: No rows for frank gore 2020 week 14
# Warning: No rows for todd gurley 2020 week 15
# Warning: No rows for frank gore 2020 week 15
# Warning: No rows for frank gore 2020 week 16
# Warning: No rows for elijah mitchell 2021 week 2

# %%
driver.quit()

# %%
d
# Out:
# [{'Year': 2020,
#   'Week': 1,
#   'Player Name': 'christian mccaffrey',
#   'Team': 'CAR',
#   'Anytime Touchdown Line': '-188',
#   'Receiving Yards Projection': 'O 51.5',
#   'Receiving Yards Over': '(-105)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 6.5',
#   'Receptions Over': '(-130)',
#   'Receptions Under': '(+110)',
#   'Rushing Yards Projection': 'O 73.5',
#   'Rushing Yards Over': '(-122)',
#   'Rushing Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'ezekiel elliott',
#   'Team': 'DAL',
#   'Receiving Yards Projection': 'O 29.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-152)',
#   'Receptions Under': '(+120)',
#   'Rushing Yards Projection': 'O 81.5',
#   'Rushing Yards Over': '(-115)',
#   'Rushing Yards Under': '(EVEN)',
#   'Anytime Touchdown Line': '-163'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'dalvin cook',
#   'Team': 'MIN',
#   'Anytime Touchdown Line': '-138',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-130)',
#   'Receptions Under': '(+110)',
#   'Rushing Yards Projection': 'O 74.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Receiving Yards Projection': 'O 28.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'josh jacobs',
#   'Team': 'LV',
#   'Receiving Yards Projection': 'O 16.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-105)',
#   'Anytime Touchdown Line': '-155',
#   'Rushing Yards Projection': 'O 79.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(EVEN)',
#   'Receptions Under': '(-120)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'saquon barkley',
#   'Team': 'NYG',
#   'Rushing Yards Projection': 'O 72.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-134)',
#   'Receptions Under': '(-170)',
#   'Receiving Yards Projection': 'O 33.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '-110'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'derrick henry',
#   'Team': 'TEN',
#   'Receiving Yards Projection': 'O 14.5',
#   'Receiving Yards Over': '(-105)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(+155)',
#   'Receptions Under': '(-220)',
#   'Anytime Touchdown Line': '-160',
#   'Rushing Yards Projection': 'O 96.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'alvin kamara',
#   'Team': 'NO',
#   'Rushing Yards Projection': 'O 49.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Receiving Yards Projection': 'O 39.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(EVEN)',
#   'Receptions Under': '(-120)',
#   'Anytime Touchdown Line': '-138'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'austin ekeler',
#   'Team': 'LAC',
#   'Rushing Yards Projection': 'O 57.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-110)',
#   'Receptions Under': '(-124)',
#   'Anytime Touchdown Line': 'EVEN',
#   'Receiving Yards Projection': 'O 33.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'joe mixon',
#   'Team': 'CIN',
#   'Rushing Yards Projection': 'O 73.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Receiving Yards Projection': 'O 18.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+110'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'clyde edwardshelaire',
#   'Team': 'KC',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-118)',
#   'Receptions Under': '(-108)',
#   'Receiving Yards Projection': 'O 26.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '-125',
#   'Rushing Yards Projection': 'O 57.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'james conner',
#   'Team': 'PIT',
#   'Rushing Yards Projection': 'O 66.5',
#   'Rushing Yards Over': '(-115)',
#   'Rushing Yards Under': '(-105)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-130)',
#   'Receptions Under': '(+110)',
#   'Anytime Touchdown Line': '-110',
#   'Receiving Yards Projection': 'O 25.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'aaron jones',
#   'Team': 'GB',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+120)',
#   'Receptions Under': '(-140)',
#   'Receiving Yards Projection': 'O 22.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-105)',
#   'Rushing Yards Projection': 'O 67.5',
#   'Rushing Yards Over': '(-115)',
#   'Rushing Yards Under': '(-115)',
#   'Anytime Touchdown Line': '-105'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'chris carson',
#   'Team': 'SEA',
#   'Anytime Touchdown Line': 'EVEN',
#   'Rushing Yards Projection': 'O 65.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-120)',
#   'Receptions Under': '(EVEN)',
#   'Receiving Yards Projection': 'O 18.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'kenyan drake',
#   'Team': 'ARI',
#   'Rushing Yards Projection': 'O 58.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+110',
#   'Receiving Yards Projection': 'O 22.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+115)',
#   'Receptions Under': '(-135)'},
#  {'Year': 2020, 'Week': 1, 'Player Name': 'todd gurley', 'Team': 'ATL'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'nick chubb',
#   'Team': 'CLE',
#   'Receiving Yards Projection': 'O 74.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-120)',
#   'Anytime Touchdown Line': '+120',
#   'Rushing Yards Projection': 'O 62.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'david johnson',
#   'Team': 'HOU',
#   'Anytime Touchdown Line': '+200',
#   'Rushing Yards Projection': 'O 49.5',
#   'Rushing Yards Over': '(-162)',
#   'Rushing Yards Under': '(+105)',
#   'Receiving Yards Projection': 'O 21.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-105)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'mark ingram',
#   'Team': 'BAL',
#   'Receiving Yards Projection': 'O 10.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Rushing Yards Projection': 'O 51.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Anytime Touchdown Line': '-105'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'raheem mostert',
#   'Team': 'SF',
#   'Anytime Touchdown Line': '-110',
#   'Rushing Yards Projection': 'O 58.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'melvin gordon',
#   'Team': 'DEN',
#   'Anytime Touchdown Line': '+163',
#   'Receiving Yards Projection': 'O 19.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-142)',
#   'Receptions Under': '(+112)',
#   'Rushing Yards Projection': 'O 45.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'leveon bell',
#   'Team': 'NYJ',
#   'Rushing Yards Projection': 'O 56.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+163'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'jonathan taylor',
#   'Team': 'IND',
#   'Anytime Touchdown Line': '+125',
#   'Rushing Yards Projection': 'O 56.5',
#   'Rushing Yards Over': '(-105)',
#   'Rushing Yards Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'boston scott',
#   'Team': 'PHI',
#   'Anytime Touchdown Line': '+163'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'devin singletary',
#   'Team': 'BUF',
#   'Rushing Yards Projection': 'O 60.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Receiving Yards Projection': 'O 17.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-120)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-130)',
#   'Receptions Under': '(EVEN)',
#   'Anytime Touchdown Line': '+163'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'james white',
#   'Team': 'NE',
#   'Receiving Yards Projection': 'O 32.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Rushing Yards Projection': 'O 17.5',
#   'Rushing Yards Over': '(-115)',
#   'Rushing Yards Under': '(-105)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-130)',
#   'Receptions Under': '(+110)',
#   'Anytime Touchdown Line': '+200'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'antonio gibson',
#   'Team': 'WAS',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-125)',
#   'Receptions Under': '(+105)',
#   'Rushing Yards Projection': 'O 37.5',
#   'Rushing Yards Over': '(-122)',
#   'Rushing Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+175'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'cam akers',
#   'Team': 'LAR',
#   'Rushing Yards Projection': 'O 40.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-128)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-175)',
#   'Receptions Under': '(+106)',
#   'Receiving Yards Projection': 'O 12.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+185'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'tarik cohen',
#   'Team': 'CHI',
#   'Anytime Touchdown Line': '+180'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'ronald jones',
#   'Team': 'TB',
#   'Receiving Yards Projection': 'O 13.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(+115)',
#   'Receptions Under': '(-135)',
#   'Rushing Yards Projection': 'O 38.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+200'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'jordan howard',
#   'Team': 'MIA',
#   'Rushing Yards Projection': 'O 48.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+188'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'chris thompson',
#   'Team': 'JAX',
#   'Anytime Touchdown Line': '+400',
#   'Receiving Yards Projection': 'O 24.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'kerryon johnson',
#   'Team': 'DET',
#   'Anytime Touchdown Line': '+170'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'ezekiel elliott',
#   'Team': 'DAL',
#   'Anytime Touchdown Line': '-175',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+130)',
#   'Receptions Under': '(+118)',
#   'Rushing Yards Projection': 'O 87.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Receiving Yards Projection': 'O 30.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'derrick henry',
#   'Team': 'TEN',
#   'Rushing Yards Projection': 'O 114.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Anytime Touchdown Line': '-250',
#   'Receiving Yards Projection': 'O 15.5',
#   'Receiving Yards Over': '(-105)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(+110)',
#   'Receptions Under': '(-130)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'christian mccaffrey',
#   'Team': 'CAR',
#   'Anytime Touchdown Line': '-138',
#   'Receiving Yards Projection': 'O 45.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Rushing Yards Projection': 'O 63.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(-142)',
#   'Receptions Under': '(+110)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'alvin kamara',
#   'Team': 'NO',
#   'Anytime Touchdown Line': '-140',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(-140)',
#   'Receptions Under': '(+110)',
#   'Rushing Yards Projection': 'O 57.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Receiving Yards Projection': 'O 46.5',
#   'Receiving Yards Over': '(-111)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'dalvin cook',
#   'Team': 'MIN',
#   'Rushing Yards Projection': 'O 72.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Receiving Yards Projection': 'O 22.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+102)',
#   'Receptions Under': '(-130)',
#   'Anytime Touchdown Line': '-120'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'saquon barkley',
#   'Team': 'NYG',
#   'Rushing Yards Projection': 'O 68.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Anytime Touchdown Line': 'EVEN',
#   'Receiving Yards Projection': 'O 30.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+102)',
#   'Receptions Under': '(-130)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'clyde edwardshelaire',
#   'Team': 'KC',
#   'Anytime Touchdown Line': '-138',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-176)',
#   'Receptions Under': '(-175)',
#   'Rushing Yards Projection': 'O 72.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Receiving Yards Projection': 'O 20.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'josh jacobs',
#   'Team': 'LV',
#   'Anytime Touchdown Line': '-138',
#   'Rushing Yards Projection': 'O 70.5',
#   'Rushing Yards Over': '(-111)',
#   'Rushing Yards Under': '(-110)',
#   'Receiving Yards Projection': 'O 24.5',
#   'Receiving Yards Over': '(-112)',
#   'Receiving Yards Under': '(-108)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-161)',
#   'Receptions Under': '(+130)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'aaron jones',
#   'Team': 'GB',
#   'Rushing Yards Projection': 'O 68.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Receiving Yards Projection': 'O 20.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-105)',
#   'Anytime Touchdown Line': '-145',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-164)',
#   'Receptions Under': '(+128)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'jonathan taylor',
#   'Team': 'IND',
#   'Receiving Yards Projection': 'O 19.5',
#   'Receiving Yards Over': '(-128)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': 'EVEN',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(EVEN)',
#   'Receptions Under': '(-120)',
#   'Rushing Yards Projection': 'O 60.5',
#   'Rushing Yards Over': '(-125)',
#   'Rushing Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'joe mixon',
#   'Team': 'CIN',
#   'Anytime Touchdown Line': '+110',
#   'Receiving Yards Projection': 'O 85.5',
#   'Receiving Yards Over': '(-112)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(EVEN)',
#   'Receptions Under': '(-148)',
#   'Rushing Yards Projection': 'O 67.5',
#   'Rushing Yards Over': '(-115)',
#   'Rushing Yards Under': '(-122)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'austin ekeler',
#   'Team': 'LAC',
#   'Anytime Touchdown Line': '+120',
#   'Rushing Yards Projection': 'O 55.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Receiving Yards Projection': 'O 33.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-172)',
#   'Receptions Under': '(-180)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'nick chubb',
#   'Team': 'CLE',
#   'Receiving Yards Projection': 'O 8.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '-130',
#   'Receptions Projection': 'O 1.5',
#   'Receptions Over': '(+152)',
#   'Receptions Under': '(-196)',
#   'Rushing Yards Projection': 'O 78.5',
#   'Rushing Yards Over': '(-105)',
#   'Rushing Yards Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'kenyan drake',
#   'Team': 'ARI',
#   'Receiving Yards Projection': 'O 15.5',
#   'Receiving Yards Over': '(-122)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-130)',
#   'Receptions Under': '(+110)',
#   'Rushing Yards Projection': 'O 62.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Anytime Touchdown Line': '-152'},
#  {'Year': 2020, 'Week': 2, 'Player Name': 'todd gurley', 'Team': 'ATL'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'raheem mostert',
#   'Team': 'SF',
#   'Rushing Yards Projection': 'O 63.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Receiving Yards Projection': 'O 9.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '-105'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'chris carson',
#   'Team': 'SEA',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-164)',
#   'Receptions Under': '(+128)',
#   'Receiving Yards Projection': 'O 19.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Rushing Yards Projection': 'O 53.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+110'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'miles sanders',
#   'Team': 'PHI',
#   'Anytime Touchdown Line': '+120',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-126)',
#   'Receptions Under': '(-150)',
#   'Rushing Yards Projection': 'O 56.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Receiving Yards Projection': 'O 21.5',
#   'Receiving Yards Over': '(-142)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'david johnson',
#   'Team': 'HOU',
#   'Receiving Yards Projection': 'O 29.5',
#   'Receiving Yards Over': '(-105)',
#   'Receiving Yards Under': '(-115)',
#   'Rushing Yards Projection': 'O 63.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+138'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'ronald jones',
#   'Team': 'TB',
#   'Rushing Yards Projection': 'O 59.5',
#   'Rushing Yards Over': '(-122)',
#   'Rushing Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+110'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'melvin gordon',
#   'Team': 'DEN',
#   'Rushing Yards Projection': 'O 49.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Receiving Yards Projection': 'O 22.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(+130)',
#   'Receptions Under': '(+112)',
#   'Anytime Touchdown Line': '+162'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'mark ingram',
#   'Team': 'BAL',
#   'Rushing Yards Projection': 'O 52.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Receiving Yards Projection': 'O 10.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+120'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'david montgomery',
#   'Team': 'CHI',
#   'Rushing Yards Projection': 'O 58.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+125',
#   'Receiving Yards Projection': 'O 9.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-122)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'devin singletary',
#   'Team': 'BUF',
#   'Anytime Touchdown Line': '+163',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(+105)',
#   'Receptions Under': '(-134)',
#   'Receiving Yards Projection': 'O 15.5',
#   'Receiving Yards Over': '(-106)',
#   'Receiving Yards Under': '(-114)',
#   'Rushing Yards Projection': 'O 53.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'malcolm brown',
#   'Team': 'LAR',
#   'Anytime Touchdown Line': '+138',
#   'Receiving Yards Projection': 'O 10.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Rushing Yards Projection': 'O 42.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'james robinson',
#   'Team': 'JAX',
#   'Receptions Projection': 'O 1.5',
#   'Receptions Over': '(-150)',
#   'Receptions Under': '(+130)',
#   'Rushing Yards Projection': 'O 51.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Receiving Yards Projection': 'O 11.5',
#   'Receiving Yards Over': '(-105)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+165'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'antonio gibson',
#   'Team': 'WAS',
#   'Anytime Touchdown Line': '+200',
#   'Rushing Yards Projection': 'O 37.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Receiving Yards Projection': 'O 11.5',
#   'Receiving Yards Over': '(-105)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'james conner',
#   'Team': 'PIT',
#   'Rushing Yards Projection': 'O 45.5',
#   'Rushing Yards Over': '(EVEN)',
#   'Rushing Yards Under': '(-122)',
#   'Receiving Yards Projection': 'O 19.5',
#   'Receiving Yards Over': '(-122)',
#   'Receiving Yards Under': '(EVEN)',
#   'Anytime Touchdown Line': '+120'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'adrian peterson',
#   'Team': 'DET',
#   'Rushing Yards Projection': '--',
#   'Rushing Yards Over': '--',
#   'Rushing Yards Under': '--',
#   'Anytime Touchdown Line': '--'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'sony michel',
#   'Team': 'NE',
#   'Rushing Yards Projection': 'O 39.5',
#   'Rushing Yards Over': '(-115)',
#   'Rushing Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+175'},
#  {'Year': 2020, 'Week': 2, 'Player Name': 'frank gore', 'Team': 'NYJ'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'jordan howard',
#   'Team': 'MIA',
#   'Rushing Yards Projection': 'O 29.5',
#   'Rushing Yards Over': '(-106)',
#   'Rushing Yards Under': '(-114)',
#   'Anytime Touchdown Line': '+250'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'ezekiel elliott',
#   'Team': 'DAL',
#   'Receiving Yards Projection': 'O 31.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-111)',
#   'Rushing Yards Projection': 'O 80.5',
#   'Rushing Yards Over': '(-115)',
#   'Rushing Yards Under': '(-110)',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+104)',
#   'Receptions Under': '(-140)',
#   'Anytime Touchdown Line': '-170'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'alvin kamara',
#   'Team': 'NO',
#   'Anytime Touchdown Line': '-250',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(-142)',
#   'Receptions Under': '(+115)',
#   'Receiving Yards Projection': 'O 47.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Rushing Yards Projection': 'O 66.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'derrick henry',
#   'Team': 'TEN',
#   'Receptions Projection': 'O 1.5',
#   'Receptions Over': '(-170)',
#   'Receptions Under': '(+140)',
#   'Rushing Yards Projection': 'O 101.5',
#   'Rushing Yards Over': '(-111)',
#   'Rushing Yards Under': '(-110)',
#   'Anytime Touchdown Line': '-175',
#   'Receiving Yards Projection': 'O 11.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-120)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'jonathan taylor',
#   'Team': 'IND',
#   'Receiving Yards Projection': 'O 20.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '-155',
#   'Rushing Yards Projection': 'O 84.5',
#   'Rushing Yards Over': '(-122)',
#   'Rushing Yards Under': '(EVEN)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-145)',
#   'Receptions Under': '(+115)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'miles sanders',
#   'Team': 'PHI',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+118)',
#   'Receptions Under': '(+120)',
#   'Receiving Yards Projection': 'O 27.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Rushing Yards Projection': 'O 83.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-111)',
#   'Anytime Touchdown Line': '-105'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'dalvin cook',
#   'Team': 'MIN',
#   'Rushing Yards Projection': 'O 79.5',
#   'Rushing Yards Over': '(-111)',
#   'Rushing Yards Under': '(-110)',
#   'Receiving Yards Projection': 'O 24.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-120)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+105)',
#   'Receptions Under': '(-135)',
#   'Anytime Touchdown Line': '-137'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'aaron jones',
#   'Team': 'GB',
#   'Anytime Touchdown Line': '-164',
#   'Receiving Yards Projection': 'O 32.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Rushing Yards Projection': 'O 69.5',
#   'Rushing Yards Over': '(-111)',
#   'Rushing Yards Under': '(-110)',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+105)',
#   'Receptions Under': '(-135)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'kenyan drake',
#   'Team': 'ARI',
#   'Rushing Yards Projection': 'O 79.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-111)',
#   'Receiving Yards Projection': 'O 19.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-170)',
#   'Receptions Under': '(-158)',
#   'Anytime Touchdown Line': '-145'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'nick chubb',
#   'Team': 'CLE',
#   'Anytime Touchdown Line': '-137',
#   'Receiving Yards Projection': 'O 9.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Rushing Yards Projection': 'O 79.5',
#   'Rushing Yards Over': '(-111)',
#   'Rushing Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'austin ekeler',
#   'Team': 'LAC',
#   'Anytime Touchdown Line': '+105',
#   'Receiving Yards Projection': 'O 31.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-110)',
#   'Rushing Yards Projection': 'O 62.5',
#   'Rushing Yards Over': '(-115)',
#   'Rushing Yards Under': '(-110)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-154)',
#   'Receptions Under': '(+122)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'josh jacobs',
#   'Team': 'LV',
#   'Receiving Yards Projection': 'O 17.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-105)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-113)',
#   'Receptions Under': '(-113)',
#   'Anytime Touchdown Line': '-139',
#   'Rushing Yards Projection': 'O 70.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'clyde edwardshelaire',
#   'Team': 'KC',
#   'Receiving Yards Projection': 'O 25.5',
#   'Receiving Yards Over': '(-122)',
#   'Receiving Yards Under': '(EVEN)',
#   'Anytime Touchdown Line': '-120',
#   'Rushing Yards Projection': 'O 62.5',
#   'Rushing Yards Over': '(-105)',
#   'Rushing Yards Under': '(-122)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-146)',
#   'Receptions Under': '(+114)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'chris carson',
#   'Team': 'SEA',
#   'Receiving Yards Projection': 'O 19.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Rushing Yards Projection': 'O 62.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-111)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-180)',
#   'Receptions Under': '(+130)',
#   'Anytime Touchdown Line': '-164'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'james conner',
#   'Team': 'PIT',
#   'Anytime Touchdown Line': '-152',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+142)',
#   'Receptions Under': '(-184)',
#   'Receiving Yards Projection': 'O 20.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Rushing Yards Projection': 'O 69.5',
#   'Rushing Yards Over': '(-111)',
#   'Rushing Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'joe mixon',
#   'Team': 'CIN',
#   'Receiving Yards Projection': 'O 16.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Rushing Yards Projection': 'O 63.5',
#   'Rushing Yards Over': '(-111)',
#   'Rushing Yards Under': '(-110)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-105)',
#   'Receptions Under': '(-125)',
#   'Anytime Touchdown Line': '+110'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'james robinson',
#   'Team': 'JAX',
#   'Rushing Yards Projection': 'O 70.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Receiving Yards Projection': 'O 15.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '-110',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(+125)',
#   'Receptions Under': '(-145)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'david montgomery',
#   'Team': 'CHI',
#   'Anytime Touchdown Line': 'EVEN',
#   'Rushing Yards Projection': 'O 54.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Receiving Yards Projection': 'O 15.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2020, 'Week': 3, 'Player Name': 'todd gurley', 'Team': 'ATL'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'devin singletary',
#   'Team': 'BUF',
#   'Rushing Yards Projection': 'O 63.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+130',
#   'Receiving Yards Projection': 'O 19.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-160)',
#   'Receptions Under': '(+130)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'melvin gordon',
#   'Team': 'DEN',
#   'Receiving Yards Projection': 'O 18.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-146)',
#   'Receptions Under': '(EVEN)',
#   'Rushing Yards Projection': 'O 56.5',
#   'Rushing Yards Over': '(-111)',
#   'Rushing Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+130'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'david johnson',
#   'Team': 'HOU',
#   'Anytime Touchdown Line': '+125',
#   'Receiving Yards Projection': 'O 24.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+110)',
#   'Receptions Under': '(-158)',
#   'Rushing Yards Projection': 'O 47.5',
#   'Rushing Yards Over': '(-115)',
#   'Rushing Yards Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'leonard fournette',
#   'Team': 'TB',
#   'Rushing Yards Projection': 'O 58.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-120)',
#   'Receptions Under': '(-110)',
#   'Anytime Touchdown Line': '+130',
#   'Receiving Yards Projection': 'O 15.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'mark ingram',
#   'Team': 'BAL',
#   'Anytime Touchdown Line': '+120',
#   'Receiving Yards Projection': 'O 14.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 2.0',
#   'Receptions Over': '(+140)',
#   'Receptions Under': '(-170)',
#   'Rushing Yards Projection': 'O 52.5',
#   'Rushing Yards Over': '(-115)',
#   'Rushing Yards Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'jerick mckinnon',
#   'Team': 'SF',
#   'Anytime Touchdown Line': '+105',
#   'Rushing Yards Projection': 'O 58.5',
#   'Rushing Yards Over': '(-142)',
#   'Rushing Yards Under': '(+116)',
#   'Receiving Yards Projection': 'O 17.5',
#   'Receiving Yards Over': '(-132)',
#   'Receiving Yards Under': '(+108)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-146)',
#   'Receptions Under': '(+114)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'antonio gibson',
#   'Team': 'WAS',
#   'Anytime Touchdown Line': '+180',
#   'Rushing Yards Projection': 'O 50.5',
#   'Rushing Yards Over': '(-111)',
#   'Rushing Yards Under': '(-110)',
#   'Receiving Yards Projection': 'O 13.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(+136)',
#   'Receptions Under': '(-174)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'mike davis',
#   'Team': 'CAR',
#   'Receiving Yards Projection': 'O 30.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+125',
#   'Rushing Yards Projection': 'O 43.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+120)',
#   'Receptions Under': '(-150)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'darrell henderson',
#   'Team': 'LAR',
#   'Anytime Touchdown Line': '+162'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'dandre swift',
#   'Team': 'DET',
#   'Anytime Touchdown Line': '+210',
#   'Rushing Yards Projection': 'O 18.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Receiving Yards Projection': 'O 21.5',
#   'Receiving Yards Over': '(-122)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'myles gaskin',
#   'Team': 'MIA',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-155)',
#   'Receptions Under': '(+135)',
#   'Anytime Touchdown Line': '+185',
#   'Receiving Yards Projection': 'O 20.5',
#   'Receiving Yards Over': '(-122)',
#   'Receiving Yards Under': '(EVEN)',
#   'Rushing Yards Projection': 'O 37.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-111)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'dion lewis',
#   'Team': 'NYG',
#   'Rushing Yards Projection': 'O 35.5',
#   'Rushing Yards Over': '(-115)',
#   'Rushing Yards Under': '(-152)',
#   'Anytime Touchdown Line': '+200',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-108)',
#   'Receptions Under': '(-118)',
#   'Receiving Yards Projection': 'O 15.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'sony michel',
#   'Team': 'NE',
#   'Rushing Yards Projection': 'O 44.5',
#   'Rushing Yards Over': '(-120)',
#   'Rushing Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+125'},
#  {'Year': 2020, 'Week': 3, 'Player Name': 'frank gore', 'Team': 'NYJ'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'alvin kamara',
#   'Team': 'NO',
#   'Receiving Yards Projection': 'O 60.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '-225',
#   'Rushing Yards Projection': 'O 58.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-111)',
#   'Receptions Projection': 'O 7.5',
#   'Receptions Over': '(+110)',
#   'Receptions Under': '(-140)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'ezekiel elliott',
#   'Team': 'DAL',
#   'Receiving Yards Projection': 'O 31.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-111)',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(EVEN)',
#   'Receptions Under': '(-125)',
#   'Anytime Touchdown Line': '-250',
#   'Rushing Yards Projection': 'O 85.5',
#   'Rushing Yards Over': '(-111)',
#   'Rushing Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'dalvin cook',
#   'Team': 'MIN',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-120)',
#   'Receptions Under': '(-150)',
#   'Receiving Yards Projection': 'O 24.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '-150',
#   'Rushing Yards Projection': 'O 79.5',
#   'Rushing Yards Over': '(-118)',
#   'Rushing Yards Under': '(-104)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'aaron jones',
#   'Team': 'GB',
#   'Anytime Touchdown Line': '-300',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-120)',
#   'Receptions Under': '(-110)',
#   'Rushing Yards Projection': 'O 80.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-115)',
#   'Receiving Yards Projection': 'O 38.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-105)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'jonathan taylor',
#   'Team': 'IND',
#   'Receiving Yards Projection': 'O 14.5',
#   'Receiving Yards Over': '(-111)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '-118',
#   'Rushing Yards Projection': 'O 76.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-115)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(+120)',
#   'Receptions Under': '(-143)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'clyde edwardshelaire',
#   'Team': 'KC',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+130)',
#   'Receptions Under': '(-170)',
#   'Anytime Touchdown Line': '-163',
#   'Receiving Yards Projection': 'O 35.5',
#   'Receiving Yards Over': '(-120)',
#   'Receiving Yards Under': '(-120)',
#   'Rushing Yards Projection': 'O 72.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'josh jacobs',
#   'Team': 'LV',
#   'Anytime Touchdown Line': '-163',
#   'Receiving Yards Projection': 'O 18.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-105)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-146)',
#   'Receptions Under': '(+115)',
#   'Rushing Yards Projection': 'O 80.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-111)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'kenyan drake',
#   'Team': 'ARI',
#   'Anytime Touchdown Line': '-155',
#   'Rushing Yards Projection': 'O 70.5',
#   'Rushing Yards Over': '(-115)',
#   'Rushing Yards Under': '(-111)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'miles sanders',
#   'Team': 'PHI',
#   'Receiving Yards Projection': 'O 31.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+130',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(EVEN)',
#   'Receptions Under': '(-125)',
#   'Rushing Yards Projection': 'O 59.5',
#   'Rushing Yards Over': '(-115)',
#   'Rushing Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'nick chubb',
#   'Team': 'CLE',
#   'Anytime Touchdown Line': '-125',
#   'Rushing Yards Projection': 'O 71.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'austin ekeler',
#   'Team': 'LAC',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-156)',
#   'Receptions Under': '(+110)',
#   'Receiving Yards Projection': 'O 37.5',
#   'Receiving Yards Over': '(-150)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+163',
#   'Rushing Yards Projection': 'O 48.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'james robinson',
#   'Team': 'JAX',
#   'Rushing Yards Projection': 'O 63.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-111)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(EVEN)',
#   'Receptions Under': '(-125)',
#   'Anytime Touchdown Line': '-110',
#   'Receiving Yards Projection': 'O 16.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'joe mixon',
#   'Team': 'CIN',
#   'Anytime Touchdown Line': '-125',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(EVEN)',
#   'Receptions Under': '(-118)',
#   'Receiving Yards Projection': 'O 15.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Rushing Yards Projection': 'O 73.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-111)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'david johnson',
#   'Team': 'HOU',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-140)',
#   'Receptions Under': '(-184)',
#   'Anytime Touchdown Line': '-138',
#   'Receiving Yards Projection': 'O 21.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Rushing Yards Projection': 'O 67.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'mike davis',
#   'Team': 'CAR',
#   'Anytime Touchdown Line': '-130',
#   'Rushing Yards Projection': 'O 54.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-111)',
#   'Receiving Yards Projection': 'O 39.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(+105)',
#   'Receptions Under': '(-135)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'darrell henderson',
#   'Team': 'LAR',
#   'Receiving Yards Projection': 'O 14.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '-145',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(+112)',
#   'Receptions Under': '(-142)',
#   'Rushing Yards Projection': 'O 72.5',
#   'Rushing Yards Over': '(-111)',
#   'Rushing Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'melvin gordon',
#   'Team': 'DEN',
#   'Receiving Yards Projection': 'O 20.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-110)',
#   'Rushing Yards Projection': 'O 64.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+120)',
#   'Receptions Under': '(-150)',
#   'Anytime Touchdown Line': '-130'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'david montgomery',
#   'Team': 'CHI',
#   'Anytime Touchdown Line': 'EVEN',
#   'Receiving Yards Projection': 'O 19.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 3.0',
#   'Receptions Over': '(+110)',
#   'Receptions Under': '(-133)',
#   'Rushing Yards Projection': 'O 61.5',
#   'Rushing Yards Over': '(-111)',
#   'Rushing Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'devin singletary',
#   'Team': 'BUF',
#   'Rushing Yards Projection': 'O 64.5',
#   'Rushing Yards Over': '(-115)',
#   'Rushing Yards Under': '(-110)',
#   'Anytime Touchdown Line': 'EVEN',
#   'Receiving Yards Projection': 'O 21.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+125)',
#   'Receptions Under': '(-125)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'ronald jones',
#   'Team': 'TB',
#   'Receiving Yards Projection': 'O 18.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Rushing Yards Projection': 'O 66.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Anytime Touchdown Line': 'EVEN',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-170)',
#   'Receptions Under': '(+140)'},
#  {'Year': 2020, 'Week': 4, 'Player Name': 'todd gurley', 'Team': 'ATL'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'jerick mckinnon',
#   'Team': 'SF',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+130)',
#   'Receptions Under': '(-162)',
#   'Rushing Yards Projection': 'O 53.5',
#   'Rushing Yards Over': '(-111)',
#   'Rushing Yards Under': '(-110)',
#   'Anytime Touchdown Line': 'EVEN',
#   'Receiving Yards Projection': 'O 21.5',
#   'Receiving Yards Over': '(-111)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'chris carson',
#   'Team': 'SEA',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+132)',
#   'Receptions Under': '(-170)',
#   'Receiving Yards Projection': 'O 21.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '-125',
#   'Rushing Yards Projection': 'O 70.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'myles gaskin',
#   'Team': 'MIA',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-120)',
#   'Receptions Under': '(-110)',
#   'Anytime Touchdown Line': '+138',
#   'Rushing Yards Projection': 'O 52.5',
#   'Rushing Yards Over': '(-115)',
#   'Rushing Yards Under': '(-128)',
#   'Receiving Yards Projection': 'O 25.5',
#   'Receiving Yards Over': '(-111)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'mark ingram',
#   'Team': 'BAL',
#   'Rushing Yards Projection': 'O 54.5',
#   'Rushing Yards Over': '(-105)',
#   'Rushing Yards Under': '(-115)',
#   'Anytime Touchdown Line': '-110'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'antonio gibson',
#   'Team': 'WAS',
#   'Anytime Touchdown Line': '+200',
#   'Receiving Yards Projection': 'O 9.5',
#   'Receiving Yards Over': '(-120)',
#   'Receiving Yards Under': '(-110)',
#   'Rushing Yards Projection': 'O 40.5',
#   'Rushing Yards Over': '(-111)',
#   'Rushing Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'adrian peterson',
#   'Team': 'DET',
#   'Rushing Yards Projection': 'O 48.5',
#   'Rushing Yards Over': '(-111)',
#   'Rushing Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+140',
#   'Receiving Yards Projection': 'O 8.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'james white',
#   'Team': 'NE',
#   'Receiving Yards Projection': 'O 24.5',
#   'Receiving Yards Over': '(-105)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+225',
#   'Rushing Yards Projection': 'O 15.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)'},
#  {'Year': 2020, 'Week': 4, 'Player Name': 'frank gore', 'Team': 'NYJ'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'devonta freeman',
#   'Team': 'NYG',
#   'Anytime Touchdown Line': '+230',
#   'Rushing Yards Projection': 'O 34.5',
#   'Rushing Yards Over': '(-120)',
#   'Rushing Yards Under': '(-110)',
#   'Receiving Yards Projection': 'O 9.5',
#   'Receiving Yards Over': '(-120)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'alvin kamara',
#   'Team': 'NO',
#   'Receiving Yards Projection': 'O 59.5',
#   'Receiving Yards Over': '(-135)',
#   'Receiving Yards Under': '(+105)',
#   'Receptions Projection': 'O 6.5',
#   'Receptions Over': '(-145)',
#   'Receptions Under': '(+115)',
#   'Anytime Touchdown Line': '-275',
#   'Rushing Yards Projection': 'O 66.5',
#   'Rushing Yards Over': '(-113)',
#   'Rushing Yards Under': '(-113)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'ezekiel elliott',
#   'Team': 'DAL',
#   'Receiving Yards Projection': 'O 32.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+104)',
#   'Receptions Under': '(-132)',
#   'Rushing Yards Projection': 'O 88.5',
#   'Rushing Yards Over': '(-115)',
#   'Rushing Yards Under': '(-115)',
#   'Anytime Touchdown Line': '-227'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'clyde edwardshelaire',
#   'Team': 'KC',
#   'Anytime Touchdown Line': '-190',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-125)',
#   'Receptions Under': '(+114)',
# ...
#   'Week': 16,
#   'Player Name': 'devonta freeman',
#   'Team': 'BAL',
#   'Receiving Yards Projection': 'O 13.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-115)',
#   'Rushing Yards Projection': 'O 43.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+175'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'rex burkhead',
#   'Team': 'HOU',
#   'Rushing Yards Projection': 'O 42.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+180',
#   'Receiving Yards Projection': 'O 16.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'duke johnson',
#   'Team': 'MIA',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(EVEN)',
#   'Receptions Under': '(-130)',
#   'Rushing Yards Projection': 'O 35.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Receiving Yards Projection': 'O 15.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+250'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'craig reynolds',
#   'Team': 'DET',
#   'Anytime Touchdown Line': '+250'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'chuba hubbard',
#   'Team': 'CAR',
#   'Anytime Touchdown Line': '+210',
#   'Rushing Yards Projection': 'O 37.5',
#   'Rushing Yards Over': '(-115)',
#   'Rushing Yards Under': '(-111)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'jonathan taylor',
#   'Team': 'IND',
#   'Receiving Yards Projection': 'O 15.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-120)',
#   'Anytime Touchdown Line': '-250',
#   'Rushing Yards Projection': 'O 110.5',
#   'Rushing Yards Over': '(-115)',
#   'Rushing Yards Under': '(-115)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'nick chubb',
#   'Team': 'CLE',
#   'Receptions Projection': 'O 1.5',
#   'Receptions Over': '(-175)',
#   'Receptions Under': '(+135)',
#   'Receiving Yards Projection': 'O 11.5',
#   'Receiving Yards Over': '(-120)',
#   'Receiving Yards Under': '(-110)',
#   'Rushing Yards Projection': 'O 93.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-115)',
#   'Anytime Touchdown Line': '-135'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'austin ekeler',
#   'Team': 'LAC',
#   'Rushing Yards Projection': 'O 56.5',
#   'Rushing Yards Over': '(-118)',
#   'Rushing Yards Under': '(-111)',
#   'Anytime Touchdown Line': '-150',
#   'Receiving Yards Projection': 'O 27.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'david montgomery',
#   'Team': 'CHI',
#   'Receiving Yards Projection': 'O 24.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-120)',
#   'Receptions Under': '(-111)',
#   'Anytime Touchdown Line': '-115',
#   'Rushing Yards Projection': 'O 70.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-115)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'alvin kamara',
#   'Team': 'NO',
#   'Receiving Yards Projection': 'O 28.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '-125',
#   'Rushing Yards Projection': 'O 62.5',
#   'Rushing Yards Over': '(-115)',
#   'Rushing Yards Under': '(-115)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-150)',
#   'Receptions Under': '(+115)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'dalvin cook',
#   'Team': 'MIN',
#   'Receiving Yards Projection': 'O 15.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+140',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(+110)',
#   'Receptions Under': '(-145)',
#   'Rushing Yards Projection': 'O 80.5',
#   'Rushing Yards Over': '(-115)',
#   'Rushing Yards Under': '(-110)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'joe mixon',
#   'Team': 'CIN',
#   'Receiving Yards Projection': 'O 15.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '-120',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(+110)',
#   'Receptions Under': '(-145)',
#   'Rushing Yards Projection': 'O 71.5',
#   'Rushing Yards Over': '(-115)',
#   'Rushing Yards Under': '(-111)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'najee harris',
#   'Team': 'PIT',
#   'Receiving Yards Projection': 'O 23.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '-120',
#   'Rushing Yards Projection': 'O 74.5',
#   'Rushing Yards Over': '(-111)',
#   'Rushing Yards Under': '(-115)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-143)',
#   'Receptions Under': '(+110)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'ronald jones',
#   'Team': 'TB',
#   'Rushing Yards Projection': 'O 72.5',
#   'Rushing Yards Over': '(-115)',
#   'Rushing Yards Under': '(-115)',
#   'Anytime Touchdown Line': '-139'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'sony michel',
#   'Team': 'LAR',
#   'Receiving Yards Projection': 'O 13.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Rushing Yards Projection': 'O 70.5',
#   'Rushing Yards Over': '(-115)',
#   'Rushing Yards Under': '(-110)',
#   'Anytime Touchdown Line': '-125'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'aaron jones',
#   'Team': 'GB',
#   'Anytime Touchdown Line': '-105',
#   'Rushing Yards Projection': 'O 55.5',
#   'Rushing Yards Over': '(-115)',
#   'Rushing Yards Under': '(-111)',
#   'Receiving Yards Projection': 'O 17.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-140)',
#   'Receptions Under': '(+105)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'josh jacobs',
#   'Team': 'LV',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+110)',
#   'Receptions Under': '(-143)',
#   'Anytime Touchdown Line': '+120',
#   'Rushing Yards Projection': 'O 53.5',
#   'Rushing Yards Over': '(-115)',
#   'Rushing Yards Under': '(-115)',
#   'Receiving Yards Projection': 'O 21.5',
#   'Receiving Yards Over': '(-111)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'ezekiel elliott',
#   'Team': 'DAL',
#   'Rushing Yards Projection': 'O 54.5',
#   'Rushing Yards Over': '(-115)',
#   'Rushing Yards Under': '(-115)',
#   'Receiving Yards Projection': 'O 15.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '-120'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'darrel williams',
#   'Team': 'KC',
#   'Rushing Yards Projection': 'O 49.5',
#   'Rushing Yards Over': '(-115)',
#   'Rushing Yards Under': '(-118)',
#   'Anytime Touchdown Line': '+125',
#   'Receiving Yards Projection': 'O 26.5',
#   'Receiving Yards Over': '(-111)',
#   'Receiving Yards Under': '(-120)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'dandre swift',
#   'Team': 'DET',
#   'Receiving Yards Projection': 'O 29.5',
#   'Receiving Yards Over': '(-111)',
#   'Receiving Yards Under': '(-118)',
#   'Anytime Touchdown Line': '+115',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-180)',
#   'Receptions Under': '(+120)',
#   'Rushing Yards Projection': 'O 50.5',
#   'Rushing Yards Over': '(-105)',
#   'Rushing Yards Under': '(-122)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'damien harris',
#   'Team': 'NE',
#   'Anytime Touchdown Line': '-135'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'rashaad penny',
#   'Team': 'SEA',
#   'Anytime Touchdown Line': '+110',
#   'Rushing Yards Projection': 'O 61.5',
#   'Rushing Yards Over': '(-115)',
#   'Rushing Yards Under': '(-115)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'devin singletary',
#   'Team': 'BUF',
#   'Receiving Yards Projection': 'O 17.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-120)',
#   'Rushing Yards Projection': 'O 57.5',
#   'Rushing Yards Over': '(-111)',
#   'Rushing Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+115',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-115)',
#   'Receptions Under': '(-115)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'elijah mitchell',
#   'Team': 'SF',
#   'Receptions Projection': '--',
#   'Receptions Over': '--',
#   'Receptions Under': '--',
#   'Rushing Yards Projection': '--',
#   'Rushing Yards Over': '--',
#   'Rushing Yards Under': '--',
#   'Receiving Yards Projection': '--',
#   'Receiving Yards Over': '--',
#   'Receiving Yards Under': '--'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'javonte williams',
#   'Team': 'DEN',
#   'Rushing Yards Projection': 'O 57.5',
#   'Rushing Yards Over': '(-115)',
#   'Rushing Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+125',
#   'Receiving Yards Projection': 'O 14.5',
#   'Receiving Yards Over': '(-111)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'chase edmonds',
#   'Team': 'ARI',
#   'Rushing Yards Projection': 'O 56.5',
#   'Rushing Yards Over': '(-115)',
#   'Rushing Yards Under': '(-115)',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+115)',
#   'Receptions Under': '(-150)',
#   'Receiving Yards Projection': 'O 28.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+110'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'saquon barkley',
#   'Team': 'NYG',
#   'Rushing Yards Projection': 'O 52.5',
#   'Rushing Yards Over': '(-115)',
#   'Rushing Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+163',
#   'Receiving Yards Projection': 'O 17.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-111)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'cordarrelle patterson',
#   'Team': 'ATL',
#   'Rushing Yards Projection': 'O 40.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-118)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-165)',
#   'Receptions Under': '(+125)',
#   'Anytime Touchdown Line': '+130',
#   'Receiving Yards Projection': 'O 19.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'michael carter',
#   'Team': 'NYJ',
#   'Receiving Yards Projection': 'O 18.5',
#   'Receiving Yards Over': '(-120)',
#   'Receiving Yards Under': '(-109)',
#   'Rushing Yards Projection': 'O 43.5',
#   'Rushing Yards Over': '(-115)',
#   'Rushing Yards Under': '(-114)',
#   'Anytime Touchdown Line': '+160'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'donta foreman',
#   'Team': 'TEN',
#   'Anytime Touchdown Line': '+140',
#   'Rushing Yards Projection': 'O 45.5',
#   'Rushing Yards Over': '(-115)',
#   'Rushing Yards Under': '(-115)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'jaret patterson',
#   'Team': 'WAS',
#   'Anytime Touchdown Line': 'EVEN',
#   'Rushing Yards Projection': 'O 49.5',
#   'Rushing Yards Over': '(-115)',
#   'Rushing Yards Under': '(-110)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'dare ogunbowale',
#   'Team': 'JAX',
#   'Receiving Yards Projection': 'O 17.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Rushing Yards Projection': 'O 38.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+200'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'boston scott',
#   'Team': 'PHI',
#   'Anytime Touchdown Line': '+130',
#   'Rushing Yards Projection': 'O 41.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-115)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'rex burkhead',
#   'Team': 'HOU',
#   'Anytime Touchdown Line': '+190',
#   'Rushing Yards Projection': 'O 44.5',
#   'Rushing Yards Over': '(-115)',
#   'Rushing Yards Under': '(-115)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'devonta freeman',
#   'Team': 'BAL',
#   'Anytime Touchdown Line': '+175',
#   'Rushing Yards Projection': 'O 39.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-115)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'duke johnson',
#   'Team': 'MIA',
#   'Rushing Yards Projection': 'O 32.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+250'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'chuba hubbard',
#   'Team': 'CAR',
#   'Receiving Yards Projection': 'O 7.5',
#   'Receiving Yards Over': '(-102)',
#   'Receiving Yards Under': '(-125)',
#   'Anytime Touchdown Line': '+225',
#   'Rushing Yards Projection': 'O 37.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-115)'},
#  {'Year': 2022,
#   'Week': 1,
#   'Player Name': 'jonathan taylor',
#   'Team': 'IND',
#   'Anytime Touchdown Line': '-220',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(+140)',
#   'Receptions Under': '(-200)',
#   'Rushing Yards Projection': 'O 96.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Receiving Yards Projection': 'O 14.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-125)'},
#  {'Year': 2022,
#   'Week': 1,
#   'Player Name': 'christian mccaffrey',
#   'Team': 'CAR',
#   'Anytime Touchdown Line': '-150',
#   'Receiving Yards Projection': 'O 45.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(+110)',
#   'Receptions Under': '(-166)',
#   'Rushing Yards Projection': 'O 66.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)'},
#  {'Year': 2022,
#   'Week': 1,
#   'Player Name': 'derrick henry',
#   'Team': 'TEN',
#   'Receptions Projection': 'O 1.5',
#   'Receptions Over': '(-128)',
#   'Receptions Under': '(EVEN)',
#   'Anytime Touchdown Line': '-250',
#   'Receiving Yards Projection': 'O 10.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Rushing Yards Projection': 'O 96.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)'},
#  {'Year': 2022,
#   'Week': 1,
#   'Player Name': 'austin ekeler',
#   'Team': 'LAC',
#   'Anytime Touchdown Line': '-225',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-105)',
#   'Receptions Under': '(-125)',
#   'Rushing Yards Projection': 'O 60.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Receiving Yards Projection': 'O 35.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2022,
#   'Week': 1,
#   'Player Name': 'dalvin cook',
#   'Team': 'MIN',
#   'Rushing Yards Projection': 'O 71.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-185)',
#   'Receptions Under': '(+128)',
#   'Receiving Yards Projection': 'O 18.5',
#   'Receiving Yards Over': '(-114)',
#   'Receiving Yards Under': '(-114)',
#   'Anytime Touchdown Line': '-115'},
#  {'Year': 2022,
#   'Week': 1,
#   'Player Name': 'alvin kamara',
#   'Team': 'NO',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+112)',
#   'Receptions Under': '(-148)',
#   'Anytime Touchdown Line': '-130',
#   'Receiving Yards Projection': 'O 26.5',
#   'Receiving Yards Over': '(-118)',
#   'Receiving Yards Under': '(-115)',
#   'Rushing Yards Projection': 'O 60.5',
#   'Rushing Yards Over': '(-114)',
#   'Rushing Yards Under': '(-114)'},
#  {'Year': 2022,
#   'Week': 1,
#   'Player Name': 'joe mixon',
#   'Team': 'CIN',
#   'Rushing Yards Projection': 'O 71.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Receiving Yards Projection': 'O 15.5',
#   'Receiving Yards Over': '(-114)',
#   'Receiving Yards Under': '(-114)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-145)',
#   'Receptions Under': '(+105)',
#   'Anytime Touchdown Line': '-190'},
#  {'Year': 2022,
#   'Week': 1,
#   'Player Name': 'najee harris',
#   'Team': 'PIT',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(EVEN)',
#   'Receptions Under': '(-125)',
#   'Rushing Yards Projection': 'O 58.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+145',
#   'Receiving Yards Projection': 'O 22.5',
#   'Receiving Yards Over': '(-114)',
#   'Receiving Yards Under': '(-114)'},
#  ...]

# %%
import pandas as pd

df = pd.json_normalize(d)

df
# Out:
#       Year  Week          Player Name Team Anytime Touchdown Line  \
# 0     2020     1  christian mccaffrey  CAR                   -188
# 1     2020     1      ezekiel elliott  DAL                   -163
# 2     2020     1          dalvin cook  MIN                   -138
# 3     2020     1          josh jacobs   LV                   -155
# 4     2020     1       saquon barkley  NYG                   -110
# ...    ...   ...                  ...  ...                    ...
# 2011  2023    17        jaylen warren  PIT                   +210
# 2012  2023    17          jerome ford  CLE                   +160
# 2013  2023    17          gus edwards  BAL                   EVEN
# 2014  2023    17       khalil herbert  CHI                   +175
# 2015  2023    17       brian robinson  WAS                   +205
#
#      Receiving Yards Projection Receiving Yards Over Receiving Yards Under  \
# 0                        O 51.5               (-105)                (-115)
# 1                        O 29.5               (-110)                (-110)
# 2                        O 28.5               (-110)                (-110)
# 3                        O 16.5               (-115)                (-105)
# 4                        O 33.5               (-110)                (-110)
# ...                         ...                  ...                   ...
# 2011                     O 25.5               (-115)                (-115)
# 2012                     O 19.5               (-120)                (-110)
# 2013                      O 7.5               (-110)                (-115)
# 2014                      O 7.5               (-110)                (-110)
# 2015                     O 10.5               (-113)                (-110)
#
#      Receptions Projection Receptions Over Receptions Under  \
# 0                    O 6.5          (-130)           (+110)
# 1                    O 3.5          (-152)           (+120)
# 2                    O 3.5          (-130)           (+110)
# 3                    O 2.5          (EVEN)           (-120)
# 4                    O 3.5          (-134)           (-170)
# ...                    ...             ...              ...
# 2011                 O 3.5          (-125)           (-105)
# 2012                 O 3.5          (+133)           (-180)
# 2013                 O 1.5          (+150)           (-200)
# 2014                 O 1.5          (EVEN)           (-131)
# 2015                 O 1.5          (-175)           (+130)
#
#      Rushing Yards Projection Rushing Yards Over Rushing Yards Under
# 0                      O 73.5             (-122)              (-110)
# 1                      O 81.5             (-115)              (EVEN)
# 2                      O 74.5             (-110)              (-110)
# 3                      O 79.5             (-110)              (-110)
# 4                      O 72.5             (-110)              (-110)
# ...                       ...                ...                 ...
# 2011                   O 36.5             (-115)              (-115)
# 2012                   O 47.5             (-115)              (-115)
# 2013                   O 41.5             (-113)              (-110)
# 2014                   O 49.5             (-115)              (-110)
# 2015                   O 41.5             (-113)              (-115)
#
# [2016 rows x 14 columns]

# %%
for column in ('Rushing Yards Projection', 'Receiving Yards Projection', 'Receptions Projection'):
    df[column] = df[column].str.extract(r'(\d+\.\d+)').astype(float)

df
# Out:
#       Year  Week          Player Name Team Anytime Touchdown Line  \
# 0     2020     1  christian mccaffrey  CAR                   -188
# 1     2020     1      ezekiel elliott  DAL                   -163
# 2     2020     1          dalvin cook  MIN                   -138
# 3     2020     1          josh jacobs   LV                   -155
# 4     2020     1       saquon barkley  NYG                   -110
# ...    ...   ...                  ...  ...                    ...
# 2011  2023    17        jaylen warren  PIT                   +210
# 2012  2023    17          jerome ford  CLE                   +160
# 2013  2023    17          gus edwards  BAL                   EVEN
# 2014  2023    17       khalil herbert  CHI                   +175
# 2015  2023    17       brian robinson  WAS                   +205
#
#       Receiving Yards Projection Receiving Yards Over Receiving Yards Under  \
# 0                           51.5               (-105)                (-115)
# 1                           29.5               (-110)                (-110)
# 2                           28.5               (-110)                (-110)
# 3                           16.5               (-115)                (-105)
# 4                           33.5               (-110)                (-110)
# ...                          ...                  ...                   ...
# 2011                        25.5               (-115)                (-115)
# 2012                        19.5               (-120)                (-110)
# 2013                         7.5               (-110)                (-115)
# 2014                         7.5               (-110)                (-110)
# 2015                        10.5               (-113)                (-110)
#
#       Receptions Projection Receptions Over Receptions Under  \
# 0                       6.5          (-130)           (+110)
# 1                       3.5          (-152)           (+120)
# 2                       3.5          (-130)           (+110)
# 3                       2.5          (EVEN)           (-120)
# 4                       3.5          (-134)           (-170)
# ...                     ...             ...              ...
# 2011                    3.5          (-125)           (-105)
# 2012                    3.5          (+133)           (-180)
# 2013                    1.5          (+150)           (-200)
# 2014                    1.5          (EVEN)           (-131)
# 2015                    1.5          (-175)           (+130)
#
#       Rushing Yards Projection Rushing Yards Over Rushing Yards Under
# 0                         73.5             (-122)              (-110)
# 1                         81.5             (-115)              (EVEN)
# 2                         74.5             (-110)              (-110)
# 3                         79.5             (-110)              (-110)
# 4                         72.5             (-110)              (-110)
# ...                        ...                ...                 ...
# 2011                      36.5             (-115)              (-115)
# 2012                      47.5             (-115)              (-115)
# 2013                      41.5             (-113)              (-110)
# 2014                      49.5             (-115)              (-110)
# 2015                      41.5             (-113)              (-115)
#
# [2016 rows x 14 columns]

# %%
for column in ('Rushing Yards Over', 'Rushing Yards Under', 'Receiving Yards Over', 'Receiving Yards Under', 'Receptions Over', 'Receptions Under'):
    df.loc[df[column].str.contains('EVEN', regex=False, na=False), column] = '100'
    df.loc[df[column] == '--', column] = 'nan'
    df[column] = df[column].str.replace(r'\(|\)', '', regex=True).astype(float)

df
# Out:
#       Year  Week          Player Name Team Anytime Touchdown Line  \
# 0     2020     1  christian mccaffrey  CAR                   -188
# 1     2020     1      ezekiel elliott  DAL                   -163
# 2     2020     1          dalvin cook  MIN                   -138
# 3     2020     1          josh jacobs   LV                   -155
# 4     2020     1       saquon barkley  NYG                   -110
# ...    ...   ...                  ...  ...                    ...
# 2011  2023    17        jaylen warren  PIT                   +210
# 2012  2023    17          jerome ford  CLE                   +160
# 2013  2023    17          gus edwards  BAL                   EVEN
# 2014  2023    17       khalil herbert  CHI                   +175
# 2015  2023    17       brian robinson  WAS                   +205
#
#       Receiving Yards Projection  Receiving Yards Over  Receiving Yards Under  \
# 0                           51.5                -105.0                 -115.0
# 1                           29.5                -110.0                 -110.0
# 2                           28.5                -110.0                 -110.0
# 3                           16.5                -115.0                 -105.0
# 4                           33.5                -110.0                 -110.0
# ...                          ...                   ...                    ...
# 2011                        25.5                -115.0                 -115.0
# 2012                        19.5                -120.0                 -110.0
# 2013                         7.5                -110.0                 -115.0
# 2014                         7.5                -110.0                 -110.0
# 2015                        10.5                -113.0                 -110.0
#
#       Receptions Projection  Receptions Over  Receptions Under  \
# 0                       6.5           -130.0             110.0
# 1                       3.5           -152.0             120.0
# 2                       3.5           -130.0             110.0
# 3                       2.5            100.0            -120.0
# 4                       3.5           -134.0            -170.0
# ...                     ...              ...               ...
# 2011                    3.5           -125.0            -105.0
# 2012                    3.5            133.0            -180.0
# 2013                    1.5            150.0            -200.0
# 2014                    1.5            100.0            -131.0
# 2015                    1.5           -175.0             130.0
#
#       Rushing Yards Projection  Rushing Yards Over  Rushing Yards Under
# 0                         73.5              -122.0               -110.0
# 1                         81.5              -115.0                100.0
# 2                         74.5              -110.0               -110.0
# 3                         79.5              -110.0               -110.0
# 4                         72.5              -110.0               -110.0
# ...                        ...                 ...                  ...
# 2011                      36.5              -115.0               -115.0
# 2012                      47.5              -115.0               -115.0
# 2013                      41.5              -113.0               -110.0
# 2014                      49.5              -115.0               -110.0
# 2015                      41.5              -113.0               -115.0
#
# [2016 rows x 14 columns]

# %%
for column in ('Anytime Touchdown Line', ):
    df.loc[df[column].str.contains('EVEN', regex=False, na=False), column] = '100'
    df.loc[df[column] == '--', column] = 'nan'
    df[column] = df[column].astype(float)

df
# Out:
#       Year  Week          Player Name Team  Anytime Touchdown Line  \
# 0     2020     1  christian mccaffrey  CAR                  -188.0
# 1     2020     1      ezekiel elliott  DAL                  -163.0
# 2     2020     1          dalvin cook  MIN                  -138.0
# 3     2020     1          josh jacobs   LV                  -155.0
# 4     2020     1       saquon barkley  NYG                  -110.0
# ...    ...   ...                  ...  ...                     ...
# 2011  2023    17        jaylen warren  PIT                   210.0
# 2012  2023    17          jerome ford  CLE                   160.0
# 2013  2023    17          gus edwards  BAL                   100.0
# 2014  2023    17       khalil herbert  CHI                   175.0
# 2015  2023    17       brian robinson  WAS                   205.0
#
#       Receiving Yards Projection  Receiving Yards Over  Receiving Yards Under  \
# 0                           51.5                -105.0                 -115.0
# 1                           29.5                -110.0                 -110.0
# 2                           28.5                -110.0                 -110.0
# 3                           16.5                -115.0                 -105.0
# 4                           33.5                -110.0                 -110.0
# ...                          ...                   ...                    ...
# 2011                        25.5                -115.0                 -115.0
# 2012                        19.5                -120.0                 -110.0
# 2013                         7.5                -110.0                 -115.0
# 2014                         7.5                -110.0                 -110.0
# 2015                        10.5                -113.0                 -110.0
#
#       Receptions Projection  Receptions Over  Receptions Under  \
# 0                       6.5           -130.0             110.0
# 1                       3.5           -152.0             120.0
# 2                       3.5           -130.0             110.0
# 3                       2.5            100.0            -120.0
# 4                       3.5           -134.0            -170.0
# ...                     ...              ...               ...
# 2011                    3.5           -125.0            -105.0
# 2012                    3.5            133.0            -180.0
# 2013                    1.5            150.0            -200.0
# 2014                    1.5            100.0            -131.0
# 2015                    1.5           -175.0             130.0
#
#       Rushing Yards Projection  Rushing Yards Over  Rushing Yards Under
# 0                         73.5              -122.0               -110.0
# 1                         81.5              -115.0                100.0
# 2                         74.5              -110.0               -110.0
# 3                         79.5              -110.0               -110.0
# 4                         72.5              -110.0               -110.0
# ...                        ...                 ...                  ...
# 2011                      36.5              -115.0               -115.0
# 2012                      47.5              -115.0               -115.0
# 2013                      41.5              -113.0               -110.0
# 2014                      49.5              -115.0               -110.0
# 2015                      41.5              -113.0               -115.0
#
# [2016 rows x 14 columns]

# %%
def american_odds_to_probability(odds):
    """
    Converts American betting odds to implied probability.
    
    Args:
        odds (int or float): The American odds value (e.g., -150, +200).

    Returns:
        float: The implied probability as a decimal (e.g., 0.60 for 60%).
    """
    if odds > 0:
        # Positive odds: (100 / (odds + 100))
        probability = 100 / (odds + 100)
    else:
        # Negative odds: (-odds / (-odds + 100))
        probability = -odds / (-odds + 100)
    
    return probability

# %% [markdown]
# Adjust projections based on over/under lines

# %%
for stat in ('Rushing Yards', 'Receiving Yards', 'Receptions'):
    df[f'Adjusted {stat} Projection'] = (
        df[f'{stat} Projection'] +
        0.5 * df[f'{stat} Over'].apply(american_odds_to_probability) -
        0.5 * df[f'{stat} Under'].apply(american_odds_to_probability)
    )

df
# Out:
#       Year  Week          Player Name Team  Anytime Touchdown Line  \
# 0     2020     1  christian mccaffrey  CAR                  -188.0
# 1     2020     1      ezekiel elliott  DAL                  -163.0
# 2     2020     1          dalvin cook  MIN                  -138.0
# 3     2020     1          josh jacobs   LV                  -155.0
# 4     2020     1       saquon barkley  NYG                  -110.0
# ...    ...   ...                  ...  ...                     ...
# 2011  2023    17        jaylen warren  PIT                   210.0
# 2012  2023    17          jerome ford  CLE                   160.0
# 2013  2023    17          gus edwards  BAL                   100.0
# 2014  2023    17       khalil herbert  CHI                   175.0
# 2015  2023    17       brian robinson  WAS                   205.0
#
#       Receiving Yards Projection  Receiving Yards Over  Receiving Yards Under  \
# 0                           51.5                -105.0                 -115.0
# 1                           29.5                -110.0                 -110.0
# 2                           28.5                -110.0                 -110.0
# 3                           16.5                -115.0                 -105.0
# 4                           33.5                -110.0                 -110.0
# ...                          ...                   ...                    ...
# 2011                        25.5                -115.0                 -115.0
# 2012                        19.5                -120.0                 -110.0
# 2013                         7.5                -110.0                 -115.0
# 2014                         7.5                -110.0                 -110.0
# 2015                        10.5                -113.0                 -110.0
#
#       Receptions Projection  Receptions Over  Receptions Under  \
# 0                       6.5           -130.0             110.0
# 1                       3.5           -152.0             120.0
# 2                       3.5           -130.0             110.0
# 3                       2.5            100.0            -120.0
# 4                       3.5           -134.0            -170.0
# ...                     ...              ...               ...
# 2011                    3.5           -125.0            -105.0
# 2012                    3.5            133.0            -180.0
# 2013                    1.5            150.0            -200.0
# 2014                    1.5            100.0            -131.0
# 2015                    1.5           -175.0             130.0
#
#       Rushing Yards Projection  Rushing Yards Over  Rushing Yards Under  \
# 0                         73.5              -122.0               -110.0
# 1                         81.5              -115.0                100.0
# 2                         74.5              -110.0               -110.0
# 3                         79.5              -110.0               -110.0
# 4                         72.5              -110.0               -110.0
# ...                        ...                 ...                  ...
# 2011                      36.5              -115.0               -115.0
# 2012                      47.5              -115.0               -115.0
# 2013                      41.5              -113.0               -110.0
# 2014                      49.5              -115.0               -110.0
# 2015                      41.5              -113.0               -115.0
#
#       Adjusted Rushing Yards Projection  Adjusted Receiving Yards Projection  \
# 0                             73.512870                            51.488656
# 1                             81.517442                            29.500000
# 2                             74.500000                            28.500000
# 3                             79.500000                            16.511344
# 4                             72.500000                            33.500000
# ...                                 ...                                  ...
# 2011                          36.500000                            25.500000
# 2012                          47.500000                            19.510823
# 2013                          41.503353                             7.494463
# 2014                          49.505537                             7.500000
# 2015                          41.497816                            10.503353
#
#       Adjusted Receptions Projection
# 0                           6.544513
# 1                           3.574315
# 2                           3.544513
# 3                           2.477273
# 4                           3.471510
# ...                              ...
# 2011                        3.521680
# 2012                        3.393164
# 2013                        1.366667
# 2014                        1.466450
# 2015                        1.600791
#
# [2016 rows x 17 columns]

# %%
df['Anytime Touchdown Probability'] = df['Anytime Touchdown Line'].apply(american_odds_to_probability)

df
# Out:
#       Year  Week          Player Name Team  Anytime Touchdown Line  \
# 0     2020     1  christian mccaffrey  CAR                  -188.0
# 1     2020     1      ezekiel elliott  DAL                  -163.0
# 2     2020     1          dalvin cook  MIN                  -138.0
# 3     2020     1          josh jacobs   LV                  -155.0
# 4     2020     1       saquon barkley  NYG                  -110.0
# ...    ...   ...                  ...  ...                     ...
# 2011  2023    17        jaylen warren  PIT                   210.0
# 2012  2023    17          jerome ford  CLE                   160.0
# 2013  2023    17          gus edwards  BAL                   100.0
# 2014  2023    17       khalil herbert  CHI                   175.0
# 2015  2023    17       brian robinson  WAS                   205.0
#
#       Receiving Yards Projection  Receiving Yards Over  Receiving Yards Under  \
# 0                           51.5                -105.0                 -115.0
# 1                           29.5                -110.0                 -110.0
# 2                           28.5                -110.0                 -110.0
# 3                           16.5                -115.0                 -105.0
# 4                           33.5                -110.0                 -110.0
# ...                          ...                   ...                    ...
# 2011                        25.5                -115.0                 -115.0
# 2012                        19.5                -120.0                 -110.0
# 2013                         7.5                -110.0                 -115.0
# 2014                         7.5                -110.0                 -110.0
# 2015                        10.5                -113.0                 -110.0
#
#       Receptions Projection  Receptions Over  Receptions Under  \
# 0                       6.5           -130.0             110.0
# 1                       3.5           -152.0             120.0
# 2                       3.5           -130.0             110.0
# 3                       2.5            100.0            -120.0
# 4                       3.5           -134.0            -170.0
# ...                     ...              ...               ...
# 2011                    3.5           -125.0            -105.0
# 2012                    3.5            133.0            -180.0
# 2013                    1.5            150.0            -200.0
# 2014                    1.5            100.0            -131.0
# 2015                    1.5           -175.0             130.0
#
#       Rushing Yards Projection  Rushing Yards Over  Rushing Yards Under  \
# 0                         73.5              -122.0               -110.0
# 1                         81.5              -115.0                100.0
# 2                         74.5              -110.0               -110.0
# 3                         79.5              -110.0               -110.0
# 4                         72.5              -110.0               -110.0
# ...                        ...                 ...                  ...
# 2011                      36.5              -115.0               -115.0
# 2012                      47.5              -115.0               -115.0
# 2013                      41.5              -113.0               -110.0
# 2014                      49.5              -115.0               -110.0
# 2015                      41.5              -113.0               -115.0
#
#       Adjusted Rushing Yards Projection  Adjusted Receiving Yards Projection  \
# 0                             73.512870                            51.488656
# 1                             81.517442                            29.500000
# 2                             74.500000                            28.500000
# 3                             79.500000                            16.511344
# 4                             72.500000                            33.500000
# ...                                 ...                                  ...
# 2011                          36.500000                            25.500000
# 2012                          47.500000                            19.510823
# 2013                          41.503353                             7.494463
# 2014                          49.505537                             7.500000
# 2015                          41.497816                            10.503353
#
#       Adjusted Receptions Projection  Anytime Touchdown Probability
# 0                           6.544513                       0.652778
# 1                           3.574315                       0.619772
# 2                           3.544513                       0.579832
# 3                           2.477273                       0.607843
# 4                           3.471510                       0.523810
# ...                              ...                            ...
# 2011                        3.521680                       0.322581
# 2012                        3.393164                       0.384615
# 2013                        1.366667                       0.500000
# 2014                        1.466450                       0.363636
# 2015                        1.600791                       0.327869
#
# [2016 rows x 18 columns]

# %%
df.to_parquet(r'..\..\data\betting_lines\rb1_props.parquet')

print('Done')
# Out:
# Done
