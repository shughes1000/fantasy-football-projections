# %% [markdown]
# Find relevant quarterbacks to webscrape

# %%
import pandas as pd

pd.set_option('display.max_columns', 100)

df_superflex_rankings = pd.read_parquet(r'..\..\data\fantasypros_in_season_rankings\superflex_rankings.parquet')

df_superflex_rankings = df_superflex_rankings.loc[df_superflex_rankings['Player Name'].notna(), :].reset_index(drop=True)

# make names easier to match
df_superflex_rankings['Player Name'] = (
    df_superflex_rankings['Player Name']
    .str.split().str[:2].str.join(' ')  # make names just the first two words
    .str.replace(r'[^a-zA-Z0-9\s]', '', regex=True)  # remove non-alphanumeric characters
    .str.lower()  # lowercase only (helps with matching)
)

df_superflex_rankings
# Out:
#        Year  Week   RK      Player Name POS  POS RK
# 0      2018     1    1      todd gurley  RB       1
# 1      2018     1    2    david johnson  RB       2
# 2      2018     1    3     alvin kamara  RB       3
# 3      2018     1    4    melvin gordon  RB       4
# 4      2018     1    5  ezekiel elliott  RB       5
# ...     ...   ...  ...              ...  ..     ...
# 41050  2023    17  461      steven sims  WR     183
# 41051  2023    17  462   jashaun corbin  RB     112
# 41052  2023    17  463     dee eskridge  WR     184
# 41053  2023    17  464     clayton tune  QB      65
# 41054  2023    17  465    brady russell  TE     104
#
# [41055 rows x 6 columns]

# %%
df_qb = df_superflex_rankings.loc[df_superflex_rankings['POS'] == 'QB', :].sort_values(['Year', 'Week', 'POS RK'], ignore_index=True)

df_qb = df_qb.loc[df_qb['Year'] >= 2020, :].reset_index(drop=True)  # for now

df_qb.sort_values(['Year', 'Week', 'POS RK'], ignore_index=True, inplace=True)

df_qb
# Out:
#       Year  Week   RK      Player Name POS  POS RK
# 0     2020     1    1  patrick mahomes  QB       1
# 1     2020     1    2    lamar jackson  QB       2
# 2     2020     1    4     dak prescott  QB       3
# 3     2020     1    5   russell wilson  QB       4
# 4     2020     1    6   deshaun watson  QB       5
# ...    ...   ...  ...              ...  ..     ...
# 3695  2023    17  453   jameis winston  QB      61
# 3696  2023    17  454     jeff driskel  QB      62
# 3697  2023    17  455     brett rypien  QB      63
# 3698  2023    17  456        pj walker  QB      64
# 3699  2023    17  464     clayton tune  QB      65
#
# [3700 rows x 6 columns]

# %% [markdown]
# Filter to relevant players

# %%
df_teams = pd.read_parquet('../../data/fantasy_points/footballguys_half_ppr.parquet')[['Season', 'Week', 'Name', 'Team', 'Position']]

df_teams['Name'] = (
    df_teams['Name'].str.split().str[:2].str.join(' ')  # make names just the first two words
    .str.replace(r'[^a-zA-Z0-9\s]', '', regex=True)  # remove non-alphanumeric characters
    .str.lower()  # lowercase only (helps with matching)
)

df_teams = df_teams.loc[df_teams['Position'] == 'QB', :].reset_index(drop=True)

df_teams
# Out:
#       Season  Week              Name Team Position
# 0       2018     1  ryan fitzpatrick   TB       QB
# 1       2018     1        drew brees   NO       QB
# 2       2018     1   patrick mahomes   KC       QB
# 3       2018     1     philip rivers  LAC       QB
# 4       2018     1     aaron rodgers   GB       QB
# ...      ...   ...               ...  ...      ...
# 3608    2023    17        mike white  MIA       QB
# 3609    2023    17        kyle allen  BUF       QB
# 3610    2023    17       sam darnold   SF       QB
# 3611    2023    17      matt barkley  JAX       QB
# 3612    2023    17    desmond ridder  ATL       QB
#
# [3613 rows x 5 columns]

# %%
df_qb = df_qb.merge(
    df_teams.rename(columns={'Season': 'Year', 'Name': 'Player Name', 'Position': 'POS'}),
    how='left',
    on=['Year', 'Week', 'Player Name', 'POS'],
)

df_qb.loc[(df_qb['Team'].isna()) & (df_qb['POS RK'] <= 25), :]

# 2022 Week 17 Bills at Bengals was cancelled
# 2020 Week 2 Tyrod Taylor got hurt right before the game
# Out:
#     Year  Week  RK   Player Name POS  POS RK Team
# 88  2020     2  38  tyrod taylor  QB      24  NaN

# %% [markdown]
# Fix players with difficult names

# %%
# df_teams.loc[df_teams['Name'] == 'will fuller', 'Name'] = 'william fuller'

# %%
df_qb.loc[(df_qb['Team'].isna()) & (df_qb['POS RK'] <= 32*1), :].groupby(['Player Name'])['POS'].count().sort_values(ascending=False).head(10)
# Out:
# Player Name
# cj beathard          6
# jameis winston       6
# trey lance           6
# mitchell trubisky    5
# jarrett stidham      5
# pj walker            5
# malik willis         4
# bailey zappe         4
# cooper rush          3
# drew lock            3
# Name: POS, dtype: int64

# %%
df_qb = df_qb.loc[df_qb['Team'].notna(), :].reset_index(drop=True)

df_qb
# Out:
#       Year  Week   RK      Player Name POS  POS RK Team
# 0     2020     1    1  patrick mahomes  QB       1   KC
# 1     2020     1    2    lamar jackson  QB       2  BAL
# 2     2020     1    4     dak prescott  QB       3  DAL
# 3     2020     1    5   russell wilson  QB       4  SEA
# 4     2020     1    6   deshaun watson  QB       5  HOU
# ...    ...   ...  ...              ...  ..     ...  ...
# 2310  2023    17  430   desmond ridder  QB      47  ATL
# 2311  2023    17  431    sean clifford  QB      48   GB
# 2312  2023    17  436      davis mills  QB      52  HOU
# 2313  2023    17  450     matt barkley  QB      60  JAX
# 2314  2023    17  464     clayton tune  QB      65  ARI
#
# [2315 rows x 7 columns]

# %%
df_qb = df_qb.groupby(['Year', 'Week', 'Team']).nth(0).reset_index(drop=True)

df_qb
# Out:
#       Year  Week  RK      Player Name POS  POS RK Team
# 0     2020     1   1  patrick mahomes  QB       1   KC
# 1     2020     1   2    lamar jackson  QB       2  BAL
# 2     2020     1   4     dak prescott  QB       3  DAL
# 3     2020     1   5   russell wilson  QB       4  SEA
# 4     2020     1   6   deshaun watson  QB       5  HOU
# ...    ...   ...  ..              ...  ..     ...  ...
# 2000  2023    17  52  taylor heinicke  QB      28  ATL
# 2001  2023    17  54      cj beathard  QB      29  JAX
# 2002  2023    17  59       sam howell  QB      30  WAS
# 2003  2023    17  71     bailey zappe  QB      31   NE
# 2004  2023    17  94   trevor siemian  QB      32  NYJ
#
# [2005 rows x 7 columns]

# %%
df_qb['Player Name URL'] = df_qb['Player Name'].str.replace(' ', '-')

# fix players who are known to have issues
df_qb.loc[df_qb['Player Name'] == 'josh allen', 'Player Name URL'] = 'josh-allen-qb'
df_qb.loc[df_qb['Player Name'] == 'mitchell trubisky', 'Player Name URL'] = 'mitch-trubisky'
df_qb.loc[df_qb['Player Name'] == 'pj walker', 'Player Name URL'] = 'phillip-walker'
df_qb.loc[df_qb['Player Name'] == 'robert griffin', 'Player Name URL'] = 'robert-griffin-iii'
df_qb.loc[df_qb['Player Name'] == 'dorian thompsonrobinson', 'Player Name URL'] = 'dorian-thompson-robinson'

df_qb
# Out:
#       Year  Week  RK      Player Name POS  POS RK Team  Player Name URL
# 0     2020     1   1  patrick mahomes  QB       1   KC  patrick-mahomes
# 1     2020     1   2    lamar jackson  QB       2  BAL    lamar-jackson
# 2     2020     1   4     dak prescott  QB       3  DAL     dak-prescott
# 3     2020     1   5   russell wilson  QB       4  SEA   russell-wilson
# 4     2020     1   6   deshaun watson  QB       5  HOU   deshaun-watson
# ...    ...   ...  ..              ...  ..     ...  ...              ...
# 2000  2023    17  52  taylor heinicke  QB      28  ATL  taylor-heinicke
# 2001  2023    17  54      cj beathard  QB      29  JAX      cj-beathard
# 2002  2023    17  59       sam howell  QB      30  WAS       sam-howell
# 2003  2023    17  71     bailey zappe  QB      31   NE     bailey-zappe
# 2004  2023    17  94   trevor siemian  QB      32  NYJ   trevor-siemian
#
# [2005 rows x 8 columns]

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

options = Options()
# options.add_argument('--headless')

driver = webdriver.Chrome(options=options)

# %%
import time
from selenium.webdriver.common.by import By

def scrape_props(player_name, player_name_url, year, week, team):
    driver.get(url=f"https://www.bettingpros.com/nfl/odds/player-props/{player_name_url}/?season={year}&week={week}")
    time.sleep(5)

    # the page uses lazy loading
    # this loop helps all relevant elements load before scraping
    for _ in range(3):
        # find all loaded rows
        rows = driver.find_elements(
            by=By.CLASS_NAME,
            value="grouped-items-with-sticky-footer__content",
        )

        # scroll to the last loaded row, which should load subsequent rows if there are any
        if len(rows) > 0:
            driver.execute_script(f"window.scrollTo(0, {rows[-1].location['y']});")

        time.sleep(3)

    rows = driver.find_elements(
        by=By.CLASS_NAME,
        value="grouped-items-with-sticky-footer__content",
    )

    if len(rows) == 0:
        print(f"Warning: No rows for {player_name} {year} week {week}")
        
    data = {
        'Year': year,
        'Week': week,
        'Player Name': player_name,
        'Team': team,
    }
    for row in rows:
        t = row.text.split('\n')
        if t[0] == 'Passing Touchdowns Over/Under':
            data['Passing Touchdowns Projection'] = t[-4]
            data['Passing Touchdowns Over'] = t[-3]
            data['Passing Touchdowns Under'] = t[-1]
        elif t[0] == 'Passing Yards Over/Under':
            data['Passing Yards Projection'] = t[-4]
            data['Passing Yards Over'] = t[-3]
            data['Passing Yards Under'] = t[-1]
        elif t[0] == 'Anytime Touchdown Scorer':
            data['Anytime Touchdown Line'] = t[-1]
        elif t[0] == 'Rushing Yards Over/Under':
            data['Rushing Yards Projection'] = t[-4]
            data['Rushing Yards Over'] = t[-3]
            data['Rushing Yards Under'] = t[-1]
        elif t[0] == 'Interceptions Over/Under':
            data['Interceptions Projection'] = t[-4]
            data['Interceptions Over'] = t[-3]
            data['Interceptions Under'] = t[-1]

    return data

# %%
from tqdm.autonotebook import tqdm

d = []
for index, row in tqdm(list(df_qb.iterrows())):
    try:
        d.append(scrape_props(row['Player Name'], row['Player Name URL'], row['Year'], row['Week'], row['Team']))
    except Exception as e:
        print(f"Error with {row['Player Name'], row['Player Name URL'], row['Year'], row['Week'], row['Team']}: {e}")
# Out:
# C:\Users\mhugh\AppData\Local\Temp\ipykernel_7388\2890197602.py:1: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm
#   0%|          | 0/2005 [00:00<?, ?it/s]
# Warning: No rows for trevor lawrence 2023 week 10

# %%
driver.quit()

# %%
d
# Out:
# [{'Year': 2020,
#   'Week': 1,
#   'Player Name': 'patrick mahomes',
#   'Team': 'KC',
#   'Passing Touchdowns Projection': 'O 2.5',
#   'Passing Touchdowns Over': '(+104)',
#   'Passing Touchdowns Under': '(-132)',
#   'Passing Yards Projection': 'O 306.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+300',
#   'Rushing Yards Projection': 'O 20.5',
#   'Rushing Yards Over': '(-105)',
#   'Rushing Yards Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'lamar jackson',
#   'Team': 'BAL',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-152)',
#   'Passing Touchdowns Under': '(-120)',
#   'Passing Yards Projection': 'O 222.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+110',
#   'Rushing Yards Projection': 'O 60.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'dak prescott',
#   'Team': 'DAL',
#   'Passing Touchdowns Projection': 'O 2.5',
#   'Passing Touchdowns Over': '(-175)',
#   'Passing Touchdowns Under': '(-182)',
#   'Passing Yards Projection': 'O 285.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Rushing Yards Projection': 'O 11.5',
#   'Rushing Yards Over': '(-132)',
#   'Rushing Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+333'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'russell wilson',
#   'Team': 'SEA',
#   'Anytime Touchdown Line': '+400',
#   'Rushing Yards Projection': 'O 21.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Passing Yards Projection': 'O 259.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-140)',
#   'Passing Touchdowns Under': '(+120)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'deshaun watson',
#   'Team': 'HOU',
#   'Rushing Yards Projection': 'O 30.5',
#   'Rushing Yards Over': '(-122)',
#   'Rushing Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+190',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-152)',
#   'Passing Touchdowns Under': '(+120)',
#   'Passing Yards Projection': 'O 275.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'drew brees',
#   'Team': 'NO',
#   'Passing Yards Projection': 'O 291.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Passing Touchdowns Projection': 'O 2.5',
#   'Passing Touchdowns Over': '(+145)',
#   'Passing Touchdowns Under': '(-196)',
#   'Anytime Touchdown Line': '+1000'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'matt ryan',
#   'Team': 'ATL',
#   'Anytime Touchdown Line': '+1000',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-200)',
#   'Passing Touchdowns Under': '(+170)',
#   'Passing Yards Projection': 'O 295.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'josh allen',
#   'Team': 'BUF',
#   'Passing Yards Projection': 'O 210.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Rushing Yards Projection': 'O 28.5',
#   'Rushing Yards Over': '(-115)',
#   'Rushing Yards Under': '(-115)',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(+155)',
#   'Passing Touchdowns Under': '(-190)',
#   'Anytime Touchdown Line': '+135'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'carson wentz',
#   'Team': 'PHI',
#   'Passing Yards Projection': 'O 260.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-130)',
#   'Passing Touchdowns Under': '(+110)',
#   'Rushing Yards Projection': 'O 10.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-122)',
#   'Anytime Touchdown Line': '+700'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'kyler murray',
#   'Team': 'ARI',
#   'Passing Yards Projection': 'O 231.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+275',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(+116)',
#   'Passing Touchdowns Under': '(-148)',
#   'Rushing Yards Projection': 'O 26.5',
#   'Rushing Yards Over': '(-132)',
#   'Rushing Yards Under': '(+108)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'ben roethlisberger',
#   'Team': 'PIT',
#   'Passing Yards Projection': 'O 277.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-164)',
#   'Passing Touchdowns Under': '(+128)',
#   'Anytime Touchdown Line': '+1000'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'tom brady',
#   'Team': 'TB',
#   'Passing Yards Projection': 'O 274.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-170)',
#   'Passing Touchdowns Under': '(+128)',
#   'Anytime Touchdown Line': '+1200'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'cam newton',
#   'Team': 'NE',
#   'Passing Yards Projection': 'O 244.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+240',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-130)',
#   'Passing Touchdowns Under': '(+110)',
#   'Rushing Yards Projection': 'O 27.5',
#   'Rushing Yards Over': '(-115)',
#   'Rushing Yards Under': '(-105)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'jared goff',
#   'Team': 'LAR',
#   'Passing Yards Projection': 'O 281.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-122)',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-164)',
#   'Passing Touchdowns Under': '(+128)',
#   'Anytime Touchdown Line': '+800'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'aaron rodgers',
#   'Team': 'GB',
#   'Anytime Touchdown Line': '+800',
#   'Passing Yards Projection': 'O 253.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-105)',
#   'Passing Touchdowns Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'matthew stafford',
#   'Team': 'DET',
#   'Anytime Touchdown Line': '+1100',
#   'Passing Yards Projection': 'O 271.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-145)',
#   'Passing Touchdowns Under': '(+125)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'jimmy garoppolo',
#   'Team': 'SF',
#   'Anytime Touchdown Line': '+700',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-138)',
#   'Passing Touchdowns Under': '(+108)',
#   'Passing Yards Projection': 'O 245.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'gardner minshew',
#   'Team': 'JAX',
#   'Passing Yards Projection': 'O 245.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+650',
#   'Rushing Yards Projection': 'O 17.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(+105)',
#   'Passing Touchdowns Under': '(-125)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'tyrod taylor',
#   'Team': 'LAC',
#   'Rushing Yards Projection': 'O 25.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(+126)',
#   'Passing Touchdowns Under': '(-150)',
#   'Passing Yards Projection': 'O 217.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+340'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'derek carr',
#   'Team': 'LV',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-150)',
#   'Passing Touchdowns Under': '(+130)',
#   'Anytime Touchdown Line': '+900',
#   'Passing Yards Projection': 'O 266.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'philip rivers',
#   'Team': 'IND',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-110)',
#   'Passing Touchdowns Under': '(-110)',
#   'Passing Yards Projection': 'O 235.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+1300'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'teddy bridgewater',
#   'Team': 'CAR',
#   'Anytime Touchdown Line': '+650',
#   'Passing Yards Projection': 'O 256.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-120)',
#   'Passing Touchdowns Under': '(EVEN)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'ryan tannehill',
#   'Team': 'TEN',
#   'Passing Yards Projection': 'O 228.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-115)',
#   'Passing Touchdowns Under': '(-112)',
#   'Anytime Touchdown Line': '+440',
#   'Rushing Yards Projection': 'O 14.5',
#   'Rushing Yards Over': '(-115)',
#   'Rushing Yards Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'kirk cousins',
#   'Team': 'MIN',
#   'Passing Yards Projection': 'O 250.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+1000',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-130)',
#   'Passing Touchdowns Under': '(+110)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'joe burrow',
#   'Team': 'CIN',
#   'Rushing Yards Projection': 'O 14.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(+115)',
#   'Passing Touchdowns Under': '(-154)',
#   'Passing Yards Projection': 'O 243.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+600'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'daniel jones',
#   'Team': 'NYG',
#   'Passing Yards Projection': 'O 237.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(+116)',
#   'Passing Touchdowns Under': '(-148)',
#   'Rushing Yards Projection': 'O 18.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+500'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'mitchell trubisky',
#   'Team': 'CHI',
#   'Anytime Touchdown Line': '+500',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(+110)',
#   'Passing Touchdowns Under': '(-130)',
#   'Rushing Yards Projection': 'O 13.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Passing Yards Projection': 'O 241.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'baker mayfield',
#   'Team': 'CLE',
#   'Rushing Yards Projection': 'O 5.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(+115)',
#   'Passing Touchdowns Under': '(-154)',
#   'Anytime Touchdown Line': '+750',
#   'Passing Yards Projection': 'O 245.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'drew lock',
#   'Team': 'DEN',
#   'Passing Yards Projection': 'O 228.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+1000',
#   'Rushing Yards Projection': 'O 15.5',
#   'Rushing Yards Over': '(-105)',
#   'Rushing Yards Under': '(-115)',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(+105)',
#   'Passing Touchdowns Under': '(-136)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'ryan fitzpatrick',
#   'Team': 'MIA',
#   'Rushing Yards Projection': 'O 14.5',
#   'Rushing Yards Over': '(-105)',
#   'Rushing Yards Under': '(-115)',
#   'Passing Yards Projection': 'O 239.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(+125)',
#   'Passing Touchdowns Under': '(-145)',
#   'Anytime Touchdown Line': '+700'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'dwayne haskins',
#   'Team': 'WAS',
#   'Passing Yards Projection': 'O 222.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+800',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(+144)',
#   'Passing Touchdowns Under': '(-182)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'sam darnold',
#   'Team': 'NYJ',
#   'Rushing Yards Projection': 'O 4.5',
#   'Rushing Yards Over': '(-120)',
#   'Rushing Yards Under': '(-110)',
#   'Passing Yards Projection': 'O 218.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+900',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(+140)',
#   'Passing Touchdowns Under': '(-170)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'lamar jackson',
#   'Team': 'BAL',
#   'Rushing Yards Projection': '--',
#   'Rushing Yards Over': '--',
#   'Rushing Yards Under': '--',
#   'Passing Yards Projection': '--',
#   'Passing Yards Over': '--',
#   'Passing Yards Under': '--'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'patrick mahomes',
#   'Team': 'KC',
#   'Anytime Touchdown Line': '+400',
#   'Passing Yards Projection': 'O 283.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Passing Touchdowns Projection': 'O 2.5',
#   'Passing Touchdowns Over': '(+144)',
#   'Passing Touchdowns Under': '(-200)',
#   'Interceptions Projection': 'NL',
#   'Interceptions Over': 'NL',
#   'Interceptions Under': '(-160)',
#   'Rushing Yards Projection': 'O 14.5',
#   'Rushing Yards Over': '(-114)',
#   'Rushing Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'dak prescott',
#   'Team': 'DAL',
#   'Rushing Yards Projection': 'O 15.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-118)',
#   'Anytime Touchdown Line': '+300',
#   'Interceptions Projection': 'NL',
#   'Interceptions Over': 'NL',
#   'Interceptions Under': '(-128)',
#   'Passing Yards Projection': 'O 296.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Passing Touchdowns Projection': 'O 2.5',
#   'Passing Touchdowns Over': '(-200)',
#   'Passing Touchdowns Under': '(-190)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'josh allen',
#   'Team': 'BUF',
#   'Rushing Yards Projection': 'O 36.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Interceptions Projection': 'NL',
#   'Interceptions Over': 'NL',
#   'Interceptions Under': '(-136)',
#   'Anytime Touchdown Line': '+138',
#   'Passing Yards Projection': 'O 225.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(+102)',
#   'Passing Touchdowns Under': '(-130)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'kyler murray',
#   'Team': 'ARI',
#   'Passing Yards Projection': 'O 258.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Rushing Yards Projection': 'O 30.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+175',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-145)',
#   'Passing Touchdowns Under': '(+125)',
#   'Interceptions Projection': 'NL',
#   'Interceptions Over': 'NL',
#   'Interceptions Under': '(-130)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'russell wilson',
#   'Team': 'SEA',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-140)',
#   'Passing Touchdowns Under': '(+110)',
#   'Passing Yards Projection': 'O 239.5',
#   'Passing Yards Over': '(-105)',
#   'Passing Yards Under': '(-115)',
#   'Rushing Yards Projection': 'O 22.5',
#   'Rushing Yards Over': '(-128)',
#   'Rushing Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+400',
#   'Interceptions Projection': 'NL',
#   'Interceptions Over': 'NL',
#   'Interceptions Under': '(-190)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'matt ryan',
#   'Team': 'ATL',
#   'Interceptions Projection': 'NL',
#   'Interceptions Over': 'NL',
#   'Interceptions Under': '(-112)',
#   'Anytime Touchdown Line': '+1000',
#   'Passing Touchdowns Projection': 'O 2.5',
#   'Passing Touchdowns Over': '(+150)',
#   'Passing Touchdowns Under': '(-190)',
#   'Passing Yards Projection': 'O 309.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'aaron rodgers',
#   'Team': 'GB',
#   'Rushing Yards Projection': 'O 7.5',
#   'Rushing Yards Over': '(-115)',
#   'Rushing Yards Under': '(-105)',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-145)',
#   'Passing Touchdowns Under': '(+125)',
#   'Anytime Touchdown Line': '+600',
#   'Passing Yards Projection': 'O 270.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Interceptions Projection': 'NL',
#   'Interceptions Over': 'NL',
#   'Interceptions Under': '(-260)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'deshaun watson',
#   'Team': 'HOU',
#   'Interceptions Projection': 'NL',
#   'Interceptions Over': 'NL',
#   'Interceptions Under': '(-124)',
#   'Rushing Yards Projection': 'O 30.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+225',
#   'Passing Yards Projection': 'O 250.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-142)',
#   'Passing Touchdowns Under': '(+112)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'tom brady',
#   'Team': 'TB',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-152)',
#   'Passing Touchdowns Under': '(+120)',
#   'Anytime Touchdown Line': '+700',
#   'Interceptions Projection': 'NL',
#   'Interceptions Over': 'NL',
#   'Interceptions Under': '(-118)',
#   'Passing Yards Projection': 'O 276.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'cam newton',
#   'Team': 'NE',
#   'Rushing Yards Projection': '--',
#   'Rushing Yards Over': '--',
#   'Rushing Yards Under': '--',
#   'Passing Yards Projection': '--',
#   'Passing Yards Over': '--',
#   'Passing Yards Under': '--',
#   'Anytime Touchdown Line': '--'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'drew brees',
#   'Team': 'NO',
#   'Anytime Touchdown Line': '+950',
#   'Passing Touchdowns Projection': 'O 2.5',
#   'Passing Touchdowns Over': '(+150)',
#   'Passing Touchdowns Under': '(-180)',
#   'Passing Yards Projection': 'O 265.5',
#   'Passing Yards Over': '(-111)',
#   'Passing Yards Under': '(-111)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'ben roethlisberger',
#   'Team': 'PIT',
#   'Interceptions Projection': 'NL',
#   'Interceptions Over': 'NL',
#   'Interceptions Under': '(-108)',
#   'Passing Yards Projection': 'O 253.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+1100',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-152)',
#   'Passing Touchdowns Under': '(EVEN)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'matthew stafford',
#   'Team': 'DET',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-120)',
#   'Passing Touchdowns Under': '(-110)',
#   'Anytime Touchdown Line': '+1200',
#   'Rushing Yards Projection': 'O 6.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Passing Yards Projection': 'O 272.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Interceptions Projection': 'NL',
#   'Interceptions Over': 'NL',
#   'Interceptions Under': '(+152)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'carson wentz',
#   'Team': 'PHI',
#   'Rushing Yards Projection': 'O 9.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+700',
#   'Interceptions Projection': 'NL',
#   'Interceptions Over': 'NL',
#   'Interceptions Under': '(-102)',
#   'Passing Yards Projection': 'O 264.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-126)',
#   'Passing Touchdowns Under': '(-120)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'jared goff',
#   'Team': 'LAR',
#   'Anytime Touchdown Line': '+700',
#   'Passing Yards Projection': 'O 272.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-158)',
#   'Passing Touchdowns Under': '(+120)',
#   'Interceptions Projection': 'NL',
#   'Interceptions Over': 'NL',
#   'Interceptions Under': '(+128)',
#   'Rushing Yards Projection': 'O 4.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'ryan tannehill',
#   'Team': 'TEN',
#   'Passing Yards Projection': 'O 224.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Rushing Yards Projection': 'O 16.5',
#   'Rushing Yards Over': '(-115)',
#   'Rushing Yards Under': '(-115)',
#   'Interceptions Projection': 'NL',
#   'Interceptions Over': 'NL',
#   'Interceptions Under': '(-160)',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-118)',
#   'Passing Touchdowns Under': '(-108)',
#   'Anytime Touchdown Line': '+400'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'gardner minshew',
#   'Team': 'JAX',
#   'Interceptions Projection': 'NL',
#   'Interceptions Over': 'NL',
#   'Interceptions Under': '(-136)',
#   'Rushing Yards Projection': 'O 19.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+600',
#   'Passing Yards Projection': 'O 238.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(+112)',
#   'Passing Touchdowns Under': '(-145)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'joe burrow',
#   'Team': 'CIN',
#   'Anytime Touchdown Line': '+450',
#   'Passing Yards Projection': 'O 238.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Rushing Yards Projection': 'O 25.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(+112)',
#   'Passing Touchdowns Under': '(-150)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'jimmy garoppolo',
#   'Team': 'SF',
#   'Passing Yards Projection': 'O 221.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Interceptions Projection': 'NL',
#   'Interceptions Over': 'NL',
#   'Interceptions Under': '(-158)',
#   'Anytime Touchdown Line': '+800',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-104)',
#   'Passing Touchdowns Under': '(-125)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'philip rivers',
#   'Team': 'IND',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-152)',
#   'Passing Touchdowns Under': '(+120)',
#   'Interceptions Projection': 'NL',
#   'Interceptions Over': 'NL',
#   'Interceptions Under': '(+132)',
#   'Passing Yards Projection': 'O 261.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+1400'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'kirk cousins',
#   'Team': 'MIN',
#   'Anytime Touchdown Line': '+800',
#   'Interceptions Projection': 'NL',
#   'Interceptions Over': 'NL',
#   'Interceptions Under': '(-205)',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-140)',
#   'Passing Touchdowns Under': '(+112)',
#   'Passing Yards Projection': 'O 242.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'mitchell trubisky',
#   'Team': 'CHI',
#   'Interceptions Projection': 'NL',
#   'Interceptions Over': 'NL',
#   'Interceptions Under': '(-112)',
#   'Passing Yards Projection': 'O 241.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+500',
#   'Rushing Yards Projection': 'O 19.5',
#   'Rushing Yards Over': '(-115)',
#   'Rushing Yards Under': '(-115)',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-108)',
#   'Passing Touchdowns Under': '(-105)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'baker mayfield',
#   'Team': 'CLE',
#   'Passing Yards Projection': 'O 235.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+550',
#   'Rushing Yards Projection': 'O 5.5',
#   'Rushing Yards Over': '(-135)',
#   'Rushing Yards Under': '(+115)',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-108)',
#   'Passing Touchdowns Under': '(-120)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'teddy bridgewater',
#   'Team': 'CAR',
#   'Passing Yards Projection': 'O 256.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-110)',
#   'Passing Touchdowns Under': '(-128)',
#   'Interceptions Projection': 'NL',
#   'Interceptions Over': 'NL',
#   'Interceptions Under': '(+106)',
#   'Rushing Yards Projection': 'O 11.5',
#   'Rushing Yards Over': '(-105)',
#   'Rushing Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+800'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'daniel jones',
#   'Team': 'NYG',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(+110)',
#   'Passing Touchdowns Under': '(-130)',
#   'Passing Yards Projection': 'O 241.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+600',
#   'Rushing Yards Projection': 'O 17.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Interceptions Projection': 'NL',
#   'Interceptions Over': 'NL',
#   'Interceptions Under': '(+154)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'derek carr',
#   'Team': 'LV',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-140)',
#   'Passing Touchdowns Under': '(+120)',
#   'Anytime Touchdown Line': '+900',
#   'Passing Yards Projection': 'O 260.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-111)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'dwayne haskins',
#   'Team': 'WAS',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(+148)',
#   'Passing Touchdowns Under': '(-190)',
#   'Anytime Touchdown Line': '+800',
#   'Rushing Yards Projection': 'O 13.5',
#   'Rushing Yards Over': '(-128)',
#   'Rushing Yards Under': '(+104)',
#   'Passing Yards Projection': 'O 224.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Interceptions Projection': 'NL',
#   'Interceptions Over': 'NL',
#   'Interceptions Under': '(+170)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'drew lock',
#   'Team': 'DEN',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(+145)',
#   'Passing Touchdowns Under': '(-200)',
#   'Rushing Yards Projection': 'O 11.5',
#   'Rushing Yards Over': '(-115)',
#   'Rushing Yards Under': '(-105)',
#   'Passing Yards Projection': 'O 219.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Interceptions Projection': 'NL',
#   'Interceptions Over': 'NL',
#   'Interceptions Under': '(+142)',
#   'Anytime Touchdown Line': '+1000'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'ryan fitzpatrick',
#   'Team': 'MIA',
#   'Interceptions Projection': 'NL',
#   'Interceptions Over': 'NL',
#   'Interceptions Under': '(+164)',
#   'Rushing Yards Projection': 'O 16.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(+130)',
#   'Passing Touchdowns Under': '(-170)',
#   'Anytime Touchdown Line': '+700',
#   'Passing Yards Projection': 'O 217.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'sam darnold',
#   'Team': 'NYJ',
#   'Interceptions Projection': 'NL',
#   'Interceptions Over': 'NL',
#   'Interceptions Under': '(+150)',
#   'Passing Yards Projection': 'O 220.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-122)',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(+174)',
#   'Passing Touchdowns Under': '(-210)',
#   'Anytime Touchdown Line': '+900'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'justin herbert',
#   'Team': 'LAC',
#   'Anytime Touchdown Line': '--',
#   'Passing Touchdowns Projection': '--',
#   'Passing Touchdowns Over': '--',
#   'Passing Touchdowns Under': '--',
#   'Interceptions Projection': '--',
#   'Interceptions Over': '--',
#   'Interceptions Under': '--',
#   'Passing Yards Projection': '--',
#   'Passing Yards Over': '--',
#   'Passing Yards Under': '--'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'lamar jackson',
#   'Team': 'BAL',
#   'Rushing Yards Projection': 'O 64.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-111)',
#   'Anytime Touchdown Line': '+110',
#   'Passing Yards Projection': 'O 249.5',
#   'Passing Yards Over': '(-111)',
#   'Passing Yards Under': '(-110)',
#   'Interceptions Projection': '+1.0',
#   'Interceptions Over': '(-184)',
#   'Interceptions Under': '(-167)',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-150)',
#   'Passing Touchdowns Under': '(+120)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'russell wilson',
#   'Team': 'SEA',
#   'Rushing Yards Projection': 'O 26.5',
#   'Rushing Yards Over': '(-112)',
#   'Rushing Yards Under': '(-111)',
#   'Passing Touchdowns Projection': 'O 2.5',
#   'Passing Touchdowns Over': '(-208)',
#   'Passing Touchdowns Under': '(-200)',
#   'Interceptions Projection': '+1.0',
#   'Interceptions Over': '(-194)',
#   'Interceptions Under': '(-208)',
#   'Anytime Touchdown Line': '+320',
#   'Passing Yards Projection': 'O 290.5',
#   'Passing Yards Over': '(-111)',
#   'Passing Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'kyler murray',
#   'Team': 'ARI',
#   'Rushing Yards Projection': 'O 41.5',
#   'Rushing Yards Over': '(-115)',
#   'Rushing Yards Under': '(-105)',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-180)',
#   'Passing Touchdowns Under': '(+150)',
#   'Anytime Touchdown Line': '+150',
#   'Interceptions Projection': '+1.0',
#   'Interceptions Over': '(-130)',
#   'Interceptions Under': '(-133)',
#   'Passing Yards Projection': 'O 283.5',
#   'Passing Yards Over': '(-111)',
#   'Passing Yards Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'dak prescott',
#   'Team': 'DAL',
#   'Rushing Yards Projection': 'O 18.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Interceptions Projection': '+1.0',
#   'Interceptions Over': '(+114)',
#   'Interceptions Under': '(+105)',
#   'Anytime Touchdown Line': '+180',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-167)',
#   'Passing Touchdowns Under': '(+135)',
#   'Passing Yards Projection': 'O 301.5',
#   'Passing Yards Over': '(-111)',
#   'Passing Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'patrick mahomes',
#   'Team': 'KC',
#   'Anytime Touchdown Line': '+350',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-208)',
#   'Passing Touchdowns Under': '(+165)',
#   'Interceptions Projection': '+1.0',
#   'Interceptions Over': '(-113)',
#   'Interceptions Under': '(-125)',
#   'Rushing Yards Projection': 'O 21.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Passing Yards Projection': 'O 296.5',
#   'Passing Yards Over': '(-111)',
#   'Passing Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'cam newton',
#   'Team': 'NE',
#   'Passing Yards Projection': 'O 251.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-115)',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-130)',
#   'Passing Touchdowns Under': '(EVEN)',
#   'Anytime Touchdown Line': '+120',
#   'Rushing Yards Projection': 'O 45.5',
#   'Rushing Yards Over': '(-111)',
#   'Rushing Yards Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'josh allen',
#   'Team': 'BUF',
#   'Interceptions Projection': 'NL',
#   'Interceptions Over': 'NL',
#   'Interceptions Under': '(+130)',
#   'Passing Yards Projection': 'O 258.5',
#   'Passing Yards Over': '(-111)',
#   'Passing Yards Under': '(-115)',
#   'Rushing Yards Projection': 'O 35.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+130',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-140)',
#   'Passing Touchdowns Under': '(+110)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'matt ryan',
#   'Team': 'ATL',
#   'Anytime Touchdown Line': '+1100',
#   'Passing Yards Projection': 'O 277.5',
#   'Passing Yards Over': '(-115)',
#   'Passing Yards Under': '(-115)',
#   'Rushing Yards Projection': 'O 6.5',
#   'Rushing Yards Over': '(-115)',
#   'Rushing Yards Under': '(-115)',
#   'Interceptions Projection': 'NL',
#   'Interceptions Over': 'NL',
#   'Interceptions Under': '(-113)',
#   'Passing Touchdowns Projection': 'O 2.5',
#   'Passing Touchdowns Over': '(-170)',
#   'Passing Touchdowns Under': '(+140)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'ben roethlisberger',
#   'Team': 'PIT',
#   'Anytime Touchdown Line': '+1300',
#   'Passing Yards Projection': 'O 266.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-111)',
#   'Rushing Yards Projection': 'O 4.5',
#   'Rushing Yards Over': '(-105)',
#   'Rushing Yards Under': '(-125)',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-154)',
#   'Passing Touchdowns Under': '(+125)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'gardner minshew',
#   'Team': 'JAX',
#   'Anytime Touchdown Line': '+360',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-170)',
#   'Passing Touchdowns Under': '(+140)',
#   'Passing Yards Projection': 'O 262.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Rushing Yards Projection': 'O 18.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Interceptions Projection': '+1.0',
#   'Interceptions Over': '(-138)',
#   'Interceptions Under': '(-125)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'aaron rodgers',
#   'Team': 'GB',
#   'Anytime Touchdown Line': '+600',
#   'Passing Yards Projection': 'O 253.5',
#   'Passing Yards Over': '(-111)',
#   'Passing Yards Under': '(-110)',
#   'Interceptions Projection': '+1.0',
#   'Interceptions Over': '(-260)',
#   'Interceptions Under': '(-250)',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-136)',
#   'Passing Touchdowns Under': '(+106)',
#   'Rushing Yards Projection': 'O 9.5',
#   'Rushing Yards Over': '(-115)',
#   'Rushing Yards Under': '(-105)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'deshaun watson',
#   'Team': 'HOU',
#   'Anytime Touchdown Line': '+187',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-115)',
#   'Passing Touchdowns Under': '(-113)',
#   'Passing Yards Projection': 'O 267.5',
#   'Passing Yards Over': '(-111)',
#   'Passing Yards Under': '(-110)',
#   'Rushing Yards Projection': 'O 24.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-111)',
#   'Interceptions Projection': '+1.0',
#   'Interceptions Over': '(EVEN)',
#   'Interceptions Under': '(EVEN)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'matthew stafford',
#   'Team': 'DET',
#   'Rushing Yards Projection': 'O 7.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-120)',
#   'Anytime Touchdown Line': '+1100',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-139)',
#   'Passing Touchdowns Under': '(+115)',
#   'Passing Yards Projection': 'O 282.5',
#   'Passing Yards Over': '(-111)',
#   'Passing Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'carson wentz',
#   'Team': 'PHI',
#   'Passing Yards Projection': 'O 270.5',
#   'Passing Yards Over': '(-111)',
#   'Passing Yards Under': '(-110)',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-143)',
#   'Passing Touchdowns Under': '(+115)',
#   'Rushing Yards Projection': 'O 9.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+450',
#   'Interceptions Projection': 'NL',
#   'Interceptions Over': 'NL',
#   'Interceptions Under': '(-130)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'ryan tannehill',
#   'Team': 'TEN',
#   'Passing Yards Projection': 'O 242.5',
#   'Passing Yards Over': '(-111)',
#   'Passing Yards Under': '(-115)',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-170)',
#   'Passing Touchdowns Under': '(+140)',
#   'Anytime Touchdown Line': '+500',
#   'Rushing Yards Projection': 'O 13.5',
#   'Rushing Yards Over': '(-120)',
#   'Rushing Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'drew brees',
#   'Team': 'NO',
#   'Anytime Touchdown Line': '+850',
#   'Passing Yards Projection': 'O 273.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Passing Touchdowns Projection': 'O 2.5',
#   'Passing Touchdowns Over': '(+160)',
#   'Passing Touchdowns Under': '(-200)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'joe burrow',
#   'Team': 'CIN',
#   'Rushing Yards Projection': 'O 23.5',
#   'Rushing Yards Over': '(-115)',
#   'Rushing Yards Under': '(-110)',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(+105)',
#   'Passing Touchdowns Under': '(-128)',
#   'Interceptions Projection': '+1.0',
#   'Interceptions Over': '(+140)',
#   'Interceptions Under': '(+120)',
#   'Passing Yards Projection': 'O 261.5',
#   'Passing Yards Over': '(-111)',
#   'Passing Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+375'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'tom brady',
#   'Team': 'TB',
#   'Interceptions Projection': '+1.0',
#   'Interceptions Over': '(-146)',
#   'Interceptions Under': '(-161)',
#   'Passing Yards Projection': 'O 252.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-111)',
#   'Anytime Touchdown Line': '+700',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-120)',
#   'Passing Touchdowns Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'mitchell trubisky',
#   'Team': 'CHI',
#   'Anytime Touchdown Line': '+500',
#   'Passing Yards Projection': 'O 253.5',
#   'Passing Yards Over': '(-111)',
#   'Passing Yards Under': '(-111)',
#   'Rushing Yards Projection': 'O 17.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-125)',
#   'Passing Touchdowns Under': '(+105)',
#   'Interceptions Projection': 'NL',
#   'Interceptions Over': 'NL',
#   'Interceptions Under': '(+130)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'ryan fitzpatrick',
#   'Team': 'MIA',
#   'Anytime Touchdown Line': '+500',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-136)',
#   'Passing Touchdowns Under': '(+106)',
#   'Passing Yards Projection': 'O 274.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Rushing Yards Projection': 'O 14.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'philip rivers',
#   'Team': 'IND',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-140)',
#   'Passing Touchdowns Under': '(+110)',
#   'Anytime Touchdown Line': '+1100',
#   'Passing Yards Projection': 'O 235.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-111)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'jared goff',
#   'Team': 'LAR',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-143)',
#   'Passing Touchdowns Under': '(+115)',
#   'Anytime Touchdown Line': '+500',
#   'Passing Yards Projection': 'O 260.5',
#   'Passing Yards Over': '(-111)',
#   'Passing Yards Under': '(-110)',
#   'Rushing Yards Projection': 'O 5.5',
#   'Rushing Yards Over': '(-120)',
#   'Rushing Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'daniel jones',
#   'Team': 'NYG',
#   'Passing Yards Projection': 'O 238.5',
#   'Passing Yards Over': '(-132)',
#   'Passing Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+600',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(+108)',
#   'Passing Touchdowns Under': '(-140)',
#   'Rushing Yards Projection': 'O 15.5',
#   'Rushing Yards Over': '(-128)',
#   'Rushing Yards Under': '(-115)',
#   'Interceptions Projection': 'NL',
#   'Interceptions Over': 'NL',
#   'Interceptions Under': '(+140)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'baker mayfield',
#   'Team': 'CLE',
#   'Anytime Touchdown Line': '+500',
#   'Interceptions Projection': '+1.0',
#   'Interceptions Over': '(+108)',
#   'Interceptions Under': '(+105)',
#   'Passing Yards Projection': 'O 235.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-111)',
#   'Rushing Yards Projection': 'O 5.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-125)',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-110)',
#   'Passing Touchdowns Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'kirk cousins',
#   'Team': 'MIN',
#   'Passing Yards Projection': 'O 253.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-111)',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-140)',
#   'Passing Touchdowns Under': '(+114)',
#   'Interceptions Projection': '+1.0',
#   'Interceptions Over': '(-146)',
#   'Interceptions Under': '(-149)',
#   'Anytime Touchdown Line': '+750',
#   'Rushing Yards Projection': 'O 5.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'justin herbert',
#   'Team': 'LAC',
#   'Anytime Touchdown Line': '+375',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-139)',
#   'Passing Touchdowns Under': '(+110)',
#   'Rushing Yards Projection': 'O 16.5',
#   'Rushing Yards Over': '(-115)',
#   'Rushing Yards Under': '(-110)',
#   'Passing Yards Projection': 'O 244.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'teddy bridgewater',
#   'Team': 'CAR',
#   'Anytime Touchdown Line': '+600',
#   'Rushing Yards Projection': 'O 10.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-120)',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(+115)',
#   'Passing Touchdowns Under': '(-145)',
#   'Passing Yards Projection': 'O 247.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-111)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'dwayne haskins',
#   'Team': 'WAS',
#   'Anytime Touchdown Line': '+850',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(+170)',
#   'Passing Touchdowns Under': '(-208)',
#   'Passing Yards Projection': 'O 227.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-111)',
#   'Rushing Yards Projection': 'O 10.5',
#   'Rushing Yards Over': '(-111)',
#   'Rushing Yards Under': '(-110)',
#   'Interceptions Projection': '+1.0',
#   'Interceptions Over': '(+158)',
#   'Interceptions Under': '(+155)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'derek carr',
#   'Team': 'LV',
#   'Passing Yards Projection': 'O 240.5',
#   'Passing Yards Over': '(-111)',
#   'Passing Yards Under': '(-115)',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(+105)',
#   'Passing Touchdowns Under': '(-130)',
#   'Anytime Touchdown Line': '+1000'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'jeff driskel',
#   'Team': 'DEN',
#   'Rushing Yards Projection': 'O 20.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(+170)',
#   'Passing Touchdowns Under': '(-215)',
#   'Anytime Touchdown Line': '+450',
#   'Passing Yards Projection': 'O 221.5',
#   'Passing Yards Over': '(-111)',
#   'Passing Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'nick mullens',
#   'Team': 'SF',
#   'Anytime Touchdown Line': '+900',
#   'Passing Yards Projection': 'O 247.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-130)',
#   'Passing Touchdowns Under': '(EVEN)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'sam darnold',
#   'Team': 'NYJ',
#   'Anytime Touchdown Line': '+850',
#   'Passing Yards Projection': 'O 205.5',
#   'Passing Yards Over': '(-111)',
#   'Passing Yards Under': '(-110)',
#   'Rushing Yards Projection': 'O 5.5',
#   'Rushing Yards Over': '(-125)',
#   'Rushing Yards Under': '(-105)',
#   'Passing Touchdowns Projection': 'O 0.5',
#   'Passing Touchdowns Over': '(-250)',
#   'Passing Touchdowns Under': '(+200)',
#   'Interceptions Projection': 'NL',
#   'Interceptions Over': 'NL',
#   'Interceptions Under': '(+152)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'russell wilson',
#   'Team': 'SEA',
#   'Passing Yards Projection': 'O 293.5',
#   'Passing Yards Over': '(-111)',
#   'Passing Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+350',
#   'Passing Touchdowns Projection': 'O 2.5',
#   'Passing Touchdowns Over': '(+140)',
#   'Passing Touchdowns Under': '(-170)',
#   'Rushing Yards Projection': 'O 23.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'lamar jackson',
#   'Team': 'BAL',
#   'Passing Yards Projection': 'O 211.5',
#   'Passing Yards Over': '(-112)',
#   'Passing Yards Under': '(-111)',
#   'Anytime Touchdown Line': '+115',
#   'Rushing Yards Projection': 'O 72.5',
#   'Rushing Yards Over': '(-111)',
#   'Rushing Yards Under': '(-110)',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-120)',
#   'Passing Touchdowns Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'dak prescott',
#   'Team': 'DAL',
#   'Passing Touchdowns Projection': 'O 2.5',
#   'Passing Touchdowns Over': '(+120)',
#   'Passing Touchdowns Under': '(-150)',
#   'Passing Yards Projection': 'O 317.5',
#   'Passing Yards Over': '(-111)',
#   'Passing Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+190',
#   'Rushing Yards Projection': 'O 20.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'josh allen',
#   'Team': 'BUF',
#   'Interceptions Projection': '+1.0',
#   'Interceptions Over': '(+130)',
#   'Interceptions Under': '(+140)',
#   'Anytime Touchdown Line': '+120',
#   'Rushing Yards Projection': 'O 39.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-111)',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-175)',
#   'Passing Touchdowns Under': '(+145)',
#   'Passing Yards Projection': 'O 282.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-111)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'patrick mahomes',
#   'Team': 'KC',
#   'Anytime Touchdown Line': '+350',
#   'Passing Touchdowns Projection': 'O 2.5',
#   'Passing Touchdowns Over': '(+110)',
#   'Passing Touchdowns Under': '(-140)',
#   'Rushing Yards Projection': 'O 21.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Passing Yards Projection': 'O 296.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Interceptions Projection': '+1.0',
#   'Interceptions Over': '(-146)',
#   'Interceptions Under': '(-147)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'kyler murray',
#   'Team': 'ARI',
#   'Anytime Touchdown Line': '+130',
#   'Rushing Yards Projection': 'O 41.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
# ...
#   'Passing Yards Under': '(-111)',
#   'Rushing Yards Projection': 'O 12.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-120)',
#   'Anytime Touchdown Line': '+370',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(EVEN)',
#   'Passing Touchdowns Under': '(-133)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'ben roethlisberger',
#   'Team': 'PIT',
#   'Passing Yards Projection': 'O 240.5',
#   'Passing Yards Over': '(-115)',
#   'Passing Yards Under': '(-115)',
#   'Interceptions Projection': 'O 0.5',
#   'Interceptions Over': '(EVEN)',
#   'Interceptions Under': '(-130)',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-105)',
#   'Passing Touchdowns Under': '(-125)',
#   'Anytime Touchdown Line': '+1400'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'davis mills',
#   'Team': 'HOU',
#   'Anytime Touchdown Line': '+1100',
#   'Passing Yards Projection': 'O 220.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-115)',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(+200)',
#   'Passing Touchdowns Under': '(-260)',
#   'Interceptions Projection': 'O 0.5',
#   'Interceptions Over': '(-165)',
#   'Interceptions Under': '(+125)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'baker mayfield',
#   'Team': 'CLE',
#   'Rushing Yards Projection': 'O 7.5',
#   'Rushing Yards Over': '(-115)',
#   'Rushing Yards Under': '(-111)',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(+136)',
#   'Passing Touchdowns Under': '(-174)',
#   'Interceptions Projection': 'O 0.5',
#   'Interceptions Over': '(-140)',
#   'Interceptions Under': '(+105)',
#   'Passing Yards Projection': 'O 219.5',
#   'Passing Yards Over': '(-120)',
#   'Passing Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+750'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'taylor heinicke',
#   'Team': 'WAS',
#   'Anytime Touchdown Line': '+450',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(+186)',
#   'Passing Touchdowns Under': '(+200)',
#   'Passing Yards Projection': 'O 197.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-115)',
#   'Rushing Yards Projection': 'O 12.5',
#   'Rushing Yards Over': '(-115)',
#   'Rushing Yards Under': '(-115)',
#   'Interceptions Projection': 'O 0.5',
#   'Interceptions Over': '(-185)',
#   'Interceptions Under': '(+140)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'zach wilson',
#   'Team': 'NYJ',
#   'Passing Touchdowns Projection': 'O 0.5',
#   'Passing Touchdowns Over': '(-220)',
#   'Passing Touchdowns Under': '(+170)',
#   'Rushing Yards Projection': 'O 14.5',
#   'Rushing Yards Over': '(-118)',
#   'Rushing Yards Under': '(-110)',
#   'Interceptions Projection': 'O 0.5',
#   'Interceptions Over': '(-210)',
#   'Interceptions Under': '(+155)',
#   'Passing Yards Projection': 'O 199.5',
#   'Passing Yards Over': '(-105)',
#   'Passing Yards Under': '(-125)',
#   'Anytime Touchdown Line': '+500'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'andy dalton',
#   'Team': 'CHI',
#   'Interceptions Projection': 'O 0.5',
#   'Interceptions Over': '(-125)',
#   'Interceptions Under': '(-105)',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(+154)',
#   'Passing Touchdowns Under': '(-195)',
#   'Anytime Touchdown Line': '+550',
#   'Passing Yards Projection': 'O 208.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-115)',
#   'Rushing Yards Projection': 'O 9.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-120)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'sam darnold',
#   'Team': 'CAR',
#   'Passing Touchdowns Projection': 'O 0.5',
#   'Passing Touchdowns Over': '(-160)',
#   'Passing Touchdowns Under': '(+130)',
#   'Anytime Touchdown Line': '+400',
#   'Interceptions Projection': 'O 0.5',
#   'Interceptions Over': '(-175)',
#   'Interceptions Under': '(+130)',
#   'Passing Yards Projection': 'O 196.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-115)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'drew lock',
#   'Team': 'DEN',
#   'Passing Touchdowns Projection': 'O 0.5',
#   'Passing Touchdowns Over': '(-215)',
#   'Passing Touchdowns Under': '(+165)',
#   'Anytime Touchdown Line': '+550',
#   'Passing Yards Projection': 'O 186.5',
#   'Passing Yards Over': '(-115)',
#   'Passing Yards Under': '(-115)',
#   'Interceptions Projection': 'O 0.5',
#   'Interceptions Over': '(-175)',
#   'Interceptions Under': '(+130)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'trevor lawrence',
#   'Team': 'JAX',
#   'Passing Touchdowns Projection': 'O 0.5',
#   'Passing Touchdowns Over': '(-165)',
#   'Passing Touchdowns Under': '(+130)',
#   'Interceptions Projection': 'O 1.5',
#   'Interceptions Over': '(+180)',
#   'Interceptions Under': '(-245)',
#   'Passing Yards Projection': 'O 198.5',
#   'Passing Yards Over': '(-115)',
#   'Passing Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+550'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'sean mannion',
#   'Team': 'MIN',
#   'Anytime Touchdown Line': '+900',
#   'Interceptions Projection': 'O 0.5',
#   'Interceptions Over': '(-215)',
#   'Interceptions Under': '(+155)',
#   'Passing Touchdowns Projection': 'O 0.5',
#   'Passing Touchdowns Over': '(-205)',
#   'Passing Touchdowns Under': '(+150)',
#   'Passing Yards Projection': 'O 183.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-115)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'mike glennon',
#   'Team': 'NYG',
#   'Anytime Touchdown Line': '+900'},
#  {'Year': 2022,
#   'Week': 1,
#   'Player Name': 'lamar jackson',
#   'Team': 'BAL',
#   'Anytime Touchdown Line': '+140',
#   'Rushing Yards Projection': 'O 61.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Passing Yards Projection': 'O 226.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-130)',
#   'Passing Touchdowns Under': '(-106)',
#   'Interceptions Projection': 'O 0.5',
#   'Interceptions Over': '(+115)',
#   'Interceptions Under': '(-155)'},
#  {'Year': 2022,
#   'Week': 1,
#   'Player Name': 'josh allen',
#   'Team': 'BUF',
#   'Anytime Touchdown Line': '+160',
#   'Passing Yards Projection': 'O 270.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-186)',
#   'Passing Touchdowns Under': '(+120)',
#   'Rushing Yards Projection': 'O 37.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Interceptions Projection': 'O 0.5',
#   'Interceptions Over': '(-110)',
#   'Interceptions Under': '(-120)'},
#  {'Year': 2022,
#   'Week': 1,
#   'Player Name': 'patrick mahomes',
#   'Team': 'KC',
#   'Passing Yards Projection': 'O 286.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Rushing Yards Projection': 'O 17.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Interceptions Projection': 'O 0.5',
#   'Interceptions Over': '(-105)',
#   'Interceptions Under': '(-130)',
#   'Anytime Touchdown Line': '+280',
#   'Passing Touchdowns Projection': 'O 2.5',
#   'Passing Touchdowns Over': '(+132)',
#   'Passing Touchdowns Under': '(-170)'},
#  {'Year': 2022,
#   'Week': 1,
#   'Player Name': 'justin herbert',
#   'Team': 'LAC',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-215)',
#   'Passing Touchdowns Under': '(-200)',
#   'Anytime Touchdown Line': '+390',
#   'Interceptions Projection': 'O 0.5',
#   'Interceptions Over': '(+110)',
#   'Interceptions Under': '(-150)',
#   'Rushing Yards Projection': 'O 14.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Passing Yards Projection': 'O 284.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)'},
#  {'Year': 2022,
#   'Week': 1,
#   'Player Name': 'jalen hurts',
#   'Team': 'PHI',
#   'Anytime Touchdown Line': '+130',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-105)',
#   'Passing Touchdowns Under': '(-130)',
#   'Interceptions Projection': 'O 0.5',
#   'Interceptions Over': '(-105)',
#   'Interceptions Under': '(-125)',
#   'Rushing Yards Projection': 'O 46.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Passing Yards Projection': 'O 225.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)'},
#  {'Year': 2022,
#   'Week': 1,
#   'Player Name': 'kyler murray',
#   'Team': 'ARI',
#   'Passing Yards Projection': 'O 256.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Interceptions Projection': 'O 0.5',
#   'Interceptions Over': '(-120)',
#   'Interceptions Under': '(-110)',
#   'Rushing Yards Projection': 'O 36.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+165',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(EVEN)',
#   'Passing Touchdowns Under': '(-130)'},
#  {'Year': 2022,
#   'Week': 1,
#   'Player Name': 'russell wilson',
#   'Team': 'DEN',
#   'Interceptions Projection': 'O 0.5',
#   'Interceptions Over': '(+130)',
#   'Interceptions Under': '(-175)',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-150)',
#   'Passing Touchdowns Under': '(+115)',
#   'Passing Yards Projection': 'O 253.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+350',
#   'Rushing Yards Projection': 'O 12.5',
#   'Rushing Yards Over': '(-130)',
#   'Rushing Yards Under': '(-115)'},
#  {'Year': 2022,
#   'Week': 1,
#   'Player Name': 'tom brady',
#   'Team': 'TB',
#   'Interceptions Projection': 'O 0.5',
#   'Interceptions Over': '(-135)',
#   'Interceptions Under': '(EVEN)',
#   'Passing Touchdowns Projection': 'O 2.5',
#   'Passing Touchdowns Over': '(-225)',
#   'Passing Touchdowns Under': '(-220)',
#   'Rushing Yards Projection': 'O 0.5',
#   'Rushing Yards Over': '(-120)',
#   'Rushing Yards Under': '(-110)',
#   'Passing Yards Projection': 'O 274.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+900'},
#  {'Year': 2022,
#   'Week': 1,
#   'Player Name': 'joe burrow',
#   'Team': 'CIN',
#   'Interceptions Projection': 'O 0.5',
#   'Interceptions Over': '(+110)',
#   'Interceptions Under': '(-145)',
#   'Passing Yards Projection': 'O 259.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+450',
#   'Rushing Yards Projection': 'O 6.5',
#   'Rushing Yards Over': '(-114)',
#   'Rushing Yards Under': '(-106)',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-166)',
#   'Passing Touchdowns Under': '(+110)'},
#  {'Year': 2022,
#   'Week': 1,
#   'Player Name': 'dak prescott',
#   'Team': 'DAL',
#   'Passing Yards Projection': 'O 262.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Interceptions Projection': 'O 0.5',
#   'Interceptions Over': '(+105)',
#   'Interceptions Under': '(-145)',
#   'Rushing Yards Projection': 'O 13.5',
#   'Rushing Yards Over': '(-115)',
#   'Rushing Yards Under': '(-128)',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-155)',
#   'Passing Touchdowns Under': '(+104)',
#   'Anytime Touchdown Line': '+260'},
#  {'Year': 2022,
#   'Week': 1,
#   'Player Name': 'aaron rodgers',
#   'Team': 'GB',
#   'Passing Yards Projection': 'O 258.5',
#   'Passing Yards Over': '(-125)',
#   'Passing Yards Under': '(-110)',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-205)',
#   'Passing Touchdowns Under': '(+152)',
#   'Interceptions Projection': 'O 0.5',
#   'Interceptions Over': '(+175)',
#   'Interceptions Under': '(-250)',
#   'Anytime Touchdown Line': '+500'},
#  {'Year': 2022,
#   'Week': 1,
#   'Player Name': 'trey lance',
#   'Team': 'SF',
#   'Rushing Yards Projection': 'O 39.5',
#   'Rushing Yards Over': '(-110)',
#   'Rushing Yards Under': '(-110)',
#   'Passing Yards Projection': 'O 177.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Interceptions Projection': 'O 0.5',
#   'Interceptions Over': '(+120)',
#   'Interceptions Under': '(-160)',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(+185)',
#   'Passing Touchdowns Under': '(-250)',
#   'Anytime Touchdown Line': '+180'},
#  {'Year': 2022,
#   'Week': 1,
#   'Player Name': 'derek carr',
#   'Team': 'LV',
#   'Interceptions Projection': 'O 0.5',
#   'Interceptions Over': '(-110)',
#   'Interceptions Under': '(-120)',
#   'Anytime Touchdown Line': '+550',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-138)',
#   'Passing Touchdowns Under': '(+108)',
#   'Passing Yards Projection': 'O 268.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Rushing Yards Projection': 'O 4.5',
#   'Rushing Yards Over': '(-120)',
#   'Rushing Yards Under': '(-110)'},
#  {'Year': 2022,
#   'Week': 1,
#   'Player Name': 'matthew stafford',
#   'Team': 'LAR',
#   'Anytime Touchdown Line': '+900',
#   'Passing Yards Projection': 'O 265.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Rushing Yards Projection': 'O 1.5',
#   'Rushing Yards Over': '(-115)',
#   'Rushing Yards Under': '(-115)',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-180)',
#   'Passing Touchdowns Under': '(+130)',
#   'Interceptions Projection': 'O 0.5',
#   'Interceptions Over': '(-130)',
#   'Interceptions Under': '(-105)'},
#  {'Year': 2022,
#   'Week': 1,
#   'Player Name': 'kirk cousins',
#   'Team': 'MIN',
#   'Interceptions Projection': 'O 0.5',
#   'Interceptions Over': '(-105)',
#   'Interceptions Under': '(-130)',
#   'Rushing Yards Projection': 'O 4.5',
#   'Rushing Yards Over': '(-105)',
#   'Rushing Yards Under': '(-125)',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-160)',
#   'Passing Touchdowns Under': '(+108)',
#   'Passing Yards Projection': 'O 270.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+850'},
#  {'Year': 2022,
#   'Week': 1,
#   'Player Name': 'jameis winston',
#   'Team': 'NO',
#   'Interceptions Projection': 'O 0.5',
#   'Interceptions Over': '(-125)',
#   'Interceptions Under': '(-105)',
#   'Rushing Yards Projection': 'O 14.5',
#   'Rushing Yards Over': '(-114)',
#   'Rushing Yards Under': '(-140)',
#   'Anytime Touchdown Line': '+500',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(+105)',
#   'Passing Touchdowns Under': '(-130)',
#   'Passing Yards Projection': 'O 224.5',
#   'Passing Yards Over': '(-114)',
#   'Passing Yards Under': '(-125)'},
#  {'Year': 2022,
#   'Week': 1,
#   'Player Name': 'matt ryan',
#   'Team': 'IND',
#   'Passing Yards Projection': 'O 235.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(+102)',
#   'Passing Touchdowns Under': '(-130)',
#   'Anytime Touchdown Line': '+900',
#   'Interceptions Projection': 'O 0.5',
#   'Interceptions Over': '(+155)',
#   'Interceptions Under': '(-200)'},
#  {'Year': 2022,
#   'Week': 1,
#   'Player Name': 'trevor lawrence',
#   'Team': 'JAX',
#   'Passing Yards Projection': 'O 232.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Rushing Yards Projection': 'O 16.5',
#   'Rushing Yards Over': '(-120)',
#   'Rushing Yards Under': '(-120)',
#   'Anytime Touchdown Line': '+240',
#   'Interceptions Projection': 'O 0.5',
#   'Interceptions Over': '(-167)',
#   'Interceptions Under': '(+128)',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(+125)',
#   'Passing Touchdowns Under': '(-165)'},
#  {'Year': 2022,
#   'Week': 1,
#   'Player Name': 'tua tagovailoa',
#   'Team': 'MIA',
#   'Anytime Touchdown Line': '+290',
#   'Passing Touchdowns Projection': 'O 1.5',
#   'Passing Touchdowns Over': '(-106)',
#   'Passing Touchdowns Under': '(-130)',
#   'Passing Yards Projection': 'O 227.5',
#   'Passing Yards Over': '(-110)',
#   'Passing Yards Under': '(-110)',
#   'Rushing Yards Projection': 'O 9.5',
#   'Rushing Yards Over': '(-114)',
#   'Rushing Yards Under': '(-125)',
#   'Interceptions Projection': 'O 0.5',
#   'Interceptions Over': '(+110)',
#   'Interceptions Under': '(-145)'},
#  ...]

# %%
import pandas as pd

df = pd.json_normalize(d)

df
# Out:
#       Year  Week      Player Name Team Passing Touchdowns Projection  \
# 0     2020     1  patrick mahomes   KC                         O 2.5
# 1     2020     1    lamar jackson  BAL                         O 1.5
# 2     2020     1     dak prescott  DAL                         O 2.5
# 3     2020     1   russell wilson  SEA                         O 1.5
# 4     2020     1   deshaun watson  HOU                         O 1.5
# ...    ...   ...              ...  ...                           ...
# 2000  2023    17  taylor heinicke  ATL                         O 1.5
# 2001  2023    17      cj beathard  JAX                         O 1.5
# 2002  2023    17       sam howell  WAS                         O 1.5
# 2003  2023    17     bailey zappe   NE                         O 0.5
# 2004  2023    17   trevor siemian  NYJ                         O 0.5
#
#      Passing Touchdowns Over Passing Touchdowns Under  \
# 0                     (+104)                   (-132)
# 1                     (-152)                   (-120)
# 2                     (-175)                   (-182)
# 3                     (-140)                   (+120)
# 4                     (-152)                   (+120)
# ...                      ...                      ...
# 2000                  (+195)                   (-270)
# 2001                  (+160)                   (-214)
# 2002                  (+135)                   (-175)
# 2003                  (-184)                   (+140)
# 2004                  (-115)                   (-115)
#
#      Passing Yards Projection Passing Yards Over Passing Yards Under  \
# 0                     O 306.5             (-110)              (-110)
# 1                     O 222.5             (-110)              (-110)
# 2                     O 285.5             (-110)              (-110)
# 3                     O 259.5             (-110)              (-110)
# 4                     O 275.5             (-110)              (-110)
# ...                       ...                ...                 ...
# 2000                  O 203.5             (-110)              (-115)
# 2001                  O 214.5             (-111)              (-115)
# 2002                  O 234.5             (-115)              (-115)
# 2003                  O 195.5             (-115)              (-115)
# 2004                  O 177.5             (-110)              (-115)
#
#      Anytime Touchdown Line Rushing Yards Projection Rushing Yards Over  \
# 0                      +300                   O 20.5             (-105)
# 1                      +110                   O 60.5             (-110)
# 2                      +333                   O 11.5             (-132)
# 3                      +400                   O 21.5             (-110)
# 4                      +190                   O 30.5             (-122)
# ...                     ...                      ...                ...
# 2000                   +550                   O 10.5             (-115)
# 2001                   +650                   O 10.5             (-115)
# 2002                   +550                   O 12.5             (-111)
# 2003                  +1600                    O 5.5             (-110)
# 2004                    NaN                    O 7.5             (-105)
#
#      Rushing Yards Under Interceptions Projection Interceptions Over  \
# 0                 (-115)                      NaN                NaN
# 1                 (-110)                      NaN                NaN
# 2                 (-115)                      NaN                NaN
# 3                 (-110)                      NaN                NaN
# 4                 (-110)                      NaN                NaN
# ...                  ...                      ...                ...
# 2000              (-111)                    O 0.5             (-120)
# 2001              (-115)                    O 0.5             (-150)
# 2002              (-110)                    O 0.5             (-204)
# 2003              (-120)                    O 0.5             (-185)
# 2004              (-122)                      NaN                NaN
#
#      Interceptions Under
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ...                  ...
# 2000              (-110)
# 2001              (+115)
# 2002              (+155)
# 2003              (+140)
# 2004                 NaN
#
# [2005 rows x 17 columns]

# %%
for column in ('Passing Touchdowns Projection', 'Passing Yards Projection', 'Rushing Yards Projection', 'Interceptions Projection'):
    df[column] = df[column].str.extract(r'(\d+\.\d+)').astype(float)

df
# Out:
#       Year  Week      Player Name Team  Passing Touchdowns Projection  \
# 0     2020     1  patrick mahomes   KC                            2.5
# 1     2020     1    lamar jackson  BAL                            1.5
# 2     2020     1     dak prescott  DAL                            2.5
# 3     2020     1   russell wilson  SEA                            1.5
# 4     2020     1   deshaun watson  HOU                            1.5
# ...    ...   ...              ...  ...                            ...
# 2000  2023    17  taylor heinicke  ATL                            1.5
# 2001  2023    17      cj beathard  JAX                            1.5
# 2002  2023    17       sam howell  WAS                            1.5
# 2003  2023    17     bailey zappe   NE                            0.5
# 2004  2023    17   trevor siemian  NYJ                            0.5
#
#      Passing Touchdowns Over Passing Touchdowns Under  \
# 0                     (+104)                   (-132)
# 1                     (-152)                   (-120)
# 2                     (-175)                   (-182)
# 3                     (-140)                   (+120)
# 4                     (-152)                   (+120)
# ...                      ...                      ...
# 2000                  (+195)                   (-270)
# 2001                  (+160)                   (-214)
# 2002                  (+135)                   (-175)
# 2003                  (-184)                   (+140)
# 2004                  (-115)                   (-115)
#
#       Passing Yards Projection Passing Yards Over Passing Yards Under  \
# 0                        306.5             (-110)              (-110)
# 1                        222.5             (-110)              (-110)
# 2                        285.5             (-110)              (-110)
# 3                        259.5             (-110)              (-110)
# 4                        275.5             (-110)              (-110)
# ...                        ...                ...                 ...
# 2000                     203.5             (-110)              (-115)
# 2001                     214.5             (-111)              (-115)
# 2002                     234.5             (-115)              (-115)
# 2003                     195.5             (-115)              (-115)
# 2004                     177.5             (-110)              (-115)
#
#      Anytime Touchdown Line  Rushing Yards Projection Rushing Yards Over  \
# 0                      +300                      20.5             (-105)
# 1                      +110                      60.5             (-110)
# 2                      +333                      11.5             (-132)
# 3                      +400                      21.5             (-110)
# 4                      +190                      30.5             (-122)
# ...                     ...                       ...                ...
# 2000                   +550                      10.5             (-115)
# 2001                   +650                      10.5             (-115)
# 2002                   +550                      12.5             (-111)
# 2003                  +1600                       5.5             (-110)
# 2004                    NaN                       7.5             (-105)
#
#      Rushing Yards Under  Interceptions Projection Interceptions Over  \
# 0                 (-115)                       NaN                NaN
# 1                 (-110)                       NaN                NaN
# 2                 (-115)                       NaN                NaN
# 3                 (-110)                       NaN                NaN
# 4                 (-110)                       NaN                NaN
# ...                  ...                       ...                ...
# 2000              (-111)                       0.5             (-120)
# 2001              (-115)                       0.5             (-150)
# 2002              (-110)                       0.5             (-204)
# 2003              (-120)                       0.5             (-185)
# 2004              (-122)                       NaN                NaN
#
#      Interceptions Under
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ...                  ...
# 2000              (-110)
# 2001              (+115)
# 2002              (+155)
# 2003              (+140)
# 2004                 NaN
#
# [2005 rows x 17 columns]

# %%
for column in ('Passing Touchdowns Over', 'Passing Touchdowns Under', 'Passing Yards Over', 'Passing Yards Under', 'Rushing Yards Over', 'Rushing Yards Under', 'Interceptions Over', 'Interceptions Under'):
    df.loc[df[column].str.contains('EVEN', regex=False, na=False), column] = '100'
    df.loc[df[column] == '--', column] = 'nan'
    df.loc[df[column] == 'NL', column] = 'nan'
    df[column] = df[column].str.replace(r'\(|\)', '', regex=True).astype(float)

df
# Out:
#       Year  Week      Player Name Team  Passing Touchdowns Projection  \
# 0     2020     1  patrick mahomes   KC                            2.5
# 1     2020     1    lamar jackson  BAL                            1.5
# 2     2020     1     dak prescott  DAL                            2.5
# 3     2020     1   russell wilson  SEA                            1.5
# 4     2020     1   deshaun watson  HOU                            1.5
# ...    ...   ...              ...  ...                            ...
# 2000  2023    17  taylor heinicke  ATL                            1.5
# 2001  2023    17      cj beathard  JAX                            1.5
# 2002  2023    17       sam howell  WAS                            1.5
# 2003  2023    17     bailey zappe   NE                            0.5
# 2004  2023    17   trevor siemian  NYJ                            0.5
#
#       Passing Touchdowns Over  Passing Touchdowns Under  \
# 0                       104.0                    -132.0
# 1                      -152.0                    -120.0
# 2                      -175.0                    -182.0
# 3                      -140.0                     120.0
# 4                      -152.0                     120.0
# ...                       ...                       ...
# 2000                    195.0                    -270.0
# 2001                    160.0                    -214.0
# 2002                    135.0                    -175.0
# 2003                   -184.0                     140.0
# 2004                   -115.0                    -115.0
#
#       Passing Yards Projection  Passing Yards Over  Passing Yards Under  \
# 0                        306.5              -110.0               -110.0
# 1                        222.5              -110.0               -110.0
# 2                        285.5              -110.0               -110.0
# 3                        259.5              -110.0               -110.0
# 4                        275.5              -110.0               -110.0
# ...                        ...                 ...                  ...
# 2000                     203.5              -110.0               -115.0
# 2001                     214.5              -111.0               -115.0
# 2002                     234.5              -115.0               -115.0
# 2003                     195.5              -115.0               -115.0
# 2004                     177.5              -110.0               -115.0
#
#      Anytime Touchdown Line  Rushing Yards Projection  Rushing Yards Over  \
# 0                      +300                      20.5              -105.0
# 1                      +110                      60.5              -110.0
# 2                      +333                      11.5              -132.0
# 3                      +400                      21.5              -110.0
# 4                      +190                      30.5              -122.0
# ...                     ...                       ...                 ...
# 2000                   +550                      10.5              -115.0
# 2001                   +650                      10.5              -115.0
# 2002                   +550                      12.5              -111.0
# 2003                  +1600                       5.5              -110.0
# 2004                    NaN                       7.5              -105.0
#
#       Rushing Yards Under  Interceptions Projection  Interceptions Over  \
# 0                  -115.0                       NaN                 NaN
# 1                  -110.0                       NaN                 NaN
# 2                  -115.0                       NaN                 NaN
# 3                  -110.0                       NaN                 NaN
# 4                  -110.0                       NaN                 NaN
# ...                   ...                       ...                 ...
# 2000               -111.0                       0.5              -120.0
# 2001               -115.0                       0.5              -150.0
# 2002               -110.0                       0.5              -204.0
# 2003               -120.0                       0.5              -185.0
# 2004               -122.0                       NaN                 NaN
#
#       Interceptions Under
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 2000               -110.0
# 2001                115.0
# 2002                155.0
# 2003                140.0
# 2004                  NaN
#
# [2005 rows x 17 columns]

# %%
for column in ('Anytime Touchdown Line', ):
    df.loc[df[column].str.contains('EVEN', regex=False, na=False), column] = '100'
    df.loc[df[column] == '--', column] = 'nan'
    df.loc[df[column] == 'NL', column] = 'nan'
    df[column] = df[column].astype(float)

df
# Out:
#       Year  Week      Player Name Team  Passing Touchdowns Projection  \
# 0     2020     1  patrick mahomes   KC                            2.5
# 1     2020     1    lamar jackson  BAL                            1.5
# 2     2020     1     dak prescott  DAL                            2.5
# 3     2020     1   russell wilson  SEA                            1.5
# 4     2020     1   deshaun watson  HOU                            1.5
# ...    ...   ...              ...  ...                            ...
# 2000  2023    17  taylor heinicke  ATL                            1.5
# 2001  2023    17      cj beathard  JAX                            1.5
# 2002  2023    17       sam howell  WAS                            1.5
# 2003  2023    17     bailey zappe   NE                            0.5
# 2004  2023    17   trevor siemian  NYJ                            0.5
#
#       Passing Touchdowns Over  Passing Touchdowns Under  \
# 0                       104.0                    -132.0
# 1                      -152.0                    -120.0
# 2                      -175.0                    -182.0
# 3                      -140.0                     120.0
# 4                      -152.0                     120.0
# ...                       ...                       ...
# 2000                    195.0                    -270.0
# 2001                    160.0                    -214.0
# 2002                    135.0                    -175.0
# 2003                   -184.0                     140.0
# 2004                   -115.0                    -115.0
#
#       Passing Yards Projection  Passing Yards Over  Passing Yards Under  \
# 0                        306.5              -110.0               -110.0
# 1                        222.5              -110.0               -110.0
# 2                        285.5              -110.0               -110.0
# 3                        259.5              -110.0               -110.0
# 4                        275.5              -110.0               -110.0
# ...                        ...                 ...                  ...
# 2000                     203.5              -110.0               -115.0
# 2001                     214.5              -111.0               -115.0
# 2002                     234.5              -115.0               -115.0
# 2003                     195.5              -115.0               -115.0
# 2004                     177.5              -110.0               -115.0
#
#       Anytime Touchdown Line  Rushing Yards Projection  Rushing Yards Over  \
# 0                      300.0                      20.5              -105.0
# 1                      110.0                      60.5              -110.0
# 2                      333.0                      11.5              -132.0
# 3                      400.0                      21.5              -110.0
# 4                      190.0                      30.5              -122.0
# ...                      ...                       ...                 ...
# 2000                   550.0                      10.5              -115.0
# 2001                   650.0                      10.5              -115.0
# 2002                   550.0                      12.5              -111.0
# 2003                  1600.0                       5.5              -110.0
# 2004                     NaN                       7.5              -105.0
#
#       Rushing Yards Under  Interceptions Projection  Interceptions Over  \
# 0                  -115.0                       NaN                 NaN
# 1                  -110.0                       NaN                 NaN
# 2                  -115.0                       NaN                 NaN
# 3                  -110.0                       NaN                 NaN
# 4                  -110.0                       NaN                 NaN
# ...                   ...                       ...                 ...
# 2000               -111.0                       0.5              -120.0
# 2001               -115.0                       0.5              -150.0
# 2002               -110.0                       0.5              -204.0
# 2003               -120.0                       0.5              -185.0
# 2004               -122.0                       NaN                 NaN
#
#       Interceptions Under
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 2000               -110.0
# 2001                115.0
# 2002                155.0
# 2003                140.0
# 2004                  NaN
#
# [2005 rows x 17 columns]

# %%
def american_odds_to_probability(odds):
    """
    Converts American betting odds to implied probability.
    
    Args:
        odds (int or float): The American odds value (e.g., -150, +200).

    Returns:
        float: The implied probability as a decimal (e.g., 0.60 for 60%).
    """
    if odds > 0:
        # Positive odds: (100 / (odds + 100))
        probability = 100 / (odds + 100)
    else:
        # Negative odds: (-odds / (-odds + 100))
        probability = -odds / (-odds + 100)
    
    return probability

# %% [markdown]
# Adjust projections based on over/under lines

# %%
for stat in ('Passing Touchdowns', 'Passing Yards', 'Rushing Yards', 'Interceptions'):
    df[f'Adjusted {stat} Projection'] = (
        df[f'{stat} Projection'] +
        0.5 * df[f'{stat} Over'].apply(american_odds_to_probability) -
        0.5 * df[f'{stat} Under'].apply(american_odds_to_probability)
    )

df
# Out:
#       Year  Week      Player Name Team  Passing Touchdowns Projection  \
# 0     2020     1  patrick mahomes   KC                            2.5
# 1     2020     1    lamar jackson  BAL                            1.5
# 2     2020     1     dak prescott  DAL                            2.5
# 3     2020     1   russell wilson  SEA                            1.5
# 4     2020     1   deshaun watson  HOU                            1.5
# ...    ...   ...              ...  ...                            ...
# 2000  2023    17  taylor heinicke  ATL                            1.5
# 2001  2023    17      cj beathard  JAX                            1.5
# 2002  2023    17       sam howell  WAS                            1.5
# 2003  2023    17     bailey zappe   NE                            0.5
# 2004  2023    17   trevor siemian  NYJ                            0.5
#
#       Passing Touchdowns Over  Passing Touchdowns Under  \
# 0                       104.0                    -132.0
# 1                      -152.0                    -120.0
# 2                      -175.0                    -182.0
# 3                      -140.0                     120.0
# 4                      -152.0                     120.0
# ...                       ...                       ...
# 2000                    195.0                    -270.0
# 2001                    160.0                    -214.0
# 2002                    135.0                    -175.0
# 2003                   -184.0                     140.0
# 2004                   -115.0                    -115.0
#
#       Passing Yards Projection  Passing Yards Over  Passing Yards Under  \
# 0                        306.5              -110.0               -110.0
# 1                        222.5              -110.0               -110.0
# 2                        285.5              -110.0               -110.0
# 3                        259.5              -110.0               -110.0
# 4                        275.5              -110.0               -110.0
# ...                        ...                 ...                  ...
# 2000                     203.5              -110.0               -115.0
# 2001                     214.5              -111.0               -115.0
# 2002                     234.5              -115.0               -115.0
# 2003                     195.5              -115.0               -115.0
# 2004                     177.5              -110.0               -115.0
#
#       Anytime Touchdown Line  Rushing Yards Projection  Rushing Yards Over  \
# 0                      300.0                      20.5              -105.0
# 1                      110.0                      60.5              -110.0
# 2                      333.0                      11.5              -132.0
# 3                      400.0                      21.5              -110.0
# 4                      190.0                      30.5              -122.0
# ...                      ...                       ...                 ...
# 2000                   550.0                      10.5              -115.0
# 2001                   650.0                      10.5              -115.0
# 2002                   550.0                      12.5              -111.0
# 2003                  1600.0                       5.5              -110.0
# 2004                     NaN                       7.5              -105.0
#
#       Rushing Yards Under  Interceptions Projection  Interceptions Over  \
# 0                  -115.0                       NaN                 NaN
# 1                  -110.0                       NaN                 NaN
# 2                  -115.0                       NaN                 NaN
# 3                  -110.0                       NaN                 NaN
# 4                  -110.0                       NaN                 NaN
# ...                   ...                       ...                 ...
# 2000               -111.0                       0.5              -120.0
# 2001               -115.0                       0.5              -150.0
# 2002               -110.0                       0.5              -204.0
# 2003               -120.0                       0.5              -185.0
# 2004               -122.0                       NaN                 NaN
#
#       Interceptions Under  Adjusted Passing Touchdowns Projection  \
# 0                     NaN                                2.460615
# 1                     NaN                                1.528860
# 2                     NaN                                2.495487
# 3                     NaN                                1.564394
# 4                     NaN                                1.574315
# ...                   ...                                     ...
# 2000               -110.0                                1.304627
# 2001                115.0                                1.351543
# 2002                155.0                                1.394584
# 2003                140.0                                0.615610
# 2004                  NaN                                0.500000
#
#       Adjusted Passing Yards Projection  Adjusted Rushing Yards Projection  \
# 0                            306.500000                          20.488656
# 1                            222.500000                          60.500000
# 2                            285.500000                          11.517041
# 3                            259.500000                          21.500000
# 4                            275.500000                          30.512870
# ...                                 ...                                ...
# 2000                         203.494463                          10.504409
# 2001                         214.495591                          10.500000
# 2002                         234.500000                          12.501128
# 2003                         195.500000                           5.489177
# 2004                         177.494463                           7.481323
#
#       Adjusted Interceptions Projection
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# ...                                 ...
# 2000                           0.510823
# 2001                           0.567442
# 2002                           0.639448
# 2003                           0.616228
# 2004                                NaN
#
# [2005 rows x 21 columns]

# %%
df['Anytime Touchdown Probability'] = df['Anytime Touchdown Line'].apply(american_odds_to_probability)

df
# Out:
#       Year  Week      Player Name Team  Passing Touchdowns Projection  \
# 0     2020     1  patrick mahomes   KC                            2.5
# 1     2020     1    lamar jackson  BAL                            1.5
# 2     2020     1     dak prescott  DAL                            2.5
# 3     2020     1   russell wilson  SEA                            1.5
# 4     2020     1   deshaun watson  HOU                            1.5
# ...    ...   ...              ...  ...                            ...
# 2000  2023    17  taylor heinicke  ATL                            1.5
# 2001  2023    17      cj beathard  JAX                            1.5
# 2002  2023    17       sam howell  WAS                            1.5
# 2003  2023    17     bailey zappe   NE                            0.5
# 2004  2023    17   trevor siemian  NYJ                            0.5
#
#       Passing Touchdowns Over  Passing Touchdowns Under  \
# 0                       104.0                    -132.0
# 1                      -152.0                    -120.0
# 2                      -175.0                    -182.0
# 3                      -140.0                     120.0
# 4                      -152.0                     120.0
# ...                       ...                       ...
# 2000                    195.0                    -270.0
# 2001                    160.0                    -214.0
# 2002                    135.0                    -175.0
# 2003                   -184.0                     140.0
# 2004                   -115.0                    -115.0
#
#       Passing Yards Projection  Passing Yards Over  Passing Yards Under  \
# 0                        306.5              -110.0               -110.0
# 1                        222.5              -110.0               -110.0
# 2                        285.5              -110.0               -110.0
# 3                        259.5              -110.0               -110.0
# 4                        275.5              -110.0               -110.0
# ...                        ...                 ...                  ...
# 2000                     203.5              -110.0               -115.0
# 2001                     214.5              -111.0               -115.0
# 2002                     234.5              -115.0               -115.0
# 2003                     195.5              -115.0               -115.0
# 2004                     177.5              -110.0               -115.0
#
#       Anytime Touchdown Line  Rushing Yards Projection  Rushing Yards Over  \
# 0                      300.0                      20.5              -105.0
# 1                      110.0                      60.5              -110.0
# 2                      333.0                      11.5              -132.0
# 3                      400.0                      21.5              -110.0
# 4                      190.0                      30.5              -122.0
# ...                      ...                       ...                 ...
# 2000                   550.0                      10.5              -115.0
# 2001                   650.0                      10.5              -115.0
# 2002                   550.0                      12.5              -111.0
# 2003                  1600.0                       5.5              -110.0
# 2004                     NaN                       7.5              -105.0
#
#       Rushing Yards Under  Interceptions Projection  Interceptions Over  \
# 0                  -115.0                       NaN                 NaN
# 1                  -110.0                       NaN                 NaN
# 2                  -115.0                       NaN                 NaN
# 3                  -110.0                       NaN                 NaN
# 4                  -110.0                       NaN                 NaN
# ...                   ...                       ...                 ...
# 2000               -111.0                       0.5              -120.0
# 2001               -115.0                       0.5              -150.0
# 2002               -110.0                       0.5              -204.0
# 2003               -120.0                       0.5              -185.0
# 2004               -122.0                       NaN                 NaN
#
#       Interceptions Under  Adjusted Passing Touchdowns Projection  \
# 0                     NaN                                2.460615
# 1                     NaN                                1.528860
# 2                     NaN                                2.495487
# 3                     NaN                                1.564394
# 4                     NaN                                1.574315
# ...                   ...                                     ...
# 2000               -110.0                                1.304627
# 2001                115.0                                1.351543
# 2002                155.0                                1.394584
# 2003                140.0                                0.615610
# 2004                  NaN                                0.500000
#
#       Adjusted Passing Yards Projection  Adjusted Rushing Yards Projection  \
# 0                            306.500000                          20.488656
# 1                            222.500000                          60.500000
# 2                            285.500000                          11.517041
# 3                            259.500000                          21.500000
# 4                            275.500000                          30.512870
# ...                                 ...                                ...
# 2000                         203.494463                          10.504409
# 2001                         214.495591                          10.500000
# 2002                         234.500000                          12.501128
# 2003                         195.500000                           5.489177
# 2004                         177.494463                           7.481323
#
#       Adjusted Interceptions Projection  Anytime Touchdown Probability
# 0                                   NaN                       0.250000
# 1                                   NaN                       0.476190
# 2                                   NaN                       0.230947
# 3                                   NaN                       0.200000
# 4                                   NaN                       0.344828
# ...                                 ...                            ...
# 2000                           0.510823                       0.153846
# 2001                           0.567442                       0.133333
# 2002                           0.639448                       0.153846
# 2003                           0.616228                       0.058824
# 2004                                NaN                            NaN
#
# [2005 rows x 22 columns]

# %%
df.to_parquet(r'..\..\data\betting_lines\qb1_props.parquet')

print('Done')
# Out:
# Done
