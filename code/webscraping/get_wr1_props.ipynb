# %% [markdown]
# Find relevant wide receivers to webscrape

# %%
import pandas as pd

pd.set_option('display.max_columns', 100)

df_superflex_rankings = pd.read_parquet(r'..\..\data\fantasypros_in_season_rankings\superflex_rankings.parquet')

df_superflex_rankings = df_superflex_rankings.loc[df_superflex_rankings['Player Name'].notna(), :].reset_index(drop=True)

df_superflex_rankings
# Out:
#        Year  Week   RK        Player Name POS  POS RK
# 0      2018     1    1     Todd Gurley II  RB       1
# 1      2018     1    2      David Johnson  RB       2
# 2      2018     1    3       Alvin Kamara  RB       3
# 3      2018     1    4  Melvin Gordon III  RB       4
# 4      2018     1    5    Ezekiel Elliott  RB       5
# ...     ...   ...  ...                ...  ..     ...
# 41050  2023    17  461    Steven Sims Jr.  WR     183
# 41051  2023    17  462     Jashaun Corbin  RB     112
# 41052  2023    17  463       Dee Eskridge  WR     184
# 41053  2023    17  464       Clayton Tune  QB      65
# 41054  2023    17  465      Brady Russell  TE     104
#
# [41055 rows x 6 columns]

# %%
df_wr = df_superflex_rankings.loc[df_superflex_rankings['POS'] == 'WR', :].sort_values(['Year', 'Week', 'POS RK'], ignore_index=True)

df_wr = df_wr.loc[df_wr['Year'] >= 2020, :].reset_index(drop=True)  # for now

df_wr.sort_values(['Year', 'Week', 'POS RK'], ignore_index=True, inplace=True)

df_wr
# Out:
#        Year  Week   RK       Player Name POS  POS RK
# 0      2020     1   21    Michael Thomas  WR       1
# 1      2020     1   33     Davante Adams  WR       2
# 2      2020     1   36       Julio Jones  WR       3
# 3      2020     1   37       Tyreek Hill  WR       4
# 4      2020     1   45      Chris Godwin  WR       5
# ...     ...   ...  ...               ...  ..     ...
# 11449  2023    17  458     Lucky Jackson  WR     180
# 11450  2023    17  459         DJ Turner  WR     181
# 11451  2023    17  460  Laquon Treadwell  WR     182
# 11452  2023    17  461   Steven Sims Jr.  WR     183
# 11453  2023    17  463      Dee Eskridge  WR     184
#
# [11454 rows x 6 columns]

# %%
df_wr.loc[df_wr['Player Name'].str.contains('-'), 'Player Name'].unique()
# Out:
# array(['JuJu Smith-Schuster', 'Marquez Valdes-Scantling',
#        'J.J. Arcega-Whiteside', 'Antonio Gandy-Golden',
#        'Ray-Ray McCloud III', 'Nick Westbrook-Ikhine',
#        'Tyron Billy-Johnson', 'Donovan Peoples-Jones',
#        'Amon-Ra St. Brown', 'Ihmir Smith-Marsette',
#        'Anthony Ratliff-Williams', 'Jaxon Smith-Njigba'], dtype=object)

# %%
df_wr.loc[df_wr['Player Name'].str.contains(r'(Sr\.|Jr\.)$', regex=True), 'Player Name'].unique()
# Out:
# C:\Users\mhugh\AppData\Local\Temp\ipykernel_10960\1394298560.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df_wr.loc[df_wr['Player Name'].str.contains(r'(Sr\.|Jr\.)$', regex=True), 'Player Name'].unique()
# array(['DJ Chark Jr.', 'Odell Beckham Jr.', 'Marvin Jones Jr.',
#        'Mecole Hardman Jr.', 'Steven Sims Jr.', 'Michael Pittman Jr.',
#        'Laviska Shenault Jr.', 'Jakeem Grant Sr.', 'Ted Ginn Jr.',
#        'Keelan Cole Sr.', 'Mohamed Sanu Sr.', 'KJ Hill Jr.',
#        'Cedrick Wilson Jr.', 'Jason Moore Jr.', 'Richie James Jr.',
#        'Trent Sherfield Sr.', 'Steven Mitchell Jr.', 'Cyril Grayson Jr.',
#        'Lynn Bowden Jr.', 'Victor Bolden Jr.', 'Paul Richardson Jr.',
#        'Deebo Samuel Sr.', 'Stanley Morgan Jr.', 'Terrace Marshall Jr.',
#        'Easop Winston Jr.', 'Jeff Cotton Jr.', 'Kaylon Geiger Sr.',
#        'Justin Hardee Sr.', 'Velus Jones Jr.', 'Marvin Mims Jr.',
#        'Austin Watkins Jr.'], dtype=object)

# %%
# make names easier to match
df_wr['Player Name'] = (
    df_wr['Player Name']
    .str.split().str[:2].str.join(' ')  # make names just the first two words
    .str.replace(r'[^a-zA-Z0-9\s]', '', regex=True)  # remove non-alphanumeric characters
    .str.lower()  # lowercase only (helps with matching)
)

df_wr
# Out:
#        Year  Week   RK       Player Name POS  POS RK
# 0      2020     1   21    michael thomas  WR       1
# 1      2020     1   33     davante adams  WR       2
# 2      2020     1   36       julio jones  WR       3
# 3      2020     1   37       tyreek hill  WR       4
# 4      2020     1   45      chris godwin  WR       5
# ...     ...   ...  ...               ...  ..     ...
# 11449  2023    17  458     lucky jackson  WR     180
# 11450  2023    17  459         dj turner  WR     181
# 11451  2023    17  460  laquon treadwell  WR     182
# 11452  2023    17  461       steven sims  WR     183
# 11453  2023    17  463      dee eskridge  WR     184
#
# [11454 rows x 6 columns]

# %% [markdown]
# Filter to relevant players

# %%
df_teams = pd.read_parquet('../../data/fantasy_points/footballguys_half_ppr.parquet')[['Season', 'Week', 'Name', 'Team', 'Position']]

df_teams['Name'] = (
    df_teams['Name'].str.split().str[:2].str.join(' ')  # make names just the first two words
    .str.replace(r'[^a-zA-Z0-9\s]', '', regex=True)  # remove non-alphanumeric characters
    .str.lower()  # lowercase only (helps with matching)
)

df_teams = df_teams.loc[df_teams['Position'] == 'WR', :].reset_index(drop=True)

df_teams
# Out:
#        Season  Week               Name Team Position
# 0        2018     1        tyreek hill   KC       WR
# 1        2018     1     michael thomas   NO       WR
# 2        2018     1     desean jackson   TB       WR
# 3        2018     1       randall cobb   GB       WR
# 4        2018     1       kenny stills  MIA       WR
# ...       ...   ...                ...  ...      ...
# 14200    2023    17   laquon treadwell  BAL       WR
# 14201    2023    17    kavontae turpin  DAL       WR
# 14202    2023    17      tylan wallace  BAL       WR
# 14203    2023    17  olamide zaccheaus  PHI       WR
# 14204    2023    17       samori toure   GB       WR
#
# [14205 rows x 5 columns]

# %% [markdown]
# Fix players with difficult names

# %%
df_teams.loc[df_teams['Name'] == 'will fuller', 'Name'] = 'william fuller'

# %%
df_wr = df_wr.merge(
    df_teams.rename(columns={'Season': 'Year', 'Name': 'Player Name', 'Position': 'POS'}),
    how='left',
    on=['Year', 'Week', 'Player Name', 'POS'],
)

df_wr.loc[(df_wr['Team'].isna()) & (df_wr['POS RK'] <= 25), :]

# 2022 Week 17 Bills at Bengals was cancelled
# Out:
#       Year  Week  RK   Player Name POS  POS RK Team
# 8359  2022    17  20  jamarr chase  WR       2  NaN

# %%
df_wr.loc[(df_wr['Team'].isna()) & (df_wr['POS RK'] <= 32*3), :].groupby(['Player Name'])['POS'].count().sort_values(ascending=False).head(10)
# Out:
# Player Name
# bisi johnson            3
# albert wilson           2
# terrace marshall        2
# aj green                1
# brandon zylstra         1
# antonio gandygolden     1
# braxton berrios         1
# dee eskridge            1
# donovan peoplesjones    1
# denzel mims             1
# Name: POS, dtype: int64

# %%
df_wr = df_wr.loc[df_wr['Team'].notna(), :].reset_index(drop=True)

df_wr
# Out:
#       Year  Week   RK       Player Name POS  POS RK Team
# 0     2020     1   21    michael thomas  WR       1   NO
# 1     2020     1   33     davante adams  WR       2   GB
# 2     2020     1   36       julio jones  WR       3  ATL
# 3     2020     1   37       tyreek hill  WR       4   KC
# 4     2020     1   45      chris godwin  WR       5   TB
# ...    ...   ...  ...               ...  ..     ...  ...
# 9697  2023    17  414      jalen brooks  WR     168  DAL
# 9698  2023    17  423       keelan doss  WR     171  LAC
# 9699  2023    17  448   austin trammell  WR     177  LAR
# 9700  2023    17  458     lucky jackson  WR     180  MIN
# 9701  2023    17  460  laquon treadwell  WR     182  BAL
#
# [9702 rows x 7 columns]

# %%
df_wr = df_wr.groupby(['Year', 'Week', 'Team']).nth(0).reset_index(drop=True)

df_wr
# Out:
#       Year  Week   RK       Player Name POS  POS RK Team
# 0     2020     1   21    michael thomas  WR       1   NO
# 1     2020     1   33     davante adams  WR       2   GB
# 2     2020     1   36       julio jones  WR       3  ATL
# 3     2020     1   37       tyreek hill  WR       4   KC
# 4     2020     1   45      chris godwin  WR       5   TB
# ...    ...   ...  ...               ...  ..     ...  ...
# 2011  2023    17  114   demario douglas  WR      41   NE
# 2012  2023    17  120      elijah moore  WR      43  CLE
# 2013  2023    17  135  wandale robinson  WR      49  NYG
# 2014  2023    17  137  quentin johnston  WR      51  LAC
# 2015  2023    17  138    michael wilson  WR      52  ARI
#
# [2016 rows x 7 columns]

# %%
df_wr['Player Name URL'] = df_wr['Player Name'].str.replace(' ', '-')

# fix players who are known to have issues
df_wr.loc[df_wr['Player Name'] == 'juju smithschuster', 'Player Name URL'] = 'juju-smith-schuster'
df_wr.loc[df_wr['Player Name'] == 'jj arcegawhiteside', 'Player Name URL'] = 'jj-arcega-whiteside'
df_wr.loc[df_wr['Player Name'] == 'rayray mccloud', 'Player Name URL'] = 'ray-ray-mccloud'
df_wr.loc[df_wr['Player Name'] == 'donovan peoplesjones', 'Player Name URL'] = 'donovan-peoples-jones'
df_wr.loc[df_wr['Player Name'] == 'amonra st', 'Player Name URL'] = 'amonra-stbrown'
df_wr.loc[df_wr['Player Name'] == 'jaxon smithnjigba', 'Player Name URL'] = 'jaxon-smith-njigba'
df_wr.loc[df_wr['Player Name'] == 'ted ginn', 'Player Name URL'] = 'ted-ginn-jr'
df_wr.loc[df_wr['Player Name'] == 'michael thomas', 'Player Name URL'] = 'michael-thomas-wr'
df_wr.loc[df_wr['Player Name'] == 'dj moore', 'Player Name URL'] = 'dj-moore-wr'
df_wr.loc[df_wr['Player Name'] == 'william fuller', 'Player Name URL'] = 'will-fuller'
df_wr.loc[df_wr['Player Name'] == 'robbie chosen', 'Player Name URL'] = 'robby-anderson'
df_wr.loc[df_wr['Player Name'] == 'mike williams', 'Player Name URL'] = 'mike-williams-wr'
df_wr.loc[df_wr['Player Name'] == 'scotty miller', 'Player Name URL'] = 'scott-miller'
df_wr.loc[df_wr['Player Name'] == 'gabe davis', 'Player Name URL'] = 'gabriel-davis'
df_wr.loc[df_wr['Player Name'] == 'nick westbrookikhine', 'Player Name URL'] = 'nick-westbrook'

df_wr
# Out:
#       Year  Week   RK       Player Name POS  POS RK Team   Player Name URL
# 0     2020     1   21    michael thomas  WR       1   NO    michael-thomas
# 1     2020     1   33     davante adams  WR       2   GB     davante-adams
# 2     2020     1   36       julio jones  WR       3  ATL       julio-jones
# 3     2020     1   37       tyreek hill  WR       4   KC       tyreek-hill
# 4     2020     1   45      chris godwin  WR       5   TB      chris-godwin
# ...    ...   ...  ...               ...  ..     ...  ...               ...
# 2011  2023    17  114   demario douglas  WR      41   NE   demario-douglas
# 2012  2023    17  120      elijah moore  WR      43  CLE      elijah-moore
# 2013  2023    17  135  wandale robinson  WR      49  NYG  wandale-robinson
# 2014  2023    17  137  quentin johnston  WR      51  LAC  quentin-johnston
# 2015  2023    17  138    michael wilson  WR      52  ARI    michael-wilson
#
# [2016 rows x 8 columns]

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

options = Options()
# options.add_argument('--headless')

driver = webdriver.Chrome(options=options)

# %%
import time
from selenium.webdriver.common.by import By

def scrape_props(player_name, player_name_url, year, week, team):
    driver.get(url=f"https://www.bettingpros.com/nfl/odds/player-props/{player_name_url}/?season={year}&week={week}")
    time.sleep(5)

    # the page uses lazy loading
    # this loop helps all relevant elements load before scraping
    for _ in range(3):
        # find all loaded rows
        rows = driver.find_elements(
            by=By.CLASS_NAME,
            value="grouped-items-with-sticky-footer__content",
        )

        # scroll to the last loaded row, which should load subsequent rows if there are any
        if len(rows) > 0:
            driver.execute_script(f"window.scrollTo(0, {rows[-1].location['y']});")

        time.sleep(3)

    rows = driver.find_elements(
        by=By.CLASS_NAME,
        value="grouped-items-with-sticky-footer__content",
    )

    if len(rows) == 0:
        print(f"Warning: No rows for {player_name} {year} week {week}")
        
    data = {
        'Year': year,
        'Week': week,
        'Player Name': player_name,
        'Team': team,
    }
    for row in rows:
        t = row.text.split('\n')
        if t[0] == 'Rushing Yards Over/Under':
            data['Rushing Yards Projection'] = t[-4]
            data['Rushing Yards Over'] = t[-3]
            data['Rushing Yards Under'] = t[-1]
        elif t[0] == 'Receiving Yards Over/Under':
            data['Receiving Yards Projection'] = t[-4]
            data['Receiving Yards Over'] = t[-3]
            data['Receiving Yards Under'] = t[-1]
        elif t[0] == 'Receptions Over/Under':
            data['Receptions Projection'] = t[-4]
            data['Receptions Over'] = t[-3]
            data['Receptions Under'] = t[-1]
        elif t[0] == 'Anytime Touchdown Scorer':
            data['Anytime Touchdown Line'] = t[-1]

    return data

# %%
from tqdm.autonotebook import tqdm

d = []
for index, row in tqdm(list(df_wr.iterrows())):
    try:
        d.append(scrape_props(row['Player Name'], row['Player Name URL'], row['Year'], row['Week'], row['Team']))
    except Exception as e:
        print(f"Error with {row['Player Name'], row['Player Name URL'], row['Year'], row['Week'], row['Team']}: {e}")
# Out:
# C:\Users\mhugh\AppData\Local\Temp\ipykernel_10960\94795647.py:1: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm
#   0%|          | 0/2016 [00:00<?, ?it/s]
# Warning: No rows for michael thomas 2020 week 1
# Warning: No rows for dj moore 2020 week 1
# Warning: No rows for william fuller 2020 week 1
# Warning: No rows for dj moore 2020 week 2
# Warning: No rows for william fuller 2020 week 2
# Warning: No rows for dj moore 2020 week 3
# Warning: No rows for william fuller 2020 week 3
# Warning: No rows for dj moore 2020 week 4
# Warning: No rows for william fuller 2020 week 4
# Warning: No rows for robbie chosen 2020 week 5
# Warning: No rows for william fuller 2020 week 5
# Warning: No rows for william fuller 2020 week 6
# Warning: No rows for robbie chosen 2020 week 6
# Warning: No rows for william fuller 2020 week 7
# Warning: No rows for robbie chosen 2020 week 7
# Warning: No rows for robbie chosen 2020 week 8
# Warning: No rows for william fuller 2020 week 9
# Warning: No rows for michael thomas 2020 week 9
# Warning: No rows for robbie chosen 2020 week 9
# Warning: No rows for michael thomas 2020 week 10
# Warning: No rows for robbie chosen 2020 week 10
# Warning: No rows for william fuller 2020 week 10
# Warning: No rows for william fuller 2020 week 11
# Warning: No rows for michael thomas 2020 week 11
# Warning: No rows for robbie chosen 2020 week 11
# Warning: No rows for william fuller 2020 week 12
# Warning: No rows for michael thomas 2020 week 12
# Warning: No rows for dj moore 2020 week 12
# Warning: No rows for michael thomas 2020 week 13
# Warning: No rows for robbie chosen 2020 week 14
# Warning: No rows for michael thomas 2020 week 14
# Warning: No rows for robbie chosen 2020 week 15
# Warning: No rows for dj moore 2020 week 16
# Warning: No rows for mike williams 2020 week 16
# Warning: No rows for dj moore 2021 week 1
# Warning: No rows for dj moore 2021 week 2
# Warning: No rows for dj moore 2021 week 3
# Warning: No rows for dj moore 2021 week 4
# Warning: No rows for nick westbrookikhine 2021 week 4
# Warning: No rows for dj moore 2021 week 5
# Warning: No rows for dj moore 2021 week 6
# Warning: No rows for dj moore 2021 week 7
# Warning: No rows for dj moore 2021 week 8
# Warning: No rows for mike williams 2021 week 8
# Warning: No rows for dj moore 2021 week 9
# Warning: No rows for dj moore 2021 week 10
# Warning: No rows for dj moore 2021 week 11
# Warning: No rows for dj moore 2021 week 12
# Warning: No rows for nick westbrookikhine 2021 week 12
# Warning: No rows for mike williams 2021 week 14
# Warning: No rows for dj moore 2021 week 14
# Warning: No rows for dj moore 2021 week 15
# Warning: No rows for dj moore 2021 week 16
# Warning: No rows for dj moore 2021 week 17
# Warning: No rows for dj moore 2022 week 1
# Warning: No rows for michael thomas 2022 week 1
# Warning: No rows for mike williams 2022 week 2
# Warning: No rows for dj moore 2022 week 2
# Warning: No rows for michael thomas 2022 week 2
# Warning: No rows for michael thomas 2022 week 3
# Warning: No rows for mike williams 2022 week 3
# Warning: No rows for dj moore 2022 week 3
# Warning: No rows for mike williams 2022 week 4
# Warning: No rows for dj moore 2022 week 4
# Warning: No rows for mike williams 2022 week 5
# Warning: No rows for dj moore 2022 week 5
# Warning: No rows for mike williams 2022 week 6
# Warning: No rows for dj moore 2022 week 6
# Warning: No rows for mike williams 2022 week 7
# Warning: No rows for dj moore 2022 week 7
# Warning: No rows for dj moore 2022 week 8
# Warning: No rows for dj moore 2022 week 9
# Warning: No rows for joshua palmer 2022 week 9
# Warning: No rows for dj moore 2022 week 10
# Warning: No rows for joshua palmer 2022 week 10
# Warning: No rows for mike williams 2022 week 11
# Warning: No rows for dj moore 2022 week 11
# Warning: No rows for dj moore 2022 week 12
# Warning: No rows for dj moore 2022 week 14
# Warning: No rows for dj moore 2022 week 15
# Warning: No rows for equanimeous st 2022 week 15
# Warning: No rows for dj moore 2022 week 16
# Warning: No rows for dj moore 2022 week 17
# Warning: No rows for dj moore 2023 week 1
# Warning: No rows for dj moore 2023 week 2
# Warning: No rows for dj moore 2023 week 3
# Warning: No rows for ceedee lamb 2023 week 4
# Warning: No rows for dj moore 2023 week 4
# Warning: No rows for dj moore 2023 week 5
# Warning: No rows for dj moore 2023 week 6
# Warning: No rows for dj moore 2023 week 7
# Warning: No rows for dj moore 2023 week 8
# Warning: No rows for dj moore 2023 week 9
# Warning: No rows for tank dell 2023 week 10
# Warning: No rows for dj moore 2023 week 10
# Warning: No rows for tank dell 2023 week 11
# Warning: No rows for dj moore 2023 week 11
# Warning: No rows for tank dell 2023 week 12
# Warning: No rows for dj moore 2023 week 12
# Warning: No rows for tank dell 2023 week 13
# Warning: No rows for dj moore 2023 week 14
# Warning: No rows for dj moore 2023 week 15
# Warning: No rows for dj moore 2023 week 16
# Warning: No rows for joshua palmer 2023 week 16
# Warning: No rows for dj moore 2023 week 17

# %%
driver.quit()

# %%
d
# Out:
# [{'Year': 2020, 'Week': 1, 'Player Name': 'michael thomas', 'Team': 'NO'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'davante adams',
#   'Team': 'GB',
#   'Receptions Projection': 'O 7.5',
#   'Receptions Over': '(+105)',
#   'Receptions Under': '(-125)',
#   'Anytime Touchdown Line': '+110',
#   'Receiving Yards Projection': 'O 87.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'julio jones',
#   'Team': 'ATL',
#   'Receptions Projection': 'O 6.5',
#   'Receptions Over': '(-130)',
#   'Receptions Under': '(+110)',
#   'Anytime Touchdown Line': '+110',
#   'Receiving Yards Projection': 'O 92.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'tyreek hill',
#   'Team': 'KC',
#   'Receiving Yards Projection': 'O 74.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(+112)',
#   'Receptions Under': '(-142)',
#   'Anytime Touchdown Line': '-130'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'chris godwin',
#   'Team': 'TB',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(-140)',
#   'Receptions Under': '(+106)',
#   'Receiving Yards Projection': 'O 70.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+125'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'allen robinson',
#   'Team': 'CHI',
#   'Anytime Touchdown Line': '+138',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(-105)',
#   'Receptions Under': '(-115)',
#   'Receiving Yards Projection': 'O 70.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020, 'Week': 1, 'Player Name': 'dj moore', 'Team': 'CAR'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'deandre hopkins',
#   'Team': 'ARI',
#   'Anytime Touchdown Line': '+138',
#   'Receiving Yards Projection': 'O 63.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(+108)',
#   'Receptions Under': '(-138)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'juju smithschuster',
#   'Team': 'PIT',
#   'Receiving Yards Projection': 'O 68.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+120',
#   'Receptions Projection': 'O 6.5',
#   'Receptions Over': '(+120)',
#   'Receptions Under': '(-172)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'adam thielen',
#   'Team': 'MIN',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(+125)',
#   'Receptions Under': '(-145)',
#   'Anytime Touchdown Line': '+120',
#   'Receiving Yards Projection': 'O 75.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'robert woods',
#   'Team': 'LAR',
#   'Receiving Yards Projection': 'O 63.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(-110)',
#   'Receptions Under': '(-110)',
#   'Anytime Touchdown Line': '+180'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'aj brown',
#   'Team': 'TEN',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+108)',
#   'Receptions Under': '(-138)',
#   'Anytime Touchdown Line': '+163',
#   'Receiving Yards Projection': 'O 61.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'tyler lockett',
#   'Team': 'SEA',
#   'Anytime Touchdown Line': '+138',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-135)',
#   'Receptions Under': '(+115)',
#   'Receiving Yards Projection': 'O 63.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'terry mclaurin',
#   'Team': 'WAS',
#   'Receiving Yards Projection': 'O 63.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-126)',
#   'Receptions Under': '(-105)',
#   'Anytime Touchdown Line': '+175'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'keenan allen',
#   'Team': 'LAC',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-146)',
#   'Receptions Under': '(EVEN)',
#   'Anytime Touchdown Line': '+163',
#   'Receiving Yards Projection': 'O 58.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'dj chark',
#   'Team': 'JAX',
#   'Anytime Touchdown Line': '+200',
#   'Receiving Yards Projection': 'O 63.5',
#   'Receiving Yards Over': '(-105)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'amari cooper',
#   'Team': 'DAL',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-120)',
#   'Receptions Under': '(-108)',
#   'Receiving Yards Projection': 'O 64.5',
#   'Receiving Yards Over': '(EVEN)',
#   'Receiving Yards Under': '(-120)',
#   'Anytime Touchdown Line': '+135'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'odell beckham',
#   'Team': 'CLE',
#   'Anytime Touchdown Line': '+200',
#   'Receiving Yards Projection': 'O 58.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'ty hilton',
#   'Team': 'IND',
#   'Anytime Touchdown Line': '+140',
#   'Receiving Yards Projection': 'O 62.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'stefon diggs',
#   'Team': 'BUF',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-130)',
#   'Receptions Under': '(EVEN)',
#   'Receiving Yards Projection': 'O 52.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+160'},
#  {'Year': 2020, 'Week': 1, 'Player Name': 'william fuller', 'Team': 'HOU'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'marvin jones',
#   'Team': 'DET',
#   'Anytime Touchdown Line': '+115',
#   'Receiving Yards Projection': 'O 63.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'marquise brown',
#   'Team': 'BAL',
#   'Anytime Touchdown Line': '+175',
#   'Receiving Yards Projection': 'O 47.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-160)',
#   'Receptions Under': '(+130)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'julian edelman',
#   'Team': 'NE',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-150)',
#   'Receptions Under': '(+130)',
#   'Receiving Yards Projection': 'O 57.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+163'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'tyler boyd',
#   'Team': 'CIN',
#   'Receiving Yards Projection': 'O 53.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-118)',
#   'Receptions Under': '(-110)',
#   'Anytime Touchdown Line': '+200'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'desean jackson',
#   'Team': 'PHI',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-130)',
#   'Receptions Under': '(+102)',
#   'Receiving Yards Projection': 'O 50.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+200'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'devante parker',
#   'Team': 'MIA',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+125)',
#   'Receptions Under': '(-145)',
#   'Anytime Touchdown Line': '+188',
#   'Receiving Yards Projection': 'O 65.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-122)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'jamison crowder',
#   'Team': 'NYJ',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-130)',
#   'Receptions Under': '(EVEN)',
#   'Receiving Yards Projection': 'O 55.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+225'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'henry ruggs',
#   'Team': 'LV',
#   'Anytime Touchdown Line': '+225',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-110)',
#   'Receptions Under': '(-110)',
#   'Receiving Yards Projection': 'O 40.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'jerry jeudy',
#   'Team': 'DEN',
#   'Receiving Yards Projection': 'O 44.5',
#   'Receiving Yards Over': '(-120)',
#   'Receiving Yards Under': '(EVEN)',
#   'Anytime Touchdown Line': '+225',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-136)',
#   'Receptions Under': '(+108)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'sterling shepard',
#   'Team': 'NYG',
#   'Receiving Yards Projection': 'O 54.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+125)',
#   'Receptions Under': '(-145)',
#   'Anytime Touchdown Line': '+190'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'kendrick bourne',
#   'Team': 'SF',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+130)',
#   'Receptions Under': '(-150)',
#   'Anytime Touchdown Line': '+200',
#   'Receiving Yards Projection': 'O 40.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-105)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'davante adams',
#   'Team': 'GB',
#   'Receptions Projection': 'O 7.5',
#   'Receptions Over': '(+110)',
#   'Receptions Under': '(-130)',
#   'Anytime Touchdown Line': '-145',
#   'Receiving Yards Projection': 'O 92.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'julio jones',
#   'Team': 'ATL',
#   'Anytime Touchdown Line': '+115',
#   'Receptions Projection': 'O 6.5',
#   'Receptions Over': '(-118)',
#   'Receptions Under': '(-110)',
#   'Receiving Yards Projection': 'O 89.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'deandre hopkins',
#   'Team': 'ARI',
#   'Receiving Yards Projection': 'O 78.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '-115',
#   'Receptions Projection': 'O 6.5',
#   'Receptions Over': '(-134)',
#   'Receptions Under': '(+106)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'tyreek hill',
#   'Team': 'KC',
#   'Anytime Touchdown Line': 'EVEN',
#   'Receiving Yards Projection': 'O 64.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(+112)',
#   'Receptions Under': '(+130)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'adam thielen',
#   'Team': 'MIN',
#   'Receiving Yards Projection': 'O 69.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+120',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-120)',
#   'Receptions Under': '(EVEN)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'allen robinson',
#   'Team': 'CHI',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(+112)',
#   'Receptions Under': '(-142)',
#   'Anytime Touchdown Line': '+138',
#   'Receiving Yards Projection': 'O 67.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-118)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'amari cooper',
#   'Team': 'DAL',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(EVEN)',
#   'Receptions Under': '(-128)',
#   'Anytime Touchdown Line': '+120',
#   'Receiving Yards Projection': 'O 72.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'juju smithschuster',
#   'Team': 'PIT',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(EVEN)',
#   'Receptions Under': '(-138)',
#   'Receiving Yards Projection': 'O 59.5',
#   'Receiving Yards Over': '(-125)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+138'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'mike evans',
#   'Team': 'TB',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(+116)',
#   'Receptions Under': '(-148)',
#   'Anytime Touchdown Line': '-105',
#   'Receiving Yards Projection': 'O 72.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'robert woods',
#   'Team': 'LAR',
#   'Anytime Touchdown Line': '+188',
#   'Receiving Yards Projection': 'O 66.5',
#   'Receiving Yards Over': '(-114)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(-140)',
#   'Receptions Under': '(-118)'},
#  {'Year': 2020, 'Week': 2, 'Player Name': 'dj moore', 'Team': 'CAR'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'terry mclaurin',
#   'Team': 'WAS',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-112)',
#   'Receptions Under': '(-115)',
#   'Receiving Yards Projection': 'O 59.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+170'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'tyler lockett',
#   'Team': 'SEA',
#   'Receiving Yards Projection': 'O 57.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-118)',
#   'Receptions Under': '(-125)',
#   'Anytime Touchdown Line': '+140'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'dj chark',
#   'Team': 'JAX',
#   'Anytime Touchdown Line': '+195',
#   'Receiving Yards Projection': 'O 52.5',
#   'Receiving Yards Over': '(-105)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+108)',
#   'Receptions Under': '(-138)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'ty hilton',
#   'Team': 'IND',
#   'Receiving Yards Projection': 'O 69.5',
#   'Receiving Yards Over': '(-122)',
#   'Receiving Yards Under': '(EVEN)',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(+106)',
#   'Receptions Under': '(-134)',
#   'Anytime Touchdown Line': '+135'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'marquise brown',
#   'Team': 'BAL',
#   'Receiving Yards Projection': 'O 54.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-160)',
#   'Receptions Under': '(+122)',
#   'Anytime Touchdown Line': '+145'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'odell beckham',
#   'Team': 'CLE',
#   'Anytime Touchdown Line': '+138',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-112)',
#   'Receptions Under': '(+105)',
#   'Receiving Yards Projection': 'O 59.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'stefon diggs',
#   'Team': 'BUF',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-150)',
#   'Receptions Under': '(+128)',
#   'Anytime Touchdown Line': '+175',
#   'Receiving Yards Projection': 'O 54.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020, 'Week': 2, 'Player Name': 'william fuller', 'Team': 'HOU'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'keenan allen',
#   'Team': 'LAC',
#   'Anytime Touchdown Line': '+220',
#   'Receiving Yards Projection': 'O 57.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-146)',
#   'Receptions Under': '(+110)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'marvin jones',
#   'Team': 'DET',
#   'Anytime Touchdown Line': '+138',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+106)',
#   'Receptions Under': '(-134)',
#   'Receiving Yards Projection': 'O 60.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'aj green',
#   'Team': 'CIN',
#   'Anytime Touchdown Line': '+180',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+102)',
#   'Receptions Under': '(-125)',
#   'Receiving Yards Projection': 'O 56.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'emmanuel sanders',
#   'Team': 'NO',
#   'Receiving Yards Projection': 'O 59.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-111)',
#   'Anytime Touchdown Line': '+125',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-110)',
#   'Receptions Under': '(-111)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'julian edelman',
#   'Team': 'NE',
#   'Receiving Yards Projection': 'O 54.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-118)',
#   'Receptions Under': '(-110)',
#   'Anytime Touchdown Line': '+200'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'darius slayton',
#   'Team': 'NYG',
#   'Anytime Touchdown Line': '+250',
#   'Receiving Yards Projection': 'O 48.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-110)',
#   'Receptions Under': '(-116)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'courtland sutton',
#   'Team': 'DEN',
#   'Receiving Yards Projection': 'O 48.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+225'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'corey davis',
#   'Team': 'TEN',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-150)',
#   'Receptions Under': '(+130)',
#   'Receiving Yards Projection': 'O 50.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+165'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'desean jackson',
#   'Team': 'PHI',
#   'Anytime Touchdown Line': '+200',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+116)',
#   'Receptions Under': '(-148)',
#   'Receiving Yards Projection': 'O 45.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'preston williams',
#   'Team': 'MIA',
#   'Anytime Touchdown Line': '+137'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'henry ruggs',
#   'Team': 'LV',
#   'Anytime Touchdown Line': '+225',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-130)',
#   'Receptions Under': '(+105)',
#   'Receiving Yards Projection': 'O 44.5',
#   'Receiving Yards Over': '(-111)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'breshad perriman',
#   'Team': 'NYJ',
#   'Receiving Yards Projection': 'O 55.5',
#   'Receiving Yards Over': '(EVEN)',
#   'Receiving Yards Under': '(-125)',
#   'Anytime Touchdown Line': '+250',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-128)',
#   'Receptions Under': '(+102)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'kendrick bourne',
#   'Team': 'SF',
#   'Receiving Yards Projection': 'O 45.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+200'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'deandre hopkins',
#   'Team': 'ARI',
#   'Receptions Projection': 'O 6.5',
#   'Receptions Over': '(-130)',
#   'Receptions Under': '(EVEN)',
#   'Anytime Touchdown Line': '-135',
#   'Receiving Yards Projection': 'O 81.5',
#   'Receiving Yards Over': '(-111)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'calvin ridley',
#   'Team': 'ATL',
#   'Anytime Touchdown Line': '+105',
#   'Receiving Yards Projection': 'O 78.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(+122)',
#   'Receptions Under': '(-156)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'tyreek hill',
#   'Team': 'KC',
#   'Anytime Touchdown Line': 'EVEN',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(-115)',
#   'Receptions Under': '(-106)',
#   'Receiving Yards Projection': 'O 69.5',
#   'Receiving Yards Over': '(-111)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'allen robinson',
#   'Team': 'CHI',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(EVEN)',
#   'Receptions Under': '(-130)',
#   'Anytime Touchdown Line': '+120',
#   'Receiving Yards Projection': 'O 72.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'amari cooper',
#   'Team': 'DAL',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-149)',
#   'Receptions Under': '(+120)',
#   'Receiving Yards Projection': 'O 71.5',
#   'Receiving Yards Over': '(-111)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+105'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'adam thielen',
#   'Team': 'MIN',
#   'Receiving Yards Projection': 'O 73.5',
#   'Receiving Yards Over': '(-111)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-145)',
#   'Receptions Under': '(+115)',
#   'Anytime Touchdown Line': 'EVEN'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'dk metcalf',
#   'Team': 'SEA',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-120)',
#   'Receptions Under': '(-106)',
#   'Receiving Yards Projection': 'O 63.5',
#   'Receiving Yards Over': '(-125)',
#   'Receiving Yards Under': '(-105)',
#   'Anytime Touchdown Line': '-115'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'mike evans',
#   'Team': 'TB',
#   'Anytime Touchdown Line': '+110',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-145)',
#   'Receptions Under': '(+110)',
#   'Receiving Yards Projection': 'O 60.5',
#   'Receiving Yards Over': '(-111)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'terry mclaurin',
#   'Team': 'WAS',
#   'Anytime Touchdown Line': '+163',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-115)',
#   'Receptions Under': '(-115)',
#   'Receiving Yards Projection': 'O 61.5',
#   'Receiving Yards Over': '(-111)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020, 'Week': 3, 'Player Name': 'dj moore', 'Team': 'CAR'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'juju smithschuster',
#   'Team': 'PIT',
#   'Anytime Touchdown Line': '+105',
#   'Receiving Yards Projection': 'O 62.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(-128)',
#   'Receptions Under': '(EVEN)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'cooper kupp',
#   'Team': 'LAR',
#   'Anytime Touchdown Line': '+180',
#   'Receiving Yards Projection': 'O 54.5',
#   'Receiving Yards Over': '(-111)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-125)',
#   'Receptions Under': '(EVEN)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'odell beckham',
#   'Team': 'CLE',
#   'Anytime Touchdown Line': '+110',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(EVEN)',
#   'Receptions Under': '(-130)',
#   'Receiving Yards Projection': 'O 55.5',
#   'Receiving Yards Over': '(-111)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'keenan allen',
#   'Team': 'LAC',
#   'Anytime Touchdown Line': '+130',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(+130)',
#   'Receptions Under': '(-160)',
#   'Receiving Yards Projection': 'O 62.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-111)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'marquise brown',
#   'Team': 'BAL',
#   'Anytime Touchdown Line': '+135',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-110)',
#   'Receptions Under': '(-120)',
#   'Receiving Yards Projection': 'O 52.5',
#   'Receiving Yards Over': '(-122)',
#   'Receiving Yards Under': '(EVEN)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'stefon diggs',
#   'Team': 'BUF',
#   'Receiving Yards Projection': 'O 61.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-111)',
#   'Anytime Touchdown Line': '+155',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-120)',
#   'Receptions Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'julian edelman',
#   'Team': 'NE',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-156)',
#   'Receptions Under': '(+122)',
#   'Receiving Yards Projection': 'O 65.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+140'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'ty hilton',
#   'Team': 'IND',
#   'Receiving Yards Projection': 'O 58.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+115',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-130)',
#   'Receptions Under': '(EVEN)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'tyler boyd',
#   'Team': 'CIN',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-139)',
#   'Receptions Under': '(+110)',
#   'Anytime Touchdown Line': '+220',
#   'Receiving Yards Projection': 'O 58.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-111)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'devante parker',
#   'Team': 'MIA',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+114)',
#   'Receptions Under': '(-135)',
#   'Anytime Touchdown Line': '+125',
#   'Receiving Yards Projection': 'O 61.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'darius slayton',
#   'Team': 'NYG',
#   'Anytime Touchdown Line': '+160',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-111)',
#   'Receptions Under': '(-115)',
#   'Receiving Yards Projection': 'O 42.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'kenny golladay',
#   'Team': 'DET',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+110)',
#   'Receptions Under': '(-138)',
#   'Anytime Touchdown Line': '+115',
#   'Receiving Yards Projection': 'O 56.5',
#   'Receiving Yards Over': '(-114)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'corey davis',
#   'Team': 'TEN',
#   'Receiving Yards Projection': 'O 52.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-180)',
#   'Receptions Under': '(+110)',
#   'Anytime Touchdown Line': '+150'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'desean jackson',
#   'Team': 'PHI',
#   'Receiving Yards Projection': 'O 57.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-111)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-150)',
#   'Receptions Under': '(+120)',
#   'Anytime Touchdown Line': '+160'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'laviska shenault',
#   'Team': 'JAX',
#   'Anytime Touchdown Line': '+200',
#   'Receiving Yards Projection': 'O 45.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-105)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-164)',
#   'Receptions Under': '(+128)'},
#  {'Year': 2020, 'Week': 3, 'Player Name': 'william fuller', 'Team': 'HOU'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'allen lazard',
#   'Team': 'GB',
#   'Anytime Touchdown Line': '+180',
#   'Receiving Yards Projection': 'O 53.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+116)',
#   'Receptions Under': '(-148)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'jerry jeudy',
#   'Team': 'DEN',
#   'Receiving Yards Projection': 'O 45.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+210',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-105)',
#   'Receptions Under': '(-125)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'trequan smith',
#   'Team': 'NO',
#   'Anytime Touchdown Line': '+190',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-156)',
#   'Receptions Under': '(+122)',
#   'Receiving Yards Projection': 'O 50.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-105)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'brandon aiyuk',
#   'Team': 'SF',
#   'Anytime Touchdown Line': '+350',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-160)',
#   'Receptions Under': '(-162)',
#   'Receiving Yards Projection': 'O 34.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'bryan edwards',
#   'Team': 'LV',
#   'Anytime Touchdown Line': '+390'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'chris hogan',
#   'Team': 'NYJ',
#   'Anytime Touchdown Line': '+270',
#   'Receiving Yards Projection': 'O 39.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+102)',
#   'Receptions Under': '(-130)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'deandre hopkins',
#   'Team': 'ARI',
#   'Anytime Touchdown Line': '+105',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(-148)',
#   'Receptions Under': '(+116)',
#   'Receiving Yards Projection': 'O 67.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'calvin ridley',
#   'Team': 'ATL',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(-110)',
#   'Receptions Under': '(-115)',
#   'Anytime Touchdown Line': '+110',
#   'Receiving Yards Projection': 'O 78.5',
#   'Receiving Yards Over': '(-111)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'tyler lockett',
#   'Team': 'SEA',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(+105)',
#   'Receptions Under': '(-128)',
#   'Anytime Touchdown Line': '-115',
#   'Receiving Yards Projection': 'O 74.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-111)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'tyreek hill',
#   'Team': 'KC',
#   'Anytime Touchdown Line': '-115',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(+125)',
#   'Receptions Under': '(-167)',
#   'Receiving Yards Projection': 'O 66.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'amari cooper',
#   'Team': 'DAL',
#   'Receiving Yards Projection': 'O 81.5',
#   'Receiving Yards Over': '(-111)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+120',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(-139)',
#   'Receptions Under': '(+110)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'allen robinson',
#   'Team': 'CHI',
#   'Receiving Yards Projection': 'O 69.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-111)',
#   'Anytime Touchdown Line': '+130',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(-115)',
#   'Receptions Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'adam thielen',
#   'Team': 'MIN',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(-145)',
#   'Receptions Under': '(+115)',
#   'Receiving Yards Projection': 'O 69.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+120'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'stefon diggs',
#   'Team': 'BUF',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-145)',
#   'Receptions Under': '(+115)',
#   'Anytime Touchdown Line': '+138',
#   'Receiving Yards Projection': 'O 64.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-111)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'mike evans',
#   'Team': 'TB',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-145)',
#   'Receptions Under': '(+110)',
#   'Anytime Touchdown Line': '-105',
#   'Receiving Yards Projection': 'O 62.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'cooper kupp',
#   'Team': 'LAR',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(+120)',
#   'Receptions Under': '(-150)',
#   'Anytime Touchdown Line': '+130',
#   'Receiving Yards Projection': 'O 63.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-111)'},
#  {'Year': 2020, 'Week': 4, 'Player Name': 'dj moore', 'Team': 'CAR'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'keenan allen',
#   'Team': 'LAC',
#   'Receiving Yards Projection': 'O 62.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-145)',
#   'Receptions Under': '(+115)',
#   'Anytime Touchdown Line': '+175'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'kenny golladay',
#   'Team': 'DET',
#   'Anytime Touchdown Line': '+115',
#   'Receiving Yards Projection': 'O 62.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-105)',
#   'Receptions Under': '(-118)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'odell beckham',
#   'Team': 'CLE',
#   'Anytime Touchdown Line': '+110',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-150)',
#   'Receptions Under': '(+120)',
#   'Receiving Yards Projection': 'O 69.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'devante parker',
#   'Team': 'MIA',
#   'Anytime Touchdown Line': '+160',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-115)',
#   'Receptions Under': '(-115)',
#   'Receiving Yards Projection': 'O 61.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020, 'Week': 4, 'Player Name': 'william fuller', 'Team': 'HOU'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'tyler boyd',
#   'Team': 'CIN',
#   'Anytime Touchdown Line': '+170',
#   'Receiving Yards Projection': 'O 57.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-111)',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(+120)',
#   'Receptions Under': '(-150)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'terry mclaurin',
#   'Team': 'WAS',
#   'Anytime Touchdown Line': '+200',
#   'Receiving Yards Projection': 'O 52.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+102)',
#   'Receptions Under': '(-130)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'julian edelman',
#   'Team': 'NE',
#   'Receiving Yards Projection': 'O 61.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+200',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(+133)',
#   'Receptions Under': '(-164)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'marquise brown',
#   'Team': 'BAL',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(EVEN)',
#   'Receptions Under': '(-130)',
#   'Anytime Touchdown Line': '+150',
#   'Receiving Yards Projection': 'O 41.5',
#   'Receiving Yards Over': '(-111)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'ty hilton',
#   'Team': 'IND',
#   'Receiving Yards Projection': 'O 54.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+175',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+115)',
#   'Receptions Under': '(-145)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'marquez valdesscantling',
#   'Team': 'GB',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-133)',
#   'Receptions Under': '(+110)',
#   'Receiving Yards Projection': 'O 61.0',
#   'Receiving Yards Over': '(-125)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '-115'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'dj chark',
#   'Team': 'JAX',
#   'Anytime Touchdown Line': '+155',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+124)',
#   'Receptions Under': '(-158)',
#   'Receiving Yards Projection': 'O 51.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'darius slayton',
#   'Team': 'NYG',
#   'Anytime Touchdown Line': '+220',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-136)',
#   'Receptions Under': '(+106)',
#   'Receiving Yards Projection': 'O 49.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'jerry jeudy',
#   'Team': 'DEN',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-105)',
#   'Receptions Under': '(-115)',
#   'Anytime Touchdown Line': '+187',
#   'Receiving Yards Projection': 'O 55.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'hunter renfrow',
#   'Team': 'LV',
#   'Receiving Yards Projection': 'O 57.5',
#   'Receiving Yards Over': '(-111)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+240',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-154)',
#   'Receptions Under': '(+125)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'trequan smith',
#   'Team': 'NO',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+126)',
#   'Receptions Under': '(-162)',
#   'Anytime Touchdown Line': '+170',
#   'Receiving Yards Projection': 'O 51.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'brandon aiyuk',
#   'Team': 'SF',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-113)',
#   'Receptions Under': '(-115)',
#   'Receiving Yards Projection': 'O 43.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-111)',
#   'Anytime Touchdown Line': '+180'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'greg ward',
#   'Team': 'PHI',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+105)',
#   'Receptions Under': '(-128)',
#   'Receiving Yards Projection': 'O 46.5',
#   'Receiving Yards Over': '(-111)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+250'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'jamison crowder',
#   'Team': 'NYJ',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-136)',
#   'Receptions Under': '(EVEN)',
#   'Anytime Touchdown Line': '+160',
#   'Receiving Yards Projection': 'O 51.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'deandre hopkins',
#   'Team': 'ARI',
#   'Anytime Touchdown Line': 'EVEN',
#   'Receiving Yards Projection': 'O 75.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 7.5',
#   'Receptions Over': '(+120)',
#   'Receptions Under': '(-125)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'tyreek hill',
#   'Team': 'KC',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(+105)',
#   'Receptions Under': '(-138)',
#   'Anytime Touchdown Line': '-138',
#   'Receiving Yards Projection': 'O 67.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'adam thielen',
#   'Team': 'MIN',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(-125)',
#   'Receptions Under': '(-110)',
#   'Receiving Yards Projection': 'O 80.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': 'EVEN'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'dk metcalf',
#   'Team': 'SEA',
#   'Receiving Yards Projection': 'O 72.5',
#   'Receiving Yards Over': '(-133)',
#   'Receiving Yards Under': '(EVEN)',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-136)',
#   'Receptions Under': '(+106)',
#   'Anytime Touchdown Line': '-120'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'calvin ridley',
#   'Team': 'ATL',
#   'Receiving Yards Projection': 'O 78.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': 'EVEN',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(-156)',
#   'Receptions Under': '(+122)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'amari cooper',
#   'Team': 'DAL',
#   'Anytime Touchdown Line': 'EVEN',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(-156)',
#   'Receptions Under': '(+122)',
#   'Receiving Yards Projection': 'O 76.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'stefon diggs',
#   'Team': 'BUF',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(-128)',
#   'Receptions Under': '(EVEN)',
#   'Anytime Touchdown Line': '+105',
#   'Receiving Yards Projection': 'O 82.5',
#   'Receiving Yards Over': '(-120)',
#   'Receiving Yards Under': '(-111)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'keenan allen',
#   'Team': 'LAC',
#   'Receiving Yards Projection': 'O 81.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-113)',
#   'Receptions Projection': 'O 6.5',
#   'Receptions Over': '(-156)',
#   'Receptions Under': '(+120)',
#   'Anytime Touchdown Line': '+138'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'allen robinson',
#   'Team': 'CHI',
#   'Anytime Touchdown Line': '+138',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(-125)',
#   'Receptions Under': '(-104)',
#   'Receiving Yards Projection': 'O 72.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'cooper kupp',
#   'Team': 'LAR',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(+108)',
#   'Receptions Under': '(-138)',
#   'Receiving Yards Projection': 'O 65.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+125'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'dj chark',
#   'Team': 'JAX',
#   'Receiving Yards Projection': 'O 60.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-115)',
#   'Receptions Under': '(-113)',
#   'Anytime Touchdown Line': '+125'},
#  {'Year': 2020, 'Week': 5, 'Player Name': 'robbie chosen', 'Team': 'CAR'},
#  {'Year': 2020, 'Week': 5, 'Player Name': 'william fuller', 'Team': 'HOU'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'mike evans',
#   'Team': 'TB',
#   'Anytime Touchdown Line': '-118',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-125)',
#   'Receptions Under': '(-105)',
#   'Receiving Yards Projection': 'O 65.5',
#   'Receiving Yards Over': '(-120)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'terry mclaurin',
#   'Team': 'WAS',
#   'Anytime Touchdown Line': '+163',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(EVEN)',
#   'Receptions Under': '(-130)',
#   'Receiving Yards Projection': 'O 71.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'odell beckham',
#   'Team': 'CLE',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-125)',
#   'Receptions Under': '(-110)',
#   'Anytime Touchdown Line': '+120',
#   'Receiving Yards Projection': 'O 63.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'marquise brown',
#   'Team': 'BAL',
#   'Anytime Touchdown Line': '+140',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-160)',
#   'Receptions Under': '(-160)',
#   'Receiving Yards Projection': 'O 53.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'devante parker',
#   'Team': 'MIA',
#   'Receiving Yards Projection': 'O 70.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+163',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-150)',
#   'Receptions Under': '(+114)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'juju smithschuster',
#   'Team': 'PIT',
#   'Receiving Yards Projection': 'O 56.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-150)',
#   'Receptions Under': '(+120)',
#   'Anytime Touchdown Line': '+125'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'tyler boyd',
#   'Team': 'CIN',
#   'Anytime Touchdown Line': '+225',
#   'Receiving Yards Projection': 'O 60.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(+120)',
#   'Receptions Under': '(-154)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'darius slayton',
#   'Team': 'NYG',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+118)',
#   'Receptions Under': '(-150)',
#   'Receiving Yards Projection': 'O 60.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+165'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'jamison crowder',
#   'Team': 'NYJ',
#   'Anytime Touchdown Line': '+170',
#   'Receiving Yards Projection': 'O 61.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(EVEN)',
#   'Receptions Under': '(-130)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'aj brown',
#   'Team': 'TEN',
#   'Receiving Yards Projection': 'O 60.5',
#   'Receiving Yards Over': '(-135)',
#   'Receiving Yards Under': '(+105)',
#   'Anytime Touchdown Line': '+155',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-130)',
#   'Receptions Under': '(EVEN)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'ty hilton',
#   'Team': 'IND',
#   'Anytime Touchdown Line': '+200',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-105)',
#   'Receptions Under': '(-125)',
#   'Receiving Yards Projection': 'O 53.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'brandon aiyuk',
#   'Team': 'SF',
#   'Receiving Yards Projection': 'O 35.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+148)',
#   'Receptions Under': '(-192)',
#   'Anytime Touchdown Line': '+200'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'hunter renfrow',
#   'Team': 'LV',
#   'Anytime Touchdown Line': '+250',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-146)',
#   'Receptions Under': '(+114)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'emmanuel sanders',
#   'Team': 'NO',
#   'Anytime Touchdown Line': '+150',
#   'Receiving Yards Projection': 'O 53.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-160)',
#   'Receptions Under': '(-170)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'greg ward',
#   'Team': 'PHI',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+110)',
#   'Receptions Under': '(-140)',
#   'Anytime Touchdown Line': '+300',
#   'Receiving Yards Projection': 'O 44.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 6,
#   'Player Name': 'deandre hopkins',
#   'Team': 'ARI',
#   'Receptions Projection': 'O 6.5',
#   'Receptions Over': '(-154)',
#   'Receptions Under': '(+115)',
#   'Receiving Yards Projection': 'O 91.5',
#   'Receiving Yards Over': '(-130)',
#   'Receiving Yards Under': '(EVEN)',
#   'Anytime Touchdown Line': '-120'},
#  {'Year': 2020,
#   'Week': 6,
#   'Player Name': 'tyreek hill',
#   'Team': 'KC',
#   'Anytime Touchdown Line': '-145',
#   'Receiving Yards Projection': 'O 71.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(-105)',
#   'Receptions Under': '(-122)'},
#  {'Year': 2020,
#   'Week': 6,
#   'Player Name': 'adam thielen',
#   'Team': 'MIN',
#   'Anytime Touchdown Line': '-110',
#   'Receiving Yards Projection': 'O 84.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(-143)',
#   'Receptions Under': '(+105)'},
#  {'Year': 2020,
#   'Week': 6,
#   'Player Name': 'davante adams',
#   'Team': 'GB',
# ...
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-105)',
#   'Receptions Under': '(-125)',
#   'Anytime Touchdown Line': '+280'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'darnell mooney',
#   'Team': 'CHI',
#   'Anytime Touchdown Line': '+210',
#   'Receiving Yards Projection': 'O 49.5',
#   'Receiving Yards Over': '(-111)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+105)',
#   'Receptions Under': '(-135)'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'devonta smith',
#   'Team': 'PHI',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+105)',
#   'Receptions Under': '(-140)',
#   'Receiving Yards Projection': 'O 45.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+165'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'jarvis landry',
#   'Team': 'CLE',
#   'Anytime Touchdown Line': '+275',
#   'Receiving Yards Projection': 'O 49.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(+120)',
#   'Receptions Under': '(-160)'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'jakobi meyers',
#   'Team': 'NE',
#   'Anytime Touchdown Line': '+200',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-106)',
#   'Receptions Under': '(-125)',
#   'Receiving Yards Projection': 'O 45.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'marvin jones',
#   'Team': 'JAX',
#   'Anytime Touchdown Line': '+200',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-150)',
#   'Receptions Under': '(+115)',
#   'Receiving Yards Projection': 'O 48.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'jerry jeudy',
#   'Team': 'DEN',
#   'Anytime Touchdown Line': '+260',
#   'Receiving Yards Projection': 'O 41.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-120)',
#   'Receptions Under': '(-110)'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'braxton berrios',
#   'Team': 'NYJ',
#   'Anytime Touchdown Line': '+280',
#   'Receiving Yards Projection': 'O 41.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-111)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-135)',
#   'Receptions Under': '(+105)'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'kenny golladay',
#   'Team': 'NYG',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-170)',
#   'Receptions Under': '(+135)',
#   'Receiving Yards Projection': 'O 41.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+310'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'marquez callaway',
#   'Team': 'NO',
#   'Receiving Yards Projection': 'O 35.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-140)',
#   'Receptions Under': '(+105)',
#   'Anytime Touchdown Line': '+310'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'nico collins',
#   'Team': 'HOU',
#   'Anytime Touchdown Line': '+210',
#   'Receiving Yards Projection': 'O 41.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-128)',
#   'Receptions Under': '(EVEN)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'cooper kupp',
#   'Team': 'LAR',
#   'Receptions Projection': 'O 8.5',
#   'Receptions Over': '(-113)',
#   'Receptions Under': '(-113)',
#   'Anytime Touchdown Line': '-164',
#   'Receiving Yards Projection': 'O 109.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'davante adams',
#   'Team': 'GB',
#   'Anytime Touchdown Line': '-155',
#   'Receiving Yards Projection': 'O 90.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 7.5',
#   'Receptions Over': '(+108)',
#   'Receptions Under': '(-138)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'tyreek hill',
#   'Team': 'KC',
#   'Receiving Yards Projection': 'O 74.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '-120',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(-133)',
#   'Receptions Under': '(EVEN)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'deebo samuel',
#   'Team': 'SF',
#   'Anytime Touchdown Line': '-115',
#   'Receiving Yards Projection': 'O 46.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Rushing Yards Projection': 'O 25.5',
#   'Rushing Yards Over': '(-118)',
#   'Rushing Yards Under': '(-110)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-150)',
#   'Receptions Under': '(+115)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'stefon diggs',
#   'Team': 'BUF',
#   'Anytime Touchdown Line': 'EVEN',
#   'Receiving Yards Projection': 'O 72.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(-145)',
#   'Receptions Under': '(+110)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'aj brown',
#   'Team': 'TEN',
#   'Receiving Yards Projection': 'O 71.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(-115)',
#   'Receptions Under': '(-115)',
#   'Anytime Touchdown Line': '+110'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'antonio brown',
#   'Team': 'TB',
#   'Receiving Yards Projection': 'O 77.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '-145'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'tee higgins',
#   'Team': 'CIN',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(-120)',
#   'Receptions Under': '(-110)',
#   'Anytime Touchdown Line': '+150',
#   'Receiving Yards Projection': 'O 70.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'diontae johnson',
#   'Team': 'PIT',
#   'Receptions Projection': 'O 6.5',
#   'Receptions Over': '(-105)',
#   'Receptions Under': '(-125)',
#   'Anytime Touchdown Line': '+115',
#   'Receiving Yards Projection': 'O 72.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'ceedee lamb',
#   'Team': 'DAL',
#   'Receiving Yards Projection': 'O 64.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(-105)',
#   'Receptions Under': '(-125)',
#   'Anytime Touchdown Line': '+120'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'keenan allen',
#   'Team': 'LAC',
#   'Receiving Yards Projection': 'O 73.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(-150)',
#   'Receptions Under': '(+115)',
#   'Anytime Touchdown Line': '+125'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'justin jefferson',
#   'Team': 'MIN',
#   'Receiving Yards Projection': 'O 71.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+165',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(-139)',
#   'Receptions Under': '(+105)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'jaylen waddle',
#   'Team': 'MIA',
#   'Receiving Yards Projection': 'O 70.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 6.5',
#   'Receptions Over': '(-105)',
#   'Receptions Under': '(-125)',
#   'Anytime Touchdown Line': '+170'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'hunter renfrow',
#   'Team': 'LV',
#   'Receiving Yards Projection': 'O 57.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+175',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(-125)',
#   'Receptions Under': '(-110)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'tyler lockett',
#   'Team': 'SEA',
#   'Receiving Yards Projection': 'O 58.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+145'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'amonra st',
#   'Team': 'DET',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(-130)',
#   'Receptions Under': '(EVEN)',
#   'Receiving Yards Projection': 'O 56.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+200',
#   'Rushing Yards Projection': 'O 2.5',
#   'Rushing Yards Over': '(-120)',
#   'Rushing Yards Under': '(-110)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'brandin cooks',
#   'Team': 'HOU',
#   'Anytime Touchdown Line': '+190',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(+105)',
#   'Receptions Under': '(-135)',
#   'Receiving Yards Projection': 'O 64.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'michael pittman',
#   'Team': 'IND',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-120)',
#   'Receptions Under': '(-110)',
#   'Anytime Touchdown Line': '+140',
#   'Receiving Yards Projection': 'O 55.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-111)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'christian kirk',
#   'Team': 'ARI',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-130)',
#   'Receptions Under': '(EVEN)',
#   'Receiving Yards Projection': 'O 59.5',
#   'Receiving Yards Over': '(-111)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+210'},
#  {'Year': 2021, 'Week': 17, 'Player Name': 'dj moore', 'Team': 'CAR'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'devonta smith',
#   'Team': 'PHI',
#   'Anytime Touchdown Line': '+175',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+130)',
#   'Receptions Under': '(-165)',
#   'Receiving Yards Projection': 'O 55.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'marquise brown',
#   'Team': 'BAL',
#   'Receiving Yards Projection': 'O 51.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(+118)',
#   'Receptions Under': '(-150)',
#   'Anytime Touchdown Line': '+200'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'terry mclaurin',
#   'Team': 'WAS',
#   'Anytime Touchdown Line': '+180',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+110)',
#   'Receptions Under': '(-140)',
#   'Receiving Yards Projection': 'O 50.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'russell gage',
#   'Team': 'ATL',
#   'Anytime Touchdown Line': '+275',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-105)',
#   'Receptions Under': '(-125)',
#   'Receiving Yards Projection': 'O 47.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-111)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'darnell mooney',
#   'Team': 'CHI',
#   'Receiving Yards Projection': 'O 43.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-111)',
#   'Anytime Touchdown Line': '+220'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'jarvis landry',
#   'Team': 'CLE',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-149)',
#   'Receptions Under': '(+115)',
#   'Receiving Yards Projection': 'O 47.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+190'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'jakobi meyers',
#   'Team': 'NE',
#   'Receiving Yards Projection': 'O 45.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+187'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'braxton berrios',
#   'Team': 'NYJ',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-170)',
#   'Receptions Under': '(+115)',
#   'Anytime Touchdown Line': '+290',
#   'Receiving Yards Projection': 'O 48.5',
#   'Receiving Yards Over': '(-111)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'courtland sutton',
#   'Team': 'DEN',
#   'Receiving Yards Projection': 'O 43.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-111)',
#   'Anytime Touchdown Line': '+250'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'marvin jones',
#   'Team': 'JAX',
#   'Receiving Yards Projection': 'O 41.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-110)',
#   'Receptions Under': '(-120)',
#   'Anytime Touchdown Line': '+300'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'kenny golladay',
#   'Team': 'NYG',
#   'Anytime Touchdown Line': '+250'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'marquez callaway',
#   'Team': 'NO',
#   'Receiving Yards Projection': 'O 37.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-120)',
#   'Anytime Touchdown Line': '+250',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-160)',
#   'Receptions Under': '(+120)'},
#  {'Year': 2022,
#   'Week': 1,
#   'Player Name': 'justin jefferson',
#   'Team': 'MIN',
#   'Receptions Projection': 'O 6.5',
#   'Receptions Over': '(EVEN)',
#   'Receptions Under': '(-130)',
#   'Receiving Yards Projection': 'O 82.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '-120'},
#  {'Year': 2022,
#   'Week': 1,
#   'Player Name': 'cooper kupp',
#   'Team': 'LAR',
#   'Anytime Touchdown Line': '-200',
#   'Receiving Yards Projection': 'O 90.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 7.5',
#   'Receptions Over': '(-105)',
#   'Receptions Under': '(-125)'},
#  {'Year': 2022,
#   'Week': 1,
#   'Player Name': 'jamarr chase',
#   'Team': 'CIN',
#   'Anytime Touchdown Line': '+105',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(-102)',
#   'Receptions Under': '(-125)',
#   'Receiving Yards Projection': 'O 73.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2022,
#   'Week': 1,
#   'Player Name': 'davante adams',
#   'Team': 'LV',
#   'Anytime Touchdown Line': '-110',
#   'Receptions Projection': 'O 6.5',
#   'Receptions Over': '(-135)',
#   'Receptions Under': '(-113)',
#   'Receiving Yards Projection': 'O 79.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2022,
#   'Week': 1,
#   'Player Name': 'stefon diggs',
#   'Team': 'BUF',
#   'Anytime Touchdown Line': 'EVEN',
#   'Receiving Yards Projection': 'O 65.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(-136)',
#   'Receptions Under': '(+106)'},
#  {'Year': 2022,
#   'Week': 1,
#   'Player Name': 'ceedee lamb',
#   'Team': 'DAL',
#   'Receiving Yards Projection': 'O 72.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(-140)',
#   'Receptions Under': '(+102)',
#   'Anytime Touchdown Line': '-110'},
#  {'Year': 2022,
#   'Week': 1,
#   'Player Name': 'mike evans',
#   'Team': 'TB',
#   'Receiving Yards Projection': 'O 66.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(+102)',
#   'Receptions Under': '(-165)',
#   'Anytime Touchdown Line': '-110'},
#  {'Year': 2022,
#   'Week': 1,
#   'Player Name': 'michael pittman',
#   'Team': 'IND',
#   'Anytime Touchdown Line': '+135',
#   'Receiving Yards Projection': 'O 65.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(EVEN)',
#   'Receptions Under': '(-138)'},
#  ...]

# %%
import pandas as pd

df = pd.json_normalize(d)

df
# Out:
#       Year  Week       Player Name Team Receptions Projection Receptions Over  \
# 0     2020     1    michael thomas   NO                   NaN             NaN
# 1     2020     1     davante adams   GB                 O 7.5          (+105)
# 2     2020     1       julio jones  ATL                 O 6.5          (-130)
# 3     2020     1       tyreek hill   KC                 O 5.5          (+112)
# 4     2020     1      chris godwin   TB                 O 5.5          (-140)
# ...    ...   ...               ...  ...                   ...             ...
# 2011  2023    17   demario douglas   NE                 O 5.5          (+124)
# 2012  2023    17      elijah moore  CLE                 O 3.5          (-135)
# 2013  2023    17  wandale robinson  NYG                 O 3.5          (-139)
# 2014  2023    17  quentin johnston  LAC                 O 3.5          (+125)
# 2015  2023    17    michael wilson  ARI                 O 2.5          (-125)
#
#      Receptions Under Anytime Touchdown Line Receiving Yards Projection  \
# 0                 NaN                    NaN                        NaN
# 1              (-125)                   +110                     O 87.5
# 2              (+110)                   +110                     O 92.5
# 3              (-142)                   -130                     O 74.5
# 4              (+106)                   +125                     O 70.5
# ...               ...                    ...                        ...
# 2011           (-166)                   +440                     O 49.5
# 2012           (EVEN)                   +220                     O 43.5
# 2013           (+105)                   +390                     O 33.5
# 2014           (-165)                   +350                     O 36.5
# 2015           (-106)                   +300                     O 30.5
#
#      Receiving Yards Over Receiving Yards Under Rushing Yards Projection  \
# 0                     NaN                   NaN                      NaN
# 1                  (-110)                (-110)                      NaN
# 2                  (-110)                (-110)                      NaN
# 3                  (-110)                (-110)                      NaN
# 4                  (-110)                (-110)                      NaN
# ...                   ...                   ...                      ...
# 2011               (-110)                (-115)                      NaN
# 2012               (-115)                (-111)                      NaN
# 2013               (-110)                (-115)                      NaN
# 2014               (-110)                (-115)                      NaN
# 2015               (-117)                (-110)                      NaN
#
#      Rushing Yards Over Rushing Yards Under
# 0                   NaN                 NaN
# 1                   NaN                 NaN
# 2                   NaN                 NaN
# 3                   NaN                 NaN
# 4                   NaN                 NaN
# ...                 ...                 ...
# 2011                NaN                 NaN
# 2012                NaN                 NaN
# 2013                NaN                 NaN
# 2014                NaN                 NaN
# 2015                NaN                 NaN
#
# [2016 rows x 14 columns]

# %%
for column in ('Rushing Yards Projection', 'Receiving Yards Projection', 'Receptions Projection'):
    df[column] = df[column].str.extract(r'(\d+\.\d+)').astype(float)

df
# Out:
#       Year  Week       Player Name Team  Receptions Projection  \
# 0     2020     1    michael thomas   NO                    NaN
# 1     2020     1     davante adams   GB                    7.5
# 2     2020     1       julio jones  ATL                    6.5
# 3     2020     1       tyreek hill   KC                    5.5
# 4     2020     1      chris godwin   TB                    5.5
# ...    ...   ...               ...  ...                    ...
# 2011  2023    17   demario douglas   NE                    5.5
# 2012  2023    17      elijah moore  CLE                    3.5
# 2013  2023    17  wandale robinson  NYG                    3.5
# 2014  2023    17  quentin johnston  LAC                    3.5
# 2015  2023    17    michael wilson  ARI                    2.5
#
#      Receptions Over Receptions Under Anytime Touchdown Line  \
# 0                NaN              NaN                    NaN
# 1             (+105)           (-125)                   +110
# 2             (-130)           (+110)                   +110
# 3             (+112)           (-142)                   -130
# 4             (-140)           (+106)                   +125
# ...              ...              ...                    ...
# 2011          (+124)           (-166)                   +440
# 2012          (-135)           (EVEN)                   +220
# 2013          (-139)           (+105)                   +390
# 2014          (+125)           (-165)                   +350
# 2015          (-125)           (-106)                   +300
#
#       Receiving Yards Projection Receiving Yards Over Receiving Yards Under  \
# 0                            NaN                  NaN                   NaN
# 1                           87.5               (-110)                (-110)
# 2                           92.5               (-110)                (-110)
# 3                           74.5               (-110)                (-110)
# 4                           70.5               (-110)                (-110)
# ...                          ...                  ...                   ...
# 2011                        49.5               (-110)                (-115)
# 2012                        43.5               (-115)                (-111)
# 2013                        33.5               (-110)                (-115)
# 2014                        36.5               (-110)                (-115)
# 2015                        30.5               (-117)                (-110)
#
#       Rushing Yards Projection Rushing Yards Over Rushing Yards Under
# 0                          NaN                NaN                 NaN
# 1                          NaN                NaN                 NaN
# 2                          NaN                NaN                 NaN
# 3                          NaN                NaN                 NaN
# 4                          NaN                NaN                 NaN
# ...                        ...                ...                 ...
# 2011                       NaN                NaN                 NaN
# 2012                       NaN                NaN                 NaN
# 2013                       NaN                NaN                 NaN
# 2014                       NaN                NaN                 NaN
# 2015                       NaN                NaN                 NaN
#
# [2016 rows x 14 columns]

# %%
for column in ('Rushing Yards Over', 'Rushing Yards Under', 'Receiving Yards Over', 'Receiving Yards Under', 'Receptions Over', 'Receptions Under'):
    df.loc[df[column].str.contains('EVEN', regex=False, na=False), column] = '100'
    df.loc[df[column] == '--', column] = 'nan'
    df[column] = df[column].str.replace(r'\(|\)', '', regex=True).astype(float)

df
# Out:
#       Year  Week       Player Name Team  Receptions Projection  \
# 0     2020     1    michael thomas   NO                    NaN
# 1     2020     1     davante adams   GB                    7.5
# 2     2020     1       julio jones  ATL                    6.5
# 3     2020     1       tyreek hill   KC                    5.5
# 4     2020     1      chris godwin   TB                    5.5
# ...    ...   ...               ...  ...                    ...
# 2011  2023    17   demario douglas   NE                    5.5
# 2012  2023    17      elijah moore  CLE                    3.5
# 2013  2023    17  wandale robinson  NYG                    3.5
# 2014  2023    17  quentin johnston  LAC                    3.5
# 2015  2023    17    michael wilson  ARI                    2.5
#
#       Receptions Over  Receptions Under Anytime Touchdown Line  \
# 0                 NaN               NaN                    NaN
# 1               105.0            -125.0                   +110
# 2              -130.0             110.0                   +110
# 3               112.0            -142.0                   -130
# 4              -140.0             106.0                   +125
# ...               ...               ...                    ...
# 2011            124.0            -166.0                   +440
# 2012           -135.0             100.0                   +220
# 2013           -139.0             105.0                   +390
# 2014            125.0            -165.0                   +350
# 2015           -125.0            -106.0                   +300
#
#       Receiving Yards Projection  Receiving Yards Over  Receiving Yards Under  \
# 0                            NaN                   NaN                    NaN
# 1                           87.5                -110.0                 -110.0
# 2                           92.5                -110.0                 -110.0
# 3                           74.5                -110.0                 -110.0
# 4                           70.5                -110.0                 -110.0
# ...                          ...                   ...                    ...
# 2011                        49.5                -110.0                 -115.0
# 2012                        43.5                -115.0                 -111.0
# 2013                        33.5                -110.0                 -115.0
# 2014                        36.5                -110.0                 -115.0
# 2015                        30.5                -117.0                 -110.0
#
#       Rushing Yards Projection  Rushing Yards Over  Rushing Yards Under
# 0                          NaN                 NaN                  NaN
# 1                          NaN                 NaN                  NaN
# 2                          NaN                 NaN                  NaN
# 3                          NaN                 NaN                  NaN
# 4                          NaN                 NaN                  NaN
# ...                        ...                 ...                  ...
# 2011                       NaN                 NaN                  NaN
# 2012                       NaN                 NaN                  NaN
# 2013                       NaN                 NaN                  NaN
# 2014                       NaN                 NaN                  NaN
# 2015                       NaN                 NaN                  NaN
#
# [2016 rows x 14 columns]

# %%
for column in ('Anytime Touchdown Line', ):
    df.loc[df[column].str.contains('EVEN', regex=False, na=False), column] = '100'
    df.loc[df[column] == '--', column] = 'nan'
    df[column] = df[column].astype(float)

df
# Out:
#       Year  Week       Player Name Team  Receptions Projection  \
# 0     2020     1    michael thomas   NO                    NaN
# 1     2020     1     davante adams   GB                    7.5
# 2     2020     1       julio jones  ATL                    6.5
# 3     2020     1       tyreek hill   KC                    5.5
# 4     2020     1      chris godwin   TB                    5.5
# ...    ...   ...               ...  ...                    ...
# 2011  2023    17   demario douglas   NE                    5.5
# 2012  2023    17      elijah moore  CLE                    3.5
# 2013  2023    17  wandale robinson  NYG                    3.5
# 2014  2023    17  quentin johnston  LAC                    3.5
# 2015  2023    17    michael wilson  ARI                    2.5
#
#       Receptions Over  Receptions Under  Anytime Touchdown Line  \
# 0                 NaN               NaN                     NaN
# 1               105.0            -125.0                   110.0
# 2              -130.0             110.0                   110.0
# 3               112.0            -142.0                  -130.0
# 4              -140.0             106.0                   125.0
# ...               ...               ...                     ...
# 2011            124.0            -166.0                   440.0
# 2012           -135.0             100.0                   220.0
# 2013           -139.0             105.0                   390.0
# 2014            125.0            -165.0                   350.0
# 2015           -125.0            -106.0                   300.0
#
#       Receiving Yards Projection  Receiving Yards Over  Receiving Yards Under  \
# 0                            NaN                   NaN                    NaN
# 1                           87.5                -110.0                 -110.0
# 2                           92.5                -110.0                 -110.0
# 3                           74.5                -110.0                 -110.0
# 4                           70.5                -110.0                 -110.0
# ...                          ...                   ...                    ...
# 2011                        49.5                -110.0                 -115.0
# 2012                        43.5                -115.0                 -111.0
# 2013                        33.5                -110.0                 -115.0
# 2014                        36.5                -110.0                 -115.0
# 2015                        30.5                -117.0                 -110.0
#
#       Rushing Yards Projection  Rushing Yards Over  Rushing Yards Under
# 0                          NaN                 NaN                  NaN
# 1                          NaN                 NaN                  NaN
# 2                          NaN                 NaN                  NaN
# 3                          NaN                 NaN                  NaN
# 4                          NaN                 NaN                  NaN
# ...                        ...                 ...                  ...
# 2011                       NaN                 NaN                  NaN
# 2012                       NaN                 NaN                  NaN
# 2013                       NaN                 NaN                  NaN
# 2014                       NaN                 NaN                  NaN
# 2015                       NaN                 NaN                  NaN
#
# [2016 rows x 14 columns]

# %%
def american_odds_to_probability(odds):
    """
    Converts American betting odds to implied probability.
    
    Args:
        odds (int or float): The American odds value (e.g., -150, +200).

    Returns:
        float: The implied probability as a decimal (e.g., 0.60 for 60%).
    """
    if odds > 0:
        # Positive odds: (100 / (odds + 100))
        probability = 100 / (odds + 100)
    else:
        # Negative odds: (-odds / (-odds + 100))
        probability = -odds / (-odds + 100)
    
    return probability

# %% [markdown]
# Adjust projections based on over/under lines

# %%
for stat in ('Rushing Yards', 'Receiving Yards', 'Receptions'):
    df[f'Adjusted {stat} Projection'] = (
        df[f'{stat} Projection'] +
        0.5 * df[f'{stat} Over'].apply(american_odds_to_probability) -
        0.5 * df[f'{stat} Under'].apply(american_odds_to_probability)
    )

df
# Out:
#       Year  Week       Player Name Team  Receptions Projection  \
# 0     2020     1    michael thomas   NO                    NaN
# 1     2020     1     davante adams   GB                    7.5
# 2     2020     1       julio jones  ATL                    6.5
# 3     2020     1       tyreek hill   KC                    5.5
# 4     2020     1      chris godwin   TB                    5.5
# ...    ...   ...               ...  ...                    ...
# 2011  2023    17   demario douglas   NE                    5.5
# 2012  2023    17      elijah moore  CLE                    3.5
# 2013  2023    17  wandale robinson  NYG                    3.5
# 2014  2023    17  quentin johnston  LAC                    3.5
# 2015  2023    17    michael wilson  ARI                    2.5
#
#       Receptions Over  Receptions Under  Anytime Touchdown Line  \
# 0                 NaN               NaN                     NaN
# 1               105.0            -125.0                   110.0
# 2              -130.0             110.0                   110.0
# 3               112.0            -142.0                  -130.0
# 4              -140.0             106.0                   125.0
# ...               ...               ...                     ...
# 2011            124.0            -166.0                   440.0
# 2012           -135.0             100.0                   220.0
# 2013           -139.0             105.0                   390.0
# 2014            125.0            -165.0                   350.0
# 2015           -125.0            -106.0                   300.0
#
#       Receiving Yards Projection  Receiving Yards Over  Receiving Yards Under  \
# 0                            NaN                   NaN                    NaN
# 1                           87.5                -110.0                 -110.0
# 2                           92.5                -110.0                 -110.0
# 3                           74.5                -110.0                 -110.0
# 4                           70.5                -110.0                 -110.0
# ...                          ...                   ...                    ...
# 2011                        49.5                -110.0                 -115.0
# 2012                        43.5                -115.0                 -111.0
# 2013                        33.5                -110.0                 -115.0
# 2014                        36.5                -110.0                 -115.0
# 2015                        30.5                -117.0                 -110.0
#
#       Rushing Yards Projection  Rushing Yards Over  Rushing Yards Under  \
# 0                          NaN                 NaN                  NaN
# 1                          NaN                 NaN                  NaN
# 2                          NaN                 NaN                  NaN
# 3                          NaN                 NaN                  NaN
# 4                          NaN                 NaN                  NaN
# ...                        ...                 ...                  ...
# 2011                       NaN                 NaN                  NaN
# 2012                       NaN                 NaN                  NaN
# 2013                       NaN                 NaN                  NaN
# 2014                       NaN                 NaN                  NaN
# 2015                       NaN                 NaN                  NaN
#
#       Adjusted Rushing Yards Projection  Adjusted Receiving Yards Projection  \
# 0                                   NaN                                  NaN
# 1                                   NaN                            87.500000
# 2                                   NaN                            92.500000
# 3                                   NaN                            74.500000
# 4                                   NaN                            70.500000
# ...                                 ...                                  ...
# 2011                                NaN                            49.494463
# 2012                                NaN                            43.504409
# 2013                                NaN                            33.494463
# 2014                                NaN                            36.494463
# 2015                                NaN                            30.507680
#
#       Adjusted Receptions Projection
# 0                                NaN
# 1                           7.466125
# 2                           6.544513
# 3                           5.442461
# 4                           5.548948
# ...                              ...
# 2011                        5.411184
# 2012                        3.537234
# 2013                        3.546893
# 2014                        3.410901
# 2015                        2.520496
#
# [2016 rows x 17 columns]

# %%
df['Anytime Touchdown Probability'] = df['Anytime Touchdown Line'].apply(american_odds_to_probability)

df
# Out:
#       Year  Week       Player Name Team  Receptions Projection  \
# 0     2020     1    michael thomas   NO                    NaN
# 1     2020     1     davante adams   GB                    7.5
# 2     2020     1       julio jones  ATL                    6.5
# 3     2020     1       tyreek hill   KC                    5.5
# 4     2020     1      chris godwin   TB                    5.5
# ...    ...   ...               ...  ...                    ...
# 2011  2023    17   demario douglas   NE                    5.5
# 2012  2023    17      elijah moore  CLE                    3.5
# 2013  2023    17  wandale robinson  NYG                    3.5
# 2014  2023    17  quentin johnston  LAC                    3.5
# 2015  2023    17    michael wilson  ARI                    2.5
#
#       Receptions Over  Receptions Under  Anytime Touchdown Line  \
# 0                 NaN               NaN                     NaN
# 1               105.0            -125.0                   110.0
# 2              -130.0             110.0                   110.0
# 3               112.0            -142.0                  -130.0
# 4              -140.0             106.0                   125.0
# ...               ...               ...                     ...
# 2011            124.0            -166.0                   440.0
# 2012           -135.0             100.0                   220.0
# 2013           -139.0             105.0                   390.0
# 2014            125.0            -165.0                   350.0
# 2015           -125.0            -106.0                   300.0
#
#       Receiving Yards Projection  Receiving Yards Over  Receiving Yards Under  \
# 0                            NaN                   NaN                    NaN
# 1                           87.5                -110.0                 -110.0
# 2                           92.5                -110.0                 -110.0
# 3                           74.5                -110.0                 -110.0
# 4                           70.5                -110.0                 -110.0
# ...                          ...                   ...                    ...
# 2011                        49.5                -110.0                 -115.0
# 2012                        43.5                -115.0                 -111.0
# 2013                        33.5                -110.0                 -115.0
# 2014                        36.5                -110.0                 -115.0
# 2015                        30.5                -117.0                 -110.0
#
#       Rushing Yards Projection  Rushing Yards Over  Rushing Yards Under  \
# 0                          NaN                 NaN                  NaN
# 1                          NaN                 NaN                  NaN
# 2                          NaN                 NaN                  NaN
# 3                          NaN                 NaN                  NaN
# 4                          NaN                 NaN                  NaN
# ...                        ...                 ...                  ...
# 2011                       NaN                 NaN                  NaN
# 2012                       NaN                 NaN                  NaN
# 2013                       NaN                 NaN                  NaN
# 2014                       NaN                 NaN                  NaN
# 2015                       NaN                 NaN                  NaN
#
#       Adjusted Rushing Yards Projection  Adjusted Receiving Yards Projection  \
# 0                                   NaN                                  NaN
# 1                                   NaN                            87.500000
# 2                                   NaN                            92.500000
# 3                                   NaN                            74.500000
# 4                                   NaN                            70.500000
# ...                                 ...                                  ...
# 2011                                NaN                            49.494463
# 2012                                NaN                            43.504409
# 2013                                NaN                            33.494463
# 2014                                NaN                            36.494463
# 2015                                NaN                            30.507680
#
#       Adjusted Receptions Projection  Anytime Touchdown Probability
# 0                                NaN                            NaN
# 1                           7.466125                       0.476190
# 2                           6.544513                       0.476190
# 3                           5.442461                       0.565217
# 4                           5.548948                       0.444444
# ...                              ...                            ...
# 2011                        5.411184                       0.185185
# 2012                        3.537234                       0.312500
# 2013                        3.546893                       0.204082
# 2014                        3.410901                       0.222222
# 2015                        2.520496                       0.250000
#
# [2016 rows x 18 columns]

# %%
df.to_parquet(r'..\..\data\betting_lines\wr1_props.parquet')

print('Done')
# Out:
# Done
