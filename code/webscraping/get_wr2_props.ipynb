# %% [markdown]
# Find relevant wide receivers to webscrape

# %%
import pandas as pd

pd.set_option('display.max_columns', 100)

df_superflex_rankings = pd.read_parquet(r'..\..\data\fantasypros_in_season_rankings\superflex_rankings.parquet')

df_superflex_rankings = df_superflex_rankings.loc[df_superflex_rankings['Player Name'].notna(), :].reset_index(drop=True)

df_superflex_rankings
# Out:
#        Year  Week   RK        Player Name POS  POS RK
# 0      2018     1    1     Todd Gurley II  RB       1
# 1      2018     1    2      David Johnson  RB       2
# 2      2018     1    3       Alvin Kamara  RB       3
# 3      2018     1    4  Melvin Gordon III  RB       4
# 4      2018     1    5    Ezekiel Elliott  RB       5
# ...     ...   ...  ...                ...  ..     ...
# 41050  2023    17  461    Steven Sims Jr.  WR     183
# 41051  2023    17  462     Jashaun Corbin  RB     112
# 41052  2023    17  463       Dee Eskridge  WR     184
# 41053  2023    17  464       Clayton Tune  QB      65
# 41054  2023    17  465      Brady Russell  TE     104
#
# [41055 rows x 6 columns]

# %%
df_wr = df_superflex_rankings.loc[df_superflex_rankings['POS'] == 'WR', :].sort_values(['Year', 'Week', 'POS RK'], ignore_index=True)

df_wr = df_wr.loc[df_wr['Year'] >= 2020, :].reset_index(drop=True)  # for now

df_wr.sort_values(['Year', 'Week', 'POS RK'], ignore_index=True, inplace=True)

df_wr
# Out:
#        Year  Week   RK       Player Name POS  POS RK
# 0      2020     1   21    Michael Thomas  WR       1
# 1      2020     1   33     Davante Adams  WR       2
# 2      2020     1   36       Julio Jones  WR       3
# 3      2020     1   37       Tyreek Hill  WR       4
# 4      2020     1   45      Chris Godwin  WR       5
# ...     ...   ...  ...               ...  ..     ...
# 11449  2023    17  458     Lucky Jackson  WR     180
# 11450  2023    17  459         DJ Turner  WR     181
# 11451  2023    17  460  Laquon Treadwell  WR     182
# 11452  2023    17  461   Steven Sims Jr.  WR     183
# 11453  2023    17  463      Dee Eskridge  WR     184
#
# [11454 rows x 6 columns]

# %%
df_wr.loc[df_wr['Player Name'].str.contains('-'), 'Player Name'].unique()
# Out:
# array(['JuJu Smith-Schuster', 'Marquez Valdes-Scantling',
#        'J.J. Arcega-Whiteside', 'Antonio Gandy-Golden',
#        'Ray-Ray McCloud III', 'Nick Westbrook-Ikhine',
#        'Tyron Billy-Johnson', 'Donovan Peoples-Jones',
#        'Amon-Ra St. Brown', 'Ihmir Smith-Marsette',
#        'Anthony Ratliff-Williams', 'Jaxon Smith-Njigba'], dtype=object)

# %%
df_wr.loc[df_wr['Player Name'].str.contains(r'(Sr\.|Jr\.)$', regex=True), 'Player Name'].unique()
# Out:
# C:\Users\mhugh\AppData\Local\Temp\ipykernel_8420\1394298560.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df_wr.loc[df_wr['Player Name'].str.contains(r'(Sr\.|Jr\.)$', regex=True), 'Player Name'].unique()
# array(['DJ Chark Jr.', 'Odell Beckham Jr.', 'Marvin Jones Jr.',
#        'Mecole Hardman Jr.', 'Steven Sims Jr.', 'Michael Pittman Jr.',
#        'Laviska Shenault Jr.', 'Jakeem Grant Sr.', 'Ted Ginn Jr.',
#        'Keelan Cole Sr.', 'Mohamed Sanu Sr.', 'KJ Hill Jr.',
#        'Cedrick Wilson Jr.', 'Jason Moore Jr.', 'Richie James Jr.',
#        'Trent Sherfield Sr.', 'Steven Mitchell Jr.', 'Cyril Grayson Jr.',
#        'Lynn Bowden Jr.', 'Victor Bolden Jr.', 'Paul Richardson Jr.',
#        'Deebo Samuel Sr.', 'Stanley Morgan Jr.', 'Terrace Marshall Jr.',
#        'Easop Winston Jr.', 'Jeff Cotton Jr.', 'Kaylon Geiger Sr.',
#        'Justin Hardee Sr.', 'Velus Jones Jr.', 'Marvin Mims Jr.',
#        'Austin Watkins Jr.'], dtype=object)

# %%
# make names easier to match
df_wr['Player Name'] = (
    df_wr['Player Name']
    .str.split().str[:2].str.join(' ')  # make names just the first two words
    .str.replace(r'[^a-zA-Z0-9\s]', '', regex=True)  # remove non-alphanumeric characters
    .str.lower()  # lowercase only (helps with matching)
)

df_wr
# Out:
#        Year  Week   RK       Player Name POS  POS RK
# 0      2020     1   21    michael thomas  WR       1
# 1      2020     1   33     davante adams  WR       2
# 2      2020     1   36       julio jones  WR       3
# 3      2020     1   37       tyreek hill  WR       4
# 4      2020     1   45      chris godwin  WR       5
# ...     ...   ...  ...               ...  ..     ...
# 11449  2023    17  458     lucky jackson  WR     180
# 11450  2023    17  459         dj turner  WR     181
# 11451  2023    17  460  laquon treadwell  WR     182
# 11452  2023    17  461       steven sims  WR     183
# 11453  2023    17  463      dee eskridge  WR     184
#
# [11454 rows x 6 columns]

# %% [markdown]
# Filter to relevant players

# %%
df_teams = pd.read_parquet('../../data/fantasy_points/footballguys_half_ppr.parquet')[['Season', 'Week', 'Name', 'Team', 'Position']]

df_teams['Name'] = (
    df_teams['Name'].str.split().str[:2].str.join(' ')  # make names just the first two words
    .str.replace(r'[^a-zA-Z0-9\s]', '', regex=True)  # remove non-alphanumeric characters
    .str.lower()  # lowercase only (helps with matching)
)

df_teams = df_teams.loc[df_teams['Position'] == 'WR', :].reset_index(drop=True)

df_teams
# Out:
#        Season  Week               Name Team Position
# 0        2018     1        tyreek hill   KC       WR
# 1        2018     1     michael thomas   NO       WR
# 2        2018     1     desean jackson   TB       WR
# 3        2018     1       randall cobb   GB       WR
# 4        2018     1       kenny stills  MIA       WR
# ...       ...   ...                ...  ...      ...
# 14200    2023    17   laquon treadwell  BAL       WR
# 14201    2023    17    kavontae turpin  DAL       WR
# 14202    2023    17      tylan wallace  BAL       WR
# 14203    2023    17  olamide zaccheaus  PHI       WR
# 14204    2023    17       samori toure   GB       WR
#
# [14205 rows x 5 columns]

# %% [markdown]
# Fix players with difficult names

# %%
df_teams.loc[df_teams['Name'] == 'will fuller', 'Name'] = 'william fuller'

# %%
df_wr = df_wr.merge(
    df_teams.rename(columns={'Season': 'Year', 'Name': 'Player Name', 'Position': 'POS'}),
    how='left',
    on=['Year', 'Week', 'Player Name', 'POS'],
)

df_wr.loc[(df_wr['Team'].isna()) & (df_wr['POS RK'] <= 25), :]

# 2022 Week 17 Bills at Bengals was cancelled
# Out:
#       Year  Week  RK   Player Name POS  POS RK Team
# 8359  2022    17  20  jamarr chase  WR       2  NaN

# %%
df_wr.loc[(df_wr['Team'].isna()) & (df_wr['POS RK'] <= 32*3), :].groupby(['Player Name'])['POS'].count()
# Out:
# Player Name
# aj green                   1
# albert wilson              2
# antonio gandygolden        1
# bisi johnson               3
# brandon zylstra            1
# braxton berrios            1
# dee eskridge               1
# denzel mims                1
# donovan peoplesjones       1
# gabe davis                 1
# greg dortch                1
# jamarr chase               1
# jarvis landry              1
# josh reynolds              1
# khadarel hodge             1
# marquez valdesscantling    1
# mecole hardman             1
# parris campbell            1
# rayray mccloud             1
# terrace marshall           2
# tom kennedy                1
# trenton irwin              1
# Name: POS, dtype: int64

# %%
df_wr = df_wr.loc[df_wr['Team'].notna(), :].reset_index(drop=True)

df_wr
# Out:
#       Year  Week   RK       Player Name POS  POS RK Team
# 0     2020     1   21    michael thomas  WR       1   NO
# 1     2020     1   33     davante adams  WR       2   GB
# 2     2020     1   36       julio jones  WR       3  ATL
# 3     2020     1   37       tyreek hill  WR       4   KC
# 4     2020     1   45      chris godwin  WR       5   TB
# ...    ...   ...  ...               ...  ..     ...  ...
# 9697  2023    17  414      jalen brooks  WR     168  DAL
# 9698  2023    17  423       keelan doss  WR     171  LAC
# 9699  2023    17  448   austin trammell  WR     177  LAR
# 9700  2023    17  458     lucky jackson  WR     180  MIN
# 9701  2023    17  460  laquon treadwell  WR     182  BAL
#
# [9702 rows x 7 columns]

# %%
df_wr = df_wr.groupby(['Year', 'Week', 'Team']).nth(1).reset_index(drop=True)

df_wr
# Out:
#       Year  Week   RK      Player Name POS  POS RK Team
# 0     2020     1   61    calvin ridley  WR      12  ATL
# 1     2020     1   64      cooper kupp  WR      14  LAR
# 2     2020     1   73       dk metcalf  WR      20  SEA
# 3     2020     1   84   michael gallup  WR      26  DAL
# 4     2020     1   90         aj green  WR      31  CIN
# ...    ...   ...  ...              ...  ..     ...  ...
# 2011  2023    17  176  brandon johnson  WR      72  DEN
# 2012  2023    17  198    alex erickson  WR      78  LAC
# 2013  2023    17  210    xavier gipson  WR      83  NYJ
# 2014  2023    17  219      tyler scott  WR      90  CHI
# 2015  2023    17  270    van jefferson  WR     112  ATL
#
# [2016 rows x 7 columns]

# %%
df_wr['Player Name URL'] = df_wr['Player Name'].str.replace(' ', '-')

# fix players who are known to have issues
df_wr.loc[df_wr['Player Name'] == 'juju smithschuster', 'Player Name URL'] = 'juju-smith-schuster'
df_wr.loc[df_wr['Player Name'] == 'jj arcegawhiteside', 'Player Name URL'] = 'jj-arcega-whiteside'
df_wr.loc[df_wr['Player Name'] == 'rayray mccloud', 'Player Name URL'] = 'ray-ray-mccloud'
df_wr.loc[df_wr['Player Name'] == 'donovan peoplesjones', 'Player Name URL'] = 'donovan-peoples-jones'
df_wr.loc[df_wr['Player Name'] == 'amonra st', 'Player Name URL'] = 'amonra-stbrown'
df_wr.loc[df_wr['Player Name'] == 'jaxon smithnjigba', 'Player Name URL'] = 'jaxon-smith-njigba'
df_wr.loc[df_wr['Player Name'] == 'ted ginn', 'Player Name URL'] = 'ted-ginn-jr'


df_wr
# Out:
#       Year  Week   RK      Player Name POS  POS RK Team  Player Name URL
# 0     2020     1   61    calvin ridley  WR      12  ATL    calvin-ridley
# 1     2020     1   64      cooper kupp  WR      14  LAR      cooper-kupp
# 2     2020     1   73       dk metcalf  WR      20  SEA       dk-metcalf
# 3     2020     1   84   michael gallup  WR      26  DAL   michael-gallup
# 4     2020     1   90         aj green  WR      31  CIN         aj-green
# ...    ...   ...  ...              ...  ..     ...  ...              ...
# 2011  2023    17  176  brandon johnson  WR      72  DEN  brandon-johnson
# 2012  2023    17  198    alex erickson  WR      78  LAC    alex-erickson
# 2013  2023    17  210    xavier gipson  WR      83  NYJ    xavier-gipson
# 2014  2023    17  219      tyler scott  WR      90  CHI      tyler-scott
# 2015  2023    17  270    van jefferson  WR     112  ATL    van-jefferson
#
# [2016 rows x 8 columns]

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

options = Options()
# options.add_argument('--headless')

driver = webdriver.Chrome(options=options)

# %%
import time
from selenium.webdriver.common.by import By

def scrape_props(player_name, player_name_url, year, week, team):
    driver.get(url=f"https://www.bettingpros.com/nfl/odds/player-props/{player_name_url}/?season={year}&week={week}")
    time.sleep(5)

    # the page uses lazy loading
    # this loop helps all relevant elements load before scraping
    for _ in range(3):
        # find all loaded rows
        rows = driver.find_elements(
            by=By.CLASS_NAME,
            value="grouped-items-with-sticky-footer__content",
        )

        # scroll to the last loaded row, which should load subsequent rows if there are any
        if len(rows) > 0:
            driver.execute_script(f"window.scrollTo(0, {rows[-1].location['y']});")

        time.sleep(3)

    rows = driver.find_elements(
        by=By.CLASS_NAME,
        value="grouped-items-with-sticky-footer__content",
    )

    if len(rows) == 0:
        print(f"Warning: No rows for {player_name} {year} week {week}")
        
    data = {
        'Year': year,
        'Week': week,
        'Player Name': player_name,
        'Team': team,
    }
    for row in rows:
        t = row.text.split('\n')
        if t[0] == 'Rushing Yards Over/Under':
            data['Rushing Yards Projection'] = t[-4]
            data['Rushing Yards Over'] = t[-3]
            data['Rushing Yards Under'] = t[-1]
        elif t[0] == 'Receiving Yards Over/Under':
            data['Receiving Yards Projection'] = t[-4]
            data['Receiving Yards Over'] = t[-3]
            data['Receiving Yards Under'] = t[-1]
        elif t[0] == 'Receptions Over/Under':
            data['Receptions Projection'] = t[-4]
            data['Receptions Over'] = t[-3]
            data['Receptions Under'] = t[-1]
        elif t[0] == 'Anytime Touchdown Scorer':
            data['Anytime Touchdown Line'] = t[-1]

    return data

# %%
from tqdm.autonotebook import tqdm

d = []
for index, row in tqdm(list(df_wr.iterrows())):
    try:
        d.append(scrape_props(row['Player Name'], row['Player Name URL'], row['Year'], row['Week'], row['Team']))
    except Exception as e:
        print(f"Error with {row['Player Name'], row['Player Name URL'], row['Year'], row['Week'], row['Team']}: {e}")
# Out:
# C:\Users\mhugh\AppData\Local\Temp\ipykernel_8420\94795647.py:1: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm
#   0%|          | 0/2016 [00:00<?, ?it/s]
# Warning: No rows for robbie chosen 2020 week 1
# Warning: No rows for mike williams 2020 week 1
# Warning: No rows for mike williams 2020 week 2
# Warning: No rows for robbie chosen 2020 week 2
# Warning: No rows for scotty miller 2020 week 2
# Warning: No rows for robbie chosen 2020 week 3
# Warning: No rows for mike williams 2020 week 3
# Warning: No rows for larry fitzgerald 2020 week 3
# Warning: No rows for robbie chosen 2020 week 4
# Warning: No rows for scotty miller 2020 week 4
# Warning: No rows for larry fitzgerald 2020 week 4
# Warning: No rows for dj moore 2020 week 5
# Warning: No rows for scotty miller 2020 week 5
# Warning: No rows for dj moore 2020 week 6
# Warning: No rows for dj moore 2020 week 7
# Warning: No rows for mike williams 2020 week 7
# Warning: No rows for dj moore 2020 week 8
# Warning: No rows for mike williams 2020 week 8
# Warning: No rows for scotty miller 2020 week 8
# Warning: No rows for dj moore 2020 week 9
# Warning: No rows for mike williams 2020 week 9
# Warning: No rows for dj moore 2020 week 10
# Warning: No rows for mike williams 2020 week 10
# Warning: No rows for dj moore 2020 week 11
# Warning: No rows for mike williams 2020 week 11
# Warning: No rows for robbie chosen 2020 week 12
# Warning: No rows for mike williams 2020 week 12
# Warning: No rows for dez bryant 2020 week 12
# Warning: No rows for bisi johnson 2020 week 12
# Warning: No rows for mike williams 2020 week 13
# Warning: No rows for mike williams 2020 week 14
# Warning: No rows for dj moore 2020 week 15
# Warning: No rows for tyron billyjohnson 2020 week 15
# Warning: No rows for robbie chosen 2020 week 16
# Warning: No rows for tyron billyjohnson 2020 week 16
# Warning: No rows for derrick willies 2020 week 16
# Warning: No rows for robbie chosen 2021 week 1
# Warning: No rows for mike williams 2021 week 1
# Warning: No rows for mike williams 2021 week 2
# Warning: No rows for robbie chosen 2021 week 2
# Warning: No rows for mike williams 2021 week 3
# Warning: No rows for robbie chosen 2021 week 3
# Warning: No rows for mike williams 2021 week 4
# Warning: No rows for robbie chosen 2021 week 4
# Warning: No rows for mike williams 2021 week 5
# Warning: No rows for robbie chosen 2021 week 5
# Warning: No rows for mike williams 2021 week 6
# Warning: No rows for robbie chosen 2021 week 6
# Warning: No rows for robbie chosen 2021 week 7
# Warning: No rows for robbie chosen 2021 week 8
# Warning: No rows for equanimeous st 2021 week 8
# Warning: No rows for mike williams 2021 week 9
# Warning: No rows for robbie chosen 2021 week 9
# Warning: No rows for mike williams 2021 week 10
# Warning: No rows for robbie chosen 2021 week 10
# Warning: No rows for nick westbrookikhine 2021 week 10
# Warning: No rows for mike williams 2021 week 11
# Warning: No rows for robbie chosen 2021 week 11
# Warning: No rows for mike williams 2021 week 12
# Warning: No rows for robbie chosen 2021 week 12
# Warning: No rows for mike williams 2021 week 13
# Warning: No rows for nick westbrookikhine 2021 week 14
# Warning: No rows for robbie chosen 2021 week 14
# Warning: No rows for mike williams 2021 week 15
# Warning: No rows for gabe davis 2021 week 15
# Warning: No rows for robbie chosen 2021 week 15
# Warning: No rows for nick westbrookikhine 2021 week 15
# Warning: No rows for joshua palmer 2021 week 16
# Warning: No rows for robbie chosen 2021 week 16
# Warning: No rows for mike williams 2021 week 17
# Warning: No rows for gabe davis 2021 week 17
# Warning: No rows for robbie chosen 2021 week 17
# Warning: No rows for nick westbrookikhine 2021 week 17
# Warning: No rows for mike williams 2022 week 1
# Warning: No rows for gabe davis 2022 week 1
# Warning: No rows for robbie chosen 2022 week 1
# Warning: No rows for joshua palmer 2022 week 2
# Warning: No rows for robbie chosen 2022 week 2
# Warning: No rows for gabe davis 2022 week 3
# Warning: No rows for robbie chosen 2022 week 3
# Warning: No rows for joshua palmer 2022 week 3
# Warning: No rows for equanimeous st 2022 week 3
# Warning: No rows for gabe davis 2022 week 4
# Warning: No rows for joshua palmer 2022 week 4
# Warning: No rows for robbie chosen 2022 week 4
# Warning: No rows for equanimeous st 2022 week 4
# Warning: No rows for gabe davis 2022 week 5
# Warning: No rows for joshua palmer 2022 week 5
# Warning: No rows for robbie chosen 2022 week 5
# Warning: No rows for nick westbrookikhine 2022 week 5
# Warning: No rows for equanimeous st 2022 week 5
# Warning: No rows for gabe davis 2022 week 6
# Warning: No rows for joshua palmer 2022 week 6
# Warning: No rows for robbie chosen 2022 week 6
# Warning: No rows for equanimeous st 2022 week 6
# Warning: No rows for nick westbrookikhine 2022 week 7
# Warning: No rows for equanimeous st 2022 week 7
# Warning: No rows for gabe davis 2022 week 8
# Warning: No rows for nick westbrookikhine 2022 week 8
# Warning: No rows for equanimeous st 2022 week 8
# Warning: No rows for gabe davis 2022 week 9
# Warning: No rows for nick westbrookikhine 2022 week 9
# Warning: No rows for gabe davis 2022 week 10
# Warning: No rows for gabe davis 2022 week 11
# Warning: No rows for gabe davis 2022 week 12
# Warning: No rows for joshua palmer 2022 week 12
# Warning: No rows for joshua palmer 2022 week 13
# Warning: No rows for gabe davis 2022 week 13
# Warning: No rows for gabe davis 2022 week 14
# Warning: No rows for mike williams 2022 week 14
# Warning: No rows for nick westbrookikhine 2022 week 14
# Warning: No rows for mike williams 2022 week 15
# Warning: No rows for gabe davis 2022 week 15
# Warning: No rows for nick westbrookikhine 2022 week 15
# Warning: No rows for brandon johnson 2022 week 15
# Warning: No rows for mike williams 2022 week 16
# Warning: No rows for gabe davis 2022 week 16
# Warning: No rows for mike williams 2022 week 17
# Warning: No rows for mike williams 2023 week 1
# Warning: No rows for gabe davis 2023 week 1
# Warning: No rows for michael thomas 2023 week 1
# Warning: No rows for mike williams 2023 week 2
# Warning: No rows for michael thomas 2023 week 2
# Warning: No rows for gabe davis 2023 week 2
# Warning: No rows for mike williams 2023 week 3
# Warning: No rows for michael thomas 2023 week 3
# Warning: No rows for gabe davis 2023 week 3
# Warning: No rows for tank dell 2023 week 3
# Warning: No rows for tank dell 2023 week 4
# Warning: No rows for michael thomas 2023 week 4
# Warning: No rows for gabe davis 2023 week 4
# Warning: No rows for joshua palmer 2023 week 4
# Warning: No rows for nick westbrookikhine 2023 week 4
# Warning: No rows for tank dell 2023 week 5
# Warning: No rows for gabe davis 2023 week 5
# Warning: No rows for michael thomas 2023 week 5
# Warning: No rows for nick westbrookikhine 2023 week 5
# Warning: No rows for gabe davis 2023 week 6
# Warning: No rows for michael thomas 2023 week 6
# Warning: No rows for joshua palmer 2023 week 6
# Warning: No rows for nick westbrookikhine 2023 week 6
# Warning: No rows for joshua palmer 2023 week 7
# Warning: No rows for michael thomas 2023 week 7
# Warning: No rows for gabe davis 2023 week 7
# Warning: No rows for tank dell 2023 week 8
# Warning: No rows for joshua palmer 2023 week 8
# Warning: No rows for gabe davis 2023 week 8
# Warning: No rows for michael thomas 2023 week 8
# Warning: No rows for gabe davis 2023 week 9
# Warning: No rows for tank dell 2023 week 9
# Warning: No rows for michael thomas 2023 week 9
# Warning: No rows for gabe davis 2023 week 10
# Warning: No rows for michael thomas 2023 week 10
# Warning: No rows for josh downs 2023 week 10
# Warning: No rows for nick westbrookikhine 2023 week 10
# Warning: No rows for gabe davis 2023 week 11
# Warning: No rows for gabe davis 2023 week 12
# Warning: No rows for nick westbrookikhine 2023 week 13
# Warning: No rows for gabe davis 2023 week 14
# Warning: No rows for nick westbrookikhine 2023 week 14
# Warning: No rows for gabe davis 2023 week 15
# Warning: No rows for joshua palmer 2023 week 15
# Warning: No rows for nick westbrookikhine 2023 week 15
# Warning: No rows for gabe davis 2023 week 16
# Warning: No rows for gabe davis 2023 week 17
# Warning: No rows for brandon johnson 2023 week 17
# Warning: No rows for tyler scott 2023 week 17

# %%
driver.quit()

# %%
d
# Out:
# [{'Year': 2020,
#   'Week': 1,
#   'Player Name': 'calvin ridley',
#   'Team': 'ATL',
#   'Anytime Touchdown Line': '+130',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-125)',
#   'Receptions Under': '(+105)',
#   'Receiving Yards Projection': 'O 60.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'cooper kupp',
#   'Team': 'LAR',
#   'Receiving Yards Projection': 'O 62.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(-190)',
#   'Receptions Under': '(-118)',
#   'Anytime Touchdown Line': '+135'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'dk metcalf',
#   'Team': 'SEA',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-110)',
#   'Receptions Under': '(-110)',
#   'Anytime Touchdown Line': '+138',
#   'Receiving Yards Projection': 'O 57.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'michael gallup',
#   'Team': 'DAL',
#   'Receiving Yards Projection': 'O 66.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-105)',
#   'Receptions Under': '(-108)',
#   'Anytime Touchdown Line': '+155'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'aj green',
#   'Team': 'CIN',
#   'Receiving Yards Projection': 'O 51.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+120)',
#   'Receptions Under': '(-154)',
#   'Anytime Touchdown Line': '+190'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'jarvis landry',
#   'Team': 'CLE',
#   'Anytime Touchdown Line': '+200',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+105)',
#   'Receptions Under': '(-135)',
#   'Receiving Yards Projection': 'O 55.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'diontae johnson',
#   'Team': 'PIT',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-126)',
#   'Receptions Under': '(+105)',
#   'Receiving Yards Projection': 'O 51.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+225'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'john brown',
#   'Team': 'BUF',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+105)',
#   'Receptions Under': '(-135)',
#   'Anytime Touchdown Line': '+225',
#   'Receiving Yards Projection': 'O 46.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'mike evans',
#   'Team': 'TB',
#   'Anytime Touchdown Line': '+125'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'anthony miller',
#   'Team': 'CHI',
#   'Anytime Touchdown Line': '+280',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+125)',
#   'Receptions Under': '(-145)',
#   'Receiving Yards Projection': 'O 41.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'emmanuel sanders',
#   'Team': 'NO',
#   'Receiving Yards Projection': 'O 42.5',
#   'Receiving Yards Over': '(-125)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+116)',
#   'Receptions Under': '(-148)',
#   'Anytime Touchdown Line': '+250'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'brandin cooks',
#   'Team': 'HOU',
#   'Anytime Touchdown Line': '+225'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'christian kirk',
#   'Team': 'ARI',
#   'Receiving Yards Projection': 'O 46.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+320',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-110)',
#   'Receptions Under': '(-124)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'preston williams',
#   'Team': 'MIA',
#   'Anytime Touchdown Line': '+162'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'darius slayton',
#   'Team': 'NYG',
#   'Receiving Yards Projection': 'O 42.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(EVEN)',
#   'Receptions Under': '(-152)',
#   'Anytime Touchdown Line': '+250'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'mecole hardman',
#   'Team': 'KC',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(+126)',
#   'Receptions Under': '(-160)',
#   'Anytime Touchdown Line': '+270',
#   'Receiving Yards Projection': 'O 26.5',
#   'Receiving Yards Over': '(EVEN)',
#   'Receiving Yards Under': '(-122)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'allen lazard',
#   'Team': 'GB',
#   'Anytime Touchdown Line': '+300',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+105)',
#   'Receptions Under': '(-125)',
#   'Receiving Yards Projection': 'O 38.5',
#   'Receiving Yards Over': '(-105)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2020, 'Week': 1, 'Player Name': 'robbie chosen', 'Team': 'CAR'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'nkeal harry',
#   'Team': 'NE',
#   'Anytime Touchdown Line': '+225'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'parris campbell',
#   'Team': 'IND',
#   'Anytime Touchdown Line': '+240',
#   'Receiving Yards Projection': 'O 40.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-140)',
#   'Receptions Under': '(+120)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'bryan edwards',
#   'Team': 'LV',
#   'Anytime Touchdown Line': '+330'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'breshad perriman',
#   'Team': 'NYJ',
#   'Receiving Yards Projection': 'O 45.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+275'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'steven sims',
#   'Team': 'WAS',
#   'Receiving Yards Projection': 'O 39.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+275'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'laviska shenault',
#   'Team': 'JAX',
#   'Anytime Touchdown Line': '+450'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'justin jefferson',
#   'Team': 'MIN',
#   'Receiving Yards Projection': 'O 31.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+400',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-125)',
#   'Receptions Under': '(+105)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'danny amendola',
#   'Team': 'DET',
#   'Anytime Touchdown Line': '+250'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'corey davis',
#   'Team': 'TEN',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-176)',
#   'Receptions Under': '(+138)',
#   'Anytime Touchdown Line': '+250',
#   'Receiving Yards Projection': 'O 38.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'miles boykin',
#   'Team': 'BAL',
#   'Anytime Touchdown Line': '+350'},
#  {'Year': 2020, 'Week': 1, 'Player Name': 'mike williams', 'Team': 'LAC'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'jj arcegawhiteside',
#   'Team': 'PHI',
#   'Anytime Touchdown Line': '+550'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'trent taylor',
#   'Team': 'SF',
#   'Anytime Touchdown Line': '+400'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'tim patrick',
#   'Team': 'DEN',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(+110)',
#   'Receptions Under': '(-130)',
#   'Receiving Yards Projection': 'O 29.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+350'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'calvin ridley',
#   'Team': 'ATL',
#   'Anytime Touchdown Line': '+110',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(-140)',
#   'Receptions Under': '(-140)',
#   'Receiving Yards Projection': 'O 69.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'cooper kupp',
#   'Team': 'LAR',
#   'Anytime Touchdown Line': '+155',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-126)',
#   'Receptions Under': '(-110)',
#   'Receiving Yards Projection': 'O 60.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'michael gallup',
#   'Team': 'DAL',
#   'Receiving Yards Projection': 'O 64.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+150',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-110)',
#   'Receptions Under': '(-124)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'dk metcalf',
#   'Team': 'SEA',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+115)',
#   'Receptions Under': '(-148)',
#   'Receiving Yards Projection': 'O 51.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+138'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'diontae johnson',
#   'Team': 'PIT',
#   'Anytime Touchdown Line': '+220',
#   'Receiving Yards Projection': 'O 58.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+145)',
#   'Receptions Under': '(-170)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'tyler boyd',
#   'Team': 'CIN',
#   'Anytime Touchdown Line': '+250',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+105)',
#   'Receptions Under': '(-154)',
#   'Receiving Yards Projection': 'O 50.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'jarvis landry',
#   'Team': 'CLE',
#   'Receiving Yards Projection': 'O 54.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+175',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+125)',
#   'Receptions Under': '(-160)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'parris campbell',
#   'Team': 'IND',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-108)',
#   'Receptions Under': '(-125)',
#   'Anytime Touchdown Line': '+175',
#   'Receiving Yards Projection': 'O 55.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'john brown',
#   'Team': 'BUF',
#   'Anytime Touchdown Line': '+190',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+108)',
#   'Receptions Under': '(-136)',
#   'Receiving Yards Projection': 'O 46.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'anthony miller',
#   'Team': 'CHI',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+116)',
#   'Receptions Under': '(-160)',
#   'Anytime Touchdown Line': '+250',
#   'Receiving Yards Projection': 'O 42.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020, 'Week': 2, 'Player Name': 'mike williams', 'Team': 'LAC'},
#  {'Year': 2020, 'Week': 2, 'Player Name': 'robbie chosen', 'Team': 'CAR'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'jerry jeudy',
#   'Team': 'DEN',
#   'Receiving Yards Projection': 'O 41.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+275'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'sterling shepard',
#   'Team': 'NYG',
#   'Receiving Yards Projection': 'O 45.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+210',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-135)',
#   'Receptions Under': '(-136)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'sammy watkins',
#   'Team': 'KC',
#   'Anytime Touchdown Line': '+165',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-125)',
#   'Receptions Under': '(-108)',
#   'Receiving Yards Projection': 'O 44.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'allen lazard',
#   'Team': 'GB',
#   'Anytime Touchdown Line': '+175',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+150)',
#   'Receptions Under': '(-175)',
#   'Receiving Yards Projection': 'O 51.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'christian kirk',
#   'Team': 'ARI',
#   'Receiving Yards Projection': 'O 43.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+225',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-158)',
#   'Receptions Under': '(-135)'},
#  {'Year': 2020, 'Week': 2, 'Player Name': 'scotty miller', 'Team': 'TB'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'devante parker',
#   'Team': 'MIA',
#   'Anytime Touchdown Line': '+200',
#   'Receiving Yards Projection': 'O 53.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+116)',
#   'Receptions Under': '(-148)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'laviska shenault',
#   'Team': 'JAX',
#   'Anytime Touchdown Line': '+333',
#   'Receiving Yards Projection': 'O 32.5',
#   'Receiving Yards Over': '(-105)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'brandin cooks',
#   'Team': 'HOU',
#   'Anytime Touchdown Line': '+340'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'jalen reagor',
#   'Team': 'PHI',
#   'Anytime Touchdown Line': '+350',
#   'Receiving Yards Projection': 'O 37.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-150)',
#   'Receptions Under': '(+112)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'trequan smith',
#   'Team': 'NO',
#   'Anytime Touchdown Line': '+260',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+120)',
#   'Receptions Under': '(-154)',
#   'Receiving Yards Projection': 'O 36.5',
#   'Receiving Yards Over': '(EVEN)',
#   'Receiving Yards Under': '(-122)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'nkeal harry',
#   'Team': 'NE',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-126)',
#   'Receptions Under': '(-102)',
#   'Anytime Touchdown Line': '+300',
#   'Receiving Yards Projection': 'O 39.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-105)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'steven sims',
#   'Team': 'WAS',
#   'Receiving Yards Projection': 'O 40.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+300'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'brandon aiyuk',
#   'Team': 'SF',
#   'Receiving Yards Projection': 'O 37.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+130)',
#   'Receptions Under': '(-182)',
#   'Anytime Touchdown Line': '+260'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'bryan edwards',
#   'Team': 'LV',
#   'Anytime Touchdown Line': '+400',
#   'Receiving Yards Projection': 'O 30.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-143)',
#   'Receptions Under': '(+110)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'danny amendola',
#   'Team': 'DET',
#   'Receiving Yards Projection': 'O 48.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+240',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+120)',
#   'Receptions Under': '(-154)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'justin jefferson',
#   'Team': 'MIN',
#   'Receiving Yards Projection': 'O 24.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+400'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'adam humphries',
#   'Team': 'TEN',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-140)',
#   'Receptions Under': '(EVEN)',
#   'Anytime Touchdown Line': '+275',
#   'Receiving Yards Projection': 'O 45.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'miles boykin',
#   'Team': 'BAL',
#   'Anytime Touchdown Line': '+310'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'chris hogan',
#   'Team': 'NYJ',
#   'Anytime Touchdown Line': '+400',
#   'Receiving Yards Projection': 'O 30.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'tyler lockett',
#   'Team': 'SEA',
#   'Receiving Yards Projection': 'O 70.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-111)',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(+115)',
#   'Receptions Under': '(-145)',
#   'Anytime Touchdown Line': '-111'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'chris godwin',
#   'Team': 'TB',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(+120)',
#   'Receptions Under': '(-145)',
#   'Anytime Touchdown Line': '+135',
#   'Receiving Yards Projection': 'O 63.5',
#   'Receiving Yards Over': '(-111)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'diontae johnson',
#   'Team': 'PIT',
#   'Anytime Touchdown Line': '+165',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(-115)',
#   'Receptions Under': '(-115)',
#   'Receiving Yards Projection': 'O 61.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'robert woods',
#   'Team': 'LAR',
#   'Anytime Touchdown Line': '+210',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(+105)',
#   'Receptions Under': '(-135)',
#   'Receiving Yards Projection': 'O 57.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'ceedee lamb',
#   'Team': 'DAL',
#   'Anytime Touchdown Line': '+200',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-145)',
#   'Receptions Under': '(+115)',
#   'Receiving Yards Projection': 'O 62.5',
#   'Receiving Yards Over': '(-111)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'aj green',
#   'Team': 'CIN',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+105)',
#   'Receptions Under': '(-135)',
#   'Receiving Yards Projection': 'O 52.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+200'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'marvin jones',
#   'Team': 'DET',
#   'Receiving Yards Projection': 'O 59.5',
#   'Receiving Yards Over': '(-111)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-113)',
#   'Receptions Under': '(-113)',
#   'Anytime Touchdown Line': '+125'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'john brown',
#   'Team': 'BUF',
#   'Anytime Touchdown Line': '+150',
#   'Receiving Yards Projection': 'O 49.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-166)',
#   'Receptions Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'jarvis landry',
#   'Team': 'CLE',
#   'Anytime Touchdown Line': '+150',
#   'Receiving Yards Projection': 'O 48.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-111)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-156)',
#   'Receptions Under': '(+122)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'russell gage',
#   'Team': 'ATL',
#   'Anytime Touchdown Line': '+210',
#   'Receiving Yards Projection': 'O 51.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020, 'Week': 3, 'Player Name': 'robbie chosen', 'Team': 'CAR'},
#  {'Year': 2020, 'Week': 3, 'Player Name': 'mike williams', 'Team': 'LAC'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'marquez valdesscantling',
#   'Team': 'GB',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+120)',
#   'Receptions Under': '(-150)',
#   'Anytime Touchdown Line': '+200',
#   'Receiving Yards Projection': 'O 47.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'keelan cole',
#   'Team': 'JAX',
#   'Receiving Yards Projection': 'O 55.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-136)',
#   'Receptions Under': '(+106)',
#   'Anytime Touchdown Line': '+160'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'brandin cooks',
#   'Team': 'HOU',
#   'Anytime Touchdown Line': '+200',
#   'Receiving Yards Projection': 'O 44.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'preston williams',
#   'Team': 'MIA',
#   'Receiving Yards Projection': 'O 46.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+160',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-105)',
#   'Receptions Under': '(-118)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'golden tate',
#   'Team': 'NYG',
#   'Anytime Touchdown Line': '+188',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-125)',
#   'Receptions Under': '(+118)',
#   'Receiving Yards Projection': 'O 42.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'nkeal harry',
#   'Team': 'NE',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+118)',
#   'Receptions Under': '(-150)',
#   'Receiving Yards Projection': 'O 48.5',
#   'Receiving Yards Over': '(EVEN)',
#   'Receiving Yards Under': '(-122)',
#   'Anytime Touchdown Line': '+220'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'emmanuel sanders',
#   'Team': 'NO',
#   'Anytime Touchdown Line': '+137',
#   'Receiving Yards Projection': 'O 47.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-104)',
#   'Receptions Under': '(-115)'},
#  {'Year': 2020, 'Week': 3, 'Player Name': 'larry fitzgerald', 'Team': 'ARI'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'anthony miller',
#   'Team': 'CHI',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+108)',
#   'Receptions Under': '(-160)',
#   'Anytime Touchdown Line': '+230',
#   'Receiving Yards Projection': 'O 39.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'michael pittman',
#   'Team': 'IND',
#   'Receiving Yards Projection': 'O 41.5',
#   'Receiving Yards Over': '(-111)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+290',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-111)',
#   'Receptions Under': '(-113)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'adam humphries',
#   'Team': 'TEN',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-155)',
#   'Receptions Under': '(+125)',
#   'Receiving Yards Projection': 'O 46.5',
#   'Receiving Yards Over': '(-111)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+230'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'kj hamler',
#   'Team': 'DEN',
#   'Receiving Yards Projection': 'O 34.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+375',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-145)',
#   'Receptions Under': '(+115)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'kendrick bourne',
#   'Team': 'SF',
#   'Anytime Touchdown Line': '+250',
#   'Receiving Yards Projection': 'O 48.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-125)',
#   'Receptions Under': '(-105)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'steven sims',
#   'Team': 'WAS',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+120)',
#   'Receptions Under': '(-174)',
#   'Anytime Touchdown Line': '+210',
#   'Receiving Yards Projection': 'O 35.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'mecole hardman',
#   'Team': 'KC',
#   'Anytime Touchdown Line': '+240',
#   'Receiving Yards Projection': 'O 22.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(+120)',
#   'Receptions Under': '(-150)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'hunter renfrow',
#   'Team': 'LV',
#   'Receiving Yards Projection': 'O 41.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+260'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'justin jefferson',
#   'Team': 'MIN',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-135)',
#   'Receptions Under': '(+105)',
#   'Receiving Yards Projection': 'O 33.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+260'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'miles boykin',
#   'Team': 'BAL',
#   'Anytime Touchdown Line': '+290',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-150)',
#   'Receptions Under': '(+120)',
#   'Receiving Yards Projection': 'O 33.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-111)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'braxton berrios',
#   'Team': 'NYJ',
#   'Receiving Yards Projection': 'O 40.5',
#   'Receiving Yards Over': '(-120)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+350',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-115)',
#   'Receptions Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'greg ward',
#   'Team': 'PHI',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-170)',
#   'Receptions Under': '(+106)',
#   'Receiving Yards Projection': 'O 31.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+260'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'dk metcalf',
#   'Team': 'SEA',
#   'Anytime Touchdown Line': '-105',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-156)',
#   'Receptions Under': '(+125)',
#   'Receiving Yards Projection': 'O 67.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'robert woods',
#   'Team': 'LAR',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(-105)',
#   'Receptions Under': '(-125)',
#   'Anytime Touchdown Line': '+115',
#   'Receiving Yards Projection': 'O 62.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-111)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'julio jones',
#   'Team': 'ATL',
#   'Anytime Touchdown Line': '+145',
#   'Receiving Yards Projection': 'O 73.5',
#   'Receiving Yards Over': '(-111)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(+110)',
#   'Receptions Under': '(-140)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'michael gallup',
#   'Team': 'DAL',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+130)',
#   'Receptions Under': '(-154)',
#   'Receiving Yards Projection': 'O 58.5',
#   'Receiving Yards Over': '(-111)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+155'},
#  {'Year': 2020, 'Week': 4, 'Player Name': 'robbie chosen', 'Team': 'CAR'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'jarvis landry',
#   'Team': 'CLE',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-140)',
#   'Receptions Under': '(-115)',
#   'Anytime Touchdown Line': '+165',
#   'Receiving Yards Projection': 'O 56.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'brandin cooks',
#   'Team': 'HOU',
#   'Receiving Yards Projection': 'O 55.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+200',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(EVEN)',
#   'Receptions Under': '(-130)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'aj green',
#   'Team': 'CIN',
#   'Receiving Yards Projection': 'O 52.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+163',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+110)',
#   'Receptions Under': '(-140)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'marvin jones',
#   'Team': 'DET',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-120)',
#   'Receptions Under': '(-105)',
#   'Anytime Touchdown Line': '+170',
#   'Receiving Yards Projection': 'O 46.5',
#   'Receiving Yards Over': '(-111)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'justin jefferson',
#   'Team': 'MIN',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-120)',
#   'Receptions Under': '(-110)',
#   'Receiving Yards Projection': 'O 56.5',
#   'Receiving Yards Over': '(-132)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+130'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'preston williams',
#   'Team': 'MIA',
#   'Anytime Touchdown Line': '+190',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-115)',
#   'Receptions Under': '(-115)',
#   'Receiving Yards Projection': 'O 48.5',
#   'Receiving Yards Over': '(-111)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'emmanuel sanders',
#   'Team': 'NO',
#   'Anytime Touchdown Line': '+180',
#   'Receiving Yards Projection': 'O 49.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-110)',
#   'Receptions Under': '(-106)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'john brown',
#   'Team': 'BUF',
#   'Receiving Yards Projection': 'O 53.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-111)',
#   'Anytime Touchdown Line': '+210',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-161)',
#   'Receptions Under': '(+130)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'laviska shenault',
#   'Team': 'JAX',
#   'Anytime Touchdown Line': '+275',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+132)',
#   'Receptions Under': '(-170)',
#   'Receiving Yards Projection': 'O 33.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'golden tate',
#   'Team': 'NYG',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-161)',
#   'Receptions Under': '(+130)',
#   'Receiving Yards Projection': 'O 47.5',
#   'Receiving Yards Over': '(-111)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+270'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'nkeal harry',
#   'Team': 'NE',
#   'Anytime Touchdown Line': '+290',
#   'Receiving Yards Projection': 'O 40.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-149)',
#   'Receptions Under': '(+120)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'sammy watkins',
#   'Team': 'KC',
#   'Receiving Yards Projection': 'O 48.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+180',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-150)',
#   'Receptions Under': '(+130)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'anthony miller',
#   'Team': 'CHI',
#   'Anytime Touchdown Line': '+250',
#   'Receiving Yards Projection': 'O 30.5',
#   'Receiving Yards Over': '(-122)',
#   'Receiving Yards Under': '(EVEN)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-105)',
#   'Receptions Under': '(-125)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'kj hamler',
#   'Team': 'DEN',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+125)',
#   'Receptions Under': '(-154)',
#   'Receiving Yards Projection': 'O 36.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-111)',
#   'Anytime Touchdown Line': '+350'},
#  {'Year': 2020, 'Week': 4, 'Player Name': 'scotty miller', 'Team': 'TB'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'zach pascal',
#   'Team': 'IND',
#   'Anytime Touchdown Line': '+200',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+110)',
#   'Receptions Under': '(-139)',
#   'Receiving Yards Projection': 'O 37.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-111)'},
#  {'Year': 2020, 'Week': 4, 'Player Name': 'larry fitzgerald', 'Team': 'ARI'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'kendrick bourne',
#   'Team': 'SF',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+110)',
#   'Receptions Under': '(-162)',
#   'Receiving Yards Projection': 'O 48.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-145)',
#   'Anytime Touchdown Line': '+230'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'braxton berrios',
#   'Team': 'NYJ',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+120)',
#   'Receptions Under': '(-149)',
#   'Anytime Touchdown Line': '+240',
#   'Receiving Yards Projection': 'O 36.5',
#   'Receiving Yards Over': '(-111)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'nelson agholor',
#   'Team': 'LV',
#   'Receiving Yards Projection': 'O 34.5',
#   'Receiving Yards Over': '(-111)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+140)',
#   'Receptions Under': '(-170)',
#   'Anytime Touchdown Line': '+310'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'dontrelle inman',
#   'Team': 'WAS',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-128)',
#   'Receptions Under': '(EVEN)',
#   'Anytime Touchdown Line': '+320',
#   'Receiving Yards Projection': 'O 32.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'miles boykin',
#   'Team': 'BAL',
#   'Anytime Touchdown Line': '+370',
#   'Receiving Yards Projection': 'O 22.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-111)',
#   'Receptions Projection': 'O 1.5',
#   'Receptions Over': '(-170)',
#   'Receptions Under': '(+130)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'john hightower',
#   'Team': 'PHI',
#   'Receiving Yards Projection': 'O 26.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+450',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(EVEN)',
#   'Receptions Under': '(-138)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'jalen guyton',
#   'Team': 'LAC',
#   'Receiving Yards Projection': 'O 19.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-120)',
#   'Anytime Touchdown Line': '+450'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'darrius shepherd',
#   'Team': 'GB',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-115)',
#   'Receptions Under': '(-115)',
#   'Anytime Touchdown Line': '+370',
#   'Receiving Yards Projection': 'O 40.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'tyler lockett',
#   'Team': 'SEA',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(-128)',
#   'Receptions Under': '(EVEN)',
#   'Receiving Yards Projection': 'O 75.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '-138'},
#  {'Year': 2020, 'Week': 5, 'Player Name': 'dj moore', 'Team': 'CAR'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'robert woods',
#   'Team': 'LAR',
#   'Receiving Yards Projection': 'O 57.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+138',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(+108)',
#   'Receptions Under': '(-138)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'justin jefferson',
#   'Team': 'MIN',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-140)',
#   'Receptions Under': '(+110)',
#   'Receiving Yards Projection': 'O 71.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+138'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'ceedee lamb',
#   'Team': 'DAL',
#   'Receiving Yards Projection': 'O 58.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+115)',
#   'Receptions Under': '(-150)',
#   'Anytime Touchdown Line': '+138'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'diontae johnson',
#   'Team': 'PIT',
#   'Receiving Yards Projection': 'O 55.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+155',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(+114)',
#   'Receptions Under': '(-146)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'jarvis landry',
#   'Team': 'CLE',
#   'Receiving Yards Projection': 'O 47.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-135)',
#   'Receptions Under': '(+105)',
#   'Anytime Touchdown Line': '+200'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'golden tate',
#   'Team': 'NYG',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+108)',
#   'Receptions Under': '(-138)',
#   'Anytime Touchdown Line': '+200',
#   'Receiving Yards Projection': 'O 51.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'laviska shenault',
#   'Team': 'JAX',
#   'Receiving Yards Projection': 'O 38.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+115)',
#   'Receptions Under': '(-150)',
#   'Anytime Touchdown Line': '+230'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'russell gage',
#   'Team': 'ATL',
#   'Receiving Yards Projection': 'O 56.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-174)',
#   'Receptions Under': '(+136)',
#   'Anytime Touchdown Line': '+185'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'tee higgins',
#   'Team': 'CIN',
#   'Receiving Yards Projection': 'O 43.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+250',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-130)',
#   'Receptions Under': '(EVEN)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'sammy watkins',
#   'Team': 'KC',
#   'Anytime Touchdown Line': '+180',
#   'Receiving Yards Projection': 'O 46.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-150)',
#   'Receptions Under': '(+120)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'brandin cooks',
#   'Team': 'HOU',
#   'Anytime Touchdown Line': '+185',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-110)',
#   'Receptions Under': '(-138)',
#   'Receiving Yards Projection': 'O 44.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020, 'Week': 5, 'Player Name': 'scotty miller', 'Team': 'TB'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'deebo samuel',
#   'Team': 'SF',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-174)',
#   'Receptions Under': '(+115)',
#   'Anytime Touchdown Line': '+200',
#   'Receiving Yards Projection': 'O 31.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'trequan smith',
#   'Team': 'NO',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+130)',
#   'Receptions Under': '(-166)',
#   'Anytime Touchdown Line': '+188',
#   'Receiving Yards Projection': 'O 50.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'zach pascal',
#   'Team': 'IND',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-130)',
#   'Receptions Under': '(+102)',
#   'Receiving Yards Projection': 'O 46.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+225'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'cole beasley',
#   'Team': 'BUF',
#   'Receiving Yards Projection': 'O 49.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+190',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-125)',
#   'Receptions Under': '(-138)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'christian kirk',
#   'Team': 'ARI',
#   'Receiving Yards Projection': 'O 36.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+275',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+115)',
#   'Receptions Under': '(-162)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'preston williams',
#   'Team': 'MIA',
#   'Receiving Yards Projection': 'O 33.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+290',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+144)',
#   'Receptions Under': '(-186)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'henry ruggs',
#   'Team': 'LV',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-132)',
#   'Receptions Under': '(+104)',
#   'Anytime Touchdown Line': '+260',
#   'Receiving Yards Projection': 'O 34.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'anthony miller',
#   'Team': 'CHI',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-156)',
#   'Receptions Under': '(+110)',
#   'Anytime Touchdown Line': '+275',
#   'Receiving Yards Projection': 'O 30.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'dontrelle inman',
#   'Team': 'WAS',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-128)',
#   'Receptions Under': '(EVEN)',
#   'Receiving Yards Projection': 'O 34.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+350'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'miles boykin',
#   'Team': 'BAL',
#   'Anytime Touchdown Line': '+320',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(+102)',
#   'Receptions Under': '(-130)',
#   'Receiving Yards Projection': 'O 30.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'jeff smith',
#   'Team': 'NYJ',
#   'Anytime Touchdown Line': '+480',
#   'Receiving Yards Projection': 'O 36.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+118)',
#   'Receptions Under': '(-125)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'jalen guyton',
#   'Team': 'LAC',
#   'Anytime Touchdown Line': '+400',
#   'Receiving Yards Projection': 'O 17.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'john hightower',
#   'Team': 'PHI',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(+115)',
#   'Receptions Under': '(-152)',
#   'Anytime Touchdown Line': '+650',
#   'Receiving Yards Projection': 'O 27.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'kalif raymond',
#   'Team': 'TEN',
#   'Anytime Touchdown Line': '+225',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-146)',
#   'Receptions Under': '(-120)',
#   'Receiving Yards Projection': 'O 38.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 6,
#   'Player Name': 'robert woods',
#   'Team': 'LAR',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(EVEN)',
#   'Receptions Under': '(-133)',
#   'Receiving Yards Projection': 'O 61.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+150'},
#  {'Year': 2020,
#   'Week': 6,
#   'Player Name': 'ceedee lamb',
#   'Team': 'DAL',
#   'Receiving Yards Projection': 'O 64.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-130)',
#   'Receptions Under': '(EVEN)',
#   'Anytime Touchdown Line': '+155'},
#  {'Year': 2020,
#   'Week': 6,
#   'Player Name': 'chris godwin',
#   'Team': 'TB',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(-130)',
#   'Receptions Under': '(EVEN)',
#   'Receiving Yards Projection': 'O 70.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+110'},
#  {'Year': 2020,
#   'Week': 6,
#   'Player Name': 'julio jones',
#   'Team': 'ATL',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(EVEN)',
#   'Receptions Under': '(-133)',
#   'Receiving Yards Projection': 'O 72.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+105'},
#  {'Year': 2020,
#   'Week': 6,
#   'Player Name': 'justin jefferson',
#   'Team': 'MIN',
#   'Receiving Yards Projection': 'O 66.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': 'EVEN',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-133)',
#   'Receptions Under': '(-128)'},
#  {'Year': 2020, 'Week': 6, 'Player Name': 'dj moore', 'Team': 'CAR'},
#  {'Year': 2020,
#   'Week': 6,
#   'Player Name': 'juju smithschuster',
#   'Team': 'PIT',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(+114)',
#   'Receptions Under': '(-146)',
#   'Anytime Touchdown Line': '-133',
#   'Receiving Yards Projection': 'O 57.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 6,
#   'Player Name': 'laviska shenault',
#   'Team': 'JAX',
#   'Receiving Yards Projection': 'O 51.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+210'},
#  {'Year': 2020,
#   'Week': 6,
#   'Player Name': 'mecole hardman',
#   'Team': 'KC',
#   'Anytime Touchdown Line': '+175',
#   'Receiving Yards Projection': 'O 46.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(EVEN)',
#   'Receptions Under': '(-133)'},
#  {'Year': 2020,
#   'Week': 6,
#   'Player Name': 'brandin cooks',
#   'Team': 'HOU',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-125)',
#   'Receptions Under': '(-105)',
#   'Receiving Yards Projection': 'O 59.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+140'},
#  {'Year': 2020,
#   'Week': 6,
#   'Player Name': 'jarvis landry',
#   'Team': 'CLE',
#   'Receiving Yards Projection': 'O 52.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+106)',
#   'Receptions Under': '(-136)',
#   'Anytime Touchdown Line': '+160'},
#  {'Year': 2020,
#   'Week': 6,
#   'Player Name': 'tee higgins',
#   'Team': 'CIN',
#   'Receiving Yards Projection': 'O 47.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+185',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-161)',
#   'Receptions Under': '(+118)'},
#  {'Year': 2020,
#   'Week': 6,
#   'Player Name': 'john brown',
#   'Team': 'BUF',
#   'Anytime Touchdown Line': '+250',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+120)',
#   'Receptions Under': '(-154)',
#   'Receiving Yards Projection': 'O 43.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 6,
#   'Player Name': 'christian kirk',
#   'Team': 'ARI',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-128)',
#   'Receptions Under': '(EVEN)',
# ...
#   'Week': 16,
#   'Player Name': 'allen lazard',
#   'Team': 'GB',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-138)',
#   'Receptions Under': '(+105)',
#   'Receiving Yards Projection': 'O 41.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-120)',
#   'Anytime Touchdown Line': '+187'},
#  {'Year': 2021, 'Week': 16, 'Player Name': 'robbie chosen', 'Team': 'CAR'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'laquon treadwell',
#   'Team': 'JAX',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-150)',
#   'Receptions Under': '(+120)',
#   'Anytime Touchdown Line': '+290',
#   'Receiving Yards Projection': 'O 45.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'donovan peoplesjones',
#   'Team': 'CLE',
#   'Anytime Touchdown Line': '+360',
#   'Receiving Yards Projection': 'O 36.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-155)',
#   'Receptions Under': '(+120)'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'josh reynolds',
#   'Team': 'DET',
#   'Receiving Yards Projection': 'O 33.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+380'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'kendrick bourne',
#   'Team': 'NE',
#   'Anytime Touchdown Line': '+210',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-110)',
#   'Receptions Under': '(-120)',
#   'Receiving Yards Projection': 'O 39.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'tyler johnson',
#   'Team': 'TB',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-115)',
#   'Receptions Under': '(-115)',
#   'Receiving Yards Projection': 'O 37.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+190'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'courtland sutton',
#   'Team': 'DEN',
#   'Anytime Touchdown Line': '+350',
#   'Receiving Yards Projection': 'O 31.5',
#   'Receiving Yards Over': '(-111)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-133)',
#   'Receptions Under': '(EVEN)'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'rashod bateman',
#   'Team': 'BAL',
#   'Anytime Touchdown Line': '+350',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-140)',
#   'Receptions Under': '(+110)',
#   'Receiving Yards Projection': 'O 29.5',
#   'Receiving Yards Over': '(-111)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'zay jones',
#   'Team': 'LV',
#   'Anytime Touchdown Line': '+250',
#   'Receiving Yards Projection': 'O 39.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-111)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+110)',
#   'Receptions Under': '(-145)'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'kadarius toney',
#   'Team': 'NYG',
#   'Receiving Yards Projection': 'O 35.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+333'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'emmanuel sanders',
#   'Team': 'BUF',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-120)',
#   'Receptions Under': '(-110)',
#   'Anytime Touchdown Line': '+300',
#   'Receiving Yards Projection': 'O 42.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-118)'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'trequan smith',
#   'Team': 'NO',
#   'Receiving Yards Projection': 'O 31.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+375',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-115)',
#   'Receptions Under': '(-115)'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'julio jones',
#   'Team': 'TEN',
#   'Receiving Yards Projection': 'O 36.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+120)',
#   'Receptions Under': '(-154)',
#   'Anytime Touchdown Line': '+275'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'mecole hardman',
#   'Team': 'KC',
#   'Receiving Yards Projection': 'O 28.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-118)',
#   'Anytime Touchdown Line': '+290'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'keelan cole',
#   'Team': 'NYJ',
#   'Receiving Yards Projection': 'O 38.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-111)',
#   'Anytime Touchdown Line': '+230',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+114)',
#   'Receptions Under': '(-146)'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'ty hilton',
#   'Team': 'IND',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-110)',
#   'Receptions Under': '(-120)',
#   'Receiving Yards Projection': 'O 28.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-120)',
#   'Anytime Touchdown Line': '+310'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'adam humphries',
#   'Team': 'WAS',
#   'Receiving Yards Projection': 'O 28.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+600',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-133)',
#   'Receptions Under': '(EVEN)'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'chris conley',
#   'Team': 'HOU',
#   'Anytime Touchdown Line': '+310',
#   'Receiving Yards Projection': 'O 28.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'olamide zaccheaus',
#   'Team': 'ATL',
#   'Receiving Yards Projection': 'O 27.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+300',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(+126)',
#   'Receptions Under': '(-162)'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'damiere byrd',
#   'Team': 'CHI',
#   'Anytime Touchdown Line': '+290',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-175)',
#   'Receptions Under': '(+130)',
#   'Receiving Yards Projection': 'O 31.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-118)'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'quez watkins',
#   'Team': 'PHI',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(+125)',
#   'Receptions Under': '(-160)',
#   'Anytime Touchdown Line': '+375',
#   'Receiving Yards Projection': 'O 24.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-111)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'jamarr chase',
#   'Team': 'CIN',
#   'Anytime Touchdown Line': '+130',
#   'Receiving Yards Projection': 'O 67.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'amari cooper',
#   'Team': 'DAL',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-145)',
#   'Receptions Under': '(+115)',
#   'Receiving Yards Projection': 'O 58.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+137'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'dk metcalf',
#   'Team': 'SEA',
#   'Anytime Touchdown Line': '+135',
#   'Receiving Yards Projection': 'O 59.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'odell beckham',
#   'Team': 'LAR',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-175)',
#   'Receptions Under': '(+130)',
#   'Anytime Touchdown Line': '+150',
#   'Receiving Yards Projection': 'O 48.5',
#   'Receiving Yards Over': '(-130)',
#   'Receiving Yards Under': '(EVEN)'},
#  {'Year': 2021, 'Week': 17, 'Player Name': 'mike williams', 'Team': 'LAC'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'mike evans',
#   'Team': 'TB',
#   'Anytime Touchdown Line': '-125',
#   'Receiving Yards Projection': 'O 45.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'brandon aiyuk',
#   'Team': 'SF',
#   'Anytime Touchdown Line': '+210',
#   'Receiving Yards Projection': 'O 35.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-111)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'chase claypool',
#   'Team': 'PIT',
#   'Receiving Yards Projection': 'O 40.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-105)',
#   'Anytime Touchdown Line': '+200',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(EVEN)',
#   'Receptions Under': '(-133)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'marquez valdesscantling',
#   'Team': 'GB',
#   'Anytime Touchdown Line': '+200',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+144)',
#   'Receptions Under': '(-180)',
#   'Receiving Yards Projection': 'O 37.5',
#   'Receiving Yards Over': '(-120)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'kendrick bourne',
#   'Team': 'NE',
#   'Receiving Yards Projection': 'O 39.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+170'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'aj green',
#   'Team': 'ARI',
#   'Receiving Yards Projection': 'O 47.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-120)',
#   'Receptions Under': '(-110)',
#   'Anytime Touchdown Line': '+220'},
#  {'Year': 2021, 'Week': 17, 'Player Name': 'gabe davis', 'Team': 'BUF'},
#  {'Year': 2021, 'Week': 17, 'Player Name': 'robbie chosen', 'Team': 'CAR'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'kj osborn',
#   'Team': 'MIN',
#   'Anytime Touchdown Line': '+290',
#   'Receiving Yards Projection': 'O 31.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'zay jones',
#   'Team': 'LV',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-140)',
#   'Receptions Under': '(+105)',
#   'Receiving Yards Projection': 'O 40.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-120)',
#   'Anytime Touchdown Line': '+275'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'rashod bateman',
#   'Team': 'BAL',
#   'Receiving Yards Projection': 'O 38.5',
#   'Receiving Yards Over': '(-111)',
#   'Receiving Yards Under': '(-120)',
#   'Anytime Touchdown Line': '+350'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'donovan peoplesjones',
#   'Team': 'CLE',
#   'Receiving Yards Projection': 'O 34.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-110)',
#   'Receptions Under': '(-120)',
#   'Anytime Touchdown Line': '+270'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'laquon treadwell',
#   'Team': 'JAX',
#   'Receiving Yards Projection': 'O 38.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+450'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'ty hilton',
#   'Team': 'IND',
#   'Receiving Yards Projection': 'O 25.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(+150)',
#   'Receptions Under': '(-194)',
#   'Anytime Touchdown Line': '+290'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'byron pringle',
#   'Team': 'KC',
#   'Anytime Touchdown Line': '+280'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'allen robinson',
#   'Team': 'CHI',
#   'Anytime Touchdown Line': '+240'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'nico collins',
#   'Team': 'HOU',
#   'Anytime Touchdown Line': '+280',
#   'Receiving Yards Projection': 'O 27.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'keelan cole',
#   'Team': 'NYJ',
#   'Receiving Yards Projection': 'O 33.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+400',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-180)',
#   'Receptions Under': '(+135)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'nick westbrookikhine',
#   'Team': 'TEN'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'quez watkins',
#   'Team': 'PHI',
#   'Anytime Touchdown Line': '+400',
#   'Receiving Yards Projection': 'O 27.5',
#   'Receiving Yards Over': '(-111)',
#   'Receiving Yards Under': '(-118)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(+115)',
#   'Receptions Under': '(-150)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'adam humphries',
#   'Team': 'WAS',
#   'Anytime Touchdown Line': '+400',
#   'Receiving Yards Projection': 'O 27.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-135)',
#   'Receptions Under': '(+120)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'olamide zaccheaus',
#   'Team': 'ATL',
#   'Receiving Yards Projection': 'O 30.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+450',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-140)',
#   'Receptions Under': '(+105)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'liljordan humphrey',
#   'Team': 'NO',
#   'Anytime Touchdown Line': '+600'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'kendall hinton',
#   'Team': 'DEN',
#   'Anytime Touchdown Line': '+310'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'pharoh cooper',
#   'Team': 'NYG',
#   'Anytime Touchdown Line': '+330'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'khadarel hodge',
#   'Team': 'DET',
#   'Anytime Touchdown Line': '+600'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'mack hollins',
#   'Team': 'MIA',
#   'Anytime Touchdown Line': '+650'},
#  {'Year': 2022,
#   'Week': 1,
#   'Player Name': 'tee higgins',
#   'Team': 'CIN',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(+108)',
#   'Receptions Under': '(-138)',
#   'Anytime Touchdown Line': '+120',
#   'Receiving Yards Projection': 'O 68.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2022, 'Week': 1, 'Player Name': 'mike williams', 'Team': 'LAC'},
#  {'Year': 2022,
#   'Week': 1,
#   'Player Name': 'jaylen waddle',
#   'Team': 'MIA',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(+102)',
#   'Receptions Under': '(-136)',
#   'Anytime Touchdown Line': 'EVEN',
#   'Receiving Yards Projection': 'O 55.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2022, 'Week': 1, 'Player Name': 'gabe davis', 'Team': 'BUF'},
#  {'Year': 2022,
#   'Week': 1,
#   'Player Name': 'allen robinson',
#   'Team': 'LAR',
#   'Anytime Touchdown Line': '+125',
#   'Receiving Yards Projection': 'O 60.5',
#   'Receiving Yards Over': '(-135)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-172)',
#   'Receptions Under': '(+120)'},
#  {'Year': 2022,
#   'Week': 1,
#   'Player Name': 'jerry jeudy',
#   'Team': 'DEN',
#   'Receiving Yards Projection': 'O 58.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-150)',
#   'Receptions Under': '(+106)',
#   'Anytime Touchdown Line': '+110'},
#  {'Year': 2022,
#   'Week': 1,
#   'Player Name': 'adam thielen',
#   'Team': 'MIN',
#   'Receiving Yards Projection': 'O 49.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+102)',
#   'Receptions Under': '(-150)',
#   'Anytime Touchdown Line': 'EVEN'},
#  {'Year': 2022,
#   'Week': 1,
#   'Player Name': 'hunter renfrow',
#   'Team': 'LV',
#   'Anytime Touchdown Line': '+120',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(+126)',
#   'Receptions Under': '(-162)',
#   'Receiving Yards Projection': 'O 47.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  ...]

# %%
import pandas as pd

df = pd.json_normalize(d)

df
# Out:
#       Year  Week      Player Name Team Anytime Touchdown Line  \
# 0     2020     1    calvin ridley  ATL                   +130
# 1     2020     1      cooper kupp  LAR                   +135
# 2     2020     1       dk metcalf  SEA                   +138
# 3     2020     1   michael gallup  DAL                   +155
# 4     2020     1         aj green  CIN                   +190
# ...    ...   ...              ...  ...                    ...
# 2011  2023    17  brandon johnson  DEN                    NaN
# 2012  2023    17    alex erickson  LAC                   +550
# 2013  2023    17    xavier gipson  NYJ                   +650
# 2014  2023    17      tyler scott  CHI                    NaN
# 2015  2023    17    van jefferson  ATL                   +700
#
#      Receptions Projection Receptions Over Receptions Under  \
# 0                    O 4.5          (-125)           (+105)
# 1                    O 5.5          (-190)           (-118)
# 2                    O 4.5          (-110)           (-110)
# 3                    O 4.5          (-105)           (-108)
# 4                    O 4.5          (+120)           (-154)
# ...                    ...             ...              ...
# 2011                   NaN             NaN              NaN
# 2012                 O 2.5          (+135)           (-174)
# 2013                 O 2.5          (+150)           (-195)
# 2014                   NaN             NaN              NaN
# 2015                 O 1.5          (+170)           (-225)
#
#      Receiving Yards Projection Receiving Yards Over Receiving Yards Under  \
# 0                        O 60.5               (-110)                (-110)
# 1                        O 62.5               (-110)                (-110)
# 2                        O 57.5               (-110)                (-110)
# 3                        O 66.5               (-110)                (-110)
# 4                        O 51.5               (-110)                (-110)
# ...                         ...                  ...                   ...
# 2011                        NaN                  NaN                   NaN
# 2012                     O 22.5               (-115)                (-115)
# 2013                     O 18.5               (-115)                (-115)
# 2014                        NaN                  NaN                   NaN
# 2015                     O 11.5               (-110)                (-121)
#
#      Rushing Yards Projection Rushing Yards Over Rushing Yards Under
# 0                         NaN                NaN                 NaN
# 1                         NaN                NaN                 NaN
# 2                         NaN                NaN                 NaN
# 3                         NaN                NaN                 NaN
# 4                         NaN                NaN                 NaN
# ...                       ...                ...                 ...
# 2011                      NaN                NaN                 NaN
# 2012                      NaN                NaN                 NaN
# 2013                      NaN                NaN                 NaN
# 2014                      NaN                NaN                 NaN
# 2015                      NaN                NaN                 NaN
#
# [2016 rows x 14 columns]

# %%
for column in ('Rushing Yards Projection', 'Receiving Yards Projection', 'Receptions Projection'):
    df[column] = df[column].str.extract(r'(\d+\.\d+)').astype(float)

df
# Out:
#       Year  Week      Player Name Team Anytime Touchdown Line  \
# 0     2020     1    calvin ridley  ATL                   +130
# 1     2020     1      cooper kupp  LAR                   +135
# 2     2020     1       dk metcalf  SEA                   +138
# 3     2020     1   michael gallup  DAL                   +155
# 4     2020     1         aj green  CIN                   +190
# ...    ...   ...              ...  ...                    ...
# 2011  2023    17  brandon johnson  DEN                    NaN
# 2012  2023    17    alex erickson  LAC                   +550
# 2013  2023    17    xavier gipson  NYJ                   +650
# 2014  2023    17      tyler scott  CHI                    NaN
# 2015  2023    17    van jefferson  ATL                   +700
#
#       Receptions Projection Receptions Over Receptions Under  \
# 0                       4.5          (-125)           (+105)
# 1                       5.5          (-190)           (-118)
# 2                       4.5          (-110)           (-110)
# 3                       4.5          (-105)           (-108)
# 4                       4.5          (+120)           (-154)
# ...                     ...             ...              ...
# 2011                    NaN             NaN              NaN
# 2012                    2.5          (+135)           (-174)
# 2013                    2.5          (+150)           (-195)
# 2014                    NaN             NaN              NaN
# 2015                    1.5          (+170)           (-225)
#
#       Receiving Yards Projection Receiving Yards Over Receiving Yards Under  \
# 0                           60.5               (-110)                (-110)
# 1                           62.5               (-110)                (-110)
# 2                           57.5               (-110)                (-110)
# 3                           66.5               (-110)                (-110)
# 4                           51.5               (-110)                (-110)
# ...                          ...                  ...                   ...
# 2011                         NaN                  NaN                   NaN
# 2012                        22.5               (-115)                (-115)
# 2013                        18.5               (-115)                (-115)
# 2014                         NaN                  NaN                   NaN
# 2015                        11.5               (-110)                (-121)
#
#       Rushing Yards Projection Rushing Yards Over Rushing Yards Under
# 0                          NaN                NaN                 NaN
# 1                          NaN                NaN                 NaN
# 2                          NaN                NaN                 NaN
# 3                          NaN                NaN                 NaN
# 4                          NaN                NaN                 NaN
# ...                        ...                ...                 ...
# 2011                       NaN                NaN                 NaN
# 2012                       NaN                NaN                 NaN
# 2013                       NaN                NaN                 NaN
# 2014                       NaN                NaN                 NaN
# 2015                       NaN                NaN                 NaN
#
# [2016 rows x 14 columns]

# %%
for column in ('Rushing Yards Over', 'Rushing Yards Under', 'Receiving Yards Over', 'Receiving Yards Under', 'Receptions Over', 'Receptions Under'):
    df.loc[df[column].str.contains('EVEN', regex=False, na=False), column] = '100'
    df.loc[df[column] == '--', column] = 'nan'
    df[column] = df[column].str.replace(r'\(|\)', '', regex=True).astype(float)

df
# Out:
#       Year  Week      Player Name Team Anytime Touchdown Line  \
# 0     2020     1    calvin ridley  ATL                   +130
# 1     2020     1      cooper kupp  LAR                   +135
# 2     2020     1       dk metcalf  SEA                   +138
# 3     2020     1   michael gallup  DAL                   +155
# 4     2020     1         aj green  CIN                   +190
# ...    ...   ...              ...  ...                    ...
# 2011  2023    17  brandon johnson  DEN                    NaN
# 2012  2023    17    alex erickson  LAC                   +550
# 2013  2023    17    xavier gipson  NYJ                   +650
# 2014  2023    17      tyler scott  CHI                    NaN
# 2015  2023    17    van jefferson  ATL                   +700
#
#       Receptions Projection  Receptions Over  Receptions Under  \
# 0                       4.5           -125.0             105.0
# 1                       5.5           -190.0            -118.0
# 2                       4.5           -110.0            -110.0
# 3                       4.5           -105.0            -108.0
# 4                       4.5            120.0            -154.0
# ...                     ...              ...               ...
# 2011                    NaN              NaN               NaN
# 2012                    2.5            135.0            -174.0
# 2013                    2.5            150.0            -195.0
# 2014                    NaN              NaN               NaN
# 2015                    1.5            170.0            -225.0
#
#       Receiving Yards Projection  Receiving Yards Over  Receiving Yards Under  \
# 0                           60.5                -110.0                 -110.0
# 1                           62.5                -110.0                 -110.0
# 2                           57.5                -110.0                 -110.0
# 3                           66.5                -110.0                 -110.0
# 4                           51.5                -110.0                 -110.0
# ...                          ...                   ...                    ...
# 2011                         NaN                   NaN                    NaN
# 2012                        22.5                -115.0                 -115.0
# 2013                        18.5                -115.0                 -115.0
# 2014                         NaN                   NaN                    NaN
# 2015                        11.5                -110.0                 -121.0
#
#       Rushing Yards Projection  Rushing Yards Over  Rushing Yards Under
# 0                          NaN                 NaN                  NaN
# 1                          NaN                 NaN                  NaN
# 2                          NaN                 NaN                  NaN
# 3                          NaN                 NaN                  NaN
# 4                          NaN                 NaN                  NaN
# ...                        ...                 ...                  ...
# 2011                       NaN                 NaN                  NaN
# 2012                       NaN                 NaN                  NaN
# 2013                       NaN                 NaN                  NaN
# 2014                       NaN                 NaN                  NaN
# 2015                       NaN                 NaN                  NaN
#
# [2016 rows x 14 columns]

# %%
for column in ('Anytime Touchdown Line', ):
    df.loc[df[column].str.contains('EVEN', regex=False, na=False), column] = '100'
    df.loc[df[column] == '--', column] = 'nan'
    df[column] = df[column].astype(float)

df
# Out:
#       Year  Week      Player Name Team  Anytime Touchdown Line  \
# 0     2020     1    calvin ridley  ATL                   130.0
# 1     2020     1      cooper kupp  LAR                   135.0
# 2     2020     1       dk metcalf  SEA                   138.0
# 3     2020     1   michael gallup  DAL                   155.0
# 4     2020     1         aj green  CIN                   190.0
# ...    ...   ...              ...  ...                     ...
# 2011  2023    17  brandon johnson  DEN                     NaN
# 2012  2023    17    alex erickson  LAC                   550.0
# 2013  2023    17    xavier gipson  NYJ                   650.0
# 2014  2023    17      tyler scott  CHI                     NaN
# 2015  2023    17    van jefferson  ATL                   700.0
#
#       Receptions Projection  Receptions Over  Receptions Under  \
# 0                       4.5           -125.0             105.0
# 1                       5.5           -190.0            -118.0
# 2                       4.5           -110.0            -110.0
# 3                       4.5           -105.0            -108.0
# 4                       4.5            120.0            -154.0
# ...                     ...              ...               ...
# 2011                    NaN              NaN               NaN
# 2012                    2.5            135.0            -174.0
# 2013                    2.5            150.0            -195.0
# 2014                    NaN              NaN               NaN
# 2015                    1.5            170.0            -225.0
#
#       Receiving Yards Projection  Receiving Yards Over  Receiving Yards Under  \
# 0                           60.5                -110.0                 -110.0
# 1                           62.5                -110.0                 -110.0
# 2                           57.5                -110.0                 -110.0
# 3                           66.5                -110.0                 -110.0
# 4                           51.5                -110.0                 -110.0
# ...                          ...                   ...                    ...
# 2011                         NaN                   NaN                    NaN
# 2012                        22.5                -115.0                 -115.0
# 2013                        18.5                -115.0                 -115.0
# 2014                         NaN                   NaN                    NaN
# 2015                        11.5                -110.0                 -121.0
#
#       Rushing Yards Projection  Rushing Yards Over  Rushing Yards Under
# 0                          NaN                 NaN                  NaN
# 1                          NaN                 NaN                  NaN
# 2                          NaN                 NaN                  NaN
# 3                          NaN                 NaN                  NaN
# 4                          NaN                 NaN                  NaN
# ...                        ...                 ...                  ...
# 2011                       NaN                 NaN                  NaN
# 2012                       NaN                 NaN                  NaN
# 2013                       NaN                 NaN                  NaN
# 2014                       NaN                 NaN                  NaN
# 2015                       NaN                 NaN                  NaN
#
# [2016 rows x 14 columns]

# %%
def american_odds_to_probability(odds):
    """
    Converts American betting odds to implied probability.
    
    Args:
        odds (int or float): The American odds value (e.g., -150, +200).

    Returns:
        float: The implied probability as a decimal (e.g., 0.60 for 60%).
    """
    if odds > 0:
        # Positive odds: (100 / (odds + 100))
        probability = 100 / (odds + 100)
    else:
        # Negative odds: (-odds / (-odds + 100))
        probability = -odds / (-odds + 100)
    
    return probability

# %% [markdown]
# Adjust projections based on over/under lines

# %%
for stat in ('Rushing Yards', 'Receiving Yards', 'Receptions'):
    df[f'Adjusted {stat} Projection'] = (
        df[f'{stat} Projection'] +
        0.5 * df[f'{stat} Over'].apply(american_odds_to_probability) -
        0.5 * df[f'{stat} Under'].apply(american_odds_to_probability)
    )

df
# Out:
#       Year  Week      Player Name Team  Anytime Touchdown Line  \
# 0     2020     1    calvin ridley  ATL                   130.0
# 1     2020     1      cooper kupp  LAR                   135.0
# 2     2020     1       dk metcalf  SEA                   138.0
# 3     2020     1   michael gallup  DAL                   155.0
# 4     2020     1         aj green  CIN                   190.0
# ...    ...   ...              ...  ...                     ...
# 2011  2023    17  brandon johnson  DEN                     NaN
# 2012  2023    17    alex erickson  LAC                   550.0
# 2013  2023    17    xavier gipson  NYJ                   650.0
# 2014  2023    17      tyler scott  CHI                     NaN
# 2015  2023    17    van jefferson  ATL                   700.0
#
#       Receptions Projection  Receptions Over  Receptions Under  \
# 0                       4.5           -125.0             105.0
# 1                       5.5           -190.0            -118.0
# 2                       4.5           -110.0            -110.0
# 3                       4.5           -105.0            -108.0
# 4                       4.5            120.0            -154.0
# ...                     ...              ...               ...
# 2011                    NaN              NaN               NaN
# 2012                    2.5            135.0            -174.0
# 2013                    2.5            150.0            -195.0
# 2014                    NaN              NaN               NaN
# 2015                    1.5            170.0            -225.0
#
#       Receiving Yards Projection  Receiving Yards Over  Receiving Yards Under  \
# 0                           60.5                -110.0                 -110.0
# 1                           62.5                -110.0                 -110.0
# 2                           57.5                -110.0                 -110.0
# 3                           66.5                -110.0                 -110.0
# 4                           51.5                -110.0                 -110.0
# ...                          ...                   ...                    ...
# 2011                         NaN                   NaN                    NaN
# 2012                        22.5                -115.0                 -115.0
# 2013                        18.5                -115.0                 -115.0
# 2014                         NaN                   NaN                    NaN
# 2015                        11.5                -110.0                 -121.0
#
#       Rushing Yards Projection  Rushing Yards Over  Rushing Yards Under  \
# 0                          NaN                 NaN                  NaN
# 1                          NaN                 NaN                  NaN
# 2                          NaN                 NaN                  NaN
# 3                          NaN                 NaN                  NaN
# 4                          NaN                 NaN                  NaN
# ...                        ...                 ...                  ...
# 2011                       NaN                 NaN                  NaN
# 2012                       NaN                 NaN                  NaN
# 2013                       NaN                 NaN                  NaN
# 2014                       NaN                 NaN                  NaN
# 2015                       NaN                 NaN                  NaN
#
#       Adjusted Rushing Yards Projection  Adjusted Receiving Yards Projection  \
# 0                                   NaN                            60.500000
# 1                                   NaN                            62.500000
# 2                                   NaN                            57.500000
# 3                                   NaN                            66.500000
# 4                                   NaN                            51.500000
# ...                                 ...                                  ...
# 2011                                NaN                                  NaN
# 2012                                NaN                            22.500000
# 2013                                NaN                            18.500000
# 2014                                NaN                                  NaN
# 2015                                NaN                            11.488149
#
#       Adjusted Receptions Projection
# 0                           4.533875
# 1                           5.556944
# 2                           4.500000
# 3                           4.496482
# 4                           4.424123
# ...                              ...
# 2011                             NaN
# 2012                        2.395248
# 2013                        2.369492
# 2014                             NaN
# 2015                        1.339031
#
# [2016 rows x 17 columns]

# %%
df['Anytime Touchdown Probability'] = df['Anytime Touchdown Line'].apply(american_odds_to_probability)

df
# Out:
#       Year  Week      Player Name Team  Anytime Touchdown Line  \
# 0     2020     1    calvin ridley  ATL                   130.0
# 1     2020     1      cooper kupp  LAR                   135.0
# 2     2020     1       dk metcalf  SEA                   138.0
# 3     2020     1   michael gallup  DAL                   155.0
# 4     2020     1         aj green  CIN                   190.0
# ...    ...   ...              ...  ...                     ...
# 2011  2023    17  brandon johnson  DEN                     NaN
# 2012  2023    17    alex erickson  LAC                   550.0
# 2013  2023    17    xavier gipson  NYJ                   650.0
# 2014  2023    17      tyler scott  CHI                     NaN
# 2015  2023    17    van jefferson  ATL                   700.0
#
#       Receptions Projection  Receptions Over  Receptions Under  \
# 0                       4.5           -125.0             105.0
# 1                       5.5           -190.0            -118.0
# 2                       4.5           -110.0            -110.0
# 3                       4.5           -105.0            -108.0
# 4                       4.5            120.0            -154.0
# ...                     ...              ...               ...
# 2011                    NaN              NaN               NaN
# 2012                    2.5            135.0            -174.0
# 2013                    2.5            150.0            -195.0
# 2014                    NaN              NaN               NaN
# 2015                    1.5            170.0            -225.0
#
#       Receiving Yards Projection  Receiving Yards Over  Receiving Yards Under  \
# 0                           60.5                -110.0                 -110.0
# 1                           62.5                -110.0                 -110.0
# 2                           57.5                -110.0                 -110.0
# 3                           66.5                -110.0                 -110.0
# 4                           51.5                -110.0                 -110.0
# ...                          ...                   ...                    ...
# 2011                         NaN                   NaN                    NaN
# 2012                        22.5                -115.0                 -115.0
# 2013                        18.5                -115.0                 -115.0
# 2014                         NaN                   NaN                    NaN
# 2015                        11.5                -110.0                 -121.0
#
#       Rushing Yards Projection  Rushing Yards Over  Rushing Yards Under  \
# 0                          NaN                 NaN                  NaN
# 1                          NaN                 NaN                  NaN
# 2                          NaN                 NaN                  NaN
# 3                          NaN                 NaN                  NaN
# 4                          NaN                 NaN                  NaN
# ...                        ...                 ...                  ...
# 2011                       NaN                 NaN                  NaN
# 2012                       NaN                 NaN                  NaN
# 2013                       NaN                 NaN                  NaN
# 2014                       NaN                 NaN                  NaN
# 2015                       NaN                 NaN                  NaN
#
#       Adjusted Rushing Yards Projection  Adjusted Receiving Yards Projection  \
# 0                                   NaN                            60.500000
# 1                                   NaN                            62.500000
# 2                                   NaN                            57.500000
# 3                                   NaN                            66.500000
# 4                                   NaN                            51.500000
# ...                                 ...                                  ...
# 2011                                NaN                                  NaN
# 2012                                NaN                            22.500000
# 2013                                NaN                            18.500000
# 2014                                NaN                                  NaN
# 2015                                NaN                            11.488149
#
#       Adjusted Receptions Projection  Anytime Touchdown Probability
# 0                           4.533875                       0.434783
# 1                           5.556944                       0.425532
# 2                           4.500000                       0.420168
# 3                           4.496482                       0.392157
# 4                           4.424123                       0.344828
# ...                              ...                            ...
# 2011                             NaN                            NaN
# 2012                        2.395248                       0.153846
# 2013                        2.369492                       0.133333
# 2014                             NaN                            NaN
# 2015                        1.339031                       0.125000
#
# [2016 rows x 18 columns]

# %%
df.to_parquet(r'..\..\data\betting_lines\wr2_props.parquet')

print('Done')
# Out:
# Done
