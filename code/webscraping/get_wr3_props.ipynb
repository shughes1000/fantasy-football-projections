# %% [markdown]
# Find relevant wide receivers to webscrape

# %%
import pandas as pd

pd.set_option('display.max_columns', 100)

df_superflex_rankings = pd.read_parquet(r'..\..\data\fantasypros_in_season_rankings\superflex_rankings.parquet')

df_superflex_rankings = df_superflex_rankings.loc[df_superflex_rankings['Player Name'].notna(), :].reset_index(drop=True)

df_superflex_rankings
# Out:
#        Year  Week   RK        Player Name POS  POS RK
# 0      2018     1    1     Todd Gurley II  RB       1
# 1      2018     1    2      David Johnson  RB       2
# 2      2018     1    3       Alvin Kamara  RB       3
# 3      2018     1    4  Melvin Gordon III  RB       4
# 4      2018     1    5    Ezekiel Elliott  RB       5
# ...     ...   ...  ...                ...  ..     ...
# 41050  2023    17  461    Steven Sims Jr.  WR     183
# 41051  2023    17  462     Jashaun Corbin  RB     112
# 41052  2023    17  463       Dee Eskridge  WR     184
# 41053  2023    17  464       Clayton Tune  QB      65
# 41054  2023    17  465      Brady Russell  TE     104
#
# [41055 rows x 6 columns]

# %%
df_wr = df_superflex_rankings.loc[df_superflex_rankings['POS'] == 'WR', :].sort_values(['Year', 'Week', 'POS RK'], ignore_index=True)

df_wr = df_wr.loc[df_wr['Year'] >= 2020, :].reset_index(drop=True)  # for now

df_wr.sort_values(['Year', 'Week', 'POS RK'], ignore_index=True, inplace=True)

df_wr
# Out:
#        Year  Week   RK       Player Name POS  POS RK
# 0      2020     1   21    Michael Thomas  WR       1
# 1      2020     1   33     Davante Adams  WR       2
# 2      2020     1   36       Julio Jones  WR       3
# 3      2020     1   37       Tyreek Hill  WR       4
# 4      2020     1   45      Chris Godwin  WR       5
# ...     ...   ...  ...               ...  ..     ...
# 11449  2023    17  458     Lucky Jackson  WR     180
# 11450  2023    17  459         DJ Turner  WR     181
# 11451  2023    17  460  Laquon Treadwell  WR     182
# 11452  2023    17  461   Steven Sims Jr.  WR     183
# 11453  2023    17  463      Dee Eskridge  WR     184
#
# [11454 rows x 6 columns]

# %%
df_wr.loc[df_wr['Player Name'].str.contains('-'), 'Player Name'].unique()
# Out:
# array(['JuJu Smith-Schuster', 'Marquez Valdes-Scantling',
#        'J.J. Arcega-Whiteside', 'Antonio Gandy-Golden',
#        'Ray-Ray McCloud III', 'Nick Westbrook-Ikhine',
#        'Tyron Billy-Johnson', 'Donovan Peoples-Jones',
#        'Amon-Ra St. Brown', 'Ihmir Smith-Marsette',
#        'Anthony Ratliff-Williams', 'Jaxon Smith-Njigba'], dtype=object)

# %%
df_wr.loc[df_wr['Player Name'].str.contains(r'(Sr\.|Jr\.)$', regex=True), 'Player Name'].unique()
# Out:
# C:\Users\mhugh\AppData\Local\Temp\ipykernel_21388\1394298560.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df_wr.loc[df_wr['Player Name'].str.contains(r'(Sr\.|Jr\.)$', regex=True), 'Player Name'].unique()
# array(['DJ Chark Jr.', 'Odell Beckham Jr.', 'Marvin Jones Jr.',
#        'Mecole Hardman Jr.', 'Steven Sims Jr.', 'Michael Pittman Jr.',
#        'Laviska Shenault Jr.', 'Jakeem Grant Sr.', 'Ted Ginn Jr.',
#        'Keelan Cole Sr.', 'Mohamed Sanu Sr.', 'KJ Hill Jr.',
#        'Cedrick Wilson Jr.', 'Jason Moore Jr.', 'Richie James Jr.',
#        'Trent Sherfield Sr.', 'Steven Mitchell Jr.', 'Cyril Grayson Jr.',
#        'Lynn Bowden Jr.', 'Victor Bolden Jr.', 'Paul Richardson Jr.',
#        'Deebo Samuel Sr.', 'Stanley Morgan Jr.', 'Terrace Marshall Jr.',
#        'Easop Winston Jr.', 'Jeff Cotton Jr.', 'Kaylon Geiger Sr.',
#        'Justin Hardee Sr.', 'Velus Jones Jr.', 'Marvin Mims Jr.',
#        'Austin Watkins Jr.'], dtype=object)

# %%
# make names easier to match
df_wr['Player Name'] = (
    df_wr['Player Name']
    .str.split().str[:2].str.join(' ')  # make names just the first two words
    .str.replace(r'[^a-zA-Z0-9\s]', '', regex=True)  # remove non-alphanumeric characters
    .str.lower()  # lowercase only (helps with matching)
)

df_wr
# Out:
#        Year  Week   RK       Player Name POS  POS RK
# 0      2020     1   21    michael thomas  WR       1
# 1      2020     1   33     davante adams  WR       2
# 2      2020     1   36       julio jones  WR       3
# 3      2020     1   37       tyreek hill  WR       4
# 4      2020     1   45      chris godwin  WR       5
# ...     ...   ...  ...               ...  ..     ...
# 11449  2023    17  458     lucky jackson  WR     180
# 11450  2023    17  459         dj turner  WR     181
# 11451  2023    17  460  laquon treadwell  WR     182
# 11452  2023    17  461       steven sims  WR     183
# 11453  2023    17  463      dee eskridge  WR     184
#
# [11454 rows x 6 columns]

# %% [markdown]
# Filter to relevant players

# %%
df_teams = pd.read_parquet('../../data/fantasy_points/footballguys_half_ppr.parquet')[['Season', 'Week', 'Name', 'Team', 'Position']]

df_teams['Name'] = (
    df_teams['Name'].str.split().str[:2].str.join(' ')  # make names just the first two words
    .str.replace(r'[^a-zA-Z0-9\s]', '', regex=True)  # remove non-alphanumeric characters
    .str.lower()  # lowercase only (helps with matching)
)

df_teams = df_teams.loc[df_teams['Position'] == 'WR', :].reset_index(drop=True)

df_teams
# Out:
#        Season  Week               Name Team Position
# 0        2018     1        tyreek hill   KC       WR
# 1        2018     1     michael thomas   NO       WR
# 2        2018     1     desean jackson   TB       WR
# 3        2018     1       randall cobb   GB       WR
# 4        2018     1       kenny stills  MIA       WR
# ...       ...   ...                ...  ...      ...
# 14200    2023    17   laquon treadwell  BAL       WR
# 14201    2023    17    kavontae turpin  DAL       WR
# 14202    2023    17      tylan wallace  BAL       WR
# 14203    2023    17  olamide zaccheaus  PHI       WR
# 14204    2023    17       samori toure   GB       WR
#
# [14205 rows x 5 columns]

# %% [markdown]
# Fix players with difficult names

# %%
df_teams.loc[df_teams['Name'] == 'will fuller', 'Name'] = 'william fuller'

# %%
df_wr = df_wr.merge(
    df_teams.rename(columns={'Season': 'Year', 'Name': 'Player Name', 'Position': 'POS'}),
    how='left',
    on=['Year', 'Week', 'Player Name', 'POS'],
)

df_wr.loc[(df_wr['Team'].isna()) & (df_wr['POS RK'] <= 25), :]

# 2022 Week 17 Bills at Bengals was cancelled
# Out:
#       Year  Week  RK   Player Name POS  POS RK Team
# 8359  2022    17  20  jamarr chase  WR       2  NaN

# %%
df_wr.loc[(df_wr['Team'].isna()) & (df_wr['POS RK'] <= 32*3), :].groupby(['Player Name'])['POS'].count()
# Out:
# Player Name
# aj green                   1
# albert wilson              2
# antonio gandygolden        1
# bisi johnson               3
# brandon zylstra            1
# braxton berrios            1
# dee eskridge               1
# denzel mims                1
# donovan peoplesjones       1
# gabe davis                 1
# greg dortch                1
# jamarr chase               1
# jarvis landry              1
# josh reynolds              1
# khadarel hodge             1
# marquez valdesscantling    1
# mecole hardman             1
# parris campbell            1
# rayray mccloud             1
# terrace marshall           2
# tom kennedy                1
# trenton irwin              1
# Name: POS, dtype: int64

# %%
df_wr = df_wr.loc[df_wr['Team'].notna(), :].reset_index(drop=True)

df_wr
# Out:
#       Year  Week   RK       Player Name POS  POS RK Team
# 0     2020     1   21    michael thomas  WR       1   NO
# 1     2020     1   33     davante adams  WR       2   GB
# 2     2020     1   36       julio jones  WR       3  ATL
# 3     2020     1   37       tyreek hill  WR       4   KC
# 4     2020     1   45      chris godwin  WR       5   TB
# ...    ...   ...  ...               ...  ..     ...  ...
# 9697  2023    17  414      jalen brooks  WR     168  DAL
# 9698  2023    17  423       keelan doss  WR     171  LAC
# 9699  2023    17  448   austin trammell  WR     177  LAR
# 9700  2023    17  458     lucky jackson  WR     180  MIN
# 9701  2023    17  460  laquon treadwell  WR     182  BAL
#
# [9702 rows x 7 columns]

# %%
df_wr = df_wr.groupby(['Year', 'Week', 'Team']).nth(2).reset_index(drop=True)

df_wr
# Out:
#       Year  Week   RK       Player Name POS  POS RK Team
# 0     2020     1  114       ceedee lamb  WR      41  DAL
# 1     2020     1  140     sammy watkins  WR      51   KC
# 2     2020     1  145     curtis samuel  WR      52  CAR
# 3     2020     1  151      randall cobb  WR      56  HOU
# 4     2020     1  153  larry fitzgerald  WR      58  ARI
# ...    ...   ...  ...               ...  ..     ...  ...
# 2008  2023    17  250        david bell  WR     103  CLE
# 2009  2023    17  266    equanimeous st  WR     110  CHI
# 2010  2023    17  272       julio jones  WR     113  PHI
# 2011  2023    17  297    khadarel hodge  WR     119  ATL
# 2012  2023    17  304       ronnie bell  WR     123   SF
#
# [2013 rows x 7 columns]

# %%
df_wr['Player Name URL'] = df_wr['Player Name'].str.replace(' ', '-')

# fix players who are known to have issues
df_wr.loc[df_wr['Player Name'] == 'juju smithschuster', 'Player Name URL'] = 'juju-smith-schuster'
df_wr.loc[df_wr['Player Name'] == 'jj arcegawhiteside', 'Player Name URL'] = 'jj-arcega-whiteside'
df_wr.loc[df_wr['Player Name'] == 'rayray mccloud', 'Player Name URL'] = 'ray-ray-mccloud'
df_wr.loc[df_wr['Player Name'] == 'donovan peoplesjones', 'Player Name URL'] = 'donovan-peoples-jones'
df_wr.loc[df_wr['Player Name'] == 'amonra st', 'Player Name URL'] = 'amonra-stbrown'
df_wr.loc[df_wr['Player Name'] == 'jaxon smithnjigba', 'Player Name URL'] = 'jaxon-smith-njigba'
df_wr.loc[df_wr['Player Name'] == 'ted ginn', 'Player Name URL'] = 'ted-ginn-jr'


df_wr
# Out:
#       Year  Week   RK       Player Name POS  POS RK Team   Player Name URL
# 0     2020     1  114       ceedee lamb  WR      41  DAL       ceedee-lamb
# 1     2020     1  140     sammy watkins  WR      51   KC     sammy-watkins
# 2     2020     1  145     curtis samuel  WR      52  CAR     curtis-samuel
# 3     2020     1  151      randall cobb  WR      56  HOU      randall-cobb
# 4     2020     1  153  larry fitzgerald  WR      58  ARI  larry-fitzgerald
# ...    ...   ...  ...               ...  ..     ...  ...               ...
# 2008  2023    17  250        david bell  WR     103  CLE        david-bell
# 2009  2023    17  266    equanimeous st  WR     110  CHI    equanimeous-st
# 2010  2023    17  272       julio jones  WR     113  PHI       julio-jones
# 2011  2023    17  297    khadarel hodge  WR     119  ATL    khadarel-hodge
# 2012  2023    17  304       ronnie bell  WR     123   SF       ronnie-bell
#
# [2013 rows x 8 columns]

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

options = Options()
# options.add_argument('--headless')

driver = webdriver.Chrome(options=options)

# %%
import time
from selenium.webdriver.common.by import By

def scrape_props(player_name, player_name_url, year, week, team):
    driver.get(url=f"https://www.bettingpros.com/nfl/odds/player-props/{player_name_url}/?season={year}&week={week}")
    time.sleep(5)

    # the page uses lazy loading
    # this loop helps all relevant elements load before scraping
    for _ in range(3):
        # find all loaded rows
        rows = driver.find_elements(
            by=By.CLASS_NAME,
            value="grouped-items-with-sticky-footer__content",
        )

        # scroll to the last loaded row, which should load subsequent rows if there are any
        if len(rows) > 0:
            driver.execute_script(f"window.scrollTo(0, {rows[-1].location['y']});")

        time.sleep(3)

    rows = driver.find_elements(
        by=By.CLASS_NAME,
        value="grouped-items-with-sticky-footer__content",
    )

    if len(rows) == 0:
        print(f"Warning: No rows for {player_name} {year} week {week}")
        
    data = {
        'Year': year,
        'Week': week,
        'Player Name': player_name,
        'Team': team,
    }
    for row in rows:
        t = row.text.split('\n')
        if t[0] == 'Rushing Yards Over/Under':
            data['Rushing Yards Projection'] = t[-4]
            data['Rushing Yards Over'] = t[-3]
            data['Rushing Yards Under'] = t[-1]
        elif t[0] == 'Receiving Yards Over/Under':
            data['Receiving Yards Projection'] = t[-4]
            data['Receiving Yards Over'] = t[-3]
            data['Receiving Yards Under'] = t[-1]
        elif t[0] == 'Receptions Over/Under':
            data['Receptions Projection'] = t[-4]
            data['Receptions Over'] = t[-3]
            data['Receptions Under'] = t[-1]
        elif t[0] == 'Anytime Touchdown Scorer':
            data['Anytime Touchdown Line'] = t[-1]

    return data

# %%
from tqdm.autonotebook import tqdm

d = []
for index, row in tqdm(list(df_wr.iterrows())):
    try:
        d.append(scrape_props(row['Player Name'], row['Player Name URL'], row['Year'], row['Week'], row['Team']))
    except Exception as e:
        print(f"Error with {row['Player Name'], row['Player Name URL'], row['Year'], row['Week'], row['Team']}: {e}")
# Out:
# C:\Users\mhugh\AppData\Local\Temp\ipykernel_21388\94795647.py:1: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm
#   0%|          | 0/2013 [00:00<?, ?it/s]
# Warning: No rows for larry fitzgerald 2020 week 1
# Warning: No rows for bisi johnson 2020 week 1
# Warning: No rows for scotty miller 2020 week 1
# Warning: No rows for larry fitzgerald 2020 week 2
# Warning: No rows for bisi johnson 2020 week 2
# Warning: No rows for scotty miller 2020 week 3
# Warning: No rows for bisi johnson 2020 week 4
# Warning: No rows for gabe davis 2020 week 5
# Warning: No rows for bisi johnson 2020 week 5
# Warning: No rows for mike williams 2020 week 5
# Warning: No rows for nick westbrookikhine 2020 week 5
# Warning: No rows for scotty miller 2020 week 6
# Warning: No rows for seth roberts 2020 week 6
# Warning: No rows for gabe davis 2020 week 7
# Warning: No rows for larry fitzgerald 2020 week 7
# Warning: No rows for scotty miller 2020 week 7
# Warning: No rows for austin carr 2020 week 8
# Warning: No rows for larry fitzgerald 2020 week 9
# Warning: No rows for larry fitzgerald 2020 week 10
# Warning: No rows for larry fitzgerald 2020 week 11
# Warning: No rows for gabe davis 2020 week 12
# Warning: No rows for cameron batson 2020 week 12
# Warning: No rows for gabe davis 2020 week 13
# Warning: No rows for steven mitchell 2020 week 13
# Warning: No rows for gabe davis 2020 week 14
# Warning: No rows for larry fitzgerald 2020 week 14
# Warning: No rows for cameron batson 2020 week 14
# Warning: No rows for gabe davis 2020 week 15
# Warning: No rows for larry fitzgerald 2020 week 15
# Warning: No rows for cameron batson 2020 week 15
# Warning: No rows for gabe davis 2020 week 16
# Warning: No rows for larry fitzgerald 2020 week 16
# Warning: No rows for cameron batson 2020 week 16
# Warning: No rows for joshua palmer 2021 week 1
# Warning: No rows for dee eskridge 2021 week 1
# Warning: No rows for william fuller 2021 week 3
# Warning: No rows for scotty miller 2021 week 3
# Warning: No rows for william fuller 2021 week 4
# Warning: No rows for nick westbrookikhine 2021 week 7
# Warning: No rows for nick westbrookikhine 2021 week 8
# Warning: No rows for nick westbrookikhine 2021 week 9
# Warning: No rows for nick westbrookikhine 2021 week 11
# Warning: No rows for joshua palmer 2021 week 11
# Warning: No rows for joshua palmer 2021 week 12
# Warning: No rows for joshua palmer 2021 week 13
# Warning: No rows for joshua palmer 2021 week 14
# Warning: No rows for dee eskridge 2021 week 14
# Warning: No rows for dee eskridge 2021 week 15
# Warning: No rows for nick westbrookikhine 2021 week 16
# Warning: No rows for scotty miller 2021 week 16
# Warning: No rows for dee eskridge 2021 week 16
# Warning: No rows for equanimeous st 2021 week 16
# Warning: No rows for joshua palmer 2021 week 17
# Warning: No rows for dee eskridge 2021 week 17
# Warning: No rows for joshua palmer 2022 week 1
# Warning: No rows for nick westbrookikhine 2022 week 1
# Warning: No rows for equanimeous st 2022 week 1
# Warning: No rows for dee eskridge 2022 week 1
# Warning: No rows for equanimeous st 2022 week 2
# Warning: No rows for dee eskridge 2022 week 2
# Warning: No rows for scotty miller 2022 week 3
# Warning: No rows for nick westbrookikhine 2022 week 3
# Warning: No rows for nick westbrookikhine 2022 week 4
# Warning: No rows for dee eskridge 2022 week 5
# Warning: No rows for velus jones 2022 week 6
# Warning: No rows for dee eskridge 2022 week 6
# Warning: No rows for robbie chosen 2022 week 7
# Warning: No rows for robbie chosen 2022 week 8
# Warning: No rows for mike thomas 2022 week 8
# Warning: No rows for mike thomas 2022 week 9
# Warning: No rows for robbie chosen 2022 week 9
# Warning: No rows for dee eskridge 2022 week 9
# Warning: No rows for tyron billyjohnson 2022 week 9
# Warning: No rows for robbie chosen 2022 week 10
# Warning: No rows for nick westbrookikhine 2022 week 10
# Warning: No rows for joshua palmer 2022 week 11
# Warning: No rows for nick westbrookikhine 2022 week 11
# Warning: No rows for equanimeous st 2022 week 11
# Warning: No rows for nick westbrookikhine 2022 week 12
# Warning: No rows for equanimeous st 2022 week 12
# Warning: No rows for brandon johnson 2022 week 12
# Warning: No rows for nick westbrookikhine 2022 week 13
# Warning: No rows for equanimeous st 2022 week 13
# Warning: No rows for joshua palmer 2022 week 14
# Warning: No rows for brandon johnson 2022 week 14
# Warning: No rows for joshua palmer 2022 week 15
# Warning: No rows for robbie chosen 2022 week 15
# Warning: No rows for joshua palmer 2022 week 16
# Warning: No rows for nick westbrookikhine 2022 week 16
# Warning: No rows for robbie chosen 2022 week 16
# Warning: No rows for velus jones 2022 week 16
# Warning: No rows for joshua palmer 2022 week 17
# Warning: No rows for nick westbrookikhine 2022 week 17
# Warning: No rows for tank dell 2023 week 1
# Warning: No rows for nick westbrookikhine 2023 week 1
# Warning: No rows for brandon johnson 2023 week 1
# Warning: No rows for tank dell 2023 week 2
# Warning: No rows for nick westbrookikhine 2023 week 2
# Warning: No rows for scotty miller 2023 week 2
# Warning: No rows for joshua palmer 2023 week 3
# Warning: No rows for nick westbrookikhine 2023 week 3
# Warning: No rows for tyler scott 2023 week 4
# Warning: No rows for equanimeous st 2023 week 5
# Warning: No rows for tyler scott 2023 week 6
# Warning: No rows for tyler scott 2023 week 7
# Warning: No rows for nick westbrookikhine 2023 week 8
# Warning: No rows for tyler scott 2023 week 8
# Warning: No rows for nick westbrookikhine 2023 week 9
# Warning: No rows for tyler scott 2023 week 9
# Warning: No rows for jauan jennings 2023 week 10
# Warning: No rows for tyler scott 2023 week 10
# Warning: No rows for nick westbrookikhine 2023 week 11
# Warning: No rows for tyler scott 2023 week 11
# Warning: No rows for tyler scott 2023 week 12
# Warning: No rows for tyler scott 2023 week 14
# Warning: No rows for tyler scott 2023 week 15
# Warning: No rows for tyler scott 2023 week 16
# Warning: No rows for equanimeous st 2023 week 17

# %%
driver.quit()

# %%
d
# Out:
# [{'Year': 2020,
#   'Week': 1,
#   'Player Name': 'ceedee lamb',
#   'Team': 'DAL',
#   'Receiving Yards Projection': 'O 50.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+125)',
#   'Receptions Under': '(-145)',
#   'Anytime Touchdown Line': '+260'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'sammy watkins',
#   'Team': 'KC',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+108)',
#   'Receptions Under': '(-136)',
#   'Anytime Touchdown Line': '+240',
#   'Receiving Yards Projection': 'O 42.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'curtis samuel',
#   'Team': 'CAR',
#   'Anytime Touchdown Line': '+275',
#   'Receiving Yards Projection': 'O 36.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+125)',
#   'Receptions Under': '(-145)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'randall cobb',
#   'Team': 'HOU',
#   'Anytime Touchdown Line': '+350',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-172)',
#   'Receptions Under': '(+134)',
#   'Receiving Yards Projection': 'O 35.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020, 'Week': 1, 'Player Name': 'larry fitzgerald', 'Team': 'ARI'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'hunter renfrow',
#   'Team': 'LV',
#   'Anytime Touchdown Line': '+180',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(EVEN)',
#   'Receptions Under': '(-120)',
#   'Receiving Yards Projection': 'O 43.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'michael pittman',
#   'Team': 'IND',
#   'Anytime Touchdown Line': '+360'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'james washington',
#   'Team': 'PIT',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-164)',
#   'Receptions Under': '(-160)',
#   'Anytime Touchdown Line': '+320',
#   'Receiving Yards Projection': 'O 35.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'cole beasley',
#   'Team': 'BUF',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+115)',
#   'Receptions Under': '(-145)',
#   'Receiving Yards Projection': 'O 40.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-120)',
#   'Anytime Touchdown Line': '+275'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'russell gage',
#   'Team': 'ATL',
#   'Anytime Touchdown Line': '+350'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'chris conley',
#   'Team': 'JAX',
#   'Anytime Touchdown Line': '+300',
#   'Receiving Yards Projection': 'O 35.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-135)',
#   'Receptions Under': '(+115)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'john ross',
#   'Team': 'CIN',
#   'Anytime Touchdown Line': '+350'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'van jefferson',
#   'Team': 'LAR',
#   'Anytime Touchdown Line': '+600'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'marquez valdesscantling',
#   'Team': 'GB',
#   'Anytime Touchdown Line': '+350',
#   'Receiving Yards Projection': 'O 30.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-115)',
#   'Receptions Under': '(-105)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'trequan smith',
#   'Team': 'NO',
#   'Anytime Touchdown Line': '+370'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'adam humphries',
#   'Team': 'TEN',
#   'Receiving Yards Projection': 'O 35.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+500',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-145)',
#   'Receptions Under': '(+125)'},
#  {'Year': 2020, 'Week': 1, 'Player Name': 'bisi johnson', 'Team': 'MIN'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'greg ward',
#   'Team': 'PHI',
#   'Receiving Yards Projection': 'O 27.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+375'},
#  {'Year': 2020, 'Week': 1, 'Player Name': 'scotty miller', 'Team': 'TB'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'david moore',
#   'Team': 'SEA',
#   'Anytime Touchdown Line': '+500'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'devin duvernay',
#   'Team': 'BAL',
#   'Anytime Touchdown Line': '+600'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'jakobi meyers',
#   'Team': 'NE',
#   'Anytime Touchdown Line': '+550'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'jakeem grant',
#   'Team': 'MIA',
#   'Anytime Touchdown Line': '+450'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'joe reed',
#   'Team': 'LAC',
#   'Anytime Touchdown Line': '+460'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'javon wims',
#   'Team': 'CHI',
#   'Anytime Touchdown Line': '+1000'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'dontrelle inman',
#   'Team': 'WAS',
#   'Anytime Touchdown Line': '+450'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'quintez cephus',
#   'Team': 'DET',
#   'Anytime Touchdown Line': '+900'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'chris hogan',
#   'Team': 'NYJ',
#   'Anytime Touchdown Line': '+600'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'dante pettis',
#   'Team': 'SF',
#   'Anytime Touchdown Line': '+500'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'daesean hamilton',
#   'Team': 'DEN',
#   'Receiving Yards Projection': 'O 32.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+420',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-160)',
#   'Receptions Under': '(+140)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'rashard higgins',
#   'Team': 'CLE',
#   'Anytime Touchdown Line': '+900'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'damion ratley',
#   'Team': 'NYG',
#   'Anytime Touchdown Line': '+700'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'ceedee lamb',
#   'Team': 'DAL',
#   'Anytime Touchdown Line': '+188',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-142)',
#   'Receptions Under': '(+110)',
#   'Receiving Yards Projection': 'O 62.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'marquez valdesscantling',
#   'Team': 'GB',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(+115)',
#   'Receptions Under': '(-135)',
#   'Receiving Yards Projection': 'O 27.5',
#   'Receiving Yards Over': '(-105)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+188'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'russell gage',
#   'Team': 'ATL',
#   'Receiving Yards Projection': 'O 44.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+340',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-140)',
#   'Receptions Under': '(-160)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'curtis samuel',
#   'Team': 'CAR',
#   'Anytime Touchdown Line': '+350',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+120)',
#   'Receptions Under': '(-152)',
#   'Receiving Yards Projection': 'O 37.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020, 'Week': 2, 'Player Name': 'larry fitzgerald', 'Team': 'ARI'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'mecole hardman',
#   'Team': 'KC',
#   'Anytime Touchdown Line': '+400',
#   'Receiving Yards Projection': 'O 18.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'randall cobb',
#   'Team': 'HOU',
#   'Anytime Touchdown Line': '+400'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'james washington',
#   'Team': 'PIT',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-125)',
#   'Receptions Under': '(+105)',
#   'Receiving Yards Projection': 'O 32.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+350'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'cole beasley',
#   'Team': 'BUF',
#   'Receiving Yards Projection': 'O 36.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+290',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+110)',
#   'Receptions Under': '(-168)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'hunter renfrow',
#   'Team': 'LV',
#   'Anytime Touchdown Line': '+250',
#   'Receiving Yards Projection': 'O 37.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+115)',
#   'Receptions Under': '(-143)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'golden tate',
#   'Team': 'NYG',
#   'Anytime Touchdown Line': '+280'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'john ross',
#   'Team': 'CIN',
#   'Anytime Touchdown Line': '+350',
#   'Receiving Yards Projection': 'O 30.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(EVEN)',
#   'Receptions Under': '(-138)'},
#  {'Year': 2020, 'Week': 2, 'Player Name': 'bisi johnson', 'Team': 'MIN'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'quintez cephus',
#   'Team': 'DET',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+110)',
#   'Receptions Under': '(-130)',
#   'Anytime Touchdown Line': '+220',
#   'Receiving Yards Projection': 'O 43.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'van jefferson',
#   'Team': 'LAR',
#   'Anytime Touchdown Line': '+650'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'greg ward',
#   'Team': 'PHI',
#   'Anytime Touchdown Line': '+350',
#   'Receiving Yards Projection': 'O 24.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(+112)',
#   'Receptions Under': '(-135)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'michael pittman',
#   'Team': 'IND',
#   'Anytime Touchdown Line': '+370'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'willie snead',
#   'Team': 'BAL',
#   'Anytime Touchdown Line': '+300'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'keelan cole',
#   'Team': 'JAX',
#   'Receiving Yards Projection': 'O 34.5',
#   'Receiving Yards Over': '(-105)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+400'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'dontrelle inman',
#   'Team': 'WAS',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(+110)',
#   'Receptions Under': '(-130)',
#   'Anytime Touchdown Line': '+450',
#   'Receiving Yards Projection': 'O 28.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'damiere byrd',
#   'Team': 'NE',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-130)',
#   'Receptions Under': '(+110)',
#   'Receiving Yards Projection': 'O 27.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+500'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'kj hamler',
#   'Team': 'DEN',
#   'Anytime Touchdown Line': '+700'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'isaiah ford',
#   'Team': 'MIA',
#   'Anytime Touchdown Line': '+450'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'david moore',
#   'Team': 'SEA',
#   'Anytime Touchdown Line': '+450'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'dante pettis',
#   'Team': 'SF',
#   'Anytime Touchdown Line': '+350'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'justin watson',
#   'Team': 'TB',
#   'Anytime Touchdown Line': '+450'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'deonte harty',
#   'Team': 'NO',
#   'Anytime Touchdown Line': '+650'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'kalif raymond',
#   'Team': 'TEN',
#   'Anytime Touchdown Line': '+500'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'javon wims',
#   'Team': 'CHI',
#   'Receiving Yards Projection': 'O 11.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+800'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'braxton berrios',
#   'Team': 'NYJ',
#   'Anytime Touchdown Line': '+500'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'jalen guyton',
#   'Team': 'LAC',
#   'Anytime Touchdown Line': '+650'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'rashard higgins',
#   'Team': 'CLE',
#   'Anytime Touchdown Line': '+600'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'michael gallup',
#   'Team': 'DAL',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+108)',
#   'Receptions Under': '(-138)',
#   'Receiving Yards Projection': 'O 60.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-111)',
#   'Anytime Touchdown Line': '+150'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'curtis samuel',
#   'Team': 'CAR',
#   'Anytime Touchdown Line': '+230',
#   'Receiving Yards Projection': 'O 32.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-130)',
#   'Receptions Under': '(EVEN)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'cole beasley',
#   'Team': 'BUF',
#   'Anytime Touchdown Line': '+290',
#   'Receiving Yards Projection': 'O 43.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-135)',
#   'Receptions Under': '(+105)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'sammy watkins',
#   'Team': 'KC',
#   'Anytime Touchdown Line': '+210',
#   'Receiving Yards Projection': 'O 39.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+115)',
#   'Receptions Under': '(-145)'},
#  {'Year': 2020, 'Week': 3, 'Player Name': 'scotty miller', 'Team': 'TB'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'randall cobb',
#   'Team': 'HOU',
#   'Anytime Touchdown Line': '+420',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+120)',
#   'Receptions Under': '(-146)',
#   'Receiving Yards Projection': 'O 38.5',
#   'Receiving Yards Over': '(-111)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'danny amendola',
#   'Team': 'DET',
#   'Anytime Touchdown Line': '+320',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-110)',
#   'Receptions Under': '(-111)',
#   'Receiving Yards Projection': 'O 44.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-111)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'chris conley',
#   'Team': 'JAX',
#   'Receiving Yards Projection': 'O 35.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+260',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-155)',
#   'Receptions Under': '(+135)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'zach pascal',
#   'Team': 'IND',
#   'Anytime Touchdown Line': '+140',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-156)',
#   'Receptions Under': '(+105)',
#   'Receiving Yards Projection': 'O 33.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'chase claypool',
#   'Team': 'PIT',
#   'Anytime Touchdown Line': '+310'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'andy isabella',
#   'Team': 'ARI',
#   'Anytime Touchdown Line': '+290',
#   'Receiving Yards Projection': 'O 31.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-130)',
#   'Receptions Under': '(EVEN)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'van jefferson',
#   'Team': 'LAR',
#   'Anytime Touchdown Line': '+420',
#   'Receiving Yards Projection': 'O 22.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'damiere byrd',
#   'Team': 'NE',
#   'Anytime Touchdown Line': '+290'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'isaiah ford',
#   'Team': 'MIA',
#   'Anytime Touchdown Line': '+375',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+125)',
#   'Receptions Under': '(-150)',
#   'Receiving Yards Projection': 'O 35.5',
#   'Receiving Yards Over': '(-111)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'tee higgins',
#   'Team': 'CIN',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-118)',
#   'Receptions Under': '(-108)',
#   'Receiving Yards Projection': 'O 33.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+400'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'david moore',
#   'Team': 'SEA',
#   'Anytime Touchdown Line': '+230'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'darnell mooney',
#   'Team': 'CHI',
#   'Anytime Touchdown Line': '+360'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'willie snead',
#   'Team': 'BAL',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-110)',
#   'Receptions Under': '(-120)',
#   'Anytime Touchdown Line': '+230',
#   'Receiving Yards Projection': 'O 30.5',
#   'Receiving Yards Over': '(-111)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'tim patrick',
#   'Team': 'DEN',
#   'Anytime Touchdown Line': '+550',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(+120)',
#   'Receptions Under': '(-150)',
#   'Receiving Yards Projection': 'O 28.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'nelson agholor',
#   'Team': 'LV',
#   'Anytime Touchdown Line': '+350'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'trent taylor',
#   'Team': 'SF',
#   'Anytime Touchdown Line': '+480'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'dontrelle inman',
#   'Team': 'WAS',
#   'Anytime Touchdown Line': '+400'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'jj arcegawhiteside',
#   'Team': 'PHI',
#   'Anytime Touchdown Line': '+400'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'deonte harty',
#   'Team': 'NO',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-113)',
#   'Receptions Under': '(-110)',
#   'Anytime Touchdown Line': '+280',
#   'Receiving Yards Projection': 'O 28.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'khadarel hodge',
#   'Team': 'CLE',
#   'Anytime Touchdown Line': '+390',
#   'Receiving Yards Projection': 'O 15.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'josh malone',
#   'Team': 'NYJ',
#   'Anytime Touchdown Line': '+450'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'jalen guyton',
#   'Team': 'LAC',
#   'Anytime Touchdown Line': '+375',
#   'Receiving Yards Projection': 'O 14.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'kalif raymond',
#   'Team': 'TEN',
#   'Anytime Touchdown Line': '+410'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'damion ratley',
#   'Team': 'NYG',
#   'Anytime Touchdown Line': '+800'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'olamide zaccheaus',
#   'Team': 'ATL',
#   'Anytime Touchdown Line': '+400'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'chad beebe',
#   'Team': 'MIN',
#   'Anytime Touchdown Line': '+950'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'ceedee lamb',
#   'Team': 'DAL',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-145)',
#   'Receptions Under': '(+115)',
#   'Receiving Yards Projection': 'O 62.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-111)',
#   'Anytime Touchdown Line': '+170'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'russell gage',
#   'Team': 'ATL',
#   'Anytime Touchdown Line': '+240',
#   'Receiving Yards Projection': 'O 50.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-125)',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+120)',
#   'Receptions Under': '(-150)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'tee higgins',
#   'Team': 'CIN',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-150)',
#   'Receptions Under': '(+120)',
#   'Anytime Touchdown Line': '+225',
#   'Receiving Yards Projection': 'O 45.5',
#   'Receiving Yards Over': '(-111)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'cole beasley',
#   'Team': 'BUF',
#   'Receiving Yards Projection': 'O 50.5',
#   'Receiving Yards Over': '(-112)',
#   'Receiving Yards Under': '(-111)',
#   'Anytime Touchdown Line': '+280',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+110)',
#   'Receptions Under': '(-133)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'keelan cole',
#   'Team': 'JAX',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+115)',
#   'Receptions Under': '(-143)',
#   'Anytime Touchdown Line': '+280',
#   'Receiving Yards Projection': 'O 40.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-111)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'curtis samuel',
#   'Team': 'CAR',
#   'Anytime Touchdown Line': '+190',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-110)',
#   'Receptions Under': '(-120)',
#   'Receiving Yards Projection': 'O 38.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-111)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'randall cobb',
#   'Team': 'HOU',
#   'Receiving Yards Projection': 'O 42.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+225',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(EVEN)',
#   'Receptions Under': '(-146)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'mecole hardman',
#   'Team': 'KC',
#   'Receiving Yards Projection': 'O 24.5',
#   'Receiving Yards Over': '(-120)',
#   'Receiving Yards Under': '(EVEN)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-188)',
#   'Receptions Under': '(-138)',
#   'Anytime Touchdown Line': '+300'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'andy isabella',
#   'Team': 'ARI',
#   'Anytime Touchdown Line': '+350'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'danny amendola',
#   'Team': 'DET',
#   'Receiving Yards Projection': 'O 36.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+400',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+120)',
#   'Receptions Under': '(-150)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'isaiah ford',
#   'Team': 'MIA',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+130)',
#   'Receptions Under': '(-162)',
#   'Anytime Touchdown Line': '+440',
#   'Receiving Yards Projection': 'O 37.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-111)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'damiere byrd',
#   'Team': 'NE',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+144)',
#   'Receptions Under': '(-186)',
#   'Receiving Yards Projection': 'O 34.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+500'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'chris hogan',
#   'Team': 'NYJ',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-115)',
#   'Receptions Under': '(-130)',
#   'Anytime Touchdown Line': '+333',
#   'Receiving Yards Projection': 'O 25.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'tim patrick',
#   'Team': 'DEN',
#   'Receiving Yards Projection': 'O 30.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-120)',
#   'Receptions Under': '(-105)',
#   'Anytime Touchdown Line': '+333'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'david moore',
#   'Team': 'SEA',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(+130)',
#   'Receptions Under': '(-160)',
#   'Receiving Yards Projection': 'O 24.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+450'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'willie snead',
#   'Team': 'BAL',
#   'Anytime Touchdown Line': '+320',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-190)',
#   'Receptions Under': '(+155)',
#   'Receiving Yards Projection': 'O 21.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-111)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'darnell mooney',
#   'Team': 'CHI',
#   'Anytime Touchdown Line': '+375',
#   'Receiving Yards Projection': 'O 28.5',
#   'Receiving Yards Over': '(-111)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-110)',
#   'Receptions Under': '(-113)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'justin watson',
#   'Team': 'TB',
#   'Anytime Touchdown Line': '+310'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'josh reynolds',
#   'Team': 'LAR',
#   'Anytime Touchdown Line': '+410',
#   'Receiving Yards Projection': 'O 31.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(+105)',
#   'Receptions Under': '(-125)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'deebo samuel',
#   'Team': 'SF',
#   'Anytime Touchdown Line': '+225',
#   'Receptions Projection': 'O 1.5',
#   'Receptions Over': '(-160)',
#   'Receptions Under': '(+130)',
#   'Receiving Yards Projection': 'O 19.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'zay jones',
#   'Team': 'LV',
#   'Receiving Yards Projection': 'O 27.5',
#   'Receiving Yards Over': '(-111)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+370',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(EVEN)',
#   'Receptions Under': '(-130)'},
#  {'Year': 2020, 'Week': 4, 'Player Name': 'bisi johnson', 'Team': 'MIN'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'deonte harty',
#   'Team': 'NO',
#   'Anytime Touchdown Line': '+450'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'daurice fountain',
#   'Team': 'IND',
#   'Anytime Touchdown Line': '+750'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'damion ratley',
#   'Team': 'NYG',
#   'Anytime Touchdown Line': '+1100',
#   'Receiving Yards Projection': 'O 8.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'deontay burnett',
#   'Team': 'PHI',
#   'Receiving Yards Projection': 'O 17.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+700'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'isaiah wright',
#   'Team': 'WAS',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-106)',
#   'Receptions Under': '(-120)',
#   'Anytime Touchdown Line': '+650',
#   'Receiving Yards Projection': 'O 28.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'kj hill',
#   'Team': 'LAC',
#   'Anytime Touchdown Line': '+800'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'malik taylor',
#   'Team': 'GB',
#   'Anytime Touchdown Line': '+550'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'donovan peoplesjones',
#   'Team': 'CLE',
#   'Anytime Touchdown Line': '+1100'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'michael gallup',
#   'Team': 'DAL',
#   'Anytime Touchdown Line': '+170',
#   'Receiving Yards Projection': 'O 44.5',
#   'Receiving Yards Over': '(-122)',
#   'Receiving Yards Under': '(EVEN)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+118)',
#   'Receptions Under': '(-150)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'aj green',
#   'Team': 'CIN',
#   'Anytime Touchdown Line': '+275',
#   'Receiving Yards Projection': 'O 38.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-113)',
#   'Receptions Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'mecole hardman',
#   'Team': 'KC',
#   'Anytime Touchdown Line': '+225',
#   'Receiving Yards Projection': 'O 29.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-102)',
#   'Receptions Under': '(-125)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'curtis samuel',
#   'Team': 'CAR',
#   'Receiving Yards Projection': 'O 36.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+112)',
#   'Receptions Under': '(-142)',
#   'Anytime Touchdown Line': '+195'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'randall cobb',
#   'Team': 'HOU',
#   'Receiving Yards Projection': 'O 35.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+200',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-145)',
#   'Receptions Under': '(-158)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'olamide zaccheaus',
#   'Team': 'ATL',
#   'Anytime Touchdown Line': '+300'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'keelan cole',
#   'Team': 'JAX',
#   'Anytime Touchdown Line': '+275',
#   'Receiving Yards Projection': 'O 39.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+118)',
#   'Receptions Under': '(-150)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'isaiah ford',
#   'Team': 'MIA',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-125)',
#   'Receptions Under': '(-115)',
#   'Anytime Touchdown Line': '+400',
#   'Receiving Yards Projection': 'O 44.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-134)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'david moore',
#   'Team': 'SEA',
#   'Receiving Yards Projection': 'O 28.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(+125)',
#   'Receptions Under': '(-167)',
#   'Anytime Touchdown Line': '+200'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'darnell mooney',
#   'Team': 'CHI',
#   'Anytime Touchdown Line': '+350',
#   'Receiving Yards Projection': 'O 37.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+120)',
#   'Receptions Under': '(-182)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'andy isabella',
#   'Team': 'ARI',
#   'Anytime Touchdown Line': '+450',
#   'Receiving Yards Projection': 'O 24.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(+115)',
#   'Receptions Under': '(-145)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'nelson agholor',
#   'Team': 'LV',
#   'Receiving Yards Projection': 'O 25.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+470',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(+118)',
#   'Receptions Under': '(-150)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'kendrick bourne',
#   'Team': 'SF',
#   'Anytime Touchdown Line': '+290',
#   'Receiving Yards Projection': 'O 30.5',
#   'Receiving Yards Over': '(-118)',
#   'Receiving Yards Under': '(-118)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+144)',
#   'Receptions Under': '(-186)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'james washington',
#   'Team': 'PIT',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-140)',
#   'Receptions Under': '(+110)',
#   'Anytime Touchdown Line': '+350',
#   'Receiving Yards Projection': 'O 31.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'chris hogan',
#   'Team': 'NYJ',
#   'Anytime Touchdown Line': '+350'},
#  {'Year': 2020, 'Week': 5, 'Player Name': 'gabe davis', 'Team': 'BUF'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'josh reynolds',
#   'Team': 'LAR',
#   'Receiving Yards Projection': 'O 26.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+500',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(+136)',
#   'Receptions Under': '(-174)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'willie snead',
#   'Team': 'BAL',
#   'Anytime Touchdown Line': '+410',
#   'Receiving Yards Projection': 'O 24.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(+140)',
#   'Receptions Under': '(-175)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'isaiah wright',
#   'Team': 'WAS',
#   'Anytime Touchdown Line': '+470'},
#  {'Year': 2020, 'Week': 5, 'Player Name': 'bisi johnson', 'Team': 'MIN'},
#  {'Year': 2020, 'Week': 5, 'Player Name': 'mike williams', 'Team': 'LAC'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'tyler johnson',
#   'Team': 'TB',
#   'Anytime Touchdown Line': '+400',
#   'Receiving Yards Projection': 'O 19.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'daurice fountain',
#   'Team': 'IND',
#   'Anytime Touchdown Line': '+1000'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'travis fulgham',
#   'Team': 'PHI',
#   'Anytime Touchdown Line': '+650'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'damion ratley',
#   'Team': 'NYG',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(+140)',
#   'Receptions Under': '(-170)',
#   'Anytime Touchdown Line': '+850',
#   'Receiving Yards Projection': 'O 24.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'donovan peoplesjones',
#   'Team': 'CLE',
#   'Anytime Touchdown Line': '+650'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'nick westbrookikhine',
#   'Team': 'TEN'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'marquez callaway',
#   'Team': 'NO',
#   'Anytime Touchdown Line': '+550'},
#  {'Year': 2020,
#   'Week': 6,
#   'Player Name': 'michael gallup',
#   'Team': 'DAL',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+142)',
#   'Receptions Under': '(-182)',
#   'Receiving Yards Projection': 'O 41.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+200'},
#  {'Year': 2020,
#   'Week': 6,
#   'Player Name': 'keelan cole',
#   'Team': 'JAX',
#   'Anytime Touchdown Line': '+240'},
#  {'Year': 2020,
#   'Week': 6,
#   'Player Name': 'cole beasley',
#   'Team': 'BUF',
#   'Anytime Touchdown Line': '+310',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-140)',
#   'Receptions Under': '(+110)',
#   'Receiving Yards Projection': 'O 44.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 6,
#   'Player Name': 'randall cobb',
#   'Team': 'HOU',
#   'Receiving Yards Projection': 'O 41.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-105)',
#   'Receptions Under': '(-115)',
#   'Anytime Touchdown Line': '+310'},
#  {'Year': 2020,
#   'Week': 6,
#   'Player Name': 'russell gage',
#   'Team': 'ATL',
#   'Receiving Yards Projection': 'O 40.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-113)',
#   'Receptions Under': '(-113)',
#   'Anytime Touchdown Line': '+220'},
#  {'Year': 2020,
#   'Week': 6,
#   'Player Name': 'james washington',
#   'Team': 'PIT',
#   'Anytime Touchdown Line': '+200',
#   'Receiving Yards Projection': 'O 43.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 6,
#   'Player Name': 'damiere byrd',
#   'Team': 'NE',
#   'Receiving Yards Projection': 'O 38.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+300'},
#  {'Year': 2020, 'Week': 6, 'Player Name': 'scotty miller', 'Team': 'TB'},
#  {'Year': 2020,
#   'Week': 6,
#   'Player Name': 'demarcus robinson',
#   'Team': 'KC',
#   'Anytime Touchdown Line': '+290',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-125)',
#   'Receptions Under': '(-105)',
#   'Receiving Yards Projection': 'O 32.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 6,
#   'Player Name': 'aj green',
#   'Team': 'CIN',
#   'Anytime Touchdown Line': '+190'},
#  {'Year': 2020,
#   'Week': 6,
#   'Player Name': 'anthony miller',
#   'Team': 'CHI',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-110)',
#   'Receptions Under': '(-120)',
#   'Receiving Yards Projection': 'O 27.5',
#   'Receiving Yards Over': '(-120)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+320'},
#  {'Year': 2020,
#   'Week': 6,
#   'Player Name': 'andy isabella',
#   'Team': 'ARI',
#   'Receptions Projection': 'O 1.5',
#   'Receptions Over': '(-180)',
#   'Receptions Under': '(+150)',
#   'Receiving Yards Projection': 'O 24.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+400'},
#  {'Year': 2020,
#   'Week': 6,
#   'Player Name': 'kendrick bourne',
#   'Team': 'SF',
#   'Receiving Yards Projection': 'O 30.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+340',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-102)',
#   'Receptions Under': '(-125)'},
#  {'Year': 2020,
#   'Week': 6,
#   'Player Name': 'danny amendola',
#   'Team': 'DET',
#   'Receiving Yards Projection': 'O 37.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+300',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+115)',
#   'Receptions Under': '(-156)'},
#  {'Year': 2020,
#   'Week': 6,
#   'Player Name': 'isaiah ford',
#   'Team': 'MIA',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-140)',
#   'Receptions Under': '(+110)',
#   'Anytime Touchdown Line': '+333',
#   'Receiving Yards Projection': 'O 30.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 6,
#   'Player Name': 'josh reynolds',
#   'Team': 'LAR',
#   'Receiving Yards Projection': 'O 30.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-105)',
#   'Receptions Under': '(-105)',
#   'Anytime Touchdown Line': '+500'},
#  {'Year': 2020,
#   'Week': 6,
#   'Player Name': 'john hightower',
#   'Team': 'PHI',
#   'Anytime Touchdown Line': '+450'},
#  {'Year': 2020,
#   'Week': 6,
#   'Player Name': 'breshad perriman',
#   'Team': 'NYJ',
#   'Anytime Touchdown Line': '+300'},
#  {'Year': 2020,
#   'Week': 6,
#   'Player Name': 'kalif raymond',
#   'Team': 'TEN',
#   'Anytime Touchdown Line': '+350'},
#  {'Year': 2020,
#   'Week': 6,
#   'Player Name': 'willie snead',
#   'Team': 'BAL',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(+140)',
#   'Receptions Under': '(-170)',
#   'Anytime Touchdown Line': '+310',
#   'Receiving Yards Projection': 'O 23.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 6,
#   'Player Name': 'isaiah wright',
#   'Team': 'WAS',
#   'Anytime Touchdown Line': '+550',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(+110)',
#   'Receptions Under': '(-147)',
#   'Receiving Yards Projection': 'O 24.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 6,
#   'Player Name': 'daesean hamilton',
#   'Team': 'DEN',
#   'Anytime Touchdown Line': '+410'},
#  {'Year': 2020,
#   'Week': 6,
#   'Player Name': 'marcus johnson',
#   'Team': 'IND',
#   'Anytime Touchdown Line': '+400'},
#  {'Year': 2020,
#   'Week': 6,
#   'Player Name': 'rashard higgins',
#   'Team': 'CLE',
#   'Anytime Touchdown Line': '+375'},
#  {'Year': 2020,
#   'Week': 6,
#   'Player Name': 'chad beebe',
#   'Team': 'MIN',
#   'Anytime Touchdown Line': '+750'},
#  {'Year': 2020,
#   'Week': 6,
#   'Player Name': 'darrius shepherd',
#   'Team': 'GB',
#   'Anytime Touchdown Line': '+650'},
#  {'Year': 2020, 'Week': 6, 'Player Name': 'seth roberts', 'Team': 'CAR'},
#  {'Year': 2020,
#   'Week': 6,
#   'Player Name': 'cj board',
#   'Team': 'NYG',
#   'Anytime Touchdown Line': '+550',
#   'Receptions Projection': 'O 1.5',
#   'Receptions Over': '(-182)',
#   'Receptions Under': '(+135)'},
#  {'Year': 2020,
#   'Week': 7,
#   'Player Name': 'diontae johnson',
#   'Team': 'PIT',
#   'Anytime Touchdown Line': '+190',
#   'Receiving Yards Projection': 'O 43.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-115)',
#   'Receptions Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 7,
#   'Player Name': 'michael gallup',
#   'Team': 'DAL',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-150)',
#   'Receptions Under': '(+130)',
#   'Anytime Touchdown Line': '+310',
#   'Receiving Yards Projection': 'O 41.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 7,
#   'Player Name': 'keelan cole',
#   'Team': 'JAX',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-120)',
#   'Receptions Under': '(-110)',
#   'Anytime Touchdown Line': '+250',
#   'Receiving Yards Projection': 'O 47.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 7,
#   'Player Name': 'aj green',
#   'Team': 'CIN',
#   'Receiving Yards Projection': 'O 50.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+225'},
#  {'Year': 2020,
#   'Week': 7,
#   'Player Name': 'randall cobb',
#   'Team': 'HOU',
#   'Anytime Touchdown Line': '+220',
#   'Receiving Yards Projection': 'O 43.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(EVEN)',
#   'Receptions Under': '(-128)'},
#  {'Year': 2020,
#   'Week': 7,
#   'Player Name': 'russell gage',
#   'Team': 'ATL',
#   'Anytime Touchdown Line': '+275',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(EVEN)',
#   'Receptions Under': '(-130)',
#   'Receiving Yards Projection': 'O 40.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2020, 'Week': 7, 'Player Name': 'gabe davis', 'Team': 'BUF'},
#  {'Year': 2020,
#   'Week': 7,
#   'Player Name': 'mecole hardman',
#   'Team': 'KC',
#   'Receiving Yards Projection': 'O 25.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+250',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(+124)',
#   'Receptions Under': '(-158)'},
#  {'Year': 2020,
#   'Week': 7,
#   'Player Name': 'adam humphries',
#   'Team': 'TEN',
#   'Receiving Yards Projection': 'O 41.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+250',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+114)',
#   'Receptions Under': '(-146)'},
#  {'Year': 2020,
#   'Week': 7,
#   'Player Name': 'nkeal harry',
#   'Team': 'NE',
#   'Receiving Yards Projection': 'O 38.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-118)',
#   'Receptions Under': '(-108)',
#   'Anytime Touchdown Line': '+250'},
#  {'Year': 2020,
#   'Week': 7,
#   'Player Name': 'greg ward',
#   'Team': 'PHI',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-136)',
#   'Receptions Under': '(+105)',
#   'Receiving Yards Projection': 'O 32.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+200'},
#  {'Year': 2020,
#   'Week': 7,
#   'Player Name': 'danny amendola',
#   'Team': 'DET',
#   'Anytime Touchdown Line': '+350',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-150)',
#   'Receptions Under': '(+120)',
#   'Receiving Yards Projection': 'O 33.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2020, 'Week': 7, 'Player Name': 'larry fitzgerald', 'Team': 'ARI'},
#  {'Year': 2020,
#   'Week': 7,
#   'Player Name': 'anthony miller',
#   'Team': 'CHI',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-113)',
#   'Receptions Under': '(-115)',
#   'Receiving Yards Projection': 'O 28.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+400'},
#  {'Year': 2020,
#   'Week': 7,
#   'Player Name': 'kendrick bourne',
#   'Team': 'SF',
#   'Receiving Yards Projection': 'O 28.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(+102)',
#   'Receptions Under': '(-130)',
#   'Anytime Touchdown Line': '+400'},
#  {'Year': 2020,
#   'Week': 7,
#   'Player Name': 'nelson agholor',
#   'Team': 'LV',
#   'Receiving Yards Projection': 'O 25.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+400',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(+126)',
#   'Receptions Under': '(-162)'},
#  {'Year': 2020, 'Week': 7, 'Player Name': 'scotty miller', 'Team': 'TB'},
#  {'Year': 2020,
#   'Week': 7,
#   'Player Name': 'curtis samuel',
#   'Team': 'CAR',
#   'Receiving Yards Projection': 'O 39.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-120)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(EVEN)',
#   'Receptions Under': '(-130)',
#   'Anytime Touchdown Line': '+350'},
#  {'Year': 2020,
#   'Week': 7,
#   'Player Name': 'jeff smith',
#   'Team': 'NYJ',
#   'Anytime Touchdown Line': '+350',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-160)',
#   'Receptions Under': '(+130)',
#   'Receiving Yards Projection': 'O 34.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 7,
#   'Player Name': 'josh reynolds',
#   'Team': 'LAR',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-110)',
#   'Receptions Under': '(-120)',
#   'Receiving Yards Projection': 'O 33.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-120)',
#   'Anytime Touchdown Line': '+350'},
#  {'Year': 2020,
#   'Week': 7,
#   'Player Name': 'david moore',
#   'Team': 'SEA',
#   'Receiving Yards Projection': 'O 24.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(+140)',
#   'Receptions Under': '(-180)',
#   'Anytime Touchdown Line': '+350'},
#  {'Year': 2020,
#   'Week': 7,
#   'Player Name': 'sterling shepard',
#   'Team': 'NYG',
#   'Receiving Yards Projection': 'O 31.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-120)',
#   'Anytime Touchdown Line': '+250'},
#  {'Year': 2020,
#   'Week': 7,
#   'Player Name': 'rashard higgins',
#   'Team': 'CLE',
#   'Anytime Touchdown Line': '+350'},
#  {'Year': 2020,
#   'Week': 7,
#   'Player Name': 'jalen guyton',
#   'Team': 'LAC',
#   'Anytime Touchdown Line': '+350',
#   'Receiving Yards Projection': 'O 23.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 7,
#   'Player Name': 'daesean hamilton',
#   'Team': 'DEN',
#   'Anytime Touchdown Line': '+1000'},
#  {'Year': 2020,
#   'Week': 7,
#   'Player Name': 'deonte harty',
#   'Team': 'NO',
#   'Receiving Yards Projection': 'O 21.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(+140)',
#   'Receptions Under': '(-170)',
#   'Anytime Touchdown Line': '+400'},
#  {'Year': 2020,
#   'Week': 7,
#   'Player Name': 'darrius shepherd',
#   'Team': 'GB',
#   'Anytime Touchdown Line': '+600'},
#  {'Year': 2020,
#   'Week': 7,
#   'Player Name': 'cam sims',
#   'Team': 'WAS',
#   'Receiving Yards Projection': 'O 23.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+500'},
#  {'Year': 2020,
#   'Week': 8,
#   'Player Name': 'chase claypool',
# ...
#   'Week': 15,
#   'Player Name': 'mack hollins',
#   'Team': 'MIA',
#   'Anytime Touchdown Line': '+450'},
#  {'Year': 2021,
#   'Week': 15,
#   'Player Name': 'quez watkins',
#   'Team': 'PHI',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(+125)',
#   'Receptions Under': '(-167)',
#   'Anytime Touchdown Line': '+450',
#   'Receiving Yards Projection': 'O 27.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2021,
#   'Week': 15,
#   'Player Name': 'brandon zylstra',
#   'Team': 'CAR',
#   'Anytime Touchdown Line': '+800',
#   'Receiving Yards Projection': 'O 19.5',
#   'Receiving Yards Over': '(+105)',
#   'Receiving Yards Under': '(-135)'},
#  {'Year': 2021,
#   'Week': 15,
#   'Player Name': 'ihmir smithmarsette',
#   'Team': 'MIN',
#   'Anytime Touchdown Line': '+400'},
#  {'Year': 2021,
#   'Week': 15,
#   'Player Name': 'liljordan humphrey',
#   'Team': 'NO',
#   'Receiving Yards Projection': 'O 19.5',
#   'Receiving Yards Over': '(-120)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+650'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'van jefferson',
#   'Team': 'LAR',
#   'Receiving Yards Projection': 'O 47.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+180',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-125)',
#   'Receptions Under': '(-105)'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'michael gallup',
#   'Team': 'DAL',
#   'Receiving Yards Projection': 'O 46.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+180',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+124)',
#   'Receptions Under': '(-158)'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'tyler boyd',
#   'Team': 'CIN',
#   'Anytime Touchdown Line': '+200',
#   'Receiving Yards Projection': 'O 46.5',
#   'Receiving Yards Over': '(-111)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+120)',
#   'Receptions Under': '(-160)'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'tim patrick',
#   'Team': 'DEN',
#   'Anytime Touchdown Line': '+300',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-128)',
#   'Receptions Under': '(+105)',
#   'Receiving Yards Projection': 'O 29.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-111)'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'kj osborn',
#   'Team': 'MIN',
#   'Anytime Touchdown Line': '+290'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'nick westbrookikhine',
#   'Team': 'TEN'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'byron pringle',
#   'Team': 'KC',
#   'Receiving Yards Projection': 'O 26.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+250'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'james washington',
#   'Team': 'PIT',
#   'Anytime Touchdown Line': '+450'},
#  {'Year': 2021, 'Week': 16, 'Player Name': 'scotty miller', 'Team': 'TB'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'kalif raymond',
#   'Team': 'DET',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-118)',
#   'Receptions Under': '(-115)',
#   'Receiving Yards Projection': 'O 27.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-120)',
#   'Anytime Touchdown Line': '+350'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'isaiah mckenzie',
#   'Team': 'BUF',
#   'Anytime Touchdown Line': '+250',
#   'Receiving Yards Projection': 'O 18.5',
#   'Receiving Yards Over': '(-114)',
#   'Receiving Yards Under': '(-114)'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'darius slayton',
#   'Team': 'NYG',
#   'Anytime Touchdown Line': '+450'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'antoine wesley',
#   'Team': 'ARI',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-160)',
#   'Receptions Under': '(+115)',
#   'Receiving Yards Projection': 'O 30.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-130)',
#   'Anytime Touchdown Line': '+225'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'desean jackson',
#   'Team': 'LV',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-150)',
#   'Receptions Under': '(+120)',
#   'Receiving Yards Projection': 'O 37.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-120)',
#   'Anytime Touchdown Line': '+350'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'deandre carter',
#   'Team': 'WAS',
#   'Anytime Touchdown Line': '+400',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(+105)',
#   'Receptions Under': '(-140)',
#   'Receiving Yards Projection': 'O 24.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'nkeal harry',
#   'Team': 'NE',
#   'Anytime Touchdown Line': '+650',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(+115)',
#   'Receptions Under': '(-154)',
#   'Receiving Yards Projection': 'O 24.5',
#   'Receiving Yards Over': '(-118)',
#   'Receiving Yards Under': '(-111)'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'jauan jennings',
#   'Team': 'SF',
#   'Receptions Projection': 'O 1.5',
#   'Receptions Over': '(-165)',
#   'Receptions Under': '(+130)',
#   'Anytime Touchdown Line': '+400',
#   'Receiving Yards Projection': 'O 20.5',
#   'Receiving Yards Over': '(-118)',
#   'Receiving Yards Under': '(-111)'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'jalen reagor',
#   'Team': 'PHI',
#   'Receptions Projection': 'O 1.5',
#   'Receptions Over': '(-149)',
#   'Receptions Under': '(+115)',
#   'Receiving Yards Projection': 'O 17.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-118)',
#   'Anytime Touchdown Line': '+410'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'rashard higgins',
#   'Team': 'CLE',
#   'Receiving Yards Projection': 'O 14.5',
#   'Receiving Yards Over': '(-120)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+600'},
#  {'Year': 2021, 'Week': 16, 'Player Name': 'dee eskridge', 'Team': 'SEA'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'phillip dorsett',
#   'Team': 'HOU',
#   'Receiving Yards Projection': 'O 20.0',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+450'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'sammy watkins',
#   'Team': 'BAL',
#   'Receiving Yards Projection': 'O 20.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+350'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'ashton dulin',
#   'Team': 'IND',
#   'Anytime Touchdown Line': '+550'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'denzel mims',
#   'Team': 'NYJ',
#   'Anytime Touchdown Line': '+390'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'liljordan humphrey',
#   'Team': 'NO',
#   'Anytime Touchdown Line': '+600'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'tavon austin',
#   'Team': 'JAX',
#   'Anytime Touchdown Line': '+380'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'marquise goodwin',
#   'Team': 'CHI',
#   'Anytime Touchdown Line': '+350'},
#  {'Year': 2021, 'Week': 16, 'Player Name': 'equanimeous st', 'Team': 'GB'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'isaiah ford',
#   'Team': 'MIA',
#   'Anytime Touchdown Line': '+750'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'christian blake',
#   'Team': 'ATL',
#   'Anytime Touchdown Line': '+1400'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'terrace marshall',
#   'Team': 'CAR',
#   'Receiving Yards Projection': 'O 23.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-125)',
#   'Anytime Touchdown Line': '+650'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'jason moore',
#   'Team': 'LAC',
#   'Anytime Touchdown Line': '+340'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'van jefferson',
#   'Team': 'LAR',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+136)',
#   'Receptions Under': '(-174)',
#   'Anytime Touchdown Line': '+200',
#   'Receiving Yards Projection': 'O 45.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'tyler boyd',
#   'Team': 'CIN',
#   'Receiving Yards Projection': 'O 47.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+210'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'michael gallup',
#   'Team': 'DAL',
#   'Receiving Yards Projection': 'O 43.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-111)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-118)',
#   'Receptions Under': '(-111)',
#   'Anytime Touchdown Line': '+180'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'allen lazard',
#   'Team': 'GB',
#   'Anytime Touchdown Line': '+220',
#   'Receiving Yards Projection': 'O 34.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-160)',
#   'Receptions Under': '(+130)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'cole beasley',
#   'Team': 'BUF',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+115)',
#   'Receptions Under': '(-149)',
#   'Receiving Yards Projection': 'O 40.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-118)',
#   'Anytime Touchdown Line': '+170'},
#  {'Year': 2021, 'Week': 17, 'Player Name': 'joshua palmer', 'Team': 'LAC'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'laviska shenault',
#   'Team': 'JAX',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-160)',
#   'Receptions Under': '(+120)',
#   'Receiving Yards Projection': 'O 34.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+380'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'mecole hardman',
#   'Team': 'KC',
#   'Anytime Touchdown Line': '+390'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'antoine wesley',
#   'Team': 'ARI',
#   'Anytime Touchdown Line': '+350'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'breshad perriman',
#   'Team': 'TB',
#   'Anytime Touchdown Line': '+240'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'desean jackson',
#   'Team': 'LV',
#   'Anytime Touchdown Line': '+500'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'chris conley',
#   'Team': 'HOU',
#   'Anytime Touchdown Line': '+450'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'jalen reagor',
#   'Team': 'PHI',
#   'Anytime Touchdown Line': '+410',
#   'Receiving Yards Projection': 'O 17.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'james washington',
#   'Team': 'PIT',
#   'Receiving Yards Projection': 'O 10.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-120)',
#   'Anytime Touchdown Line': '+450'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'deandre carter',
#   'Team': 'WAS',
#   'Anytime Touchdown Line': '+400'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'zach pascal',
#   'Team': 'IND',
#   'Receiving Yards Projection': 'O 21.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+300'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'jauan jennings',
#   'Team': 'SF',
#   'Anytime Touchdown Line': '+500'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'chester rogers',
#   'Team': 'TEN',
#   'Anytime Touchdown Line': '+400'},
#  {'Year': 2021, 'Week': 17, 'Player Name': 'dee eskridge', 'Team': 'SEA'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'damiere byrd',
#   'Team': 'CHI',
#   'Anytime Touchdown Line': '+500'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'deonte harty',
#   'Team': 'NO',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(+110)',
#   'Receptions Under': '(-145)',
#   'Receiving Yards Projection': 'O 25.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-118)',
#   'Anytime Touchdown Line': '+310'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'sammy watkins',
#   'Team': 'BAL',
#   'Anytime Touchdown Line': '+450'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'diontae spencer',
#   'Team': 'DEN',
#   'Anytime Touchdown Line': '+550'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'shi smith',
#   'Team': 'CAR',
#   'Anytime Touchdown Line': '+950'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'tom kennedy',
#   'Team': 'DET',
#   'Anytime Touchdown Line': '+1000'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'dede westbrook',
#   'Team': 'MIN',
#   'Anytime Touchdown Line': '+600'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'christian blake',
#   'Team': 'ATL',
#   'Anytime Touchdown Line': '+950'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'david sills',
#   'Team': 'NYG',
#   'Anytime Touchdown Line': '+550'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'anthony schwartz',
#   'Team': 'CLE',
#   'Anytime Touchdown Line': '+650'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'jeff smith',
#   'Team': 'NYJ',
#   'Anytime Touchdown Line': '+1200'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'isaiah ford',
#   'Team': 'MIA',
#   'Anytime Touchdown Line': '+900'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'gunner olszewski',
#   'Team': 'NE',
#   'Anytime Touchdown Line': '+1300'},
#  {'Year': 2022,
#   'Week': 1,
#   'Player Name': 'tyler boyd',
#   'Team': 'CIN',
#   'Receiving Yards Projection': 'O 40.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+150',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-136)',
#   'Receptions Under': '(-155)'},
#  {'Year': 2022,
#   'Week': 1,
#   'Player Name': 'george pickens',
#   'Team': 'PIT',
#   'Receiving Yards Projection': 'O 43.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+220',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-128)',
#   'Receptions Under': '(EVEN)'},
#  {'Year': 2022,
#   'Week': 1,
#   'Player Name': 'russell gage',
#   'Team': 'TB',
#   'Receiving Yards Projection': 'O 34.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+200'},
#  {'Year': 2022,
#   'Week': 1,
#   'Player Name': 'jarvis landry',
#   'Team': 'NO',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-102)',
#   'Receptions Under': '(-125)',
#   'Anytime Touchdown Line': '+200',
#   'Receiving Yards Projection': 'O 39.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2022,
#   'Week': 1,
#   'Player Name': 'isaiah mckenzie',
#   'Team': 'BUF',
#   'Anytime Touchdown Line': '+310',
#   'Receiving Yards Projection': 'O 29.5',
#   'Receiving Yards Over': '(-118)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-155)',
#   'Receptions Under': '(-158)'},
#  {'Year': 2022,
#   'Week': 1,
#   'Player Name': 'mecole hardman',
#   'Team': 'KC',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-160)',
#   'Receptions Under': '(+102)',
#   'Receiving Yards Projection': 'O 37.5',
#   'Receiving Yards Over': '(-114)',
#   'Receiving Yards Under': '(-114)',
#   'Anytime Touchdown Line': '+190'},
#  {'Year': 2022,
#   'Week': 1,
#   'Player Name': 'garrett wilson',
#   'Team': 'NYJ',
#   'Anytime Touchdown Line': '+290',
#   'Receiving Yards Projection': 'O 19.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2022, 'Week': 1, 'Player Name': 'joshua palmer', 'Team': 'LAC'},
#  {'Year': 2022,
#   'Week': 1,
#   'Player Name': 'kj osborn',
#   'Team': 'MIN',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-175)',
#   'Receptions Under': '(-188)',
#   'Receiving Yards Projection': 'O 37.5',
#   'Receiving Yards Over': '(-114)',
#   'Receiving Yards Under': '(-114)',
#   'Anytime Touchdown Line': '+220'},
#  {'Year': 2022,
#   'Week': 1,
#   'Player Name': 'curtis samuel',
#   'Team': 'WAS',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-106)',
#   'Receptions Under': '(-120)',
#   'Receiving Yards Projection': 'O 25.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-105)',
#   'Anytime Touchdown Line': '+320'},
#  ...]

# %%
import pandas as pd

df = pd.json_normalize(d)

df
# Out:
#       Year  Week       Player Name Team Receiving Yards Projection  \
# 0     2020     1       ceedee lamb  DAL                     O 50.5
# 1     2020     1     sammy watkins   KC                     O 42.5
# 2     2020     1     curtis samuel  CAR                     O 36.5
# 3     2020     1      randall cobb  HOU                     O 35.5
# 4     2020     1  larry fitzgerald  ARI                        NaN
# ...    ...   ...               ...  ...                        ...
# 2008  2023    17        david bell  CLE                     O 13.5
# 2009  2023    17    equanimeous st  CHI                        NaN
# 2010  2023    17       julio jones  PHI                      O 8.5
# 2011  2023    17    khadarel hodge  ATL                      O 8.5
# 2012  2023    17       ronnie bell   SF                        NaN
#
#      Receiving Yards Over Receiving Yards Under Receptions Projection  \
# 0                  (-110)                (-110)                 O 3.5
# 1                  (-110)                (-110)                 O 3.5
# 2                  (-110)                (-110)                 O 3.5
# 3                  (-110)                (-110)                 O 2.5
# 4                     NaN                   NaN                   NaN
# ...                   ...                   ...                   ...
# 2008               (-110)                (-120)                 O 1.5
# 2009                  NaN                   NaN                   NaN
# 2010               (-110)                (-110)                 O 1.5
# 2011               (-110)                (-110)                 O 0.5
# 2012                  NaN                   NaN                   NaN
#
#      Receptions Over Receptions Under Anytime Touchdown Line  \
# 0             (+125)           (-145)                   +260
# 1             (+108)           (-136)                   +240
# 2             (+125)           (-145)                   +275
# 3             (-172)           (+134)                   +350
# 4                NaN              NaN                    NaN
# ...              ...              ...                    ...
# 2008          (-113)           (-113)                   +600
# 2009             NaN              NaN                    NaN
# 2010          (+165)           (-224)                   +900
# 2011          (-210)           (+152)                  +1100
# 2012             NaN              NaN                   +900
#
#      Rushing Yards Projection Rushing Yards Over Rushing Yards Under
# 0                         NaN                NaN                 NaN
# 1                         NaN                NaN                 NaN
# 2                         NaN                NaN                 NaN
# 3                         NaN                NaN                 NaN
# 4                         NaN                NaN                 NaN
# ...                       ...                ...                 ...
# 2008                      NaN                NaN                 NaN
# 2009                      NaN                NaN                 NaN
# 2010                      NaN                NaN                 NaN
# 2011                      NaN                NaN                 NaN
# 2012                      NaN                NaN                 NaN
#
# [2013 rows x 14 columns]

# %%
for column in ('Rushing Yards Projection', 'Receiving Yards Projection', 'Receptions Projection'):
    df[column] = df[column].str.extract(r'(\d+\.\d+)').astype(float)

df
# Out:
#       Year  Week       Player Name Team  Receiving Yards Projection  \
# 0     2020     1       ceedee lamb  DAL                        50.5
# 1     2020     1     sammy watkins   KC                        42.5
# 2     2020     1     curtis samuel  CAR                        36.5
# 3     2020     1      randall cobb  HOU                        35.5
# 4     2020     1  larry fitzgerald  ARI                         NaN
# ...    ...   ...               ...  ...                         ...
# 2008  2023    17        david bell  CLE                        13.5
# 2009  2023    17    equanimeous st  CHI                         NaN
# 2010  2023    17       julio jones  PHI                         8.5
# 2011  2023    17    khadarel hodge  ATL                         8.5
# 2012  2023    17       ronnie bell   SF                         NaN
#
#      Receiving Yards Over Receiving Yards Under  Receptions Projection  \
# 0                  (-110)                (-110)                    3.5
# 1                  (-110)                (-110)                    3.5
# 2                  (-110)                (-110)                    3.5
# 3                  (-110)                (-110)                    2.5
# 4                     NaN                   NaN                    NaN
# ...                   ...                   ...                    ...
# 2008               (-110)                (-120)                    1.5
# 2009                  NaN                   NaN                    NaN
# 2010               (-110)                (-110)                    1.5
# 2011               (-110)                (-110)                    0.5
# 2012                  NaN                   NaN                    NaN
#
#      Receptions Over Receptions Under Anytime Touchdown Line  \
# 0             (+125)           (-145)                   +260
# 1             (+108)           (-136)                   +240
# 2             (+125)           (-145)                   +275
# 3             (-172)           (+134)                   +350
# 4                NaN              NaN                    NaN
# ...              ...              ...                    ...
# 2008          (-113)           (-113)                   +600
# 2009             NaN              NaN                    NaN
# 2010          (+165)           (-224)                   +900
# 2011          (-210)           (+152)                  +1100
# 2012             NaN              NaN                   +900
#
#       Rushing Yards Projection Rushing Yards Over Rushing Yards Under
# 0                          NaN                NaN                 NaN
# 1                          NaN                NaN                 NaN
# 2                          NaN                NaN                 NaN
# 3                          NaN                NaN                 NaN
# 4                          NaN                NaN                 NaN
# ...                        ...                ...                 ...
# 2008                       NaN                NaN                 NaN
# 2009                       NaN                NaN                 NaN
# 2010                       NaN                NaN                 NaN
# 2011                       NaN                NaN                 NaN
# 2012                       NaN                NaN                 NaN
#
# [2013 rows x 14 columns]

# %%
for column in ('Rushing Yards Over', 'Rushing Yards Under', 'Receiving Yards Over', 'Receiving Yards Under', 'Receptions Over', 'Receptions Under'):
    df.loc[df[column].str.contains('EVEN', regex=False, na=False), column] = '100'
    df.loc[df[column] == '--', column] = 'nan'
    df[column] = df[column].str.replace(r'\(|\)', '', regex=True).astype(float)

df
# Out:
#       Year  Week       Player Name Team  Receiving Yards Projection  \
# 0     2020     1       ceedee lamb  DAL                        50.5
# 1     2020     1     sammy watkins   KC                        42.5
# 2     2020     1     curtis samuel  CAR                        36.5
# 3     2020     1      randall cobb  HOU                        35.5
# 4     2020     1  larry fitzgerald  ARI                         NaN
# ...    ...   ...               ...  ...                         ...
# 2008  2023    17        david bell  CLE                        13.5
# 2009  2023    17    equanimeous st  CHI                         NaN
# 2010  2023    17       julio jones  PHI                         8.5
# 2011  2023    17    khadarel hodge  ATL                         8.5
# 2012  2023    17       ronnie bell   SF                         NaN
#
#       Receiving Yards Over  Receiving Yards Under  Receptions Projection  \
# 0                   -110.0                 -110.0                    3.5
# 1                   -110.0                 -110.0                    3.5
# 2                   -110.0                 -110.0                    3.5
# 3                   -110.0                 -110.0                    2.5
# 4                      NaN                    NaN                    NaN
# ...                    ...                    ...                    ...
# 2008                -110.0                 -120.0                    1.5
# 2009                   NaN                    NaN                    NaN
# 2010                -110.0                 -110.0                    1.5
# 2011                -110.0                 -110.0                    0.5
# 2012                   NaN                    NaN                    NaN
#
#       Receptions Over  Receptions Under Anytime Touchdown Line  \
# 0               125.0            -145.0                   +260
# 1               108.0            -136.0                   +240
# 2               125.0            -145.0                   +275
# 3              -172.0             134.0                   +350
# 4                 NaN               NaN                    NaN
# ...               ...               ...                    ...
# 2008           -113.0            -113.0                   +600
# 2009              NaN               NaN                    NaN
# 2010            165.0            -224.0                   +900
# 2011           -210.0             152.0                  +1100
# 2012              NaN               NaN                   +900
#
#       Rushing Yards Projection  Rushing Yards Over  Rushing Yards Under
# 0                          NaN                 NaN                  NaN
# 1                          NaN                 NaN                  NaN
# 2                          NaN                 NaN                  NaN
# 3                          NaN                 NaN                  NaN
# 4                          NaN                 NaN                  NaN
# ...                        ...                 ...                  ...
# 2008                       NaN                 NaN                  NaN
# 2009                       NaN                 NaN                  NaN
# 2010                       NaN                 NaN                  NaN
# 2011                       NaN                 NaN                  NaN
# 2012                       NaN                 NaN                  NaN
#
# [2013 rows x 14 columns]

# %%
for column in ('Anytime Touchdown Line', ):
    df.loc[df[column].str.contains('EVEN', regex=False, na=False), column] = '100'
    df.loc[df[column] == '--', column] = 'nan'
    df[column] = df[column].astype(float)

df
# Out:
#       Year  Week       Player Name Team  Receiving Yards Projection  \
# 0     2020     1       ceedee lamb  DAL                        50.5
# 1     2020     1     sammy watkins   KC                        42.5
# 2     2020     1     curtis samuel  CAR                        36.5
# 3     2020     1      randall cobb  HOU                        35.5
# 4     2020     1  larry fitzgerald  ARI                         NaN
# ...    ...   ...               ...  ...                         ...
# 2008  2023    17        david bell  CLE                        13.5
# 2009  2023    17    equanimeous st  CHI                         NaN
# 2010  2023    17       julio jones  PHI                         8.5
# 2011  2023    17    khadarel hodge  ATL                         8.5
# 2012  2023    17       ronnie bell   SF                         NaN
#
#       Receiving Yards Over  Receiving Yards Under  Receptions Projection  \
# 0                   -110.0                 -110.0                    3.5
# 1                   -110.0                 -110.0                    3.5
# 2                   -110.0                 -110.0                    3.5
# 3                   -110.0                 -110.0                    2.5
# 4                      NaN                    NaN                    NaN
# ...                    ...                    ...                    ...
# 2008                -110.0                 -120.0                    1.5
# 2009                   NaN                    NaN                    NaN
# 2010                -110.0                 -110.0                    1.5
# 2011                -110.0                 -110.0                    0.5
# 2012                   NaN                    NaN                    NaN
#
#       Receptions Over  Receptions Under  Anytime Touchdown Line  \
# 0               125.0            -145.0                   260.0
# 1               108.0            -136.0                   240.0
# 2               125.0            -145.0                   275.0
# 3              -172.0             134.0                   350.0
# 4                 NaN               NaN                     NaN
# ...               ...               ...                     ...
# 2008           -113.0            -113.0                   600.0
# 2009              NaN               NaN                     NaN
# 2010            165.0            -224.0                   900.0
# 2011           -210.0             152.0                  1100.0
# 2012              NaN               NaN                   900.0
#
#       Rushing Yards Projection  Rushing Yards Over  Rushing Yards Under
# 0                          NaN                 NaN                  NaN
# 1                          NaN                 NaN                  NaN
# 2                          NaN                 NaN                  NaN
# 3                          NaN                 NaN                  NaN
# 4                          NaN                 NaN                  NaN
# ...                        ...                 ...                  ...
# 2008                       NaN                 NaN                  NaN
# 2009                       NaN                 NaN                  NaN
# 2010                       NaN                 NaN                  NaN
# 2011                       NaN                 NaN                  NaN
# 2012                       NaN                 NaN                  NaN
#
# [2013 rows x 14 columns]

# %%
def american_odds_to_probability(odds):
    """
    Converts American betting odds to implied probability.
    
    Args:
        odds (int or float): The American odds value (e.g., -150, +200).

    Returns:
        float: The implied probability as a decimal (e.g., 0.60 for 60%).
    """
    if odds > 0:
        # Positive odds: (100 / (odds + 100))
        probability = 100 / (odds + 100)
    else:
        # Negative odds: (-odds / (-odds + 100))
        probability = -odds / (-odds + 100)
    
    return probability

# %% [markdown]
# Adjust projections based on over/under lines

# %%
for stat in ('Rushing Yards', 'Receiving Yards', 'Receptions'):
    df[f'Adjusted {stat} Projection'] = (
        df[f'{stat} Projection'] +
        0.5 * df[f'{stat} Over'].apply(american_odds_to_probability) -
        0.5 * df[f'{stat} Under'].apply(american_odds_to_probability)
    )

df
# Out:
#       Year  Week       Player Name Team  Receiving Yards Projection  \
# 0     2020     1       ceedee lamb  DAL                        50.5
# 1     2020     1     sammy watkins   KC                        42.5
# 2     2020     1     curtis samuel  CAR                        36.5
# 3     2020     1      randall cobb  HOU                        35.5
# 4     2020     1  larry fitzgerald  ARI                         NaN
# ...    ...   ...               ...  ...                         ...
# 2008  2023    17        david bell  CLE                        13.5
# 2009  2023    17    equanimeous st  CHI                         NaN
# 2010  2023    17       julio jones  PHI                         8.5
# 2011  2023    17    khadarel hodge  ATL                         8.5
# 2012  2023    17       ronnie bell   SF                         NaN
#
#       Receiving Yards Over  Receiving Yards Under  Receptions Projection  \
# 0                   -110.0                 -110.0                    3.5
# 1                   -110.0                 -110.0                    3.5
# 2                   -110.0                 -110.0                    3.5
# 3                   -110.0                 -110.0                    2.5
# 4                      NaN                    NaN                    NaN
# ...                    ...                    ...                    ...
# 2008                -110.0                 -120.0                    1.5
# 2009                   NaN                    NaN                    NaN
# 2010                -110.0                 -110.0                    1.5
# 2011                -110.0                 -110.0                    0.5
# 2012                   NaN                    NaN                    NaN
#
#       Receptions Over  Receptions Under  Anytime Touchdown Line  \
# 0               125.0            -145.0                   260.0
# 1               108.0            -136.0                   240.0
# 2               125.0            -145.0                   275.0
# 3              -172.0             134.0                   350.0
# 4                 NaN               NaN                     NaN
# ...               ...               ...                     ...
# 2008           -113.0            -113.0                   600.0
# 2009              NaN               NaN                     NaN
# 2010            165.0            -224.0                   900.0
# 2011           -210.0             152.0                  1100.0
# 2012              NaN               NaN                   900.0
#
#       Rushing Yards Projection  Rushing Yards Over  Rushing Yards Under  \
# 0                          NaN                 NaN                  NaN
# 1                          NaN                 NaN                  NaN
# 2                          NaN                 NaN                  NaN
# 3                          NaN                 NaN                  NaN
# 4                          NaN                 NaN                  NaN
# ...                        ...                 ...                  ...
# 2008                       NaN                 NaN                  NaN
# 2009                       NaN                 NaN                  NaN
# 2010                       NaN                 NaN                  NaN
# 2011                       NaN                 NaN                  NaN
# 2012                       NaN                 NaN                  NaN
#
#       Adjusted Rushing Yards Projection  Adjusted Receiving Yards Projection  \
# 0                                   NaN                            50.500000
# 1                                   NaN                            42.500000
# 2                                   NaN                            36.500000
# 3                                   NaN                            35.500000
# 4                                   NaN                                  NaN
# ...                                 ...                                  ...
# 2008                                NaN                            13.489177
# 2009                                NaN                                  NaN
# 2010                                NaN                             8.500000
# 2011                                NaN                             8.500000
# 2012                                NaN                                  NaN
#
#       Adjusted Receptions Projection
# 0                           3.426304
# 1                           3.452249
# 2                           3.426304
# 3                           2.602501
# 4                                NaN
# ...                              ...
# 2008                        1.500000
# 2009                             NaN
# 2010                        1.343000
# 2011                        0.640297
# 2012                             NaN
#
# [2013 rows x 17 columns]

# %%
df['Anytime Touchdown Probability'] = df['Anytime Touchdown Line'].apply(american_odds_to_probability)

df
# Out:
#       Year  Week       Player Name Team  Receiving Yards Projection  \
# 0     2020     1       ceedee lamb  DAL                        50.5
# 1     2020     1     sammy watkins   KC                        42.5
# 2     2020     1     curtis samuel  CAR                        36.5
# 3     2020     1      randall cobb  HOU                        35.5
# 4     2020     1  larry fitzgerald  ARI                         NaN
# ...    ...   ...               ...  ...                         ...
# 2008  2023    17        david bell  CLE                        13.5
# 2009  2023    17    equanimeous st  CHI                         NaN
# 2010  2023    17       julio jones  PHI                         8.5
# 2011  2023    17    khadarel hodge  ATL                         8.5
# 2012  2023    17       ronnie bell   SF                         NaN
#
#       Receiving Yards Over  Receiving Yards Under  Receptions Projection  \
# 0                   -110.0                 -110.0                    3.5
# 1                   -110.0                 -110.0                    3.5
# 2                   -110.0                 -110.0                    3.5
# 3                   -110.0                 -110.0                    2.5
# 4                      NaN                    NaN                    NaN
# ...                    ...                    ...                    ...
# 2008                -110.0                 -120.0                    1.5
# 2009                   NaN                    NaN                    NaN
# 2010                -110.0                 -110.0                    1.5
# 2011                -110.0                 -110.0                    0.5
# 2012                   NaN                    NaN                    NaN
#
#       Receptions Over  Receptions Under  Anytime Touchdown Line  \
# 0               125.0            -145.0                   260.0
# 1               108.0            -136.0                   240.0
# 2               125.0            -145.0                   275.0
# 3              -172.0             134.0                   350.0
# 4                 NaN               NaN                     NaN
# ...               ...               ...                     ...
# 2008           -113.0            -113.0                   600.0
# 2009              NaN               NaN                     NaN
# 2010            165.0            -224.0                   900.0
# 2011           -210.0             152.0                  1100.0
# 2012              NaN               NaN                   900.0
#
#       Rushing Yards Projection  Rushing Yards Over  Rushing Yards Under  \
# 0                          NaN                 NaN                  NaN
# 1                          NaN                 NaN                  NaN
# 2                          NaN                 NaN                  NaN
# 3                          NaN                 NaN                  NaN
# 4                          NaN                 NaN                  NaN
# ...                        ...                 ...                  ...
# 2008                       NaN                 NaN                  NaN
# 2009                       NaN                 NaN                  NaN
# 2010                       NaN                 NaN                  NaN
# 2011                       NaN                 NaN                  NaN
# 2012                       NaN                 NaN                  NaN
#
#       Adjusted Rushing Yards Projection  Adjusted Receiving Yards Projection  \
# 0                                   NaN                            50.500000
# 1                                   NaN                            42.500000
# 2                                   NaN                            36.500000
# 3                                   NaN                            35.500000
# 4                                   NaN                                  NaN
# ...                                 ...                                  ...
# 2008                                NaN                            13.489177
# 2009                                NaN                                  NaN
# 2010                                NaN                             8.500000
# 2011                                NaN                             8.500000
# 2012                                NaN                                  NaN
#
#       Adjusted Receptions Projection  Anytime Touchdown Probability
# 0                           3.426304                       0.277778
# 1                           3.452249                       0.294118
# 2                           3.426304                       0.266667
# 3                           2.602501                       0.222222
# 4                                NaN                            NaN
# ...                              ...                            ...
# 2008                        1.500000                       0.142857
# 2009                             NaN                            NaN
# 2010                        1.343000                       0.100000
# 2011                        0.640297                       0.083333
# 2012                             NaN                       0.100000
#
# [2013 rows x 18 columns]

# %%
df.to_parquet(r'..\..\data\betting_lines\wr3_props.parquet')

print('Done')
# Out:
# Done
