# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

options = Options()
# options.add_argument('--headless')

driver = webdriver.Chrome(options=options)

# %%
import time
from selenium.webdriver.common.by import By

TEAMS = {
    'Arizona',
    'Atlanta',
    'Baltimore',
    'Buffalo',
    'Carolina',
    'Chicago',
    'Cincinnati',
    'Cleveland',
    'Dallas',
    'Denver',
    'Detroit',
    'Green Bay',
    'Houston',
    'Indianapolis',
    'Jacksonville',
    'Kansas City',
    'Las Vegas',
    'Los Angeles',
    'Miami',
    'Minnesota',
    'New England',
    'New Orleans',
    'New York',
    'Philadelphia',
    'Pittsburgh',
    'San Francisco',
    'Seattle',
    'Tampa Bay',
    'Tennessee',
    'Washington',
}

problematic_rows = []
def scrape_totals(year, week):
    driver.get(url=f"https://www.bettingpros.com/nfl/odds/total/?season={year}&week={week}")
    time.sleep(10)

    # the page uses lazy loading
    # this loop helps all relevant elements load before scraping
    for _ in range(5):
        # find all loaded rows
        rows = driver.find_elements(
            by=By.CLASS_NAME,
            value="grouped-items-with-sticky-footer__content",
        )

        # scroll to the last loaded row, which should load subsequent rows if there are any
        if len(rows) > 0:
            driver.execute_script(f"window.scrollTo(0, {rows[-1].location['y']});")

        time.sleep(6)

    rows = driver.find_elements(
        by=By.CLASS_NAME,
        value="grouped-items-with-sticky-footer__content",
    )

    if len(rows) == 0:
        print(f"Warning: No rows for {year} week {week}")
        problematic_rows.append({'year': year, 'week': week})
    
    data = []
    for row in rows:
        t = row.text.split('\n')
        home_team = t[3]
        if home_team not in TEAMS:
            home_team = t[2]
        data.append((
            year,
            week,
            t[0],  # away team
            home_team,  # home team
            t[-4],  # over line
            t[-3],  # over odds
            t[-2],  # under line
            t[-1],  # under odds
        ))

    return data

# %%
from itertools import product
from tqdm.autonotebook import tqdm

d = []
for year, week in tqdm(list(product([year for year in range(2018, 2024)], [week for week in range(1, 18)]))):
    if ((week != 17) or (year >= 2021)) and ((year != 2018) or (week > 4)):
        d.append(scrape_totals(year, week))
# Out:
# C:\Users\mhugh\AppData\Local\Temp\ipykernel_17884\2242548319.py:2: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm
#   0%|          | 0/102 [00:00<?, ?it/s]

# %%
problematic_rows
# Out:
# []

# %%
for params in tqdm(problematic_rows):
    d.append(scrape_totals(**params))
# Out:
# 0it [00:00, ?it/s]

# %%
driver.quit()

# %%
d
# Out:
# [[(2018,
#    5,
#    'Indianapolis',
#    'New England',
#    'O 49.5',
#    '(-110)',
#    'U 49.5',
#    '(-110)'),
#   (2018,
#    5,
#    'Jacksonville',
#    'Kansas City',
#    'O 48.0',
#    '(-110)',
#    'U 48.0',
#    '(-110)'),
#   (2018, 5, 'Baltimore', 'Cleveland', 'O 44.5', '(-110)', 'U 44.5', '(-110)'),
#   (2018, 5, 'Green Bay', 'Detroit', 'O 50.0', '(-110)', 'U 50.0', '(-110)'),
#   (2018, 5, 'Miami', 'Cincinnati', 'O 47.5', '(-110)', 'U 47.5', '(-110)'),
#   (2018, 5, 'Tennessee', 'Buffalo', 'O 39.0', '(-110)', 'U 39.0', '(-110)'),
#   (2018, 5, 'New York', 'Carolina', 'O 43.5', '(-110)', 'U 43.5', '(-110)'),
#   (2018, 5, 'Denver', 'New York', 'O 42.5', '(-105)', 'U 42.5', '(-115)'),
#   (2018, 5, 'Atlanta', 'Pittsburgh', 'O 57.0', '(-110)', 'U 57.0', '(-110)'),
#   (2018,
#    5,
#    'Las Vegas',
#    'Los Angeles',
#    'O 52.0',
#    '(EVEN)',
#    'U 52.0',
#    '(-120)'),
#   (2018,
#    5,
#    'Arizona',
#    'San Francisco',
#    'O 40.5',
#    '(-110)',
#    'U 40.5',
#    '(-110)'),
#   (2018, 5, 'Los Angeles', 'Seattle', 'O 50.5', '(-105)', 'U 50.5', '(-115)'),
#   (2018,
#    5,
#    'Minnesota',
#    'Philadelphia',
#    'O 48.5',
#    '(-110)',
#    'U 48.5',
#    '(-110)'),
#   (2018, 5, 'Dallas', 'Houston', 'O 45.5', '(-110)', 'U 45.5', '(-110)'),
#   (2018,
#    5,
#    'Washington',
#    'New Orleans',
#    'O 51.5',
#    '(-110)',
#    'U 51.5',
#    '(-110)')],
#  [(2018,
#    6,
#    'Philadelphia',
#    'New York',
#    'O 44.5',
#    '(-115)',
#    'U 44.5',
#    '(-105)'),
#   (2018, 6, 'Seattle', 'Las Vegas', 'O 48.5', '(-110)', 'U 48.5', '(-110)'),
#   (2018,
#    6,
#    'Indianapolis',
#    'New York',
#    'O 47.5',
#    '(-110)',
#    'U 47.5',
#    '(-110)'),
#   (2018,
#    6,
#    'Los Angeles',
#    'Cleveland',
#    'O 47.0',
#    '(EVEN)',
#    'U 47.0',
#    '(-120)'),
#   (2018, 6, 'Chicago', 'Miami', 'O 41.0', '(-110)', 'U 41.0', '(-110)'),
#   (2018, 6, 'Tampa Bay', 'Atlanta', 'O 57.0', '(-110)', 'U 57.0', '(-110)'),
#   (2018, 6, 'Arizona', 'Minnesota', 'O 42.5', '(-120)', 'U 42.5', '(EVEN)'),
#   (2018, 6, 'Buffalo', 'Houston', 'O 40.5', '(-110)', 'U 40.5', '(-110)'),
#   (2018,
#    6,
#    'Pittsburgh',
#    'Cincinnati',
#    'O 49.5',
#    '(-105)',
#    'U 49.5',
#    '(-115)'),
#   (2018, 6, 'Carolina', 'Washington', 'O 44.5', '(-110)', 'U 44.5', '(-110)'),
#   (2018, 6, 'Los Angeles', 'Denver', 'O 50.0', '(-110)', 'U 50.0', '(-110)'),
#   (2018, 6, 'Baltimore', 'Tennessee', 'O 43.5', '(-110)', 'U 43.5', '(-110)'),
#   (2018, 6, 'Jacksonville', 'Dallas', 'O 39.0', '(-120)', 'U 39.0', '(EVEN)'),
#   (2018,
#    6,
#    'Kansas City',
#    'New England',
#    'O 59.5',
#    '(-105)',
#    'U 59.5',
#    '(-115)'),
#   (2018,
#    6,
#    'San Francisco',
#    'Green Bay',
#    'O 46.5',
#    '(-110)',
#    'U 46.5',
#    '(-110)')],
#  [(2018, 7, 'Denver', 'Arizona', 'O 42.5', '(-105)', 'U 42.5', '(-115)'),
#   (2018,
#    7,
#    'Tennessee',
#    'Los Angeles',
#    'O 46.0',
#    '(-110)',
#    'U 46.0',
#    '(-110)'),
#   (2018, 7, 'New England', 'Chicago', 'O 48.5', '(-110)', 'U 48.5', '(-110)'),
#   (2018, 7, 'Cleveland', 'Tampa Bay', 'O 52.5', '(-110)', 'U 52.5', '(-110)'),
#   (2018, 7, 'Houston', 'Jacksonville', 'O 42.5', '(-110)', 'U 42.5', '(-110)'),
#   (2018, 7, 'Minnesota', 'New York', 'O 45.5', '(-110)', 'U 45.5', '(-110)'),
#   (2018, 7, 'Buffalo', 'Indianapolis', 'O 43.0', '(-110)', 'U 43.0', '(-110)'),
#   (2018, 7, 'Detroit', 'Miami', 'O 47.0', '(-110)', 'U 47.0', '(-110)'),
#   (2018,
#    7,
#    'Carolina',
#    'Philadelphia',
#    'O 45.0',
#    '(-110)',
#    'U 45.0',
#    '(-110)'),
#   (2018,
#    7,
#    'New Orleans',
#    'Baltimore',
#    'O 49.0',
#    '(-110)',
#    'U 49.0',
#    '(-110)'),
#   (2018, 7, 'Dallas', 'Washington', 'O 40.5', '(-110)', 'U 40.5', '(-110)'),
#   (2018,
#    7,
#    'Los Angeles',
#    'San Francisco',
#    'O 52.0',
#    '(-110)',
#    'U 52.0',
#    '(-110)'),
#   (2018,
#    7,
#    'Cincinnati',
#    'Kansas City',
#    'O 56.0',
#    '(-110)',
#    'U 56.0',
#    '(-110)'),
#   (2018, 7, 'New York', 'Atlanta', 'O 52.0', '(-110)', 'U 52.0', '(-110)')],
#  [(2018, 8, 'Miami', 'Houston', 'O 45.0', '(-115)', 'U 45.0', '(-105)'),
#   (2018,
#    8,
#    'Philadelphia',
#    'Jacksonville',
#    'O 44.5',
#    '(-110)',
#    'U 44.5',
#    '(-110)'),
#   (2018, 8, 'Denver', 'Kansas City', 'O 52.0', '(-120)', 'U 52.0', '(EVEN)'),
#   (2018, 8, 'Cleveland', 'Pittsburgh', 'O 48.0', '(-110)', 'U 48.0', '(-110)'),
#   (2018, 8, 'Tampa Bay', 'Cincinnati', 'O 54.5', '(-120)', 'U 54.5', '(EVEN)'),
#   (2018, 8, 'Baltimore', 'Carolina', 'O 44.5', '(-110)', 'U 44.5', '(-110)'),
#   (2018, 8, 'Washington', 'New York', 'O 44.0', '(-110)', 'U 44.0', '(-110)'),
#   (2018, 8, 'New York', 'Chicago', 'O 41.5', '(-110)', 'U 41.5', '(-110)'),
#   (2018, 8, 'Seattle', 'Detroit', 'O 48.5', '(-110)', 'U 48.5', '(-110)'),
#   (2018,
#    8,
#    'Indianapolis',
#    'Las Vegas',
#    'O 51.0',
#    '(-110)',
#    'U 51.0',
#    '(-110)'),
#   (2018,
#    8,
#    'Green Bay',
#    'Los Angeles',
#    'O 57.0',
#    '(-105)',
#    'U 57.0',
#    '(-115)'),
#   (2018,
#    8,
#    'San Francisco',
#    'Arizona',
#    'O 41.0',
#    '(+105)',
#    'U 41.0',
#    '(-125)'),
#   (2018,
#    8,
#    'New Orleans',
#    'Minnesota',
#    'O 53.5',
#    '(-110)',
#    'U 53.5',
#    '(-110)'),
#   (2018, 8, 'New England', 'Buffalo', 'O 44.0', '(-105)', 'U 44.0', '(-115)')],
#  [(2018,
#    9,
#    'Las Vegas',
#    'San Francisco',
#    'O 43.5',
#    '(-110)',
#    'U 43.5',
#    '(-110)'),
#   (2018, 9, 'Chicago', 'Buffalo', 'O 38.5', '(EVEN)', 'U 38.5', '(-120)'),
#   (2018,
#    9,
#    'Kansas City',
#    'Cleveland',
#    'O 51.5',
#    '(EVEN)',
#    'U 51.5',
#    '(-120)'),
#   (2018, 9, 'Tampa Bay', 'Carolina', 'O 55.0', '(-110)', 'U 55.0', '(-110)'),
#   (2018, 9, 'New York', 'Miami', 'O 42.5', '(-110)', 'U 42.5', '(-110)'),
#   (2018, 9, 'Atlanta', 'Washington', 'O 47.0', '(EVEN)', 'U 47.0', '(-120)'),
#   (2018, 9, 'Pittsburgh', 'Baltimore', 'O 46.0', '(-110)', 'U 46.0', '(-110)'),
#   (2018, 9, 'Detroit', 'Minnesota', 'O 47.5', '(-110)', 'U 47.5', '(-110)'),
#   (2018, 9, 'Los Angeles', 'Seattle', 'O 48.0', '(-110)', 'U 48.0', '(-110)'),
#   (2018, 9, 'Houston', 'Denver', 'O 46.5', '(-110)', 'U 46.5', '(-110)'),
#   (2018,
#    9,
#    'Los Angeles',
#    'New Orleans',
#    'O 56.5',
#    '(-120)',
#    'U 56.5',
#    '(EVEN)'),
#   (2018,
#    9,
#    'Green Bay',
#    'New England',
#    'O 56.0',
#    '(EVEN)',
#    'U 56.0',
#    '(-120)'),
#   (2018, 9, 'Tennessee', 'Dallas', 'O 40.0', '(-110)', 'U 40.0', '(-110)')],
#  [(2018, 10, 'Carolina', 'Pittsburgh', 'O 51.0', '(-110)', 'U 51.0', '(-110)'),
#   (2018, 10, 'Buffalo', 'New York', 'O 38.0', '(-110)', 'U 38.0', '(-110)'),
#   (2018,
#    10,
#    'New England',
#    'Tennessee',
#    'O 47.0',
#    '(EVEN)',
#    'U 47.0',
#    '(-120)'),
#   (2018,
#    10,
#    'New Orleans',
#    'Cincinnati',
#    'O 53.5',
#    '(-110)',
#    'U 53.5',
#    '(-110)'),
#   (2018, 10, 'Arizona', 'Kansas City', 'O 49.5', '(-110)', 'U 49.5', '(-110)'),
#   (2018,
#    10,
#    'Washington',
#    'Tampa Bay',
#    'O 51.0',
#    '(EVEN)',
#    'U 51.0',
#    '(-120)'),
#   (2018, 10, 'Detroit', 'Chicago', 'O 44.5', '(-120)', 'U 44.5', '(EVEN)'),
#   (2018, 10, 'Atlanta', 'Cleveland', 'O 50.5', '(-110)', 'U 50.5', '(-110)'),
#   (2018,
#    10,
#    'Jacksonville',
#    'Indianapolis',
#    'O 48.0',
#    '(-110)',
#    'U 48.0',
#    '(-110)'),
#   (2018,
#    10,
#    'Los Angeles',
#    'Las Vegas',
#    'O 50.0',
#    '(-120)',
#    'U 50.0',
#    '(EVEN)'),
#   (2018, 10, 'Miami', 'Green Bay', 'O 48.5', '(-110)', 'U 48.5', '(-110)'),
#   (2018, 10, 'Seattle', 'Los Angeles', 'O 51.0', '(-105)', 'U 51.0', '(-115)'),
#   (2018, 10, 'Dallas', 'Philadelphia', 'O 45.0', '(-110)', 'U 45.0', '(-110)'),
#   (2018,
#    10,
#    'New York',
#    'San Francisco',
#    'O 45.0',
#    '(-115)',
#    'U 45.0',
#    '(-105)')],
#  [(2018, 11, 'Green Bay', 'Seattle', 'O 49.0', '(-110)', 'U 49.0', '(-110)'),
#   (2018, 11, 'Houston', 'Washington', 'O 41.5', '(-105)', 'U 41.5', '(-115)'),
#   (2018,
#    11,
#    'Cincinnati',
#    'Baltimore',
#    'O 44.0',
#    '(-105)',
#    'U 44.0',
#    '(-115)'),
#   (2018,
#    11,
#    'Tennessee',
#    'Indianapolis',
#    'O 50.5',
#    '(-110)',
#    'U 50.5',
#    '(-110)'),
#   (2018,
#    11,
#    'Pittsburgh',
#    'Jacksonville',
#    'O 47.0',
#    '(-110)',
#    'U 47.0',
#    '(-110)'),
#   (2018, 11, 'Carolina', 'Detroit', 'O 49.0', '(-110)', 'U 49.0', '(-110)'),
#   (2018, 11, 'Dallas', 'Atlanta', 'O 49.0', '(-110)', 'U 49.0', '(-110)'),
#   (2018, 11, 'Tampa Bay', 'New York', 'O 53.5', '(-110)', 'U 53.5', '(-110)'),
#   (2018, 11, 'Las Vegas', 'Arizona', 'O 41.0', '(-110)', 'U 41.0', '(-110)'),
#   (2018, 11, 'Denver', 'Los Angeles', 'O 47.0', '(-110)', 'U 47.0', '(-110)'),
#   (2018,
#    11,
#    'Philadelphia',
#    'New Orleans',
#    'O 56.0',
#    '(-115)',
#    'U 56.0',
#    '(-105)'),
#   (2018, 11, 'Minnesota', 'Chicago', 'O 44.0', '(-105)', 'U 44.0', '(-115)'),
#   (2018,
#    11,
#    'Kansas City',
#    'Los Angeles',
#    'O 63.5',
#    '(-115)',
#    'U 63.5',
#    '(-105)')],
#  [(2018, 12, 'Chicago', 'Detroit', 'O 43.0', '(EVEN)', 'U 43.0', '(-120)'),
#   (2018, 12, 'Washington', 'Dallas', 'O 40.0', '(-110)', 'U 40.0', '(-110)'),
#   (2018, 12, 'Atlanta', 'New Orleans', 'O 60.5', '(-110)', 'U 60.5', '(-110)'),
#   (2018, 12, 'Las Vegas', 'Baltimore', 'O 42.0', '(EVEN)', 'U 42.0', '(-120)'),
#   (2018,
#    12,
#    'New England',
#    'New York',
#    'O 46.5',
#    '(-110)',
#    'U 46.5',
#    '(-110)'),
#   (2018,
#    12,
#    'New York',
#    'Philadelphia',
#    'O 49.0',
#    '(-110)',
#    'U 49.0',
#    '(-110)'),
#   (2018,
#    12,
#    'San Francisco',
#    'Tampa Bay',
#    'O 54.5',
#    '(-110)',
#    'U 54.5',
#    '(-110)'),
#   (2018,
#    12,
#    'Cleveland',
#    'Cincinnati',
#    'O 46.0',
#    '(-120)',
#    'U 46.0',
#    '(EVEN)'),
#   (2018, 12, 'Seattle', 'Carolina', 'O 46.0', '(-110)', 'U 46.0', '(-110)'),
#   (2018,
#    12,
#    'Jacksonville',
#    'Buffalo',
#    'O 36.5',
#    '(-110)',
#    'U 36.5',
#    '(-110)'),
#   (2018, 12, 'Arizona', 'Los Angeles', 'O 43.0', '(-120)', 'U 43.0', '(EVEN)'),
#   (2018, 12, 'Miami', 'Indianapolis', 'O 52.5', '(-110)', 'U 52.5', '(-110)'),
#   (2018, 12, 'Pittsburgh', 'Denver', 'O 47.5', '(-110)', 'U 47.5', '(-110)'),
#   (2018, 12, 'Green Bay', 'Minnesota', 'O 48.0', '(-120)', 'U 48.0', '(EVEN)'),
#   (2018, 12, 'Tennessee', 'Houston', 'O 42.5', '(-110)', 'U 42.5', '(-110)')],
#  [(2018, 13, 'New Orleans', 'Dallas', 'O 51.5', '(EVEN)', 'U 51.5', '(-120)'),
#   (2018, 13, 'Chicago', 'New York', 'O 43.5', '(-110)', 'U 43.5', '(-110)'),
#   (2018, 13, 'Baltimore', 'Atlanta', 'O 47.0', '(-110)', 'U 47.0', '(-110)'),
#   (2018, 13, 'Arizona', 'Green Bay', 'O 41.0', '(-110)', 'U 41.0', '(-110)'),
#   (2018, 13, 'Los Angeles', 'Detroit', 'O 54.0', '(EVEN)', 'U 54.0', '(-120)'),
#   (2018, 13, 'Denver', 'Cincinnati', 'O 44.5', '(-110)', 'U 44.5', '(-110)'),
#   (2018, 13, 'Buffalo', 'Miami', 'O 39.5', '(-110)', 'U 39.5', '(-110)'),
#   (2018, 13, 'Cleveland', 'Houston', 'O 47.5', '(-110)', 'U 47.5', '(-110)'),
#   (2018, 13, 'Carolina', 'Tampa Bay', 'O 52.0', '(-110)', 'U 52.0', '(-110)'),
#   (2018,
#    13,
#    'Indianapolis',
#    'Jacksonville',
#    'O 46.0',
#    '(-110)',
#    'U 46.0',
#    '(-110)'),
#   (2018,
#    13,
#    'Kansas City',
#    'Las Vegas',
#    'O 53.5',
#    '(-110)',
#    'U 53.5',
#    '(-110)'),
#   (2018, 13, 'New York', 'Tennessee', 'O 40.5', '(-110)', 'U 40.5', '(-110)'),
#   (2018,
#    13,
#    'San Francisco',
#    'Seattle',
#    'O 45.5',
#    '(EVEN)',
#    'U 45.5',
#    '(-120)'),
#   (2018,
#    13,
#    'Minnesota',
#    'New England',
#    'O 49.5',
#    '(-110)',
#    'U 49.5',
#    '(-110)'),
#   (2018,
#    13,
#    'Los Angeles',
#    'Pittsburgh',
#    'O 52.5',
#    '(-115)',
#    'U 52.5',
#    '(-105)'),
#   (2018,
#    13,
#    'Washington',
#    'Philadelphia',
#    'O 45.0',
#    '(-115)',
#    'U 45.0',
#    '(-105)')],
#  [(2018,
#    14,
#    'Jacksonville',
#    'Tennessee',
#    'O 37.5',
#    '(EVEN)',
#    'U 37.5',
#    '(-120)'),
#   (2018, 14, 'Carolina', 'Cleveland', 'O 47.5', '(-115)', 'U 47.5', '(-105)'),
#   (2018,
#    14,
#    'New Orleans',
#    'Tampa Bay',
#    'O 54.5',
#    '(EVEN)',
#    'U 54.5',
#    '(-120)'),
#   (2018, 14, 'New York', 'Washington', 'O 40.5', '(-110)', 'U 40.5', '(-110)'),
#   (2018,
#    14,
#    'Indianapolis',
#    'Houston',
#    'O 49.0',
#    '(-110)',
#    'U 49.0',
#    '(-110)'),
#   (2018,
#    14,
#    'Baltimore',
#    'Kansas City',
#    'O 49.5',
#    '(EVEN)',
#    'U 49.5',
#    '(-120)'),
#   (2018, 14, 'Atlanta', 'Green Bay', 'O 50.0', '(-110)', 'U 50.0', '(-110)'),
#   (2018, 14, 'New York', 'Buffalo', 'O 37.5', '(-110)', 'U 37.5', '(-110)'),
#   (2018, 14, 'New England', 'Miami', 'O 49.0', '(-120)', 'U 49.0', '(EVEN)'),
#   (2018,
#    14,
#    'Denver',
#    'San Francisco',
#    'O 45.5',
#    '(-110)',
#    'U 45.5',
#    '(-110)'),
#   (2018,
#    14,
#    'Cincinnati',
#    'Los Angeles',
#    'O 48.5',
#    '(-110)',
#    'U 48.5',
#    '(-110)'),
#   (2018, 14, 'Detroit', 'Arizona', 'O 40.5', '(-110)', 'U 40.5', '(-110)'),
#   (2018, 14, 'Philadelphia', 'Dallas', 'O 45.5', '(EVEN)', 'U 45.5', '(-120)'),
#   (2018,
#    14,
#    'Pittsburgh',
#    'Las Vegas',
#    'O 51.0',
#    '(-110)',
#    'U 51.0',
#    '(-110)'),
#   (2018, 14, 'Los Angeles', 'Chicago', 'O 51.0', '(EVEN)', 'U 51.0', '(-120)'),
#   (2018, 14, 'Minnesota', 'Seattle', 'O 45.5', '(-115)', 'U 45.5', '(-105)')],
#  [(2018,
#    15,
#    'Los Angeles',
#    'Kansas City',
#    'O 54.0',
#    '(-120)',
#    'U 54.0',
#    '(EVEN)'),
#   (2018, 15, 'Houston', 'New York', 'O 44.0', '(-110)', 'U 44.0', '(-110)'),
#   (2018, 15, 'Cleveland', 'Denver', 'O 47.0', '(-110)', 'U 47.0', '(-110)'),
#   (2018, 15, 'Tennessee', 'New York', 'O 42.5', '(-110)', 'U 42.5', '(-110)'),
#   (2018, 15, 'Tampa Bay', 'Baltimore', 'O 45.0', '(-105)', 'U 45.0', '(-115)'),
#   (2018, 15, 'Green Bay', 'Chicago', 'O 46.5', '(-115)', 'U 46.5', '(-105)'),
#   (2018, 15, 'Detroit', 'Buffalo', 'O 40.0', '(-110)', 'U 40.0', '(-110)'),
#   (2018, 15, 'Miami', 'Minnesota', 'O 45.0', '(-115)', 'U 45.0', '(-105)'),
#   (2018,
#    15,
#    'Las Vegas',
#    'Cincinnati',
#    'O 46.0',
#    '(-110)',
#    'U 46.0',
#    '(-110)'),
#   (2018, 15, 'Arizona', 'Atlanta', 'O 43.5', '(-110)', 'U 43.5', '(-110)'),
#   (2018, 15, 'Dallas', 'Indianapolis', 'O 46.5', '(-120)', 'U 46.5', '(EVEN)'),
#   (2018,
#    15,
#    'Washington',
#    'Jacksonville',
#    'O 36.5',
#    '(-110)',
#    'U 36.5',
#    '(-110)'),
#   (2018,
#    15,
#    'Seattle',
#    'San Francisco',
#    'O 44.0',
#    '(-105)',
#    'U 44.0',
#    '(-115)'),
#   (2018,
#    15,
#    'New England',
#    'Pittsburgh',
#    'O 56.0',
#    '(+105)',
#    'U 56.0',
#    '(-125)'),
#   (2018,
#    15,
#    'Philadelphia',
#    'Los Angeles',
#    'O 52.5',
#    '(-110)',
#    'U 52.5',
#    '(-110)'),
#   (2018,
#    15,
#    'New Orleans',
#    'Carolina',
#    'O 50.5',
#    '(EVEN)',
#    'U 50.5',
#    '(-120)')],
#  [(2018,
#    16,
#    'Washington',
#    'Tennessee',
#    'O 37.5',
#    '(-120)',
#    'U 37.5',
#    '(EVEN)'),
#   (2018,
#    16,
#    'Baltimore',
#    'Los Angeles',
#    'O 42.5',
#    '(-110)',
#    'U 42.5',
#    '(-110)'),
#   (2018, 16, 'Minnesota', 'Detroit', 'O 43.5', '(-115)', 'U 43.5', '(-105)'),
#   (2018, 16, 'Atlanta', 'Carolina', 'O 45.0', '(-110)', 'U 45.0', '(-110)'),
#   (2018,
#    16,
#    'New York',
#    'Indianapolis',
#    'O 48.5',
#    '(-110)',
#    'U 48.5',
#    '(-110)'),
#   (2018, 16, 'Green Bay', 'New York', 'O 47.5', '(-105)', 'U 47.5', '(-115)'),
#   (2018, 16, 'Tampa Bay', 'Dallas', 'O 48.0', '(-110)', 'U 48.0', '(-110)'),
#   (2018,
#    16,
#    'Cincinnati',
#    'Cleveland',
#    'O 44.0',
#    '(-110)',
#    'U 44.0',
#    '(-110)'),
#   (2018, 16, 'Buffalo', 'New England', 'O 45.0', '(-110)', 'U 45.0', '(-110)'),
#   (2018,
#    16,
#    'Houston',
#    'Philadelphia',
#    'O 46.5',
#    '(-115)',
#    'U 46.5',
#    '(-105)'),
#   (2018, 16, 'Jacksonville', 'Miami', 'O 39.0', '(-110)', 'U 39.0', '(-110)'),
#   (2018, 16, 'Los Angeles', 'Arizona', 'O 43.5', '(-105)', 'U 43.5', '(-115)'),
#   (2018,
#    16,
#    'Chicago',
#    'San Francisco',
#    'O 43.5',
#    '(EVEN)',
#    'U 43.5',
#    '(-120)'),
#   (2018,
#    16,
#    'Pittsburgh',
#    'New Orleans',
#    'O 53.0',
#    '(-110)',
#    'U 53.0',
#    '(-110)'),
#   (2018, 16, 'Kansas City', 'Seattle', 'O 54.5', '(-110)', 'U 54.5', '(-110)'),
#   (2018, 16, 'Denver', 'Las Vegas', 'O 42.5', '(-110)', 'U 42.5', '(-110)')],
#  [(2019, 1, 'Green Bay', 'Chicago', 'O 46.5', '(-106)', 'U 46.5', '(-114)'),
#   (2019, 1, 'Tennessee', 'Cleveland', 'O 44.0', '(-107)', 'U 44.0', '(-114)'),
#   (2019, 1, 'Baltimore', 'Miami', 'O 40.5', '(-114)', 'U 40.5', '(-107)'),
#   (2019, 1, 'Buffalo', 'New York', 'O 41.0', '(-110)', 'U 41.0', '(-110)'),
#   (2019,
#    1,
#    'Washington',
#    'Philadelphia',
#    'O 44.5',
#    '(-110)',
#    'U 44.5',
#    '(-110)'),
#   (2019,
#    1,
#    'Kansas City',
#    'Jacksonville',
#    'O 49.0',
#    '(-110)',
#    'U 49.0',
#    '(-110)'),
#   (2019, 1, 'Los Angeles', 'Carolina', 'O 49.5', '(-110)', 'U 49.5', '(-110)'),
#   (2019, 1, 'Atlanta', 'Minnesota', 'O 47.0', '(-106)', 'U 47.0', '(-115)'),
#   (2019, 1, 'Cincinnati', 'Seattle', 'O 44.5', '(-110)', 'U 44.5', '(-110)'),
#   (2019,
#    1,
#    'Indianapolis',
#    'Los Angeles',
#    'O 45.0',
#    '(-110)',
#    'U 45.0',
#    '(-110)'),
#   (2019,
#    1,
#    'San Francisco',
#    'Tampa Bay',
#    'O 51.5',
#    '(-110)',
#    'U 51.5',
#    '(-110)'),
#   (2019, 1, 'Detroit', 'Arizona', 'O 45.5', '(-110)', 'U 45.5', '(-110)'),
#   (2019, 1, 'New York', 'Dallas', 'O 45.0', '(-110)', 'U 45.0', '(-110)'),
#   (2019,
#    1,
#    'Pittsburgh',
#    'New England',
#    'O 48.5',
#    '(-110)',
#    'U 48.5',
#    '(-110)'),
#   (2019, 1, 'Houston', 'New Orleans', 'O 51.5', '(-110)', 'U 51.5', '(-110)'),
#   (2019, 1, 'Denver', 'Las Vegas', 'O 42.5', '(-110)', 'U 42.5', '(-110)')],
#  [(2019, 2, 'Tampa Bay', 'Carolina', 'O 49.5', '(-110)', 'U 49.5', '(-110)'),
#   (2019, 2, 'Los Angeles', 'Detroit', 'O 46.5', '(-110)', 'U 46.5', '(-110)'),
#   (2019,
#    2,
#    'Indianapolis',
#    'Tennessee',
#    'O 43.5',
#    '(-114)',
#    'U 43.5',
#    '(-107)'),
#   (2019, 2, 'Dallas', 'Washington', 'O 46.5', '(-110)', 'U 46.5', '(-110)'),
#   (2019, 2, 'Seattle', 'Pittsburgh', 'O 47.5', '(-107)', 'U 47.5', '(-114)'),
#   (2019, 2, 'Minnesota', 'Green Bay', 'O 43.0', '(-110)', 'U 43.0', '(-110)'),
#   (2019, 2, 'Buffalo', 'New York', 'O 44.5', '(-114)', 'U 44.5', '(-107)'),
#   (2019, 2, 'Jacksonville', 'Houston', 'O 43.0', '(-110)', 'U 43.0', '(-110)'),
#   (2019, 2, 'Arizona', 'Baltimore', 'O 46.5', '(-110)', 'U 46.5', '(-110)'),
#   (2019,
#    2,
#    'San Francisco',
#    'Cincinnati',
#    'O 46.0',
#    '(-115)',
#    'U 46.0',
#    '(-112)'),
#   (2019, 2, 'New England', 'Miami', 'O 48.5', '(-110)', 'U 48.5', '(-113)'),
#   (2019,
#    2,
#    'Kansas City',
#    'Las Vegas',
#    'O 53.5',
#    '(-110)',
#    'U 53.5',
#    '(-110)'),
#   (2019, 2, 'Chicago', 'Denver', 'O 40.0', '(-110)', 'U 40.0', '(-110)'),
#   (2019,
#    2,
#    'New Orleans',
#    'Los Angeles',
#    'O 52.5',
#    '(-110)',
#    'U 52.5',
#    '(-110)'),
#   (2019, 2, 'Philadelphia', 'Atlanta', 'O 52.5', '(-110)', 'U 52.5', '(-110)'),
#   (2019, 2, 'Cleveland', 'New York', 'O 45.5', '(-110)', 'U 45.5', '(-110)')],
#  [(2019,
#    3,
#    'Tennessee',
#    'Jacksonville',
#    'O 38.0',
#    '(-110)',
#    'U 38.0',
#    '(-110)'),
#   (2019, 3, 'Denver', 'Green Bay', 'O 42.5', '(-110)', 'U 42.5', '(-110)'),
#   (2019, 3, 'Atlanta', 'Indianapolis', 'O 47.0', '(-110)', 'U 47.0', '(-110)'),
#   (2019,
#    3,
#    'Baltimore',
#    'Kansas City',
#    'O 52.0',
#    '(-110)',
#    'U 52.0',
#    '(-110)'),
#   (2019, 3, 'Cincinnati', 'Buffalo', 'O 44.0', '(-110)', 'U 44.0', '(-110)'),
#   (2019, 3, 'New York', 'New England', 'O 43.5', '(-110)', 'U 43.5', '(-110)'),
#   (2019, 3, 'Detroit', 'Philadelphia', 'O 45.0', '(-110)', 'U 45.0', '(-110)'),
#   (2019, 3, 'Las Vegas', 'Minnesota', 'O 43.5', '(-110)', 'U 43.5', '(-110)'),
#   (2019, 3, 'Miami', 'Dallas', 'O 47.5', '(-110)', 'U 47.5', '(-125)'),
#   (2019, 3, 'New York', 'Tampa Bay', 'O 48.0', '(-110)', 'U 48.0', '(-110)'),
#   (2019, 3, 'Carolina', 'Arizona', 'O 44.5', '(-108)', 'U 44.5', '(-112)'),
#   (2019,
#    3,
#    'Pittsburgh',
#    'San Francisco',
#    'O 44.0',
#    '(-107)',
#    'U 44.0',
#    '(-114)'),
#   (2019, 3, 'Houston', 'Los Angeles', 'O 48.5', '(-110)', 'U 48.5', '(-110)'),
#   (2019, 3, 'New Orleans', 'Seattle', 'O 44.5', '(-110)', 'U 44.5', '(-110)'),
#   (2019,
#    3,
#    'Los Angeles',
#    'Cleveland',
#    'O 48.0',
#    '(-110)',
#    'U 48.0',
#    '(-110)'),
#   (2019, 3, 'Chicago', 'Washington', 'O 41.5', '(-110)', 'U 41.5', '(-110)')],
#  [(2019,
#    4,
#    'Philadelphia',
#    'Green Bay',
#    'O 47.0',
#    '(-110)',
#    'U 47.0',
#    '(-110)'),
#   (2019, 4, 'Carolina', 'Houston', 'O 47.5', '(-110)', 'U 47.5', '(-110)'),
#   (2019, 4, 'Cleveland', 'Baltimore', 'O 45.0', '(-110)', 'U 45.0', '(-110)'),
#   (2019, 4, 'Kansas City', 'Detroit', 'O 54.5', '(-107)', 'U 54.5', '(-114)'),
#   (2019, 4, 'New England', 'Buffalo', 'O 41.5', '(-110)', 'U 41.5', '(-110)'),
#   (2019, 4, 'Los Angeles', 'Miami', 'O 43.5', '(-110)', 'U 43.5', '(-110)'),
#   (2019,
#    4,
#    'Las Vegas',
#    'Indianapolis',
#    'O 45.5',
#    '(-110)',
#    'U 45.5',
#    '(-110)'),
#   (2019, 4, 'Tennessee', 'Atlanta', 'O 46.0', '(-110)', 'U 46.0', '(-112)'),
#   (2019, 4, 'Washington', 'New York', 'O 49.0', '(-110)', 'U 49.0', '(-110)'),
#   (2019,
#    4,
#    'Tampa Bay',
#    'Los Angeles',
#    'O 48.5',
#    '(-110)',
#    'U 48.5',
#    '(-110)'),
#   (2019, 4, 'Seattle', 'Arizona', 'O 47.5', '(-110)', 'U 47.5', '(-110)'),
#   (2019, 4, 'Minnesota', 'Chicago', 'O 38.0', '(-110)', 'U 38.0', '(-110)'),
#   (2019, 4, 'Jacksonville', 'Denver', 'O 37.5', '(-110)', 'U 37.5', '(-110)'),
#   (2019, 4, 'Dallas', 'New Orleans', 'O 47.5', '(-110)', 'U 47.5', '(-110)'),
#   (2019,
#    4,
#    'Cincinnati',
#    'Pittsburgh',
#    'O 44.5',
#    '(-110)',
#    'U 44.5',
#    '(-110)')],
#  [(2019, 5, 'Los Angeles', 'Seattle', 'O 48.5', '(-120)', 'U 48.5', '(-103)'),
#   (2019, 5, 'Buffalo', 'Tennessee', 'O 39.5', '(-110)', 'U 39.5', '(-112)'),
#   (2019, 5, 'Atlanta', 'Houston', 'O 50.0', '(-110)', 'U 50.0', '(-110)'),
#   (2019, 5, 'Baltimore', 'Pittsburgh', 'O 44.0', '(-110)', 'U 44.0', '(-110)'),
#   (2019,
#    5,
#    'New England',
#    'Washington',
#    'O 42.0',
#    '(-110)',
#    'U 42.0',
#    '(-110)'),
#   (2019, 5, 'Arizona', 'Cincinnati', 'O 46.5', '(-110)', 'U 46.5', '(-110)'),
#   (2019,
#    5,
#    'Jacksonville',
#    'Carolina',
#    'O 40.0',
#    '(-110)',
#    'U 40.0',
#    '(-110)'),
#   (2019,
#    5,
#    'Tampa Bay',
#    'New Orleans',
#    'O 46.5',
#    '(-110)',
#    'U 46.5',
#    '(-110)'),
#   (2019,
#    5,
#    'New York',
#    'Philadelphia',
#    'O 43.5',
#    '(-110)',
#    'U 43.5',
#    '(-110)'),
#   (2019, 5, 'Chicago', 'Las Vegas', 'O 40.5', '(-110)', 'U 40.5', '(-110)'),
#   (2019, 5, 'Minnesota', 'New York', 'O 43.5', '(-110)', 'U 43.5', '(-110)'),
#   (2019, 5, 'Denver', 'Los Angeles', 'O 44.5', '(-110)', 'U 44.5', '(-110)'),
#   (2019, 5, 'Green Bay', 'Dallas', 'O 46.5', '(-114)', 'U 46.5', '(-107)'),
#   (2019,
#    5,
#    'Indianapolis',
#    'Kansas City',
#    'O 55.5',
#    '(-110)',
#    'U 55.5',
#    '(-118)'),
#   (2019,
#    5,
#    'Cleveland',
#    'San Francisco',
#    'O 47.5',
#    '(-110)',
#    'U 47.5',
#    '(-110)')],
#  [(2019, 6, 'New York', 'New England', 'O 42.5', '(-110)', 'U 42.5', '(-110)'),
#   (2019, 6, 'Carolina', 'Tampa Bay', 'O 47.0', '(-110)', 'U 47.0', '(-110)'),
#   (2019, 6, 'Houston', 'Kansas City', 'O 54.0', '(-110)', 'U 54.0', '(-110)'),
#   (2019, 6, 'Seattle', 'Cleveland', 'O 46.5', '(-110)', 'U 46.5', '(-110)'),
#   (2019, 6, 'Cincinnati', 'Baltimore', 'O 47.5', '(-110)', 'U 47.5', '(-110)'),
#   (2019,
#    6,
#    'New Orleans',
#    'Jacksonville',
#    'O 43.0',
#    '(-110)',
#    'U 43.0',
#    '(-110)'),
#   (2019,
#    6,
#    'Philadelphia',
#    'Minnesota',
#    'O 44.0',
#    '(-110)',
#    'U 44.0',
#    '(-110)'),
#   (2019, 6, 'Washington', 'Miami', 'O 42.5', '(-110)', 'U 42.5', '(-110)'),
#   (2019,
#    6,
#    'San Francisco',
#    'Los Angeles',
#    'O 49.5',
#    '(-107)',
#    'U 49.5',
#    '(-114)'),
#   (2019, 6, 'Atlanta', 'Arizona', 'O 52.5', '(-112)', 'U 52.5', '(-110)'),
#   (2019, 6, 'Dallas', 'New York', 'O 43.5', '(-110)', 'U 43.5', '(-110)'),
#   (2019, 6, 'Tennessee', 'Denver', 'O 41.0', '(-110)', 'U 41.0', '(-110)'),
#   (2019,
#    6,
#    'Pittsburgh',
#    'Los Angeles',
#    'O 42.5',
#    '(-110)',
#    'U 42.5',
#    '(-110)'),
#   (2019, 6, 'Detroit', 'Green Bay', 'O 45.5', '(-110)', 'U 45.5', '(-110)')],
#  [(2019, 7, 'Kansas City', 'Denver', 'O 49.5', '(-110)', 'U 49.5', '(-110)'),
#   (2019, 7, 'Las Vegas', 'Green Bay', 'O 47.5', '(-113)', 'U 47.5', '(-110)'),
#   (2019, 7, 'Miami', 'Buffalo', 'O 41.0', '(-110)', 'U 41.0', '(-110)'),
#   (2019, 7, 'Los Angeles', 'Atlanta', 'O 54.5', '(-110)', 'U 54.5', '(-113)'),
#   (2019, 7, 'Minnesota', 'Detroit', 'O 43.5', '(-114)', 'U 43.5', '(-107)'),
#   (2019, 7, 'Houston', 'Indianapolis', 'O 46.5', '(-110)', 'U 46.5', '(-110)'),
#   (2019, 7, 'Arizona', 'New York', 'O 50.5', '(-107)', 'U 50.5', '(-114)'),
#   (2019,
#    7,
#    'San Francisco',
#    'Washington',
#    'O 39.5',
#    '(-112)',
#    'U 39.5',
#    '(-110)'),
#   (2019,
#    7,
#    'Jacksonville',
#    'Cincinnati',
#    'O 43.5',
#    '(-110)',
#    'U 43.5',
#    '(-110)'),
#   (2019,
#    7,
#    'Los Angeles',
#    'Tennessee',
#    'O 42.5',
#    '(-110)',
#    'U 42.5',
#    '(-110)'),
#   (2019, 7, 'New Orleans', 'Chicago', 'O 37.5', '(-106)', 'U 37.5', '(-114)'),
#   (2019, 7, 'Baltimore', 'Seattle', 'O 48.5', '(-110)', 'U 48.5', '(-110)'),
#   (2019, 7, 'Philadelphia', 'Dallas', 'O 49.5', '(-110)', 'U 49.5', '(-110)'),
#   (2019,
#    7,
#    'New England',
#    'New York',
#    'O 43.5',
#    '(-107)',
#    'U 43.5',
#    '(-114)')],
#  [(2019, 8, 'Washington', 'Minnesota', 'O 41.5', '(-110)', 'U 41.5', '(-110)'),
#   (2019, 8, 'Seattle', 'Atlanta', 'O 51.0', '(-110)', 'U 51.0', '(-110)'),
#   (2019, 8, 'Denver', 'Indianapolis', 'O 42.5', '(-110)', 'U 42.5', '(-110)'),
#   (2019, 8, 'Arizona', 'New Orleans', 'O 48.0', '(-110)', 'U 48.0', '(-110)'),
#   (2019, 8, 'Los Angeles', 'Chicago', 'O 40.5', '(-110)', 'U 40.5', '(-110)'),
#   (2019,
#    8,
#    'Cincinnati',
#    'Los Angeles',
#    'O 46.5',
#    '(-113)',
#    'U 46.5',
#    '(-110)'),
#   (2019,
#    8,
#    'New York',
#    'Jacksonville',
#    'O 40.5',
#    '(-110)',
#    'U 40.5',
#    '(-110)'),
#   (2019, 8, 'New York', 'Detroit', 'O 49.5', '(-110)', 'U 49.5', '(-110)'),
#   (2019, 8, 'Tampa Bay', 'Tennessee', 'O 45.5', '(-110)', 'U 45.5', '(-110)'),
#   (2019, 8, 'Philadelphia', 'Buffalo', 'O 41.5', '(-114)', 'U 41.5', '(-115)'),
#   (2019,
#    8,
#    'Carolina',
#    'San Francisco',
#    'O 40.5',
#    '(-115)',
#    'U 40.5',
#    '(-107)'),
#   (2019, 8, 'Las Vegas', 'Houston', 'O 51.5', '(-110)', 'U 51.5', '(-110)'),
#   (2019,
#    8,
#    'Cleveland',
#    'New England',
#    'O 43.5',
#    '(-114)',
#    'U 43.5',
#    '(-115)'),
#   (2019,
#    8,
#    'Green Bay',
#    'Kansas City',
#    'O 47.5',
#    '(-110)',
#    'U 47.5',
#    '(-110)'),
#   (2019, 8, 'Miami', 'Pittsburgh', 'O 43.5', '(-110)', 'U 43.5', '(-110)')],
#  [(2019,
#    9,
#    'San Francisco',
#    'Arizona',
#    'O 43.0',
#    '(-110)',
#    'U 43.0',
#    '(-110)'),
#   (2019, 9, 'Houston', 'Jacksonville', 'O 46.5', '(-110)', 'U 46.5', '(-110)'),
#   (2019, 9, 'Chicago', 'Philadelphia', 'O 41.5', '(-110)', 'U 41.5', '(-110)'),
#   (2019,
#    9,
#    'Minnesota',
#    'Kansas City',
#    'O 46.5',
#    '(-110)',
#    'U 46.5',
#    '(-110)'),
#   (2019, 9, 'Washington', 'Buffalo', 'O 36.5', '(-110)', 'U 36.5', '(-110)'),
#   (2019,
#    9,
#    'Indianapolis',
#    'Pittsburgh',
#    'O 40.0',
#    '(-110)',
#    'U 40.0',
#    '(-110)'),
#   (2019, 9, 'New York', 'Miami', 'O 42.5', '(-110)', 'U 42.5', '(-110)'),
#   (2019, 9, 'Tennessee', 'Carolina', 'O 42.5', '(-110)', 'U 42.5', '(-110)'),
#   (2019, 9, 'Tampa Bay', 'Seattle', 'O 51.5', '(-110)', 'U 51.5', '(-110)'),
#   (2019, 9, 'Detroit', 'Las Vegas', 'O 50.5', '(-110)', 'U 50.5', '(-110)'),
#   (2019, 9, 'Cleveland', 'Denver', 'O 39.5', '(-110)', 'U 39.5', '(-110)'),
#   (2019,
#    9,
#    'Green Bay',
#    'Los Angeles',
#    'O 49.5',
#    '(-114)',
#    'U 49.5',
#    '(-107)'),
#   (2019,
#    9,
#    'New England',
#    'Baltimore',
#    'O 44.5',
#    '(-110)',
#    'U 44.5',
#    '(-110)'),
#   (2019, 9, 'Dallas', 'New York', 'O 48.5', '(-110)', 'U 48.5', '(-110)')],
#  [(2019,
#    10,
#    'Los Angeles',
#    'Las Vegas',
#    'O 48.5',
#    '(-110)',
#    'U 48.5',
#    '(-110)'),
#   (2019,
#    10,
#    'Baltimore',
#    'Cincinnati',
#    'O 44.5',
#    '(-110)',
#    'U 44.5',
#    '(-110)'),
#   (2019, 10, 'Buffalo', 'Cleveland', 'O 39.5', '(-125)', 'U 39.5', '(-110)'),
#   (2019, 10, 'Atlanta', 'New Orleans', 'O 51.5', '(-110)', 'U 51.5', '(-110)'),
#   (2019, 10, 'New York', 'New York', 'O 44.5', '(-110)', 'U 44.5', '(-110)'),
#   (2019,
#    10,
#    'Kansas City',
#    'Tennessee',
#    'O 49.5',
#    '(-110)',
#    'U 49.5',
#    '(-110)'),
#   (2019, 10, 'Arizona', 'Tampa Bay', 'O 52.0', '(-110)', 'U 52.0', '(-110)'),
#   (2019, 10, 'Detroit', 'Chicago', 'O 41.5', '(-110)', 'U 41.5', '(-110)'),
#   (2019, 10, 'Miami', 'Indianapolis', 'O 44.5', '(-110)', 'U 44.5', '(-110)'),
#   (2019,
#    10,
#    'Los Angeles',
#    'Pittsburgh',
#    'O 43.5',
#    '(-110)',
#    'U 43.5',
#    '(-110)'),
#   (2019, 10, 'Carolina', 'Green Bay', 'O 48.5', '(-110)', 'U 48.5', '(-110)'),
#   (2019, 10, 'Minnesota', 'Dallas', 'O 47.5', '(-110)', 'U 47.5', '(-110)'),
#   (2019,
#    10,
#    'Seattle',
#    'San Francisco',
#    'O 46.5',
#    '(-110)',
#    'U 46.5',
#    '(-110)')],
#  [(2019,
#    11,
#    'Pittsburgh',
#    'Cleveland',
#    'O 41.5',
#    '(-110)',
#    'U 41.5',
#    '(-110)'),
#   (2019, 11, 'Dallas', 'Detroit', 'O 46.5', '(-110)', 'U 46.5', '(-110)'),
#   (2019,
#    11,
#    'Jacksonville',
#    'Indianapolis',
#    'O 43.5',
#    '(-110)',
#    'U 43.5',
#    '(-110)'),
#   (2019, 11, 'Denver', 'Minnesota', 'O 40.5', '(-110)', 'U 40.5', '(-110)'),
#   (2019, 11, 'Houston', 'Baltimore', 'O 51.5', '(-114)', 'U 51.5', '(-107)'),
#   (2019, 11, 'New York', 'Washington', 'O 38.5', '(-110)', 'U 38.5', '(-110)'),
#   (2019, 11, 'Atlanta', 'Carolina', 'O 49.5', '(-110)', 'U 49.5', '(-110)'),
#   (2019, 11, 'Buffalo', 'Miami', 'O 40.5', '(-110)', 'U 40.5', '(-110)'),
#   (2019,
#    11,
#    'New Orleans',
#    'Tampa Bay',
#    'O 49.5',
#    '(-110)',
#    'U 49.5',
#    '(-110)'),
#   (2019,
#    11,
#    'Arizona',
#    'San Francisco',
#    'O 44.5',
#    '(-110)',
#    'U 44.5',
#    '(-110)'),
#   (2019,
#    11,
#    'New England',
#    'Philadelphia',
#    'O 44.5',
#    '(-110)',
#    'U 44.5',
#    '(-110)'),
#   (2019,
#    11,
#    'Cincinnati',
#    'Las Vegas',
#    'O 47.5',
#    '(-110)',
#    'U 47.5',
#    '(-110)'),
#   (2019, 11, 'Chicago', 'Los Angeles', 'O 40.5', '(-110)', 'U 40.5', '(-110)'),
#   (2019,
#    11,
#    'Kansas City',
#    'Los Angeles',
#    'O 52.5',
#    '(-110)',
#    'U 52.5',
#    '(-110)')],
#  [(2019,
#    12,
#    'Indianapolis',
#    'Houston',
#    'O 45.5',
#    '(-110)',
#    'U 45.5',
#    '(-110)'),
#   (2019, 12, 'Tampa Bay', 'Atlanta', 'O 51.5', '(-110)', 'U 51.5', '(-110)'),
#   (2019, 12, 'Miami', 'Cleveland', 'O 45.5', '(-110)', 'U 45.5', '(-110)'),
#   (2019, 12, 'New York', 'Chicago', 'O 40.5', '(-110)', 'U 40.5', '(-110)'),
#   (2019,
#    12,
#    'Seattle',
#    'Philadelphia',
#    'O 47.5',
#    '(EVEN)',
#    'U 47.5',
#    '(-120)'),
#   (2019,
#    12,
#    'Carolina',
#    'New Orleans',
#    'O 45.5',
#    '(-114)',
#    'U 45.5',
#    '(-107)'),
#   (2019, 12, 'Las Vegas', 'New York', 'O 46.5', '(-110)', 'U 46.5', '(-110)'),
#   (2019, 12, 'Denver', 'Buffalo', 'O 36.5', '(-106)', 'U 36.5', '(-115)'),
#   (2019, 12, 'Detroit', 'Washington', 'O 40.5', '(-110)', 'U 40.5', '(-110)'),
#   (2019,
#    12,
#    'Pittsburgh',
#    'Cincinnati',
#    'O 37.5',
#    '(-110)',
#    'U 37.5',
#    '(-110)'),
#   (2019,
#    12,
#    'Jacksonville',
#    'Tennessee',
#    'O 41.5',
#    '(-110)',
#    'U 41.5',
#    '(-110)'),
#   (2019, 12, 'Dallas', 'New England', 'O 44.5', '(-110)', 'U 44.5', '(-110)'),
#   (2019,
#    12,
#    'Green Bay',
#    'San Francisco',
#    'O 47.5',
#    '(-110)',
#    'U 47.5',
#    '(-110)'),
#   (2019,
#    12,
#    'Baltimore',
#    'Los Angeles',
#    'O 47.5',
#    '(-110)',
#    'U 47.5',
#    '(-110)')],
#  [(2019, 13, 'Chicago', 'Detroit', 'O 36.5', '(-110)', 'U 36.5', '(-110)'),
#   (2019, 13, 'Buffalo', 'Dallas', 'O 47.0', '(-112)', 'U 47.0', '(-110)'),
#   (2019, 13, 'New Orleans', 'Atlanta', 'O 48.5', '(-110)', 'U 48.5', '(-110)'),
#   (2019, 13, 'Philadelphia', 'Miami', 'O 44.5', '(-110)', 'U 44.5', '(-110)'),
#   (2019, 13, 'New York', 'Cincinnati', 'O 42.5', '(-110)', 'U 42.5', '(-110)'),
#   (2019,
#    13,
#    'Tennessee',
#    'Indianapolis',
#    'O 42.5',
#    '(-110)',
#    'U 42.5',
#    '(-110)'),
#   (2019,
#    13,
#    'Cleveland',
#    'Pittsburgh',
#    'O 39.5',
#    '(-110)',
#    'U 39.5',
#    '(-110)'),
#   (2019, 13, 'Washington', 'Carolina', 'O 38.5', '(-110)', 'U 38.5', '(-110)'),
#   (2019, 13, 'Green Bay', 'New York', 'O 44.5', '(-110)', 'U 44.5', '(-110)'),
#   (2019,
#    13,
#    'San Francisco',
#    'Baltimore',
#    'O 44.5',
#    '(-110)',
#    'U 44.5',
#    '(-110)'),
#   (2019,
#    13,
#    'Tampa Bay',
#    'Jacksonville',
#    'O 46.5',
#    '(-110)',
#    'U 46.5',
#    '(-110)'),
#   (2019, 13, 'Los Angeles', 'Arizona', 'O 47.5', '(-110)', 'U 47.5', '(-110)'),
#   (2019,
#    13,
#    'Las Vegas',
#    'Kansas City',
#    'O 49.5',
#    '(-110)',
#    'U 49.5',
#    '(-110)'),
#   (2019, 13, 'Los Angeles', 'Denver', 'O 37.5', '(-110)', 'U 37.5', '(-110)'),
#   (2019, 13, 'New England', 'Houston', 'O 46.5', '(-107)', 'U 46.5', '(-114)'),
#   (2019, 13, 'Minnesota', 'Seattle', 'O 48.5', '(-110)', 'U 48.5', '(-110)')],
#  [(2019, 14, 'Dallas', 'Chicago', 'O 43.5', '(-110)', 'U 43.5', '(-110)'),
#   (2019,
#    14,
#    'Washington',
#    'Green Bay',
#    'O 41.5',
#    '(-110)',
#    'U 41.5',
#    '(-110)'),
#   (2019, 14, 'Detroit', 'Minnesota', 'O 43.5', '(-110)', 'U 43.5', '(-110)'),
#   (2019, 14, 'Carolina', 'Atlanta', 'O 47.5', '(-108)', 'U 47.5', '(-115)'),
#   (2019,
#    14,
#    'San Francisco',
#    'New Orleans',
#    'O 44.5',
#    '(-110)',
#    'U 44.5',
#    '(-110)'),
#   (2019,
#    14,
#    'Cincinnati',
#    'Cleveland',
#    'O 42.5',
#    '(-110)',
#    'U 42.5',
#    '(-110)'),
#   (2019,
#    14,
#    'Indianapolis',
#    'Tampa Bay',
#    'O 47.5',
#    '(-110)',
#    'U 47.5',
#    '(-110)'),
#   (2019, 14, 'Denver', 'Houston', 'O 42.5', '(-110)', 'U 42.5', '(-110)'),
#   (2019, 14, 'Miami', 'New York', 'O 45.5', '(-110)', 'U 45.5', '(-110)'),
#   (2019, 14, 'Baltimore', 'Buffalo', 'O 43.5', '(-110)', 'U 43.5', '(-110)'),
#   (2019,
#    14,
#    'Los Angeles',
#    'Jacksonville',
#    'O 41.5',
#    '(-110)',
#    'U 41.5',
#    '(-110)'),
#   (2019, 14, 'Tennessee', 'Las Vegas', 'O 47.5', '(-110)', 'U 47.5', '(-114)'),
#   (2019,
#    14,
#    'Kansas City',
#    'New England',
#    'O 49.5',
#    '(-110)',
#    'U 49.5',
#    '(-110)'),
#   (2019, 14, 'Pittsburgh', 'Arizona', 'O 43.5', '(-110)', 'U 43.5', '(-110)'),
#   (2019, 14, 'Seattle', 'Los Angeles', 'O 47.5', '(-110)', 'U 47.5', '(-110)'),
#   (2019,
#    14,
#    'New York',
#    'Philadelphia',
#    'O 45.5',
#    '(-110)',
#    'U 45.5',
#    '(-110)')],
#  [(2019, 15, 'New York', 'Baltimore', 'O 44.5', '(-110)', 'U 44.5', '(-110)'),
#   (2019, 15, 'Denver', 'Kansas City', 'O 44.5', '(-110)', 'U 44.5', '(-110)'),
#   (2019, 15, 'Tampa Bay', 'Detroit', 'O 45.5', '(-110)', 'U 45.5', '(-110)'),
#   (2019, 15, 'Houston', 'Tennessee', 'O 51.5', '(-110)', 'U 51.5', '(-110)'),
#   (2019, 15, 'Miami', 'New York', 'O 44.5', '(-110)', 'U 44.5', '(-110)'),
#   (2019, 15, 'Seattle', 'Carolina', 'O 49.5', '(-110)', 'U 49.5', '(-110)'),
#   (2019, 15, 'Chicago', 'Green Bay', 'O 40.5', '(-110)', 'U 40.5', '(-110)'),
#   (2019,
#    15,
#    'New England',
#    'Cincinnati',
#    'O 41.5',
#    '(-110)',
#    'U 41.5',
#    '(-110)'),
#   (2019,
#    15,
#    'Philadelphia',
#    'Washington',
#    'O 38.5',
#    '(-110)',
#    'U 38.5',
#    '(-110)'),
#   (2019, 15, 'Cleveland', 'Arizona', 'O 48.5', '(-110)', 'U 48.5', '(-110)'),
#   (2019,
#    15,
#    'Jacksonville',
#    'Las Vegas',
#    'O 46.5',
#    '(-110)',
#    'U 46.5',
#    '(-110)'),
#   (2019,
#    15,
#    'Minnesota',
#    'Los Angeles',
#    'O 45.5',
#    '(-110)',
#    'U 45.5',
#    '(-110)'),
#   (2019,
#    15,
#    'Atlanta',
#    'San Francisco',
#    'O 48.5',
#    '(-110)',
#    'U 48.5',
#    '(-110)'),
#   (2019, 15, 'Los Angeles', 'Dallas', 'O 48.5', '(-110)', 'U 48.5', '(-110)'),
#   (2019, 15, 'Buffalo', 'Pittsburgh', 'O 37.5', '(-110)', 'U 37.5', '(-110)'),
#   (2019,
#    15,
#    'Indianapolis',
#    'New Orleans',
#    'O 47.5',
#    '(-113)',
#    'U 47.5',
#    '(-110)')],
#  [(2019, 16, 'Houston', 'Tampa Bay', 'O 50.5', '(-110)', 'U 50.5', '(-110)'),
#   (2019, 16, 'Buffalo', 'New England', 'O 37.5', '(-110)', 'U 37.5', '(-110)'),
#   (2019,
#    16,
#    'Los Angeles',
#    'San Francisco',
#    'O 45.5',
#    '(-110)',
#    'U 45.5',
#    '(-110)'),
#   (2019, 16, 'New York', 'Washington', 'O 41.5', '(-110)', 'U 41.5', '(-110)'),
#   (2019, 16, 'Cincinnati', 'Miami', 'O 45.5', '(-110)', 'U 45.5', '(-110)'),
#   (2019,
#    16,
#    'New Orleans',
#    'Tennessee',
#    'O 50.5',
#    '(-110)',
#    'U 50.5',
#    '(-110)'),
#   (2019, 16, 'Pittsburgh', 'New York', 'O 37.0', '(-110)', 'U 37.0', '(-110)'),
#   (2019, 16, 'Baltimore', 'Cleveland', 'O 49.5', '(-110)', 'U 49.5', '(-110)'),
#   (2019,
#    16,
#    'Carolina',
#    'Indianapolis',
#    'O 47.5',
#    '(-110)',
#    'U 47.5',
#    '(-110)'),
#   (2019,
#    16,
#    'Jacksonville',
#    'Atlanta',
#    'O 47.5',
#    '(-110)',
#    'U 47.5',
#    '(-110)'),
#   (2019,
#    16,
#    'Las Vegas',
#    'Los Angeles',
#    'O 45.5',
#    '(-110)',
#    'U 45.5',
#    '(-110)'),
#   (2019, 16, 'Detroit', 'Denver', 'O 39.5', '(-110)', 'U 39.5', '(-110)'),
#   (2019, 16, 'Arizona', 'Seattle', 'O 51.0', '(-110)', 'U 51.0', '(-110)'),
#   (2019, 16, 'Dallas', 'Philadelphia', 'O 46.5', '(-110)', 'U 46.5', '(-110)'),
#   (2019, 16, 'Kansas City', 'Chicago', 'O 45.5', '(-110)', 'U 45.5', '(-110)'),
#   (2019,
#    16,
#    'Green Bay',
#    'Minnesota',
#    'O 47.5',
#    '(-110)',
#    'U 47.5',
#    '(-110)')],
#  [(2020, 1, 'Houston', 'Kansas City', 'O 53.5', '(-110)', 'U 53.5', '(-110)'),
#   (2020, 1, 'Green Bay', 'Minnesota', 'O 44.5', '(-110)', 'U 44.5', '(-110)'),
#   (2020, 1, 'Chicago', 'Detroit', 'O 42.5', '(-110)', 'U 42.5', '(-110)'),
#   (2020,
#    1,
#    'Indianapolis',
#    'Jacksonville',
#    'O 44.5',
#    '(-110)',
#    'U 44.5',
#    '(-110)'),
#   (2020, 1, 'Las Vegas', 'Carolina', 'O 48.0', '(-110)', 'U 48.0', '(-110)'),
#   (2020, 1, 'New York', 'Buffalo', 'O 41.0', '(-110)', 'U 41.0', '(-110)'),
#   (2020,
#    1,
#    'Philadelphia',
#    'Washington',
#    'O 38.5',
#    '(-110)',
#    'U 38.5',
#    '(-110)'),
#   (2020, 1, 'Miami', 'New England', 'O 41.5', '(-105)', 'U 41.5', '(-115)'),
#   (2020, 1, 'Cleveland', 'Baltimore', 'O 47.5', '(-110)', 'U 47.5', '(-110)'),
#   (2020,
#    1,
#    'Los Angeles',
#    'Cincinnati',
#    'O 41.0',
#    '(-110)',
#    'U 41.0',
#    '(-110)'),
#   (2020,
#    1,
#    'Tampa Bay',
#    'New Orleans',
#    'O 48.5',
#    '(-110)',
#    'U 48.5',
#    '(-110)'),
#   (2020,
#    1,
#    'Arizona',
#    'San Francisco',
#    'O 47.0',
#    '(-110)',
#    'U 47.0',
#    '(-110)'),
#   (2020, 1, 'Dallas', 'Los Angeles', 'O 52.0', '(-110)', 'U 52.0', '(-110)'),
#   (2020, 1, 'Pittsburgh', 'New York', 'O 44.0', '(-110)', 'U 44.0', '(-110)'),
#   (2020, 1, 'Tennessee', 'Denver', 'O 41.5', '(-107)', 'U 41.5', '(-113)')],
#  [(2020, 2, 'Cincinnati', 'Cleveland', 'O 44.5', '(-110)', 'U 44.5', '(-110)'),
#   (2020,
#    2,
#    'Jacksonville',
#    'Tennessee',
#    'O 44.5',
#    '(-110)',
#    'U 44.5',
#    '(-110)'),
#   (2020, 2, 'New York', 'Chicago', 'O 42.5', '(-110)', 'U 42.5', '(-110)'),
#   (2020, 2, 'Atlanta', 'Dallas', 'O 53.5', '(-110)', 'U 53.5', '(-110)'),
#   (2020, 2, 'Denver', 'Pittsburgh', 'O 40.5', '(-110)', 'U 40.5', '(-110)'),
#   (2020,
#    2,
#    'Minnesota',
#    'Indianapolis',
#    'O 49.0',
#    '(-110)',
#    'U 49.0',
#    '(-110)'),
#   (2020, 2, 'Carolina', 'Tampa Bay', 'O 47.0', '(-110)', 'U 47.0', '(-110)'),
#   (2020, 2, 'Buffalo', 'Miami', 'O 42.5', '(-110)', 'U 42.5', '(-110)'),
#   (2020,
#    2,
#    'San Francisco',
#    'New York',
#    'O 41.5',
#    '(-110)',
#    'U 41.5',
#    '(-110)'),
#   (2020,
#    2,
#    'Los Angeles',
#    'Philadelphia',
#    'O 46.0',
#    '(-110)',
#    'U 46.0',
#    '(-110)'),
#   (2020, 2, 'Detroit', 'Green Bay', 'O 50.5', '(-110)', 'U 50.5', '(-110)'),
#   (2020, 2, 'Washington', 'Arizona', 'O 46.5', '(-110)', 'U 46.5', '(-110)'),
#   (2020, 2, 'Baltimore', 'Houston', 'O 49.5', '(-110)', 'U 49.5', '(-110)'),
#   (2020,
#    2,
#    'Kansas City',
#    'Los Angeles',
#    'O 47.0',
#    '(-110)',
#    'U 47.0',
#    '(-110)'),
#   (2020, 2, 'New England', 'Seattle', 'O 45.0', '(-110)', 'U 45.0', '(-110)'),
#   (2020,
#    2,
#    'New Orleans',
#    'Las Vegas',
#    'O 48.0',
#    '(-110)',
#    'U 48.0',
#    '(-110)')],
#  [(2020, 3, 'Miami', 'Jacksonville', 'O 49.0', '(-110)', 'U 49.0', '(-110)'),
#   (2020, 3, 'Houston', 'Pittsburgh', 'O 46.5', '(-110)', 'U 46.5', '(-110)'),
#   (2020, 3, 'Tennessee', 'Minnesota', 'O 49.5', '(-110)', 'U 49.5', '(-110)'),
#   (2020, 3, 'Chicago', 'Atlanta', 'O 46.0', '(-110)', 'U 46.0', '(-110)'),
#   (2020,
#    3,
#    'Las Vegas',
#    'New England',
#    'O 47.0',
#    '(-110)',
#    'U 47.0',
#    '(-110)'),
#   (2020,
#    3,
#    'San Francisco',
#    'New York',
#    'O 43.5',
#    '(-110)',
#    'U 43.5',
#    '(-110)'),
#   (2020,
#    3,
#    'Cincinnati',
#    'Philadelphia',
#    'O 46.5',
#    '(-110)',
#    'U 46.5',
#    '(-110)'),
#   (2020, 3, 'Washington', 'Cleveland', 'O 45.0', '(-110)', 'U 45.0', '(-110)'),
#   (2020, 3, 'Los Angeles', 'Buffalo', 'O 46.5', '(-110)', 'U 46.5', '(-110)'),
#   (2020,
#    3,
#    'New York',
#    'Indianapolis',
#    'O 44.0',
#    '(-110)',
#    'U 44.0',
#    '(-110)'),
#   (2020, 3, 'Carolina', 'Los Angeles', 'O 43.5', '(-110)', 'U 43.5', '(-110)'),
#   (2020, 3, 'Detroit', 'Arizona', 'O 55.5', '(-110)', 'U 55.5', '(-110)'),
#   (2020, 3, 'Dallas', 'Seattle', 'O 57.0', '(-110)', 'U 57.0', '(-110)'),
#   (2020, 3, 'Tampa Bay', 'Denver', 'O 42.5', '(-110)', 'U 42.5', '(-110)'),
#   (2020,
#    3,
#    'Green Bay',
#    'New Orleans',
#    'O 51.5',
#    '(-110)',
#    'U 51.5',
#    '(-110)'),
#   (2020,
#    3,
#    'Kansas City',
#    'Baltimore',
#    'O 55.0',
#    '(-110)',
#    'U 55.0',
#    '(-110)')],
#  [(2020, 4, 'Denver', 'New York', 'O 41.0', '(-110)', 'U 41.0', '(-110)'),
#   (2020, 4, 'Cleveland', 'Dallas', 'O 56.5', '(-110)', 'U 56.5', '(-110)'),
#   (2020, 4, 'New Orleans', 'Detroit', 'O 51.5', '(-110)', 'U 51.5', '(-110)'),
#   (2020, 4, 'Minnesota', 'Houston', 'O 53.0', '(-110)', 'U 53.0', '(-110)'),
#   (2020,
#    4,
#    'Los Angeles',
#    'Tampa Bay',
#    'O 42.5',
#    '(-110)',
#    'U 42.5',
#    '(-110)'),
#   (2020, 4, 'Baltimore', 'Washington', 'O 45.0', '(-109)', 'U 45.0', '(-112)'),
#   (2020, 4, 'Arizona', 'Carolina', 'O 52.0', '(-110)', 'U 52.0', '(-110)'),
#   (2020,
#    4,
#    'Jacksonville',
#    'Cincinnati',
#    'O 49.5',
#    '(-110)',
#    'U 49.5',
#    '(-110)'),
#   (2020, 4, 'Seattle', 'Miami', 'O 55.0', '(-110)', 'U 55.0', '(-110)'),
#   (2020, 4, 'New York', 'Los Angeles', 'O 49.5', '(-110)', 'U 49.5', '(-110)'),
#   (2020, 4, 'Buffalo', 'Las Vegas', 'O 52.5', '(-110)', 'U 52.5', '(-110)'),
#   (2020, 4, 'Indianapolis', 'Chicago', 'O 43.0', '(-110)', 'U 43.0', '(-110)'),
#   (2020,
#    4,
#    'Philadelphia',
#    'San Francisco',
#    'O 45.5',
#    '(-110)',
#    'U 45.5',
#    '(-110)'),
#   (2020,
#    4,
#    'New England',
#    'Kansas City',
#    'O 48.5',
#    '(-110)',
#    'U 48.5',
#    '(-110)'),
#   (2020, 4, 'Atlanta', 'Green Bay', 'O 56.5', '(-110)', 'U 56.5', '(-110)')],
#  [(2020, 5, 'Tampa Bay', 'Chicago', 'O 44.0', '(-110)', 'U 44.0', '(-110)'),
#   (2020, 5, 'Cincinnati', 'Baltimore', 'O 49.0', '(-110)', 'U 49.0', '(-110)'),
#   (2020, 5, 'Carolina', 'Atlanta', 'O 53.0', '(-110)', 'U 53.0', '(-110)'),
#   (2020,
#    5,
#    'Las Vegas',
#    'Kansas City',
#    'O 54.5',
#    '(-110)',
#    'U 54.5',
#    '(-110)'),
#   (2020,
#    5,
#    'Philadelphia',
#    'Pittsburgh',
#    'O 44.0',
#    '(-110)',
#    'U 44.0',
#    '(-110)'),
#   (2020,
#    5,
#    'Los Angeles',
#    'Washington',
#    'O 44.0',
#    '(-110)',
#    'U 44.0',
#    '(-110)'),
#   (2020, 5, 'Arizona', 'New York', 'O 48.5', '(-110)', 'U 48.5', '(-110)'),
#   (2020, 5, 'Jacksonville', 'Houston', 'O 54.5', '(-110)', 'U 54.5', '(-110)'),
#   (2020, 5, 'Miami', 'San Francisco', 'O 50.5', '(-110)', 'U 50.5', '(-110)'),
#   (2020, 5, 'New York', 'Dallas', 'O 52.0', '(-110)', 'U 52.0', '(-110)'),
#   (2020,
#    5,
#    'Indianapolis',
#    'Cleveland',
#    'O 49.0',
#    '(-110)',
#    'U 49.0',
#    '(-110)'),
#   (2020, 5, 'Minnesota', 'Seattle', 'O 53.5', '(-110)', 'U 53.5', '(-110)'),
#   (2020,
#    5,
#    'Los Angeles',
#    'New Orleans',
#    'O 49.5',
#    '(-110)',
#    'U 49.5',
#    '(-110)'),
#   (2020, 5, 'Buffalo', 'Tennessee', 'O 52.0', '(-110)', 'U 52.0', '(-110)')],
#  [(2020, 6, 'Houston', 'Tennessee', 'O 52.0', '(-110)', 'U 52.0', '(-110)'),
#   (2020, 6, 'Washington', 'New York', 'O 42.0', '(-110)', 'U 42.0', '(-110)'),
#   (2020, 6, 'Atlanta', 'Minnesota', 'O 53.5', '(-110)', 'U 53.5', '(-110)'),
#   (2020, 6, 'Chicago', 'Carolina', 'O 45.0', '(-110)', 'U 45.0', '(-110)'),
#   (2020, 6, 'Detroit', 'Jacksonville', 'O 53.0', '(-110)', 'U 53.0', '(-110)'),
#   (2020, 6, 'Cleveland', 'Pittsburgh', 'O 50.0', '(-110)', 'U 50.0', '(-110)'),
#   (2020,
#    6,
#    'Cincinnati',
#    'Indianapolis',
#    'O 46.0',
#    '(-110)',
#    'U 46.0',
#    '(-110)'),
#   (2020,
#    6,
#    'Baltimore',
#    'Philadelphia',
#    'O 46.5',
#    '(-110)',
#    'U 46.5',
#    '(-110)'),
#   (2020, 6, 'Denver', 'New England', 'O 44.0', '(-110)', 'U 44.0', '(-110)'),
#   (2020, 6, 'New York', 'Miami', 'O 46.5', '(-110)', 'U 46.5', '(-110)'),
#   (2020, 6, 'Green Bay', 'Tampa Bay', 'O 54.5', '(-110)', 'U 54.5', '(-110)'),
#   (2020,
#    6,
#    'Los Angeles',
#    'San Francisco',
#    'O 51.5',
#    '(-110)',
#    'U 51.5',
#    '(-110)'),
#   (2020, 6, 'Kansas City', 'Buffalo', 'O 55.0', '(-110)', 'U 55.0', '(-110)'),
#   (2020, 6, 'Arizona', 'Dallas', 'O 55.0', '(-115)', 'U 55.0', '(-105)')],
#  [(2020,
#    7,
#    'New York',
#    'Philadelphia',
#    'O 44.5',
#    '(-110)',
#    'U 44.5',
#    '(-110)'),
#   (2020, 7, 'Pittsburgh', 'Tennessee', 'O 51.0', '(-110)', 'U 51.0', '(-110)'),
#   (2020, 7, 'Green Bay', 'Houston', 'O 55.5', '(-110)', 'U 55.5', '(-110)'),
#   (2020, 7, 'Detroit', 'Atlanta', 'O 54.5', '(-110)', 'U 54.5', '(-110)'),
#   (2020, 7, 'Dallas', 'Washington', 'O 44.5', '(-110)', 'U 44.5', '(-110)'),
#   (2020, 7, 'Buffalo', 'New York', 'O 46.5', '(-110)', 'U 46.5', '(-110)'),
#   (2020, 7, 'Cleveland', 'Cincinnati', 'O 50.0', '(-110)', 'U 50.0', '(-110)'),
#   (2020, 7, 'Carolina', 'New Orleans', 'O 50.0', '(-110)', 'U 50.0', '(-110)'),
#   (2020, 7, 'Tampa Bay', 'Las Vegas', 'O 51.5', '(-110)', 'U 51.5', '(-110)'),
#   (2020, 7, 'Kansas City', 'Denver', 'O 46.0', '(-110)', 'U 46.0', '(-110)'),
#   (2020,
#    7,
#    'San Francisco',
#    'New England',
#    'O 44.5',
#    '(-110)',
#    'U 44.5',
#    '(-110)'),
#   (2020,
#    7,
#    'Jacksonville',
#    'Los Angeles',
#    'O 48.5',
#    '(-110)',
#    'U 48.5',
#    '(-110)'),
#   (2020, 7, 'Seattle', 'Arizona', 'O 55.5', '(-110)', 'U 55.5', '(-110)'),
#   (2020, 7, 'Chicago', 'Los Angeles', 'O 43.5', '(-110)', 'U 43.5', '(-110)')],
#  [(2020, 8, 'Atlanta', 'Carolina', 'O 52.0', '(-110)', 'U 52.0', '(-110)'),
#   (2020, 8, 'Pittsburgh', 'Baltimore', 'O 44.0', '(-115)', 'U 44.0', '(-105)'),
#   (2020, 8, 'New York', 'Kansas City', 'O 49.0', '(-110)', 'U 49.0', '(-110)'),
#   (2020, 8, 'Tennessee', 'Cincinnati', 'O 49.5', '(-110)', 'U 49.5', '(-110)'),
#   (2020, 8, 'Los Angeles', 'Miami', 'O 46.5', '(-114)', 'U 46.5', '(-107)'),
#   (2020, 8, 'Indianapolis', 'Detroit', 'O 49.0', '(-110)', 'U 49.0', '(-110)'),
#   (2020, 8, 'New England', 'Buffalo', 'O 41.0', '(-110)', 'U 41.0', '(-110)'),
#   (2020, 8, 'Las Vegas', 'Cleveland', 'O 47.5', '(-110)', 'U 47.5', '(-110)'),
#   (2020, 8, 'Minnesota', 'Green Bay', 'O 48.0', '(-110)', 'U 48.0', '(-110)'),
#   (2020, 8, 'Los Angeles', 'Denver', 'O 44.5', '(-110)', 'U 44.5', '(-110)'),
#   (2020, 8, 'New Orleans', 'Chicago', 'O 41.0', '(-110)', 'U 41.0', '(-110)'),
#   (2020,
#    8,
#    'San Francisco',
#    'Seattle',
#    'O 54.5',
#    '(-110)',
#    'U 54.5',
#    '(-110)'),
#   (2020, 8, 'Dallas', 'Philadelphia', 'O 43.0', '(-110)', 'U 43.0', '(-110)'),
#   (2020, 8, 'Tampa Bay', 'New York', 'O 47.0', '(-110)', 'U 47.0', '(-110)')],
#  [(2020,
#    9,
#    'Green Bay',
#    'San Francisco',
#    'O 48.5',
#    '(-110)',
#    'U 48.5',
#    '(-110)'),
#   (2020, 9, 'Chicago', 'Tennessee', 'O 46.5', '(-110)', 'U 46.5', '(-110)'),
#   (2020, 9, 'Detroit', 'Minnesota', 'O 51.5', '(-110)', 'U 51.5', '(-110)'),
#   (2020, 9, 'New York', 'Washington', 'O 43.0', '(-110)', 'U 43.0', '(-110)'),
#   (2020, 9, 'Seattle', 'Buffalo', 'O 55.0', '(-110)', 'U 55.0', '(-110)'),
#   (2020,
#    9,
#    'Baltimore',
#    'Indianapolis',
#    'O 48.0',
#    '(-110)',
#    'U 48.0',
#    '(-110)'),
#   (2020, 9, 'Carolina', 'Kansas City', 'O 51.5', '(-110)', 'U 51.5', '(-110)'),
#   (2020, 9, 'Houston', 'Jacksonville', 'O 48.5', '(-110)', 'U 48.5', '(-110)'),
#   (2020, 9, 'Denver', 'Atlanta', 'O 50.0', '(-110)', 'U 50.0', '(-110)'),
#   (2020,
#    9,
#    'Las Vegas',
#    'Los Angeles',
#    'O 52.5',
#    '(-110)',
#    'U 52.5',
#    '(-110)'),
#   (2020, 9, 'Pittsburgh', 'Dallas', 'O 44.0', '(-110)', 'U 44.0', '(-110)'),
#   (2020, 9, 'Miami', 'Arizona', 'O 49.0', '(-110)', 'U 49.0', '(-110)'),
#   (2020,
#    9,
#    'New Orleans',
#    'Tampa Bay',
#    'O 50.5',
#    '(-110)',
#    'U 50.5',
#    '(-110)'),
#   (2020,
#    9,
#    'New England',
#    'New York',
#    'O 42.0',
#    '(-110)',
#    'U 42.0',
#    '(-110)')],
#  [(2020,
#    10,
#    'Indianapolis',
#    'Tennessee',
#    'O 48.5',
#    '(-110)',
#    'U 48.5',
#    '(-110)'),
#   (2020, 10, 'Washington', 'Detroit', 'O 45.5', '(-110)', 'U 45.5', '(-110)'),
#   (2020,
#    10,
#    'Jacksonville',
#    'Green Bay',
#    'O 47.0',
#    '(-110)',
#    'U 47.0',
#    '(-110)'),
#   (2020,
#    10,
#    'Philadelphia',
#    'New York',
#    'O 45.5',
#    '(-110)',
#    'U 45.5',
#    '(-110)'),
# ...
#   (2023,
#    5,
#    'Kansas City',
#    'Minnesota',
#    'O 52.5',
#    '(-110)',
#    'U 52.5',
#    '(-110)'),
#   (2023, 5, 'Dallas', 'San Francisco', 'O 45.0', '(-110)', 'U 45.0', '(-110)'),
#   (2023, 5, 'Green Bay', 'Las Vegas', 'O 45.0', '(-110)', 'U 45.0', '(-110)')],
#  [(2023, 6, 'Denver', 'Kansas City', 'O 47.5', '(-108)', 'U 47.5', '(-112)'),
#   (2023, 6, 'Baltimore', 'Tennessee', 'O 42.5', '(-110)', 'U 42.5', '(-110)'),
#   (2023, 6, 'Washington', 'Atlanta', 'O 42.0', '(-110)', 'U 42.0', '(-110)'),
#   (2023,
#    6,
#    'San Francisco',
#    'Cleveland',
#    'O 36.0',
#    '(-110)',
#    'U 36.0',
#    '(-110)'),
#   (2023, 6, 'New Orleans', 'Houston', 'O 42.0', '(-110)', 'U 42.0', '(-110)'),
#   (2023, 6, 'Carolina', 'Miami', 'O 47.5', '(-108)', 'U 47.5', '(-112)'),
#   (2023, 6, 'Seattle', 'Cincinnati', 'O 45.5', '(-110)', 'U 45.5', '(-110)'),
#   (2023,
#    6,
#    'Indianapolis',
#    'Jacksonville',
#    'O 44.0',
#    '(-110)',
#    'U 44.0',
#    '(-110)'),
#   (2023, 6, 'Minnesota', 'Chicago', 'O 44.5', '(-110)', 'U 44.5', '(-110)'),
#   (2023,
#    6,
#    'New England',
#    'Las Vegas',
#    'O 41.5',
#    '(-110)',
#    'U 41.5',
#    '(-110)'),
#   (2023, 6, 'Detroit', 'Tampa Bay', 'O 43.5', '(-110)', 'U 43.5', '(-110)'),
#   (2023, 6, 'Arizona', 'Los Angeles', 'O 47.5', '(-110)', 'U 47.5', '(-110)'),
#   (2023,
#    6,
#    'Philadelphia',
#    'New York',
#    'O 43.5',
#    '(-110)',
#    'U 43.5',
#    '(-110)'),
#   (2023, 6, 'New York', 'Buffalo', 'O 43.5', '(-110)', 'U 43.5', '(-110)'),
#   (2023, 6, 'Dallas', 'Los Angeles', 'O 49.5', '(-110)', 'U 49.5', '(-110)')],
#  [(2023,
#    7,
#    'Jacksonville',
#    'New Orleans',
#    'O 41.5',
#    '(-110)',
#    'U 41.5',
#    '(-110)'),
#   (2023, 7, 'Washington', 'New York', 'O 37.0', '(-110)', 'U 37.0', '(-110)'),
#   (2023, 7, 'Buffalo', 'New England', 'O 41.0', '(-110)', 'U 41.0', '(-110)'),
#   (2023, 7, 'Atlanta', 'Tampa Bay', 'O 37.5', '(-110)', 'U 37.5', '(-110)'),
#   (2023, 7, 'Detroit', 'Baltimore', 'O 43.5', '(-110)', 'U 43.5', '(-110)'),
#   (2023, 7, 'Las Vegas', 'Chicago', 'O 38.5', '(-110)', 'U 38.5', '(-110)'),
#   (2023,
#    7,
#    'Cleveland',
#    'Indianapolis',
#    'O 40.0',
#    '(-110)',
#    'U 40.0',
#    '(-110)'),
#   (2023,
#    7,
#    'Pittsburgh',
#    'Los Angeles',
#    'O 44.0',
#    '(-110)',
#    'U 44.0',
#    '(-110)'),
#   (2023, 7, 'Arizona', 'Seattle', 'O 43.5', '(-110)', 'U 43.5', '(-110)'),
#   (2023,
#    7,
#    'Los Angeles',
#    'Kansas City',
#    'O 48.5',
#    '(-110)',
#    'U 48.5',
#    '(-110)'),
#   (2023, 7, 'Green Bay', 'Denver', 'O 44.0', '(-110)', 'U 44.0', '(-110)'),
#   (2023, 7, 'Miami', 'Philadelphia', 'O 52.0', '(-110)', 'U 52.0', '(-112)'),
#   (2023,
#    7,
#    'San Francisco',
#    'Minnesota',
#    'O 44.0',
#    '(-110)',
#    'U 44.0',
#    '(-110)')],
#  [(2023, 8, 'Tampa Bay', 'Buffalo', 'O 43.0', '(-110)', 'U 43.0', '(-110)'),
#   (2023, 8, 'Los Angeles', 'Dallas', 'O 44.5', '(-110)', 'U 44.5', '(-110)'),
#   (2023, 8, 'Houston', 'Carolina', 'O 43.0', '(-110)', 'U 43.0', '(-110)'),
#   (2023, 8, 'Minnesota', 'Green Bay', 'O 41.5', '(-110)', 'U 41.5', '(-110)'),
#   (2023, 8, 'New York', 'New York', 'O 34.5', '(-110)', 'U 34.5', '(-110)'),
#   (2023, 8, 'New England', 'Miami', 'O 46.5', '(-110)', 'U 46.5', '(-110)'),
#   (2023, 8, 'Atlanta', 'Tennessee', 'O 35.0', '(-110)', 'U 35.0', '(-110)'),
#   (2023,
#    8,
#    'Philadelphia',
#    'Washington',
#    'O 42.5',
#    '(-110)',
#    'U 42.5',
#    '(-110)'),
#   (2023,
#    8,
#    'New Orleans',
#    'Indianapolis',
#    'O 43.5',
#    '(-110)',
#    'U 43.5',
#    '(-110)'),
#   (2023,
#    8,
#    'Jacksonville',
#    'Pittsburgh',
#    'O 41.0',
#    '(-110)',
#    'U 41.0',
#    '(-110)'),
#   (2023, 8, 'Cleveland', 'Seattle', 'O 39.5', '(-110)', 'U 39.5', '(-110)'),
#   (2023, 8, 'Kansas City', 'Denver', 'O 45.5', '(-110)', 'U 45.5', '(-110)'),
#   (2023, 8, 'Baltimore', 'Arizona', 'O 45.0', '(-110)', 'U 45.0', '(-110)'),
#   (2023,
#    8,
#    'Cincinnati',
#    'San Francisco',
#    'O 44.0',
#    '(-110)',
#    'U 44.0',
#    '(-110)'),
#   (2023, 8, 'Chicago', 'Los Angeles', 'O 46.0', '(-112)', 'U 46.0', '(-108)'),
#   (2023, 8, 'Las Vegas', 'Detroit', 'O 46.0', '(-110)', 'U 46.0', '(-110)')],
#  [(2023, 9, 'Tennessee', 'Pittsburgh', 'O 37.0', '(-112)', 'U 37.0', '(-108)'),
#   (2023, 9, 'Miami', 'Kansas City', 'O 51.5', '(-110)', 'U 51.5', '(-110)'),
#   (2023, 9, 'Minnesota', 'Atlanta', 'O 38.5', '(-110)', 'U 38.5', '(-110)'),
#   (2023, 9, 'Seattle', 'Baltimore', 'O 44.5', '(-110)', 'U 44.5', '(-110)'),
#   (2023, 9, 'Chicago', 'New Orleans', 'O 42.0', '(-110)', 'U 42.0', '(-110)'),
#   (2023, 9, 'Arizona', 'Cleveland', 'O 38.0', '(-110)', 'U 38.0', '(-110)'),
#   (2023, 9, 'Tampa Bay', 'Houston', 'O 40.0', '(-110)', 'U 40.0', '(-110)'),
#   (2023,
#    9,
#    'Washington',
#    'New England',
#    'O 40.5',
#    '(-110)',
#    'U 40.5',
#    '(-110)'),
#   (2023,
#    9,
#    'Los Angeles',
#    'Green Bay',
#    'O 37.5',
#    '(-110)',
#    'U 37.5',
#    '(-110)'),
#   (2023,
#    9,
#    'Indianapolis',
#    'Carolina',
#    'O 45.0',
#    '(-112)',
#    'U 45.0',
#    '(-108)'),
#   (2023, 9, 'Dallas', 'Philadelphia', 'O 46.5', '(-112)', 'U 46.5', '(-108)'),
#   (2023, 9, 'New York', 'Las Vegas', 'O 38.5', '(-110)', 'U 38.5', '(-110)'),
#   (2023, 9, 'Buffalo', 'Cincinnati', 'O 51.0', '(-110)', 'U 51.0', '(-110)'),
#   (2023,
#    9,
#    'Los Angeles',
#    'New York',
#    'O 41.0',
#    '(-110)',
#    'U 41.0',
#    '(-110)')],
#  [(2023, 10, 'Carolina', 'Chicago', 'O 38.0', '(-110)', 'U 38.0', '(-110)'),
#   (2023,
#    10,
#    'Indianapolis',
#    'New England',
#    'O 42.5',
#    '(-110)',
#    'U 42.5',
#    '(-110)'),
#   (2023,
#    10,
#    'Green Bay',
#    'Pittsburgh',
#    'O 38.5',
#    '(-110)',
#    'U 38.5',
#    '(-110)'),
#   (2023,
#    10,
#    'New Orleans',
#    'Minnesota',
#    'O 40.5',
#    '(-110)',
#    'U 40.5',
#    '(-110)'),
#   (2023, 10, 'Houston', 'Cincinnati', 'O 45.5', '(-110)', 'U 45.5', '(-110)'),
#   (2023, 10, 'Cleveland', 'Baltimore', 'O 39.0', '(-110)', 'U 39.0', '(-110)'),
#   (2023, 10, 'Tennessee', 'Tampa Bay', 'O 39.0', '(-110)', 'U 39.0', '(-110)'),
#   (2023,
#    10,
#    'San Francisco',
#    'Jacksonville',
#    'O 44.5',
#    '(-110)',
#    'U 44.5',
#    '(-110)'),
#   (2023, 10, 'Detroit', 'Los Angeles', 'O 48.5', '(-110)', 'U 48.5', '(-110)'),
#   (2023, 10, 'Atlanta', 'Arizona', 'O 43.5', '(-110)', 'U 43.5', '(-110)'),
#   (2023, 10, 'Washington', 'Seattle', 'O 44.0', '(-110)', 'U 44.0', '(-110)'),
#   (2023, 10, 'New York', 'Dallas', 'O 39.0', '(-110)', 'U 39.0', '(-110)'),
#   (2023, 10, 'New York', 'Las Vegas', 'O 35.5', '(-110)', 'U 35.5', '(-110)'),
#   (2023, 10, 'Denver', 'Buffalo', 'O 47.5', '(-108)', 'U 47.5', '(-112)')],
#  [(2023,
#    11,
#    'Cincinnati',
#    'Baltimore',
#    'O 46.5',
#    '(-110)',
#    'U 46.5',
#    '(-110)'),
#   (2023, 11, 'Dallas', 'Carolina', 'O 43.5', '(-110)', 'U 43.5', '(-110)'),
#   (2023,
#    11,
#    'Pittsburgh',
#    'Cleveland',
#    'O 34.0',
#    '(-110)',
#    'U 34.0',
#    '(-110)'),
#   (2023, 11, 'Chicago', 'Detroit', 'O 48.0', '(-115)', 'U 48.0', '(-110)'),
#   (2023, 11, 'Arizona', 'Houston', 'O 48.0', '(-110)', 'U 48.0', '(-110)'),
#   (2023, 11, 'Las Vegas', 'Miami', 'O 44.5', '(-110)', 'U 44.5', '(-110)'),
#   (2023, 11, 'New York', 'Washington', 'O 39.0', '(-110)', 'U 39.0', '(-110)'),
#   (2023,
#    11,
#    'Los Angeles',
#    'Green Bay',
#    'O 44.0',
#    '(-110)',
#    'U 44.0',
#    '(-110)'),
#   (2023,
#    11,
#    'Tennessee',
#    'Jacksonville',
#    'O 40.0',
#    '(-110)',
#    'U 40.0',
#    '(-110)'),
#   (2023,
#    11,
#    'Tampa Bay',
#    'San Francisco',
#    'O 41.5',
#    '(-112)',
#    'U 41.5',
#    '(-108)'),
#   (2023, 11, 'New York', 'Buffalo', 'O 39.5', '(-108)', 'U 39.5', '(-112)'),
#   (2023, 11, 'Seattle', 'Los Angeles', 'O 46.0', '(-112)', 'U 46.0', '(-108)'),
#   (2023, 11, 'Minnesota', 'Denver', 'O 43.0', '(-110)', 'U 43.0', '(-110)'),
#   (2023,
#    11,
#    'Philadelphia',
#    'Kansas City',
#    'O 46.0',
#    '(-112)',
#    'U 46.0',
#    '(-108)')],
#  [(2023, 12, 'Green Bay', 'Detroit', 'O 47.0', '(-110)', 'U 47.0', '(-110)'),
#   (2023, 12, 'Washington', 'Dallas', 'O 48.0', '(-110)', 'U 48.0', '(-110)'),
#   (2023,
#    12,
#    'San Francisco',
#    'Seattle',
#    'O 43.0',
#    '(-110)',
#    'U 43.0',
#    '(-110)'),
#   (2023, 12, 'Miami', 'New York', 'O 40.0', '(-110)', 'U 40.0', '(-110)'),
#   (2023,
#    12,
#    'Jacksonville',
#    'Houston',
#    'O 48.0',
#    '(-108)',
#    'U 48.0',
#    '(-112)'),
#   (2023,
#    12,
#    'Pittsburgh',
#    'Cincinnati',
#    'O 36.0',
#    '(-110)',
#    'U 36.0',
#    '(-110)'),
#   (2023, 12, 'Carolina', 'Tennessee', 'O 36.5', '(-110)', 'U 36.5', '(-110)'),
#   (2023, 12, 'New Orleans', 'Atlanta', 'O 42.0', '(-110)', 'U 42.0', '(-110)'),
#   (2023,
#    12,
#    'Tampa Bay',
#    'Indianapolis',
#    'O 44.5',
#    '(-110)',
#    'U 44.5',
#    '(-110)'),
#   (2023,
#    12,
#    'New England',
#    'New York',
#    'O 36.0',
#    '(-110)',
#    'U 36.0',
#    '(-110)'),
#   (2023, 12, 'Cleveland', 'Denver', 'O 37.5', '(-110)', 'U 37.5', '(-110)'),
#   (2023, 12, 'Los Angeles', 'Arizona', 'O 45.0', '(-108)', 'U 45.0', '(-112)'),
#   (2023,
#    12,
#    'Buffalo',
#    'Philadelphia',
#    'O 48.5',
#    '(-110)',
#    'U 48.5',
#    '(-110)'),
#   (2023,
#    12,
#    'Kansas City',
#    'Las Vegas',
#    'O 42.5',
#    '(-110)',
#    'U 42.5',
#    '(-110)'),
#   (2023,
#    12,
#    'Baltimore',
#    'Los Angeles',
#    'O 49.0',
#    '(-110)',
#    'U 49.0',
#    '(-110)'),
#   (2023, 12, 'Chicago', 'Minnesota', 'O 43.5', '(-110)', 'U 43.5', '(-110)')],
#  [(2023, 13, 'Seattle', 'Dallas', 'O 47.5', '(-110)', 'U 47.5', '(-110)'),
#   (2023,
#    13,
#    'Indianapolis',
#    'Tennessee',
#    'O 42.0',
#    '(-110)',
#    'U 42.0',
#    '(-110)'),
#   (2023,
#    13,
#    'Los Angeles',
#    'New England',
#    'O 38.5',
#    '(-110)',
#    'U 38.5',
#    '(-110)'),
#   (2023, 13, 'Detroit', 'New Orleans', 'O 48.0', '(-110)', 'U 48.0', '(-110)'),
#   (2023, 13, 'Arizona', 'Pittsburgh', 'O 41.0', '(-110)', 'U 41.0', '(-110)'),
#   (2023, 13, 'Atlanta', 'New York', 'O 33.0', '(-110)', 'U 33.0', '(-110)'),
#   (2023, 13, 'Miami', 'Washington', 'O 49.5', '(-110)', 'U 49.5', '(-110)'),
#   (2023, 13, 'Denver', 'Houston', 'O 47.0', '(-110)', 'U 47.0', '(-110)'),
#   (2023, 13, 'Carolina', 'Tampa Bay', 'O 37.0', '(-112)', 'U 37.0', '(-108)'),
#   (2023,
#    13,
#    'San Francisco',
#    'Philadelphia',
#    'O 46.5',
#    '(-110)',
#    'U 46.5',
#    '(-110)'),
#   (2023,
#    13,
#    'Cleveland',
#    'Los Angeles',
#    'O 39.5',
#    '(-110)',
#    'U 39.5',
#    '(-110)'),
#   (2023,
#    13,
#    'Kansas City',
#    'Green Bay',
#    'O 44.0',
#    '(-110)',
#    'U 44.0',
#    '(-110)'),
#   (2023,
#    13,
#    'Cincinnati',
#    'Jacksonville',
#    'O 41.0',
#    '(-110)',
#    'U 41.0',
#    '(-110)')],
#  [(2023,
#    14,
#    'New England',
#    'Pittsburgh',
#    'O 30.5',
#    '(-110)',
#    'U 30.5',
#    '(-110)'),
#   (2023, 14, 'Tampa Bay', 'Atlanta', 'O 41.5', '(-110)', 'U 41.5', '(-110)'),
#   (2023,
#    14,
#    'Carolina',
#    'New Orleans',
#    'O 38.5',
#    '(-110)',
#    'U 38.5',
#    '(-110)'),
#   (2023, 14, 'Houston', 'New York', 'O 33.5', '(-110)', 'U 33.5', '(-110)'),
#   (2023,
#    14,
#    'Indianapolis',
#    'Cincinnati',
#    'O 45.0',
#    '(-110)',
#    'U 45.0',
#    '(-110)'),
#   (2023,
#    14,
#    'Los Angeles',
#    'Baltimore',
#    'O 42.0',
#    '(-110)',
#    'U 42.0',
#    '(-110)'),
#   (2023, 14, 'Detroit', 'Chicago', 'O 44.5', '(-110)', 'U 44.5', '(-110)'),
#   (2023,
#    14,
#    'Jacksonville',
#    'Cleveland',
#    'O 37.5',
#    '(-110)',
#    'U 37.5',
#    '(-110)'),
#   (2023,
#    14,
#    'Seattle',
#    'San Francisco',
#    'O 44.5',
#    '(-110)',
#    'U 44.5',
#    '(-110)'),
#   (2023, 14, 'Minnesota', 'Las Vegas', 'O 40.5', '(-110)', 'U 40.5', '(-110)'),
#   (2023, 14, 'Buffalo', 'Kansas City', 'O 49.0', '(-110)', 'U 49.0', '(-110)'),
#   (2023, 14, 'Denver', 'Los Angeles', 'O 45.5', '(-110)', 'U 45.5', '(-110)'),
#   (2023, 14, 'Philadelphia', 'Dallas', 'O 52.5', '(-110)', 'U 52.5', '(-110)'),
#   (2023, 14, 'Green Bay', 'New York', 'O 37.0', '(-110)', 'U 37.0', '(-110)'),
#   (2023, 14, 'Tennessee', 'Miami', 'O 44.5', '(-110)', 'U 44.5', '(-110)')],
#  [(2023,
#    15,
#    'Los Angeles',
#    'Las Vegas',
#    'O 36.0',
#    '(-110)',
#    'U 36.0',
#    '(-110)'),
#   (2023,
#    15,
#    'Minnesota',
#    'Cincinnati',
#    'O 41.5',
#    '(-110)',
#    'U 41.5',
#    '(-110)'),
#   (2023,
#    15,
#    'Pittsburgh',
#    'Indianapolis',
#    'O 41.5',
#    '(-108)',
#    'U 41.5',
#    '(-112)'),
#   (2023, 15, 'Denver', 'Detroit', 'O 49.0', '(-110)', 'U 49.0', '(-110)'),
#   (2023, 15, 'Tampa Bay', 'Green Bay', 'O 41.0', '(-110)', 'U 41.0', '(-110)'),
#   (2023, 15, 'Atlanta', 'Carolina', 'O 32.5', '(-110)', 'U 32.5', '(-110)'),
#   (2023,
#    15,
#    'New York',
#    'New Orleans',
#    'O 39.5',
#    '(-110)',
#    'U 39.5',
#    '(-110)'),
#   (2023, 15, 'Houston', 'Tennessee', 'O 38.0', '(-110)', 'U 38.0', '(-110)'),
#   (2023, 15, 'Chicago', 'Cleveland', 'O 38.0', '(-110)', 'U 38.0', '(-110)'),
#   (2023, 15, 'New York', 'Miami', 'O 35.5', '(-110)', 'U 35.5', '(-110)'),
#   (2023,
#    15,
#    'Kansas City',
#    'New England',
#    'O 39.5',
#    '(-110)',
#    'U 39.5',
#    '(-110)'),
#   (2023,
#    15,
#    'Washington',
#    'Los Angeles',
#    'O 48.5',
#    '(-110)',
#    'U 48.5',
#    '(-110)'),
#   (2023,
#    15,
#    'San Francisco',
#    'Arizona',
#    'O 48.0',
#    '(-110)',
#    'U 48.0',
#    '(-110)'),
#   (2023, 15, 'Dallas', 'Buffalo', 'O 49.5', '(-110)', 'U 49.5', '(-110)'),
#   (2023,
#    15,
#    'Baltimore',
#    'Jacksonville',
#    'O 42.5',
#    '(-110)',
#    'U 42.5',
#    '(-110)'),
#   (2023,
#    15,
#    'Philadelphia',
#    'Seattle',
#    'O 46.0',
#    '(-110)',
#    'U 46.0',
#    '(-110)')],
#  [(2023,
#    16,
#    'New Orleans',
#    'Los Angeles',
#    'O 45.5',
#    '(-108)',
#    'U 45.5',
#    '(-112)'),
#   (2023,
#    16,
#    'Cincinnati',
#    'Pittsburgh',
#    'O 39.0',
#    '(-110)',
#    'U 39.0',
#    '(-110)'),
#   (2023, 16, 'Buffalo', 'Los Angeles', 'O 44.5', '(-110)', 'U 44.5', '(-110)'),
#   (2023, 16, 'Seattle', 'Tennessee', 'O 42.5', '(-110)', 'U 42.5', '(-110)'),
#   (2023,
#    16,
#    'Indianapolis',
#    'Atlanta',
#    'O 44.0',
#    '(-110)',
#    'U 44.0',
#    '(-110)'),
#   (2023, 16, 'Cleveland', 'Houston', 'O 40.0', '(-110)', 'U 40.0', '(-110)'),
#   (2023, 16, 'Green Bay', 'Carolina', 'O 39.5', '(-110)', 'U 39.5', '(-110)'),
#   (2023, 16, 'Washington', 'New York', 'O 36.0', '(-110)', 'U 36.0', '(-110)'),
#   (2023, 16, 'Detroit', 'Minnesota', 'O 47.5', '(-110)', 'U 47.5', '(-110)'),
#   (2023,
#    16,
#    'Jacksonville',
#    'Tampa Bay',
#    'O 43.0',
#    '(-110)',
#    'U 43.0',
#    '(-110)'),
#   (2023, 16, 'Arizona', 'Chicago', 'O 42.0', '(-110)', 'U 42.0', '(-110)'),
#   (2023, 16, 'Dallas', 'Miami', 'O 48.5', '(-110)', 'U 48.5', '(-110)'),
#   (2023, 16, 'New England', 'Denver', 'O 37.5', '(-112)', 'U 37.5', '(-108)'),
#   (2023,
#    16,
#    'Las Vegas',
#    'Kansas City',
#    'O 40.5',
#    '(-108)',
#    'U 40.5',
#    '(-112)'),
#   (2023,
#    16,
#    'New York',
#    'Philadelphia',
#    'O 41.5',
#    '(-110)',
#    'U 41.5',
#    '(-110)'),
#   (2023,
#    16,
#    'Baltimore',
#    'San Francisco',
#    'O 47.0',
#    '(-110)',
#    'U 47.0',
#    '(-110)')],
#  [(2023, 17, 'New York', 'Cleveland', 'O 33.5', '(-110)', 'U 33.5', '(-110)'),
#   (2023, 17, 'Detroit', 'Dallas', 'O 53.5', '(-110)', 'U 53.5', '(-110)'),
#   (2023, 17, 'New England', 'Buffalo', 'O 40.0', '(-110)', 'U 40.0', '(-110)'),
#   (2023, 17, 'Miami', 'Baltimore', 'O 47.0', '(-110)', 'U 47.0', '(-110)'),
#   (2023,
#    17,
#    'Las Vegas',
#    'Indianapolis',
#    'O 42.5',
#    '(-110)',
#    'U 42.5',
#    '(-110)'),
#   (2023, 17, 'Atlanta', 'Chicago', 'O 39.0', '(-110)', 'U 39.0', '(-110)'),
#   (2023,
#    17,
#    'Carolina',
#    'Jacksonville',
#    'O 38.0',
#    '(-110)',
#    'U 38.0',
#    '(-110)'),
#   (2023,
#    17,
#    'New Orleans',
#    'Tampa Bay',
#    'O 42.5',
#    '(-110)',
#    'U 42.5',
#    '(-110)'),
#   (2023,
#    17,
#    'Arizona',
#    'Philadelphia',
#    'O 48.0',
#    '(-110)',
#    'U 48.0',
#    '(-110)'),
#   (2023,
#    17,
#    'Los Angeles',
#    'New York',
#    'O 43.5',
#    '(-110)',
#    'U 43.5',
#    '(-110)'),
#   (2023, 17, 'Tennessee', 'Houston', 'O 44.0', '(-110)', 'U 44.0', '(-110)'),
#   (2023,
#    17,
#    'San Francisco',
#    'Washington',
#    'O 48.5',
#    '(-110)',
#    'U 48.5',
#    '(-110)'),
#   (2023, 17, 'Pittsburgh', 'Seattle', 'O 40.5', '(-112)', 'U 40.5', '(-108)'),
#   (2023,
#    17,
#    'Cincinnati',
#    'Kansas City',
#    'O 46.0',
#    '(-110)',
#    'U 46.0',
#    '(-110)'),
#   (2023, 17, 'Los Angeles', 'Denver', 'O 39.5', '(-110)', 'U 39.5', '(-110)'),
#   (2023,
#    17,
#    'Green Bay',
#    'Minnesota',
#    'O 42.5',
#    '(-110)',
#    'U 42.5',
#    '(-110)')]]

# %%
import pandas as pd

df = pd.concat(
    [
        pd.DataFrame(
            [i for i in j if len(i) > 0],
            columns=['Season', 'Week', 'Away Team', 'Home Team', 'Over Line', 'Over Odds', 'Under Line', 'Under Odds'],
        )
        for j in d
    ],
)

df
# Out:
#     Season  Week      Away Team    Home Team Over Line Over Odds Under Line  \
# 0     2018     5   Indianapolis  New England    O 49.5    (-110)     U 49.5
# 1     2018     5   Jacksonville  Kansas City    O 48.0    (-110)     U 48.0
# 2     2018     5      Baltimore    Cleveland    O 44.5    (-110)     U 44.5
# 3     2018     5      Green Bay      Detroit    O 50.0    (-110)     U 50.0
# 4     2018     5          Miami   Cincinnati    O 47.5    (-110)     U 47.5
# ..     ...   ...            ...          ...       ...       ...        ...
# 11    2023    17  San Francisco   Washington    O 48.5    (-110)     U 48.5
# 12    2023    17     Pittsburgh      Seattle    O 40.5    (-112)     U 40.5
# 13    2023    17     Cincinnati  Kansas City    O 46.0    (-110)     U 46.0
# 14    2023    17    Los Angeles       Denver    O 39.5    (-110)     U 39.5
# 15    2023    17      Green Bay    Minnesota    O 42.5    (-110)     U 42.5
#
#    Under Odds
# 0      (-110)
# 1      (-110)
# 2      (-110)
# 3      (-110)
# 4      (-110)
# ..        ...
# 11     (-110)
# 12     (-108)
# 13     (-110)
# 14     (-110)
# 15     (-110)
#
# [1398 rows x 8 columns]

# %%
df['Total'] = df['Over Line'].str.extract(r'(\d+\.\d+)').astype(float)

df
# Out:
#     Season  Week      Away Team    Home Team Over Line Over Odds Under Line  \
# 0     2018     5   Indianapolis  New England    O 49.5    (-110)     U 49.5
# 1     2018     5   Jacksonville  Kansas City    O 48.0    (-110)     U 48.0
# 2     2018     5      Baltimore    Cleveland    O 44.5    (-110)     U 44.5
# 3     2018     5      Green Bay      Detroit    O 50.0    (-110)     U 50.0
# 4     2018     5          Miami   Cincinnati    O 47.5    (-110)     U 47.5
# ..     ...   ...            ...          ...       ...       ...        ...
# 11    2023    17  San Francisco   Washington    O 48.5    (-110)     U 48.5
# 12    2023    17     Pittsburgh      Seattle    O 40.5    (-112)     U 40.5
# 13    2023    17     Cincinnati  Kansas City    O 46.0    (-110)     U 46.0
# 14    2023    17    Los Angeles       Denver    O 39.5    (-110)     U 39.5
# 15    2023    17      Green Bay    Minnesota    O 42.5    (-110)     U 42.5
#
#    Under Odds  Total
# 0      (-110)   49.5
# 1      (-110)   48.0
# 2      (-110)   44.5
# 3      (-110)   50.0
# 4      (-110)   47.5
# ..        ...    ...
# 11     (-110)   48.5
# 12     (-108)   40.5
# 13     (-110)   46.0
# 14     (-110)   39.5
# 15     (-110)   42.5
#
# [1398 rows x 9 columns]

# %%
df.loc[df['Over Odds'] == '(EVEN)', 'Over Odds'] = '100'
df['Over Odds'] = df['Over Odds'].str.replace(r'\(|\)', '', regex=True).astype(int)

df.loc[df['Under Odds'] == '(EVEN)', 'Under Odds'] = '100'
df['Under Odds'] = df['Under Odds'].str.replace(r'\(|\)', '', regex=True).astype(int)

df
# Out:
#     Season  Week      Away Team    Home Team Over Line  Over Odds Under Line  \
# 0     2018     5   Indianapolis  New England    O 49.5       -110     U 49.5
# 1     2018     5   Jacksonville  Kansas City    O 48.0       -110     U 48.0
# 2     2018     5      Baltimore    Cleveland    O 44.5       -110     U 44.5
# 3     2018     5      Green Bay      Detroit    O 50.0       -110     U 50.0
# 4     2018     5          Miami   Cincinnati    O 47.5       -110     U 47.5
# ..     ...   ...            ...          ...       ...        ...        ...
# 11    2023    17  San Francisco   Washington    O 48.5       -110     U 48.5
# 12    2023    17     Pittsburgh      Seattle    O 40.5       -112     U 40.5
# 13    2023    17     Cincinnati  Kansas City    O 46.0       -110     U 46.0
# 14    2023    17    Los Angeles       Denver    O 39.5       -110     U 39.5
# 15    2023    17      Green Bay    Minnesota    O 42.5       -110     U 42.5
#
#     Under Odds  Total
# 0         -110   49.5
# 1         -110   48.0
# 2         -110   44.5
# 3         -110   50.0
# 4         -110   47.5
# ..         ...    ...
# 11        -110   48.5
# 12        -108   40.5
# 13        -110   46.0
# 14        -110   39.5
# 15        -110   42.5
#
# [1398 rows x 9 columns]

# %%
df.drop(columns=['Over Line', 'Under Line'], inplace=True)

df
# Out:
#     Season  Week      Away Team    Home Team  Over Odds  Under Odds  Total
# 0     2018     5   Indianapolis  New England       -110        -110   49.5
# 1     2018     5   Jacksonville  Kansas City       -110        -110   48.0
# 2     2018     5      Baltimore    Cleveland       -110        -110   44.5
# 3     2018     5      Green Bay      Detroit       -110        -110   50.0
# 4     2018     5          Miami   Cincinnati       -110        -110   47.5
# ..     ...   ...            ...          ...        ...         ...    ...
# 11    2023    17  San Francisco   Washington       -110        -110   48.5
# 12    2023    17     Pittsburgh      Seattle       -112        -108   40.5
# 13    2023    17     Cincinnati  Kansas City       -110        -110   46.0
# 14    2023    17    Los Angeles       Denver       -110        -110   39.5
# 15    2023    17      Green Bay    Minnesota       -110        -110   42.5
#
# [1398 rows x 7 columns]

# %%
df.insert(df.columns.get_loc('Over Odds'), 'Total', df.pop('Total'))

df
# Out:
#     Season  Week      Away Team    Home Team  Total  Over Odds  Under Odds
# 0     2018     5   Indianapolis  New England   49.5       -110        -110
# 1     2018     5   Jacksonville  Kansas City   48.0       -110        -110
# 2     2018     5      Baltimore    Cleveland   44.5       -110        -110
# 3     2018     5      Green Bay      Detroit   50.0       -110        -110
# 4     2018     5          Miami   Cincinnati   47.5       -110        -110
# ..     ...   ...            ...          ...    ...        ...         ...
# 11    2023    17  San Francisco   Washington   48.5       -110        -110
# 12    2023    17     Pittsburgh      Seattle   40.5       -112        -108
# 13    2023    17     Cincinnati  Kansas City   46.0       -110        -110
# 14    2023    17    Los Angeles       Denver   39.5       -110        -110
# 15    2023    17      Green Bay    Minnesota   42.5       -110        -110
#
# [1398 rows x 7 columns]

# %%
df.to_parquet(r'..\..\data\betting_lines\totals.parquet')

'Done'
# Out:
# 'Done'
