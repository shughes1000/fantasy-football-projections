# %% [markdown]
# Find relevant tight end to webscrape

# %%
import pandas as pd

pd.set_option('display.max_columns', 100)

df_superflex_rankings = pd.read_parquet(r'..\..\data\fantasypros_in_season_rankings\superflex_rankings.parquet')

df_superflex_rankings = df_superflex_rankings.loc[df_superflex_rankings['Player Name'].notna(), :].reset_index(drop=True)

# make names easier to match
df_superflex_rankings['Player Name'] = (
    df_superflex_rankings['Player Name']
    .str.split().str[:2].str.join(' ')  # make names just the first two words
    .str.replace(r'[^a-zA-Z0-9\s]', '', regex=True)  # remove non-alphanumeric characters
    .str.lower()  # lowercase only (helps with matching)
)

df_superflex_rankings
# Out:
#        Year  Week   RK      Player Name POS  POS RK
# 0      2018     1    1      todd gurley  RB       1
# 1      2018     1    2    david johnson  RB       2
# 2      2018     1    3     alvin kamara  RB       3
# 3      2018     1    4    melvin gordon  RB       4
# 4      2018     1    5  ezekiel elliott  RB       5
# ...     ...   ...  ...              ...  ..     ...
# 41050  2023    17  461      steven sims  WR     183
# 41051  2023    17  462   jashaun corbin  RB     112
# 41052  2023    17  463     dee eskridge  WR     184
# 41053  2023    17  464     clayton tune  QB      65
# 41054  2023    17  465    brady russell  TE     104
#
# [41055 rows x 6 columns]

# %%
df_te = df_superflex_rankings.loc[df_superflex_rankings['POS'] == 'TE', :].sort_values(['Year', 'Week', 'POS RK'], ignore_index=True)

df_te = df_te.loc[df_te['Year'] >= 2020, :].reset_index(drop=True)  # for now

df_te.sort_values(['Year', 'Week', 'POS RK'], ignore_index=True, inplace=True)

df_te
# Out:
#       Year  Week   RK         Player Name POS  POS RK
# 0     2020     1   43       george kittle  TE       1
# 1     2020     1   48        travis kelce  TE       2
# 2     2020     1   70        mark andrews  TE       3
# 3     2020     1   76           zach ertz  TE       4
# 4     2020     1   87       darren waller  TE       5
# ...    ...   ...  ...                 ...  ..     ...
# 6738  2023    17  427     rodney williams  TE     100
# 6739  2023    17  439         hunter long  TE     101
# 6740  2023    17  446  albert okwuegbunam  TE     102
# 6741  2023    17  451         david wells  TE     103
# 6742  2023    17  465       brady russell  TE     104
#
# [6743 rows x 6 columns]

# %% [markdown]
# Filter to relevant players

# %%
df_teams = pd.read_parquet('../../data/fantasy_points/footballguys_half_ppr.parquet')[['Season', 'Week', 'Name', 'Team', 'Position']]

df_teams['Name'] = (
    df_teams['Name'].str.split().str[:2].str.join(' ')  # make names just the first two words
    .str.replace(r'[^a-zA-Z0-9\s]', '', regex=True)  # remove non-alphanumeric characters
    .str.lower()  # lowercase only (helps with matching)
)

df_teams = df_teams.loc[df_teams['Position'] == 'TE', :].reset_index(drop=True)

df_teams
# Out:
#       Season  Week             Name Team Position
# 0       2018     1       jared cook  OAK       TE
# 1       2018     1   rob gronkowski   NE       TE
# 2       2018     1      will dissly  SEA       TE
# 3       2018     1       eric ebron  IND       TE
# 4       2018     1      jordan reed  WAS       TE
# ...      ...   ...              ...  ...      ...
# 8806    2023    17      david wells   TB       TE
# 8807    2023    17  mitchell wilcox  CIN       TE
# 8808    2023    17   brayden willis   SF       TE
# 8809    2023    17  rodney williams  PIT       TE
# 8810    2023    17  charlie woerner   SF       TE
#
# [8811 rows x 5 columns]

# %%
df_te = df_te.merge(
    df_teams.rename(columns={'Season': 'Year', 'Name': 'Player Name', 'Position': 'POS'}),
    how='left',
    on=['Year', 'Week', 'Player Name', 'POS'],
)

df_te.loc[(df_te['Team'].isna()) & (df_te['POS RK'] <= 25), :]

# 2022 Week 17 Bills at Bengals was cancelled
# Out:
#       Year  Week   RK     Player Name POS  POS RK Team
# 2754  2021    12  156     taysom hill  TE      21  NaN
# 3042  2021    15  179   brevin jordan  TE      25  NaN
# 4986  2022    17  125     dawson knox  TE      12  NaN
# 5634  2023     6  175  dalton kincaid  TE      25  NaN

# %% [markdown]
# Fix players with difficult names

# %%
# df_teams.loc[df_teams['Name'] == 'will fuller', 'Name'] = 'william fuller'

# %%
df_te.loc[(df_te['Team'].isna()) & (df_te['POS RK'] <= 32*1), :].groupby(['Player Name'])['POS'].count().sort_values(ascending=False).head(10)
# Out:
# Player Name
# taysom hill       2
# brevin jordan     1
# dalton kincaid    1
# dawson knox       1
# john bates        1
# juwan johnson     1
# Name: POS, dtype: int64

# %%
df_te = df_te.loc[df_te['Team'].notna(), :].reset_index(drop=True)

df_te
# Out:
#       Year  Week   RK      Player Name POS  POS RK Team
# 0     2020     1   43    george kittle  TE       1   SF
# 1     2020     1   48     travis kelce  TE       2   KC
# 2     2020     1   70     mark andrews  TE       3  BAL
# 3     2020     1   76        zach ertz  TE       4  PHI
# 4     2020     1   87    darren waller  TE       5   LV
# ...    ...   ...  ...              ...  ..     ...  ...
# 5923  2023    17  397       matt sokol  TE      92   NE
# 5924  2023    17  408   travis vokolek  TE      96  ARI
# 5925  2023    17  425   brayden willis  TE      99   SF
# 5926  2023    17  427  rodney williams  TE     100  PIT
# 5927  2023    17  451      david wells  TE     103   TB
#
# [5928 rows x 7 columns]

# %%
df_te = df_te.groupby(['Year', 'Week', 'Team']).nth(0).reset_index(drop=True)

df_te
# Out:
#       Year  Week   RK    Player Name POS  POS RK Team
# 0     2020     1   43  george kittle  TE       1   SF
# 1     2020     1   48   travis kelce  TE       2   KC
# 2     2020     1   70   mark andrews  TE       3  BAL
# 3     2020     1   76      zach ertz  TE       4  PHI
# 4     2020     1   87  darren waller  TE       5   LV
# ...    ...   ...  ...            ...  ..     ...  ...
# 2010  2023    17  197   mike gesicki  TE      31   NE
# 2011  2023    17  200    josh oliver  TE      32  MIN
# 2012  2023    17  217  austin hooper  TE      34   LV
# 2013  2023    17  225  adam trautman  TE      35  DEN
# 2014  2023    17  226  tommy tremble  TE      36  CAR
#
# [2015 rows x 7 columns]

# %%
df_te['Player Name URL'] = df_te['Player Name'].str.replace(' ', '-')

# fix players who are known to have issues
df_te.loc[df_te['Player Name'] == 'chris herndon', 'Player Name URL'] = 'chris-herndon-iv'
df_te.loc[df_te['Player Name'] == 'irv smith', 'Player Name URL'] = 'irv-smith-jr'
df_te.loc[df_te['Player Name'] == 'drew ogletree', 'Player Name URL'] = 'andrew-ogletree'
df_te.loc[df_te['Player Name'] == 'mo aliecox', 'Player Name URL'] = 'mo-alie-cox'
df_te.loc[df_te['Player Name'] == 'ricky sealsjones', 'Player Name URL'] = 'ricky-seals-jones'
df_te.loc[df_te['Player Name'] == 'dalton keene', 'Player Name URL'] = 'dalton-keene-te'

df_te
# Out:
#       Year  Week   RK    Player Name POS  POS RK Team Player Name URL
# 0     2020     1   43  george kittle  TE       1   SF   george-kittle
# 1     2020     1   48   travis kelce  TE       2   KC    travis-kelce
# 2     2020     1   70   mark andrews  TE       3  BAL    mark-andrews
# 3     2020     1   76      zach ertz  TE       4  PHI       zach-ertz
# 4     2020     1   87  darren waller  TE       5   LV   darren-waller
# ...    ...   ...  ...            ...  ..     ...  ...             ...
# 2010  2023    17  197   mike gesicki  TE      31   NE    mike-gesicki
# 2011  2023    17  200    josh oliver  TE      32  MIN     josh-oliver
# 2012  2023    17  217  austin hooper  TE      34   LV   austin-hooper
# 2013  2023    17  225  adam trautman  TE      35  DEN   adam-trautman
# 2014  2023    17  226  tommy tremble  TE      36  CAR   tommy-tremble
#
# [2015 rows x 8 columns]

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

options = Options()
# options.add_argument('--headless')

driver = webdriver.Chrome(options=options)

# %%
import time
from selenium.webdriver.common.by import By

def scrape_props(player_name, player_name_url, year, week, team):
    driver.get(url=f"https://www.bettingpros.com/nfl/odds/player-props/{player_name_url}/?season={year}&week={week}")
    time.sleep(5)

    # the page uses lazy loading
    # this loop helps all relevant elements load before scraping
    for _ in range(3):
        # find all loaded rows
        rows = driver.find_elements(
            by=By.CLASS_NAME,
            value="grouped-items-with-sticky-footer__content",
        )

        # scroll to the last loaded row, which should load subsequent rows if there are any
        if len(rows) > 0:
            driver.execute_script(f"window.scrollTo(0, {rows[-1].location['y']});")

        time.sleep(3)

    rows = driver.find_elements(
        by=By.CLASS_NAME,
        value="grouped-items-with-sticky-footer__content",
    )

    if len(rows) == 0:
        print(f"Warning: No rows for {player_name} {year} week {week}")
        
    data = {
        'Year': year,
        'Week': week,
        'Player Name': player_name,
        'Team': team,
    }
    for row in rows:
        t = row.text.split('\n')
        if t[0] == 'Receiving Yards Over/Under':
            data['Receiving Yards Projection'] = t[-4]
            data['Receiving Yards Over'] = t[-3]
            data['Receiving Yards Under'] = t[-1]
        elif t[0] == 'Receptions Over/Under':
            data['Receptions Projection'] = t[-4]
            data['Receptions Over'] = t[-3]
            data['Receptions Under'] = t[-1]
        elif t[0] == 'Anytime Touchdown Scorer':
            data['Anytime Touchdown Line'] = t[-1]

    return data

# %%
from tqdm.autonotebook import tqdm

d = []
for index, row in tqdm(list(df_te.iterrows())):
    try:
        d.append(scrape_props(row['Player Name'], row['Player Name URL'], row['Year'], row['Week'], row['Team']))
    except Exception as e:
        print(f"Error with {row['Player Name'], row['Player Name URL'], row['Year'], row['Week'], row['Team']}: {e}")
# Out:
# C:\Users\mhugh\AppData\Local\Temp\ipykernel_18816\2403495275.py:1: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm
#   0%|          | 0/2015 [00:00<?, ?it/s]
# Warning: No rows for devin asiasi 2020 week 1
# Warning: No rows for gerald everett 2023 week 10

# %%
driver.quit()

# %%
d
# Out:
# [{'Year': 2020,
#   'Week': 1,
#   'Player Name': 'george kittle',
#   'Team': 'SF',
#   'Anytime Touchdown Line': 'EVEN',
#   'Receiving Yards Projection': 'O 71.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 6.5',
#   'Receptions Over': '(+102)',
#   'Receptions Under': '(-130)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'travis kelce',
#   'Team': 'KC',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(-142)',
#   'Receptions Under': '(+112)',
#   'Anytime Touchdown Line': '-120',
#   'Receiving Yards Projection': 'O 69.5',
#   'Receiving Yards Over': '(-122)',
#   'Receiving Yards Under': '(EVEN)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'mark andrews',
#   'Team': 'BAL',
#   'Receiving Yards Projection': 'O 48.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+115)',
#   'Receptions Under': '(-145)',
#   'Anytime Touchdown Line': '+138'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'zach ertz',
#   'Team': 'PHI',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(-104)',
#   'Receptions Under': '(-145)',
#   'Receiving Yards Projection': 'O 54.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+163'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'darren waller',
#   'Team': 'LV',
#   'Anytime Touchdown Line': '+138',
#   'Receiving Yards Projection': 'O 52.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-130)',
#   'Receptions Under': '(+110)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'hunter henry',
#   'Team': 'LAC',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+120)',
#   'Receptions Under': '(-140)',
#   'Receiving Yards Projection': 'O 45.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+163'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'tyler higbee',
#   'Team': 'LAR',
#   'Receiving Yards Projection': 'O 48.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-150)',
#   'Receptions Under': '(+128)',
#   'Anytime Touchdown Line': '+333'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'hayden hurst',
#   'Team': 'ATL',
#   'Anytime Touchdown Line': '+200',
#   'Receiving Yards Projection': 'O 38.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-105)',
#   'Receptions Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'evan engram',
#   'Team': 'NYG',
#   'Receiving Yards Projection': 'O 48.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-122)',
#   'Anytime Touchdown Line': '+225',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-120)',
#   'Receptions Under': '(EVEN)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'jared cook',
#   'Team': 'NO',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+116)',
#   'Receptions Under': '(-148)',
#   'Receiving Yards Projection': 'O 40.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+200'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'rob gronkowski',
#   'Team': 'TB',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-160)',
#   'Receptions Under': '(+140)',
#   'Anytime Touchdown Line': '+220',
#   'Receiving Yards Projection': 'O 31.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'noah fant',
#   'Team': 'DEN',
#   'Receiving Yards Projection': 'O 40.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+225',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-152)',
#   'Receptions Under': '(+120)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'tj hockenson',
#   'Team': 'DET',
#   'Anytime Touchdown Line': '+240',
#   'Receiving Yards Projection': 'O 39.5',
#   'Receiving Yards Over': '(EVEN)',
#   'Receiving Yards Under': '(-122)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'jonnu smith',
#   'Team': 'TEN',
#   'Anytime Touchdown Line': '+290',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-176)',
#   'Receptions Under': '(+138)',
#   'Receiving Yards Projection': 'O 29.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'blake jarwin',
#   'Team': 'DAL',
#   'Receiving Yards Projection': 'O 36.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-110)',
#   'Receptions Under': '(-130)',
#   'Anytime Touchdown Line': '+330'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'austin hooper',
#   'Team': 'CLE',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-160)',
#   'Receptions Under': '(+130)',
#   'Receiving Yards Projection': 'O 32.5',
#   'Receiving Yards Over': '(-120)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+350'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'mike gesicki',
#   'Team': 'MIA',
#   'Anytime Touchdown Line': '+400'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'jack doyle',
#   'Team': 'IND',
#   'Anytime Touchdown Line': '+200',
#   'Receiving Yards Projection': 'O 32.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+130)',
#   'Receptions Under': '(-150)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'eric ebron',
#   'Team': 'PIT',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(+145)',
#   'Receptions Under': '(-170)',
#   'Receiving Yards Projection': 'O 28.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+225'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'chris herndon',
#   'Team': 'NYJ',
#   'Receiving Yards Projection': 'O 36.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-120)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+110)',
#   'Receptions Under': '(-140)',
#   'Anytime Touchdown Line': '+333'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'ian thomas',
#   'Team': 'CAR',
#   'Anytime Touchdown Line': '+400'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'greg olsen',
#   'Team': 'SEA',
#   'Anytime Touchdown Line': '+225'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'irv smith',
#   'Team': 'MIN',
#   'Anytime Touchdown Line': '+320'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'tyler eifert',
#   'Team': 'JAX',
#   'Receiving Yards Projection': 'O 22.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+410',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(+145)',
#   'Receptions Under': '(-170)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'dawson knox',
#   'Team': 'BUF',
#   'Anytime Touchdown Line': '+400'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'jimmy graham',
#   'Team': 'CHI',
#   'Anytime Touchdown Line': '+300'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'darren fells',
#   'Team': 'HOU',
#   'Anytime Touchdown Line': '+350',
#   'Receiving Yards Projection': 'O 19.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(+144)',
#   'Receptions Under': '(-182)'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'cj uzomah',
#   'Team': 'CIN',
#   'Anytime Touchdown Line': '+400'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'jace sternberger',
#   'Team': 'GB',
#   'Anytime Touchdown Line': '+1500'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'logan thomas',
#   'Team': 'WAS',
#   'Anytime Touchdown Line': '+500'},
#  {'Year': 2020, 'Week': 1, 'Player Name': 'devin asiasi', 'Team': 'NE'},
#  {'Year': 2020,
#   'Week': 1,
#   'Player Name': 'dan arnold',
#   'Team': 'ARI',
#   'Anytime Touchdown Line': '+700',
#   'Receiving Yards Projection': 'O 24.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'travis kelce',
#   'Team': 'KC',
#   'Anytime Touchdown Line': '+110',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(-134)',
#   'Receptions Under': '(-110)',
#   'Receiving Yards Projection': 'O 63.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'mark andrews',
#   'Team': 'BAL',
#   'Receiving Yards Projection': 'O 57.5',
#   'Receiving Yards Over': '(-130)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+120',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-118)',
#   'Receptions Under': '(-140)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'zach ertz',
#   'Team': 'PHI',
#   'Anytime Touchdown Line': '+188',
#   'Receiving Yards Projection': 'O 46.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-164)',
#   'Receptions Under': '(-160)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'darren waller',
#   'Team': 'LV',
#   'Anytime Touchdown Line': '+163',
#   'Receiving Yards Projection': 'O 53.5',
#   'Receiving Yards Over': '(-111)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-146)',
#   'Receptions Under': '(+114)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'jared cook',
#   'Team': 'NO',
#   'Anytime Touchdown Line': '+163',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+102)',
#   'Receptions Under': '(-130)',
#   'Receiving Yards Projection': 'O 56.5',
#   'Receiving Yards Over': '(-111)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'hunter henry',
#   'Team': 'LAC',
#   'Receiving Yards Projection': 'O 49.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+250',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+122)',
#   'Receptions Under': '(-154)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'tyler higbee',
#   'Team': 'LAR',
#   'Anytime Touchdown Line': '+220',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-135)',
#   'Receptions Under': '(+112)',
#   'Receiving Yards Projection': 'O 50.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-122)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'hayden hurst',
#   'Team': 'ATL',
#   'Anytime Touchdown Line': '+230',
#   'Receiving Yards Projection': 'O 40.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-110)',
#   'Receptions Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'jonnu smith',
#   'Team': 'TEN',
#   'Receiving Yards Projection': 'O 37.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-126)',
#   'Receptions Under': '(EVEN)',
#   'Anytime Touchdown Line': '+188'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'tj hockenson',
#   'Team': 'DET',
#   'Receptions Projection': '--',
#   'Receptions Over': '--',
#   'Receptions Under': '--',
#   'Anytime Touchdown Line': '--',
#   'Receiving Yards Projection': '--',
#   'Receiving Yards Over': '--',
#   'Receiving Yards Under': '--'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'evan engram',
#   'Team': 'NYG',
#   'Receiving Yards Projection': 'O 43.5',
#   'Receiving Yards Over': '(EVEN)',
#   'Receiving Yards Under': '(-122)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-152)',
#   'Receptions Under': '(+120)',
#   'Anytime Touchdown Line': '+275'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'noah fant',
#   'Team': 'DEN',
#   'Anytime Touchdown Line': '--',
#   'Receptions Projection': '--',
#   'Receptions Over': '--',
#   'Receptions Under': '--',
#   'Receiving Yards Projection': '--',
#   'Receiving Yards Over': '--',
#   'Receiving Yards Under': '--'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'chris herndon',
#   'Team': 'NYJ',
#   'Receiving Yards Projection': 'O 45.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+112)',
#   'Receptions Under': '(-145)',
#   'Anytime Touchdown Line': '+250'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'austin hooper',
#   'Team': 'CLE',
#   'Anytime Touchdown Line': '+200',
#   'Receiving Yards Projection': 'O 36.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+125)',
#   'Receptions Under': '(-180)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'mike gesicki',
#   'Team': 'MIA',
#   'Anytime Touchdown Line': '+333',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+112)',
#   'Receptions Under': '(-142)',
#   'Receiving Yards Projection': 'O 32.5',
#   'Receiving Yards Over': '(-105)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'logan thomas',
#   'Team': 'WAS',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+140)',
#   'Receptions Under': '(-160)',
#   'Anytime Touchdown Line': '+280',
#   'Receiving Yards Projection': 'O 35.5',
#   'Receiving Yards Over': '(-125)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'oj howard',
#   'Team': 'TB',
#   'Receiving Yards Projection': 'O 27.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+275'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'eric ebron',
#   'Team': 'PIT',
#   'Receiving Yards Projection': 'O 23.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-110)',
#   'Receptions Under': '(-124)',
#   'Anytime Touchdown Line': '+250'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'greg olsen',
#   'Team': 'SEA',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-172)',
#   'Receptions Under': '(+130)',
#   'Anytime Touchdown Line': '+250',
#   'Receiving Yards Projection': 'O 29.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'jimmy graham',
#   'Team': 'CHI',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(+108)',
#   'Receptions Under': '(-136)',
#   'Anytime Touchdown Line': '+225',
#   'Receiving Yards Projection': 'O 25.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'ian thomas',
#   'Team': 'CAR',
#   'Anytime Touchdown Line': '+450',
#   'Receiving Yards Projection': 'O 21.5',
#   'Receiving Yards Over': '(EVEN)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(+125)',
#   'Receptions Under': '(-145)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'irv smith',
#   'Team': 'MIN',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(+140)',
#   'Receptions Under': '(-180)',
#   'Anytime Touchdown Line': '+350',
#   'Receiving Yards Projection': 'O 21.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'cj uzomah',
#   'Team': 'CIN',
#   'Anytime Touchdown Line': '+430',
#   'Receiving Yards Projection': 'O 24.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-112)',
#   'Receptions Under': '(-112)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'dawson knox',
#   'Team': 'BUF',
#   'Anytime Touchdown Line': '+400',
#   'Receiving Yards Projection': 'O 19.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(+145)',
#   'Receptions Under': '(-170)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'jordan akins',
#   'Team': 'HOU',
#   'Anytime Touchdown Line': '+500'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'tyler eifert',
#   'Team': 'JAX',
#   'Anytime Touchdown Line': '+440'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'jordan reed',
#   'Team': 'SF',
#   'Anytime Touchdown Line': '+210'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'dan arnold',
#   'Team': 'ARI',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-110)',
#   'Receptions Under': '(-110)',
#   'Receiving Yards Projection': 'O 26.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+320'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'mo aliecox',
#   'Team': 'IND',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(EVEN)',
#   'Receptions Under': '(-172)',
#   'Anytime Touchdown Line': '+250',
#   'Receiving Yards Projection': 'O 24.5',
#   'Receiving Yards Over': '(-105)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'dalton schultz',
#   'Team': 'DAL',
#   'Anytime Touchdown Line': '+333'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'jace sternberger',
#   'Team': 'GB',
#   'Anytime Touchdown Line': '+700'},
#  {'Year': 2020,
#   'Week': 2,
#   'Player Name': 'devin asiasi',
#   'Team': 'NE',
#   'Anytime Touchdown Line': '+1000'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'travis kelce',
#   'Team': 'KC',
#   'Receiving Yards Projection': 'O 71.5',
#   'Receiving Yards Over': '(-111)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+105',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(-180)',
#   'Receptions Under': '(+150)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'mark andrews',
#   'Team': 'BAL',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-106)',
#   'Receptions Under': '(-120)',
#   'Anytime Touchdown Line': '+105',
#   'Receiving Yards Projection': 'O 52.5',
#   'Receiving Yards Over': '(-111)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'zach ertz',
#   'Team': 'PHI',
#   'Receiving Yards Projection': 'O 46.5',
#   'Receiving Yards Over': '(-111)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+125)',
#   'Receptions Under': '(-149)',
#   'Anytime Touchdown Line': '+137'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'darren waller',
#   'Team': 'LV',
#   'Receiving Yards Projection': 'O 51.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-105)',
#   'Anytime Touchdown Line': '+162',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(+132)',
#   'Receptions Under': '(-170)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'hunter henry',
#   'Team': 'LAC',
#   'Receiving Yards Projection': 'O 50.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-111)',
#   'Anytime Touchdown Line': '+140',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+124)',
#   'Receptions Under': '(-154)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'tyler higbee',
#   'Team': 'LAR',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-128)',
#   'Receptions Under': '(+105)',
#   'Receiving Yards Projection': 'O 51.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-111)',
#   'Anytime Touchdown Line': '+187'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'mike gesicki',
#   'Team': 'MIA',
#   'Receiving Yards Projection': 'O 55.5',
#   'Receiving Yards Over': '(-130)',
#   'Receiving Yards Under': '(+110)',
#   'Anytime Touchdown Line': '+145',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-115)',
#   'Receptions Under': '(-105)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'jonnu smith',
#   'Team': 'TEN',
#   'Receiving Yards Projection': 'O 42.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+145',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-143)',
#   'Receptions Under': '(+120)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'jared cook',
#   'Team': 'NO',
#   'Anytime Touchdown Line': '+130',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-125)',
#   'Receptions Under': '(-105)',
#   'Receiving Yards Projection': 'O 48.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'hayden hurst',
#   'Team': 'ATL',
#   'Anytime Touchdown Line': '+190',
#   'Receiving Yards Projection': 'O 48.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'tj hockenson',
#   'Team': 'DET',
#   'Receiving Yards Projection': 'O 40.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-111)',
#   'Anytime Touchdown Line': '+200',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-149)',
#   'Receptions Under': '(+120)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'noah fant',
#   'Team': 'DEN',
#   'Anytime Touchdown Line': '+160',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-146)',
#   'Receptions Under': '(+114)',
#   'Receiving Yards Projection': 'O 42.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-111)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'evan engram',
#   'Team': 'NYG',
#   'Anytime Touchdown Line': '+190',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-128)',
#   'Receptions Under': '(EVEN)',
#   'Receiving Yards Projection': 'O 45.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'logan thomas',
#   'Team': 'WAS',
#   'Anytime Touchdown Line': '+290',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-125)',
#   'Receptions Under': '(+105)',
#   'Receiving Yards Projection': 'O 37.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'jordan reed',
#   'Team': 'SF',
#   'Anytime Touchdown Line': '+190',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-136)',
#   'Receptions Under': '(EVEN)',
#   'Receiving Yards Projection': 'O 48.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'dalton schultz',
#   'Team': 'DAL',
#   'Receiving Yards Projection': 'O 32.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-115)',
#   'Receptions Under': '(-115)',
#   'Anytime Touchdown Line': '+333'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'austin hooper',
#   'Team': 'CLE',
#   'Anytime Touchdown Line': '+200',
#   'Receiving Yards Projection': 'O 33.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-160)',
#   'Receptions Under': '(-184)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'chris herndon',
#   'Team': 'NYJ',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-136)',
#   'Receptions Under': '(+106)',
#   'Receiving Yards Projection': 'O 42.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+260'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'drew sample',
#   'Team': 'CIN',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-135)',
#   'Receptions Under': '(+105)',
#   'Receiving Yards Projection': 'O 31.5',
#   'Receiving Yards Over': '(-111)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+330'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'eric ebron',
#   'Team': 'PIT',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+110)',
#   'Receptions Under': '(-139)',
#   'Anytime Touchdown Line': '+240',
#   'Receiving Yards Projection': 'O 33.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-111)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'tyler eifert',
#   'Team': 'JAX',
#   'Receiving Yards Projection': 'O 28.0',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-111)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-111)',
#   'Receptions Under': '(-110)',
#   'Anytime Touchdown Line': '+270'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'mo aliecox',
#   'Team': 'IND',
#   'Anytime Touchdown Line': '+180'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'oj howard',
#   'Team': 'TB',
#   'Anytime Touchdown Line': '+280',
#   'Receiving Yards Projection': 'O 19.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'jordan akins',
#   'Team': 'HOU',
#   'Anytime Touchdown Line': '+333',
#   'Receiving Yards Projection': 'O 25.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-111)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-120)',
#   'Receptions Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'greg olsen',
#   'Team': 'SEA',
#   'Anytime Touchdown Line': '+240'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'jimmy graham',
#   'Team': 'CHI',
#   'Anytime Touchdown Line': '+240'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'dan arnold',
#   'Team': 'ARI',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-188)',
#   'Receptions Under': '(+130)',
#   'Anytime Touchdown Line': '+200',
#   'Receiving Yards Projection': 'O 29.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'irv smith',
#   'Team': 'MIN',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-105)',
#   'Receptions Under': '(-125)',
#   'Receiving Yards Projection': 'O 23.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+380'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'ian thomas',
#   'Team': 'CAR',
#   'Anytime Touchdown Line': '+320',
#   'Receiving Yards Projection': 'O 20.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-120)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(+150)',
#   'Receptions Under': '(-180)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'robert tonyan',
#   'Team': 'GB',
#   'Anytime Touchdown Line': '+310',
#   'Receiving Yards Projection': 'O 23.5',
#   'Receiving Yards Over': '(-130)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-104)',
#   'Receptions Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'ryan izzo',
#   'Team': 'NE',
#   'Anytime Touchdown Line': '+750'},
#  {'Year': 2020,
#   'Week': 3,
#   'Player Name': 'tyler kroft',
#   'Team': 'BUF',
#   'Anytime Touchdown Line': '+410'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'travis kelce',
#   'Team': 'KC',
#   'Anytime Touchdown Line': '-125',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(-128)',
#   'Receptions Under': '(+105)',
#   'Receiving Yards Projection': 'O 65.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'zach ertz',
#   'Team': 'PHI',
#   'Receiving Yards Projection': 'O 57.5',
#   'Receiving Yards Over': '(-111)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(+110)',
#   'Receptions Under': '(-140)',
#   'Anytime Touchdown Line': '+200'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'mark andrews',
#   'Team': 'BAL',
#   'Anytime Touchdown Line': '+110',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-154)',
#   'Receptions Under': '(+125)',
#   'Receiving Yards Projection': 'O 47.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'george kittle',
#   'Team': 'SF',
#   'Receiving Yards Projection': 'O 52.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-105)',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-115)',
#   'Receptions Under': '(-110)',
#   'Anytime Touchdown Line': '+115'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'darren waller',
#   'Team': 'LV',
#   'Receiving Yards Projection': 'O 56.5',
#   'Receiving Yards Over': '(-111)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(-120)',
#   'Receptions Under': '(-110)',
#   'Anytime Touchdown Line': '+130'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'mike gesicki',
#   'Team': 'MIA',
#   'Receiving Yards Projection': 'O 47.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-111)',
#   'Anytime Touchdown Line': '+155',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-133)',
#   'Receptions Under': '(+105)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'hunter henry',
#   'Team': 'LAC',
#   'Receiving Yards Projection': 'O 49.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-120)',
#   'Anytime Touchdown Line': '+225',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-113)',
#   'Receptions Under': '(-145)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'tj hockenson',
#   'Team': 'DET',
#   'Anytime Touchdown Line': '+225',
#   'Receiving Yards Projection': 'O 41.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-154)',
#   'Receptions Under': '(+125)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'tyler higbee',
#   'Team': 'LAR',
#   'Anytime Touchdown Line': '+163',
#   'Receiving Yards Projection': 'O 43.5',
#   'Receiving Yards Over': '(-111)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+130)',
#   'Receptions Under': '(-163)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'noah fant',
#   'Team': 'DEN',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-125)',
#   'Receptions Under': '(-105)',
#   'Anytime Touchdown Line': '+150',
#   'Receiving Yards Projection': 'O 51.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-111)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'hayden hurst',
#   'Team': 'ATL',
#   'Receiving Yards Projection': 'O 40.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-111)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(EVEN)',
#   'Receptions Under': '(-125)',
#   'Anytime Touchdown Line': '+185'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'evan engram',
#   'Team': 'NYG',
#   'Anytime Touchdown Line': '+300',
#   'Receiving Yards Projection': 'O 42.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-111)',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(EVEN)',
#   'Receptions Under': '(-130)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'dalton schultz',
#   'Team': 'DAL',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(EVEN)',
#   'Receptions Under': '(-130)',
#   'Receiving Yards Projection': 'O 34.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+290'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'logan thomas',
#   'Team': 'WAS',
#   'Anytime Touchdown Line': '+300',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+118)',
#   'Receptions Under': '(-150)',
#   'Receiving Yards Projection': 'O 32.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'austin hooper',
#   'Team': 'CLE',
#   'Receiving Yards Projection': 'O 33.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+220',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-110)',
#   'Receptions Under': '(-130)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'jimmy graham',
#   'Team': 'CHI',
#   'Receiving Yards Projection': 'O 27.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+220',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-145)',
#   'Receptions Under': '(+115)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'chris herndon',
#   'Team': 'NYJ',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+130)',
#   'Receptions Under': '(-154)',
#   'Receiving Yards Projection': 'O 32.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+230'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'jordan akins',
#   'Team': 'HOU',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-170)',
#   'Receptions Under': '(+140)',
#   'Anytime Touchdown Line': '+350',
#   'Receiving Yards Projection': 'O 28.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'robert tonyan',
#   'Team': 'GB',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-125)',
#   'Receptions Under': '(-105)',
#   'Receiving Yards Projection': 'O 39.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+160'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'mo aliecox',
#   'Team': 'IND',
#   'Anytime Touchdown Line': '+225',
#   'Receiving Yards Projection': 'O 25.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-120)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-106)',
#   'Receptions Under': '(-120)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'rob gronkowski',
#   'Team': 'TB',
#   'Receiving Yards Projection': 'O 28.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+230'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'drew sample',
#   'Team': 'CIN',
#   'Anytime Touchdown Line': '+440',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-120)',
#   'Receptions Under': '(-106)',
#   'Receiving Yards Projection': 'O 23.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'greg olsen',
#   'Team': 'SEA',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-120)',
#   'Receptions Under': '(-106)',
#   'Receiving Yards Projection': 'O 26.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+250'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'tyler eifert',
#   'Team': 'JAX',
#   'Receiving Yards Projection': 'O 28.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+350',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(EVEN)',
#   'Receptions Under': '(-125)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'adam trautman',
#   'Team': 'NO',
#   'Anytime Touchdown Line': '+400'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'dan arnold',
#   'Team': 'ARI',
#   'Anytime Touchdown Line': '+275'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'kyle rudolph',
#   'Team': 'MIN',
#   'Anytime Touchdown Line': '+310',
#   'Receiving Yards Projection': 'O 21.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(+140)',
#   'Receptions Under': '(-170)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'dawson knox',
#   'Team': 'BUF',
#   'Anytime Touchdown Line': '+450',
#   'Receiving Yards Projection': 'O 22.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'ian thomas',
#   'Team': 'CAR',
#   'Anytime Touchdown Line': '+380'},
#  {'Year': 2020,
#   'Week': 4,
#   'Player Name': 'ryan izzo',
#   'Team': 'NE',
#   'Receiving Yards Projection': 'O 12.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+700'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'george kittle',
#   'Team': 'SF',
#   'Anytime Touchdown Line': '-110',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(+115)',
#   'Receptions Under': '(-145)',
#   'Receiving Yards Projection': 'O 71.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'travis kelce',
#   'Team': 'KC',
#   'Receiving Yards Projection': 'O 70.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '-145',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(-135)',
#   'Receptions Under': '(+105)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'mark andrews',
#   'Team': 'BAL',
#   'Anytime Touchdown Line': 'EVEN',
#   'Receiving Yards Projection': 'O 52.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(EVEN)',
#   'Receptions Under': '(-130)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'darren waller',
#   'Team': 'LV',
#   'Anytime Touchdown Line': '+170',
#   'Receiving Yards Projection': 'O 59.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(-146)',
#   'Receptions Under': '(+114)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'hunter henry',
#   'Team': 'LAC',
#   'Receiving Yards Projection': 'O 53.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-113)',
#   'Anytime Touchdown Line': '+200',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-104)',
#   'Receptions Under': '(-122)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'zach ertz',
#   'Team': 'PHI',
#   'Receiving Yards Projection': 'O 50.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-154)',
#   'Receptions Under': '(+115)',
#   'Anytime Touchdown Line': '+225'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'evan engram',
#   'Team': 'NYG',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-136)',
#   'Receptions Under': '(+105)',
#   'Receiving Yards Projection': 'O 47.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+210'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'dalton schultz',
#   'Team': 'DAL',
#   'Receiving Yards Projection': 'O 34.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+110)',
#   'Receptions Under': '(-147)',
#   'Anytime Touchdown Line': '+225'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'jonnu smith',
#   'Team': 'TEN',
#   'Anytime Touchdown Line': '+138',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(-105)',
#   'Receptions Under': '(-125)',
#   'Receiving Yards Projection': 'O 56.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'tyler higbee',
#   'Team': 'LAR',
#   'Receiving Yards Projection': 'O 37.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+115)',
#   'Receptions Under': '(-145)',
#   'Anytime Touchdown Line': '+200'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'hayden hurst',
#   'Team': 'ATL',
#   'Receiving Yards Projection': 'O 40.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+163'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'mike gesicki',
#   'Team': 'MIA',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+124)',
#   'Receptions Under': '(-160)',
#   'Anytime Touchdown Line': '+225',
#   'Receiving Yards Projection': 'O 35.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'eric ebron',
#   'Team': 'PIT',
#   'Receiving Yards Projection': 'O 38.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+175',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+108)',
#   'Receptions Under': '(-138)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'rob gronkowski',
#   'Team': 'TB',
#   'Anytime Touchdown Line': '+188',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-105)',
#   'Receptions Under': '(-125)',
#   'Receiving Yards Projection': 'O 35.5',
#   'Receiving Yards Over': '(-120)',
#   'Receiving Yards Under': '(-111)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'jimmy graham',
#   'Team': 'CHI',
#   'Anytime Touchdown Line': '+250',
#   'Receiving Yards Projection': 'O 28.5',
#   'Receiving Yards Over': '(EVEN)',
#   'Receiving Yards Under': '(-122)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+130)',
#   'Receptions Under': '(-164)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'greg olsen',
#   'Team': 'SEA',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+114)',
#   'Receptions Under': '(-146)',
#   'Receiving Yards Projection': 'O 36.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+175'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'austin hooper',
#   'Team': 'CLE',
#   'Anytime Touchdown Line': '+230',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-174)',
#   'Receptions Under': '(+115)',
#   'Receiving Yards Projection': 'O 30.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'logan thomas',
#   'Team': 'WAS',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+102)',
#   'Receptions Under': '(-130)',
#   'Receiving Yards Projection': 'O 28.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+280'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'drew sample',
#   'Team': 'CIN',
#   'Anytime Touchdown Line': '+550',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-160)',
#   'Receptions Under': '(+130)',
#   'Receiving Yards Projection': 'O 27.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-120)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'chris herndon',
#   'Team': 'NYJ',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-140)',
#   'Receptions Under': '(+110)',
#   'Anytime Touchdown Line': '+230',
#   'Receiving Yards Projection': 'O 28.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'darren fells',
#   'Team': 'HOU',
#   'Anytime Touchdown Line': '+160'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'ian thomas',
#   'Team': 'CAR',
#   'Receiving Yards Projection': 'O 20.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+250'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'mo aliecox',
#   'Team': 'IND',
#   'Anytime Touchdown Line': '+230',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(+102)',
#   'Receptions Under': '(-130)',
#   'Receiving Yards Projection': 'O 13.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-114)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'tyler eifert',
#   'Team': 'JAX',
#   'Anytime Touchdown Line': '+350',
#   'Receiving Yards Projection': 'O 26.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(+105)',
#   'Receptions Under': '(-143)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'taysom hill',
#   'Team': 'NO',
#   'Anytime Touchdown Line': '+400'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'kyle rudolph',
#   'Team': 'MIN',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(+120)',
#   'Receptions Under': '(-200)',
#   'Receiving Yards Projection': 'O 20.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+350'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'dawson knox',
#   'Team': 'BUF',
#   'Receiving Yards Projection': 'O 21.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+400',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(+150)',
#   'Receptions Under': '(-196)'},
#  {'Year': 2020,
#   'Week': 5,
#   'Player Name': 'dan arnold',
#   'Team': 'ARI',
#   'Anytime Touchdown Line': '+350'},
#  {'Year': 2020,
#   'Week': 6,
#   'Player Name': 'travis kelce',
#   'Team': 'KC',
#   'Anytime Touchdown Line': '-145',
#   'Receiving Yards Projection': 'O 77.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 6.5',
#   'Receptions Over': '(+102)',
#   'Receptions Under': '(-130)'},
#  {'Year': 2020,
#   'Week': 6,
#   'Player Name': 'george kittle',
#   'Team': 'SF',
#   'Receiving Yards Projection': 'O 70.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+125',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(-135)',
#   'Receptions Under': '(+105)'},
#  {'Year': 2020,
#   'Week': 6,
#   'Player Name': 'mark andrews',
#   'Team': 'BAL',
#   'Receiving Yards Projection': 'O 56.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+110',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-113)',
#   'Receptions Under': '(-113)'},
#  {'Year': 2020,
#   'Week': 6,
#   'Player Name': 'jonnu smith',
#   'Team': 'TEN',
#   'Receiving Yards Projection': 'O 43.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+105',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+154)',
#   'Receptions Under': '(-200)'},
#  {'Year': 2020,
#   'Week': 6,
#   'Player Name': 'tj hockenson',
#   'Team': 'DET',
#   'Receiving Yards Projection': 'O 43.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+170',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+120)',
#   'Receptions Under': '(-200)'},
#  {'Year': 2020,
#   'Week': 6,
#   'Player Name': 'zach ertz',
#   'Team': 'PHI',
#   'Receiving Yards Projection': 'O 46.5',
#   'Receiving Yards Over': '(-105)',
#   'Receiving Yards Under': '(-125)',
#   'Anytime Touchdown Line': '+137',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+115)',
#   'Receptions Under': '(-154)'},
#  {'Year': 2020,
#   'Week': 6,
#   'Player Name': 'evan engram',
#   'Team': 'NYG',
#   'Anytime Touchdown Line': '+125',
#   'Receiving Yards Projection': 'O 36.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-143)',
#   'Receptions Under': '(+105)'},
#  {'Year': 2020,
#   'Week': 6,
#   'Player Name': 'mike gesicki',
#   'Team': 'MIA',
#   'Anytime Touchdown Line': '+137',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-118)',
#   'Receptions Under': '(-108)',
#   'Receiving Yards Projection': 'O 40.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2020,
#   'Week': 6,
#   'Player Name': 'eric ebron',
#   'Team': 'PIT',
#   'Receiving Yards Projection': 'O 38.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+175',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+114)',
#   'Receptions Under': '(-146)'},
#  {'Year': 2020,
#   'Week': 6,
#   'Player Name': 'robert tonyan',
#   'Team': 'GB',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-120)',
#   'Receptions Under': '(-106)',
#   'Receiving Yards Projection': 'O 43.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+155'},
#  {'Year': 2020,
#   'Week': 6,
#   'Player Name': 'dalton schultz',
#   'Team': 'DAL',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+124)',
#   'Receptions Under': '(-158)',
#   'Receiving Yards Projection': 'O 30.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+225'},
#  {'Year': 2020,
#   'Week': 6,
#   'Player Name': 'hayden hurst',
#   'Team': 'ATL',
#   'Receiving Yards Projection': 'O 38.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-106)',
#   'Receptions Under': '(-125)',
#   'Anytime Touchdown Line': '+170'},
#  {'Year': 2020,
#   'Week': 6,
#   'Player Name': 'austin hooper',
#   'Team': 'CLE',
#   'Anytime Touchdown Line': '+240',
#   'Receiving Yards Projection': 'O 33.5',
#   'Receiving Yards Over': '(-115)',
# ...
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'tyler conklin',
#   'Team': 'MIN',
#   'Anytime Touchdown Line': '+260',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+105)',
#   'Receptions Under': '(-135)',
#   'Receiving Yards Projection': 'O 33.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'tyler higbee',
#   'Team': 'LAR',
#   'Anytime Touchdown Line': '+220',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-150)',
#   'Receptions Under': '(+115)',
#   'Receiving Yards Projection': 'O 27.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'cj uzomah',
#   'Team': 'CIN',
#   'Anytime Touchdown Line': '+230',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-135)',
#   'Receptions Under': '(+105)',
#   'Receiving Yards Projection': 'O 26.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'gerald everett',
#   'Team': 'SEA',
#   'Anytime Touchdown Line': '+260',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-125)',
#   'Receptions Under': '(-105)',
#   'Receiving Yards Projection': 'O 31.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'james oshaughnessy',
#   'Team': 'JAX',
#   'Anytime Touchdown Line': '+400',
#   'Receiving Yards Projection': 'O 26.5',
#   'Receiving Yards Over': '(-118)',
#   'Receiving Yards Under': '(-111)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-161)',
#   'Receptions Under': '(+125)'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'evan engram',
#   'Team': 'NYG',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(+125)',
#   'Receptions Under': '(-161)',
#   'Anytime Touchdown Line': '+400',
#   'Receiving Yards Projection': 'O 31.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-118)'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'foster moreau',
#   'Team': 'LV',
#   'Anytime Touchdown Line': '+240',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-105)',
#   'Receptions Under': '(-125)',
#   'Receiving Yards Projection': 'O 36.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-118)'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'ricky sealsjones',
#   'Team': 'WAS',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-128)',
#   'Receptions Under': '(EVEN)',
#   'Anytime Touchdown Line': '+450',
#   'Receiving Yards Projection': 'O 26.5',
#   'Receiving Yards Over': '(-111)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'david njoku',
#   'Team': 'CLE',
#   'Anytime Touchdown Line': '+400',
#   'Receiving Yards Projection': 'O 20.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-111)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(+125)',
#   'Receptions Under': '(-161)'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'brevin jordan',
#   'Team': 'HOU',
#   'Anytime Touchdown Line': '+330'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'jack doyle',
#   'Team': 'IND',
#   'Receiving Yards Projection': 'O 19.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+400'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'josiah deguara',
#   'Team': 'GB',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(+136)',
#   'Receptions Under': '(-174)',
#   'Anytime Touchdown Line': '+450',
#   'Receiving Yards Projection': 'O 18.5',
#   'Receiving Yards Over': '(-120)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'nick vannett',
#   'Team': 'NO',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(+105)',
#   'Receptions Under': '(-135)',
#   'Anytime Touchdown Line': '+500',
#   'Receiving Yards Projection': 'O 23.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'zach gentry',
#   'Team': 'PIT',
#   'Anytime Touchdown Line': '+400'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'noah gray',
#   'Team': 'KC',
#   'Anytime Touchdown Line': '+550'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'tyler kroft',
#   'Team': 'NYJ',
#   'Anytime Touchdown Line': '+390',
#   'Receiving Yards Projection': 'O 21.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(+130)',
#   'Receptions Under': '(-175)'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'brock wright',
#   'Team': 'DET',
#   'Receiving Yards Projection': 'O 14.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+500',
#   'Receptions Projection': 'O 1.5',
#   'Receptions Over': '(-155)',
#   'Receptions Under': '(+115)'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'anthony firkser',
#   'Team': 'TEN',
#   'Receiving Yards Projection': 'O 12.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-111)',
#   'Anytime Touchdown Line': '+500',
#   'Receptions Projection': 'O 1.5',
#   'Receptions Over': '(-110)',
#   'Receptions Under': '(-120)'},
#  {'Year': 2021,
#   'Week': 16,
#   'Player Name': 'tommy tremble',
#   'Team': 'CAR',
#   'Receiving Yards Projection': 'O 14.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+650',
#   'Receptions Projection': 'O 1.5',
#   'Receptions Over': '(-135)',
#   'Receptions Under': '(+105)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'taysom hill',
#   'Team': 'NO',
#   'Anytime Touchdown Line': '+140'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'travis kelce',
#   'Team': 'KC',
#   'Receiving Yards Projection': 'O 73.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '-110'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'mark andrews',
#   'Team': 'BAL',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(-180)',
#   'Receptions Under': '(+140)',
#   'Receiving Yards Projection': 'O 67.5',
#   'Receiving Yards Over': '(-111)',
#   'Receiving Yards Under': '(-118)',
#   'Anytime Touchdown Line': '+170'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'george kittle',
#   'Team': 'SF',
#   'Anytime Touchdown Line': '+125',
#   'Receiving Yards Projection': 'O 54.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-105)',
#   'Receptions Under': '(-125)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'rob gronkowski',
#   'Team': 'TB',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(EVEN)',
#   'Receptions Under': '(-130)',
#   'Receiving Yards Projection': 'O 46.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+150'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'dallas goedert',
#   'Team': 'PHI',
#   'Anytime Touchdown Line': '+175',
#   'Receiving Yards Projection': 'O 52.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+110)',
#   'Receptions Under': '(-145)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'zach ertz',
#   'Team': 'ARI',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-155)',
#   'Receptions Under': '(+120)',
#   'Receiving Yards Projection': 'O 50.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-111)',
#   'Anytime Touchdown Line': '+200'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'dawson knox',
#   'Team': 'BUF',
#   'Anytime Touchdown Line': '+160',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-130)',
#   'Receptions Under': '(EVEN)',
#   'Receiving Yards Projection': 'O 36.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-118)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'dalton schultz',
#   'Team': 'DAL',
#   'Receiving Yards Projection': 'O 46.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-118)',
#   'Anytime Touchdown Line': '+200',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-120)',
#   'Receptions Under': '(-110)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'kyle pitts',
#   'Team': 'ATL',
#   'Receiving Yards Projection': 'O 48.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-110)',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(+120)',
#   'Receptions Under': '(-161)',
#   'Anytime Touchdown Line': '+225'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'hunter henry',
#   'Team': 'NE',
#   'Anytime Touchdown Line': '+135'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'mike gesicki',
#   'Team': 'MIA',
#   'Receiving Yards Projection': 'O 41.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-111)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-160)',
#   'Receptions Under': '(+125)',
#   'Anytime Touchdown Line': '+310'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'noah fant',
#   'Team': 'DEN',
#   'Receiving Yards Projection': 'O 34.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-111)',
#   'Anytime Touchdown Line': '+310'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'pat freiermuth',
#   'Team': 'PIT',
#   'Receiving Yards Projection': 'O 33.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-120)',
#   'Anytime Touchdown Line': '+240',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-105)',
#   'Receptions Under': '(-125)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'tyler higbee',
#   'Team': 'LAR',
#   'Receiving Yards Projection': 'O 32.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-111)',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-111)',
#   'Receptions Under': '(-118)',
#   'Anytime Touchdown Line': '+260'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'gerald everett',
#   'Team': 'SEA',
#   'Anytime Touchdown Line': '+240',
#   'Receiving Yards Projection': 'O 26.5',
#   'Receiving Yards Over': '(-118)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'foster moreau',
#   'Team': 'LV',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-105)',
#   'Receptions Under': '(-125)',
#   'Receiving Yards Projection': 'O 34.5',
#   'Receiving Yards Over': '(-111)',
#   'Receiving Yards Under': '(-118)',
#   'Anytime Touchdown Line': '+275'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'cole kmet',
#   'Team': 'CHI',
#   'Anytime Touchdown Line': '+375',
#   'Receiving Yards Projection': 'O 30.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-118)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'cj uzomah',
#   'Team': 'CIN',
#   'Anytime Touchdown Line': '+275',
#   'Receiving Yards Projection': 'O 29.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'evan engram',
#   'Team': 'NYG',
#   'Anytime Touchdown Line': '+400'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'tyler conklin',
#   'Team': 'MIN',
#   'Anytime Touchdown Line': '+350',
#   'Receiving Yards Projection': 'O 21.5',
#   'Receiving Yards Over': '(-118)',
#   'Receiving Yards Under': '(-111)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'brevin jordan',
#   'Team': 'HOU',
#   'Anytime Touchdown Line': '+500'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'austin hooper',
#   'Team': 'CLE',
#   'Receiving Yards Projection': 'O 25.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-118)',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(-113)',
#   'Receptions Under': '(-113)',
#   'Anytime Touchdown Line': '+310'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'josiah deguara',
#   'Team': 'GB',
#   'Anytime Touchdown Line': '+225',
#   'Receiving Yards Projection': 'O 17.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'ricky sealsjones',
#   'Team': 'WAS',
#   'Anytime Touchdown Line': '+450',
#   'Receiving Yards Projection': 'O 17.5',
#   'Receiving Yards Over': '(-115)',
#   'Receiving Yards Under': '(-115)'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'stephen anderson',
#   'Team': 'LAC',
#   'Anytime Touchdown Line': '+300'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'mo aliecox',
#   'Team': 'IND',
#   'Anytime Touchdown Line': '+400'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'geoff swaim',
#   'Team': 'TEN',
#   'Receptions Projection': 'O 2.5',
#   'Receptions Over': '(+150)',
#   'Receptions Under': '(-180)',
#   'Receiving Yards Projection': 'O 16.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-115)',
#   'Anytime Touchdown Line': '+550'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'ian thomas',
#   'Team': 'CAR',
#   'Anytime Touchdown Line': '+500'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'chris manhertz',
#   'Team': 'JAX',
#   'Receiving Yards Projection': 'O 18.5',
#   'Receiving Yards Over': '(EVEN)',
#   'Receiving Yards Under': '(-135)',
#   'Anytime Touchdown Line': '+1300'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'kenny yeboah',
#   'Team': 'NYJ',
#   'Anytime Touchdown Line': '+400'},
#  {'Year': 2021,
#   'Week': 17,
#   'Player Name': 'jared pinkney',
#   'Team': 'DET',
#   'Anytime Touchdown Line': '+550'},
#  {'Year': 2022,
#   'Week': 1,
#   'Player Name': 'mark andrews',
#   'Team': 'BAL',
#   'Anytime Touchdown Line': '+130',
#   'Receptions Projection': 'O 5.5',
#   'Receptions Over': '(+125)',
#   'Receptions Under': '(-160)',
#   'Receiving Yards Projection': 'O 66.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2022,
#   'Week': 1,
#   'Player Name': 'travis kelce',
#   'Team': 'KC',
#   'Receptions Projection': 'O 6.5',
#   'Receptions Over': '(-108)',
#   'Receptions Under': '(-115)',
#   'Receiving Yards Projection': 'O 73.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '-175'},
#  {'Year': 2022,
#   'Week': 1,
#   'Player Name': 'kyle pitts',
#   'Team': 'ATL',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-114)',
#   'Receptions Under': '(-145)',
#   'Receiving Yards Projection': 'O 60.5',
#   'Receiving Yards Over': '(-114)',
#   'Receiving Yards Under': '(-114)',
#   'Anytime Touchdown Line': '+145'},
#  {'Year': 2022,
#   'Week': 1,
#   'Player Name': 'darren waller',
#   'Team': 'LV',
#   'Anytime Touchdown Line': '+130',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-106)',
#   'Receptions Under': '(-130)',
#   'Receiving Yards Projection': 'O 49.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2022,
#   'Week': 1,
#   'Player Name': 'dalton schultz',
#   'Team': 'DAL',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-130)',
#   'Receptions Under': '(+116)',
#   'Receiving Yards Projection': 'O 48.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+150'},
#  {'Year': 2022,
#   'Week': 1,
#   'Player Name': 'dallas goedert',
#   'Team': 'PHI',
#   'Receiving Yards Projection': 'O 46.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)',
#   'Anytime Touchdown Line': '+155',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(-158)',
#   'Receptions Under': '(-160)'},
#  {'Year': 2022,
#   'Week': 1,
#   'Player Name': 'tj hockenson',
#   'Team': 'DET',
#   'Anytime Touchdown Line': '+140',
#   'Receptions Projection': 'O 4.5',
#   'Receptions Over': '(-122)',
#   'Receptions Under': '(-150)',
#   'Receiving Yards Projection': 'O 44.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  {'Year': 2022,
#   'Week': 1,
#   'Player Name': 'dawson knox',
#   'Team': 'BUF',
#   'Anytime Touchdown Line': '+175',
#   'Receptions Projection': 'O 3.5',
#   'Receptions Over': '(EVEN)',
#   'Receptions Under': '(-135)',
#   'Receiving Yards Projection': 'O 35.5',
#   'Receiving Yards Over': '(-110)',
#   'Receiving Yards Under': '(-110)'},
#  ...]

# %%
import pandas as pd

df = pd.json_normalize(d)

df
# Out:
#       Year  Week    Player Name Team Anytime Touchdown Line  \
# 0     2020     1  george kittle   SF                   EVEN
# 1     2020     1   travis kelce   KC                   -120
# 2     2020     1   mark andrews  BAL                   +138
# 3     2020     1      zach ertz  PHI                   +163
# 4     2020     1  darren waller   LV                   +138
# ...    ...   ...            ...  ...                    ...
# 2010  2023    17   mike gesicki   NE                   +500
# 2011  2023    17    josh oliver  MIN                   +450
# 2012  2023    17  austin hooper   LV                   +450
# 2013  2023    17  adam trautman  DEN                   +400
# 2014  2023    17  tommy tremble  CAR                   +500
#
#      Receiving Yards Projection Receiving Yards Over Receiving Yards Under  \
# 0                        O 71.5               (-110)                (-110)
# 1                        O 69.5               (-122)                (EVEN)
# 2                        O 48.5               (-110)                (-110)
# 3                        O 54.5               (-110)                (-110)
# 4                        O 52.5               (-110)                (-110)
# ...                         ...                  ...                   ...
# 2010                     O 17.5               (-115)                (-110)
# 2011                     O 10.5               (-115)                (-115)
# 2012                     O 20.5               (-113)                (-110)
# 2013                      O 5.5               (-110)                (-110)
# 2014                     O 13.5               (-121)                (-110)
#
#      Receptions Projection Receptions Over Receptions Under
# 0                    O 6.5          (+102)           (-130)
# 1                    O 5.5          (-142)           (+112)
# 2                    O 4.5          (+115)           (-145)
# 3                    O 5.5          (-104)           (-145)
# 4                    O 4.5          (-130)           (+110)
# ...                    ...             ...              ...
# 2010                 O 2.5          (+116)           (-150)
# 2011                   NaN             NaN              NaN
# 2012                 O 2.5          (EVEN)           (-135)
# 2013                 O 0.5          (-174)           (+130)
# 2014                 O 1.5          (-179)           (+140)
#
# [2015 rows x 11 columns]

# %%
for column in ('Receiving Yards Projection', 'Receptions Projection'):
    df[column] = df[column].str.extract(r'(\d+\.\d+)').astype(float)

df
# Out:
#       Year  Week    Player Name Team Anytime Touchdown Line  \
# 0     2020     1  george kittle   SF                   EVEN
# 1     2020     1   travis kelce   KC                   -120
# 2     2020     1   mark andrews  BAL                   +138
# 3     2020     1      zach ertz  PHI                   +163
# 4     2020     1  darren waller   LV                   +138
# ...    ...   ...            ...  ...                    ...
# 2010  2023    17   mike gesicki   NE                   +500
# 2011  2023    17    josh oliver  MIN                   +450
# 2012  2023    17  austin hooper   LV                   +450
# 2013  2023    17  adam trautman  DEN                   +400
# 2014  2023    17  tommy tremble  CAR                   +500
#
#       Receiving Yards Projection Receiving Yards Over Receiving Yards Under  \
# 0                           71.5               (-110)                (-110)
# 1                           69.5               (-122)                (EVEN)
# 2                           48.5               (-110)                (-110)
# 3                           54.5               (-110)                (-110)
# 4                           52.5               (-110)                (-110)
# ...                          ...                  ...                   ...
# 2010                        17.5               (-115)                (-110)
# 2011                        10.5               (-115)                (-115)
# 2012                        20.5               (-113)                (-110)
# 2013                         5.5               (-110)                (-110)
# 2014                        13.5               (-121)                (-110)
#
#       Receptions Projection Receptions Over Receptions Under
# 0                       6.5          (+102)           (-130)
# 1                       5.5          (-142)           (+112)
# 2                       4.5          (+115)           (-145)
# 3                       5.5          (-104)           (-145)
# 4                       4.5          (-130)           (+110)
# ...                     ...             ...              ...
# 2010                    2.5          (+116)           (-150)
# 2011                    NaN             NaN              NaN
# 2012                    2.5          (EVEN)           (-135)
# 2013                    0.5          (-174)           (+130)
# 2014                    1.5          (-179)           (+140)
#
# [2015 rows x 11 columns]

# %%
for column in ('Receiving Yards Over', 'Receiving Yards Under', 'Receptions Over', 'Receptions Under'):
    df.loc[df[column].str.contains('EVEN', regex=False, na=False), column] = '100'
    df.loc[df[column] == '--', column] = 'nan'
    df[column] = df[column].str.replace(r'\(|\)', '', regex=True).astype(float)

df
# Out:
#       Year  Week    Player Name Team Anytime Touchdown Line  \
# 0     2020     1  george kittle   SF                   EVEN
# 1     2020     1   travis kelce   KC                   -120
# 2     2020     1   mark andrews  BAL                   +138
# 3     2020     1      zach ertz  PHI                   +163
# 4     2020     1  darren waller   LV                   +138
# ...    ...   ...            ...  ...                    ...
# 2010  2023    17   mike gesicki   NE                   +500
# 2011  2023    17    josh oliver  MIN                   +450
# 2012  2023    17  austin hooper   LV                   +450
# 2013  2023    17  adam trautman  DEN                   +400
# 2014  2023    17  tommy tremble  CAR                   +500
#
#       Receiving Yards Projection  Receiving Yards Over  Receiving Yards Under  \
# 0                           71.5                -110.0                 -110.0
# 1                           69.5                -122.0                  100.0
# 2                           48.5                -110.0                 -110.0
# 3                           54.5                -110.0                 -110.0
# 4                           52.5                -110.0                 -110.0
# ...                          ...                   ...                    ...
# 2010                        17.5                -115.0                 -110.0
# 2011                        10.5                -115.0                 -115.0
# 2012                        20.5                -113.0                 -110.0
# 2013                         5.5                -110.0                 -110.0
# 2014                        13.5                -121.0                 -110.0
#
#       Receptions Projection  Receptions Over  Receptions Under
# 0                       6.5            102.0            -130.0
# 1                       5.5           -142.0             112.0
# 2                       4.5            115.0            -145.0
# 3                       5.5           -104.0            -145.0
# 4                       4.5           -130.0             110.0
# ...                     ...              ...               ...
# 2010                    2.5            116.0            -150.0
# 2011                    NaN              NaN               NaN
# 2012                    2.5            100.0            -135.0
# 2013                    0.5           -174.0             130.0
# 2014                    1.5           -179.0             140.0
#
# [2015 rows x 11 columns]

# %%
for column in ('Anytime Touchdown Line', ):
    df.loc[df[column].str.contains('EVEN', regex=False, na=False), column] = '100'
    df.loc[df[column] == '--', column] = 'nan'
    df[column] = df[column].astype(float)

df
# Out:
#       Year  Week    Player Name Team  Anytime Touchdown Line  \
# 0     2020     1  george kittle   SF                   100.0
# 1     2020     1   travis kelce   KC                  -120.0
# 2     2020     1   mark andrews  BAL                   138.0
# 3     2020     1      zach ertz  PHI                   163.0
# 4     2020     1  darren waller   LV                   138.0
# ...    ...   ...            ...  ...                     ...
# 2010  2023    17   mike gesicki   NE                   500.0
# 2011  2023    17    josh oliver  MIN                   450.0
# 2012  2023    17  austin hooper   LV                   450.0
# 2013  2023    17  adam trautman  DEN                   400.0
# 2014  2023    17  tommy tremble  CAR                   500.0
#
#       Receiving Yards Projection  Receiving Yards Over  Receiving Yards Under  \
# 0                           71.5                -110.0                 -110.0
# 1                           69.5                -122.0                  100.0
# 2                           48.5                -110.0                 -110.0
# 3                           54.5                -110.0                 -110.0
# 4                           52.5                -110.0                 -110.0
# ...                          ...                   ...                    ...
# 2010                        17.5                -115.0                 -110.0
# 2011                        10.5                -115.0                 -115.0
# 2012                        20.5                -113.0                 -110.0
# 2013                         5.5                -110.0                 -110.0
# 2014                        13.5                -121.0                 -110.0
#
#       Receptions Projection  Receptions Over  Receptions Under
# 0                       6.5            102.0            -130.0
# 1                       5.5           -142.0             112.0
# 2                       4.5            115.0            -145.0
# 3                       5.5           -104.0            -145.0
# 4                       4.5           -130.0             110.0
# ...                     ...              ...               ...
# 2010                    2.5            116.0            -150.0
# 2011                    NaN              NaN               NaN
# 2012                    2.5            100.0            -135.0
# 2013                    0.5           -174.0             130.0
# 2014                    1.5           -179.0             140.0
#
# [2015 rows x 11 columns]

# %%
def american_odds_to_probability(odds):
    """
    Converts American betting odds to implied probability.
    
    Args:
        odds (int or float): The American odds value (e.g., -150, +200).

    Returns:
        float: The implied probability as a decimal (e.g., 0.60 for 60%).
    """
    if odds > 0:
        # Positive odds: (100 / (odds + 100))
        probability = 100 / (odds + 100)
    else:
        # Negative odds: (-odds / (-odds + 100))
        probability = -odds / (-odds + 100)
    
    return probability

# %% [markdown]
# Adjust projections based on over/under lines

# %%
for stat in ('Receiving Yards', 'Receptions'):
    df[f'Adjusted {stat} Projection'] = (
        df[f'{stat} Projection'] +
        0.5 * df[f'{stat} Over'].apply(american_odds_to_probability) -
        0.5 * df[f'{stat} Under'].apply(american_odds_to_probability)
    )

df
# Out:
#       Year  Week    Player Name Team  Anytime Touchdown Line  \
# 0     2020     1  george kittle   SF                   100.0
# 1     2020     1   travis kelce   KC                  -120.0
# 2     2020     1   mark andrews  BAL                   138.0
# 3     2020     1      zach ertz  PHI                   163.0
# 4     2020     1  darren waller   LV                   138.0
# ...    ...   ...            ...  ...                     ...
# 2010  2023    17   mike gesicki   NE                   500.0
# 2011  2023    17    josh oliver  MIN                   450.0
# 2012  2023    17  austin hooper   LV                   450.0
# 2013  2023    17  adam trautman  DEN                   400.0
# 2014  2023    17  tommy tremble  CAR                   500.0
#
#       Receiving Yards Projection  Receiving Yards Over  Receiving Yards Under  \
# 0                           71.5                -110.0                 -110.0
# 1                           69.5                -122.0                  100.0
# 2                           48.5                -110.0                 -110.0
# 3                           54.5                -110.0                 -110.0
# 4                           52.5                -110.0                 -110.0
# ...                          ...                   ...                    ...
# 2010                        17.5                -115.0                 -110.0
# 2011                        10.5                -115.0                 -115.0
# 2012                        20.5                -113.0                 -110.0
# 2013                         5.5                -110.0                 -110.0
# 2014                        13.5                -121.0                 -110.0
#
#       Receptions Projection  Receptions Over  Receptions Under  \
# 0                       6.5            102.0            -130.0
# 1                       5.5           -142.0             112.0
# 2                       4.5            115.0            -145.0
# 3                       5.5           -104.0            -145.0
# 4                       4.5           -130.0             110.0
# ...                     ...              ...               ...
# 2010                    2.5            116.0            -150.0
# 2011                    NaN              NaN               NaN
# 2012                    2.5            100.0            -135.0
# 2013                    0.5           -174.0             130.0
# 2014                    1.5           -179.0             140.0
#
#       Adjusted Receiving Yards Projection  Adjusted Receptions Projection
# 0                               71.500000                        6.464916
# 1                               69.524775                        5.557539
# 2                               48.500000                        4.436640
# 3                               54.500000                        5.458984
# 4                               52.500000                        4.544513
# ...                                   ...                             ...
# 2010                            17.505537                        2.431481
# 2011                            10.500000                             NaN
# 2012                            20.503353                        2.462766
# 2013                             5.500000                        0.600127
# 2014                            13.511851                        1.612455
#
# [2015 rows x 13 columns]

# %%
df['Anytime Touchdown Probability'] = df['Anytime Touchdown Line'].apply(american_odds_to_probability)

df
# Out:
#       Year  Week    Player Name Team  Anytime Touchdown Line  \
# 0     2020     1  george kittle   SF                   100.0
# 1     2020     1   travis kelce   KC                  -120.0
# 2     2020     1   mark andrews  BAL                   138.0
# 3     2020     1      zach ertz  PHI                   163.0
# 4     2020     1  darren waller   LV                   138.0
# ...    ...   ...            ...  ...                     ...
# 2010  2023    17   mike gesicki   NE                   500.0
# 2011  2023    17    josh oliver  MIN                   450.0
# 2012  2023    17  austin hooper   LV                   450.0
# 2013  2023    17  adam trautman  DEN                   400.0
# 2014  2023    17  tommy tremble  CAR                   500.0
#
#       Receiving Yards Projection  Receiving Yards Over  Receiving Yards Under  \
# 0                           71.5                -110.0                 -110.0
# 1                           69.5                -122.0                  100.0
# 2                           48.5                -110.0                 -110.0
# 3                           54.5                -110.0                 -110.0
# 4                           52.5                -110.0                 -110.0
# ...                          ...                   ...                    ...
# 2010                        17.5                -115.0                 -110.0
# 2011                        10.5                -115.0                 -115.0
# 2012                        20.5                -113.0                 -110.0
# 2013                         5.5                -110.0                 -110.0
# 2014                        13.5                -121.0                 -110.0
#
#       Receptions Projection  Receptions Over  Receptions Under  \
# 0                       6.5            102.0            -130.0
# 1                       5.5           -142.0             112.0
# 2                       4.5            115.0            -145.0
# 3                       5.5           -104.0            -145.0
# 4                       4.5           -130.0             110.0
# ...                     ...              ...               ...
# 2010                    2.5            116.0            -150.0
# 2011                    NaN              NaN               NaN
# 2012                    2.5            100.0            -135.0
# 2013                    0.5           -174.0             130.0
# 2014                    1.5           -179.0             140.0
#
#       Adjusted Receiving Yards Projection  Adjusted Receptions Projection  \
# 0                               71.500000                        6.464916
# 1                               69.524775                        5.557539
# 2                               48.500000                        4.436640
# 3                               54.500000                        5.458984
# 4                               52.500000                        4.544513
# ...                                   ...                             ...
# 2010                            17.505537                        2.431481
# 2011                            10.500000                             NaN
# 2012                            20.503353                        2.462766
# 2013                             5.500000                        0.600127
# 2014                            13.511851                        1.612455
#
#       Anytime Touchdown Probability
# 0                          0.500000
# 1                          0.545455
# 2                          0.420168
# 3                          0.380228
# 4                          0.420168
# ...                             ...
# 2010                       0.166667
# 2011                       0.181818
# 2012                       0.181818
# 2013                       0.200000
# 2014                       0.166667
#
# [2015 rows x 14 columns]

# %%
df.to_parquet(r'..\..\data\betting_lines\te1_props.parquet')

print('Done')
# Out:
# Done
