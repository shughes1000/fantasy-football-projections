# %%
import pandas as pd

pd.set_option('display.max_columns', 100)

df_mod = pd.read_parquet('../../data/model_data/model_data_single_output.parquet')

df_mod = df_mod.loc[df_mod['Position'] == 'TE', :].reset_index(drop=True)

df_mod
# Out:
#       Season  Week           Name Position Team  Fantasy Points   Rank  \
# 0       2020     1  george kittle       TE   SF             7.3   43.0
# 1       2020     1   travis kelce       TE   KC            14.0   48.0
# 2       2020     1   mark andrews       TE  BAL            20.3   70.0
# 3       2020     1      zach ertz       TE  PHI             9.3   76.0
# 4       2020     1  darren waller       TE   LV             7.5   87.0
# ...      ...   ...            ...      ...  ...             ...    ...
# 2010    2023    17   mike gesicki       TE   NE             5.5  197.0
# 2011    2023    17    josh oliver       TE  MIN             2.2  200.0
# 2012    2023    17  austin hooper       TE   LV             4.3  217.0
# 2013    2023    17  adam trautman       TE  DEN             1.4  225.0
# 2014    2023    17  tommy tremble       TE  CAR             1.1  226.0
#
#       Position Rank  Adjusted Passing Yards Projection  \
# 0                 1                                NaN
# 1                 2                                NaN
# 2                 3                                NaN
# 3                 4                                NaN
# 4                 5                                NaN
# ...             ...                                ...
# 2010             31                                NaN
# 2011             32                                NaN
# 2012             34                                NaN
# 2013             35                                NaN
# 2014             36                                NaN
#
#       Adjusted Passing Touchdowns Projection  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 2010                                     NaN
# 2011                                     NaN
# 2012                                     NaN
# 2013                                     NaN
# 2014                                     NaN
#
#       Adjusted Interceptions Projection  Adjusted Rushing Yards Projection  \
# 0                                   NaN                                NaN
# 1                                   NaN                                NaN
# 2                                   NaN                                NaN
# 3                                   NaN                                NaN
# 4                                   NaN                                NaN
# ...                                 ...                                ...
# 2010                                NaN                                NaN
# 2011                                NaN                                NaN
# 2012                                NaN                                NaN
# 2013                                NaN                                NaN
# 2014                                NaN                                NaN
#
#       Adjusted Receiving Yards Projection  Adjusted Receptions Projection  \
# 0                               71.500000                        6.464916
# 1                               69.524775                        5.557539
# 2                               48.500000                        4.436640
# 3                               54.500000                        5.458984
# 4                               52.500000                        4.544513
# ...                                   ...                             ...
# 2010                            17.505537                        2.431481
# 2011                            10.500000                             NaN
# 2012                            20.503353                        2.462766
# 2013                             5.500000                        0.600127
# 2014                            13.511851                        1.612455
#
#       Anytime Touchdown Probability  Location  Team Projected Score  \
# 0                          0.500000       1.0                 26.75
# 1                          0.545455       1.0                 31.50
# 2                          0.420168       1.0                 27.25
# 3                          0.380228      -1.0                 22.00
# 4                          0.420168      -1.0                 25.50
# ...                             ...       ...                   ...
# 2010                       0.166667      -1.0                 12.75
# 2011                       0.181818       1.0                 21.75
# 2012                       0.181818      -1.0                 19.50
# 2013                       0.200000       1.0                 21.50
# 2014                       0.166667      -1.0                 17.25
#
#       Opponent Projected Score
# 0                        20.25
# 1                        22.00
# 2                        20.25
# 3                        16.50
# 4                        22.50
# ...                        ...
# 2010                     27.25
# 2011                     20.75
# 2012                     23.00
# 2013                     18.00
# 2014                     20.75
#
# [2015 rows x 18 columns]

# %%
X = df_mod[[
    'Rank',
    'Position Rank',
    'Location',
    'Team Projected Score',
    'Opponent Projected Score',
    'Adjusted Receptions Projection',
    'Adjusted Receiving Yards Projection',
    'Anytime Touchdown Probability',
]].copy()

X
# Out:
#        Rank  Position Rank  Location  Team Projected Score  \
# 0      43.0              1       1.0                 26.75
# 1      48.0              2       1.0                 31.50
# 2      70.0              3       1.0                 27.25
# 3      76.0              4      -1.0                 22.00
# 4      87.0              5      -1.0                 25.50
# ...     ...            ...       ...                   ...
# 2010  197.0             31      -1.0                 12.75
# 2011  200.0             32       1.0                 21.75
# 2012  217.0             34      -1.0                 19.50
# 2013  225.0             35       1.0                 21.50
# 2014  226.0             36      -1.0                 17.25
#
#       Opponent Projected Score  Adjusted Receptions Projection  \
# 0                        20.25                        6.464916
# 1                        22.00                        5.557539
# 2                        20.25                        4.436640
# 3                        16.50                        5.458984
# 4                        22.50                        4.544513
# ...                        ...                             ...
# 2010                     27.25                        2.431481
# 2011                     20.75                             NaN
# 2012                     23.00                        2.462766
# 2013                     18.00                        0.600127
# 2014                     20.75                        1.612455
#
#       Adjusted Receiving Yards Projection  Anytime Touchdown Probability
# 0                               71.500000                       0.500000
# 1                               69.524775                       0.545455
# 2                               48.500000                       0.420168
# 3                               54.500000                       0.380228
# 4                               52.500000                       0.420168
# ...                                   ...                            ...
# 2010                            17.505537                       0.166667
# 2011                            10.500000                       0.181818
# 2012                            20.503353                       0.181818
# 2013                             5.500000                       0.200000
# 2014                            13.511851                       0.166667
#
# [2015 rows x 8 columns]

# %%
y = df_mod['Fantasy Points'].copy()

y
# Out:
# 0        7.3
# 1       14.0
# 2       20.3
# 3        9.3
# 4        7.5
#         ...
# 2010     5.5
# 2011     2.2
# 2012     4.3
# 2013     1.4
# 2014     1.1
# Name: Fantasy Points, Length: 2015, dtype: float64

# %%
groups = df_mod['Season'].astype(str) + ' Week ' + df_mod['Week'].astype(str)

groups
# Out:
# 0        2020 Week 1
# 1        2020 Week 1
# 2        2020 Week 1
# 3        2020 Week 1
# 4        2020 Week 1
#             ...
# 2010    2023 Week 17
# 2011    2023 Week 17
# 2012    2023 Week 17
# 2013    2023 Week 17
# 2014    2023 Week 17
# Length: 2015, dtype: object

# %%
df_folds = pd.read_parquet('../../data/model_data/folds.parquet')

df_folds
# Out:
#     Fold ID   Season Week
# 0         0   2022 Week 3
# 1         0   2021 Week 7
# 2         0   2021 Week 1
# 3         0  2023 Week 16
# 4         0  2021 Week 11
# ..      ...           ...
# 62        2  2020 Week 15
# 63        2  2023 Week 14
# 64        2   2021 Week 5
# 65        2   2022 Week 6
# 66        2  2022 Week 12
#
# [67 rows x 2 columns]

# %%
from sklearn.model_selection import GroupShuffleSplit
from sklearn.preprocessing import StandardScaler
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

pd.options.mode.chained_assignment = None

# splitter = GroupKFold(n_splits=3)

cv_data = []
for fold in df_folds['Fold ID'].unique():
    oos_season_week = df_folds.loc[df_folds['Fold ID'] == fold, 'Season Week']
    is_indexes = df_mod.loc[~groups.isin(oos_season_week), :].index
    oos_indexes = df_mod.loc[groups.isin(oos_season_week), :].index
    # split
    X_is = X.iloc[is_indexes]
    X_oos = X.iloc[oos_indexes]

    y_is = y.iloc[is_indexes]
    y_oos = y.iloc[oos_indexes]

    groups_is = groups.iloc[is_indexes]
    df_mod_oos = df_mod.iloc[oos_indexes]

    gss = GroupShuffleSplit(n_splits=1, test_size=0.15, random_state=22)
    for train_indexes, val_indexes in gss.split(X=X_is, y=y_is, groups=groups_is):
            X_train = X.iloc[train_indexes]
            X_val = X.iloc[val_indexes]

            y_train = y.iloc[train_indexes]
            y_val = y.iloc[val_indexes]

    # impute
    scaler = StandardScaler()
    imputer = IterativeImputer(initial_strategy='median', max_iter=100)

    X_train_fill_na = imputer.fit_transform(scaler.fit_transform(X_train))
    X_train[X_train.columns] = scaler.inverse_transform(X_train_fill_na).copy()
    X_train['Prop Bets Projection'] = (
        X_train['Adjusted Receiving Yards Projection']*0.1 + 
        X_train['Adjusted Receptions Projection']*0.5 + 
        X_train['Anytime Touchdown Probability']*6
    )

    X_val_fill_na = imputer.transform(scaler.transform(X_val))
    X_val[X_val.columns] = scaler.inverse_transform(X_val_fill_na).copy()
    X_val['Prop Bets Projection'] = (
        X_val['Adjusted Receiving Yards Projection']*0.1 + 
        X_val['Adjusted Receptions Projection']*0.5 + 
        X_val['Anytime Touchdown Probability']*6
    )

    X_oos_fill_na = imputer.transform(scaler.transform(X_oos))
    X_oos[X_oos.columns] = scaler.inverse_transform(X_oos_fill_na).copy()
    X_oos['Prop Bets Projection'] = (
        X_oos['Adjusted Receiving Yards Projection']*0.1 + 
        X_oos['Adjusted Receptions Projection']*0.5 + 
        X_oos['Anytime Touchdown Probability']*6
    )

    # X_train.drop(columns=['Adjusted Passing Yards Projection', 'Adjusted Passing Touchdowns Projection', 'Adjusted Interceptions Projection', 'Adjusted Rushing Yards Projection', 'Anytime Touchdown Probability'], inplace=True)
    # X_val.drop(columns=['Adjusted Passing Yards Projection', 'Adjusted Passing Touchdowns Projection', 'Adjusted Interceptions Projection', 'Adjusted Rushing Yards Projection', 'Anytime Touchdown Probability'], inplace=True)
    # X_oos.drop(columns=['Adjusted Passing Yards Projection', 'Adjusted Passing Touchdowns Projection', 'Adjusted Interceptions Projection', 'Adjusted Rushing Yards Projection', 'Anytime Touchdown Probability'], inplace=True)

    cv_data.append((X_train, X_val, X_oos, y_train, y_val, y_oos, df_mod_oos))

for X_train, X_val, X_oos, y_train, y_val, y_oos, df_mod_oos in cv_data:
    print(X_train.shape, X_val.shape, X_oos.shape, y_train.shape, y_val.shape, y_oos.shape, df_mod_oos.shape)
# Out:
# (1105, 9) (216, 9) (694, 9) (1105,) (216,) (694,) (694, 18)
# (1156, 9) (212, 9) (647, 9) (1156,) (212,) (647,) (647, 18)
# (1137, 9) (204, 9) (674, 9) (1137,) (204,) (674,) (674, 18)

# %%
monotonic_contraints_dict = {
    'Rank': -1,
    'Position Rank': -1,
    'Location': 1,
    'Team Projected Score': 1,
    'Adjusted Receiving Yards Projection': 1,
    'Adjusted Receptions Projection': 1,
    'Adjusted Rushing Yards Projection': 1,
    'Anytime Touchdown Probability': 1,
    'Prop Bets Projection': 1,
}

monotone_contraints = [monotonic_contraints_dict.get(c, 0) for c in X_train.columns]

monotone_contraints
# Out:
# [-1, -1, 1, 1, 0, 1, 1, 1, 1]

# %%
from sklearn.metrics import mean_squared_error
from lightgbm import LGBMRegressor
import optuna
import numpy as np

def objective(trial, cv_data=cv_data):
    # model tuning
    # params = {
    #     'random_state': 22,
    #     'objective': 'binary:logistic',
    #     'eval_metric': 'logloss',
    #     'n_estimators': 1_000,
    #     'eta': trial.suggest_float('eta', 0.005, 0.100),
    #     'max_depth': trial.suggest_int('max_depth', 4, 16),
    #     'lambda': trial.suggest_float('lambda', 1e-8, 5.0),
    #     'alpha': trial.suggest_float('alpha', 1e-8, 5.0),
    #     'min_child_weight': trial.suggest_float('min_child_weight', 1e-8, 5.0),
    #     # 'subsample': trial.suggest_float('subsample', 0.5, 1.0),
    #     'colsample_bytree': trial.suggest_float('colsample_bytree', 0.01, 0.30),
    # }
    params = {
        'random_state': 22,
        'metric': 'mean_absolute_error',
        'verbosity': -1,
        'n_estimators': 500,
        'early_stopping_round': 25,
        'monotone_constraints': monotone_contraints,
        'lambda_l1': trial.suggest_float('lambda_l1', 1e-8, 10.0),
        'lambda_l2': trial.suggest_float('lambda_l2', 1e-8, 10.0),
        'max_depth': trial.suggest_int('max_depth', 1, 32),
        'num_leaves': trial.suggest_int('num_leaves', 2, 2**8),
        'feature_fraction': trial.suggest_float('feature_fraction', 1e-8, 1.0),
        'min_child_samples': trial.suggest_int('min_child_samples', 1, 100),
    }
    mod = LGBMRegressor(**params)

    # cross validation
    y_actuals = []
    y_preds = []
    for X_train, X_val, X_test, y_train, y_val, y_test, df_mod_oos in cv_data:
        y_actuals.append(y_test)

        mod.fit(
            X_train, 
            y_train, 
            eval_set=(X_val, y_val),
        )

        y_preds.append(mod.predict(X_test))

    return mean_squared_error(np.hstack(y_actuals), np.hstack(y_preds), squared=False)

study = optuna.create_study(direction='minimize', sampler=optuna.samplers.TPESampler(seed=22, n_startup_trials=50, multivariate=True))
study.optimize(objective, n_trials=500, show_progress_bar=True)

study.best_params
# Out:
# c:\Users\mhugh\anaconda3\envs\clean\lib\site-packages\optuna\samplers\_tpe\sampler.py:295: ExperimentalWarning: ``multivariate`` option is an experimental feature. The interface can change in the future.
#   warnings.warn(
# [I 2024-10-13 20:08:16,168] A new study created in memory with name: no-name-647b8639-b06d-44d4-af77-73f95127f10b
#   0%|          | 0/500 [00:00<?, ?it/s]
# [I 2024-10-13 20:08:16,361] Trial 0 finished with value: 5.22815269557821 and parameters: {'lambda_l1': 2.084605381503821, 'lambda_l2': 4.816810622816848, 'max_depth': 14, 'num_leaves': 221, 'feature_fraction': 0.17116156190005774, 'min_child_samples': 34}. Best is trial 0 with value: 5.22815269557821.
# [I 2024-10-13 20:08:16,443] Trial 1 finished with value: 5.252678603436494 and parameters: {'lambda_l1': 2.7053283402729833, 'lambda_l2': 6.910413507585547, 'max_depth': 8, 'num_leaves': 209, 'feature_fraction': 0.010526884210839693, 'min_child_samples': 57}. Best is trial 0 with value: 5.22815269557821.
# [I 2024-10-13 20:08:16,522] Trial 2 finished with value: 5.265064321643593 and parameters: {'lambda_l1': 8.137261876014703, 'lambda_l2': 7.451002963137353, 'max_depth': 7, 'num_leaves': 3, 'feature_fraction': 0.7720438737240976, 'min_child_samples': 96}. Best is trial 0 with value: 5.22815269557821.
# [I 2024-10-13 20:08:16,630] Trial 3 finished with value: 5.207291074625464 and parameters: {'lambda_l1': 7.0193788439237315, 'lambda_l2': 2.975782675674722, 'max_depth': 25, 'num_leaves': 177, 'feature_fraction': 0.38718348650918744, 'min_child_samples': 62}. Best is trial 3 with value: 5.207291074625464.
# [I 2024-10-13 20:08:16,739] Trial 4 finished with value: 5.238717969709501 and parameters: {'lambda_l1': 4.275552404167853, 'lambda_l2': 5.842896435726052, 'max_depth': 23, 'num_leaves': 30, 'feature_fraction': 0.9232699266117512, 'min_child_samples': 99}. Best is trial 3 with value: 5.207291074625464.
# [I 2024-10-13 20:08:16,911] Trial 5 finished with value: 5.270896624872351 and parameters: {'lambda_l1': 6.7741077381062915, 'lambda_l2': 7.95164775662488, 'max_depth': 1, 'num_leaves': 47, 'feature_fraction': 0.8749277465284395, 'min_child_samples': 75}. Best is trial 3 with value: 5.207291074625464.
# [I 2024-10-13 20:08:17,068] Trial 6 finished with value: 5.133856833543593 and parameters: {'lambda_l1': 5.080901637200814, 'lambda_l2': 1.2833390269943445, 'max_depth': 16, 'num_leaves': 133, 'feature_fraction': 0.31126467031173777, 'min_child_samples': 5}. Best is trial 6 with value: 5.133856833543593.
# [I 2024-10-13 20:08:17,167] Trial 7 finished with value: 5.227099623550321 and parameters: {'lambda_l1': 4.376806606444189, 'lambda_l2': 0.9588461082215654, 'max_depth': 2, 'num_leaves': 176, 'feature_fraction': 0.8491907467156716, 'min_child_samples': 13}. Best is trial 6 with value: 5.133856833543593.
# [I 2024-10-13 20:08:17,271] Trial 8 finished with value: 5.195471532055016 and parameters: {'lambda_l1': 1.2906400808277216, 'lambda_l2': 4.730600026025964, 'max_depth': 7, 'num_leaves': 201, 'feature_fraction': 0.607413867067853, 'min_child_samples': 45}. Best is trial 6 with value: 5.133856833543593.
# [I 2024-10-13 20:08:17,389] Trial 9 finished with value: 5.186452597240411 and parameters: {'lambda_l1': 9.820291085978743, 'lambda_l2': 7.089554140971765, 'max_depth': 7, 'num_leaves': 44, 'feature_fraction': 0.5387654777120323, 'min_child_samples': 32}. Best is trial 6 with value: 5.133856833543593.
# [I 2024-10-13 20:08:17,494] Trial 10 finished with value: 5.205880027418281 and parameters: {'lambda_l1': 9.115369974738407, 'lambda_l2': 0.8625568068298629, 'max_depth': 11, 'num_leaves': 57, 'feature_fraction': 0.7366662321509689, 'min_child_samples': 83}. Best is trial 6 with value: 5.133856833543593.
# [I 2024-10-13 20:08:17,586] Trial 11 finished with value: 5.26646424095718 and parameters: {'lambda_l1': 7.445644632079445, 'lambda_l2': 1.7753703875851008, 'max_depth': 28, 'num_leaves': 3, 'feature_fraction': 0.3576431761648761, 'min_child_samples': 96}. Best is trial 6 with value: 5.133856833543593.
# [I 2024-10-13 20:08:17,709] Trial 12 finished with value: 5.167798702736895 and parameters: {'lambda_l1': 9.417763861384264, 'lambda_l2': 0.23049013654080094, 'max_depth': 22, 'num_leaves': 43, 'feature_fraction': 0.5681323746241385, 'min_child_samples': 25}. Best is trial 6 with value: 5.133856833543593.
# [I 2024-10-13 20:08:17,823] Trial 13 finished with value: 5.176481431314718 and parameters: {'lambda_l1': 1.5785591501063627, 'lambda_l2': 5.035628220122295, 'max_depth': 19, 'num_leaves': 121, 'feature_fraction': 0.5081672454060291, 'min_child_samples': 33}. Best is trial 6 with value: 5.133856833543593.
# [I 2024-10-13 20:08:18,027] Trial 14 finished with value: 5.10344876642189 and parameters: {'lambda_l1': 8.864983553736035, 'lambda_l2': 2.5183551154305976, 'max_depth': 28, 'num_leaves': 163, 'feature_fraction': 0.6972231829797998, 'min_child_samples': 4}. Best is trial 14 with value: 5.10344876642189.
# [I 2024-10-13 20:08:18,155] Trial 15 finished with value: 5.194485361590175 and parameters: {'lambda_l1': 6.573113029388262, 'lambda_l2': 9.993224216396282, 'max_depth': 17, 'num_leaves': 239, 'feature_fraction': 0.44080287410267743, 'min_child_samples': 21}. Best is trial 14 with value: 5.10344876642189.
# [I 2024-10-13 20:08:18,246] Trial 16 finished with value: 5.269584393249842 and parameters: {'lambda_l1': 8.038535684069508, 'lambda_l2': 8.07672059410554, 'max_depth': 2, 'num_leaves': 203, 'feature_fraction': 0.450041684177444, 'min_child_samples': 86}. Best is trial 14 with value: 5.10344876642189.
# [I 2024-10-13 20:08:18,464] Trial 17 finished with value: 5.084041936459944 and parameters: {'lambda_l1': 3.624168648699743, 'lambda_l2': 2.0242762718220377, 'max_depth': 28, 'num_leaves': 155, 'feature_fraction': 0.831852739197039, 'min_child_samples': 3}. Best is trial 17 with value: 5.084041936459944.
# [I 2024-10-13 20:08:18,563] Trial 18 finished with value: 5.261352514326204 and parameters: {'lambda_l1': 7.042966208974291, 'lambda_l2': 7.62995911879823, 'max_depth': 13, 'num_leaves': 51, 'feature_fraction': 0.1689230888648846, 'min_child_samples': 89}. Best is trial 17 with value: 5.084041936459944.
# [I 2024-10-13 20:08:18,647] Trial 19 finished with value: 5.218815714628433 and parameters: {'lambda_l1': 7.3094208835154015, 'lambda_l2': 8.8719403726663, 'max_depth': 9, 'num_leaves': 171, 'feature_fraction': 0.43498705260110365, 'min_child_samples': 52}. Best is trial 17 with value: 5.084041936459944.
# [I 2024-10-13 20:08:18,859] Trial 20 finished with value: 5.1014579593577185 and parameters: {'lambda_l1': 5.653980359239076, 'lambda_l2': 0.3451501808493058, 'max_depth': 28, 'num_leaves': 91, 'feature_fraction': 0.5389013475164267, 'min_child_samples': 1}. Best is trial 17 with value: 5.084041936459944.
# [I 2024-10-13 20:08:18,946] Trial 21 finished with value: 5.239392420730674 and parameters: {'lambda_l1': 0.489554667023236, 'lambda_l2': 9.333017947224663, 'max_depth': 7, 'num_leaves': 186, 'feature_fraction': 0.3980551630378403, 'min_child_samples': 74}. Best is trial 17 with value: 5.084041936459944.
# [I 2024-10-13 20:08:19,044] Trial 22 finished with value: 5.262483936491299 and parameters: {'lambda_l1': 6.511376677483669, 'lambda_l2': 9.250353214624223, 'max_depth': 20, 'num_leaves': 11, 'feature_fraction': 0.11557638950587484, 'min_child_samples': 76}. Best is trial 17 with value: 5.084041936459944.
# [I 2024-10-13 20:08:19,151] Trial 23 finished with value: 5.191991279203555 and parameters: {'lambda_l1': 4.517788248973011, 'lambda_l2': 6.046750447343872, 'max_depth': 28, 'num_leaves': 129, 'feature_fraction': 0.8169499167755174, 'min_child_samples': 65}. Best is trial 17 with value: 5.084041936459944.
# [I 2024-10-13 20:08:19,220] Trial 24 finished with value: 5.2331305121055 and parameters: {'lambda_l1': 4.585916254770666, 'lambda_l2': 2.289650598801194, 'max_depth': 27, 'num_leaves': 132, 'feature_fraction': 0.026716911481217794, 'min_child_samples': 16}. Best is trial 17 with value: 5.084041936459944.
# [I 2024-10-13 20:08:19,287] Trial 25 finished with value: 5.212190977324104 and parameters: {'lambda_l1': 9.086816463002746, 'lambda_l2': 0.35256871082678004, 'max_depth': 16, 'num_leaves': 22, 'feature_fraction': 0.539854889190807, 'min_child_samples': 70}. Best is trial 17 with value: 5.084041936459944.
# [I 2024-10-13 20:08:19,352] Trial 26 finished with value: 5.206946068564423 and parameters: {'lambda_l1': 0.5196410509014395, 'lambda_l2': 9.38557284441749, 'max_depth': 14, 'num_leaves': 249, 'feature_fraction': 0.37649331016315807, 'min_child_samples': 58}. Best is trial 17 with value: 5.084041936459944.
# [I 2024-10-13 20:08:19,462] Trial 27 finished with value: 5.182412164037508 and parameters: {'lambda_l1': 2.77050808473577, 'lambda_l2': 1.7891537117257124, 'max_depth': 17, 'num_leaves': 256, 'feature_fraction': 0.5083273485258836, 'min_child_samples': 35}. Best is trial 17 with value: 5.084041936459944.
# [I 2024-10-13 20:08:19,577] Trial 28 finished with value: 5.182501803508738 and parameters: {'lambda_l1': 1.8787035855576422, 'lambda_l2': 0.43517482596686374, 'max_depth': 18, 'num_leaves': 125, 'feature_fraction': 0.8592805504851173, 'min_child_samples': 41}. Best is trial 17 with value: 5.084041936459944.
# [I 2024-10-13 20:08:19,696] Trial 29 finished with value: 5.167818752517833 and parameters: {'lambda_l1': 2.612231957998111, 'lambda_l2': 9.981270281205395, 'max_depth': 26, 'num_leaves': 17, 'feature_fraction': 0.3158046220351414, 'min_child_samples': 9}. Best is trial 17 with value: 5.084041936459944.
# [I 2024-10-13 20:08:19,794] Trial 30 finished with value: 5.204036048294795 and parameters: {'lambda_l1': 7.455166416828882, 'lambda_l2': 2.530993227038728, 'max_depth': 12, 'num_leaves': 169, 'feature_fraction': 0.8346373618214232, 'min_child_samples': 73}. Best is trial 17 with value: 5.084041936459944.
# [I 2024-10-13 20:08:19,880] Trial 31 finished with value: 5.262028189979018 and parameters: {'lambda_l1': 4.0587436647437585, 'lambda_l2': 7.76438701377263, 'max_depth': 13, 'num_leaves': 171, 'feature_fraction': 0.18199141974675861, 'min_child_samples': 85}. Best is trial 17 with value: 5.084041936459944.
# [I 2024-10-13 20:08:19,987] Trial 32 finished with value: 5.252435755020348 and parameters: {'lambda_l1': 8.336036101202682, 'lambda_l2': 4.643317602988053, 'max_depth': 8, 'num_leaves': 3, 'feature_fraction': 0.5405971573815558, 'min_child_samples': 51}. Best is trial 17 with value: 5.084041936459944.
# [I 2024-10-13 20:08:20,063] Trial 33 finished with value: 5.2202072984208465 and parameters: {'lambda_l1': 0.4671699376957205, 'lambda_l2': 5.692352683937471, 'max_depth': 32, 'num_leaves': 207, 'feature_fraction': 0.5902617703671256, 'min_child_samples': 79}. Best is trial 17 with value: 5.084041936459944.
# [I 2024-10-13 20:08:20,132] Trial 34 finished with value: 5.238236027504435 and parameters: {'lambda_l1': 7.7739315446946184, 'lambda_l2': 4.481509122576739, 'max_depth': 13, 'num_leaves': 162, 'feature_fraction': 0.09863312332364564, 'min_child_samples': 20}. Best is trial 17 with value: 5.084041936459944.
# [I 2024-10-13 20:08:20,236] Trial 35 finished with value: 5.190728751564623 and parameters: {'lambda_l1': 0.8555555632055482, 'lambda_l2': 9.97684321181545, 'max_depth': 26, 'num_leaves': 117, 'feature_fraction': 0.1805574241161361, 'min_child_samples': 1}. Best is trial 17 with value: 5.084041936459944.
# [I 2024-10-13 20:08:20,314] Trial 36 finished with value: 5.251947836531216 and parameters: {'lambda_l1': 6.813144850607171, 'lambda_l2': 4.427815824343865, 'max_depth': 31, 'num_leaves': 138, 'feature_fraction': 0.1339572513490412, 'min_child_samples': 64}. Best is trial 17 with value: 5.084041936459944.
# [I 2024-10-13 20:08:20,383] Trial 37 finished with value: 5.258509991368897 and parameters: {'lambda_l1': 0.3413318706315758, 'lambda_l2': 5.090980726528967, 'max_depth': 27, 'num_leaves': 113, 'feature_fraction': 0.4691051702324455, 'min_child_samples': 92}. Best is trial 17 with value: 5.084041936459944.
# [I 2024-10-13 20:08:20,442] Trial 38 finished with value: 5.25133508914595 and parameters: {'lambda_l1': 7.236413490056097, 'lambda_l2': 5.591303698901367, 'max_depth': 3, 'num_leaves': 191, 'feature_fraction': 0.341136056824571, 'min_child_samples': 86}. Best is trial 17 with value: 5.084041936459944.
# [I 2024-10-13 20:08:20,509] Trial 39 finished with value: 5.2447795738893355 and parameters: {'lambda_l1': 6.155817368618826, 'lambda_l2': 4.395847102362112, 'max_depth': 20, 'num_leaves': 35, 'feature_fraction': 0.3856478817819415, 'min_child_samples': 94}. Best is trial 17 with value: 5.084041936459944.
# [I 2024-10-13 20:08:20,581] Trial 40 finished with value: 5.274904971792683 and parameters: {'lambda_l1': 5.399968572820769, 'lambda_l2': 5.391522843987809, 'max_depth': 8, 'num_leaves': 157, 'feature_fraction': 0.19258927237072163, 'min_child_samples': 96}. Best is trial 17 with value: 5.084041936459944.
# [I 2024-10-13 20:08:20,663] Trial 41 finished with value: 5.186754811324095 and parameters: {'lambda_l1': 2.702709615849796, 'lambda_l2': 5.796218029870317, 'max_depth': 25, 'num_leaves': 179, 'feature_fraction': 0.7658140957790239, 'min_child_samples': 59}. Best is trial 17 with value: 5.084041936459944.
# [I 2024-10-13 20:08:20,756] Trial 42 finished with value: 5.175606138650633 and parameters: {'lambda_l1': 1.1995862883625372, 'lambda_l2': 6.698297084546612, 'max_depth': 31, 'num_leaves': 44, 'feature_fraction': 0.8193161329747478, 'min_child_samples': 43}. Best is trial 17 with value: 5.084041936459944.
# [I 2024-10-13 20:08:20,828] Trial 43 finished with value: 5.215177594551311 and parameters: {'lambda_l1': 5.253924034309357, 'lambda_l2': 3.4318709225280926, 'max_depth': 19, 'num_leaves': 119, 'feature_fraction': 0.44123712890846883, 'min_child_samples': 47}. Best is trial 17 with value: 5.084041936459944.
# [I 2024-10-13 20:08:20,934] Trial 44 finished with value: 5.198885197022741 and parameters: {'lambda_l1': 7.283309303827439, 'lambda_l2': 7.488947183275922, 'max_depth': 12, 'num_leaves': 29, 'feature_fraction': 0.440996944133391, 'min_child_samples': 24}. Best is trial 17 with value: 5.084041936459944.
# [I 2024-10-13 20:08:21,031] Trial 45 finished with value: 5.2506533144433885 and parameters: {'lambda_l1': 5.937753990987566, 'lambda_l2': 9.27477560665493, 'max_depth': 4, 'num_leaves': 21, 'feature_fraction': 0.08474433830128524, 'min_child_samples': 39}. Best is trial 17 with value: 5.084041936459944.
# [I 2024-10-13 20:08:21,098] Trial 46 finished with value: 5.209020815488917 and parameters: {'lambda_l1': 0.7290652454728227, 'lambda_l2': 0.8353642645311443, 'max_depth': 21, 'num_leaves': 151, 'feature_fraction': 0.3716501369015927, 'min_child_samples': 64}. Best is trial 17 with value: 5.084041936459944.
# [I 2024-10-13 20:08:21,227] Trial 47 finished with value: 5.145135772168472 and parameters: {'lambda_l1': 0.9503729415542443, 'lambda_l2': 5.984877369569943, 'max_depth': 32, 'num_leaves': 222, 'feature_fraction': 0.8846092517107087, 'min_child_samples': 25}. Best is trial 17 with value: 5.084041936459944.
# [I 2024-10-13 20:08:21,315] Trial 48 finished with value: 5.201335698903871 and parameters: {'lambda_l1': 9.98309291492172, 'lambda_l2': 4.09130013452504, 'max_depth': 5, 'num_leaves': 23, 'feature_fraction': 0.5087459183109926, 'min_child_samples': 57}. Best is trial 17 with value: 5.084041936459944.
# [I 2024-10-13 20:08:21,380] Trial 49 finished with value: 5.226218468179429 and parameters: {'lambda_l1': 0.3489931223249833, 'lambda_l2': 5.985095723120339, 'max_depth': 3, 'num_leaves': 47, 'feature_fraction': 0.28627452007117343, 'min_child_samples': 60}. Best is trial 17 with value: 5.084041936459944.
# [I 2024-10-13 20:08:21,566] Trial 50 finished with value: 5.155028460997725 and parameters: {'lambda_l1': 2.4974545259302294, 'lambda_l2': 6.647164857796365, 'max_depth': 31, 'num_leaves': 188, 'feature_fraction': 0.8090975753691572, 'min_child_samples': 25}. Best is trial 17 with value: 5.084041936459944.
# [I 2024-10-13 20:08:21,740] Trial 51 finished with value: 5.146149980645343 and parameters: {'lambda_l1': 0.43868872901441225, 'lambda_l2': 5.809390962282848, 'max_depth': 32, 'num_leaves': 213, 'feature_fraction': 0.8166677140016461, 'min_child_samples': 19}. Best is trial 17 with value: 5.084041936459944.
# [I 2024-10-13 20:08:21,930] Trial 52 finished with value: 5.163341590814618 and parameters: {'lambda_l1': 1.0187254977929043, 'lambda_l2': 4.9979686039455755, 'max_depth': 32, 'num_leaves': 215, 'feature_fraction': 0.8894633134571361, 'min_child_samples': 33}. Best is trial 17 with value: 5.084041936459944.
# [I 2024-10-13 20:08:22,134] Trial 53 finished with value: 5.112661986037204 and parameters: {'lambda_l1': 5.962645558777082, 'lambda_l2': 1.301587109546289, 'max_depth': 30, 'num_leaves': 74, 'feature_fraction': 0.5011095476767647, 'min_child_samples': 6}. Best is trial 17 with value: 5.084041936459944.
# [I 2024-10-13 20:08:22,287] Trial 54 finished with value: 5.125460259390949 and parameters: {'lambda_l1': 6.704666054629926, 'lambda_l2': 1.0397475733065067, 'max_depth': 29, 'num_leaves': 63, 'feature_fraction': 0.41001097992358315, 'min_child_samples': 3}. Best is trial 17 with value: 5.084041936459944.
# [I 2024-10-13 20:08:22,466] Trial 55 finished with value: 5.125069593549095 and parameters: {'lambda_l1': 7.407524014063099, 'lambda_l2': 0.5730260834812104, 'max_depth': 26, 'num_leaves': 63, 'feature_fraction': 0.3950109995030777, 'min_child_samples': 3}. Best is trial 17 with value: 5.084041936459944.
# [I 2024-10-13 20:08:22,643] Trial 56 finished with value: 5.129627489334099 and parameters: {'lambda_l1': 5.352627027196714, 'lambda_l2': 1.9589997971945183, 'max_depth': 28, 'num_leaves': 82, 'feature_fraction': 0.508773817685697, 'min_child_samples': 7}. Best is trial 17 with value: 5.084041936459944.
# [I 2024-10-13 20:08:22,799] Trial 57 finished with value: 5.120147891559624 and parameters: {'lambda_l1': 6.078713317303239, 'lambda_l2': 0.39643852529589185, 'max_depth': 32, 'num_leaves': 84, 'feature_fraction': 0.4320994417852567, 'min_child_samples': 4}. Best is trial 17 with value: 5.084041936459944.
# [I 2024-10-13 20:08:23,040] Trial 58 finished with value: 5.071176617550061 and parameters: {'lambda_l1': 9.17134706669778, 'lambda_l2': 2.2932210460221714, 'max_depth': 24, 'num_leaves': 178, 'feature_fraction': 0.6935440819113158, 'min_child_samples': 2}. Best is trial 58 with value: 5.071176617550061.
# [I 2024-10-13 20:08:23,236] Trial 59 finished with value: 5.1257134351546805 and parameters: {'lambda_l1': 9.874540564767074, 'lambda_l2': 1.0434810808105295, 'max_depth': 26, 'num_leaves': 155, 'feature_fraction': 0.5319705344825514, 'min_child_samples': 4}. Best is trial 58 with value: 5.071176617550061.
# [I 2024-10-13 20:08:23,459] Trial 60 finished with value: 5.1078543098144245 and parameters: {'lambda_l1': 7.443953905069632, 'lambda_l2': 2.5862611897821886, 'max_depth': 27, 'num_leaves': 169, 'feature_fraction': 0.7302265818504203, 'min_child_samples': 3}. Best is trial 58 with value: 5.071176617550061.
# [I 2024-10-13 20:08:23,613] Trial 61 finished with value: 5.15665148166214 and parameters: {'lambda_l1': 8.558891718309395, 'lambda_l2': 3.8203081217961325, 'max_depth': 29, 'num_leaves': 190, 'feature_fraction': 0.7174258828609299, 'min_child_samples': 20}. Best is trial 58 with value: 5.071176617550061.
# [I 2024-10-13 20:08:23,754] Trial 62 finished with value: 5.126557819792391 and parameters: {'lambda_l1': 5.437169518037251, 'lambda_l2': 0.02824018080858548, 'max_depth': 28, 'num_leaves': 126, 'feature_fraction': 0.5445870442951568, 'min_child_samples': 8}. Best is trial 58 with value: 5.071176617550061.
# [I 2024-10-13 20:08:24,001] Trial 63 finished with value: 5.094483539060384 and parameters: {'lambda_l1': 8.033348668400503, 'lambda_l2': 2.945106238391319, 'max_depth': 25, 'num_leaves': 160, 'feature_fraction': 0.5973453111217717, 'min_child_samples': 1}. Best is trial 58 with value: 5.071176617550061.
# [I 2024-10-13 20:08:24,258] Trial 64 finished with value: 5.090463919136607 and parameters: {'lambda_l1': 9.046647645704851, 'lambda_l2': 1.875241075616333, 'max_depth': 25, 'num_leaves': 242, 'feature_fraction': 0.729749255224191, 'min_child_samples': 2}. Best is trial 58 with value: 5.071176617550061.
# [I 2024-10-13 20:08:24,476] Trial 65 finished with value: 5.127314190350442 and parameters: {'lambda_l1': 9.354738530688847, 'lambda_l2': 1.906809400761342, 'max_depth': 24, 'num_leaves': 225, 'feature_fraction': 0.8544160119449153, 'min_child_samples': 8}. Best is trial 58 with value: 5.071176617550061.
# [I 2024-10-13 20:08:24,702] Trial 66 finished with value: 5.097473923633499 and parameters: {'lambda_l1': 5.443410333248247, 'lambda_l2': 1.9038979310518878, 'max_depth': 22, 'num_leaves': 219, 'feature_fraction': 0.7455546812978601, 'min_child_samples': 5}. Best is trial 58 with value: 5.071176617550061.
# [I 2024-10-13 20:08:24,958] Trial 67 finished with value: 5.105599614651933 and parameters: {'lambda_l1': 5.743867483937348, 'lambda_l2': 2.8062479412640347, 'max_depth': 20, 'num_leaves': 221, 'feature_fraction': 0.646120892716971, 'min_child_samples': 2}. Best is trial 58 with value: 5.071176617550061.
# [I 2024-10-13 20:08:25,093] Trial 68 finished with value: 5.157872693675283 and parameters: {'lambda_l1': 8.633494144195057, 'lambda_l2': 0.675165116789175, 'max_depth': 21, 'num_leaves': 234, 'feature_fraction': 0.6270816700069173, 'min_child_samples': 22}. Best is trial 58 with value: 5.071176617550061.
# [I 2024-10-13 20:08:25,385] Trial 69 finished with value: 5.051707340372422 and parameters: {'lambda_l1': 4.805393474132485, 'lambda_l2': 1.694155527580646, 'max_depth': 31, 'num_leaves': 129, 'feature_fraction': 0.9789365193359283, 'min_child_samples': 2}. Best is trial 69 with value: 5.051707340372422.
# [I 2024-10-13 20:08:25,632] Trial 70 finished with value: 5.100573210627066 and parameters: {'lambda_l1': 2.9958826396441522, 'lambda_l2': 3.258562216440123, 'max_depth': 30, 'num_leaves': 116, 'feature_fraction': 0.9060131665968861, 'min_child_samples': 5}. Best is trial 69 with value: 5.051707340372422.
# [I 2024-10-13 20:08:25,758] Trial 71 finished with value: 5.139150847207331 and parameters: {'lambda_l1': 5.256263751804164, 'lambda_l2': 1.6396759139308505, 'max_depth': 27, 'num_leaves': 161, 'feature_fraction': 0.8618077780499482, 'min_child_samples': 21}. Best is trial 69 with value: 5.051707340372422.
# [I 2024-10-13 20:08:26,020] Trial 72 finished with value: 5.081114358327506 and parameters: {'lambda_l1': 3.706234622207631, 'lambda_l2': 2.850217530695995, 'max_depth': 30, 'num_leaves': 133, 'feature_fraction': 0.7784659535590224, 'min_child_samples': 4}. Best is trial 69 with value: 5.051707340372422.
# [I 2024-10-13 20:08:26,245] Trial 73 finished with value: 5.07704804845038 and parameters: {'lambda_l1': 3.9460592567374193, 'lambda_l2': 1.546539271368326, 'max_depth': 31, 'num_leaves': 118, 'feature_fraction': 0.9621618431609688, 'min_child_samples': 5}. Best is trial 69 with value: 5.051707340372422.
# [I 2024-10-13 20:08:26,490] Trial 74 finished with value: 5.086954254926397 and parameters: {'lambda_l1': 4.601483154755253, 'lambda_l2': 3.3553654186882884, 'max_depth': 29, 'num_leaves': 98, 'feature_fraction': 0.8781449557560734, 'min_child_samples': 2}. Best is trial 69 with value: 5.051707340372422.
# [I 2024-10-13 20:08:26,647] Trial 75 finished with value: 5.139083705505175 and parameters: {'lambda_l1': 4.25751954077048, 'lambda_l2': 1.8268934612775976, 'max_depth': 32, 'num_leaves': 134, 'feature_fraction': 0.9263789580203524, 'min_child_samples': 19}. Best is trial 69 with value: 5.051707340372422.
# [I 2024-10-13 20:08:26,887] Trial 76 finished with value: 5.106524706853134 and parameters: {'lambda_l1': 4.4946066387051635, 'lambda_l2': 1.7784017649110258, 'max_depth': 24, 'num_leaves': 87, 'feature_fraction': 0.9609299413235856, 'min_child_samples': 9}. Best is trial 69 with value: 5.051707340372422.
# [I 2024-10-13 20:08:27,149] Trial 77 finished with value: 5.080469946317364 and parameters: {'lambda_l1': 6.373395266279365, 'lambda_l2': 3.535027695984674, 'max_depth': 28, 'num_leaves': 118, 'feature_fraction': 0.9092214641296057, 'min_child_samples': 1}. Best is trial 69 with value: 5.051707340372422.
# [I 2024-10-13 20:08:27,379] Trial 78 finished with value: 5.067229377041066 and parameters: {'lambda_l1': 5.331810979316111, 'lambda_l2': 0.8465812973277496, 'max_depth': 31, 'num_leaves': 101, 'feature_fraction': 0.9770067640946354, 'min_child_samples': 4}. Best is trial 69 with value: 5.051707340372422.
# [I 2024-10-13 20:08:27,573] Trial 79 finished with value: 5.1300788118121785 and parameters: {'lambda_l1': 6.860688150992527, 'lambda_l2': 3.6913194946314496, 'max_depth': 30, 'num_leaves': 81, 'feature_fraction': 0.8753898193488627, 'min_child_samples': 13}. Best is trial 69 with value: 5.051707340372422.
# [I 2024-10-13 20:08:27,735] Trial 80 finished with value: 5.117557912727462 and parameters: {'lambda_l1': 7.708080860555787, 'lambda_l2': 0.03265888179225329, 'max_depth': 29, 'num_leaves': 110, 'feature_fraction': 0.9668489928924692, 'min_child_samples': 12}. Best is trial 69 with value: 5.051707340372422.
# [I 2024-10-13 20:08:28,052] Trial 81 finished with value: 5.087106526963668 and parameters: {'lambda_l1': 6.2421128246564574, 'lambda_l2': 3.5630195311455655, 'max_depth': 26, 'num_leaves': 108, 'feature_fraction': 0.9161176260204296, 'min_child_samples': 4}. Best is trial 69 with value: 5.051707340372422.
# [I 2024-10-13 20:08:28,290] Trial 82 finished with value: 5.105263607783027 and parameters: {'lambda_l1': 5.207244836153768, 'lambda_l2': 3.8160073732256232, 'max_depth': 31, 'num_leaves': 117, 'feature_fraction': 0.9283337334882041, 'min_child_samples': 4}. Best is trial 69 with value: 5.051707340372422.
# [I 2024-10-13 20:08:28,567] Trial 83 finished with value: 5.03430013273175 and parameters: {'lambda_l1': 5.506243831710771, 'lambda_l2': 0.15311901224376445, 'max_depth': 28, 'num_leaves': 97, 'feature_fraction': 0.9373547824944699, 'min_child_samples': 2}. Best is trial 83 with value: 5.03430013273175.
# [I 2024-10-13 20:08:28,782] Trial 84 finished with value: 5.04031076922303 and parameters: {'lambda_l1': 4.297835641208106, 'lambda_l2': 0.08656599687516009, 'max_depth': 24, 'num_leaves': 91, 'feature_fraction': 0.9992434185151621, 'min_child_samples': 3}. Best is trial 83 with value: 5.03430013273175.
# [I 2024-10-13 20:08:28,990] Trial 85 finished with value: 5.09681957301637 and parameters: {'lambda_l1': 5.657217275804474, 'lambda_l2': 1.0428424509983185, 'max_depth': 31, 'num_leaves': 100, 'feature_fraction': 0.9821393164552101, 'min_child_samples': 9}. Best is trial 83 with value: 5.03430013273175.
# [I 2024-10-13 20:08:29,181] Trial 86 finished with value: 5.090548450049368 and parameters: {'lambda_l1': 4.745916793455049, 'lambda_l2': 0.1069178174682343, 'max_depth': 29, 'num_leaves': 48, 'feature_fraction': 0.8073921478912669, 'min_child_samples': 8}. Best is trial 83 with value: 5.03430013273175.
# [I 2024-10-13 20:08:29,357] Trial 87 finished with value: 5.124147037152386 and parameters: {'lambda_l1': 3.270114690606371, 'lambda_l2': 1.2587421424138778, 'max_depth': 24, 'num_leaves': 151, 'feature_fraction': 0.9659482944201487, 'min_child_samples': 16}. Best is trial 83 with value: 5.03430013273175.
# [I 2024-10-13 20:08:29,682] Trial 88 finished with value: 5.031051114526713 and parameters: {'lambda_l1': 3.4365695009240613, 'lambda_l2': 1.1995348328436028, 'max_depth': 24, 'num_leaves': 141, 'feature_fraction': 0.7392863105807003, 'min_child_samples': 2}. Best is trial 88 with value: 5.031051114526713.
# [I 2024-10-13 20:08:29,918] Trial 89 finished with value: 5.042099208121005 and parameters: {'lambda_l1': 4.0456156319213035, 'lambda_l2': 0.26196027754391826, 'max_depth': 25, 'num_leaves': 85, 'feature_fraction': 0.9480629183770526, 'min_child_samples': 3}. Best is trial 88 with value: 5.031051114526713.
# [I 2024-10-13 20:08:30,060] Trial 90 finished with value: 5.130514603692466 and parameters: {'lambda_l1': 3.917957248950354, 'lambda_l2': 0.38776182641021617, 'max_depth': 23, 'num_leaves': 99, 'feature_fraction': 0.8375281796391123, 'min_child_samples': 18}. Best is trial 88 with value: 5.031051114526713.
# [I 2024-10-13 20:08:30,240] Trial 91 finished with value: 5.069918766749895 and parameters: {'lambda_l1': 3.161727916034426, 'lambda_l2': 0.20324760298192412, 'max_depth': 27, 'num_leaves': 109, 'feature_fraction': 0.9355856264070507, 'min_child_samples': 5}. Best is trial 88 with value: 5.031051114526713.
# [I 2024-10-13 20:08:30,553] Trial 92 finished with value: 5.059434924780233 and parameters: {'lambda_l1': 0.526208548424834, 'lambda_l2': 0.690583671617969, 'max_depth': 30, 'num_leaves': 148, 'feature_fraction': 0.9038832599808724, 'min_child_samples': 1}. Best is trial 88 with value: 5.031051114526713.
# [I 2024-10-13 20:08:30,804] Trial 93 finished with value: 5.0813147942661585 and parameters: {'lambda_l1': 0.47511317726849045, 'lambda_l2': 1.9830508032650642, 'max_depth': 27, 'num_leaves': 159, 'feature_fraction': 0.928198003401783, 'min_child_samples': 3}. Best is trial 88 with value: 5.031051114526713.
# [I 2024-10-13 20:08:31,039] Trial 94 finished with value: 5.071694588670019 and parameters: {'lambda_l1': 1.9958521746527338, 'lambda_l2': 0.07799566133989855, 'max_depth': 32, 'num_leaves': 93, 'feature_fraction': 0.9985054977516354, 'min_child_samples': 10}. Best is trial 88 with value: 5.031051114526713.
# [I 2024-10-13 20:08:31,261] Trial 95 finished with value: 5.075837998694252 and parameters: {'lambda_l1': 0.44764265976148687, 'lambda_l2': 0.3623297013383904, 'max_depth': 29, 'num_leaves': 103, 'feature_fraction': 0.9219483288218157, 'min_child_samples': 8}. Best is trial 88 with value: 5.031051114526713.
# [I 2024-10-13 20:08:31,504] Trial 96 finished with value: 5.025061545364789 and parameters: {'lambda_l1': 4.45001726806905, 'lambda_l2': 0.15325077982355767, 'max_depth': 27, 'num_leaves': 64, 'feature_fraction': 0.9020388823361755, 'min_child_samples': 2}. Best is trial 96 with value: 5.025061545364789.
# [I 2024-10-13 20:08:31,733] Trial 97 finished with value: 5.067893233489577 and parameters: {'lambda_l1': 1.6551195848687796, 'lambda_l2': 1.1392178504894903, 'max_depth': 20, 'num_leaves': 97, 'feature_fraction': 0.8617555376528072, 'min_child_samples': 3}. Best is trial 96 with value: 5.025061545364789.
# [I 2024-10-13 20:08:32,024] Trial 98 finished with value: 5.0418137329564106 and parameters: {'lambda_l1': 3.4622140682406792, 'lambda_l2': 0.28492573529768506, 'max_depth': 27, 'num_leaves': 68, 'feature_fraction': 0.8647024994390715, 'min_child_samples': 1}. Best is trial 96 with value: 5.025061545364789.
# [I 2024-10-13 20:08:32,259] Trial 99 finished with value: 5.118013101421468 and parameters: {'lambda_l1': 6.1781100447679735, 'lambda_l2': 1.3318098794931092, 'max_depth': 19, 'num_leaves': 71, 'feature_fraction': 0.8008214619154553, 'min_child_samples': 9}. Best is trial 96 with value: 5.025061545364789.
# [I 2024-10-13 20:08:32,419] Trial 100 finished with value: 5.120591380663819 and parameters: {'lambda_l1': 1.9530288379260896, 'lambda_l2': 0.5005553653954965, 'max_depth': 16, 'num_leaves': 113, 'feature_fraction': 0.8228751092857773, 'min_child_samples': 15}. Best is trial 96 with value: 5.025061545364789.
# [I 2024-10-13 20:08:32,622] Trial 101 finished with value: 5.097848638381663 and parameters: {'lambda_l1': 1.8150476043276687, 'lambda_l2': 0.2611527233003529, 'max_depth': 27, 'num_leaves': 80, 'feature_fraction': 0.692618143816062, 'min_child_samples': 9}. Best is trial 96 with value: 5.025061545364789.
# [I 2024-10-13 20:08:32,839] Trial 102 finished with value: 5.062134215123099 and parameters: {'lambda_l1': 3.6367041726207487, 'lambda_l2': 0.7332833637363463, 'max_depth': 23, 'num_leaves': 137, 'feature_fraction': 0.8049843338466702, 'min_child_samples': 4}. Best is trial 96 with value: 5.025061545364789.
# [I 2024-10-13 20:08:33,086] Trial 103 finished with value: 5.081560428996747 and parameters: {'lambda_l1': 2.6395770965328866, 'lambda_l2': 0.7036757706005978, 'max_depth': 20, 'num_leaves': 79, 'feature_fraction': 0.8289829268101773, 'min_child_samples': 3}. Best is trial 96 with value: 5.025061545364789.
# [I 2024-10-13 20:08:33,300] Trial 104 finished with value: 5.074630940853655 and parameters: {'lambda_l1': 5.868730881329217, 'lambda_l2': 0.3926627905554755, 'max_depth': 18, 'num_leaves': 106, 'feature_fraction': 0.9133884297072441, 'min_child_samples': 3}. Best is trial 96 with value: 5.025061545364789.
# [I 2024-10-13 20:08:33,479] Trial 105 finished with value: 5.110114349509802 and parameters: {'lambda_l1': 6.769203623324353, 'lambda_l2': 0.2665025441530582, 'max_depth': 25, 'num_leaves': 50, 'feature_fraction': 0.9754589548642643, 'min_child_samples': 11}. Best is trial 96 with value: 5.025061545364789.
# [I 2024-10-13 20:08:33,828] Trial 106 finished with value: 5.024649487032332 and parameters: {'lambda_l1': 2.584795014449286, 'lambda_l2': 0.6867793853662342, 'max_depth': 22, 'num_leaves': 150, 'feature_fraction': 0.8284674208215023, 'min_child_samples': 1}. Best is trial 106 with value: 5.024649487032332.
# [I 2024-10-13 20:08:34,138] Trial 107 finished with value: 5.037807619277341 and parameters: {'lambda_l1': 4.375906256086994, 'lambda_l2': 1.1333273873928855, 'max_depth': 29, 'num_leaves': 56, 'feature_fraction': 0.9578734615276964, 'min_child_samples': 2}. Best is trial 106 with value: 5.024649487032332.
# [I 2024-10-13 20:08:34,287] Trial 108 finished with value: 5.112974036381395 and parameters: {'lambda_l1': 1.958595845029125, 'lambda_l2': 2.410657179021408, 'max_depth': 23, 'num_leaves': 168, 'feature_fraction': 0.6821837539656287, 'min_child_samples': 12}. Best is trial 106 with value: 5.024649487032332.
# [I 2024-10-13 20:08:34,460] Trial 109 finished with value: 5.091588475190272 and parameters: {'lambda_l1': 3.9618435904050964, 'lambda_l2': 0.07407390890452888, 'max_depth': 22, 'num_leaves': 17, 'feature_fraction': 0.8850660546917779, 'min_child_samples': 5}. Best is trial 106 with value: 5.024649487032332.
# [I 2024-10-13 20:08:34,726] Trial 110 finished with value: 5.085166426057744 and parameters: {'lambda_l1': 2.8723987448732204, 'lambda_l2': 0.8206660323214183, 'max_depth': 23, 'num_leaves': 146, 'feature_fraction': 0.6037809437637731, 'min_child_samples': 4}. Best is trial 106 with value: 5.024649487032332.
# [I 2024-10-13 20:08:34,940] Trial 111 finished with value: 5.075699016620683 and parameters: {'lambda_l1': 3.9120155130574834, 'lambda_l2': 0.565115057054706, 'max_depth': 31, 'num_leaves': 58, 'feature_fraction': 0.9840494062252452, 'min_child_samples': 6}. Best is trial 106 with value: 5.024649487032332.
# [I 2024-10-13 20:08:35,244] Trial 112 finished with value: 5.0486730432708224 and parameters: {'lambda_l1': 4.5821687715503705, 'lambda_l2': 0.8277005352990012, 'max_depth': 21, 'num_leaves': 89, 'feature_fraction': 0.9307168459421314, 'min_child_samples': 3}. Best is trial 106 with value: 5.024649487032332.
# [I 2024-10-13 20:08:35,497] Trial 113 finished with value: 5.047883144897959 and parameters: {'lambda_l1': 3.203264305822657, 'lambda_l2': 0.5045020194915089, 'max_depth': 22, 'num_leaves': 86, 'feature_fraction': 0.9853191256661396, 'min_child_samples': 4}. Best is trial 106 with value: 5.024649487032332.
# [I 2024-10-13 20:08:35,639] Trial 114 finished with value: 5.148132175268374 and parameters: {'lambda_l1': 3.1225345373898525, 'lambda_l2': 1.3360354708352182, 'max_depth': 24, 'num_leaves': 27, 'feature_fraction': 0.9750434189095057, 'min_child_samples': 26}. Best is trial 106 with value: 5.024649487032332.
# [I 2024-10-13 20:08:35,909] Trial 115 finished with value: 5.049807793396068 and parameters: {'lambda_l1': 1.356128106327564, 'lambda_l2': 0.6884092985127427, 'max_depth': 26, 'num_leaves': 178, 'feature_fraction': 0.7220198938429251, 'min_child_samples': 1}. Best is trial 106 with value: 5.024649487032332.
# [I 2024-10-13 20:08:36,136] Trial 116 finished with value: 5.089626041892279 and parameters: {'lambda_l1': 0.7089596847588786, 'lambda_l2': 0.2124586338975295, 'max_depth': 29, 'num_leaves': 218, 'feature_fraction': 0.6788597289040019, 'min_child_samples': 9}. Best is trial 106 with value: 5.024649487032332.
# [I 2024-10-13 20:08:36,360] Trial 117 finished with value: 5.083823086328851 and parameters: {'lambda_l1': 5.6838315937807735, 'lambda_l2': 1.0106125235062755, 'max_depth': 24, 'num_leaves': 64, 'feature_fraction': 0.9507053682127438, 'min_child_samples': 5}. Best is trial 106 with value: 5.024649487032332.
# [I 2024-10-13 20:08:36,622] Trial 118 finished with value: 5.0759212683997905 and parameters: {'lambda_l1': 3.5875631601362006, 'lambda_l2': 2.1371958196048277, 'max_depth': 19, 'num_leaves': 74, 'feature_fraction': 0.9909142790985321, 'min_child_samples': 4}. Best is trial 106 with value: 5.024649487032332.
# [I 2024-10-13 20:08:36,926] Trial 119 finished with value: 5.0648884109607275 and parameters: {'lambda_l1': 1.7921646917462892, 'lambda_l2': 2.5666300959314787, 'max_depth': 15, 'num_leaves': 231, 'feature_fraction': 0.7297301385138554, 'min_child_samples': 2}. Best is trial 106 with value: 5.024649487032332.
# [I 2024-10-13 20:08:37,299] Trial 120 finished with value: 5.008749655660528 and parameters: {'lambda_l1': 2.9442956110218996, 'lambda_l2': 0.5801951069481239, 'max_depth': 21, 'num_leaves': 109, 'feature_fraction': 0.9856809475650035, 'min_child_samples': 2}. Best is trial 120 with value: 5.008749655660528.
# [I 2024-10-13 20:08:37,537] Trial 121 finished with value: 5.102707121740157 and parameters: {'lambda_l1': 3.9166531128982682, 'lambda_l2': 0.23641054778380036, 'max_depth': 13, 'num_leaves': 79, 'feature_fraction': 0.9490505788254268, 'min_child_samples': 12}. Best is trial 120 with value: 5.008749655660528.
# [I 2024-10-13 20:08:37,843] Trial 122 finished with value: 5.04702180129831 and parameters: {'lambda_l1': 2.7353525967137746, 'lambda_l2': 0.1397160679960367, 'max_depth': 21, 'num_leaves': 120, 'feature_fraction': 0.8606039034212792, 'min_child_samples': 5}. Best is trial 120 with value: 5.008749655660528.
# [I 2024-10-13 20:08:38,223] Trial 123 finished with value: 5.028085613594191 and parameters: {'lambda_l1': 4.724322017208472, 'lambda_l2': 1.1985587180604984, 'max_depth': 23, 'num_leaves': 116, 'feature_fraction': 0.7820461981885339, 'min_child_samples': 2}. Best is trial 120 with value: 5.008749655660528.
# [I 2024-10-13 20:08:38,426] Trial 124 finished with value: 5.11951760787562 and parameters: {'lambda_l1': 4.23671855112073, 'lambda_l2': 0.1017128484387636, 'max_depth': 23, 'num_leaves': 124, 'feature_fraction': 0.840907769362734, 'min_child_samples': 16}. Best is trial 120 with value: 5.008749655660528.
# [I 2024-10-13 20:08:38,733] Trial 125 finished with value: 5.070276097353301 and parameters: {'lambda_l1': 4.328996503913418, 'lambda_l2': 1.2143516928262144, 'max_depth': 18, 'num_leaves': 126, 'feature_fraction': 0.8760416996133322, 'min_child_samples': 5}. Best is trial 120 with value: 5.008749655660528.
# [I 2024-10-13 20:08:39,171] Trial 126 finished with value: 4.992087619203966 and parameters: {'lambda_l1': 3.721389307932038, 'lambda_l2': 0.08797783489740854, 'max_depth': 19, 'num_leaves': 110, 'feature_fraction': 0.8461368198509444, 'min_child_samples': 1}. Best is trial 126 with value: 4.992087619203966.
# [I 2024-10-13 20:08:39,566] Trial 127 finished with value: 5.05271149793996 and parameters: {'lambda_l1': 5.253173406468468, 'lambda_l2': 0.16282282377202012, 'max_depth': 19, 'num_leaves': 144, 'feature_fraction': 0.9105205768864267, 'min_child_samples': 3}. Best is trial 126 with value: 4.992087619203966.
# [I 2024-10-13 20:08:39,877] Trial 128 finished with value: 5.076819244847937 and parameters: {'lambda_l1': 2.124418557825174, 'lambda_l2': 1.2405073097311066, 'max_depth': 14, 'num_leaves': 166, 'feature_fraction': 0.8832954506405722, 'min_child_samples': 5}. Best is trial 126 with value: 4.992087619203966.
# [I 2024-10-13 20:08:40,133] Trial 129 finished with value: 5.085223041729737 and parameters: {'lambda_l1': 4.628426314557547, 'lambda_l2': 0.8017734783706807, 'max_depth': 25, 'num_leaves': 98, 'feature_fraction': 0.6720410324700679, 'min_child_samples': 5}. Best is trial 126 with value: 4.992087619203966.
# [I 2024-10-13 20:08:40,391] Trial 130 finished with value: 5.114836576770171 and parameters: {'lambda_l1': 2.9834551073295863, 'lambda_l2': 1.1802239734468891, 'max_depth': 24, 'num_leaves': 117, 'feature_fraction': 0.9167485372867247, 'min_child_samples': 10}. Best is trial 126 with value: 4.992087619203966.
# [I 2024-10-13 20:08:40,673] Trial 131 finished with value: 5.071060347312746 and parameters: {'lambda_l1': 4.917864744057886, 'lambda_l2': 2.717168041568657, 'max_depth': 24, 'num_leaves': 14, 'feature_fraction': 0.9593765068688622, 'min_child_samples': 2}. Best is trial 126 with value: 4.992087619203966.
# [I 2024-10-13 20:08:41,018] Trial 132 finished with value: 5.0546472976957055 and parameters: {'lambda_l1': 3.0933989687210257, 'lambda_l2': 1.0666854230623768, 'max_depth': 24, 'num_leaves': 48, 'feature_fraction': 0.8788316222024315, 'min_child_samples': 2}. Best is trial 126 with value: 4.992087619203966.
# [I 2024-10-13 20:08:41,374] Trial 133 finished with value: 5.096080027404905 and parameters: {'lambda_l1': 3.08719258522752, 'lambda_l2': 3.6372507226736617, 'max_depth': 18, 'num_leaves': 117, 'feature_fraction': 0.5839468168269162, 'min_child_samples': 1}. Best is trial 126 with value: 4.992087619203966.
# [I 2024-10-13 20:08:41,612] Trial 134 finished with value: 5.125508674532522 and parameters: {'lambda_l1': 4.995755009911485, 'lambda_l2': 0.30081007965692497, 'max_depth': 26, 'num_leaves': 80, 'feature_fraction': 0.927506495624127, 'min_child_samples': 16}. Best is trial 126 with value: 4.992087619203966.
# [I 2024-10-13 20:08:42,006] Trial 135 finished with value: 5.068108589006859 and parameters: {'lambda_l1': 4.555600076505677, 'lambda_l2': 1.9128192803584518, 'max_depth': 25, 'num_leaves': 75, 'feature_fraction': 0.966778597019909, 'min_child_samples': 3}. Best is trial 126 with value: 4.992087619203966.
# [I 2024-10-13 20:08:42,258] Trial 136 finished with value: 5.115495915595885 and parameters: {'lambda_l1': 3.8955783820497376, 'lambda_l2': 0.06563340833088731, 'max_depth': 21, 'num_leaves': 54, 'feature_fraction': 0.852725863633388, 'min_child_samples': 13}. Best is trial 126 with value: 4.992087619203966.
# [I 2024-10-13 20:08:42,594] Trial 137 finished with value: 5.0395988608111235 and parameters: {'lambda_l1': 5.819840289809486, 'lambda_l2': 0.09360838341467392, 'max_depth': 23, 'num_leaves': 92, 'feature_fraction': 0.7914105806638988, 'min_child_samples': 2}. Best is trial 126 with value: 4.992087619203966.
# [I 2024-10-13 20:08:42,962] Trial 138 finished with value: 5.0266671437307275 and parameters: {'lambda_l1': 2.653190791700083, 'lambda_l2': 0.025774903074993638, 'max_depth': 25, 'num_leaves': 95, 'feature_fraction': 0.8534724370907774, 'min_child_samples': 2}. Best is trial 126 with value: 4.992087619203966.
# [I 2024-10-13 20:08:43,135] Trial 139 finished with value: 5.199169337107912 and parameters: {'lambda_l1': 4.944518129895443, 'lambda_l2': 0.5682586736549999, 'max_depth': 12, 'num_leaves': 128, 'feature_fraction': 0.48085482287254794, 'min_child_samples': 31}. Best is trial 126 with value: 4.992087619203966.
# [I 2024-10-13 20:08:43,490] Trial 140 finished with value: 5.07122964214465 and parameters: {'lambda_l1': 3.0735402638977347, 'lambda_l2': 0.8849390260046515, 'max_depth': 19, 'num_leaves': 138, 'feature_fraction': 0.8397330399129662, 'min_child_samples': 6}. Best is trial 126 with value: 4.992087619203966.
# [I 2024-10-13 20:08:43,804] Trial 141 finished with value: 5.063002677408615 and parameters: {'lambda_l1': 6.089007490454234, 'lambda_l2': 0.41919315612636954, 'max_depth': 15, 'num_leaves': 114, 'feature_fraction': 0.6385307325185958, 'min_child_samples': 1}. Best is trial 126 with value: 4.992087619203966.
# [I 2024-10-13 20:08:44,191] Trial 142 finished with value: 5.039218432961077 and parameters: {'lambda_l1': 3.3647676805812203, 'lambda_l2': 1.4630453295244794, 'max_depth': 26, 'num_leaves': 77, 'feature_fraction': 0.9121198282425138, 'min_child_samples': 2}. Best is trial 126 with value: 4.992087619203966.
# [I 2024-10-13 20:08:44,480] Trial 143 finished with value: 5.078768754071562 and parameters: {'lambda_l1': 1.9812307980999209, 'lambda_l2': 0.6064085705393342, 'max_depth': 20, 'num_leaves': 138, 'feature_fraction': 0.9036507475602492, 'min_child_samples': 8}. Best is trial 126 with value: 4.992087619203966.
# [I 2024-10-13 20:08:44,749] Trial 144 finished with value: 5.091558811424806 and parameters: {'lambda_l1': 4.826301397177838, 'lambda_l2': 0.057331794025859306, 'max_depth': 27, 'num_leaves': 101, 'feature_fraction': 0.9339981407244019, 'min_child_samples': 7}. Best is trial 126 with value: 4.992087619203966.
# [I 2024-10-13 20:08:45,130] Trial 145 finished with value: 5.026249559928473 and parameters: {'lambda_l1': 4.077629012901103, 'lambda_l2': 0.17148010214421763, 'max_depth': 27, 'num_leaves': 93, 'feature_fraction': 0.7998822807837018, 'min_child_samples': 2}. Best is trial 126 with value: 4.992087619203966.
# [I 2024-10-13 20:08:45,472] Trial 146 finished with value: 5.001156293437246 and parameters: {'lambda_l1': 3.678951364603675, 'lambda_l2': 0.18811002044414477, 'max_depth': 26, 'num_leaves': 93, 'feature_fraction': 0.8059600058375833, 'min_child_samples': 1}. Best is trial 126 with value: 4.992087619203966.
# [I 2024-10-13 20:08:45,668] Trial 147 finished with value: 5.140643293719892 and parameters: {'lambda_l1': 2.975545626652832, 'lambda_l2': 3.9886871970849898, 'max_depth': 30, 'num_leaves': 56, 'feature_fraction': 0.8884391565448386, 'min_child_samples': 22}. Best is trial 126 with value: 4.992087619203966.
# [I 2024-10-13 20:08:45,851] Trial 148 finished with value: 5.099167445559763 and parameters: {'lambda_l1': 5.571662224290113, 'lambda_l2': 0.05027767671034531, 'max_depth': 22, 'num_leaves': 64, 'feature_fraction': 0.766745913019306, 'min_child_samples': 6}. Best is trial 126 with value: 4.992087619203966.
# [I 2024-10-13 20:08:46,082] Trial 149 finished with value: 5.091779643466972 and parameters: {'lambda_l1': 1.9316858662777407, 'lambda_l2': 3.0253361551965314, 'max_depth': 23, 'num_leaves': 62, 'feature_fraction': 0.6525535079943694, 'min_child_samples': 4}. Best is trial 126 with value: 4.992087619203966.
# [I 2024-10-13 20:08:46,315] Trial 150 finished with value: 5.01522796590408 and parameters: {'lambda_l1': 2.239634754565458, 'lambda_l2': 0.051907598189182114, 'max_depth': 30, 'num_leaves': 58, 'feature_fraction': 0.6682547277064786, 'min_child_samples': 1}. Best is trial 126 with value: 4.992087619203966.
# [I 2024-10-13 20:08:46,643] Trial 151 finished with value: 5.062282321214472 and parameters: {'lambda_l1': 2.994810062544188, 'lambda_l2': 1.417909523261297, 'max_depth': 32, 'num_leaves': 56, 'feature_fraction': 0.5016073810389848, 'min_child_samples': 1}. Best is trial 126 with value: 4.992087619203966.
# [I 2024-10-13 20:08:46,839] Trial 152 finished with value: 5.128798779768544 and parameters: {'lambda_l1': 1.0446722510045863, 'lambda_l2': 0.44604248691922227, 'max_depth': 29, 'num_leaves': 50, 'feature_fraction': 0.6847881612574072, 'min_child_samples': 15}. Best is trial 126 with value: 4.992087619203966.
# [I 2024-10-13 20:08:47,063] Trial 153 finished with value: 5.112785920891479 and parameters: {'lambda_l1': 4.181669942479741, 'lambda_l2': 1.1799936471523447, 'max_depth': 31, 'num_leaves': 48, 'feature_fraction': 0.7858186096917386, 'min_child_samples': 10}. Best is trial 126 with value: 4.992087619203966.
# ...
# [I 2024-10-13 20:09:54,428] Trial 449 finished with value: 5.1621368454685115 and parameters: {'lambda_l1': 8.082460712839072, 'lambda_l2': 6.4399680699560085, 'max_depth': 7, 'num_leaves': 29, 'feature_fraction': 0.5632714411004652, 'min_child_samples': 15}. Best is trial 310 with value: 4.989028334001922.
# [I 2024-10-13 20:09:54,608] Trial 450 finished with value: 5.257442831368403 and parameters: {'lambda_l1': 7.427363369267384, 'lambda_l2': 2.4283518159662165, 'max_depth': 11, 'num_leaves': 107, 'feature_fraction': 0.20215005161968536, 'min_child_samples': 76}. Best is trial 310 with value: 4.989028334001922.
# [I 2024-10-13 20:09:54,858] Trial 451 finished with value: 5.13845388421579 and parameters: {'lambda_l1': 3.428442838028995, 'lambda_l2': 4.317747527307546, 'max_depth': 22, 'num_leaves': 40, 'feature_fraction': 0.7476751320893633, 'min_child_samples': 17}. Best is trial 310 with value: 4.989028334001922.
# [I 2024-10-13 20:09:55,090] Trial 452 finished with value: 5.142103727728843 and parameters: {'lambda_l1': 5.272013157723483, 'lambda_l2': 2.142394978333413, 'max_depth': 8, 'num_leaves': 254, 'feature_fraction': 0.6062254418816222, 'min_child_samples': 12}. Best is trial 310 with value: 4.989028334001922.
# [I 2024-10-13 20:09:55,326] Trial 453 finished with value: 5.2183215026392356 and parameters: {'lambda_l1': 4.165511878525691, 'lambda_l2': 2.3355350533863493, 'max_depth': 12, 'num_leaves': 33, 'feature_fraction': 0.43948585579063165, 'min_child_samples': 47}. Best is trial 310 with value: 4.989028334001922.
# [I 2024-10-13 20:09:55,669] Trial 454 finished with value: 5.081418955639395 and parameters: {'lambda_l1': 0.11665695967639039, 'lambda_l2': 1.908887145107673, 'max_depth': 15, 'num_leaves': 228, 'feature_fraction': 0.8670019718008312, 'min_child_samples': 4}. Best is trial 310 with value: 4.989028334001922.
# [I 2024-10-13 20:09:55,828] Trial 455 finished with value: 5.199433698677471 and parameters: {'lambda_l1': 3.4091878211637408, 'lambda_l2': 7.696486974487664, 'max_depth': 24, 'num_leaves': 66, 'feature_fraction': 0.4813301274129804, 'min_child_samples': 33}. Best is trial 310 with value: 4.989028334001922.
# [I 2024-10-13 20:09:56,042] Trial 456 finished with value: 5.067522633448996 and parameters: {'lambda_l1': 3.991743325042859, 'lambda_l2': 0.028642450045053724, 'max_depth': 6, 'num_leaves': 48, 'feature_fraction': 0.8957882925574634, 'min_child_samples': 3}. Best is trial 310 with value: 4.989028334001922.
# [I 2024-10-13 20:09:56,355] Trial 457 finished with value: 5.08424427962829 and parameters: {'lambda_l1': 0.8279838607064958, 'lambda_l2': 2.5019887137482284, 'max_depth': 27, 'num_leaves': 76, 'feature_fraction': 0.5472166376239136, 'min_child_samples': 2}. Best is trial 310 with value: 4.989028334001922.
# [I 2024-10-13 20:09:56,490] Trial 458 finished with value: 5.181682159388359 and parameters: {'lambda_l1': 1.8549183847699326, 'lambda_l2': 1.1265611441209573, 'max_depth': 22, 'num_leaves': 130, 'feature_fraction': 0.9314979912418564, 'min_child_samples': 52}. Best is trial 310 with value: 4.989028334001922.
# [I 2024-10-13 20:09:56,672] Trial 459 finished with value: 5.170318990795087 and parameters: {'lambda_l1': 0.29728974101775574, 'lambda_l2': 3.7877077924297184, 'max_depth': 24, 'num_leaves': 152, 'feature_fraction': 0.26418683700491963, 'min_child_samples': 1}. Best is trial 310 with value: 4.989028334001922.
# [I 2024-10-13 20:09:56,862] Trial 460 finished with value: 5.188630456963512 and parameters: {'lambda_l1': 4.636944584664121, 'lambda_l2': 0.052104751104045555, 'max_depth': 14, 'num_leaves': 187, 'feature_fraction': 0.8775712376339331, 'min_child_samples': 59}. Best is trial 310 with value: 4.989028334001922.
# [I 2024-10-13 20:09:57,063] Trial 461 finished with value: 5.150599237488039 and parameters: {'lambda_l1': 3.2043288096893856, 'lambda_l2': 2.2351298553224486, 'max_depth': 12, 'num_leaves': 36, 'feature_fraction': 0.5888246799803922, 'min_child_samples': 20}. Best is trial 310 with value: 4.989028334001922.
# [I 2024-10-13 20:09:57,382] Trial 462 finished with value: 5.0813108824418505 and parameters: {'lambda_l1': 3.329540613520787, 'lambda_l2': 1.6740105248718147, 'max_depth': 14, 'num_leaves': 160, 'feature_fraction': 0.732696913868261, 'min_child_samples': 6}. Best is trial 310 with value: 4.989028334001922.
# [I 2024-10-13 20:09:57,634] Trial 463 finished with value: 5.041379011682284 and parameters: {'lambda_l1': 0.10709454368649673, 'lambda_l2': 0.048345525290666276, 'max_depth': 11, 'num_leaves': 62, 'feature_fraction': 0.6363153484924312, 'min_child_samples': 3}. Best is trial 310 with value: 4.989028334001922.
# [I 2024-10-13 20:09:57,801] Trial 464 finished with value: 5.178623843397965 and parameters: {'lambda_l1': 0.5629707341188599, 'lambda_l2': 5.476638436620238, 'max_depth': 30, 'num_leaves': 28, 'feature_fraction': 0.9745637457179854, 'min_child_samples': 48}. Best is trial 310 with value: 4.989028334001922.
# [I 2024-10-13 20:09:58,086] Trial 465 finished with value: 5.05634554122823 and parameters: {'lambda_l1': 1.3493457698096094, 'lambda_l2': 0.26961456144004325, 'max_depth': 13, 'num_leaves': 49, 'feature_fraction': 0.8972712836919703, 'min_child_samples': 5}. Best is trial 310 with value: 4.989028334001922.
# [I 2024-10-13 20:09:58,248] Trial 466 finished with value: 5.205176958387428 and parameters: {'lambda_l1': 5.920121517789007, 'lambda_l2': 8.544589206275806, 'max_depth': 30, 'num_leaves': 114, 'feature_fraction': 0.7459289193913636, 'min_child_samples': 73}. Best is trial 310 with value: 4.989028334001922.
# [I 2024-10-13 20:09:58,414] Trial 467 finished with value: 5.164247720471888 and parameters: {'lambda_l1': 1.588501191760828, 'lambda_l2': 0.599062617186739, 'max_depth': 32, 'num_leaves': 13, 'feature_fraction': 0.9657531180506711, 'min_child_samples': 26}. Best is trial 310 with value: 4.989028334001922.
# [I 2024-10-13 20:09:58,615] Trial 468 finished with value: 5.181873107771895 and parameters: {'lambda_l1': 3.873335394194741, 'lambda_l2': 5.180828371615524, 'max_depth': 10, 'num_leaves': 151, 'feature_fraction': 0.5208501594015804, 'min_child_samples': 32}. Best is trial 310 with value: 4.989028334001922.
# [I 2024-10-13 20:09:58,780] Trial 469 finished with value: 5.257626036745381 and parameters: {'lambda_l1': 9.862354439935034, 'lambda_l2': 3.6091335138975835, 'max_depth': 2, 'num_leaves': 53, 'feature_fraction': 0.7580805650068398, 'min_child_samples': 80}. Best is trial 310 with value: 4.989028334001922.
# [I 2024-10-13 20:09:58,929] Trial 470 finished with value: 5.181456498468306 and parameters: {'lambda_l1': 6.719068331183089, 'lambda_l2': 4.548738540318646, 'max_depth': 14, 'num_leaves': 6, 'feature_fraction': 0.8273381166610531, 'min_child_samples': 6}. Best is trial 310 with value: 4.989028334001922.
# [I 2024-10-13 20:09:59,082] Trial 471 finished with value: 5.16795466774002 and parameters: {'lambda_l1': 2.570019962871608, 'lambda_l2': 4.7981154661234005, 'max_depth': 5, 'num_leaves': 20, 'feature_fraction': 0.8136570934435581, 'min_child_samples': 25}. Best is trial 310 with value: 4.989028334001922.
# [I 2024-10-13 20:09:59,278] Trial 472 finished with value: 5.182256533722716 and parameters: {'lambda_l1': 6.426217206056344, 'lambda_l2': 7.130301427347504, 'max_depth': 11, 'num_leaves': 108, 'feature_fraction': 0.36203756591458836, 'min_child_samples': 25}. Best is trial 310 with value: 4.989028334001922.
# [I 2024-10-13 20:09:59,532] Trial 473 finished with value: 5.121757548595495 and parameters: {'lambda_l1': 1.7020400246541991, 'lambda_l2': 4.583227039182729, 'max_depth': 25, 'num_leaves': 202, 'feature_fraction': 0.952728331866555, 'min_child_samples': 12}. Best is trial 310 with value: 4.989028334001922.
# [I 2024-10-13 20:09:59,743] Trial 474 finished with value: 5.105549805126122 and parameters: {'lambda_l1': 0.0017527453784797649, 'lambda_l2': 1.7323531159405898, 'max_depth': 9, 'num_leaves': 76, 'feature_fraction': 0.8388983446602019, 'min_child_samples': 11}. Best is trial 310 with value: 4.989028334001922.
# [I 2024-10-13 20:09:59,898] Trial 475 finished with value: 5.207410085263158 and parameters: {'lambda_l1': 9.993373509318133, 'lambda_l2': 2.2838702429630335, 'max_depth': 3, 'num_leaves': 162, 'feature_fraction': 0.3454566392240625, 'min_child_samples': 11}. Best is trial 310 with value: 4.989028334001922.
# [I 2024-10-13 20:10:00,098] Trial 476 finished with value: 5.134149346797401 and parameters: {'lambda_l1': 1.2762952406276198, 'lambda_l2': 6.512311905694999, 'max_depth': 26, 'num_leaves': 24, 'feature_fraction': 0.8123854696503667, 'min_child_samples': 9}. Best is trial 310 with value: 4.989028334001922.
# [I 2024-10-13 20:10:00,347] Trial 477 finished with value: 5.1201860920742 and parameters: {'lambda_l1': 0.3779324927452586, 'lambda_l2': 0.22932455153008696, 'max_depth': 19, 'num_leaves': 138, 'feature_fraction': 0.4408168105516246, 'min_child_samples': 6}. Best is trial 310 with value: 4.989028334001922.
# [I 2024-10-13 20:10:00,555] Trial 478 finished with value: 5.246213988743055 and parameters: {'lambda_l1': 4.558448234641959, 'lambda_l2': 8.017614898172264, 'max_depth': 18, 'num_leaves': 197, 'feature_fraction': 0.1616312273169303, 'min_child_samples': 32}. Best is trial 310 with value: 4.989028334001922.
# [I 2024-10-13 20:10:00,728] Trial 479 finished with value: 5.232441933105629 and parameters: {'lambda_l1': 0.2655048249932417, 'lambda_l2': 8.949313874119994, 'max_depth': 19, 'num_leaves': 216, 'feature_fraction': 0.09137481830611988, 'min_child_samples': 10}. Best is trial 310 with value: 4.989028334001922.
# [I 2024-10-13 20:10:01,035] Trial 480 finished with value: 5.059739366445108 and parameters: {'lambda_l1': 3.4075702420727585, 'lambda_l2': 0.31087715783196757, 'max_depth': 17, 'num_leaves': 63, 'feature_fraction': 0.7608616770766252, 'min_child_samples': 6}. Best is trial 310 with value: 4.989028334001922.
# [I 2024-10-13 20:10:01,206] Trial 481 finished with value: 5.213077487766241 and parameters: {'lambda_l1': 2.2513386740060963, 'lambda_l2': 0.6881984374733792, 'max_depth': 18, 'num_leaves': 186, 'feature_fraction': 0.4910986179197339, 'min_child_samples': 56}. Best is trial 310 with value: 4.989028334001922.
# [I 2024-10-13 20:10:01,530] Trial 482 finished with value: 5.030562303905939 and parameters: {'lambda_l1': 0.6200104559955294, 'lambda_l2': 0.31498403397523644, 'max_depth': 22, 'num_leaves': 100, 'feature_fraction': 0.5006370721578702, 'min_child_samples': 1}. Best is trial 310 with value: 4.989028334001922.
# [I 2024-10-13 20:10:01,723] Trial 483 finished with value: 5.239610402990779 and parameters: {'lambda_l1': 6.239371291101959, 'lambda_l2': 2.09233261635394, 'max_depth': 2, 'num_leaves': 82, 'feature_fraction': 0.6857971646406473, 'min_child_samples': 44}. Best is trial 310 with value: 4.989028334001922.
# [I 2024-10-13 20:10:01,918] Trial 484 finished with value: 5.214238351002396 and parameters: {'lambda_l1': 3.1001019730884405, 'lambda_l2': 4.938774604396006, 'max_depth': 19, 'num_leaves': 54, 'feature_fraction': 0.3964287726107418, 'min_child_samples': 47}. Best is trial 310 with value: 4.989028334001922.
# [I 2024-10-13 20:10:02,238] Trial 485 finished with value: 5.07543859775566 and parameters: {'lambda_l1': 3.159596719155493, 'lambda_l2': 1.0968361958299586, 'max_depth': 15, 'num_leaves': 121, 'feature_fraction': 0.8232981135338027, 'min_child_samples': 5}. Best is trial 310 with value: 4.989028334001922.
# [I 2024-10-13 20:10:02,440] Trial 486 finished with value: 5.269888770404642 and parameters: {'lambda_l1': 5.22049379733829, 'lambda_l2': 2.0302138503264, 'max_depth': 25, 'num_leaves': 18, 'feature_fraction': 0.06570177922938314, 'min_child_samples': 93}. Best is trial 310 with value: 4.989028334001922.
# [I 2024-10-13 20:10:02,737] Trial 487 finished with value: 5.08004384830615 and parameters: {'lambda_l1': 4.130280566784644, 'lambda_l2': 1.1886091614404546, 'max_depth': 19, 'num_leaves': 204, 'feature_fraction': 0.789504811013763, 'min_child_samples': 6}. Best is trial 310 with value: 4.989028334001922.
# [I 2024-10-13 20:10:02,931] Trial 488 finished with value: 5.1978195556335915 and parameters: {'lambda_l1': 5.027445338815453, 'lambda_l2': 3.059791705225667, 'max_depth': 22, 'num_leaves': 69, 'feature_fraction': 0.5967215087812463, 'min_child_samples': 61}. Best is trial 310 with value: 4.989028334001922.
# [I 2024-10-13 20:10:03,121] Trial 489 finished with value: 5.236760956046973 and parameters: {'lambda_l1': 9.424459827252797, 'lambda_l2': 7.499933508675298, 'max_depth': 4, 'num_leaves': 191, 'feature_fraction': 0.613347816582533, 'min_child_samples': 85}. Best is trial 310 with value: 4.989028334001922.
# [I 2024-10-13 20:10:03,306] Trial 490 finished with value: 5.197910434744331 and parameters: {'lambda_l1': 7.404909580464093, 'lambda_l2': 8.639989482382788, 'max_depth': 29, 'num_leaves': 15, 'feature_fraction': 0.3462883928657534, 'min_child_samples': 37}. Best is trial 310 with value: 4.989028334001922.
# [I 2024-10-13 20:10:03,553] Trial 491 finished with value: 5.215643007167927 and parameters: {'lambda_l1': 0.5116244245552064, 'lambda_l2': 0.0015171648399201487, 'max_depth': 22, 'num_leaves': 236, 'feature_fraction': 0.5397712792749909, 'min_child_samples': 81}. Best is trial 310 with value: 4.989028334001922.
# [I 2024-10-13 20:10:03,868] Trial 492 finished with value: 5.061684999419376 and parameters: {'lambda_l1': 1.2415393986167549, 'lambda_l2': 0.34058670325640344, 'max_depth': 26, 'num_leaves': 84, 'feature_fraction': 0.6725459941299443, 'min_child_samples': 4}. Best is trial 310 with value: 4.989028334001922.
# [I 2024-10-13 20:10:04,223] Trial 493 finished with value: 5.054729674161238 and parameters: {'lambda_l1': 2.6044683593794904, 'lambda_l2': 1.6163102889682082, 'max_depth': 32, 'num_leaves': 66, 'feature_fraction': 0.9616538267285747, 'min_child_samples': 4}. Best is trial 310 with value: 4.989028334001922.
# [I 2024-10-13 20:10:04,637] Trial 494 finished with value: 5.0081202436727645 and parameters: {'lambda_l1': 2.8162553306393465, 'lambda_l2': 0.5872778943454598, 'max_depth': 15, 'num_leaves': 128, 'feature_fraction': 0.9636037875828523, 'min_child_samples': 2}. Best is trial 310 with value: 4.989028334001922.
# [I 2024-10-13 20:10:04,965] Trial 495 finished with value: 5.0642439684883955 and parameters: {'lambda_l1': 1.9391333554545103, 'lambda_l2': 0.8304652771837784, 'max_depth': 19, 'num_leaves': 200, 'feature_fraction': 0.935721596116203, 'min_child_samples': 5}. Best is trial 310 with value: 4.989028334001922.
# [I 2024-10-13 20:10:05,180] Trial 496 finished with value: 5.163798151434885 and parameters: {'lambda_l1': 6.508740076282953, 'lambda_l2': 0.05680890542982964, 'max_depth': 16, 'num_leaves': 142, 'feature_fraction': 0.7721039511745271, 'min_child_samples': 31}. Best is trial 310 with value: 4.989028334001922.
# [I 2024-10-13 20:10:05,394] Trial 497 finished with value: 5.218392885147289 and parameters: {'lambda_l1': 4.508225980452698, 'lambda_l2': 1.3668403439627899, 'max_depth': 3, 'num_leaves': 74, 'feature_fraction': 0.9421925133131063, 'min_child_samples': 36}. Best is trial 310 with value: 4.989028334001922.
# [I 2024-10-13 20:10:05,677] Trial 498 finished with value: 5.1488336964068075 and parameters: {'lambda_l1': 2.9753106649987417, 'lambda_l2': 0.6195018139996825, 'max_depth': 10, 'num_leaves': 118, 'feature_fraction': 0.8745089606157846, 'min_child_samples': 26}. Best is trial 310 with value: 4.989028334001922.
# [I 2024-10-13 20:10:05,938] Trial 499 finished with value: 5.077066583937878 and parameters: {'lambda_l1': 3.2036005570513324, 'lambda_l2': 0.8103874199853044, 'max_depth': 5, 'num_leaves': 136, 'feature_fraction': 0.7500404790942503, 'min_child_samples': 2}. Best is trial 310 with value: 4.989028334001922.
# {'lambda_l1': 3.1948120003372753,
#  'lambda_l2': 0.05811583979927415,
#  'max_depth': 11,
#  'num_leaves': 110,
#  'feature_fraction': 0.8402237232663353,
#  'min_child_samples': 1}

# %%
params = (
    {
        'random_state': 22,
        'metric': 'mean_absolute_error',
        'verbosity': -1,
        'n_estimators': 500,
        'early_stopping_round': 25,
        'monotone_constraints': monotone_contraints,
    } |
    study.best_params
)

testing_data = []
mod = LGBMRegressor(**params)
for X_train, X_val, X_test, y_train, y_val, y_test, df_mod_oos in cv_data:
    mod.fit(
        X_train, 
        y_train, 
        eval_set=(X_val, y_val),
    )
    
    testing_data.append(df_mod_oos.assign(Prediction=mod.predict(X_test)))

df_test = pd.concat(testing_data, ignore_index=True)

df_test
# Out:
#       Season  Week           Name Position Team  Fantasy Points   Rank  \
# 0       2020     5  george kittle       TE   SF             6.4   47.0
# 1       2020     5   travis kelce       TE   KC            20.8   51.0
# 2       2020     5   mark andrews       TE  BAL            14.6   69.0
# 3       2020     5  darren waller       TE   LV            13.3   75.0
# 4       2020     5   hunter henry       TE  LAC            10.3   82.0
# ...      ...   ...            ...      ...  ...             ...    ...
# 2010    2023    17   mike gesicki       TE   NE             5.5  197.0
# 2011    2023    17    josh oliver       TE  MIN             2.2  200.0
# 2012    2023    17  austin hooper       TE   LV             4.3  217.0
# 2013    2023    17  adam trautman       TE  DEN             1.4  225.0
# 2014    2023    17  tommy tremble       TE  CAR             1.1  226.0
#
#       Position Rank  Adjusted Passing Yards Projection  \
# 0                 1                                NaN
# 1                 2                                NaN
# 2                 3                                NaN
# 3                 4                                NaN
# 4                 5                                NaN
# ...             ...                                ...
# 2010             31                                NaN
# 2011             32                                NaN
# 2012             34                                NaN
# 2013             35                                NaN
# 2014             36                                NaN
#
#       Adjusted Passing Touchdowns Projection  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 2010                                     NaN
# 2011                                     NaN
# 2012                                     NaN
# 2013                                     NaN
# 2014                                     NaN
#
#       Adjusted Interceptions Projection  Adjusted Rushing Yards Projection  \
# 0                                   NaN                                NaN
# 1                                   NaN                                NaN
# 2                                   NaN                                NaN
# 3                                   NaN                                NaN
# 4                                   NaN                                NaN
# ...                                 ...                                ...
# 2010                                NaN                                NaN
# 2011                                NaN                                NaN
# 2012                                NaN                                NaN
# 2013                                NaN                                NaN
# 2014                                NaN                                NaN
#
#       Adjusted Receiving Yards Projection  Adjusted Receptions Projection  \
# 0                               71.500000                        5.436640
# 1                               70.500000                        5.543332
# 2                               52.500000                        4.467391
# 3                               59.500000                        5.563103
# 4                               53.502184                        4.480127
# ...                                   ...                             ...
# 2010                            17.505537                        2.431481
# 2011                            10.500000                             NaN
# 2012                            20.503353                        2.462766
# 2013                             5.500000                        0.600127
# 2014                            13.511851                        1.612455
#
#       Anytime Touchdown Probability  Location  Team Projected Score  \
# 0                          0.523810       1.0                 29.50
# 1                          0.591837       1.0                 32.50
# 2                          0.500000       1.0                 30.50
# 3                          0.370370      -1.0                 22.00
# 4                          0.333333      -1.0                 21.25
# ...                             ...       ...                   ...
# 2010                       0.166667      -1.0                 12.75
# 2011                       0.181818       1.0                 21.75
# 2012                       0.181818      -1.0                 19.50
# 2013                       0.200000       1.0                 21.50
# 2014                       0.166667      -1.0                 17.25
#
#       Opponent Projected Score  Prediction
# 0                        21.00   13.433193
# 1                        22.00   16.916606
# 2                        18.50   12.505849
# 3                        32.50   10.560907
# 4                        28.25    9.577299
# ...                        ...         ...
# 2010                     27.25    2.553096
# 2011                     20.75    2.117623
# 2012                     23.00    4.219020
# 2013                     18.00    2.558104
# 2014                     20.75    0.809559
#
# [2015 rows x 19 columns]

# %%
df_test['Prediction'].describe()
# Out:
# count    2015.000000
# mean        6.654829
# std         3.248218
# min        -0.359070
# 25%         4.605064
# 50%         6.317232
# 75%         7.868611
# max        27.484514
# Name: Prediction, dtype: float64

# %%
(df_test['Fantasy Points'] - df_test['Prediction']).describe()
# Out:
# count    2015.000000
# mean        0.230431
# std         4.984941
# min       -15.325745
# 25%        -3.135872
# 50%        -0.561284
# 75%         2.681344
# max        27.124879
# dtype: float64

# %%
(df_test['Fantasy Points'] - df_test['Prediction']).abs().describe()
# Out:
# count    2015.000000
# mean        3.734193
# std         3.309327
# min         0.001805
# 25%         1.434067
# 50%         2.994409
# 75%         5.001220
# max        27.124879
# dtype: float64

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(df_test['Fantasy Points'], df_test['Prediction'], squared=False)
# Out:
# 4.989028334001922

# %%
from sklearn.metrics import mean_absolute_error

mean_absolute_error(df_test['Fantasy Points'], df_test['Prediction'])
# Out:
# 3.7341927410898585

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6, 6), dpi=100)

ax = sns.regplot(
    data=df_test,
    x='Prediction',
    y='Fantasy Points',
    scatter_kws={'alpha': 0.10, 'color': sns.color_palette()[1]},
    line_kws={'color': sns.color_palette()[0]},
)

plt.title('Actual Fantasy Points vs. Predicted Fantasy Points')
plt.xlabel('Predicted Fantasy Points Scored')
plt.ylabel('Actual Fantasy Points Scored')

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6, 6), dpi=100)

ax = sns.regplot(
    data=df_test.assign(f=(df_test['Fantasy Points'] - df_test['Prediction'])),
    x='Prediction',
    y='f',
    scatter_kws={'alpha': 0.10, 'color': sns.color_palette()[0]},
    line_kws={'color': sns.color_palette()[3]},
)

plt.title('Residual Plot')
plt.xlabel('Predicted Fantasy Points Scored')
plt.ylabel('Actual Minus Predicted')

plt.show()

# %%
import shap

explainer = shap.Explainer(mod, feature_names=X_train.columns, seed=22)

shap_values = explainer(pd.concat([i[0] for i in cv_data], ignore_index=True))

shap_values.shape
# Out:
# (3398, 9)

# %%
shap.plots.beeswarm(shap_values, max_display=None)
