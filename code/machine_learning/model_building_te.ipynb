# %%
import pandas as pd

pd.set_option('display.max_columns', 100)

df_mod = pd.read_parquet('../../data/model_data/model_data_single_output.parquet')

df_mod = df_mod.loc[df_mod['Position'] == 'TE', :].reset_index(drop=True)

df_mod
# Out:
#       Season  Week           Name Position Team  Fantasy Points   Rank  \
# 0       2020     1  george kittle       TE   SF             7.3   43.0
# 1       2020     1   travis kelce       TE   KC            14.0   48.0
# 2       2020     1   mark andrews       TE  BAL            20.3   70.0
# 3       2020     1      zach ertz       TE  PHI             9.3   76.0
# 4       2020     1  darren waller       TE   LV             7.5   87.0
# ...      ...   ...            ...      ...  ...             ...    ...
# 2010    2023    17   mike gesicki       TE   NE             5.5  197.0
# 2011    2023    17    josh oliver       TE  MIN             2.2  200.0
# 2012    2023    17  austin hooper       TE   LV             4.3  217.0
# 2013    2023    17  adam trautman       TE  DEN             1.4  225.0
# 2014    2023    17  tommy tremble       TE  CAR             1.1  226.0
#
#       Position Rank  Adjusted Passing Yards Projection  \
# 0                 1                                NaN
# 1                 2                                NaN
# 2                 3                                NaN
# 3                 4                                NaN
# 4                 5                                NaN
# ...             ...                                ...
# 2010             31                                NaN
# 2011             32                                NaN
# 2012             34                                NaN
# 2013             35                                NaN
# 2014             36                                NaN
#
#       Adjusted Passing Touchdowns Projection  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 2010                                     NaN
# 2011                                     NaN
# 2012                                     NaN
# 2013                                     NaN
# 2014                                     NaN
#
#       Adjusted Interceptions Projection  Adjusted Rushing Yards Projection  \
# 0                                   NaN                                NaN
# 1                                   NaN                                NaN
# 2                                   NaN                                NaN
# 3                                   NaN                                NaN
# 4                                   NaN                                NaN
# ...                                 ...                                ...
# 2010                                NaN                                NaN
# 2011                                NaN                                NaN
# 2012                                NaN                                NaN
# 2013                                NaN                                NaN
# 2014                                NaN                                NaN
#
#       Adjusted Receiving Yards Projection  Adjusted Receptions Projection  \
# 0                               71.500000                        6.464916
# 1                               69.524775                        5.557539
# 2                               48.500000                        4.436640
# 3                               54.500000                        5.458984
# 4                               52.500000                        4.544513
# ...                                   ...                             ...
# 2010                            17.505537                        2.431481
# 2011                            10.500000                             NaN
# 2012                            20.503353                        2.462766
# 2013                             5.500000                        0.600127
# 2014                            13.511851                        1.612455
#
#       Anytime Touchdown Probability  Location  Team Projected Score  \
# 0                          0.500000       1.0                 26.75
# 1                          0.545455       1.0                 31.50
# 2                          0.420168       1.0                 27.25
# 3                          0.380228      -1.0                 22.00
# 4                          0.420168      -1.0                 25.50
# ...                             ...       ...                   ...
# 2010                       0.166667      -1.0                 12.75
# 2011                       0.181818       1.0                 21.75
# 2012                       0.181818      -1.0                 19.50
# 2013                       0.200000       1.0                 21.50
# 2014                       0.166667      -1.0                 17.25
#
#       Opponent Projected Score
# 0                        20.25
# 1                        22.00
# 2                        20.25
# 3                        16.50
# 4                        22.50
# ...                        ...
# 2010                     27.25
# 2011                     20.75
# 2012                     23.00
# 2013                     18.00
# 2014                     20.75
#
# [2015 rows x 18 columns]

# %%
X = df_mod[[
    'Rank',
    'Position Rank',
    'Location',
    'Team Projected Score',
    'Opponent Projected Score',
    'Adjusted Receptions Projection',
    'Adjusted Receiving Yards Projection',
    'Anytime Touchdown Probability',
]].copy()

X
# Out:
#        Rank  Position Rank  Location  Team Projected Score  \
# 0      43.0              1       1.0                 26.75
# 1      48.0              2       1.0                 31.50
# 2      70.0              3       1.0                 27.25
# 3      76.0              4      -1.0                 22.00
# 4      87.0              5      -1.0                 25.50
# ...     ...            ...       ...                   ...
# 2010  197.0             31      -1.0                 12.75
# 2011  200.0             32       1.0                 21.75
# 2012  217.0             34      -1.0                 19.50
# 2013  225.0             35       1.0                 21.50
# 2014  226.0             36      -1.0                 17.25
#
#       Opponent Projected Score  Adjusted Receptions Projection  \
# 0                        20.25                        6.464916
# 1                        22.00                        5.557539
# 2                        20.25                        4.436640
# 3                        16.50                        5.458984
# 4                        22.50                        4.544513
# ...                        ...                             ...
# 2010                     27.25                        2.431481
# 2011                     20.75                             NaN
# 2012                     23.00                        2.462766
# 2013                     18.00                        0.600127
# 2014                     20.75                        1.612455
#
#       Adjusted Receiving Yards Projection  Anytime Touchdown Probability
# 0                               71.500000                       0.500000
# 1                               69.524775                       0.545455
# 2                               48.500000                       0.420168
# 3                               54.500000                       0.380228
# 4                               52.500000                       0.420168
# ...                                   ...                            ...
# 2010                            17.505537                       0.166667
# 2011                            10.500000                       0.181818
# 2012                            20.503353                       0.181818
# 2013                             5.500000                       0.200000
# 2014                            13.511851                       0.166667
#
# [2015 rows x 8 columns]

# %%
y = df_mod['Fantasy Points'].copy()

y
# Out:
# 0        7.3
# 1       14.0
# 2       20.3
# 3        9.3
# 4        7.5
#         ...
# 2010     5.5
# 2011     2.2
# 2012     4.3
# 2013     1.4
# 2014     1.1
# Name: Fantasy Points, Length: 2015, dtype: float64

# %%
groups = df_mod['Season'].astype(str) + ' Week ' + df_mod['Week'].astype(str)

groups
# Out:
# 0        2020 Week 1
# 1        2020 Week 1
# 2        2020 Week 1
# 3        2020 Week 1
# 4        2020 Week 1
#             ...
# 2010    2023 Week 17
# 2011    2023 Week 17
# 2012    2023 Week 17
# 2013    2023 Week 17
# 2014    2023 Week 17
# Length: 2015, dtype: object

# %%
df_folds = pd.read_parquet('../../data/model_data/folds.parquet')

df_folds
# Out:
#     Fold ID   Season Week
# 0         0   2022 Week 3
# 1         0   2021 Week 7
# 2         0   2021 Week 1
# 3         0  2023 Week 16
# 4         0  2021 Week 11
# ..      ...           ...
# 62        2  2020 Week 15
# 63        2  2023 Week 14
# 64        2   2021 Week 5
# 65        2   2022 Week 6
# 66        2  2022 Week 12
#
# [67 rows x 2 columns]

# %%
from sklearn.model_selection import GroupShuffleSplit
from sklearn.preprocessing import StandardScaler
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

pd.options.mode.chained_assignment = None

# splitter = GroupKFold(n_splits=3)

cv_data = []
for fold in df_folds['Fold ID'].unique():
    oos_season_week = df_folds.loc[df_folds['Fold ID'] == fold, 'Season Week']
    is_indexes = df_mod.loc[~groups.isin(oos_season_week), :].index
    oos_indexes = df_mod.loc[groups.isin(oos_season_week), :].index
    # split
    X_is = X.iloc[is_indexes]
    X_oos = X.iloc[oos_indexes]

    y_is = y.iloc[is_indexes]
    y_oos = y.iloc[oos_indexes]

    groups_is = groups.iloc[is_indexes]
    df_mod_oos = df_mod.iloc[oos_indexes]

    gss = GroupShuffleSplit(n_splits=1, test_size=0.15, random_state=22)
    for train_indexes, val_indexes in gss.split(X=X_is, y=y_is, groups=groups_is):
        X_train = X_is.iloc[train_indexes]
        X_val = X_is.iloc[val_indexes]

        y_train = y_is.iloc[train_indexes]
        y_val = y_is.iloc[val_indexes]

    # impute
    scaler = StandardScaler()
    imputer = IterativeImputer(initial_strategy='median', max_iter=100)

    X_train_fill_na = imputer.fit_transform(scaler.fit_transform(X_train))
    X_train[X_train.columns] = scaler.inverse_transform(X_train_fill_na).copy()
    X_train['Prop Bets Projection'] = (
        X_train['Adjusted Receiving Yards Projection']*0.1 + 
        X_train['Adjusted Receptions Projection']*0.5 + 
        X_train['Anytime Touchdown Probability']*6
    )

    X_val_fill_na = imputer.transform(scaler.transform(X_val))
    X_val[X_val.columns] = scaler.inverse_transform(X_val_fill_na).copy()
    X_val['Prop Bets Projection'] = (
        X_val['Adjusted Receiving Yards Projection']*0.1 + 
        X_val['Adjusted Receptions Projection']*0.5 + 
        X_val['Anytime Touchdown Probability']*6
    )

    X_oos_fill_na = imputer.transform(scaler.transform(X_oos))
    X_oos[X_oos.columns] = scaler.inverse_transform(X_oos_fill_na).copy()
    X_oos['Prop Bets Projection'] = (
        X_oos['Adjusted Receiving Yards Projection']*0.1 + 
        X_oos['Adjusted Receptions Projection']*0.5 + 
        X_oos['Anytime Touchdown Probability']*6
    )

    X_train.drop(columns=['Adjusted Receiving Yards Projection', 'Adjusted Receptions Projection', 'Anytime Touchdown Probability'], inplace=True)
    X_val.drop(columns=['Adjusted Receiving Yards Projection', 'Adjusted Receptions Projection', 'Anytime Touchdown Probability'], inplace=True)
    X_oos.drop(columns=['Adjusted Receiving Yards Projection', 'Adjusted Receptions Projection', 'Anytime Touchdown Probability'], inplace=True)

    cv_data.append((X_train, X_val, X_oos, y_train, y_val, y_oos, df_mod_oos))

for X_train, X_val, X_oos, y_train, y_val, y_oos, df_mod_oos in cv_data:
    print(X_train.shape, X_val.shape, X_oos.shape, y_train.shape, y_val.shape, y_oos.shape, df_mod_oos.shape)
# Out:
# (1105, 6) (216, 6) (694, 6) (1105,) (216,) (694,) (694, 18)
# (1156, 6) (212, 6) (647, 6) (1156,) (212,) (647,) (647, 18)
# (1137, 6) (204, 6) (674, 6) (1137,) (204,) (674,) (674, 18)

# %%
monotonic_contraints_dict = {
    'Rank': -1,
    'Position Rank': -1,
    'Location': 1,
    'Team Projected Score': 1,
    'Adjusted Receiving Yards Projection': 1,
    'Adjusted Receptions Projection': 1,
    'Adjusted Rushing Yards Projection': 1,
    'Anytime Touchdown Probability': 1,
    'Prop Bets Projection': 1,
}

monotone_contraints = [monotonic_contraints_dict.get(c, 0) for c in X_train.columns]

monotone_contraints
# Out:
# [-1, -1, 1, 1, 0, 1]

# %%
from sklearn.metrics import mean_squared_error
from lightgbm import LGBMRegressor
import optuna
import numpy as np

def objective(trial, cv_data=cv_data):
    # model tuning
    # params = {
    #     'random_state': 22,
    #     'objective': 'binary:logistic',
    #     'eval_metric': 'logloss',
    #     'n_estimators': 1_000,
    #     'eta': trial.suggest_float('eta', 0.005, 0.100),
    #     'max_depth': trial.suggest_int('max_depth', 4, 16),
    #     'lambda': trial.suggest_float('lambda', 1e-8, 5.0),
    #     'alpha': trial.suggest_float('alpha', 1e-8, 5.0),
    #     'min_child_weight': trial.suggest_float('min_child_weight', 1e-8, 5.0),
    #     # 'subsample': trial.suggest_float('subsample', 0.5, 1.0),
    #     'colsample_bytree': trial.suggest_float('colsample_bytree', 0.01, 0.30),
    # }
    params = {
        'random_state': 22,
        'metric': 'mean_squared_error',
        'verbosity': -1,
        'n_estimators': 500,
        'early_stopping_round': 25,
        'monotone_constraints': monotone_contraints,
        'lambda_l1': trial.suggest_float('lambda_l1', 1e-8, 10.0),
        'lambda_l2': trial.suggest_float('lambda_l2', 1e-8, 10.0),
        'max_depth': trial.suggest_int('max_depth', 1, 32),
        'num_leaves': trial.suggest_int('num_leaves', 2, 2**8),
        'feature_fraction': trial.suggest_float('feature_fraction', 1e-8, 1.0),
        'min_child_samples': trial.suggest_int('min_child_samples', 1, 100),
    }
    mod = LGBMRegressor(**params)

    # cross validation
    y_actuals = []
    y_preds = []
    for X_train, X_val, X_test, y_train, y_val, y_test, df_mod_oos in cv_data:
        y_actuals.append(y_test)

        mod.fit(
            X_train, 
            y_train, 
            eval_set=(X_val, y_val),
        )

        y_preds.append(mod.predict(X_test))

    return mean_squared_error(np.hstack(y_actuals), np.hstack(y_preds), squared=False)

study = optuna.create_study(direction='minimize', sampler=optuna.samplers.TPESampler(seed=22, n_startup_trials=50, multivariate=True))
study.optimize(objective, n_trials=500, show_progress_bar=True)

study.best_params
# Out:
# c:\Users\mhugh\anaconda3\envs\clean\lib\site-packages\optuna\samplers\_tpe\sampler.py:295: ExperimentalWarning: ``multivariate`` option is an experimental feature. The interface can change in the future.
#   warnings.warn(
# [I 2024-10-16 21:27:11,176] A new study created in memory with name: no-name-6989fe4a-f747-48c4-83cd-890e5a4126e9
#   0%|          | 0/500 [00:00<?, ?it/s]
# [I 2024-10-16 21:27:11,371] Trial 0 finished with value: 5.3583470343272035 and parameters: {'lambda_l1': 2.084605381503821, 'lambda_l2': 4.816810622816848, 'max_depth': 14, 'num_leaves': 221, 'feature_fraction': 0.17116156190005774, 'min_child_samples': 34}. Best is trial 0 with value: 5.3583470343272035.
# [I 2024-10-16 21:27:11,478] Trial 1 finished with value: 5.347892950908795 and parameters: {'lambda_l1': 2.7053283402729833, 'lambda_l2': 6.910413507585547, 'max_depth': 8, 'num_leaves': 209, 'feature_fraction': 0.010526884210839693, 'min_child_samples': 57}. Best is trial 1 with value: 5.347892950908795.
# [I 2024-10-16 21:27:11,530] Trial 2 finished with value: 5.354599528056089 and parameters: {'lambda_l1': 8.137261876014703, 'lambda_l2': 7.451002963137353, 'max_depth': 7, 'num_leaves': 3, 'feature_fraction': 0.7720438737240976, 'min_child_samples': 96}. Best is trial 1 with value: 5.347892950908795.
# [I 2024-10-16 21:27:11,597] Trial 3 finished with value: 5.343517013539677 and parameters: {'lambda_l1': 7.0193788439237315, 'lambda_l2': 2.975782675674722, 'max_depth': 25, 'num_leaves': 177, 'feature_fraction': 0.38718348650918744, 'min_child_samples': 62}. Best is trial 3 with value: 5.343517013539677.
# [I 2024-10-16 21:27:11,673] Trial 4 finished with value: 5.351277541718116 and parameters: {'lambda_l1': 4.275552404167853, 'lambda_l2': 5.842896435726052, 'max_depth': 23, 'num_leaves': 30, 'feature_fraction': 0.9232699266117512, 'min_child_samples': 99}. Best is trial 3 with value: 5.343517013539677.
# [I 2024-10-16 21:27:11,838] Trial 5 finished with value: 5.346042371133985 and parameters: {'lambda_l1': 6.7741077381062915, 'lambda_l2': 7.95164775662488, 'max_depth': 1, 'num_leaves': 47, 'feature_fraction': 0.8749277465284395, 'min_child_samples': 75}. Best is trial 3 with value: 5.343517013539677.
# [I 2024-10-16 21:27:11,992] Trial 6 finished with value: 5.355076534987576 and parameters: {'lambda_l1': 5.080901637200814, 'lambda_l2': 1.2833390269943445, 'max_depth': 16, 'num_leaves': 133, 'feature_fraction': 0.31126467031173777, 'min_child_samples': 5}. Best is trial 3 with value: 5.343517013539677.
# [I 2024-10-16 21:27:12,057] Trial 7 finished with value: 5.345381258066632 and parameters: {'lambda_l1': 4.376806606444189, 'lambda_l2': 0.9588461082215654, 'max_depth': 2, 'num_leaves': 176, 'feature_fraction': 0.8491907467156716, 'min_child_samples': 13}. Best is trial 3 with value: 5.343517013539677.
# [I 2024-10-16 21:27:12,125] Trial 8 finished with value: 5.337576907461132 and parameters: {'lambda_l1': 1.2906400808277216, 'lambda_l2': 4.730600026025964, 'max_depth': 7, 'num_leaves': 201, 'feature_fraction': 0.607413867067853, 'min_child_samples': 45}. Best is trial 8 with value: 5.337576907461132.
# [I 2024-10-16 21:27:12,190] Trial 9 finished with value: 5.323497697401839 and parameters: {'lambda_l1': 9.820291085978743, 'lambda_l2': 7.089554140971765, 'max_depth': 7, 'num_leaves': 44, 'feature_fraction': 0.5387654777120323, 'min_child_samples': 32}. Best is trial 9 with value: 5.323497697401839.
# [I 2024-10-16 21:27:12,264] Trial 10 finished with value: 5.358552808718948 and parameters: {'lambda_l1': 9.115369974738407, 'lambda_l2': 0.8625568068298629, 'max_depth': 11, 'num_leaves': 57, 'feature_fraction': 0.7366662321509689, 'min_child_samples': 83}. Best is trial 9 with value: 5.323497697401839.
# [I 2024-10-16 21:27:12,340] Trial 11 finished with value: 5.3536256644089235 and parameters: {'lambda_l1': 7.445644632079445, 'lambda_l2': 1.7753703875851008, 'max_depth': 28, 'num_leaves': 3, 'feature_fraction': 0.3576431761648761, 'min_child_samples': 96}. Best is trial 9 with value: 5.323497697401839.
# [I 2024-10-16 21:27:12,470] Trial 12 finished with value: 5.336915528916258 and parameters: {'lambda_l1': 9.417763861384264, 'lambda_l2': 0.23049013654080094, 'max_depth': 22, 'num_leaves': 43, 'feature_fraction': 0.5681323746241385, 'min_child_samples': 25}. Best is trial 9 with value: 5.323497697401839.
# [I 2024-10-16 21:27:12,545] Trial 13 finished with value: 5.327248200153873 and parameters: {'lambda_l1': 1.5785591501063627, 'lambda_l2': 5.035628220122295, 'max_depth': 19, 'num_leaves': 121, 'feature_fraction': 0.5081672454060291, 'min_child_samples': 33}. Best is trial 9 with value: 5.323497697401839.
# [I 2024-10-16 21:27:12,703] Trial 14 finished with value: 5.360666235190168 and parameters: {'lambda_l1': 8.864983553736035, 'lambda_l2': 2.5183551154305976, 'max_depth': 28, 'num_leaves': 163, 'feature_fraction': 0.6972231829797998, 'min_child_samples': 4}. Best is trial 9 with value: 5.323497697401839.
# [I 2024-10-16 21:27:12,794] Trial 15 finished with value: 5.3300193934051645 and parameters: {'lambda_l1': 6.573113029388262, 'lambda_l2': 9.993224216396282, 'max_depth': 17, 'num_leaves': 239, 'feature_fraction': 0.44080287410267743, 'min_child_samples': 21}. Best is trial 9 with value: 5.323497697401839.
# [I 2024-10-16 21:27:12,881] Trial 16 finished with value: 5.35231632010421 and parameters: {'lambda_l1': 8.038535684069508, 'lambda_l2': 8.07672059410554, 'max_depth': 2, 'num_leaves': 203, 'feature_fraction': 0.450041684177444, 'min_child_samples': 86}. Best is trial 9 with value: 5.323497697401839.
# [I 2024-10-16 21:27:13,046] Trial 17 finished with value: 5.367585285959275 and parameters: {'lambda_l1': 3.624168648699743, 'lambda_l2': 2.0242762718220377, 'max_depth': 28, 'num_leaves': 155, 'feature_fraction': 0.831852739197039, 'min_child_samples': 3}. Best is trial 9 with value: 5.323497697401839.
# [I 2024-10-16 21:27:13,184] Trial 18 finished with value: 5.3584580372702995 and parameters: {'lambda_l1': 7.042966208974291, 'lambda_l2': 7.62995911879823, 'max_depth': 13, 'num_leaves': 51, 'feature_fraction': 0.1689230888648846, 'min_child_samples': 89}. Best is trial 9 with value: 5.323497697401839.
# [I 2024-10-16 21:27:13,283] Trial 19 finished with value: 5.324852197603871 and parameters: {'lambda_l1': 7.3094208835154015, 'lambda_l2': 8.8719403726663, 'max_depth': 9, 'num_leaves': 171, 'feature_fraction': 0.43498705260110365, 'min_child_samples': 52}. Best is trial 9 with value: 5.323497697401839.
# [I 2024-10-16 21:27:13,447] Trial 20 finished with value: 5.352009128123713 and parameters: {'lambda_l1': 5.653980359239076, 'lambda_l2': 0.3451501808493058, 'max_depth': 28, 'num_leaves': 91, 'feature_fraction': 0.5389013475164267, 'min_child_samples': 1}. Best is trial 9 with value: 5.323497697401839.
# [I 2024-10-16 21:27:13,539] Trial 21 finished with value: 5.349335130392631 and parameters: {'lambda_l1': 0.489554667023236, 'lambda_l2': 9.333017947224663, 'max_depth': 7, 'num_leaves': 186, 'feature_fraction': 0.3980551630378403, 'min_child_samples': 74}. Best is trial 9 with value: 5.323497697401839.
# [I 2024-10-16 21:27:13,629] Trial 22 finished with value: 5.353192377257341 and parameters: {'lambda_l1': 6.511376677483669, 'lambda_l2': 9.250353214624223, 'max_depth': 20, 'num_leaves': 11, 'feature_fraction': 0.11557638950587484, 'min_child_samples': 76}. Best is trial 9 with value: 5.323497697401839.
# [I 2024-10-16 21:27:13,721] Trial 23 finished with value: 5.34888888938028 and parameters: {'lambda_l1': 4.517788248973011, 'lambda_l2': 6.046750447343872, 'max_depth': 28, 'num_leaves': 129, 'feature_fraction': 0.8169499167755174, 'min_child_samples': 65}. Best is trial 9 with value: 5.323497697401839.
# [I 2024-10-16 21:27:13,879] Trial 24 finished with value: 5.37862710610085 and parameters: {'lambda_l1': 4.585916254770666, 'lambda_l2': 2.289650598801194, 'max_depth': 27, 'num_leaves': 132, 'feature_fraction': 0.026716911481217794, 'min_child_samples': 16}. Best is trial 9 with value: 5.323497697401839.
# [I 2024-10-16 21:27:13,965] Trial 25 finished with value: 5.337026429711147 and parameters: {'lambda_l1': 9.086816463002746, 'lambda_l2': 0.35256871082678004, 'max_depth': 16, 'num_leaves': 22, 'feature_fraction': 0.539854889190807, 'min_child_samples': 70}. Best is trial 9 with value: 5.323497697401839.
# [I 2024-10-16 21:27:14,061] Trial 26 finished with value: 5.3360579367036 and parameters: {'lambda_l1': 0.5196410509014395, 'lambda_l2': 9.38557284441749, 'max_depth': 14, 'num_leaves': 249, 'feature_fraction': 0.37649331016315807, 'min_child_samples': 58}. Best is trial 9 with value: 5.323497697401839.
# [I 2024-10-16 21:27:14,177] Trial 27 finished with value: 5.32614303083323 and parameters: {'lambda_l1': 2.77050808473577, 'lambda_l2': 1.7891537117257124, 'max_depth': 17, 'num_leaves': 256, 'feature_fraction': 0.5083273485258836, 'min_child_samples': 35}. Best is trial 9 with value: 5.323497697401839.
# [I 2024-10-16 21:27:14,279] Trial 28 finished with value: 5.331107404993031 and parameters: {'lambda_l1': 1.8787035855576422, 'lambda_l2': 0.43517482596686374, 'max_depth': 18, 'num_leaves': 125, 'feature_fraction': 0.8592805504851173, 'min_child_samples': 41}. Best is trial 9 with value: 5.323497697401839.
# [I 2024-10-16 21:27:14,407] Trial 29 finished with value: 5.366596064519507 and parameters: {'lambda_l1': 2.612231957998111, 'lambda_l2': 9.981270281205395, 'max_depth': 26, 'num_leaves': 17, 'feature_fraction': 0.3158046220351414, 'min_child_samples': 9}. Best is trial 9 with value: 5.323497697401839.
# [I 2024-10-16 21:27:14,491] Trial 30 finished with value: 5.348398825922254 and parameters: {'lambda_l1': 7.455166416828882, 'lambda_l2': 2.530993227038728, 'max_depth': 12, 'num_leaves': 169, 'feature_fraction': 0.8346373618214232, 'min_child_samples': 73}. Best is trial 9 with value: 5.323497697401839.
# [I 2024-10-16 21:27:14,578] Trial 31 finished with value: 5.35761298192298 and parameters: {'lambda_l1': 4.0587436647437585, 'lambda_l2': 7.76438701377263, 'max_depth': 13, 'num_leaves': 171, 'feature_fraction': 0.18199141974675861, 'min_child_samples': 85}. Best is trial 9 with value: 5.323497697401839.
# [I 2024-10-16 21:27:14,634] Trial 32 finished with value: 5.328578121680507 and parameters: {'lambda_l1': 8.336036101202682, 'lambda_l2': 4.643317602988053, 'max_depth': 8, 'num_leaves': 3, 'feature_fraction': 0.5405971573815558, 'min_child_samples': 51}. Best is trial 9 with value: 5.323497697401839.
# [I 2024-10-16 21:27:14,706] Trial 33 finished with value: 5.350766238933351 and parameters: {'lambda_l1': 0.4671699376957205, 'lambda_l2': 5.692352683937471, 'max_depth': 32, 'num_leaves': 207, 'feature_fraction': 0.5902617703671256, 'min_child_samples': 79}. Best is trial 9 with value: 5.323497697401839.
# [I 2024-10-16 21:27:14,815] Trial 34 finished with value: 5.364755972460707 and parameters: {'lambda_l1': 7.7739315446946184, 'lambda_l2': 4.481509122576739, 'max_depth': 13, 'num_leaves': 162, 'feature_fraction': 0.09863312332364564, 'min_child_samples': 20}. Best is trial 9 with value: 5.323497697401839.
# [I 2024-10-16 21:27:14,953] Trial 35 finished with value: 5.390269752963834 and parameters: {'lambda_l1': 0.8555555632055482, 'lambda_l2': 9.97684321181545, 'max_depth': 26, 'num_leaves': 117, 'feature_fraction': 0.1805574241161361, 'min_child_samples': 1}. Best is trial 9 with value: 5.323497697401839.
# [I 2024-10-16 21:27:15,122] Trial 36 finished with value: 5.350243500887961 and parameters: {'lambda_l1': 6.813144850607171, 'lambda_l2': 4.427815824343865, 'max_depth': 31, 'num_leaves': 138, 'feature_fraction': 0.1339572513490412, 'min_child_samples': 64}. Best is trial 9 with value: 5.323497697401839.
# [I 2024-10-16 21:27:15,205] Trial 37 finished with value: 5.344883778076346 and parameters: {'lambda_l1': 0.3413318706315758, 'lambda_l2': 5.090980726528967, 'max_depth': 27, 'num_leaves': 113, 'feature_fraction': 0.4691051702324455, 'min_child_samples': 92}. Best is trial 9 with value: 5.323497697401839.
# [I 2024-10-16 21:27:15,289] Trial 38 finished with value: 5.350387683742873 and parameters: {'lambda_l1': 7.236413490056097, 'lambda_l2': 5.591303698901367, 'max_depth': 3, 'num_leaves': 191, 'feature_fraction': 0.341136056824571, 'min_child_samples': 86}. Best is trial 9 with value: 5.323497697401839.
# [I 2024-10-16 21:27:15,362] Trial 39 finished with value: 5.351667427585107 and parameters: {'lambda_l1': 6.155817368618826, 'lambda_l2': 4.395847102362112, 'max_depth': 20, 'num_leaves': 35, 'feature_fraction': 0.3856478817819415, 'min_child_samples': 94}. Best is trial 9 with value: 5.323497697401839.
# [I 2024-10-16 21:27:15,468] Trial 40 finished with value: 5.3553908089941755 and parameters: {'lambda_l1': 5.399968572820769, 'lambda_l2': 5.391522843987809, 'max_depth': 8, 'num_leaves': 157, 'feature_fraction': 0.19258927237072163, 'min_child_samples': 96}. Best is trial 9 with value: 5.323497697401839.
# [I 2024-10-16 21:27:15,565] Trial 41 finished with value: 5.335218219777845 and parameters: {'lambda_l1': 2.702709615849796, 'lambda_l2': 5.796218029870317, 'max_depth': 25, 'num_leaves': 179, 'feature_fraction': 0.7658140957790239, 'min_child_samples': 59}. Best is trial 9 with value: 5.323497697401839.
# [I 2024-10-16 21:27:15,674] Trial 42 finished with value: 5.340725992934854 and parameters: {'lambda_l1': 1.1995862883625372, 'lambda_l2': 6.698297084546612, 'max_depth': 31, 'num_leaves': 44, 'feature_fraction': 0.8193161329747478, 'min_child_samples': 43}. Best is trial 9 with value: 5.323497697401839.
# [I 2024-10-16 21:27:15,774] Trial 43 finished with value: 5.32922714483941 and parameters: {'lambda_l1': 5.253924034309357, 'lambda_l2': 3.4318709225280926, 'max_depth': 19, 'num_leaves': 119, 'feature_fraction': 0.44123712890846883, 'min_child_samples': 47}. Best is trial 9 with value: 5.323497697401839.
# [I 2024-10-16 21:27:15,861] Trial 44 finished with value: 5.327361550044493 and parameters: {'lambda_l1': 7.283309303827439, 'lambda_l2': 7.488947183275922, 'max_depth': 12, 'num_leaves': 29, 'feature_fraction': 0.440996944133391, 'min_child_samples': 24}. Best is trial 9 with value: 5.323497697401839.
# [I 2024-10-16 21:27:15,949] Trial 45 finished with value: 5.353309433638267 and parameters: {'lambda_l1': 5.937753990987566, 'lambda_l2': 9.27477560665493, 'max_depth': 4, 'num_leaves': 21, 'feature_fraction': 0.08474433830128524, 'min_child_samples': 39}. Best is trial 9 with value: 5.323497697401839.
# [I 2024-10-16 21:27:16,030] Trial 46 finished with value: 5.344134836104397 and parameters: {'lambda_l1': 0.7290652454728227, 'lambda_l2': 0.8353642645311443, 'max_depth': 21, 'num_leaves': 151, 'feature_fraction': 0.3716501369015927, 'min_child_samples': 64}. Best is trial 9 with value: 5.323497697401839.
# [I 2024-10-16 21:27:16,146] Trial 47 finished with value: 5.342813944489327 and parameters: {'lambda_l1': 0.9503729415542443, 'lambda_l2': 5.984877369569943, 'max_depth': 32, 'num_leaves': 222, 'feature_fraction': 0.8846092517107087, 'min_child_samples': 25}. Best is trial 9 with value: 5.323497697401839.
# [I 2024-10-16 21:27:16,227] Trial 48 finished with value: 5.322733186392017 and parameters: {'lambda_l1': 9.98309291492172, 'lambda_l2': 4.09130013452504, 'max_depth': 5, 'num_leaves': 23, 'feature_fraction': 0.5087459183109926, 'min_child_samples': 57}. Best is trial 48 with value: 5.322733186392017.
# [I 2024-10-16 21:27:16,279] Trial 49 finished with value: 5.337535680613589 and parameters: {'lambda_l1': 0.3489931223249833, 'lambda_l2': 5.985095723120339, 'max_depth': 3, 'num_leaves': 47, 'feature_fraction': 0.28627452007117343, 'min_child_samples': 60}. Best is trial 48 with value: 5.322733186392017.
# [I 2024-10-16 21:27:16,386] Trial 50 finished with value: 5.328883724028739 and parameters: {'lambda_l1': 9.423692564022828, 'lambda_l2': 4.981761224834295, 'max_depth': 3, 'num_leaves': 31, 'feature_fraction': 0.42510096384346485, 'min_child_samples': 37}. Best is trial 48 with value: 5.322733186392017.
# [I 2024-10-16 21:27:16,474] Trial 51 finished with value: 5.330613116521433 and parameters: {'lambda_l1': 9.812872508930658, 'lambda_l2': 7.363248735871984, 'max_depth': 6, 'num_leaves': 38, 'feature_fraction': 0.6717762610682074, 'min_child_samples': 36}. Best is trial 48 with value: 5.322733186392017.
# [I 2024-10-16 21:27:16,615] Trial 52 finished with value: 5.321206834932809 and parameters: {'lambda_l1': 7.936211413817276, 'lambda_l2': 8.517760861326554, 'max_depth': 6, 'num_leaves': 160, 'feature_fraction': 0.4252578940034271, 'min_child_samples': 43}. Best is trial 52 with value: 5.321206834932809.
# [I 2024-10-16 21:27:16,727] Trial 53 finished with value: 5.334566177799657 and parameters: {'lambda_l1': 3.6450899248473387, 'lambda_l2': 1.512273886574846, 'max_depth': 19, 'num_leaves': 221, 'feature_fraction': 0.5928654998599265, 'min_child_samples': 39}. Best is trial 52 with value: 5.321206834932809.
# [I 2024-10-16 21:27:16,835] Trial 54 finished with value: 5.320395002279507 and parameters: {'lambda_l1': 8.304591584071094, 'lambda_l2': 7.721228554228989, 'max_depth': 9, 'num_leaves': 187, 'feature_fraction': 0.4292674874214325, 'min_child_samples': 50}. Best is trial 54 with value: 5.320395002279507.
# [I 2024-10-16 21:27:16,947] Trial 55 finished with value: 5.3373899100232185 and parameters: {'lambda_l1': 6.4755882751833, 'lambda_l2': 7.797428140782904, 'max_depth': 8, 'num_leaves': 135, 'feature_fraction': 0.3212134020517098, 'min_child_samples': 46}. Best is trial 54 with value: 5.320395002279507.
# [I 2024-10-16 21:27:17,068] Trial 56 finished with value: 5.321014431555201 and parameters: {'lambda_l1': 8.75633073072442, 'lambda_l2': 7.592954201115989, 'max_depth': 5, 'num_leaves': 157, 'feature_fraction': 0.4879967616606627, 'min_child_samples': 42}. Best is trial 54 with value: 5.320395002279507.
# [I 2024-10-16 21:27:17,181] Trial 57 finished with value: 5.323395924485907 and parameters: {'lambda_l1': 7.589043814548087, 'lambda_l2': 8.581874437580828, 'max_depth': 6, 'num_leaves': 179, 'feature_fraction': 0.4627087387124319, 'min_child_samples': 53}. Best is trial 54 with value: 5.320395002279507.
# [I 2024-10-16 21:27:17,307] Trial 58 finished with value: 5.316642252034766 and parameters: {'lambda_l1': 8.28761833112056, 'lambda_l2': 7.031018943536326, 'max_depth': 5, 'num_leaves': 179, 'feature_fraction': 0.4607199710056904, 'min_child_samples': 52}. Best is trial 58 with value: 5.316642252034766.
# [I 2024-10-16 21:27:17,396] Trial 59 finished with value: 5.334439689664637 and parameters: {'lambda_l1': 8.428512981684351, 'lambda_l2': 6.896493030391632, 'max_depth': 4, 'num_leaves': 198, 'feature_fraction': 0.3634784869621873, 'min_child_samples': 30}. Best is trial 58 with value: 5.316642252034766.
# [I 2024-10-16 21:27:17,509] Trial 60 finished with value: 5.343773663474781 and parameters: {'lambda_l1': 8.795374063981784, 'lambda_l2': 7.894263189805138, 'max_depth': 6, 'num_leaves': 133, 'feature_fraction': 0.36150242233186625, 'min_child_samples': 36}. Best is trial 58 with value: 5.316642252034766.
# [I 2024-10-16 21:27:17,609] Trial 61 finished with value: 5.315108930589671 and parameters: {'lambda_l1': 7.485680639597116, 'lambda_l2': 7.135197382038718, 'max_depth': 5, 'num_leaves': 172, 'feature_fraction': 0.5507385474484998, 'min_child_samples': 52}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:17,708] Trial 62 finished with value: 5.319527757936312 and parameters: {'lambda_l1': 9.224890750285258, 'lambda_l2': 8.424282085762444, 'max_depth': 3, 'num_leaves': 186, 'feature_fraction': 0.5528343442929716, 'min_child_samples': 49}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:17,830] Trial 63 finished with value: 5.328861687696669 and parameters: {'lambda_l1': 9.492775803939935, 'lambda_l2': 5.7633111850355006, 'max_depth': 5, 'num_leaves': 190, 'feature_fraction': 0.5850958958089676, 'min_child_samples': 52}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:17,926] Trial 64 finished with value: 5.32005439587126 and parameters: {'lambda_l1': 6.9407137094455695, 'lambda_l2': 6.830411986602479, 'max_depth': 3, 'num_leaves': 160, 'feature_fraction': 0.5840133901311764, 'min_child_samples': 50}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:18,017] Trial 65 finished with value: 5.333444643253004 and parameters: {'lambda_l1': 7.023172632977365, 'lambda_l2': 7.654104263545126, 'max_depth': 6, 'num_leaves': 165, 'feature_fraction': 0.6928358910308845, 'min_child_samples': 51}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:18,154] Trial 66 finished with value: 5.329311497254888 and parameters: {'lambda_l1': 9.163552859360781, 'lambda_l2': 9.220976211324006, 'max_depth': 3, 'num_leaves': 200, 'feature_fraction': 0.25637646083650134, 'min_child_samples': 50}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:18,326] Trial 67 finished with value: 5.3208311941309265 and parameters: {'lambda_l1': 9.646987482156883, 'lambda_l2': 8.828400515124072, 'max_depth': 1, 'num_leaves': 168, 'feature_fraction': 0.6496104651200094, 'min_child_samples': 45}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:18,525] Trial 68 finished with value: 5.323486918646301 and parameters: {'lambda_l1': 8.300957183477395, 'lambda_l2': 7.980849896879763, 'max_depth': 1, 'num_leaves': 211, 'feature_fraction': 0.5629767815767729, 'min_child_samples': 40}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:18,761] Trial 69 finished with value: 5.322970429384598 and parameters: {'lambda_l1': 7.503030579274664, 'lambda_l2': 9.19242203483063, 'max_depth': 1, 'num_leaves': 127, 'feature_fraction': 0.651348517304376, 'min_child_samples': 55}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:18,893] Trial 70 finished with value: 5.333331227252194 and parameters: {'lambda_l1': 9.167778288975015, 'lambda_l2': 8.299493368697718, 'max_depth': 6, 'num_leaves': 179, 'feature_fraction': 0.6440615371112307, 'min_child_samples': 55}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:19,028] Trial 71 finished with value: 5.332205356460568 and parameters: {'lambda_l1': 7.314395982222249, 'lambda_l2': 6.363783385410118, 'max_depth': 4, 'num_leaves': 191, 'feature_fraction': 0.5531782140583791, 'min_child_samples': 63}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:19,271] Trial 72 finished with value: 5.328185333919803 and parameters: {'lambda_l1': 8.532859696471013, 'lambda_l2': 7.739168109568529, 'max_depth': 2, 'num_leaves': 137, 'feature_fraction': 0.47714305711779337, 'min_child_samples': 37}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:19,409] Trial 73 finished with value: 5.332160014179472 and parameters: {'lambda_l1': 9.414882137435157, 'lambda_l2': 8.902249566441084, 'max_depth': 5, 'num_leaves': 144, 'feature_fraction': 0.5115278039067614, 'min_child_samples': 68}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:19,618] Trial 74 finished with value: 5.323040205799045 and parameters: {'lambda_l1': 9.92191176687773, 'lambda_l2': 8.387620104668397, 'max_depth': 1, 'num_leaves': 178, 'feature_fraction': 0.664705447209499, 'min_child_samples': 55}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:19,722] Trial 75 finished with value: 5.322073189313931 and parameters: {'lambda_l1': 6.916777449144551, 'lambda_l2': 6.828530900886109, 'max_depth': 12, 'num_leaves': 167, 'feature_fraction': 0.5664958681173238, 'min_child_samples': 42}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:19,858] Trial 76 finished with value: 5.330732302374435 and parameters: {'lambda_l1': 9.295437151364837, 'lambda_l2': 9.587408291674407, 'max_depth': 11, 'num_leaves': 161, 'feature_fraction': 0.582933011236471, 'min_child_samples': 30}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:19,959] Trial 77 finished with value: 5.348864601871929 and parameters: {'lambda_l1': 7.659597145154292, 'lambda_l2': 6.455527254423817, 'max_depth': 11, 'num_leaves': 182, 'feature_fraction': 0.33468226812447915, 'min_child_samples': 63}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:20,109] Trial 78 finished with value: 5.336712340246152 and parameters: {'lambda_l1': 9.054269103536814, 'lambda_l2': 6.956124796129603, 'max_depth': 10, 'num_leaves': 240, 'feature_fraction': 0.33792335703880716, 'min_child_samples': 48}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:20,241] Trial 79 finished with value: 5.339118517199328 and parameters: {'lambda_l1': 4.8759339445001775, 'lambda_l2': 6.079566969971055, 'max_depth': 3, 'num_leaves': 139, 'feature_fraction': 0.4333629562770996, 'min_child_samples': 26}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:20,334] Trial 80 finished with value: 5.3358350572915425 and parameters: {'lambda_l1': 9.9539586773752, 'lambda_l2': 9.027407373049744, 'max_depth': 3, 'num_leaves': 149, 'feature_fraction': 0.8213454942598771, 'min_child_samples': 43}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:20,467] Trial 81 finished with value: 5.330008626435632 and parameters: {'lambda_l1': 6.905095621018054, 'lambda_l2': 5.8177331043451925, 'max_depth': 3, 'num_leaves': 151, 'feature_fraction': 0.4992634926606471, 'min_child_samples': 56}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:20,633] Trial 82 finished with value: 5.334557776754304 and parameters: {'lambda_l1': 5.754011005983764, 'lambda_l2': 7.031435660668979, 'max_depth': 10, 'num_leaves': 159, 'feature_fraction': 0.6989045895487229, 'min_child_samples': 36}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:20,780] Trial 83 finished with value: 5.3395484015349295 and parameters: {'lambda_l1': 8.293750805261825, 'lambda_l2': 7.484570825625726, 'max_depth': 16, 'num_leaves': 192, 'feature_fraction': 0.6549461507185518, 'min_child_samples': 55}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:20,930] Trial 84 finished with value: 5.321492877153334 and parameters: {'lambda_l1': 8.539444312141207, 'lambda_l2': 6.162035821462207, 'max_depth': 11, 'num_leaves': 114, 'feature_fraction': 0.49710215518144, 'min_child_samples': 58}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:21,053] Trial 85 finished with value: 5.321803479371942 and parameters: {'lambda_l1': 9.993790074646173, 'lambda_l2': 7.289230314411653, 'max_depth': 11, 'num_leaves': 148, 'feature_fraction': 0.49789440859471906, 'min_child_samples': 48}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:21,237] Trial 86 finished with value: 5.322810279778489 and parameters: {'lambda_l1': 7.991145680907138, 'lambda_l2': 5.850733449634098, 'max_depth': 1, 'num_leaves': 90, 'feature_fraction': 0.7303620397100378, 'min_child_samples': 51}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:21,347] Trial 87 finished with value: 5.3368319363672905 and parameters: {'lambda_l1': 8.379228972660407, 'lambda_l2': 3.2359995979768277, 'max_depth': 9, 'num_leaves': 148, 'feature_fraction': 0.4364984470261304, 'min_child_samples': 62}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:21,532] Trial 88 finished with value: 5.322025451713889 and parameters: {'lambda_l1': 9.464787796815116, 'lambda_l2': 6.579221672654581, 'max_depth': 1, 'num_leaves': 148, 'feature_fraction': 0.5173875527841484, 'min_child_samples': 40}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:21,679] Trial 89 finished with value: 5.333304818245513 and parameters: {'lambda_l1': 8.615395604942615, 'lambda_l2': 6.027345512111696, 'max_depth': 14, 'num_leaves': 140, 'feature_fraction': 0.4875286424819773, 'min_child_samples': 67}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:21,775] Trial 90 finished with value: 5.326668059223573 and parameters: {'lambda_l1': 5.330159314774126, 'lambda_l2': 8.773022645577077, 'max_depth': 4, 'num_leaves': 187, 'feature_fraction': 0.5561875965402641, 'min_child_samples': 64}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:21,914] Trial 91 finished with value: 5.344558865039646 and parameters: {'lambda_l1': 9.122995596982182, 'lambda_l2': 6.272409649153211, 'max_depth': 9, 'num_leaves': 146, 'feature_fraction': 0.2261624805488962, 'min_child_samples': 57}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:22,044] Trial 92 finished with value: 5.325967717921615 and parameters: {'lambda_l1': 9.488573171062178, 'lambda_l2': 7.712254063447018, 'max_depth': 15, 'num_leaves': 128, 'feature_fraction': 0.5561624110549852, 'min_child_samples': 56}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:22,154] Trial 93 finished with value: 5.3366137865558105 and parameters: {'lambda_l1': 9.97248014108198, 'lambda_l2': 7.152690433745557, 'max_depth': 8, 'num_leaves': 139, 'feature_fraction': 0.3979427862513987, 'min_child_samples': 59}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:22,256] Trial 94 finished with value: 5.3323178411619265 and parameters: {'lambda_l1': 9.123658748220855, 'lambda_l2': 4.894255803053547, 'max_depth': 8, 'num_leaves': 119, 'feature_fraction': 0.6888571470563241, 'min_child_samples': 37}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:22,370] Trial 95 finished with value: 5.320717643004078 and parameters: {'lambda_l1': 9.410234621992407, 'lambda_l2': 5.581239316373409, 'max_depth': 18, 'num_leaves': 119, 'feature_fraction': 0.559797630419865, 'min_child_samples': 41}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:22,488] Trial 96 finished with value: 5.324948087975607 and parameters: {'lambda_l1': 9.562839451784463, 'lambda_l2': 5.082962666588385, 'max_depth': 22, 'num_leaves': 157, 'feature_fraction': 0.7396689782406536, 'min_child_samples': 49}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:22,630] Trial 97 finished with value: 5.3318688967038 and parameters: {'lambda_l1': 9.302679576750466, 'lambda_l2': 5.271448546572819, 'max_depth': 21, 'num_leaves': 63, 'feature_fraction': 0.6832533247065842, 'min_child_samples': 47}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:22,768] Trial 98 finished with value: 5.32277304028284 and parameters: {'lambda_l1': 9.286706311551194, 'lambda_l2': 4.069001022428421, 'max_depth': 26, 'num_leaves': 105, 'feature_fraction': 0.5146841972456332, 'min_child_samples': 43}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:22,853] Trial 99 finished with value: 5.326908728404698 and parameters: {'lambda_l1': 6.206756809407146, 'lambda_l2': 6.322084212708203, 'max_depth': 2, 'num_leaves': 170, 'feature_fraction': 0.8122198828720275, 'min_child_samples': 44}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:22,967] Trial 100 finished with value: 5.321349828891208 and parameters: {'lambda_l1': 9.329451510256288, 'lambda_l2': 9.396055413913773, 'max_depth': 4, 'num_leaves': 213, 'feature_fraction': 0.49987230231591984, 'min_child_samples': 48}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:23,106] Trial 101 finished with value: 5.333346826881753 and parameters: {'lambda_l1': 9.676642985548343, 'lambda_l2': 9.060977082334352, 'max_depth': 5, 'num_leaves': 226, 'feature_fraction': 0.41284966435379566, 'min_child_samples': 48}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:23,216] Trial 102 finished with value: 5.32997885592085 and parameters: {'lambda_l1': 9.287615782810699, 'lambda_l2': 9.95576529153831, 'max_depth': 3, 'num_leaves': 201, 'feature_fraction': 0.5174328227437126, 'min_child_samples': 60}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:23,347] Trial 103 finished with value: 5.336483095283617 and parameters: {'lambda_l1': 9.10849225067151, 'lambda_l2': 6.617486191715992, 'max_depth': 20, 'num_leaves': 116, 'feature_fraction': 0.7088813191246321, 'min_child_samples': 30}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:23,450] Trial 104 finished with value: 5.331395825457821 and parameters: {'lambda_l1': 7.737814546114459, 'lambda_l2': 8.514363595802266, 'max_depth': 10, 'num_leaves': 239, 'feature_fraction': 0.6403376202702564, 'min_child_samples': 46}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:23,576] Trial 105 finished with value: 5.324830134383433 and parameters: {'lambda_l1': 9.886224839898013, 'lambda_l2': 5.746768719846153, 'max_depth': 13, 'num_leaves': 79, 'feature_fraction': 0.48182780844125594, 'min_child_samples': 27}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:23,679] Trial 106 finished with value: 5.342433016201489 and parameters: {'lambda_l1': 8.006509366353212, 'lambda_l2': 4.4443884256011845, 'max_depth': 14, 'num_leaves': 85, 'feature_fraction': 0.560385147807768, 'min_child_samples': 71}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:23,814] Trial 107 finished with value: 5.348832903177397 and parameters: {'lambda_l1': 7.995486417105026, 'lambda_l2': 9.284918461475765, 'max_depth': 2, 'num_leaves': 230, 'feature_fraction': 0.7893795872398652, 'min_child_samples': 21}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:24,025] Trial 108 finished with value: 5.323235957461948 and parameters: {'lambda_l1': 8.724136874121363, 'lambda_l2': 9.321945315311984, 'max_depth': 1, 'num_leaves': 176, 'feature_fraction': 0.6599309768631978, 'min_child_samples': 32}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:24,210] Trial 109 finished with value: 5.3383658271376255 and parameters: {'lambda_l1': 7.616931978398106, 'lambda_l2': 6.992566758824022, 'max_depth': 2, 'num_leaves': 215, 'feature_fraction': 0.39190151274207013, 'min_child_samples': 58}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:24,332] Trial 110 finished with value: 5.3452491869053524 and parameters: {'lambda_l1': 7.436759925828753, 'lambda_l2': 6.544509282924633, 'max_depth': 5, 'num_leaves': 118, 'feature_fraction': 0.566849103791655, 'min_child_samples': 85}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:24,443] Trial 111 finished with value: 5.336224614725743 and parameters: {'lambda_l1': 7.467228309639217, 'lambda_l2': 9.417244883411144, 'max_depth': 10, 'num_leaves': 174, 'feature_fraction': 0.2879125304252329, 'min_child_samples': 43}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:24,555] Trial 112 finished with value: 5.325222995183225 and parameters: {'lambda_l1': 7.463203584839928, 'lambda_l2': 9.657389805284232, 'max_depth': 5, 'num_leaves': 157, 'feature_fraction': 0.4765332710291803, 'min_child_samples': 42}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:24,671] Trial 113 finished with value: 5.32749295554424 and parameters: {'lambda_l1': 9.391879457119376, 'lambda_l2': 9.399820589101894, 'max_depth': 2, 'num_leaves': 34, 'feature_fraction': 0.979503014008939, 'min_child_samples': 45}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:24,811] Trial 114 finished with value: 5.34290640221391 and parameters: {'lambda_l1': 9.611051040253644, 'lambda_l2': 5.380573071787192, 'max_depth': 20, 'num_leaves': 149, 'feature_fraction': 0.4047417776867148, 'min_child_samples': 26}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:24,921] Trial 115 finished with value: 5.326196613660256 and parameters: {'lambda_l1': 9.659793044244793, 'lambda_l2': 8.072955255635689, 'max_depth': 7, 'num_leaves': 190, 'feature_fraction': 0.4846879223002808, 'min_child_samples': 43}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:25,016] Trial 116 finished with value: 5.321792172309243 and parameters: {'lambda_l1': 7.988585135072894, 'lambda_l2': 6.3589923206455845, 'max_depth': 9, 'num_leaves': 134, 'feature_fraction': 0.5763384963763349, 'min_child_samples': 46}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:25,124] Trial 117 finished with value: 5.338763750249499 and parameters: {'lambda_l1': 6.445356109361878, 'lambda_l2': 5.0977710405404455, 'max_depth': 11, 'num_leaves': 98, 'feature_fraction': 0.37497171873104523, 'min_child_samples': 57}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:25,338] Trial 118 finished with value: 5.381839189338892 and parameters: {'lambda_l1': 2.401790493893144, 'lambda_l2': 6.43805508083169, 'max_depth': 24, 'num_leaves': 228, 'feature_fraction': 0.09272574804824979, 'min_child_samples': 16}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:25,452] Trial 119 finished with value: 5.346652513092707 and parameters: {'lambda_l1': 3.1925621816160765, 'lambda_l2': 8.809000953387232, 'max_depth': 14, 'num_leaves': 81, 'feature_fraction': 0.42854997365830916, 'min_child_samples': 94}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:25,591] Trial 120 finished with value: 5.354712257022344 and parameters: {'lambda_l1': 7.674943942517641, 'lambda_l2': 8.09978040248432, 'max_depth': 31, 'num_leaves': 234, 'feature_fraction': 0.05697129815536395, 'min_child_samples': 69}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:25,696] Trial 121 finished with value: 5.331320735377388 and parameters: {'lambda_l1': 8.742843129218578, 'lambda_l2': 6.431382736455281, 'max_depth': 9, 'num_leaves': 104, 'feature_fraction': 0.6436236599656961, 'min_child_samples': 45}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:25,799] Trial 122 finished with value: 5.319358358764759 and parameters: {'lambda_l1': 8.361597822865148, 'lambda_l2': 7.523673668143022, 'max_depth': 11, 'num_leaves': 136, 'feature_fraction': 0.5018948144942643, 'min_child_samples': 48}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:25,901] Trial 123 finished with value: 5.319341625399351 and parameters: {'lambda_l1': 7.700983778011727, 'lambda_l2': 8.073219041541435, 'max_depth': 13, 'num_leaves': 99, 'feature_fraction': 0.487049089786964, 'min_child_samples': 50}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:26,033] Trial 124 finished with value: 5.334945980060488 and parameters: {'lambda_l1': 5.198619680790154, 'lambda_l2': 7.328583195860129, 'max_depth': 12, 'num_leaves': 72, 'feature_fraction': 0.6178198951834243, 'min_child_samples': 43}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:26,152] Trial 125 finished with value: 5.339488429936395 and parameters: {'lambda_l1': 7.142346190209735, 'lambda_l2': 7.357388430752579, 'max_depth': 17, 'num_leaves': 64, 'feature_fraction': 0.42744985284497483, 'min_child_samples': 73}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:26,262] Trial 126 finished with value: 5.328453206121076 and parameters: {'lambda_l1': 6.889431558178846, 'lambda_l2': 7.912579610941554, 'max_depth': 16, 'num_leaves': 72, 'feature_fraction': 0.708107576069922, 'min_child_samples': 58}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:26,375] Trial 127 finished with value: 5.3541199608789345 and parameters: {'lambda_l1': 0.5144382358681261, 'lambda_l2': 1.009762291528069, 'max_depth': 29, 'num_leaves': 22, 'feature_fraction': 0.055747593793744, 'min_child_samples': 96}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:26,576] Trial 128 finished with value: 5.325504378961221 and parameters: {'lambda_l1': 8.926843171774271, 'lambda_l2': 5.251324407518819, 'max_depth': 1, 'num_leaves': 217, 'feature_fraction': 0.7931397657349866, 'min_child_samples': 38}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:26,685] Trial 129 finished with value: 5.338876551005597 and parameters: {'lambda_l1': 8.633747378605273, 'lambda_l2': 8.561071555484034, 'max_depth': 14, 'num_leaves': 112, 'feature_fraction': 0.3994352284054328, 'min_child_samples': 51}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:26,870] Trial 130 finished with value: 5.324409734198252 and parameters: {'lambda_l1': 6.7528995257344215, 'lambda_l2': 8.218593134127884, 'max_depth': 1, 'num_leaves': 150, 'feature_fraction': 0.30195491237457395, 'min_child_samples': 50}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:27,031] Trial 131 finished with value: 5.327061280017697 and parameters: {'lambda_l1': 9.911152470441674, 'lambda_l2': 1.659599695281012, 'max_depth': 16, 'num_leaves': 113, 'feature_fraction': 0.5581074367477397, 'min_child_samples': 31}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:27,211] Trial 132 finished with value: 5.3537403872920555 and parameters: {'lambda_l1': 7.088507613358989, 'lambda_l2': 3.300821327212411, 'max_depth': 32, 'num_leaves': 182, 'feature_fraction': 0.1950369286148707, 'min_child_samples': 34}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:27,406] Trial 133 finished with value: 5.32128707922526 and parameters: {'lambda_l1': 7.610948544961458, 'lambda_l2': 7.6463352949795755, 'max_depth': 10, 'num_leaves': 135, 'feature_fraction': 0.5639566255996877, 'min_child_samples': 43}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:27,547] Trial 134 finished with value: 5.331277877990702 and parameters: {'lambda_l1': 6.508314333693352, 'lambda_l2': 7.26141326481937, 'max_depth': 7, 'num_leaves': 129, 'feature_fraction': 0.4293579810364559, 'min_child_samples': 64}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:27,690] Trial 135 finished with value: 5.326355534281785 and parameters: {'lambda_l1': 7.625805143776784, 'lambda_l2': 6.714763522942114, 'max_depth': 14, 'num_leaves': 92, 'feature_fraction': 0.42131844600499246, 'min_child_samples': 38}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:27,809] Trial 136 finished with value: 5.325827455938035 and parameters: {'lambda_l1': 5.822664930355487, 'lambda_l2': 9.91313632731403, 'max_depth': 22, 'num_leaves': 153, 'feature_fraction': 0.5733365881319136, 'min_child_samples': 33}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:27,951] Trial 137 finished with value: 5.35268283638077 and parameters: {'lambda_l1': 6.122739377054868, 'lambda_l2': 0.493949942731545, 'max_depth': 28, 'num_leaves': 30, 'feature_fraction': 0.12370315262431264, 'min_child_samples': 47}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:28,110] Trial 138 finished with value: 5.331174184048688 and parameters: {'lambda_l1': 8.55271030878797, 'lambda_l2': 5.704276607017803, 'max_depth': 9, 'num_leaves': 184, 'feature_fraction': 0.5342606866433024, 'min_child_samples': 26}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:28,226] Trial 139 finished with value: 5.342821587430506 and parameters: {'lambda_l1': 6.65467395476709, 'lambda_l2': 8.982604339611022, 'max_depth': 11, 'num_leaves': 137, 'feature_fraction': 0.6661650900264169, 'min_child_samples': 72}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:28,400] Trial 140 finished with value: 5.331924641126923 and parameters: {'lambda_l1': 7.626186776627482, 'lambda_l2': 9.01806351836496, 'max_depth': 14, 'num_leaves': 106, 'feature_fraction': 0.5542351068627487, 'min_child_samples': 30}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:28,530] Trial 141 finished with value: 5.326709028049965 and parameters: {'lambda_l1': 7.233413221620955, 'lambda_l2': 7.143909523147892, 'max_depth': 11, 'num_leaves': 147, 'feature_fraction': 0.48453930606306495, 'min_child_samples': 33}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:28,679] Trial 142 finished with value: 5.325421171162626 and parameters: {'lambda_l1': 7.926424088642541, 'lambda_l2': 6.216821125625712, 'max_depth': 7, 'num_leaves': 102, 'feature_fraction': 0.5190824333941205, 'min_child_samples': 54}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:28,830] Trial 143 finished with value: 5.323208186008592 and parameters: {'lambda_l1': 7.269149322928956, 'lambda_l2': 7.658640082301129, 'max_depth': 10, 'num_leaves': 161, 'feature_fraction': 0.4814360367751769, 'min_child_samples': 40}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:28,983] Trial 144 finished with value: 5.330001363167637 and parameters: {'lambda_l1': 4.897429178727992, 'lambda_l2': 5.445702915742869, 'max_depth': 4, 'num_leaves': 238, 'feature_fraction': 0.6096401039846875, 'min_child_samples': 47}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:29,120] Trial 145 finished with value: 5.336766956473629 and parameters: {'lambda_l1': 7.871209064055261, 'lambda_l2': 7.042170323711317, 'max_depth': 10, 'num_leaves': 136, 'feature_fraction': 0.594368910986762, 'min_child_samples': 57}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:29,270] Trial 146 finished with value: 5.348414163332374 and parameters: {'lambda_l1': 5.3649500968123816, 'lambda_l2': 1.0881885632403487, 'max_depth': 32, 'num_leaves': 49, 'feature_fraction': 0.40068259629783354, 'min_child_samples': 90}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:29,428] Trial 147 finished with value: 5.336633709848581 and parameters: {'lambda_l1': 9.68812163139952, 'lambda_l2': 9.408013319517892, 'max_depth': 2, 'num_leaves': 215, 'feature_fraction': 0.3602162252195805, 'min_child_samples': 19}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:29,656] Trial 148 finished with value: 5.35826943756065 and parameters: {'lambda_l1': 2.674822552382653, 'lambda_l2': 6.148427087641624, 'max_depth': 19, 'num_leaves': 59, 'feature_fraction': 0.7782187977904964, 'min_child_samples': 4}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:29,801] Trial 149 finished with value: 5.331888476775452 and parameters: {'lambda_l1': 7.06467719423891, 'lambda_l2': 6.586139703684176, 'max_depth': 3, 'num_leaves': 199, 'feature_fraction': 0.593244331119069, 'min_child_samples': 46}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:29,936] Trial 150 finished with value: 5.346880059250085 and parameters: {'lambda_l1': 4.905859176725681, 'lambda_l2': 1.3862487407494872, 'max_depth': 8, 'num_leaves': 32, 'feature_fraction': 0.7795303164399723, 'min_child_samples': 73}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:30,036] Trial 151 finished with value: 5.321284174135555 and parameters: {'lambda_l1': 8.17428319018946, 'lambda_l2': 6.654542331597107, 'max_depth': 3, 'num_leaves': 163, 'feature_fraction': 0.43985368564210636, 'min_child_samples': 56}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:30,158] Trial 152 finished with value: 5.321144125742339 and parameters: {'lambda_l1': 8.530457522865603, 'lambda_l2': 6.4287963948589475, 'max_depth': 6, 'num_leaves': 190, 'feature_fraction': 0.5266648645122042, 'min_child_samples': 54}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:30,289] Trial 153 finished with value: 5.324161334111516 and parameters: {'lambda_l1': 8.25419081392895, 'lambda_l2': 7.075529057792275, 'max_depth': 7, 'num_leaves': 193, 'feature_fraction': 0.509562601123385, 'min_child_samples': 60}. Best is trial 61 with value: 5.315108930589671.
# [I 2024-10-16 21:27:30,405] Trial 154 finished with value: 5.343438865963127 and parameters: {'lambda_l1': 8.847289482807618, 'lambda_l2': 7.794460320172311, 'max_depth': 6, 'num_leaves': 166, 'feature_fraction': 0.38793315897985486, 'min_child_samples': 56}. Best is trial 61 with value: 5.315108930589671.
# ...
# [I 2024-10-16 21:28:19,034] Trial 449 finished with value: 5.321157610695585 and parameters: {'lambda_l1': 8.444882118452938, 'lambda_l2': 6.448959990472197, 'max_depth': 12, 'num_leaves': 197, 'feature_fraction': 0.5402792330761081, 'min_child_samples': 52}. Best is trial 260 with value: 5.315060318632571.
# [I 2024-10-16 21:28:19,207] Trial 450 finished with value: 5.354607171575558 and parameters: {'lambda_l1': 7.427363369267384, 'lambda_l2': 2.4283518159662165, 'max_depth': 11, 'num_leaves': 107, 'feature_fraction': 0.20215005161968536, 'min_child_samples': 76}. Best is trial 260 with value: 5.315060318632571.
# [I 2024-10-16 21:28:19,337] Trial 451 finished with value: 5.333638681010822 and parameters: {'lambda_l1': 7.790583112964523, 'lambda_l2': 7.417434978036578, 'max_depth': 16, 'num_leaves': 103, 'feature_fraction': 0.5416733329795513, 'min_child_samples': 63}. Best is trial 260 with value: 5.315060318632571.
# [I 2024-10-16 21:28:19,576] Trial 452 finished with value: 5.358025949779195 and parameters: {'lambda_l1': 5.272013157723483, 'lambda_l2': 2.142394978333413, 'max_depth': 8, 'num_leaves': 254, 'feature_fraction': 0.6062254418816222, 'min_child_samples': 12}. Best is trial 260 with value: 5.315060318632571.
# [I 2024-10-16 21:28:19,726] Trial 453 finished with value: 5.323864081343178 and parameters: {'lambda_l1': 4.165511878525691, 'lambda_l2': 2.3355350533863493, 'max_depth': 12, 'num_leaves': 33, 'feature_fraction': 0.43948585579063165, 'min_child_samples': 47}. Best is trial 260 with value: 5.315060318632571.
# [I 2024-10-16 21:28:19,843] Trial 454 finished with value: 5.34611497018951 and parameters: {'lambda_l1': 3.8530593905890704, 'lambda_l2': 5.28184882849724, 'max_depth': 11, 'num_leaves': 147, 'feature_fraction': 0.7069246549929717, 'min_child_samples': 55}. Best is trial 260 with value: 5.315060318632571.
# [I 2024-10-16 21:28:20,036] Trial 455 finished with value: 5.324214174712432 and parameters: {'lambda_l1': 3.4091878211637408, 'lambda_l2': 7.696486974487664, 'max_depth': 24, 'num_leaves': 66, 'feature_fraction': 0.4813301274129804, 'min_child_samples': 33}. Best is trial 260 with value: 5.315060318632571.
# [I 2024-10-16 21:28:20,217] Trial 456 finished with value: 5.328338045260657 and parameters: {'lambda_l1': 8.263528262173532, 'lambda_l2': 9.465518321695887, 'max_depth': 32, 'num_leaves': 243, 'feature_fraction': 0.5163212964380006, 'min_child_samples': 35}. Best is trial 260 with value: 5.315060318632571.
# [I 2024-10-16 21:28:20,404] Trial 457 finished with value: 5.322998342771169 and parameters: {'lambda_l1': 7.338667848952479, 'lambda_l2': 6.172688169486943, 'max_depth': 1, 'num_leaves': 237, 'feature_fraction': 0.488644272287874, 'min_child_samples': 25}. Best is trial 260 with value: 5.315060318632571.
# [I 2024-10-16 21:28:20,518] Trial 458 finished with value: 5.334754844291564 and parameters: {'lambda_l1': 7.32146535475249, 'lambda_l2': 6.87421369671306, 'max_depth': 8, 'num_leaves': 127, 'feature_fraction': 0.4041595192258638, 'min_child_samples': 53}. Best is trial 260 with value: 5.315060318632571.
# [I 2024-10-16 21:28:20,774] Trial 459 finished with value: 5.352383520911932 and parameters: {'lambda_l1': 4.93666086453851, 'lambda_l2': 0.7667564326468304, 'max_depth': 27, 'num_leaves': 185, 'feature_fraction': 0.7184837018819324, 'min_child_samples': 8}. Best is trial 260 with value: 5.315060318632571.
# [I 2024-10-16 21:28:20,967] Trial 460 finished with value: 5.328447335819321 and parameters: {'lambda_l1': 4.636944584664121, 'lambda_l2': 0.052104751104045555, 'max_depth': 14, 'num_leaves': 187, 'feature_fraction': 0.8775712376339331, 'min_child_samples': 59}. Best is trial 260 with value: 5.315060318632571.
# [I 2024-10-16 21:28:21,180] Trial 461 finished with value: 5.348274846471301 and parameters: {'lambda_l1': 3.2043288096893856, 'lambda_l2': 2.2351298553224486, 'max_depth': 12, 'num_leaves': 36, 'feature_fraction': 0.5888246799803922, 'min_child_samples': 20}. Best is trial 260 with value: 5.315060318632571.
# [I 2024-10-16 21:28:21,366] Trial 462 finished with value: 5.327230721399922 and parameters: {'lambda_l1': 7.099969712427854, 'lambda_l2': 6.8760459829733644, 'max_depth': 12, 'num_leaves': 87, 'feature_fraction': 0.6529435389277984, 'min_child_samples': 41}. Best is trial 260 with value: 5.315060318632571.
# [I 2024-10-16 21:28:21,546] Trial 463 finished with value: 5.356982740345869 and parameters: {'lambda_l1': 3.220705825825494, 'lambda_l2': 5.912378872152598, 'max_depth': 32, 'num_leaves': 186, 'feature_fraction': 0.04129759010345402, 'min_child_samples': 80}. Best is trial 260 with value: 5.315060318632571.
# [I 2024-10-16 21:28:21,739] Trial 464 finished with value: 5.345200059413111 and parameters: {'lambda_l1': 5.107162104670435, 'lambda_l2': 1.5163034541881624, 'max_depth': 12, 'num_leaves': 124, 'feature_fraction': 0.38921327814044004, 'min_child_samples': 64}. Best is trial 260 with value: 5.315060318632571.
# [I 2024-10-16 21:28:21,872] Trial 465 finished with value: 5.349248538275087 and parameters: {'lambda_l1': 5.806589918853583, 'lambda_l2': 7.490398698170334, 'max_depth': 5, 'num_leaves': 144, 'feature_fraction': 0.3210737489178977, 'min_child_samples': 94}. Best is trial 260 with value: 5.315060318632571.
# [I 2024-10-16 21:28:22,014] Trial 466 finished with value: 5.3464783560791735 and parameters: {'lambda_l1': 5.920121517789007, 'lambda_l2': 8.544589206275806, 'max_depth': 30, 'num_leaves': 114, 'feature_fraction': 0.7459289193913636, 'min_child_samples': 73}. Best is trial 260 with value: 5.315060318632571.
# [I 2024-10-16 21:28:22,170] Trial 467 finished with value: 5.331967865174848 and parameters: {'lambda_l1': 8.116435327618593, 'lambda_l2': 4.876625802160853, 'max_depth': 26, 'num_leaves': 60, 'feature_fraction': 0.8953949139246076, 'min_child_samples': 61}. Best is trial 260 with value: 5.315060318632571.
# [I 2024-10-16 21:28:22,316] Trial 468 finished with value: 5.334436927190986 and parameters: {'lambda_l1': 9.59918195631971, 'lambda_l2': 9.16226373720433, 'max_depth': 11, 'num_leaves': 148, 'feature_fraction': 0.6898836133422134, 'min_child_samples': 60}. Best is trial 260 with value: 5.315060318632571.
# [I 2024-10-16 21:28:22,493] Trial 469 finished with value: 5.358603187089534 and parameters: {'lambda_l1': 9.862354439935034, 'lambda_l2': 3.6091335138975835, 'max_depth': 2, 'num_leaves': 53, 'feature_fraction': 0.7580805650068398, 'min_child_samples': 80}. Best is trial 260 with value: 5.315060318632571.
# [I 2024-10-16 21:28:22,636] Trial 470 finished with value: 5.320555754079456 and parameters: {'lambda_l1': 5.902178522105021, 'lambda_l2': 9.349187433355002, 'max_depth': 3, 'num_leaves': 180, 'feature_fraction': 0.4899351304636441, 'min_child_samples': 50}. Best is trial 260 with value: 5.315060318632571.
# [I 2024-10-16 21:28:22,820] Trial 471 finished with value: 5.336777729762803 and parameters: {'lambda_l1': 2.570019962871608, 'lambda_l2': 4.7981154661234005, 'max_depth': 5, 'num_leaves': 20, 'feature_fraction': 0.8136570934435581, 'min_child_samples': 25}. Best is trial 260 with value: 5.315060318632571.
# [I 2024-10-16 21:28:22,942] Trial 472 finished with value: 5.322074472188451 and parameters: {'lambda_l1': 5.849974276540485, 'lambda_l2': 9.999373298399524, 'max_depth': 7, 'num_leaves': 169, 'feature_fraction': 0.46521582867642663, 'min_child_samples': 26}. Best is trial 260 with value: 5.315060318632571.
# [I 2024-10-16 21:28:23,069] Trial 473 finished with value: 5.341280933277252 and parameters: {'lambda_l1': 5.8661785607488195, 'lambda_l2': 9.905194073881566, 'max_depth': 8, 'num_leaves': 212, 'feature_fraction': 0.4505355552702134, 'min_child_samples': 67}. Best is trial 260 with value: 5.315060318632571.
# [I 2024-10-16 21:28:23,223] Trial 474 finished with value: 5.33426239653425 and parameters: {'lambda_l1': 5.546016802156287, 'lambda_l2': 8.218264675381675, 'max_depth': 3, 'num_leaves': 163, 'feature_fraction': 0.62107452736171, 'min_child_samples': 62}. Best is trial 260 with value: 5.315060318632571.
# [I 2024-10-16 21:28:23,425] Trial 475 finished with value: 5.334144275191803 and parameters: {'lambda_l1': 6.85025481245764, 'lambda_l2': 5.535829374058758, 'max_depth': 18, 'num_leaves': 81, 'feature_fraction': 0.468295446958582, 'min_child_samples': 19}. Best is trial 260 with value: 5.315060318632571.
# [I 2024-10-16 21:28:23,612] Trial 476 finished with value: 5.330967593116828 and parameters: {'lambda_l1': 4.239803522108634, 'lambda_l2': 2.960905063706212, 'max_depth': 6, 'num_leaves': 198, 'feature_fraction': 0.7032677611624325, 'min_child_samples': 61}. Best is trial 260 with value: 5.315060318632571.
# [I 2024-10-16 21:28:23,854] Trial 477 finished with value: 5.322744973546073 and parameters: {'lambda_l1': 6.88361143098877, 'lambda_l2': 7.980814234672159, 'max_depth': 5, 'num_leaves': 210, 'feature_fraction': 0.4658348563810807, 'min_child_samples': 39}. Best is trial 260 with value: 5.315060318632571.
# [I 2024-10-16 21:28:24,109] Trial 478 finished with value: 5.338135987084587 and parameters: {'lambda_l1': 7.423343758281316, 'lambda_l2': 4.661582809189456, 'max_depth': 1, 'num_leaves': 256, 'feature_fraction': 0.5504376577681994, 'min_child_samples': 68}. Best is trial 260 with value: 5.315060318632571.
# [I 2024-10-16 21:28:24,261] Trial 479 finished with value: 5.347829177762611 and parameters: {'lambda_l1': 0.9495041165418598, 'lambda_l2': 2.960829998596223, 'max_depth': 26, 'num_leaves': 253, 'feature_fraction': 0.16726904815867144, 'min_child_samples': 57}. Best is trial 260 with value: 5.315060318632571.
# [I 2024-10-16 21:28:24,412] Trial 480 finished with value: 5.334056587111736 and parameters: {'lambda_l1': 5.1355278583324475, 'lambda_l2': 8.51144559595812, 'max_depth': 2, 'num_leaves': 196, 'feature_fraction': 0.3525188725211339, 'min_child_samples': 47}. Best is trial 260 with value: 5.315060318632571.
# [I 2024-10-16 21:28:24,563] Trial 481 finished with value: 5.331205001307212 and parameters: {'lambda_l1': 2.2513386740060963, 'lambda_l2': 0.6881984374733792, 'max_depth': 18, 'num_leaves': 186, 'feature_fraction': 0.4910986179197339, 'min_child_samples': 56}. Best is trial 260 with value: 5.315060318632571.
# [I 2024-10-16 21:28:24,744] Trial 482 finished with value: 5.339660869219356 and parameters: {'lambda_l1': 7.336583034478733, 'lambda_l2': 4.691815670894637, 'max_depth': 3, 'num_leaves': 146, 'feature_fraction': 0.2953926255379438, 'min_child_samples': 57}. Best is trial 260 with value: 5.315060318632571.
# [I 2024-10-16 21:28:24,972] Trial 483 finished with value: 5.35672640692839 and parameters: {'lambda_l1': 8.073958959135231, 'lambda_l2': 5.689657665449192, 'max_depth': 10, 'num_leaves': 169, 'feature_fraction': 0.8328041168396212, 'min_child_samples': 24}. Best is trial 260 with value: 5.315060318632571.
# [I 2024-10-16 21:28:25,115] Trial 484 finished with value: 5.323502791886036 and parameters: {'lambda_l1': 9.790616605466216, 'lambda_l2': 7.44273805104613, 'max_depth': 24, 'num_leaves': 193, 'feature_fraction': 0.5083632683767937, 'min_child_samples': 51}. Best is trial 260 with value: 5.315060318632571.
# [I 2024-10-16 21:28:25,237] Trial 485 finished with value: 5.339972749565865 and parameters: {'lambda_l1': 9.007609570258284, 'lambda_l2': 7.2850065789986305, 'max_depth': 15, 'num_leaves': 35, 'feature_fraction': 0.41145924385357385, 'min_child_samples': 57}. Best is trial 260 with value: 5.315060318632571.
# [I 2024-10-16 21:28:25,368] Trial 486 finished with value: 5.336083191471151 and parameters: {'lambda_l1': 6.569653377216599, 'lambda_l2': 9.020186644078656, 'max_depth': 27, 'num_leaves': 81, 'feature_fraction': 0.588346542948311, 'min_child_samples': 40}. Best is trial 260 with value: 5.315060318632571.
# [I 2024-10-16 21:28:25,507] Trial 487 finished with value: 5.346980156415677 and parameters: {'lambda_l1': 9.576998886420977, 'lambda_l2': 8.752744093733135, 'max_depth': 8, 'num_leaves': 117, 'feature_fraction': 0.25665656885666754, 'min_child_samples': 45}. Best is trial 260 with value: 5.315060318632571.
# [I 2024-10-16 21:28:25,683] Trial 488 finished with value: 5.336938458351684 and parameters: {'lambda_l1': 5.027445338815453, 'lambda_l2': 3.059791705225667, 'max_depth': 22, 'num_leaves': 69, 'feature_fraction': 0.5967215087812463, 'min_child_samples': 61}. Best is trial 260 with value: 5.315060318632571.
# [I 2024-10-16 21:28:25,831] Trial 489 finished with value: 5.332825589591298 and parameters: {'lambda_l1': 3.0939632372563852, 'lambda_l2': 1.0906602301166566, 'max_depth': 3, 'num_leaves': 217, 'feature_fraction': 0.6524311742067548, 'min_child_samples': 38}. Best is trial 260 with value: 5.315060318632571.
# [I 2024-10-16 21:28:25,970] Trial 490 finished with value: 5.342002401267493 and parameters: {'lambda_l1': 7.404909580464093, 'lambda_l2': 8.639989482382788, 'max_depth': 29, 'num_leaves': 15, 'feature_fraction': 0.3462883928657534, 'min_child_samples': 37}. Best is trial 260 with value: 5.315060318632571.
# [I 2024-10-16 21:28:26,127] Trial 491 finished with value: 5.351532739659878 and parameters: {'lambda_l1': 0.5116244245552064, 'lambda_l2': 0.0015171648399201487, 'max_depth': 22, 'num_leaves': 236, 'feature_fraction': 0.5397712792749909, 'min_child_samples': 81}. Best is trial 260 with value: 5.315060318632571.
# [I 2024-10-16 21:28:26,306] Trial 492 finished with value: 5.344375491185586 and parameters: {'lambda_l1': 6.697120428702246, 'lambda_l2': 0.01380986155665731, 'max_depth': 19, 'num_leaves': 85, 'feature_fraction': 0.1086708416329133, 'min_child_samples': 54}. Best is trial 260 with value: 5.315060318632571.
# [I 2024-10-16 21:28:26,452] Trial 493 finished with value: 5.3205648934746685 and parameters: {'lambda_l1': 8.768589048251185, 'lambda_l2': 6.4482592876937765, 'max_depth': 26, 'num_leaves': 250, 'feature_fraction': 0.5538926720508854, 'min_child_samples': 44}. Best is trial 260 with value: 5.315060318632571.
# [I 2024-10-16 21:28:26,578] Trial 494 finished with value: 5.328561404020657 and parameters: {'lambda_l1': 8.24069256531686, 'lambda_l2': 5.94891192924476, 'max_depth': 2, 'num_leaves': 193, 'feature_fraction': 0.6686100956263485, 'min_child_samples': 34}. Best is trial 260 with value: 5.315060318632571.
# [I 2024-10-16 21:28:26,732] Trial 495 finished with value: 5.320746980116244 and parameters: {'lambda_l1': 9.14123601621412, 'lambda_l2': 5.575818040010201, 'max_depth': 27, 'num_leaves': 244, 'feature_fraction': 0.5449429464385541, 'min_child_samples': 42}. Best is trial 260 with value: 5.315060318632571.
# [I 2024-10-16 21:28:26,883] Trial 496 finished with value: 5.31979029326184 and parameters: {'lambda_l1': 5.297144515618955, 'lambda_l2': 9.90785006275797, 'max_depth': 4, 'num_leaves': 124, 'feature_fraction': 0.5334632738427104, 'min_child_samples': 54}. Best is trial 260 with value: 5.315060318632571.
# [I 2024-10-16 21:28:27,054] Trial 497 finished with value: 5.33272367493532 and parameters: {'lambda_l1': 5.616298709313533, 'lambda_l2': 9.30363777734954, 'max_depth': 11, 'num_leaves': 102, 'feature_fraction': 0.680300166775003, 'min_child_samples': 47}. Best is trial 260 with value: 5.315060318632571.
# [I 2024-10-16 21:28:27,146] Trial 498 finished with value: 5.338840220099082 and parameters: {'lambda_l1': 6.909338799256835, 'lambda_l2': 4.563273706466801, 'max_depth': 4, 'num_leaves': 46, 'feature_fraction': 0.34040828765132036, 'min_child_samples': 56}. Best is trial 260 with value: 5.315060318632571.
# [I 2024-10-16 21:28:27,273] Trial 499 finished with value: 5.352934501242735 and parameters: {'lambda_l1': 6.4891916646401535, 'lambda_l2': 7.45513180636882, 'max_depth': 7, 'num_leaves': 119, 'feature_fraction': 0.06180337900902538, 'min_child_samples': 36}. Best is trial 260 with value: 5.315060318632571.
# {'lambda_l1': 7.057869865516933,
#  'lambda_l2': 2.2941431303150397,
#  'max_depth': 1,
#  'num_leaves': 168,
#  'feature_fraction': 0.482330632811827,
#  'min_child_samples': 50}

# %% [markdown]
# 5.31135809424466

# %%
params = (
    {
        'random_state': 22,
        'metric': 'mean_squared_error',
        'verbosity': -1,
        'n_estimators': 500,
        'early_stopping_round': 25,
        'monotone_constraints': monotone_contraints,
    } |
    study.best_params
)

testing_data = []
mod = LGBMRegressor(**params)
for X_train, X_val, X_test, y_train, y_val, y_test, df_mod_oos in cv_data:
    mod.fit(
        X_train, 
        y_train, 
        eval_set=(X_val, y_val),
    )
    
    testing_data.append(df_mod_oos.assign(Prediction=mod.predict(X_test)))

df_test = pd.concat(testing_data, ignore_index=True)

df_test
# Out:
#       Season  Week           Name Position Team  Fantasy Points   Rank  \
# 0       2020     5  george kittle       TE   SF             6.4   47.0
# 1       2020     5   travis kelce       TE   KC            20.8   51.0
# 2       2020     5   mark andrews       TE  BAL            14.6   69.0
# 3       2020     5  darren waller       TE   LV            13.3   75.0
# 4       2020     5   hunter henry       TE  LAC            10.3   82.0
# ...      ...   ...            ...      ...  ...             ...    ...
# 2010    2023    17   mike gesicki       TE   NE             5.5  197.0
# 2011    2023    17    josh oliver       TE  MIN             2.2  200.0
# 2012    2023    17  austin hooper       TE   LV             4.3  217.0
# 2013    2023    17  adam trautman       TE  DEN             1.4  225.0
# 2014    2023    17  tommy tremble       TE  CAR             1.1  226.0
#
#       Position Rank  Adjusted Passing Yards Projection  \
# 0                 1                                NaN
# 1                 2                                NaN
# 2                 3                                NaN
# 3                 4                                NaN
# 4                 5                                NaN
# ...             ...                                ...
# 2010             31                                NaN
# 2011             32                                NaN
# 2012             34                                NaN
# 2013             35                                NaN
# 2014             36                                NaN
#
#       Adjusted Passing Touchdowns Projection  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 2010                                     NaN
# 2011                                     NaN
# 2012                                     NaN
# 2013                                     NaN
# 2014                                     NaN
#
#       Adjusted Interceptions Projection  Adjusted Rushing Yards Projection  \
# 0                                   NaN                                NaN
# 1                                   NaN                                NaN
# 2                                   NaN                                NaN
# 3                                   NaN                                NaN
# 4                                   NaN                                NaN
# ...                                 ...                                ...
# 2010                                NaN                                NaN
# 2011                                NaN                                NaN
# 2012                                NaN                                NaN
# 2013                                NaN                                NaN
# 2014                                NaN                                NaN
#
#       Adjusted Receiving Yards Projection  Adjusted Receptions Projection  \
# 0                               71.500000                        5.436640
# 1                               70.500000                        5.543332
# 2                               52.500000                        4.467391
# 3                               59.500000                        5.563103
# 4                               53.502184                        4.480127
# ...                                   ...                             ...
# 2010                            17.505537                        2.431481
# 2011                            10.500000                             NaN
# 2012                            20.503353                        2.462766
# 2013                             5.500000                        0.600127
# 2014                            13.511851                        1.612455
#
#       Anytime Touchdown Probability  Location  Team Projected Score  \
# 0                          0.523810       1.0                 29.50
# 1                          0.591837       1.0                 32.50
# 2                          0.500000       1.0                 30.50
# 3                          0.370370      -1.0                 22.00
# 4                          0.333333      -1.0                 21.25
# ...                             ...       ...                   ...
# 2010                       0.166667      -1.0                 12.75
# 2011                       0.181818       1.0                 21.75
# 2012                       0.181818      -1.0                 19.50
# 2013                       0.200000       1.0                 21.50
# 2014                       0.166667      -1.0                 17.25
#
#       Opponent Projected Score  Prediction
# 0                        21.00   14.763971
# 1                        22.00   14.763971
# 2                        18.50   10.916986
# 3                        32.50   10.043621
# 4                        28.25    8.985430
# ...                        ...         ...
# 2010                     27.25    3.550378
# 2011                     20.75    2.720471
# 2012                     23.00    4.212596
# 2013                     18.00    3.049279
# 2014                     20.75    2.449160
#
# [2015 rows x 19 columns]

# %%
df_test['Prediction'].describe()
# Out:
# count    2015.000000
# mean        6.893965
# std         2.667347
# min         1.829594
# 25%         4.992675
# 50%         6.550866
# 75%         8.108635
# max        15.551959
# Name: Prediction, dtype: float64

# %%
(df_test['Fantasy Points'] - df_test['Prediction']).describe()
# Out:
# count    2015.000000
# mean       -0.008704
# std         5.316373
# min       -14.883174
# 25%        -3.645726
# 50%        -1.031969
# 75%         2.609783
# max        26.682180
# dtype: float64

# %%
(df_test['Fantasy Points'] - df_test['Prediction']).abs().describe()
# Out:
# count    2015.000000
# mean        4.055521
# std         3.436346
# min         0.000569
# 25%         1.722920
# 50%         3.289505
# 75%         5.326132
# max        26.682180
# dtype: float64

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(df_test['Fantasy Points'], df_test['Prediction'], squared=False)
# Out:
# 5.315060318632571

# %%
from sklearn.metrics import mean_absolute_error

mean_absolute_error(df_test['Fantasy Points'], df_test['Prediction'])
# Out:
# 4.055521276417016

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6, 6), dpi=100)

ax = sns.regplot(
    data=df_test,
    x='Prediction',
    y='Fantasy Points',
    scatter_kws={'alpha': 0.10, 'color': sns.color_palette()[1]},
    line_kws={'color': sns.color_palette()[0]},
)

plt.title('Actual Fantasy Points vs. Predicted Fantasy Points')
plt.xlabel('Predicted Fantasy Points Scored')
plt.ylabel('Actual Fantasy Points Scored')

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6, 6), dpi=100)

ax = sns.regplot(
    data=df_test.assign(f=(df_test['Fantasy Points'] - df_test['Prediction'])),
    x='Prediction',
    y='f',
    scatter_kws={'alpha': 0.10, 'color': sns.color_palette()[0]},
    line_kws={'color': sns.color_palette()[3]},
)

plt.title('Residual Plot')
plt.xlabel('Predicted Fantasy Points Scored')
plt.ylabel('Actual Minus Predicted')

plt.show()

# %%
import shap

explainer = shap.Explainer(mod, feature_names=X_train.columns, seed=22)

shap_values = explainer(pd.concat([i[0] for i in cv_data], ignore_index=True))

shap_values.shape
# Out:
# (3398, 6)

# %%
shap.plots.beeswarm(shap_values, max_display=None)
