# %%
import pandas as pd

pd.set_option('display.max_columns', 100)

df_mod = pd.read_parquet('../../../data/model_data/model_data_single_output.parquet')

df_mod = df_mod.loc[df_mod['Position'] == 'TE', :].reset_index(drop=True)

df_mod
# Out:
#       Season  Week           Name Position Team  Fantasy Points   Rank  \
# 0       2020     1  george kittle       TE   SF             7.3   43.0
# 1       2020     1   travis kelce       TE   KC            14.0   48.0
# 2       2020     1   mark andrews       TE  BAL            20.3   70.0
# 3       2020     1      zach ertz       TE  PHI             9.3   76.0
# 4       2020     1  darren waller       TE   LV             7.5   87.0
# ...      ...   ...            ...      ...  ...             ...    ...
# 2010    2023    17   mike gesicki       TE   NE             5.5  197.0
# 2011    2023    17    josh oliver       TE  MIN             2.2  200.0
# 2012    2023    17  austin hooper       TE   LV             4.3  217.0
# 2013    2023    17  adam trautman       TE  DEN             1.4  225.0
# 2014    2023    17  tommy tremble       TE  CAR             1.1  226.0
#
#       Position Rank  Adjusted Passing Yards Projection  \
# 0                 1                                NaN
# 1                 2                                NaN
# 2                 3                                NaN
# 3                 4                                NaN
# 4                 5                                NaN
# ...             ...                                ...
# 2010             31                                NaN
# 2011             32                                NaN
# 2012             34                                NaN
# 2013             35                                NaN
# 2014             36                                NaN
#
#       Adjusted Passing Touchdowns Projection  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 2010                                     NaN
# 2011                                     NaN
# 2012                                     NaN
# 2013                                     NaN
# 2014                                     NaN
#
#       Adjusted Interceptions Projection  Adjusted Rushing Yards Projection  \
# 0                                   NaN                                NaN
# 1                                   NaN                                NaN
# 2                                   NaN                                NaN
# 3                                   NaN                                NaN
# 4                                   NaN                                NaN
# ...                                 ...                                ...
# 2010                                NaN                                NaN
# 2011                                NaN                                NaN
# 2012                                NaN                                NaN
# 2013                                NaN                                NaN
# 2014                                NaN                                NaN
#
#       Adjusted Receiving Yards Projection  Adjusted Receptions Projection  \
# 0                               71.500000                        6.464916
# 1                               69.524775                        5.557539
# 2                               48.500000                        4.436640
# 3                               54.500000                        5.458984
# 4                               52.500000                        4.544513
# ...                                   ...                             ...
# 2010                            17.505537                        2.431481
# 2011                            10.500000                             NaN
# 2012                            20.503353                        2.462766
# 2013                             5.500000                        0.600127
# 2014                            13.511851                        1.612455
#
#       Anytime Touchdown Probability  Location  Team Projected Score  \
# 0                          0.500000       1.0                 26.75
# 1                          0.545455       1.0                 31.50
# 2                          0.420168       1.0                 27.25
# 3                          0.380228      -1.0                 22.00
# 4                          0.420168      -1.0                 25.50
# ...                             ...       ...                   ...
# 2010                       0.166667      -1.0                 12.75
# 2011                       0.181818       1.0                 21.75
# 2012                       0.181818      -1.0                 19.50
# 2013                       0.200000       1.0                 21.50
# 2014                       0.166667      -1.0                 17.25
#
#       Opponent Projected Score
# 0                        20.25
# 1                        22.00
# 2                        20.25
# 3                        16.50
# 4                        22.50
# ...                        ...
# 2010                     27.25
# 2011                     20.75
# 2012                     23.00
# 2013                     18.00
# 2014                     20.75
#
# [2015 rows x 18 columns]

# %%
X = df_mod[[
    'Rank',
    'Position Rank',
    'Location',
    'Team Projected Score',
    'Opponent Projected Score',
    'Adjusted Receptions Projection',
    'Adjusted Receiving Yards Projection',
    'Anytime Touchdown Probability',
]].copy()

X
# Out:
#        Rank  Position Rank  Location  Team Projected Score  \
# 0      43.0              1       1.0                 26.75
# 1      48.0              2       1.0                 31.50
# 2      70.0              3       1.0                 27.25
# 3      76.0              4      -1.0                 22.00
# 4      87.0              5      -1.0                 25.50
# ...     ...            ...       ...                   ...
# 2010  197.0             31      -1.0                 12.75
# 2011  200.0             32       1.0                 21.75
# 2012  217.0             34      -1.0                 19.50
# 2013  225.0             35       1.0                 21.50
# 2014  226.0             36      -1.0                 17.25
#
#       Opponent Projected Score  Adjusted Receptions Projection  \
# 0                        20.25                        6.464916
# 1                        22.00                        5.557539
# 2                        20.25                        4.436640
# 3                        16.50                        5.458984
# 4                        22.50                        4.544513
# ...                        ...                             ...
# 2010                     27.25                        2.431481
# 2011                     20.75                             NaN
# 2012                     23.00                        2.462766
# 2013                     18.00                        0.600127
# 2014                     20.75                        1.612455
#
#       Adjusted Receiving Yards Projection  Anytime Touchdown Probability
# 0                               71.500000                       0.500000
# 1                               69.524775                       0.545455
# 2                               48.500000                       0.420168
# 3                               54.500000                       0.380228
# 4                               52.500000                       0.420168
# ...                                   ...                            ...
# 2010                            17.505537                       0.166667
# 2011                            10.500000                       0.181818
# 2012                            20.503353                       0.181818
# 2013                             5.500000                       0.200000
# 2014                            13.511851                       0.166667
#
# [2015 rows x 8 columns]

# %%
y = df_mod['Fantasy Points'].copy()

y
# Out:
# 0        7.3
# 1       14.0
# 2       20.3
# 3        9.3
# 4        7.5
#         ...
# 2010     5.5
# 2011     2.2
# 2012     4.3
# 2013     1.4
# 2014     1.1
# Name: Fantasy Points, Length: 2015, dtype: float64

# %%
groups = df_mod['Season'].astype(str) + ' Week ' + df_mod['Week'].astype(str)

groups
# Out:
# 0        2020 Week 1
# 1        2020 Week 1
# 2        2020 Week 1
# 3        2020 Week 1
# 4        2020 Week 1
#             ...
# 2010    2023 Week 17
# 2011    2023 Week 17
# 2012    2023 Week 17
# 2013    2023 Week 17
# 2014    2023 Week 17
# Length: 2015, dtype: object

# %%
df_folds = pd.read_parquet('../../../data/model_data/folds.parquet')

df_folds
# Out:
#     Fold ID   Season Week
# 0         0   2022 Week 3
# 1         0   2021 Week 7
# 2         0   2021 Week 1
# 3         0  2023 Week 16
# 4         0  2021 Week 11
# ..      ...           ...
# 62        2  2020 Week 15
# 63        2  2023 Week 14
# 64        2   2021 Week 5
# 65        2   2022 Week 6
# 66        2  2022 Week 12
#
# [67 rows x 2 columns]

# %%
from sklearn.model_selection import GroupShuffleSplit
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

pd.options.mode.chained_assignment = None

# splitter = GroupKFold(n_splits=3)

cv_data = []
oos_prop_bets_data = []
# for is_indexes, oos_indexes in splitter.split(X=X, y=y, groups=groups):
for fold in df_folds['Fold ID'].unique():
    oos_season_week = df_folds.loc[df_folds['Fold ID'] == fold, 'Season Week']
    is_indexes = df_mod.loc[~groups.isin(oos_season_week), :].index
    oos_indexes = df_mod.loc[groups.isin(oos_season_week), :].index
    # split
    X_is = X.iloc[is_indexes]
    X_oos = X.iloc[oos_indexes]

    y_is = y.iloc[is_indexes]
    y_oos = y.iloc[oos_indexes]

    groups_is = groups.iloc[is_indexes]
    df_mod_oos = df_mod.iloc[oos_indexes]

    gss = GroupShuffleSplit(n_splits=1, test_size=0.15, random_state=22)
    for train_indexes, val_indexes in gss.split(X=X_is, y=y_is, groups=groups_is):
            X_train = X_is.iloc[train_indexes]
            X_val = X_is.iloc[val_indexes]

            y_train = y_is.iloc[train_indexes]
            y_val = y_is.iloc[val_indexes]

    # impute
    scaler = StandardScaler()
    imputer = IterativeImputer(initial_strategy='median', max_iter=100)

    X_train_fill_na = imputer.fit_transform(scaler.fit_transform(X_train))
    X_train[X_train.columns] = scaler.inverse_transform(X_train_fill_na).copy()
    X_train['Prop Bets Projection'] = (
        X_train['Adjusted Receiving Yards Projection']*0.1 + 
        X_train['Adjusted Receptions Projection']*0.5 + 
        X_train['Anytime Touchdown Probability']*6
    )

    scaler2 = MinMaxScaler(clip=True)  # maybe normalize and clip instead of standardize?
    scaler3 = StandardScaler()
    X_train[X_train.columns] = scaler3.fit_transform(scaler2.fit_transform(X_train)).copy()

    X_val_fill_na = imputer.transform(scaler.transform(X_val))
    X_val[X_val.columns] = scaler.inverse_transform(X_val_fill_na).copy()
    X_val['Prop Bets Projection'] = (
        X_val['Adjusted Receiving Yards Projection']*0.1 + 
        X_val['Adjusted Receptions Projection']*0.5 + 
        X_val['Anytime Touchdown Probability']*6
    )

    X_val[X_val.columns] = scaler3.transform(scaler2.transform(X_val)).copy()

    X_oos_fill_na = imputer.transform(scaler.transform(X_oos))
    X_oos[X_oos.columns] = scaler.inverse_transform(X_oos_fill_na).copy()
    X_oos['Prop Bets Projection'] = (
        X_oos['Adjusted Receiving Yards Projection']*0.1 + 
        X_oos['Adjusted Receptions Projection']*0.5 + 
        X_oos['Anytime Touchdown Probability']*6
    )

    oos_prop_bets_data.append(X_oos.assign(f=y_oos).rename(columns={'f': 'Fantasy Points'}))

    X_oos[X_oos.columns] = scaler3.transform(scaler2.transform(X_oos)).copy()

    X_train.drop(columns=['Adjusted Receiving Yards Projection', 'Adjusted Receptions Projection', 'Anytime Touchdown Probability'], inplace=True)
    X_val.drop(columns=['Adjusted Receiving Yards Projection', 'Adjusted Receptions Projection', 'Anytime Touchdown Probability'], inplace=True)
    X_oos.drop(columns=['Adjusted Receiving Yards Projection', 'Adjusted Receptions Projection', 'Anytime Touchdown Probability'], inplace=True)

    cv_data.append((X_train, X_val, X_oos, y_train, y_val, y_oos, df_mod_oos))

for X_train, X_val, X_oos, y_train, y_val, y_oos, df_mod_oos in cv_data:
    print(X_train.shape, X_val.shape, X_oos.shape, y_train.shape, y_val.shape, y_oos.shape, df_mod_oos.shape)
# Out:
# (1105, 6) (216, 6) (694, 6) (1105,) (216,) (694,) (694, 18)
# (1156, 6) (212, 6) (647, 6) (1156,) (212,) (647,) (647, 18)
# (1137, 6) (204, 6) (674, 6) (1137,) (204,) (674,) (674, 18)

# %%
pd.concat(
    oos_prop_bets_data,
    ignore_index=True,
).to_parquet('../../../data/out_of_sample_prop_bets_projections/te.parquet')

print('Done')
# Out:
# Done

# %%
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.regularizers import L1L2
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.initializers import GlorotNormal
from tensorflow.config.experimental import enable_op_determinism
from tensorflow.random import set_seed
import numpy as np
import os

os.environ["TF_ENABLE_ONEDNN_OPTS"] = "0"

def build_and_compile_model(input_shape: tuple, hidden_layer_neurons: list, l1s: list, l2s: list, learning_rate: float):
    enable_op_determinism()
    set_seed(22)
    
    inputs = Input(shape=input_shape, name='input')

    h = inputs
    for i, neurons in enumerate(hidden_layer_neurons):
        h = Dense(
            neurons, 
            activation='relu', 
            kernel_initializer=GlorotNormal(seed=22), 
            kernel_regularizer=L1L2(l1=l1s[i], l2=l2s[i]), 
            name=f"hidden_{i+1}"
        )(h)

    outputs = Dense(1, activation=None, kernel_initializer=GlorotNormal(seed=22), name='outputs')(h)

    mod = Model(inputs=inputs, outputs=outputs)

    mod.compile(optimizer=Adam(learning_rate=learning_rate), loss='mean_squared_error', metrics=['mean_absolute_error'])

    return mod

mod = build_and_compile_model(X.shape[1:], [128, 32], [0, 0.01], [0, 0.01], learning_rate=0.001)

mod.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 8)]               0
#
#  hidden_1 (Dense)            (None, 128)               1152
#
#  hidden_2 (Dense)            (None, 32)                4128
#
#  outputs (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,313
# Trainable params: 5,313
# Non-trainable params: 0
# _________________________________________________________________

# %%
from sklearn.metrics import root_mean_squared_error
import optuna

def objective(trial, cv_data=cv_data):
# model tuning
    n_hidden_layers = trial.suggest_int(f"n_hidden_layers", 1, 3)

    hidden_layer_neurons = []
    l1s = []
    l2s = []
    for i in range(n_hidden_layers):
        hidden_layer_neurons.append(trial.suggest_categorical(f"hidden_layer_{i+1}_neurons", [2**n for n in range(5, 12)]))  # change to (3, 12)
        # hidden_layer_neurons.append(trial.suggest_categorical(f"hidden_layer_{i+1}_neurons", [2**n for n in range(4, 9)]))  # bump this up
        l1s.append(trial.suggest_float(f"hidden_layer_{i+1}_l1", 0.0, 0.1))  # change to (0.0, 0.05)
        l2s.append(trial.suggest_float(f"hidden_layer_{i+1}_l2", 0.0, 0.1))  # change to (0.0, 0.20)

    learning_rate = trial.suggest_float(f"learning_rate", 0.01, 0.10)
    batch_size = trial.suggest_categorical(f"batch_size", [2**n for n in range(10, 16)])
    # batch_size = trial.suggest_categorical(f"batch_size", [2**n for n in range(4, 12)])  # bump this up

    # cross validation
    y_oos_list = []
    y_pred_list = []
    for X_train, X_val, X_oos, y_train, y_val, y_oos, df_mod_oos in cv_data:
        # make sure to build mod in loop to prevent history
        mod = build_and_compile_model(X_train.shape[1:], hidden_layer_neurons, l1s, l2s, learning_rate)

        mod.fit(
            X_train,
            y_train,
            validation_data=(X_val, y_val),
            batch_size=batch_size,
            epochs=500,
            callbacks=[EarlyStopping(patience=10, restore_best_weights=True)],
            verbose=0,
        )

        y_oos_list.append(y_oos)
        y_pred_list.append(mod.predict(X_oos, verbose=0))

    y_oos_concat = np.concatenate(y_oos_list)
    y_pred_concat = np.concatenate(y_pred_list)

    return root_mean_squared_error(y_oos_concat, y_pred_concat)

study = optuna.create_study(direction='minimize', sampler=optuna.samplers.TPESampler(seed=22, n_startup_trials=10, multivariate=True, warn_independent_sampling=False))
study.optimize(objective, n_trials=20, show_progress_bar=True)

study.best_params
# Out:
# c:\Users\mhugh\anaconda3\envs\clean2\lib\site-packages\optuna\_experimental.py:30: ExperimentalWarning: Argument ``multivariate`` is an experimental feature. The interface can change in the future.
#   warnings.warn(
# [I 2024-10-23 17:37:50,479] A new study created in memory with name: no-name-608e2dc3-b594-45a2-a731-8544263d1ced
#   0%|          | 0/20 [00:00<?, ?it/s]
# [I 2024-10-23 17:38:18,056] Trial 0 finished with value: 5.456107211502288 and parameters: {'n_hidden_layers': 1, 'hidden_layer_1_neurons': 128, 'hidden_layer_1_l1': 0.022040451663772567, 'hidden_layer_1_l2': 0.08119509205386867, 'learning_rate': 0.01094741868844976, 'batch_size': 2048}. Best is trial 0 with value: 5.456107211502288.
# [I 2024-10-23 17:38:24,028] Trial 1 finished with value: 7.928878395859585 and parameters: {'n_hidden_layers': 3, 'hidden_layer_1_neurons': 128, 'hidden_layer_1_l1': 0.058428964315689495, 'hidden_layer_1_l2': 0.07026355188654519, 'hidden_layer_2_neurons': 128, 'hidden_layer_2_l1': 0.08749277452777171, 'hidden_layer_2_l2': 0.07449320773686179, 'hidden_layer_3_neurons': 256, 'hidden_layer_3_l1': 0.009588460991804116, 'hidden_layer_3_l2': 0.004521011190769353, 'learning_rate': 0.07163458468004151, 'batch_size': 1024}. Best is trial 0 with value: 5.456107211502288.
# [I 2024-10-23 17:38:30,073] Trial 2 finished with value: 6.153773620917815 and parameters: {'n_hidden_layers': 2, 'hidden_layer_1_neurons': 64, 'hidden_layer_1_l1': 0
and parameters: {'n_hidden_layers': 1, 'hidden_layer_1_neurons': 512, 'hidden_layer_1_l1': 0.08347776026066128, 'hidden_layer_1_l2': 0.040264701983810186, 'learning_rate': 0.08823991886921408, 'batch_size': 4096}. Best is trial 12 with value: 5.328074247711247.
# [I 2024-10-23 17:41:33,190] Trial 16 finished with value: 5.337245840056542 and parameters: {'n_hidden_layers': 1, 'hidden_layer_1_neurons': 1024, 'hidden_layer_1_l1': 0.0792974943032458, 'hidden_layer_1_l2': 0.03947639214524411, 'learning_rate': 0.08768251559103381, 'batch_size': 8192}. Best is trial 12 with value: 5.328074247711247.
# [I 2024-10-23 17:41:38,795] Trial 17 finished with value: 6.6926071980712685 and parameters: {'n_hidden_layers': 1, 'hidden_layer_1_neurons': 2048, 'hidden_layer_1_l1': 0.054651698158032155, 'hidden_layer_1_l2': 0.06028806474489818, 'learning_rate': 0.09650369780785434, 'batch_size': 2048}. Best is trial 12 with value: 5.328074247711247.
# [I 2024-10-23 17:41:54,782] Trial 18 finished with value: 5.34369205082558 and parameters: {'n_hidden_layers': 1, 'hidden_layer_1_neurons': 1024, 'hidden_layer_1_l1': 0.09602741574839324, 'hidden_layer_1_l2': 0.06103642557190037, 'learning_rate': 0.08061058045927096, 'batch_size': 2048}. Best is trial 12 with value: 5.328074247711247.
# [I 2024-10-23 17:42:01,845] Trial 19 finished with value: 10.038934906643743 and parameters: {'n_hidden_layers': 2, 'hidden_layer_1_neurons': 1024, 'hidden_layer_1_l1': 0.05311519903995583, 'hidden_layer_1_l2': 0.06190172728897987, 'hidden_layer_2_neurons': 1024, 'hidden_layer_2_l1': 0.056942852907992794, 'hidden_layer_2_l2': 0.0003962149262468212, 'learning_rate': 0.0928840163820159, 'batch_size': 4096}. Best is trial 12 with value: 5.328074247711247.
# {'n_hidden_layers': 1,
#  'hidden_layer_1_neurons': 1024,
#  'hidden_layer_1_l1': 0.09854015086676172,
#  'hidden_layer_1_l2': 0.05925903198396197,
#  'learning_rate': 0.09725948301499815,
#  'batch_size': 4096}

# %% [markdown]
# 5.328074247711247

# %%
n_hidden_layers = study.best_params['n_hidden_layers']

hidden_layer_neurons = []
l1s = []
l2s = []
for i in range(n_hidden_layers):
    hidden_layer_neurons.append(study.best_params[f"hidden_layer_{i+1}_neurons"])
    l1s.append(study.best_params[f"hidden_layer_{i+1}_l1"])
    l2s.append(study.best_params[f"hidden_layer_{i+1}_l2"])

learning_rate = study.best_params[f"learning_rate"]
batch_size = study.best_params[f"batch_size"]

y_oos_list = []
y_pred_list = []
testing_data = []
for X_train, X_val, X_oos, y_train, y_val, y_oos, df_mod_oos in cv_data:
    # make sure to build mod in loop to prevent history
    mod = build_and_compile_model(X_train.shape[1:], hidden_layer_neurons, l1s, l2s, learning_rate)

    mod.fit(
        X_train,
        y_train,
        validation_data=(X_val, y_val),
        batch_size=batch_size,
        epochs=500,
        callbacks=[EarlyStopping(patience=10, restore_best_weights=True)],
        verbose=1,
    )

    y_preds = mod.predict(X_oos, verbose=0)

    df_preds = pd.DataFrame(
        y_preds,
        columns=['Prediction']
    )

    testing_data.append(pd.concat((df_mod_oos.reset_index(drop=True), df_preds), axis=1))


    y_oos_list.append(y_oos)
    y_pred_list.append(y_preds)

df_test = pd.concat(testing_data, ignore_index=True)

y_oos_concat = np.concatenate(y_oos_list)
y_pred_concat = np.concatenate(y_pred_list)

print(f"OOS RMSE: {root_mean_squared_error(y_oos_concat, y_pred_concat)}")
# Out:
# Epoch 1/500
# 1/1 [==============================] - 1s
500
# 1/1 [==============================] - 0s 53ms/step - loss: 32.9984 - mean_absolute_error: 3.8743 - val_loss: 33.0671 - val_mean_absolute_error: 3.8610
# Epoch 60/500
# 1/1 [==============================] - 0s 52ms/step - loss: 32.9543 - mean_absolute_error: 3.8769 - val_loss: 33.2447 - val_mean_absolute_error: 3.8741
# Epoch 61/500
# 1/1 [==============================] - 0s 53ms/step - loss: 33.0613 - mean_absolute_error: 3.8778 - val_loss: 33.2580 - val_mean_absolute_error: 3.8798
# Epoch 62/500
# 1/1 [==============================] - 0s 54ms/step - loss: 33.0482 - mean_absolute_error: 3.8760 - val_loss: 32.9449 - val_mean_absolute_error: 3.8696
# Epoch 63/500
# 1/1 [==============================] - 0s 55ms/step - loss: 32.8111 - mean_absolute_error: 3.8752 - val_loss: 32.9309 - val_mean_absolute_error: 3.8783
# Epoch 64/500
# 1/1 [==============================] - 0s 54ms/step - loss: 32.7506 - mean_absolute_error: 3.8772 - val_loss: 33.0747 - val_mean_absolute_error: 3.8740
# Epoch 65/500
# 1/1 [==============================] - 0s 53ms/step - loss: 32.8636 - mean_absolute_error: 3.8781 - val_loss: 33.0758 - val_mean_absolute_error: 3.8675
# Epoch 66/500
# 1/1 [==============================] - 0s 53ms/step - loss: 32.8846 - mean_absolute_error: 3.8726 - val_loss: 33.0823 - val_mean_absolute_error: 3.8740
# Epoch 67/500
# 1/1 [==============================] - 0s 52ms/step - loss: 32.8810 - mean_absolute_error: 3.8695 - val_loss: 32.9660 - val_mean_absolute_error: 3.8744
# Epoch 68/500
# 1/1 [==============================] - 0s 54ms/step - loss: 32.7411 - mean_absolute_error: 3.8752 - val_loss: 32.8788 - val_mean_absolute_error: 3.8769
# Epoch 69/500
# 1/1 [==============================] - 0s 54ms/step - loss: 32.6580 - mean_absolute_error: 3.8782 - val_loss: 32.9879 - val_mean_absolute_error: 3.8648
# Epoch 70/500
# 1/1 [==============================] - 0s 52ms/step - loss: 32.8146 - mean_absolute_error: 3.8755 - val_loss: 33.1339 - val_mean_absolute_error: 3.8729
# Epoch 71/500
# 1/1 [==============================] - 0s 53ms/step - loss: 32.9004 - mean_absolute_error: 3.8719 - val_loss: 32.9799 - val_mean_absolute_error: 3.8677
# Epoch 72/500
# 1/1 [==============================] - 0s 56ms/step - loss: 32.7746 - mean_absolute_error: 3.8734 - val_loss: 32.8760 - val_mean_absolute_error: 3.8749
# Epoch 73/500
# 1/1 [==============================] - 0s 53ms/step - loss: 32.7166 - mean_absolute_error: 3.8756 - val_loss: 32.8882 - val_mean_absolute_error: 3.8696
# Epoch 74/500
# 1/1 [==============================] - 0s 53ms/step - loss: 32.7412 - mean_absolute_error: 3.8780 - val_loss: 32.9650 - val_mean_absolute_error: 3.8586
# Epoch 75/500
# 1/1 [==============================] - 0s 54ms/step - loss: 32.8116 - mean_absolute_error: 3.8767 - val_loss: 33.0141 - val_mean_absolute_error: 3.8770
# Epoch 76/500
# 1/1 [==============================] - 0s 53ms/step - loss: 32.8340 - mean_absolute_error: 3.8710 - val_loss: 32.8959 - val_mean_absolute_error: 3.8450
# Epoch 77/500
# 1/1 [==============================] - 0s 53ms/step - loss: 32.8186 - mean_absolute_error: 3.8736 - val_loss: 32.9950 - val_mean_absolute_error: 3.8878
# Epoch 78/500
# 1/1 [==============================] - 0s 54ms/step - loss: 32.7397 - mean_absolute_error: 3.8742 - val_loss: 32.7398 - val_mean_absolute_error: 3.8315
# Epoch 79/500
# 1/1 [==============================] - 0s 88ms/step - loss: 32.7290 - mean_absolute_error: 3.8764 - val_loss: 33.1063 - val_mean_absolute_error: 3.9150
# Epoch 80/500
# 1/1 [==============================] - 0s 55ms/step - loss: 32.8110 - mean_absolute_error: 3.8776 - val_loss: 32.8830 - val_mean_absolute_error: 3.8037
# Epoch 81/500
# 1/1 [==============================] - 0s 52ms/step - loss: 32.9991 - mean_absolute_error: 3.8897 - val_loss: 33.8678 - val_mean_absolute_error: 3.9917
# Epoch 82/500
# 1/1 [==============================] - 0s 52ms/step - loss: 33.3149 - mean_absolute_error: 3.8961 - val_loss: 33.0626 - val_mean_absolute_error: 3.7809
# Epoch 83/500
# 1/1 [==============================] - 0s 54ms/step - loss: 33.3989 - mean_absolute_error: 3.9038 - val_loss: 33.5642 - val_mean_absolute_error: 3.9698
# Epoch 84/500
# 1/1 [==============================] - 0s 51ms/step - loss: 33.0165 - mean_absolute_error: 3.8912 - val_loss: 32.9370 - val_mean_absolute_error: 3.8464
# Epoch 85/500
# 1/1 [==============================] - 0s 52ms/step - loss: 32.8282 - mean_absolute_error: 3.8697 - val_loss: 32.8711 - val_mean_absolute_error: 3.8128
# Epoch 86/500
# 1/1 [==============================] - 0s 54ms/step - loss: 32.9800 - mean_absolute_error: 3.8808 - val_loss: 33.5714 - val_mean_absolute_error: 3.9669
# Epoch 87/500
# 1/1 [==============================] - 0s 54ms/step - loss: 33.0761 - mean_absolute_error: 3.8923 - val_loss: 32.7468 - val_mean_absolute_error: 3.8035
# Epoch 88/500
# 1/1 [==============================] - 0s 60ms/step - loss: 32.8393 - mean_absolute_error: 3.8785 - val_loss: 32.9077 - val_mean_absolute_error: 3.8569
# OOS RMSE: 5.328074247711247

# %%
df_test['Prediction'].describe()
# Out:
# count    2015.000000
# mean        6.903924
# std         2.549412
# min         2.335882
# 25%         5.064640
# 50%         6.346693
# 75%         8.355422
# max        15.804095
# Name: Prediction, dtype: float64

# %%
(df_test['Fantasy Points'] - df_test['Prediction']).describe()
# Out:
# count    2015.000000
# mean       -0.018664
# std         5.329364
# min       -13.470719
# 25%        -3.697262
# 50%        -1.072354
# 75%         2.619243
# max        27.127361
# dtype: float64

# %%
(df_test['Fantasy Points'] - df_test['Prediction']).abs().describe()
# Out:
# count    2015.000000
# mean        4.047328
# std         3.466046
# min         0.003707
# 25%         1.708434
# 50%         3.324446
# 75%         5.332429
# max        27.127361
# dtype: float64

# %%
from sklearn.metrics import root_mean_squared_error

root_mean_squared_error(df_test['Fantasy Points'], df_test['Prediction'])
# Out:
# 5.328074247711247

# %%
from sklearn.metrics import mean_absolute_error

mean_absolute_error(df_test['Fantasy Points'], df_test['Prediction'])
# Out:
# 4.047328192377209

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6, 6), dpi=100)

ax = sns.regplot(
    data=df_test,
    x='Prediction',
    y='Fantasy Points',
    scatter_kws={'alpha': 0.10, 'color': sns.color_palette()[1]},
    line_kws={'color': sns.color_palette()[0]},
)

plt.title('Actual Fantasy Points vs. Predicted Fantasy Points')
plt.xlabel('Predicted Fantasy Points Scored')
plt.ylabel('Actual Fantasy Points Scored')

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6, 6), dpi=100)

ax = sns.regplot(
    data=df_test.assign(f=(df_test['Fantasy Points'] - df_test['Prediction'])),
    x='Prediction',
    y='f',
    scatter_kws={'alpha': 0.10, 'color': sns.color_palette()[0]},
    line_kws={'color': sns.color_palette()[3]},
)

plt.title('Residual Plot')
plt.xlabel('Predicted Fantasy Points Scored')
plt.ylabel('Actual Minus Predicted')

plt.show()

# %%
import shap

explainer = shap.DeepExplainer(mod, X_train.to_numpy())

shap_values = explainer(X_train.to_numpy())

shap_values.feature_names = X_train.columns

shap_values.shape
# Out:
# c:\Users\mhugh\anaconda3\envs\clean2\lib\site-packages\shap\explainers\_deep\deep_tf.py:99: UserWarning: Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
#   warnings.warn("Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.")
# c:\Users\mhugh\anaconda3\envs\clean2\lib\site-packages\keras\backend.py:451: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# (1137, 6, 1)

# %%
shap.plots.beeswarm(shap_values[:, :, 0], max_display=None)

# %% [markdown]
# ### Save Predictions

# %%
df_test.to_parquet('../../../data/out_of_sample_predictions/te.parquet')

print('Done')
# Out:
# Done
