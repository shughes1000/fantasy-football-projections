# %%
import pandas as pd

pd.set_option('display.max_columns', 100)

df_mod = pd.read_parquet('../../../data/model_data/model_data_single_output.parquet')

df_mod = df_mod.loc[df_mod['Position'] == 'QB', :].reset_index(drop=True)

df_mod
# Out:
#       Season  Week             Name Position Team  Fantasy Points  Rank  \
# 0       2020     1  patrick mahomes       QB   KC            20.4   1.0
# 1       2020     1    lamar jackson       QB  BAL            27.5   2.0
# 2       2020     1     dak prescott       QB  DAL            17.6   4.0
# 3       2020     1   russell wilson       QB  SEA            31.8   5.0
# 4       2020     1   deshaun watson       QB  HOU            20.8   6.0
# ...      ...   ...              ...      ...  ...             ...   ...
# 2000    2023    17  taylor heinicke       QB  ATL            15.1  52.0
# 2001    2023    17      cj beathard       QB  JAX             9.5  54.0
# 2002    2023    17       sam howell       QB  WAS             6.7  59.0
# 2003    2023    17     bailey zappe       QB   NE            12.1  71.0
# 2004    2023    17   trevor siemian       QB  NYJ            13.7  94.0
#
#       Position Rank  Adjusted Passing Yards Projection  \
# 0                 1                         306.500000
# 1                 2                         222.500000
# 2                 3                         285.500000
# 3                 4                         259.500000
# 4                 5                         275.500000
# ...             ...                                ...
# 2000             28                         203.494463
# 2001             29                         214.495591
# 2002             30                         234.500000
# 2003             31                         195.500000
# 2004             32                         177.494463
#
#       Adjusted Passing Touchdowns Projection  \
# 0                                   2.460615
# 1                                   1.528860
# 2                                   2.495487
# 3                                   1.564394
# 4                                   1.574315
# ...                                      ...
# 2000                                1.304627
# 2001                                1.351543
# 2002                                1.394584
# 2003                                0.615610
# 2004                                0.500000
#
#       Adjusted Interceptions Projection  Adjusted Rushing Yards Projection  \
# 0                                   NaN                          20.488656
# 1                                   NaN                          60.500000
# 2                                   NaN                          11.517041
# 3                                   NaN                          21.500000
# 4                                   NaN                          30.512870
# ...                                 ...                                ...
# 2000                           0.510823                          10.504409
# 2001                           0.567442                          10.500000
# 2002                           0.639448                          12.501128
# 2003                           0.616228                           5.489177
# 2004                                NaN                           7.481323
#
#       Adjusted Receiving Yards Projection  Adjusted Receptions Projection  \
# 0                                     NaN                             NaN
# 1                                     NaN                             NaN
# 2                                     NaN                             NaN
# 3                                     NaN                             NaN
# 4                                     NaN                             NaN
# ...                                   ...                             ...
# 2000                                  NaN                             NaN
# 2001                                  NaN                             NaN
# 2002                                  NaN                             NaN
# 2003                                  NaN                             NaN
# 2004                                  NaN                             NaN
#
#       Anytime Touchdown Probability  Location  Team Projected Score  \
# 0                          0.250000       1.0                 31.50
# 1                          0.476190       1.0                 27.25
# 2                          0.230947      -1.0                 25.50
# 3                          0.200000      -1.0                   NaN
# 4                          0.344828      -1.0                 22.00
# ...                             ...       ...                   ...
# 2000                       0.153846      -1.0                 18.25
# 2001                       0.133333       1.0                 20.75
# 2002                       0.153846       1.0                 17.25
# 2003                       0.058824      -1.0                 12.75
# 2004                            NaN      -1.0                 13.25
#
#       Opponent Projected Score
# 0                        22.00
# 1                        20.25
# 2                        26.50
# 3                          NaN
# 4                        31.50
# ...                        ...
# 2000                     20.75
# 2001                     17.25
# 2002                     31.25
# 2003                     27.25
# 2004                     20.25
#
# [2005 rows x 18 columns]

# %%
X = df_mod[[
    'Rank',
    'Position Rank',
    'Location',
    'Team Projected Score',
    'Opponent Projected Score',
    'Adjusted Passing Yards Projection',
    'Adjusted Passing Touchdowns Projection',
    'Adjusted Interceptions Projection',
    'Adjusted Rushing Yards Projection',
    'Anytime Touchdown Probability',
]].copy()

X
# Out:
#       Rank  Position Rank  Location  Team Projected Score  \
# 0      1.0              1       1.0                 31.50
# 1      2.0              2       1.0                 27.25
# 2      4.0              3      -1.0                 25.50
# 3      5.0              4      -1.0                   NaN
# 4      6.0              5      -1.0                 22.00
# ...    ...            ...       ...                   ...
# 2000  52.0             28      -1.0                 18.25
# 2001  54.0             29       1.0                 20.75
# 2002  59.0             30       1.0                 17.25
# 2003  71.0             31      -1.0                 12.75
# 2004  94.0             32      -1.0                 13.25
#
#       Opponent Projected Score  Adjusted Passing Yards Projection  \
# 0                        22.00                         306.500000
# 1                        20.25                         222.500000
# 2                        26.50                         285.500000
# 3                          NaN                         259.500000
# 4                        31.50                         275.500000
# ...                        ...                                ...
# 2000                     20.75                         203.494463
# 2001                     17.25                         214.495591
# 2002                     31.25                         234.500000
# 2003                     27.25                         195.500000
# 2004                     20.25                         177.494463
#
#       Adjusted Passing Touchdowns Projection  \
# 0                                   2.460615
# 1                                   1.528860
# 2                                   2.495487
# 3                                   1.564394
# 4                                   1.574315
# ...                                      ...
# 2000                                1.304627
# 2001                                1.351543
# 2002                                1.394584
# 2003                                0.615610
# 2004                                0.500000
#
#       Adjusted Interceptions Projection  Adjusted Rushing Yards Projection  \
# 0                                   NaN                          20.488656
# 1                                   NaN                          60.500000
# 2                                   NaN                          11.517041
# 3                                   NaN                          21.500000
# 4                                   NaN                          30.512870
# ...                                 ...                                ...
# 2000                           0.510823                          10.504409
# 2001                           0.567442                          10.500000
# 2002                           0.639448                          12.501128
# 2003                           0.616228                           5.489177
# 2004                                NaN                           7.481323
#
#       Anytime Touchdown Probability
# 0                          0.250000
# 1                          0.476190
# 2                          0.230947
# 3                          0.200000
# 4                          0.344828
# ...                             ...
# 2000                       0.153846
# 2001                       0.133333
# 2002                       0.153846
# 2003                       0.058824
# 2004                            NaN
#
# [2005 rows x 10 columns]

# %%
y = df_mod['Fantasy Points'].copy()

y
# Out:
# 0       20.4
# 1       27.5
# 2       17.6
# 3       31.8
# 4       20.8
#         ...
# 2000    15.1
# 2001     9.5
# 2002     6.7
# 2003    12.1
# 2004    13.7
# Name: Fantasy Points, Length: 2005, dtype: float64

# %%
groups = df_mod['Season'].astype(str) + ' Week ' + df_mod['Week'].astype(str)

groups
# Out:
# 0        2020 Week 1
# 1        2020 Week 1
# 2        2020 Week 1
# 3        2020 Week 1
# 4        2020 Week 1
#             ...
# 2000    2023 Week 17
# 2001    2023 Week 17
# 2002    2023 Week 17
# 2003    2023 Week 17
# 2004    2023 Week 17
# Length: 2005, dtype: object

# %%
df_folds = pd.read_parquet('../../../data/model_data/folds.parquet')

df_folds
# Out:
#     Fold ID   Season Week
# 0         0   2022 Week 3
# 1         0   2021 Week 7
# 2         0   2021 Week 1
# 3         0  2023 Week 16
# 4         0  2021 Week 11
# ..      ...           ...
# 62        2  2020 Week 15
# 63        2  2023 Week 14
# 64        2   2021 Week 5
# 65        2   2022 Week 6
# 66        2  2022 Week 12
#
# [67 rows x 2 columns]

# %%
from sklearn.model_selection import GroupShuffleSplit
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

pd.options.mode.chained_assignment = None

# splitter = GroupKFold(n_splits=3)

cv_data = []
oos_prop_bets_data = []
# for is_indexes, oos_indexes in splitter.split(X=X, y=y, groups=groups):
for fold in df_folds['Fold ID'].unique():
    oos_season_week = df_folds.loc[df_folds['Fold ID'] == fold, 'Season Week']
    is_indexes = df_mod.loc[~groups.isin(oos_season_week), :].index
    oos_indexes = df_mod.loc[groups.isin(oos_season_week), :].index
    # split
    X_is = X.iloc[is_indexes]
    X_oos = X.iloc[oos_indexes]

    y_is = y.iloc[is_indexes]
    y_oos = y.iloc[oos_indexes]

    groups_is = groups.iloc[is_indexes]
    df_mod_oos = df_mod.iloc[oos_indexes]

    gss = GroupShuffleSplit(n_splits=1, test_size=0.15, random_state=22)
    for train_indexes, val_indexes in gss.split(X=X_is, y=y_is, groups=groups_is):
            X_train = X_is.iloc[train_indexes]
            X_val = X_is.iloc[val_indexes]

            y_train = y_is.iloc[train_indexes]
            y_val = y_is.iloc[val_indexes]

    # impute
    scaler = StandardScaler()
    imputer = IterativeImputer(initial_strategy='median', max_iter=100)

    X_train_fill_na = imputer.fit_transform(scaler.fit_transform(X_train))
    X_train[X_train.columns] = scaler.inverse_transform(X_train_fill_na).copy()
    X_train['Prop Bets Projection'] = (
        X_train['Adjusted Passing Yards Projection']*0.04 + 
        X_train['Adjusted Passing Touchdowns Projection']*4 + 
        X_train['Adjusted Interceptions Projection']*(-2) + 
        X_train['Adjusted Rushing Yards Projection']*0.1 +
        X_train['Anytime Touchdown Probability']*6
    )

    scaler2 = MinMaxScaler(clip=True)  # maybe normalize and clip instead of standardize?
    scaler3 = StandardScaler()
    X_train[X_train.columns] = scaler3.fit_transform(scaler2.fit_transform(X_train)).copy()

    X_val_fill_na = imputer.transform(scaler.transform(X_val))
    X_val[X_val.columns] = scaler.inverse_transform(X_val_fill_na).copy()
    X_val['Prop Bets Projection'] = (
        X_val['Adjusted Passing Yards Projection']*0.04 + 
        X_val['Adjusted Passing Touchdowns Projection']*4 + 
        X_val['Adjusted Interceptions Projection']*(-2) + 
        X_val['Adjusted Rushing Yards Projection']*0.1 +
        X_val['Anytime Touchdown Probability']*6
    )

    X_val[X_val.columns] = scaler3.transform(scaler2.transform(X_val)).copy()

    X_oos_fill_na = imputer.transform(scaler.transform(X_oos))
    X_oos[X_oos.columns] = scaler.inverse_transform(X_oos_fill_na).copy()
    X_oos['Prop Bets Projection'] = (
        X_oos['Adjusted Passing Yards Projection']*0.04 + 
        X_oos['Adjusted Passing Touchdowns Projection']*4 + 
        X_oos['Adjusted Interceptions Projection']*(-2) + 
        X_oos['Adjusted Rushing Yards Projection']*0.1 +
        X_oos['Anytime Touchdown Probability']*6
    )

    oos_prop_bets_data.append(X_oos.assign(f=y_oos).rename(columns={'f': 'Fantasy Points'}))

    X_oos[X_oos.columns] = scaler3.transform(scaler2.transform(X_oos)).copy()

    X_train.drop(columns=['Adjusted Passing Yards Projection', 'Adjusted Passing Touchdowns Projection', 'Adjusted Interceptions Projection', 'Adjusted Rushing Yards Projection', 'Anytime Touchdown Probability'], inplace=True)
    X_val.drop(columns=['Adjusted Passing Yards Projection', 'Adjusted Passing Touchdowns Projection', 'Adjusted Interceptions Projection', 'Adjusted Rushing Yards Projection', 'Anytime Touchdown Probability'], inplace=True)
    X_oos.drop(columns=['Adjusted Passing Yards Projection', 'Adjusted Passing Touchdowns Projection', 'Adjusted Interceptions Projection', 'Adjusted Rushing Yards Projection', 'Anytime Touchdown Probability'], inplace=True)

    cv_data.append((X_train, X_val, X_oos, y_train, y_val, y_oos, df_mod_oos))

for X_train, X_val, X_oos, y_train, y_val, y_oos, df_mod_oos in cv_data:
    print(X_train.shape, X_val.shape, X_oos.shape, y_train.shape, y_val.shape, y_oos.shape, df_mod_oos.shape)
# Out:
# (1102, 6) (215, 6) (688, 6) (1102,) (215,) (688,) (688, 18)
# (1150, 6) (211, 6) (644, 6) (1150,) (211,) (644,) (644, 18)
# (1129, 6) (203, 6) (673, 6) (1129,) (203,) (673,) (673, 18)

# %%
pd.concat(
    oos_prop_bets_data,
    ignore_index=True,
).to_parquet('../../../data/out_of_sample_prop_bets_projections/qb.parquet')

print('Done')
# Out:
# Done

# %%
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.regularizers import L1L2
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.initializers import GlorotNormal
from tensorflow.config.experimental import enable_op_determinism
from tensorflow.random import set_seed
import numpy as np
import os

os.environ["TF_ENABLE_ONEDNN_OPTS"] = "0"

def build_and_compile_model(input_shape: tuple, hidden_layer_neurons: list, l1s: list, l2s: list, learning_rate: float):
    enable_op_determinism()
    set_seed(22)
    
    inputs = Input(shape=input_shape, name='input')

    h = inputs
    for i, neurons in enumerate(hidden_layer_neurons):
        h = Dense(
            neurons, 
            activation='relu', 
            kernel_initializer=GlorotNormal(seed=22), 
            kernel_regularizer=L1L2(l1=l1s[i], l2=l2s[i]), 
            name=f"hidden_{i+1}"
        )(h)

    outputs = Dense(1, activation=None, kernel_initializer=GlorotNormal(seed=22), name='outputs')(h)

    mod = Model(inputs=inputs, outputs=outputs)

    mod.compile(optimizer=Adam(learning_rate=learning_rate), loss='mean_squared_error', metrics=['mean_absolute_error'])

    return mod

mod = build_and_compile_model(X.shape[1:], [128, 32], [0, 0.01], [0, 0.01], learning_rate=0.001)

mod.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 10)]              0
#
#  hidden_1 (Dense)            (None, 128)               1408
#
#  hidden_2 (Dense)            (None, 32)                4128
#
#  outputs (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5,569
# Trainable params: 5,569
# Non-trainable params: 0
# _________________________________________________________________

# %%
from sklearn.metrics import root_mean_squared_error
import optuna

def objective(trial, cv_data=cv_data):
# model tuning
    n_hidden_layers = trial.suggest_int(f"n_hidden_layers", 1, 3)

    hidden_layer_neurons = []
    l1s = []
    l2s = []
    for i in range(n_hidden_layers):
        hidden_layer_neurons.append(trial.suggest_categorical(f"hidden_layer_{i+1}_neurons", [2**n for n in range(5, 12)]))  # change to (3, 12)
        # hidden_layer_neurons.append(trial.suggest_categorical(f"hidden_layer_{i+1}_neurons", [2**n for n in range(4, 9)]))  # bump this up
        l1s.append(trial.suggest_float(f"hidden_layer_{i+1}_l1", 0.0, 0.1))  # change to (0.0, 0.05)
        l2s.append(trial.suggest_float(f"hidden_layer_{i+1}_l2", 0.0, 0.1))  # change to (0.0, 0.20)

    learning_rate = trial.suggest_float(f"learning_rate", 0.01, 0.10)
    batch_size = trial.suggest_categorical(f"batch_size", [2**n for n in range(10, 16)])
    # batch_size = trial.suggest_categorical(f"batch_size", [2**n for n in range(4, 12)])  # bump this up

    # cross validation
    y_oos_list = []
    y_pred_list = []
    for X_train, X_val, X_oos, y_train, y_val, y_oos, df_mod_oos in cv_data:
        # make sure to build mod in loop to prevent history
        mod = build_and_compile_model(X_train.shape[1:], hidden_layer_neurons, l1s, l2s, learning_rate)

        mod.fit(
            X_train,
            y_train,
            validation_data=(X_val, y_val),
            batch_size=batch_size,
            epochs=500,
            callbacks=[EarlyStopping(patience=10, restore_best_weights=True)],
            verbose=0,
        )

        y_oos_list.append(y_oos)
        y_pred_list.append(mod.predict(X_oos, verbose=0))

    y_oos_concat = np.concatenate(y_oos_list)
    y_pred_concat = np.concatenate(y_pred_list)

    return root_mean_squared_error(y_oos_concat, y_pred_concat)

study = optuna.create_study(direction='minimize', sampler=optuna.samplers.TPESampler(seed=22, n_startup_trials=10, multivariate=True, warn_independent_sampling=False))
study.optimize(objective, n_trials=20, show_progress_bar=True)

study.best_params
# Out:
# c:\Users\mhugh\anaconda3\envs\clean2\lib\site-packages\optuna\_experimental.py:30: ExperimentalWarning: Argument ``multivariate`` is an experimental feature. The interface can change in the future.
#   warnings.warn(
# [I 2024-10-23 17:20:39,451] A new study created in memory with name: no-name-5e9acd2e-bdaa-4cdf-a120-ab5f9fcaa617
#   0%|          | 0/20 [00:00<?, ?it/s]
# [I 2024-10-23 17:21:40,114] Trial 0 finished with value: 7.281197097751789 and parameters: {'n_hidden_layers': 1, 'hidden_layer_1_neurons': 128, 'hidden_layer_1_l1': 0.022040451663772567, 'hidden_layer_1_l2': 0.08119509205386867, 'learning_rate': 0.01094741868844976, 'batch_size': 2048}. Best is trial 0 with value: 7.281197097751789.
# [I 2024-10-23 17:21:46,091] Trial 1 finished with value: 16.456070609354082 and parameters: {'n_hidden_layers': 3, 'hidden_layer_1_neurons': 128, 'hidden_layer_1_l1': 0.058428964315689495, 'hidden_layer_1_l2': 0.07026355188654519, 'hidden_layer_2_neurons': 128, 'hidden_layer_2_l1': 0.08749277452777171, 'hidden_layer_2_l2': 0.07449320773686179, 'hidden_layer_3_neurons': 256, 'hidden_layer_3_l1': 0.009588460991804116, 'hidden_layer_3_l2': 0.004521011190769353, 'learning_rate': 0.07163458468004151, 'batch_size': 1024}. Best is trial 0 with value: 7.281197097751789.
# [I 2024-10-23 17:21:52,528] Trial 2 finished with value: 11.907060754050072 and parameters: {'n_hidden_layers': 2, 'hidden_layer_1_neurons': 64, 'hidden_layer_1_l1': 0.09115369973853776, 'hidden_layer_1_l2': 0.008625567976924198, 'hidden_layer_2_neurons': 2048, 'hidden_layer_2_l1': 0.0005512411903590642, 'hidden_layer_2_l2': 0.03576431697413079, 'learning_rate': 0.09578334240413691, 'batch_size': 1024}. Best is trial 0 with value: 7.281197097751789.
# [I 2024-10-23 17:22:10,263] Trial 3 finished with value: 7.286726699612637 and parameters: {'n_hidden_layers': 1, 'hidden_layer_1_neurons': 1024, 'hidden_layer_1_l1': 0.08620878124622662, 'hidden_layer_1_l2': 0.06351961895274903, 'learning_rate': 0.07275008619568284, 'batch_size': 4096}. Best is trial 0 with value: 7.281197097751789.
# [I 2024-10-23 17:22:21,300] Trial 4 finished with value: 7.349427089109273 and parameters: {'n_hidden_layers': 1, 'hidden_layer_1_neurons': 1024, 'hidden_layer_1_l1': 0.02024276263846314, 'hidden_layer_1_l2': 0.08721894394962987, 'learning_rate': 0.06424371980220045, 'batch_size': 1024}. Best is trial 0 with value: 7.281197097751789.
# [I 2024-10-23 17:22:31,304] Trial 5 finished with value: 7.39430290400214 and parameters: {'n_hidden_layers': 1, 'hidden_layer_1_neurons': 32, 'hidden_layer_1_l1': 0.05653980354893057, 'hidden_layer_1_l2': 0.00345150171194456, 'learning_rate': 0.0885147769978044, 'batch_size': 16384}. Best is trial 0 with value: 7.281197097751789.
# [I 2024-10-23 17:22:37,713] Trial 6 finished with value: 16.103648177929948 and parameters: {'n_hidden_layers': 3, 'hidden_layer_1_neurons': 256, 'hidden_layer_1_l1': 0.07564442330254927, 'hidden_layer_1_l2': 0.045177882434907994, 'hidden_layer_2_neurons': 64, 'hidden_layer_2_l1': 0.08362472880832089, 'hidden_layer_2_l2': 0.05103829122196473, 'hidden_layer_3_neurons': 128, 'hidden_layer_3_l1': 0.06951388599043494, 'hidden_layer_3_l2': 0.0051964104142108065, 'learning_rate': 0.09447015559422758, 'batch_size': 2048}. Best is trial 0 with value: 7.281197097751789.
# [I 2024-10-23 17:22:51,979] Trial 7 finished with value: 7.304191981747989 and parameters: {'n_hidden_layers': 2, 'hidden_layer_1_neurons': 32, 'hidden_layer_1_l1': 0.08592805490779229, 'hidden_layer_1_l2': 0.0407904418229531, 'hidden_layer_2_neurons': 64, 'hidden_layer_2_l1': 0.025309932195697216, 'hidden_layer_2_l2': 0.03508986025005804, 'learning_rate': 0.06905762708317247, 'batch_size': 1024}. Best is trial 0 with value: 7.281197097751789.
# [I 2024-10-23 17:23:03,021] Trial 8 finished with value: 7.373703063059008 and parameters: {'n_hidden_layers': 1, 'hidden_layer_1_neurons': 32, 'hidden_layer_1_l1': 0.004671699281628905, 'hidden_layer_1_l2': 0.056923526796298245, 'learning_rate': 0.09827798409489276, 'batch_size': 1024}. Best is trial 0 with value: 7.281197097751789.
# [I 2024-10-23 17:23:17,524] Trial 9 finished with value: 7.3388949382406405 and parameters: {'n_hidden_layers': 2, 'hidden_layer_1_neurons': 256, 'hidden_layer_1_l1': 0.0004424057058423636, 'hidden_layer_1_l2': 0.06813144847420316, 'hidden_layer_2_neurons': 64, 'hidden_layer_2_l1': 0.08249019408071431, 'hidden_layer_2_l2': 0.04359087388902699, 'learning_rate': 0.05221946484311475, 'batch_size': 1024}. Best is trial 0 with value: 7.281197097751789.
# [I 2024-10-23 17:23:42,587] Trial 10 finished with value: 7.394551443634715 and parameters: {'n_hidden_layers': 1, 'hidden_layer_1_neurons': 128, 'hidden_layer_1_l1': 0.020822305720339832, 'hidden_layer_1_l2': 0.09105201059054474, 'learning_rate': 0.03633285507832701, 'batch_size': 2048}. Best is trial 0 with value: 7.281197097751789.
# [I 2024-10-23 17:23:59,571] Trial 11 finished with value: 7.2850090877375475 and parameters: {'n_hidden_layers': 1, 'hidden_layer_1_neurons': 1024, 'hidden_layer_1_l1': 0.08794955654819853, 'hidden_layer_1_l2': 0.038756133720937364, 'learning_rate': 0.065300778058377, 'batch_size': 4096}. Best is trial 0 with value: 7.281197097751789.
# [I 2024-10-23 17:24:22,894] Trial 12 finished with value: 7.27901501100281 and parameters: {'n_hidden_layers': 1, 'hidden_layer_1_neurons': 1024, 'hidden_layer_1_l1': 0.09525596752458146, 'hidden_layer_1_l2': 0.024814972248352232, 'learning_rate': 0.038444536051553346, 'batch_size': 8192}. Best is trial 12 with value: 7.27901501100281.
# [I 2024-10-23 17:25:01,322] Trial 13 finished with value: 7.281423238080091 and parameters: {'n_hidden_layers': 1, 'hidden_layer_1_neurons': 1024, 'hidden_layer_1_l1': 0.09657698764744203, 'hidden_layer_1_l2': 0.019460100867526805, 'learning_rate': 0.01592378058872306, 'batch_size': 8192}. Best is trial 12 with value: 7.27901501100281.
# [I 2024-10-23 17:25:33,254] Trial 14 finished with value: 7.324787112596467 and parameters: {'n_hidden_layers': 2, 'hidden_layer_1_neurons': 128, 'hidden_layer_1_l1': 0.0004424205002942286, 'hidden_layer_1_l2': 0.06327928460123093, 'hidden_layer_2_neurons': 512, 'hidden_layer_2_l1': 0.04490480620139892, 'hidden_layer_2_l2': 0.09940529653696407, 'learning_rate': 0.012339412729921149, 'batch_size': 2048}. Best is trial 12 with value: 7.27901501100281.
# [I 2024-10-23 17:25:48,339] Trial 15 finished with value: 7.320139521252285 and parameters: {'n_hidden_layers': 1, 'hidden_layer_1_neurons': 128, 'hidden_layer_1_l1': 0.058869358545157215, 'hidden_layer_1_l2': 0.08004914447346914, 'learning_rate': 0.02165015969387038, 'batch_size': 1024}. Best is trial 12 with value: 7.27901501100281.
# [I 2024-10-23 17:26:08,298] Trial 16 finished with value: 7.286351476977106 and parameters: {'n_hidden_layers': 2, 'hidden_layer_1_neurons': 512, 'hidden_layer_1_l1': 0.08048843864575601, 'hidden_layer_1_l2': 0.018085926386260893, 'hidden_layer_2_neurons': 256, 'hidden_layer_2_l1': 0.05932797679633018, 'hidden_layer_2_l2': 0.005061505309514394, 'learning_rate': 0.0507960912481544, 'batch_size': 8192}. Best is trial 12 with value: 7.27901501100281.
# [I 2024-10-23 17:26:25,207] Trial 17 finished with value: 7.442398116327333 and parameters: {'n_hidden_layers': 1, 'hidden_layer_1_neurons': 2048, 'hidden_layer_1_l1': 0.029741099620247853, 'hidden_layer_1_l2': 0.030699013596471036, 'learning_rate': 0.03335975199036295, 'batch_size': 2048}. Best is trial 12 with value: 7.27901501100281.
# [I 2024-10-23 17:27:22,049] Trial 18 finished with value: 7.284032889549861 and parameters: {'n_hidden_layers': 1, 'hidden_layer_1_neurons': 256, 'hidden_layer_1_l1': 0.059130693746569714, 'hidden_layer_1_l2': 0.05817541040401575, 'learning_rate': 0.012431964379232528, 'batch_size': 2048}. Best is trial 12 with value: 7.27901501100281.
# [I 2024-10-23 17:27:56,624] Trial 19 finished with value: 7.370511969061739 and parameters: {'n_hidden_layers': 1, 'hidden_layer_1_neurons': 64, 'hidden_layer_1_l1': 0.004392640185883187, 'hidden_layer_1_l2': 0.05572511886648701, 'learning_rate': 0.01168912503323998, 'batch_size': 4096}. Best is trial 12 with value: 7.27901501100281.
# {'n_hidden_layers': 1,
#  'hidden_layer_1_neurons': 1024,
#  'hidden_layer_1_l1': 0.09525596752458146,
#  'hidden_layer_1_l2': 0.024814972248352232,
#  'learning_rate': 0.038444536051553346,
#  'batch_size': 8192}

# %% [markdown]
# 7.27901501100281

# %%
n_hidden_layers = study.best_params['n_hidden_layers']

hidden_layer_neurons = []
l1s = []
l2s = []
for i in range(n_hidden_layers):
    hidden_layer_neurons.append(study.best_params[f"hidden_layer_{i+1}_neurons"])
    l1s.append(study.best_params[f"hidden_layer_{i+1}_l1"])
    l2s.append(study.best_params[f"hidden_layer_{i+1}_l2"])

learning_rate = study.best_params[f"learning_rate"]
batch_size = study.best_params[f"batch_size"]

y_oos_list = []
y_pred_list = []
testing_data = []
for X_train, X_val, X_oos, y_train, y_val, y_oos, df_mod_oos in cv_data:
    # make sure to build mod in loop to prevent history
    mod = build_and_compile_model(X_train.shape[1:], hidden_layer_neurons, l1s, l2s, learning_rate)

    mod.fit(
        X_train,
        y_train,
        validation_data=(X_val, y_val),
        batch_size=batch_size,
        epochs=500,
        callbacks=[EarlyStopping(patience=10, restore_best_weights=True)],
        verbose=1,
    )

    y_preds = mod.predict(X_oos, verbose=0)

    df_preds = pd.DataFrame(
        y_preds,
        columns=['Prediction']
    )

    testing_data.append(pd.concat((df_mod_oos.reset_index(drop=True), df_preds), axis=1))


    y_oos_list.append(y_oos)
    y_pred_list.append(y_preds)

df_test = pd.concat(testing_data, ignore_index=True)

y_oos_concat = np.concatenate(y_oos_list)
y_pred_concat = np.concatenate(y_pred_list)

print(f"OOS RMSE: {root_mean_squared_error(y_oos_concat, y_pred_concat)}")
# Out:
# Epoch 1/500
# 1/1 [==============================] - 1s 734ms/step - loss: 366.4147 - mean_absolute_error: 16.6294 - val_loss: 248.3021 - val_mean_absolute_error: 12.8013
# Epoch 2/500
# 1/1 [==============================] - 0s 51ms/step - loss: 249.1917 - mean_absolute_error: 12.9527 - val_loss: 163.8526 - val_mean_absolute_error: 9.0665
# Epoch 3/500
# 1/1 [==============================] - 0s 53ms/step - loss: 153.7884 - mean_absolute_error: 8.9087 - val_loss: 158.2055 - val_mean_absolute_error: 8.0595
# Epoch 4/500
# 1/1 [==============================] - 0s 50ms/step - loss: 143.5975 - mean_absolute_error: 7.8645 - val_loss: 169.3567 - val_mean_absolute_error: 8.5876
# Epoch 5/500
# 1/1 [==============================] - 0s 55ms/step - loss: 162.4172 - mean_absolute_error: 8.5149 - val_loss: 123.0241 - val_mean_absolute_error: 7.2680
# Epoch 6/500
# 1/1 [==============================] - 0s 54ms/step - loss: 121.4098 - mean_absolute_error: 7.2312 - val_loss: 95.3429 - val_mean_absolute_error: 6.3453
# Epoch 7/500
# 1/1 [==============================] - 0s 53ms/step - loss: 95.3017 - mean_absolute_error: 6.2043 - val_loss: 92.6525 - val_mean_absolute_error: 6.3093
# Epoch 8/500
# 1/1 [==============================] - 0s 51ms/step - loss: 93.4841 - mean_absolute_error: 6.1787 - val_loss: 95.0822 - val_mean_absolute_error: 6.4078
# Epoch 9/500
# 1/1 [==============================] - 0s 53ms/step - loss: 96.7657 - mean_absolute_error: 6.3629 - val_loss: 92.1042 - val_mean_absolute_error: 6.2898
# Epoch 10/500
# 1/1 [==============================] - 0s 54ms/step - loss: 94.5461 - mean_absolute_error: 6.2530 - val_loss: 86.1563 - val_mean_absolute_error: 6.1027
# Epoch 11/500
# 1/1 [==============================] - 0s 67ms/step - loss: 89.1136 - mean_absolute_error: 5.9863 - val_loss: 84.7786 - val_mean_absolute_error: 6.0409
# Epoch 12/500
# 1/1 [==============================] - 0s 58ms/step - loss: 87.8307 - mean_absolute_error: 5.9799 - val_loss: 88.6615 - val_mean_absolute_error: 6.1491
500
# 1/1 [==============================] - 0s 54ms/step - loss: 56.1578 - mean_absolute_error: 5.7657 - val_loss: 54.5933 - val_mean_absolute_error: 5.8245
# Epoch 69/500
# 1/1 [==============================] - 0s 53ms/step - loss: 56.1214 - mean_absolute_error: 5.7646 - val_loss: 54.5803 - val_mean_absolute_error: 5.8263
# Epoch 70/500
# 1/1 [==============================] - 0s 104ms/step - loss: 56.0713 - mean_absolute_error: 5.7644 - val_loss: 54.5009 - val_mean_absolute_error: 5.8235
# Epoch 71/500
# 1/1 [==============================] - 0s 54ms/step - loss: 56.0257 - mean_absolute_error: 5.7651 - val_loss: 54.4378 - val_mean_absolute_error: 5.8211
# Epoch 72/500
# 1/1 [==============================] - 0s 55ms/step - loss: 55.9980 - mean_absolute_error: 5.7669 - val_loss: 54.3991 - val_mean_absolute_error: 5.8218
# Epoch 73/500
# 1/1 [==============================] - 0s 54ms/step - loss: 55.9629 - mean_absolute_error: 5.7687 - val_loss: 54.3737 - val_mean_absolute_error: 5.8230
# Epoch 74/500
# 1/1 [==============================] - 0s 55ms/step - loss: 55.9121 - mean_absolute_error: 5.7693 - val_loss: 54.3761 - val_mean_absolute_error: 5.8227
# Epoch 75/500
# 1/1 [==============================] - 0s 55ms/step - loss: 55.8877 - mean_absolute_error: 5.7683 - val_loss: 54.3712 - val_mean_absolute_error: 5.8223
# Epoch 76/500
# 1/1 [==============================] - 0s 54ms/step - loss: 55.8690 - mean_absolute_error: 5.7669 - val_loss: 54.3419 - val_mean_absolute_error: 5.8224
# Epoch 77/500
# 1/1 [==============================] - 0s 55ms/step - loss: 55.8431 - mean_absolute_error: 5.7659 - val_loss: 54.2950 - val_mean_absolute_error: 5.8228
# Epoch 78/500
# 1/1 [==============================] - 0s 55ms/step - loss: 55.8057 - mean_absolute_error: 5.7656 - val_loss: 54.2764 - val_mean_absolute_error: 5.8244
# Epoch 79/500
# 1/1 [==============================] - 0s 54ms/step - loss: 55.7624 - mean_absolute_error: 5.7661 - val_loss: 54.2952 - val_mean_absolute_error: 5.8243
# Epoch 80/500
# 1/1 [==============================] - 0s 54ms/step - loss: 55.7580 - mean_absolute_error: 5.7666 - val_loss: 54.2903 - val_mean_absolute_error: 5.8213
# Epoch 81/500
# 1/1 [==============================] - 0s 55ms/step - loss: 55.7536 - mean_absolute_error: 5.7666 - val_loss: 54.2492 - val_mean_absolute_error: 5.8197
# Epoch 82/500
# 1/1 [==============================] - 0s 56ms/step - loss: 55.7174 - mean_absolute_error: 5.7659 - val_loss: 54.2409 - val_mean_absolute_error: 5.8208
# Epoch 83/500
# 1/1 [==============================] - 0s 55ms/step - loss: 55.7006 - mean_absolute_error: 5.7648 - val_loss: 54.2371 - val_mean_absolute_error: 5.8223
# Epoch 84/500
# 1/1 [==============================] - 0s 56ms/step - loss: 55.6833 - mean_absolute_error: 5.7642 - val_loss: 54.2243 - val_mean_absolute_error: 5.8232
# Epoch 85/500
# 1/1 [==============================] - 0s 54ms/step - loss: 55.6359 - mean_absolute_error: 5.7642 - val_loss: 54.2452 - val_mean_absolute_error: 5.8229
# Epoch 86/500
# 1/1 [==============================] - 0s 57ms/step - loss: 55.6288 - mean_absolute_error: 5.7650 - val_loss: 54.2824 - val_mean_absolute_error: 5.8248
# Epoch 87/500
# 1/1 [==============================] - 0s 53ms/step - loss: 55.6298 - mean_absolute_error: 5.7647 - val_loss: 54.2728 - val_mean_absolute_error: 5.8247
# Epoch 88/500
# 1/1 [==============================] - 0s 55ms/step - loss: 55.5997 - mean_absolute_error: 5.7633 - val_loss: 54.2505 - val_mean_absolute_error: 5.8239
# Epoch 89/500
# 1/1 [==============================] - 0s 56ms/step - loss: 55.5816 - mean_absolute_error: 5.7626 - val_loss: 54.2171 - val_mean_absolute_error: 5.8228
# Epoch 90/500
# 1/1 [==============================] - 0s 54ms/step - loss: 55.5656 - mean_absolute_error: 5.7634 - val_loss: 54.2425 - val_mean_absolute_error: 5.8243
# Epoch 91/500
# 1/1 [==============================] - 0s 55ms/step - loss: 55.5653 - mean_absolute_error: 5.7638 - val_loss: 54.2265 - val_mean_absolute_error: 5.8252
# Epoch 92/500
# 1/1 [==============================] - 0s 55ms/step - loss: 55.5315 - mean_absolute_error: 5.7638 - val_loss: 54.2138 - val_mean_absolute_error: 5.8247
# Epoch 93/500
# 1/1 [==============================] - 0s 55ms/step - loss: 55.5207 - mean_absolute_error: 5.7631 - val_loss: 54.2067 - val_mean_absolute_error: 5.8245
# Epoch 94/500
# 1/1 [==============================] - 0s 52ms/step - loss: 55.4938 - mean_absolute_error: 5.7622 - val_loss: 54.2407 - val_mean_absolute_error: 5.8236
# Epoch 95/500
# 1/1 [==============================] - 0s 55ms/step - loss: 55.5227 - mean_absolute_error: 5.7614 - val_loss: 54.2878 - val_mean_absolute_error: 5.8265
# Epoch 96/500
# 1/1 [==============================] - 0s 54ms/step - loss: 55.5405 - mean_absolute_error: 5.7611 - val_loss: 54.2626 - val_mean_absolute_error: 5.8275
# Epoch 97/500
# 1/1 [==============================] - 0s 54ms/step - loss: 55.5121 - mean_absolute_error: 5.7613 - val_loss: 54.2061 - val_mean_absolute_error: 5.8257
# Epoch 98/500
# 1/1 [==============================] - 0s 62ms/step - loss: 55.4802 - mean_absolute_error: 5.7618 - val_loss: 54.1943 - val_mean_absolute_error: 5.8253
# Epoch 99/500
# 1/1 [==============================] - 0s 59ms/step - loss: 55.4660 - mean_absolute_error: 5.7618 - val_loss: 54.2030 - val_mean_absolute_error: 5.8275
# Epoch 100/500
# 1/1 [==============================] - 0s 54ms/step - loss: 55.4554 - mean_absolute_error: 5.7615 - val_loss: 54.1880 - val_mean_absolute_error: 5.8254
# Epoch 101/500
# 1/1 [==============================] - 0s 55ms/step - loss: 55.4491 - mean_absolute_error: 5.7610 - val_loss: 54.1550 - val_mean_absolute_error: 5.8223
# Epoch 102/500
# 1/1 [==============================] - 0s 54ms/step - loss: 55.4430 - mean_absolute_error: 5.7605 - val_loss: 54.1890 - val_mean_absolute_error: 5.8239
# Epoch 103/500
# 1/1 [==============================] - 0s 54ms/step - loss: 55.4686 - mean_absolute_error: 5.7601 - val_loss: 54.2092 - val_mean_absolute_error: 5.8257
# Epoch 104/500
# 1/1 [==============================] - 0s 56ms/step - loss: 55.4506 - mean_absolute_error: 5.7599 - val_loss: 54.2214 - val_mean_absolute_error: 5.8260
# Epoch 105/500
# 1/1 [==============================] - 0s 54ms/step - loss: 55.4497 - mean_absolute_error: 5.7595 - val_loss: 54.1888 - val_mean_absolute_error: 5.8246
# Epoch 106/500
# 1/1 [==============================] - 0s 54ms/step - loss: 55.4345 - mean_absolute_error: 5.7588 - val_loss: 54.2068 - val_mean_absolute_error: 5.8259
# Epoch 107/500
# 1/1 [==============================] - 0s 53ms/step - loss: 55.4334 - mean_absolute_error: 5.7581 - val_loss: 54.1839 - val_mean_absolute_error: 5.8246
# Epoch 108/500
# 1/1 [==============================] - 0s 53ms/step - loss: 55.4072 - mean_absolute_error: 5.7578 - val_loss: 54.1718 - val_mean_absolute_error: 5.8229
# Epoch 109/500
# 1/1 [==============================] - 0s 54ms/step - loss: 55.4052 - mean_absolute_error: 5.7573 - val_loss: 54.1944 - val_mean_absolute_error: 5.8242
# Epoch 110/500
# 1/1 [==============================] - 0s 51ms/step - loss: 55.4050 - mean_absolute_error: 5.7567 - val_loss: 54.2194 - val_mean_absolute_error: 5.8263
# Epoch 111/500
# 1/1 [==============================] - 0s 62ms/step - loss: 55.3969 - mean_absolute_error: 5.7561 - val_loss: 54.1978 - val_mean_absolute_error: 5.8255
# Epoch 1/500
# 1/1 [==============================] - 1s 856ms/step - loss: 368.2723 - mean_absolute_error: 16.6975 - val_loss: 241.2010 - val_mean_absolute_error: 12.7405
# Epoch 2/500
# 1/1 [==============================] - 0s 48ms/step - loss: 249.5515 - mean_absolute_error: 12.9399 - val_loss: 146.2584 - val_mean_absolute_error: 8.8500
# 1/1 [==============================] - 0s 53ms/step - loss: 59.0792 - mean_absolute_error: 5.6968 - val_loss: 58.9986 - val_mean_absolute_error: 5.9311
# Epoch 39/500
# 1/1 [==============================] - 0s 53ms/step - loss: 58.9270 - mean_absolute_error: 5.7071 - val_loss: 58.6945 - val_mean_absolute_error: 5.9356
# Epoch 40/500
# 1/1 [==============================] - 0s 53ms/step - loss: 58.5686 - mean_absolute_error: 5.7103 - val_loss: 58.4957 - val_mean_absolute_error: 5.9455
# Epoch 41/500
# 1/1 [==============================] - 0s 53ms/step - loss: 58.0326 - mean_absolute_error: 5.7056 - val_loss: 58.5827 - val_mean_absolute_error: 5.9553
# Epoch 42/500
# 1/1 [==============================] - 0s 52ms/step - loss: 57.7660 - mean_absolute_error: 5.7192 - val_loss: 58.5025 - val_mean_absolute_error: 5.9582
# Epoch 43/500
# 1/1 [==============================] - 0s 54ms/step - loss: 57.5842 - mean_absolute_error: 5.7302 - val_loss: 57.8797 - val_mean_absolute_error: 5.9539
# Epoch 44/500
# 1/1 [==============================] - 0s 54ms/step - loss: 57.1579 - mean_absolute_error: 5.7158 - val_loss: 57.2771 - val_mean_absolute_error: 5.9472
# Epoch 45/500
# 1/1 [==============================] - 0s 54ms/step - loss: 56.8785 - mean_absolute_error: 5.7032 - val_loss: 56.9670 - val_mean_absolute_error: 5.9443
# Epoch 46/500
# 1/1 [==============================] - 0s 53ms/step - loss: 56.7616 - mean_absolute_error: 5.7036 - val_loss: 56.7961 - val_mean_absolute_error: 5.9485
# Epoch 47/500
# 1/1 [==============================] - 0s 54ms/step - loss: 56.5029 - mean_absolute_error: 5.6998 - val_loss: 56.7752 - val_mean_absolute_error: 5.9575
# Epoch 48/500
# 1/1 [==============================] - 0s 53ms/step - loss: 56.1990 - mean_absolute_error: 5.6982 - val_loss: 56.9023 - val_mean_absolute_error: 5.9652
# Epoch 49/500
# 1/1 [==============================] - 0s 54ms/step - loss: 56.0908 - mean_absolute_error: 5.7104 - val_loss: 56.7417 - val_mean_absolute_error: 5.9647
# Epoch 50/500
# 1/1 [==============================] - 0s 54ms/step - loss: 55.9227 - mean_absolute_error: 5.7136 - val_loss: 56.3303 - val_mean_absolute_error: 5.9573
# Epoch 51/500
# 1/1 [==============================] - 0s 53ms/step - loss: 55.7182 - mean_absolute_error: 5.7077 - val_loss: 55.9948 - val_mean_absolute_error: 5.9500
# Epoch 52/500
# 1/1 [==============================] - 0s 53ms/step - loss: 55.6049 - mean_absolute_error: 5.7064 - val_loss: 55.7780 - val_mean_absolute_error: 5.9489
# Epoch 53/500
# 1/1 [==============================] - 0s 53ms/step - loss: 55.4303 - mean_absolute_error: 5.7020 - val_loss: 55.7632 - val_mean_absolute_error: 5.9549
# Epoch 54/500
# 1/1 [==============================] - 0s 51ms/step - loss: 55.2638 - mean_absolute_error: 5.6966 - val_loss: 55.8750 - val_mean_absolute_error: 5.9633
# Epoch 55/500
# 1/1 [==============================] - 0s 54ms/step - loss: 55.1695 - mean_absolute_error: 5.6991 - val_loss: 55.8370 - val_mean_absolute_error: 5.9678
# Epoch 56/500
# 1/1 [==============================] - 0s 56ms/step - loss: 55.0414 - mean_absolute_error: 5.7018 - val_loss: 55.6756 - val_mean_absolute_error: 5.9671
# Epoch 57/500
# 1/1 [==============================] - 0s 53ms/step - loss: 54.9420 - mean_absolute_error: 5.7006 - val_loss: 55.4815 - val_mean_absolute_error: 5.9642
# Epoch 58/500
# 1/1 [==============================] - 0s 54ms/step - loss: 54.8463 - mean_absolute_error: 5.7008 - val_loss: 55.3705 - val_mean_absolute_error: 5.9628
500
# 1/1 [==============================] - 0s 53ms/step - loss: 53.8248 - mean_absolute_error: 5.6972 - val_loss: 54.6062 - val_mean_absolute_error: 5.9687
# Epoch 79/500
# 1/1 [==============================] - 0s 54ms/step - loss: 53.8110 - mean_absolute_error: 5.6967 - val_loss: 54.5693 - val_mean_absolute_error: 5.9683
# Epoch 80/500
# 1/1 [==============================] - 0s 54ms/step - loss: 53.7622 - mean_absolute_error: 5.6968 - val_loss: 54.5571 - val_mean_absolute_error: 5.9679
# Epoch 81/500
# 1/1 [==============================] - 0s 51ms/step - loss: 53.7521 - mean_absolute_error: 5.6968 - val_loss: 54.5581 - val_mean_absolute_error: 5.9684
# Epoch 82/500
# 1/1 [==============================] - 0s 64ms/step - loss: 53.7441 - mean_absolute_error: 5.6971 - val_loss: 54.5573 - val_mean_absolute_error: 5.9688
# Epoch 83/500
# 1/1 [==============================] - 0s 57ms/step - loss: 53.7262 - mean_absolute_error: 5.6979 - val_loss: 54.5101 - val_mean_absolute_error: 5.9678
# Epoch 84/500
# 1/1 [==============================] - 0s 53ms/step - loss: 53.6964 - mean_absolute_error: 5.6979 - val_loss: 54.4651 - val_mean_absolute_error: 5.9659
# Epoch 85/500
# 1/1 [==============================] - 0s 53ms/step - loss: 53.6894 - mean_absolute_error: 5.6973 - val_loss: 54.4481 - val_mean_absolute_error: 5.9651
# Epoch 86/500
# 1/1 [==============================] - 0s 52ms/step - loss: 53.6751 - mean_absolute_error: 5.6971 - val_loss: 54.4515 - val_mean_absolute_error: 5.9656
# Epoch 87/500
# 1/1 [==============================] - 0s 52ms/step - loss: 53.6547 - mean_absolute_error: 5.6970 - val_loss: 54.4544 - val_mean_absolute_error: 5.9659
# Epoch 88/500
# 1/1 [==============================] - 0s 52ms/step - loss: 53.6428 - mean_absolute_error: 5.6969 - val_loss: 54.4599 - val_mean_absolute_error: 5.9652
# Epoch 89/500
# 1/1 [==============================] - 0s 53ms/step - loss: 53.6553 - mean_absolute_error: 5.6967 - val_loss: 54.4113 - val_mean_absolute_error: 5.9640
# Epoch 90/500
# 1/1 [==============================] - 0s 53ms/step - loss: 53.6234 - mean_absolute_error: 5.6964 - val_loss: 54.3895 - val_mean_absolute_error: 5.9642
# Epoch 91/500
# 1/1 [==============================] - 0s 54ms/step - loss: 53.6014 - mean_absolute_error: 5.6963 - val_loss: 54.3771 - val_mean_absolute_error: 5.9640
# Epoch 92/500
# 1/1 [==============================] - 0s 52ms/step - loss: 53.5982 - mean_absolute_error: 5.6960 - val_loss: 54.4051 - val_mean_absolute_error: 5.9645
# Epoch 93/500
# 1/1 [==============================] - 0s 52ms/step - loss: 53.6202 - mean_absolute_error: 5.6961 - val_loss: 54.4172 - val_mean_absolute_error: 5.9651
# Epoch 94/500
# 1/1 [==============================] - 0s 52ms/step - loss: 53.6197 - mean_absolute_error: 5.6965 - val_loss: 54.4084 - val_mean_absolute_error: 5.9653
# Epoch 95/500
# 1/1 [==============================] - 0s 55ms/step - loss: 53.6054 - mean_absolute_error: 5.6968 - val_loss: 54.3711 - val_mean_absolute_error: 5.9650
# Epoch 96/500
# 1/1 [==============================] - 0s 52ms/step - loss: 53.5740 - mean_absolute_error: 5.6965 - val_loss: 54.3481 - val_mean_absolute_error: 5.9648
# Epoch 97/500
# 1/1 [==============================] - 0s 52ms/step - loss: 53.5557 - mean_absolute_error: 5.6961 - val_loss: 54.3652 - val_mean_absolute_error: 5.9644
# Epoch 98/500
# 1/1 [==============================] - 0s 52ms/step - loss: 53.5696 - mean_absolute_error: 5.6955 - val_loss: 54.4067 - val_mean_absolute_error: 5.9640
# Epoch 99/500
# 1/1 [==============================] - 0s 51ms/step - loss: 53.6002 - mean_absolute_error: 5.6956 - val_loss: 54.3967 - val_mean_absolute_error: 5.9638
# Epoch 100/500
# 1/1 [==============================] - 0s 52ms/step - loss: 53.5965 - mean_absolute_error: 5.6954 - val_loss: 54.3786 - val_mean_absolute_error: 5.9642
# Epoch 101/500
# 1/1 [==============================] - 0s 53ms/step - loss: 53.5858 - mean_absolute_error: 5.6949 - val_loss: 54.3425 - val_mean_absolute_error: 5.9645
# Epoch 102/500
# 1/1 [==============================] - 0s 66ms/step - loss: 53.5530 - mean_absolute_error: 5.6949 - val_loss: 54.3442 - val_mean_absolute_error: 5.9641
# Epoch 103/500
# 1/1 [==============================] - 0s 58ms/step - loss: 53.5501 - mean_absolute_error: 5.6959 - val_loss: 54.3416 - val_mean_absolute_error: 5.9631
# Epoch 104/500
# 1/1 [==============================] - 0s 51ms/step - loss: 53.5496 - mean_absolute_error: 5.6965 - val_loss: 54.3512 - val_mean_absolute_error: 5.9623
# Epoch 105/500
# 1/1 [==============================] - 0s 52ms/step - loss: 53.5714 - mean_absolute_error: 5.6960 - val_loss: 54.3274 - val_mean_absolute_error: 5.9623
# Epoch 106/500
# 1/1 [==============================] - 0s 52ms/step - loss: 53.5565 - mean_absolute_error: 5.6954 - val_loss: 54.3327 - val_mean_absolute_error: 5.9636
# Epoch 107/500
# 1/1 [==============================] - 0s 52ms/step - loss: 53.5369 - mean_absolute_error: 5.6960 - val_loss: 54.3399 - val_mean_absolute_error: 5.9649
# Epoch 108/500
# 1/1 [==============================] - 0s 53ms/step - loss: 53.5262 - mean_absolute_error: 5.6961 - val_loss: 54.3385 - val_mean_absolute_error: 5.9656
# Epoch 109/500
# 1/1 [==============================] - 0s 51ms/step - loss: 53.5305 - mean_absolute_error: 5.6959 - val_loss: 54.3585 - val_mean_absolute_error: 5.9668
# Epoch 110/500
# 1/1 [==============================] - 0s 53ms/step - loss: 53.5278 - mean_absolute_error: 5.6969 - val_loss: 54.3424 - val_mean_absolute_error: 5.9671
# Epoch 111/500
# 1/1 [==============================] - 0s 54ms/step - loss: 53.5097 - mean_absolute_error: 5.6971 - val_loss: 54.2865 - val_mean_absolute_error: 5.9664
# Epoch 112/500
# 1/1 [==============================] - 0s 55ms/step - loss: 53.4822 - mean_absolute_error: 5.6964 - val_loss: 54.2840 - val_mean_absolute_error: 5.9657
# Epoch 113/500
# 1/1 [==============================] - 0s 52ms/step - loss: 53.4861 - mean_absolute_error: 5.6959 - val_loss: 54.3200 - val_mean_absolute_error: 5.9658
# Epoch 114/500
# 1/1 [==============================] - 0s 52ms/step - loss: 53.4929 - mean_absolute_error: 5.6960 - val_loss: 54.3275 - val_mean_absolute_error: 5.9651
# Epoch 115/500
# 1/1 [==============================] - 0s 55ms/step - loss: 53.4938 - mean_absolute_error: 5.6958 - val_loss: 54.3066 - val_mean_absolute_error: 5.9638
# Epoch 116/500
# 1/1 [==============================] - 0s 53ms/step - loss: 53.4824 - mean_absolute_error: 5.6954 - val_loss: 54.3020 - val_mean_absolute_error: 5.9633
# Epoch 117/500
# 1/1 [==============================] - 0s 52ms/step - loss: 53.4693 - mean_absolute_error: 5.6956 - val_loss: 54.2721 - val_mean_absolute_error: 5.9630
# Epoch 118/500
# 1/1 [==============================] - 0s 55ms/step - loss: 53.4707 - mean_absolute_error: 5.6946 - val_loss: 54.2855 - val_mean_absolute_error: 5.9638
# Epoch 119/500
# 1/1 [==============================] - 0s 53ms/step - loss: 53.4923 - mean_absolute_error: 5.6944 - val_loss: 54.2993 - val_mean_absolute_error: 5.9648
# Epoch 120/500
# 1/1 [==============================] - 0s 53ms/step - loss: 53.4749 - mean_absolute_error: 5.6959 - val_loss: 54.3102 - val_mean_absolute_error: 5.9648
# Epoch 121/500
# 1/1 [==============================] - 0s 52ms/step - loss: 53.4870 - mean_absolute_error: 5.6958 - val_loss: 54.3186 - val_mean_absolute_error: 5.9651
# Epoch 122/500
# 1/1 [==============================] - 0s 52ms/step - loss: 53.4971 - mean_absolute_error: 5.6949 - val_loss: 54.3321 - val_mean_absolute_error: 5.9640
# Epoch 123/500
# 1/1 [==============================] - 0s 57ms/step - loss: 53.5152 - mean_absolute_error: 5.6947 - val_loss: 54.2909 - val_mean_absolute_error: 5.9614
# Epoch 124/500
# 1/1 [==============================] - 0s 58ms/step - loss: 53.5092 - mean_absolute_error: 5.6947 - val_loss: 54.2473 - val_mean_absolute_error: 5.9608
# Epoch 125/500
# 1/1 [==============================] - 0s 52ms/step - loss: 53.4675 - mean_absolute_error: 5.6950 - val_loss: 54.2488 - val_mean_absolute_error: 5.9620
# Epoch 126/500
# 1/1 [==============================] - 0s 53ms/step - loss: 53.4355 - mean_absolute_error: 5.6955 - val_loss: 54.2444 - val_mean_absolute_error: 5.9629
# Epoch 127/500
# 1/1 [==============================] - 0s 54ms/step - loss: 53.4481 - mean_absolute_error: 5.6944 - val_loss: 54.2233 - val_mean_absolute_error: 5.9618
# Epoch 128/500
# 1/1 [==============================] - 0s 51ms/step - loss: 53.4380 - mean_absolute_error: 5.6941 - val_loss: 54.2335 - val_mean_absolute_error: 5.9612
# Epoch 129/500
# 1/1 [==============================] - 0s 53ms/step - loss: 53.4472 - mean_absolute_error: 5.6950 - val_loss: 54.2276 - val_mean_absolute_error: 5.9610
# Epoch 130/500
# 1/1 [==============================] - 0s 52ms/step - loss: 53.4596 - mean_absolute_error: 5.6944 - val_loss: 54.2777 - val_mean_absolute_error: 5.9639
# Epoch 131/500
# 1/1 [==============================] - 0s 52ms/step - loss: 53.4517 - mean_absolute_error: 5.6952 - val_loss: 54.2781 - val_mean_absolute_error: 5.9637
# Epoch 132/500
# 1/1 [==============================] - 0s 56ms/step - loss: 53.4447 - mean_absolute_error: 5.6956 - val_loss: 54.2158 - val_mean_absolute_error: 5.9596
# Epoch 133/500
# 1/1 [==============================] - 0s 54ms/step - loss: 53.4529 - mean_absolute_error: 5.6944 - val_loss: 54.2154 - val_mean_absolute_error: 5.9600
# Epoch 134/500
# 1/1 [==============================] - 0s 51ms/step - loss: 53.4463 - mean_absolute_error: 5.6940 - val_loss: 54.2441 - val_mean_absolute_error: 5.9616
# Epoch 135/500
# 1/1 [==============================] - 0s 52ms/step - loss: 53.4716 - mean_absolute_error: 5.6929 - val_loss: 54.2890 - val_mean_absolute_error: 5.9629
# Epoch 136/500
# 1/1 [==============================] - 0s 52ms/step - loss: 53.4775 - mean_absolute_error: 5.6944 - val_loss: 54.2631 - val_mean_absolute_error: 5.9606
# Epoch 137/500
# 1/1 [==============================] - 0s 53ms/step - loss: 53.4592 - mean_absolute_error: 5.6956 - val_loss: 54.1923 - val_mean_absolute_error: 5.9599
# Epoch 138/500
# 1/1 [==============================] - 0s 51ms/step - loss: 53.4210 - mean_absolute_error: 5.6939 - val_loss: 54.2516 - val_mean_absolute_error: 5.9627
# Epoch 139/500
# 1/1 [==============================] - 0s 52ms/step - loss: 53.4387 - mean_absolute_error: 5.6933 - val_loss: 54.2873 - val_mean_absolute_error: 5.9626
# Epoch 140/500
# 1/1 [==============================] - 0s 53ms/step - loss: 53.4635 - mean_absolute_error: 5.6939 - val_loss: 54.2408 - val_mean_absolute_error: 5.9583
# Epoch 141/500
# 1/1 [==============================] - 0s 52ms/step - loss: 53.4743 - mean_absolute_error: 5.6937 - val_loss: 54.2428 - val_mean_absolute_error: 5.9580
# Epoch 142/500
# 1/1 [==============================] - 0s 52ms/step - loss: 53.4508 - mean_absolute_error: 5.6946 - val_loss: 54.2317 - val_mean_absolute_error: 5.9582
# Epoch 143/500
# 1/1 [==============================] - 0s 51ms/step - loss: 53.4550 - mean_absolute_error: 5.6935 - val_loss: 54.2166 - val_mean_absolute_error: 5.9583
# Epoch 144/500
# 1/1 [==============================] - 0s 70ms/step - loss: 53.4463 - mean_absolute_error: 5.6932 - val_loss: 54.2305 - val_mean_absolute_error: 5.9592
# Epoch 145/500
# 1/1 [==============================] - 0s 54ms/step - loss: 53.4556 - mean_absolute_error: 5.6935 - val_loss: 54.2213 - val_mean_absolute_error: 5.9598
# Epoch 146/500
# 1/1 [==============================] - 0s 54ms/step - loss: 53.4500 - mean_absolute_error: 5.6934 - val_loss: 54.2757 - val_mean_absolute_error: 5.9616
# Epoch 147/500
# 1/1 [==============================] - 0s 59ms/step - loss: 53.4561 - mean_absolute_error: 5.6947 - val_loss: 54.2475 - val_mean_absolute_error: 5.9605
# Epoch 1/500
# 1/1 [==============================] - 1s 724ms/step - loss: 355.6190 - mean_absolute_error: 16.3355 - val_loss: 227.4135 - val_mean_absolute_error: 12.4301
# 1/1 [==============================] - 0s 51ms/step - loss: 60.4205 - mean_absolute_error: 5.7304 - val_loss: 61.0558 - val_mean_absolute_error: 5.9833
# Epoch 38/500
# 1/1 [==============================] - 0s 53ms/step - loss: 60.1585 - mean_absolute_error: 5.7370 - val_loss: 60.4708 - val_mean_absolute_error: 5.9716
# Epoch 39/500
# 1/1 [==============================] - 0s 53ms/step - loss: 59.8941 - mean_absolute_error: 5.7439 - val_loss: 60.1955 - val_mean_absolute_error: 5.9676
# Epoch 40/500
# 1/1 [==============================] - 0s 52ms/step - loss: 59.3596 - mean_absolute_error: 5.7351 - val_loss: 60.4113 - val_mean_absolute_error: 5.9826
# Epoch 41/500
# 1/1 [==============================] - 0s 52ms/step - loss: 59.0833 - mean_absolute_error: 5.7415 - val_loss: 60.5041 - val_mean_absolute_error: 5.9923
# Epoch 42/500
# 1/1 [==============================] - 0s 53ms/step - loss: 58.9601 - mean_absolute_error: 5.7486 - val_loss: 59.8680 - val_mean_absolute_error: 5.9812
# Epoch 43/500
# 1/1 [==============================] - 0s 54ms/step - loss: 58.6040 - mean_absolute_error: 5.7407 - val_loss: 59.0843 - val_mean_absolute_error: 5.9627
# Epoch 44/500
# 1/1 [==============================] - 0s 53ms/step - loss: 58.3633 - mean_absolute_error: 5.7330 - val_loss: 58.6703 - val_mean_absolute_error: 5.9591
# Epoch 45/500
# 1/1 [==============================] - 0s 53ms/step - loss: 58.3011 - mean_absolute_error: 5.7384 - val_loss: 58.5679 - val_mean_absolute_error: 5.9660
# Epoch 46/500
# 1/1 [==============================] - 0s 51ms/step - loss: 58.0788 - mean_absolute_error: 5.7378 - val_loss: 58.7420 - val_mean_absolute_error: 5.9796
# Epoch 47/500
# 1/1 [==============================] - 0s 53ms/step - loss: 57.7829 - mean_absolute_error: 5.7355 - val_loss: 59.0309 - val_mean_absolute_error: 5.9951
# Epoch 48/500
# 1/1 [==============================] - 0s 51ms/step - loss: 57.6575 - mean_absolute_error: 5.7398 - val_loss: 58.9024 - val_mean_absolute_error: 5.9942
# Epoch 49/500
# 1/1 [==============================] - 0s 52ms/step - loss: 57.4916 - mean_absolute_error: 5.7405 - val_loss: 58.4764 - val_mean_absolute_error: 5.9777
# Epoch 50/500
# 1/1 [==============================] - 0s 70ms/step - loss: 57.3714 - mean_absolute_error: 5.7347 - val_loss: 58.1150 - val_mean_absolute_error: 5.9690
# Epoch 51/500
# 1/1 [==============================] - 0s 56ms/step - loss: 57.2899 - mean_absolute_error: 5.7301 - val_loss: 58.0249 - val_mean_absolute_error: 5.9702
# Epoch 52/500
# 1/1 [==============================] - 0s 53ms/step - loss: 57.1575 - mean_absolute_error: 5.7278 - val_loss: 58.1410 - val_mean_absolute_error: 5.9831
# Epoch 53/500
# 1/1 [==============================] - 0s 52ms/step - loss: 56.9631 - mean_absolute_error: 5.7280 - val_loss: 58.2912 - val_mean_absolute_error: 5.9969
# Epoch 54/500
# 1/1 [==============================] - 0s 52ms/step - loss: 56.8203 - mean_absolute_error: 5.7318 - val_loss: 58.1864 - val_mean_absolute_error: 5.9996
# Epoch 55/500
# 1/1 [==============================] - 0s 54ms/step - loss: 56.6858 - mean_absolute_error: 5.7348 - val_loss: 57.8851 - val_mean_absolute_error: 5.9912
# Epoch 56/500
# 1/1 [==============================] - 0s 53ms/step - loss: 56.5908 - mean_absolute_error: 5.7365 - val_loss: 57.6804 - val_mean_absolute_error: 5.9853
# Epoch 57/500
# 1/1 [==============================] - 0s 53ms/step - loss: 56.5559 - mean_absolute_error: 5.7365 - val_loss: 57.6046 - val_mean_absolute_error: 5.9845
# Epoch 58/500
# 1/1 [==============================] - 0s 52ms/step - loss: 56.4494 - mean_absolute_error: 5.7338 - val_loss: 57.6483 - val_mean_absolute_error: 5.9889
# Epoch 59/500
# 1/1 [==============================] - 0s 52ms/step - loss: 56.3474 - mean_absolute_error: 5.7322 - val_loss: 57.6406 - val_mean_absolute_error: 5.9925
# Epoch 60/500
# 1/1 [==============================] - 0s 53ms/step - loss: 56.2646 - mean_absolute_error: 5.7320 - val_loss: 57.5290 - val_mean_absolute_error: 5.9909
# Epoch 61/500
# 1/1 [==============================] - 0s 54ms/step - loss: 56.2090 - mean_absolute_error: 5.7324 - val_loss: 57.4251 - val_mean_absolute_error: 5.9910
# Epoch 62/500
# 1/1 [==============================] - 0s 55ms/step - loss: 56.1763 - mean_absolute_error: 5.7338 - val_loss: 57.4231 - val_mean_absolute_error: 5.9943
# Epoch 63/500
# 1/1 [==============================] - 0s 52ms/step - loss: 56.1089 - mean_absolute_error: 5.7354 - val_loss: 57.4955 - val_mean_absolute_error: 5.9987
# Epoch 64/500
# 1/1 [==============================] - 0s 52ms/step - loss: 56.0386 - mean_absolute_error: 5.7352 - val_loss: 57.4878 - val_mean_absolute_error: 5.9986
# Epoch 65/500
# 1/1 [==============================] - 0s 54ms/step - loss: 55.9921 - mean_absolute_error: 5.7335 - val_loss: 57.3373 - val_mean_absolute_error: 5.9932
# Epoch 66/500
# 1/1 [==============================] - 0s 55ms/step - loss: 55.9441 - mean_absolute_error: 5.7311 - val_loss: 57.1805 - val_mean_absolute_error: 5.9884
# Epoch 67/500
# 1/1 [==============================] - 0s 52ms/step - loss: 55.8935 - mean_absolute_error: 5.7296 - val_loss: 57.1444 - val_mean_absolute_error: 5.9892
# Epoch 68/500
# 1/1 [==============================] - 0s 56ms/step - loss: 55.8135 - mean_absolute_error: 5.7299 - val_loss: 57.2362 - val_mean_absolute_error: 5.9941
# Epoch 69/500
# 1/1 [==============================] - 0s 51ms/step - loss: 55.7781 - mean_absolute_error: 5.7316 - val_loss: 57.3009 - val_mean_absolute_error: 5.9964
# Epoch 70/500
# 1/1 [==============================] - 0s 51ms/step - loss: 55.7961 - mean_absolute_error: 5.7330 - val_loss: 57.2026 - val_mean_absolute_error: 5.9940
# Epoch 71/500
# 1/1 [==============================] - 0s 55ms/step - loss: 55.7597 - mean_absolute_error: 5.7330 - val_loss: 57.0939 - val_mean_absolute_error: 5.9912
# Epoch 72/500
# 1/1 [==============================] - 0s 54ms/step - loss: 55.7181 - mean_absolute_error: 5.7316 - val_loss: 57.0564 - val_mean_absolute_error: 5.9903
# Epoch 73/500
# 1/1 [==============================] - 0s 53ms/step - loss: 55.6687 - mean_absolute_error: 5.7301 - val_loss: 57.0908 - val_mean_absolute_error: 5.9912
# Epoch 74/500
# 1/1 [==============================] - 0s 52ms/step - loss: 55.6692 - mean_absolute_error: 5.7293 - val_loss: 57.0813 - val_mean_absolute_error: 5.9926
# Epoch 75/500
# 1/1 [==============================] - 0s 53ms/step - loss: 55.6446 - mean_absolute_error: 5.7298 - val_loss: 57.0711 - val_mean_absolute_error: 5.9938
# Epoch 76/500
# 1/1 [==============================] - 0s 54ms/step - loss: 55.6232 - mean_absolute_error: 5.7307 - val_loss: 57.0502 - val_mean_absolute_error: 5.9946
# Epoch 77/500
# 1/1 [==============================] - 0s 55ms/step - loss: 55.5733 - mean_absolute_error: 5.7310 - val_loss: 57.0173 - val_mean_absolute_error: 5.9946
# Epoch 78/500
# 1/1 [==============================] - 0s 54ms/step - loss: 55.5140 - mean_absolute_error: 5.7302 - val_loss: 56.9790 - val_mean_absolute_error: 5.9927
# Epoch 79/500
# 1/1 [==============================] - 0s 54ms/step - loss: 55.4912 - mean_absolute_error: 5.7284 - val_loss: 56.9515 - val_mean_absolute_error: 5.9915
# Epoch 80/500
# 1/1 [==============================] - 0s 54ms/step - loss: 55.4841 - mean_absolute_error: 5.7277 - val_loss: 56.9324 - val_mean_absolute_error: 5.9910
# Epoch 81/500
# 1/1 [==============================] - 0s 53ms/step - loss: 55.4772 - mean_absolute_error: 5.7283 - val_loss: 56.9228 - val_mean_absolute_error: 5.9905
# Epoch 82/500
# 1/1 [==============================] - 0s 53ms/step - loss: 55.4802 - mean_absolute_error: 5.7292 - val_loss: 56.8942 - val_mean_absolute_error: 5.9899
# Epoch 83/500
# 1/1 [==============================] - 0s 58ms/step - loss: 55.4626 - mean_absolute_error: 5.7296 - val_loss: 56.8443 - val_mean_absolute_error: 5.9892
# Epoch 84/500
# 1/1 [==============================] - 0s 61ms/step - loss: 55.4258 - mean_absolute_error: 5.7290 - val_loss: 56.8044 - val_mean_absolute_error: 5.9880
# Epoch 85/500
# 1/1 [==============================] - 0s 51ms/step - loss: 55.3978 - mean_absolute_error: 5.7280 - val_loss: 56.8215 - val_mean_absolute_error: 5.9888
# Epoch 86/500
# 1/1 [==============================] - 0s 52ms/step - loss: 55.3877 - mean_absolute_error: 5.7275 - val_loss: 56.8503 - val_mean_absolute_error: 5.9889
# Epoch 87/500
# 1/1 [==============================] - 0s 54ms/step - loss: 55.4070 - mean_absolute_error: 5.7276 - val_loss: 56.8455 - val_mean_absolute_error: 5.9887
# Epoch 88/500
# 1/1 [==============================] - 0s 53ms/step - loss: 55.4008 - mean_absolute_error: 5.7282 - val_loss: 56.8454 - val_mean_absolute_error: 5.9907
# Epoch 89/500
# 1/1 [==============================] - 0s 51ms/step - loss: 55.3594 - mean_absolute_error: 5.7286 - val_loss: 56.8090 - val_mean_absolute_error: 5.9901
# Epoch 90/500
# 1/1 [==============================] - 0s 54ms/step - loss: 55.3343 - mean_absolute_error: 5.7283 - val_loss: 56.7380 - val_mean_absolute_error: 5.9874
# Epoch 91/500
# 1/1 [==============================] - 0s 53ms/step - loss: 55.3183 - mean_absolute_error: 5.7275 - val_loss: 56.6942 - val_mean_absolute_error: 5.9862
# Epoch 92/500
# 1/1 [==============================] - 0s 52ms/step - loss: 55.2971 - mean_absolute_error: 5.7271 - val_loss: 56.7366 - val_mean_absolute_error: 5.9871
# Epoch 93/500
# 1/1 [==============================] - 0s 52ms/step - loss: 55.3127 - mean_absolute_error: 5.7273 - val_loss: 56.7419 - val_mean_absolute_error: 5.9868
# Epoch 94/500
# 1/1 [==============================] - 0s 53ms/step - loss: 55.3208 - mean_absolute_error: 5.7277 - val_loss: 56.7293 - val_mean_absolute_error: 5.9879
# Epoch 95/500
# 1/1 [==============================] - 0s 52ms/step - loss: 55.2867 - mean_absolute_error: 5.7278 - val_loss: 56.7645 - val_mean_absolute_error: 5.9898
# Epoch 96/500
# 1/1 [==============================] - 0s 52ms/step - loss: 55.2808 - mean_absolute_error: 5.7273 - val_loss: 56.7702 - val_mean_absolute_error: 5.9888
# Epoch 97/500
# 1/1 [==============================] - 0s 52ms/step - loss: 55.2893 - mean_absolute_error: 5.7264 - val_loss: 56.7446 - val_mean_absolute_error: 5.9859
# Epoch 98/500
# 1/1 [==============================] - 0s 53ms/step - loss: 55.3051 - mean_absolute_error: 5.7256 - val_loss: 56.7066 - val_mean_absolute_error: 5.9838
# Epoch 99/500
# 1/1 [==============================] - 0s 53ms/step - loss: 55.3007 - mean_absolute_error: 5.7257 - val_loss: 56.6942 - val_mean_absolute_error: 5.9848
# Epoch 100/500
# 1/1 [==============================] - 0s 54ms/step - loss: 55.2726 - mean_absolute_error: 5.7259 - val_loss: 56.7061 - val_mean_absolute_error: 5.9867
# Epoch 101/500
# 1/1 [==============================] - 0s 57ms/step - loss: 55.2542 - mean_absolute_error: 5.7261 - val_loss: 56.6415 - val_mean_absolute_error: 5.9852
# Epoch 102/500
# 1/1 [==============================] - 0s 51ms/step - loss: 55.2349 - mean_absolute_error: 5.7257 - val_loss: 56.7179 - val_mean_absolute_error: 5.9899
# Epoch 103/500
# 1/1 [==============================] - 0s 51ms/step - loss: 55.2279 - mean_absolute_error: 5.7258 - val_loss: 56.7521 - val_mean_absolute_error: 5.9907
# Epoch 104/500
# 1/1 [==============================] - 0s 52ms/step - loss: 55.2423 - mean_absolute_error: 5.7258 - val_loss: 56.7606 - val_mean_absolute_error: 5.9891
# Epoch 105/500
# 1/1 [==============================] - 0s 51ms/step - loss: 55.2629 - mean_absolute_error: 5.7255 - val_loss: 56.7718 - val_mean_absolute_error: 5.9886
# Epoch 106/500
# 1/1 [==============================] - 0s 52ms/step - loss: 55.2678 - mean_absolute_error: 5.7248 - val_loss: 56.7117 - val_mean_absolute_error: 5.9863
# Epoch 107/500
# 1/1 [==============================] - 0s 53ms/step - loss: 55.2601 - mean_absolute_error: 5.7240 - val_loss: 56.7155 - val_mean_absolute_error: 5.9892
# Epoch 108/500
# 1/1 [==============================] - 0s 54ms/step - loss: 55.2240 - mean_absolute_error: 5.7241 - val_loss: 56.7271 - val_mean_absolute_error: 5.9910
# Epoch 109/500
# 1/1 [==============================] - 0s 53ms/step - loss: 55.2152 - mean_absolute_error: 5.7249 - val_loss: 56.6513 - val_mean_absolute_error: 5.9870
# Epoch 110/500
# 1/1 [==============================] - 0s 52ms/step - loss: 55.2106 - mean_absolute_error: 5.7248 - val_loss: 56.6631 - val_mean_absolute_error: 5.9860
# Epoch 111/500
# 1/1 [==============================] - 0s 60ms/step - loss: 55.2263 - mean_absolute_error: 5.7244 - val_loss: 56.7374 - val_mean_absolute_error: 5.9890
# OOS RMSE: 7.27901501100281

# %%
df_test['Prediction'].describe()
# Out:
# count    2005.000000
# mean       16.569618
# std         3.387216
# min         9.071401
# 25%        13.914704
# 50%        16.164001
# 75%        18.843857
# max        25.594593
# Name: Prediction, dtype: float64

# %%
(df_test['Fantasy Points'] - df_test['Prediction']).describe()
# Out:
# count    2005.000000
# mean       -0.047324
# std         7.280677
# min       -20.351245
# 25%        -4.969120
# 50%        -0.346914
# 75%         4.739747
# max        24.927928
# dtype: float64

# %%
(df_test['Fantasy Points'] - df_test['Prediction']).abs().describe()
# Out:
# count    2005.000000
# mean        5.802050
# std         4.396580
# min         0.000989
# 25%         2.294041
# 50%         4.876830
# 75%         8.441216
# max        24.927928
# dtype: float64

# %%
from sklearn.metrics import root_mean_squared_error

root_mean_squared_error(df_test['Fantasy Points'], df_test['Prediction'])
# Out:
# 7.27901501100281

# %%
from sklearn.metrics import mean_absolute_error

mean_absolute_error(df_test['Fantasy Points'], df_test['Prediction'])
# Out:
# 5.802050296564649

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6, 6), dpi=100)

ax = sns.regplot(
    data=df_test,
    x='Prediction',
    y='Fantasy Points',
    scatter_kws={'alpha': 0.10, 'color': sns.color_palette()[1]},
    line_kws={'color': sns.color_palette()[0]},
)

plt.title('Actual Fantasy Points vs. Predicted Fantasy Points')
plt.xlabel('Predicted Fantasy Points Scored')
plt.ylabel('Actual Fantasy Points Scored')

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6, 6), dpi=100)

ax = sns.regplot(
    data=df_test.assign(f=(df_test['Fantasy Points'] - df_test['Prediction'])),
    x='Prediction',
    y='f',
    scatter_kws={'alpha': 0.10, 'color': sns.color_palette()[0]},
    line_kws={'color': sns.color_palette()[3]},
)

plt.title('Residual Plot')
plt.xlabel('Predicted Fantasy Points Scored')
plt.ylabel('Actual Minus Predicted')

plt.show()

# %%
import shap

explainer = shap.DeepExplainer(mod, X_train.to_numpy())

shap_values = explainer(X_train.to_numpy())

shap_values.feature_names = X_train.columns

shap_values.shape
# Out:
# c:\Users\mhugh\anaconda3\envs\clean2\lib\site-packages\shap\explainers\_deep\deep_tf.py:99: UserWarning: Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
#   warnings.warn("Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.")
# c:\Users\mhugh\anaconda3\envs\clean2\lib\site-packages\keras\backend.py:451: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# (1129, 6, 1)

# %%
shap.plots.beeswarm(shap_values[:, :, 0], max_display=None)

# %% [markdown]
# ### Save Predictions

# %%
df_test.to_parquet('../../../data/out_of_sample_predictions/qb.parquet')

print('Done')
# Out:
# Done
