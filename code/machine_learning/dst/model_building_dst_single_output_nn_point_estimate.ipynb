# %%
import pandas as pd

pd.set_option('display.max_columns', 100)

df_mod = pd.read_parquet('../../../data/model_data/model_data_single_output.parquet')

df_mod = df_mod.loc[df_mod['Position'] == 'DST', :].reset_index(drop=True)

df_mod
# Out:
#       Season  Week                   Name Position Team  Fantasy Points  Rank  \
# 0       2020     1          Buffalo Bills      DST  BUF             8.0   NaN
# 1       2020     1    Pittsburgh Steelers      DST  PIT             8.0   NaN
# 2       2020     1       Baltimore Ravens      DST  BAL            15.0   NaN
# 3       2020     1   New England Patriots      DST   NE            11.0   NaN
# 4       2020     1    Philadelphia Eagles      DST  PHI             3.0   NaN
# ...      ...   ...                    ...      ...  ...             ...   ...
# 2011    2023    17     Cincinnati Bengals      DST  CIN             4.0   NaN
# 2012    2023    17          Detroit Lions      DST  DET             6.0   NaN
# 2013    2023    17        New York Giants      DST  NYG            16.0   NaN
# 2014    2023    17      Arizona Cardinals      DST  ARI             2.0   NaN
# 2015    2023    17  Washington Commanders      DST  WAS             1.0   NaN
#
#       Position Rank  Adjusted Passing Yards Projection  \
# 0                 1                                NaN
# 1                 2                                NaN
# 2                 3                                NaN
# 3                 4                                NaN
# 4                 5                                NaN
# ...             ...                                ...
# 2011             28                                NaN
# 2012             29                                NaN
# 2013             30                                NaN
# 2014             31                                NaN
# 2015             32                                NaN
#
#       Adjusted Passing Touchdowns Projection  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 2011                                     NaN
# 2012                                     NaN
# 2013                                     NaN
# 2014                                     NaN
# 2015                                     NaN
#
#       Adjusted Interceptions Projection  Adjusted Rushing Yards Projection  \
# 0                                   NaN                                NaN
# 1                                   NaN                                NaN
# 2                                   NaN                                NaN
# 3                                   NaN                                NaN
# 4                                   NaN                                NaN
# ...                                 ...                                ...
# 2011                                NaN                                NaN
# 2012                                NaN                                NaN
# 2013                                NaN                                NaN
# 2014                                NaN                                NaN
# 2015                                NaN                                NaN
#
#       Adjusted Receiving Yards Projection  Adjusted Receptions Projection  \
# 0                                     NaN                             NaN
# 1                                     NaN                             NaN
# 2                                     NaN                             NaN
# 3                                     NaN                             NaN
# 4                                     NaN                             NaN
# ...                                   ...                             ...
# 2011                                  NaN                             NaN
# 2012                                  NaN                             NaN
# 2013                                  NaN                             NaN
# 2014                                  NaN                             NaN
# 2015                                  NaN                             NaN
#
#       Anytime Touchdown Probability  Location  Team Projected Score  \
# 0                               NaN       1.0                 23.75
# 1                               NaN      -1.0                 25.00
# 2                               NaN       1.0                 27.25
# 3                               NaN       1.0                 24.50
# 4                               NaN      -1.0                 22.00
# ...                             ...       ...                   ...
# 2011                            NaN      -1.0                 19.50
# 2012                            NaN      -1.0                 24.50
# 2013                            NaN       1.0                 18.75
# 2014                            NaN      -1.0                 17.75
# 2015                            NaN       1.0                 17.25
#
#       Opponent Projected Score
# 0                        17.25
# 1                        19.00
# 2                        20.25
# 3                        17.00
# 4                        16.50
# ...                        ...
# 2011                     26.50
# 2012                     29.00
# 2013                     24.75
# 2014                     30.25
# 2015                     31.25
#
# [2016 rows x 18 columns]

# %%
X = df_mod[[
    'Position Rank',
    'Location',
    'Team Projected Score',
    'Opponent Projected Score',
]].copy()

X
# Out:
#       Position Rank  Location  Team Projected Score  Opponent Projected Score
# 0                 1       1.0                 23.75                     17.25
# 1                 2      -1.0                 25.00                     19.00
# 2                 3       1.0                 27.25                     20.25
# 3                 4       1.0                 24.50                     17.00
# 4                 5      -1.0                 22.00                     16.50
# ...             ...       ...                   ...                       ...
# 2011             28      -1.0                 19.50                     26.50
# 2012             29      -1.0                 24.50                     29.00
# 2013             30       1.0                 18.75                     24.75
# 2014             31      -1.0                 17.75                     30.25
# 2015             32       1.0                 17.25                     31.25
#
# [2016 rows x 4 columns]

# %%
y = df_mod['Fantasy Points'].copy()

y
# Out:
# 0        8.0
# 1        8.0
# 2       15.0
# 3       11.0
# 4        3.0
#         ...
# 2011     4.0
# 2012     6.0
# 2013    16.0
# 2014     2.0
# 2015     1.0
# Name: Fantasy Points, Length: 2016, dtype: float64

# %%
groups = df_mod['Season'].astype(str) + ' Week ' + df_mod['Week'].astype(str)

groups
# Out:
# 0        2020 Week 1
# 1        2020 Week 1
# 2        2020 Week 1
# 3        2020 Week 1
# 4        2020 Week 1
#             ...
# 2011    2023 Week 17
# 2012    2023 Week 17
# 2013    2023 Week 17
# 2014    2023 Week 17
# 2015    2023 Week 17
# Length: 2016, dtype: object

# %%
df_folds = pd.read_parquet('../../../data/model_data/folds.parquet')

df_folds
# Out:
#     Fold ID   Season Week
# 0         0   2022 Week 3
# 1         0   2021 Week 7
# 2         0   2021 Week 1
# 3         0  2023 Week 16
# 4         0  2021 Week 11
# ..      ...           ...
# 62        2  2020 Week 15
# 63        2  2023 Week 14
# 64        2   2021 Week 5
# 65        2   2022 Week 6
# 66        2  2022 Week 12
#
# [67 rows x 2 columns]

# %%
from sklearn.model_selection import GroupShuffleSplit
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

pd.options.mode.chained_assignment = None

# splitter = GroupKFold(n_splits=3)

cv_data = []
# for is_indexes, oos_indexes in splitter.split(X=X, y=y, groups=groups):
for fold in df_folds['Fold ID'].unique():
    oos_season_week = df_folds.loc[df_folds['Fold ID'] == fold, 'Season Week']
    is_indexes = df_mod.loc[~groups.isin(oos_season_week), :].index
    oos_indexes = df_mod.loc[groups.isin(oos_season_week), :].index
    # split
    X_is = X.iloc[is_indexes]
    X_oos = X.iloc[oos_indexes]

    y_is = y.iloc[is_indexes]
    y_oos = y.iloc[oos_indexes]

    groups_is = groups.iloc[is_indexes]
    df_mod_oos = df_mod.iloc[oos_indexes]

    gss = GroupShuffleSplit(n_splits=1, test_size=0.15, random_state=22)
    for train_indexes, val_indexes in gss.split(X=X_is, y=y_is, groups=groups_is):
            X_train = X_is.iloc[train_indexes]
            X_val = X_is.iloc[val_indexes]

            y_train = y_is.iloc[train_indexes]
            y_val = y_is.iloc[val_indexes]

    # impute
    scaler = StandardScaler()
    imputer = IterativeImputer(initial_strategy='median', max_iter=100)

    X_train_fill_na = imputer.fit_transform(scaler.fit_transform(X_train))
    X_train[X_train.columns] = scaler.inverse_transform(X_train_fill_na).copy()

    scaler2 = MinMaxScaler(clip=True)  # maybe normalize and clip instead of standardize?
    scaler3 = StandardScaler()
    X_train[X_train.columns] = scaler3.fit_transform(scaler2.fit_transform(X_train)).copy()

    X_val_fill_na = imputer.transform(scaler.transform(X_val))
    X_val[X_val.columns] = scaler.inverse_transform(X_val_fill_na).copy()

    X_val[X_val.columns] = scaler3.transform(scaler2.transform(X_val)).copy()

    X_oos_fill_na = imputer.transform(scaler.transform(X_oos))
    X_oos[X_oos.columns] = scaler.inverse_transform(X_oos_fill_na).copy()

    X_oos[X_oos.columns] = scaler3.transform(scaler2.transform(X_oos)).copy()

    cv_data.append((X_train, X_val, X_oos, y_train, y_val, y_oos, df_mod_oos))

for X_train, X_val, X_oos, y_train, y_val, y_oos, df_mod_oos in cv_data:
    print(X_train.shape, X_val.shape, X_oos.shape, y_train.shape, y_val.shape, y_oos.shape, df_mod_oos.shape)
# Out:
# (1106, 4) (216, 4) (694, 4) (1106,) (216,) (694,) (694, 18)
# (1156, 4) (212, 4) (648, 4) (1156,) (212,) (648,) (648, 18)
# (1138, 4) (204, 4) (674, 4) (1138,) (204,) (674,) (674, 18)

# %%
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.regularizers import L1L2
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.initializers import GlorotNormal
from tensorflow.config.experimental import enable_op_determinism
from tensorflow.random import set_seed
import numpy as np
import os

os.environ["TF_ENABLE_ONEDNN_OPTS"] = "0"

def build_and_compile_model(input_shape: tuple, hidden_layer_neurons: list, l1s: list, l2s: list, learning_rate: float):
    enable_op_determinism()
    set_seed(22)
    
    inputs = Input(shape=input_shape, name='input')

    h = inputs
    for i, neurons in enumerate(hidden_layer_neurons):
        h = Dense(
            neurons, 
            activation='relu', 
            kernel_initializer=GlorotNormal(seed=22), 
            kernel_regularizer=L1L2(l1=l1s[i], l2=l2s[i]), 
            name=f"hidden_{i+1}"
        )(h)

    outputs = Dense(1, activation=None, kernel_initializer=GlorotNormal(seed=22), name='outputs')(h)

    mod = Model(inputs=inputs, outputs=outputs)

    mod.compile(optimizer=Adam(learning_rate=learning_rate), loss='mean_squared_error', metrics=['mean_absolute_error'])

    return mod

mod = build_and_compile_model(X.shape[1:], [128, 32], [0, 0.01], [0, 0.01], learning_rate=0.001)

mod.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 4)]               0
#
#  hidden_1 (Dense)            (None, 128)               640
#
#  hidden_2 (Dense)            (None, 32)                4128
#
#  outputs (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 4,801
# Trainable params: 4,801
# Non-trainable params: 0
# _________________________________________________________________

# %%
from sklearn.metrics import root_mean_squared_error
import optuna

def objective(trial, cv_data=cv_data):
# model tuning
    n_hidden_layers = trial.suggest_int(f"n_hidden_layers", 1, 3)

    hidden_layer_neurons = []
    l1s = []
    l2s = []
    for i in range(n_hidden_layers):
        hidden_layer_neurons.append(trial.suggest_categorical(f"hidden_layer_{i+1}_neurons", [2**n for n in range(5, 12)]))  # change to (3, 12)
        # hidden_layer_neurons.append(trial.suggest_categorical(f"hidden_layer_{i+1}_neurons", [2**n for n in range(4, 9)]))  # bump this up
        l1s.append(trial.suggest_float(f"hidden_layer_{i+1}_l1", 0.0, 0.1))  # change to (0.0, 0.05)
        l2s.append(trial.suggest_float(f"hidden_layer_{i+1}_l2", 0.0, 0.1))  # change to (0.0, 0.20)

    learning_rate = trial.suggest_float(f"learning_rate", 0.01, 0.10)
    batch_size = trial.suggest_categorical(f"batch_size", [2**n for n in range(10, 16)])
    # batch_size = trial.suggest_categorical(f"batch_size", [2**n for n in range(4, 12)])  # bump this up

    # cross validation
    y_oos_list = []
    y_pred_list = []
    for X_train, X_val, X_oos, y_train, y_val, y_oos, df_mod_oos in cv_data:
        # make sure to build mod in loop to prevent history
        mod = build_and_compile_model(X_train.shape[1:], hidden_layer_neurons, l1s, l2s, learning_rate)

        mod.fit(
            X_train,
            y_train,
            validation_data=(X_val, y_val),
            batch_size=batch_size,
            epochs=500,
            callbacks=[EarlyStopping(patience=10, restore_best_weights=True)],
            verbose=0,
        )

        y_oos_list.append(y_oos)
        y_pred_list.append(mod.predict(X_oos, verbose=0))

    y_oos_concat = np.concatenate(y_oos_list)
    y_pred_concat = np.concatenate(y_pred_list)

    return root_mean_squared_error(y_oos_concat, y_pred_concat)

study = optuna.create_study(direction='minimize', sampler=optuna.samplers.TPESampler(seed=22, n_startup_trials=10, multivariate=True, warn_independent_sampling=False))
study.optimize(objective, n_trials=20, show_progress_bar=True)

study.best_params
# Out:
# c:\Users\mhugh\anaconda3\envs\clean2\lib\site-packages\optuna\_experimental.py:30: ExperimentalWarning: Argument ``multivariate`` is an experimental feature. The interface can change in the future.
#   warnings.warn(
# [I 2024-10-23 16:59:18,439] A new study created in memory with name: no-name-439e97e8-9e59-4f41-b0f0-67d5b3b03dab
#   0%|          | 0/20 [00:00<?, ?it/s]
# [I 2024-10-23 16:59:34,814] Trial 0 finished with value: 5.772438565884545 and parameters: {'n_hidden_layers': 1, 'hidden_layer_1_neurons': 128, 'hidden_layer_1_l1': 0.022040451663772567, 'hidden_layer_1_l2': 0.08119509205386867, 'learning_rate': 0.01094741868844976, 'batch_size': 2048}. Best is trial 0 with value: 5.772438565884545.
# [I 2024-10-23 16:59:40,754] Trial 1 finished with value: 7.968439465899037 and parameters: {'n_hidden_layers': 3, 'hidden_layer_1_neurons': 128, 'hidden_layer_1_l1': 0.058428964315689495, 'hidden_layer_1_l2': 0.07026355188654519, 'hidden_layer_2_neurons': 128, 'hidden_layer_2_l1': 0.08749277452777171, 'hidden_layer_2_l2': 0.07449320773686179, 'hidden_layer_3_neurons': 256, 'hidden_layer_3_l1': 0.009588460991804116, 'hidden_layer_3_l2': 0.004521011190769353, 'learning_rate': 0.07163458468004151, 'batch_size': 1024}. Best is trial 0 with value: 5.772438565884545.
# [I 2024-10-23 16:59:46,658] Trial 2 finished with value: 6.131271090024767 and parameters: {'n_hidden_layers': 2, 'hidden_layer_1_neurons': 64, 'hidden_layer_1_l1': 0.09115369973853776, 'hidden_layer_1_l2': 0.008625567976924198, 'hidden_layer_2_neurons': 2048, 'hidden_layer_2_l1': 0.0005512411903590642, 'hidden_layer_2_l2': 0.03576431697413079, 'learning_rate': 0.09578334240413691, 'batch_size': 1024}. Best is trial 0 with value: 5.772438565884545.
# [I 2024-10-23 16:59:58,307] Trial 3 finished with value: 5.8262246203798185 and parameters: {'n_hidden_layers': 1, 'hidden_layer_1_neurons': 1024, 'hidden_layer_1_l1': 0.08620878124622662, 'hidden_layer_1_l2': 0.06351961895274903, 'learning_rate': 0.07275008619568284, 'batch_size': 4096}. Best is trial 0 with value: 5.772438565884545.
# [I 2024-10-23 17:00:08,765] Trial 4 finished with value: 5.6336804182371445 and parameters: {'n_hidden_layers': 1, 'hidden_layer_1_neurons': 1024, 'hidden_layer_1_l1': 0.02024276263846314, 'hidden_layer_1_l2': 0.08721894394962987, 'learning_rate': 0.06424371980220045, 'batch_size': 1024}. Best is trial 4 with value: 5.6336804182371445.
# [I 2024-10-23 17:00:16,144] Trial 5 finished with value: 5.710749334578276 and parameters: {'n_hidden_layers': 1, 'hidden_layer_1_neurons': 32, 'hidden_layer_1_l1': 0.05653980354893057, 'hidden_layer_1_l2': 0.00345150171194456, 'learning_rate': 0.0885147769978044, 'batch_size': 16384}. Best is trial 4 with value: 5.6336804182371445.
# [I 2024-10-23 17:00:35,338] Trial 6 finished with value: 5.619926341584625 and parameters: {'n_hidden_layers': 3, 'hidden_layer_1_neurons': 256, 'hidden_layer_1_l1': 0.07564442330254927, 'hidden_layer_1_l2': 0.045177882434907994, 'hidden_layer_2_neurons': 64, 'hidden_layer_2_l1': 0.08362472880832089, 'hidden_layer_2_l2': 0.05103829122196473, 'hidden_layer_3_neurons': 128, 'hidden_layer_3_l1': 0.06951388599043494, 'hidden_layer_3_l2': 0.0051964104142108065, 'learning_rate': 0.09447015559422758, 'batch_size': 2048}. Best is trial 6 with value: 5.619926341584625.
# [I 2024-10-23 17:00:47,107] Trial 7 finished with value: 5.627288272381586 and parameters: {'n_hidden_layers': 2, 'hidden_layer_1_neurons': 32, 'hidden_layer_1_l1': 0.08592805490779229, 'hidden_layer_1_l2': 0.0407904418229531, 'hidden_layer_2_neurons': 64, 'hidden_layer_2_l1': 0.025309932195697216, 'hidden_layer_2_l2': 0.03508986025005804, 'learning_rate': 0.06905762708317247, 'batch_size': 1024}. Best is trial 6 with value: 5.619926341584625.
# [I 2024-10-23 17:00:54,989] Trial 8 finished with value: 5.662338781307277 and parameters: {'n_hidden_layers': 1, 'hidden_layer_1_neurons': 32, 'hidden_layer_1_l1': 0.004671699281628905, 'hidden_layer_1_l2': 0.056923526796298245, 'learning_rate': 0.09827798409489276, 'batch_size': 1024}. Best is trial 6 with value: 5.619926341584625.
# [I 2024-10-23 17:01:08,054] Trial 9 finished with value: 5.605584849159052 and parameters: {'n_hidden_layers': 2, 'hidden_layer_1_neurons': 256, 'hidden_layer_1_l1': 0.0004424057058423636, 'hidden_layer_1_l2': 0.06813144847420316, 'hidden_layer_2_neurons': 64, 'hidden_layer_2_l1': 0.08249019408071431, 'hidden_layer_2_l2': 0.04359087388902699, 'learning_rate': 0.05221946484311475, 'batch_size': 1024}. Best is trial 9 with value: 5.605584849159052.
# [I 2024-10-23 17:01:28,834] Trial 10 finished with value: 5.630440187381987 and parameters: {'n_hidden_layers': 2, 'hidden_layer_1_neurons': 256, 'hidden_layer_1_l1': 0.015560058030578486, 'hidden_layer_1_l2': 0.05773223896110166, 'hidden_layer_2_neurons': 1024, 'hidden_layer_2_l1': 0.05373204078200579, 'hidden_layer_2_l2': 0.003761145103296247, 'learning_rate': 0.07600810471055386, 'batch_size': 16384}. Best is trial 9 with value: 5.605584849159052.
# [I 2024-10-23 17:01:43,197] Trial 11 finished with value: 5.604530867792031 and parameters: {'n_hidden_layers': 2, 'hidden_layer_1_neurons': 256, 'hidden_layer_1_l1': 0.016031351072220416, 'hidden_layer_1_l2': 0.07542542291704282, 'hidden_layer_2_neurons': 64, 'hidden_layer_2_l1': 0.09865311357332089, 'hidden_layer_2_l2': 0.05806487655603816, 'learning_rate': 0.03800967715506095, 'batch_size': 1024}. Best is trial 11 with value: 5.604530867792031.
# [I 2024-10-23 17:01:55,366] Trial 12 finished with value: 5.644339608516382 and parameters: {'n_hidden_layers': 2, 'hidden_layer_1_neurons': 256, 'hidden_layer_1_l1': 0.013588346667710973, 'hidden_layer_1_l2': 0.07142120627122168, 'hidden_layer_2_neurons': 512, 'hidden_layer_2_l1': 0.0967473509400038, 'hidden_layer_2_l2': 0.09853393954442466, 'learning_rate': 0.032711712185607325, 'batch_size': 1024}. Best is trial 11 with value: 5.604530867792031.
# [I 2024-10-23 17:02:02,082] Trial 13 finished with value: 8.75457885922372 and parameters: {'n_hidden_layers': 2, 'hidden_layer_1_neurons': 2048, 'hidden_layer_1_l1': 0.0069503843099517505, 'hidden_layer_1_l2': 0.017191923533194813, 'hidden_layer_2_neurons': 256, 'hidden_layer_2_l1': 0.06569121217127738, 'hidden_layer_2_l2': 0.06316678461644015, 'learning_rate': 0.047322333542419985, 'batch_size': 1024}. Best is trial 11 with value: 5.604530867792031.
# [I 2024-10-23 17:02:25,010] Trial 14 finished with value: 5.622495267028847 and parameters: {'n_hidden_layers': 3, 'hidden_layer_1_neurons': 32, 'hidden_layer_1_l1': 0.036400808783969535, 'hidden_layer_1_l2': 0.07562943478566286, 'hidden_layer_2_neurons': 32, 'hidden_layer_2_l1': 0.09664214772410011, 'hidden_layer_2_l2': 0.050256806449131435, 'hidden_layer_3_neurons': 64, 'hidden_layer_3_l1': 0.09731969475085098, 'hidden_layer_3_l2': 0.09937697813181728, 'learning_rate': 0.03278355900717601, 'batch_size': 8192}. Best is trial 11 with value: 5.604530867792031.
# [I 2024-10-23 17:02:44,607] Trial 15 finished with value: 5.625921546687147 and parameters: {'n_hidden_layers': 2, 'hidden_layer_1_neurons': 128, 'hidden_layer_1_l1': 0.01758467633015904, 'hidden_layer_1_l2': 0.06178592818962292, 'hidden_layer_2_neurons': 64, 'hidden_layer_2_l1': 0.0664317621863379, 'hidden_layer_2_l2': 0.02436572765649924, 'learning_rate': 0.049452786146694024, 'batch_size': 32768}. Best is trial 11 with value: 5.604530867792031.
# [I 2024-10-23 17:02:54,857] Trial 16 finished with value: 5.625980502329847 and parameters: {'n_hidden_layers': 1, 'hidden_layer_1_neurons': 256, 'hidden_layer_1_l1': 0.044053776163744986, 'hidden_layer_1_l2': 0.036197728930330166, 'learning_rate': 0.034158127096796956, 'batch_size': 1024}. Best is trial 11 with value: 5.604530867792031.
# [I 2024-10-23 17:03:03,552] Trial 17 finished with value: 5.769257909583969 and parameters: {'n_hidden_layers': 1, 'hidden_layer_1_neurons': 256, 'hidden_layer_1_l1': 0.00029849308925126213, 'hidden_layer_1_l2': 0.05998142282304684, 'learning_rate': 0.05029604918075895, 'batch_size': 8192}. Best is trial 11 with value: 5.604530867792031.
# [I 2024-10-23 17:03:20,892] Trial 18 finished with value: 5.624859048515407 and parameters: {'n_hidden_layers': 3, 'hidden_layer_1_neurons': 256, 'hidden_layer_1_l1': 0.03919816565924614, 'hidden_layer_1_l2': 0.048057429507968666, 'hidden_layer_2_neurons': 64, 'hidden_layer_2_l1': 0.09954337524183104, 'hidden_layer_2_l2': 0.07340797715744085, 'hidden_layer_3_neurons': 512, 'hidden_layer_3_l1': 0.04348376756308598, 'hidden_layer_3_l2': 0.05496871932868526, 'learning_rate': 0.022498246687584992, 'batch_size': 4096}. Best is trial 11 with value: 5.604530867792031.
# [I 2024-10-23 17:03:26,760] Trial 19 finished with value: 6.010080204790636 and parameters: {'n_hidden_layers': 2, 'hidden_layer_1_neurons': 256, 'hidden_layer_1_l1': 0.06248696502509928, 'hidden_layer_1_l2': 0.09166160025418012, 'hidden_layer_2_neurons': 64, 'hidden_layer_2_l1': 0.042431725505474464, 'hidden_layer_2_l2': 0.05339728936129376, 'learning_rate': 0.06314151642587847, 'batch_size': 2048}. Best is trial 11 with value: 5.604530867792031.
# {'n_hidden_layers': 2,
#  'hidden_layer_1_neurons': 256,
#  'hidden_layer_1_l1': 0.016031351072220416,
#  'hidden_layer_1_l2': 0.07542542291704282,
#  'hidden_layer_2_neurons': 64,
#  'hidden_layer_2_l1': 0.09865311357332089,
#  'hidden_layer_2_l2': 0.05806487655603816,
#  'learning_rate': 0.03800967715506095,
#  'batch_size': 1024}

# %% [markdown]
# 5.604530867792031

# %%
n_hidden_layers = study.best_params['n_hidden_layers']

hidden_layer_neurons = []
l1s = []
l2s = []
for i in range(n_hidden_layers):
    hidden_layer_neurons.append(study.best_params[f"hidden_layer_{i+1}_neurons"])
    l1s.append(study.best_params[f"hidden_layer_{i+1}_l1"])
    l2s.append(study.best_params[f"hidden_layer_{i+1}_l2"])

learning_rate = study.best_params[f"learning_rate"]
batch_size = study.best_params[f"batch_size"]

y_oos_list = []
y_pred_list = []
testing_data = []
for X_train, X_val, X_oos, y_train, y_val, y_oos, df_mod_oos in cv_data:
    # make sure to build mod in loop to prevent history
    mod = build_and_compile_model(X_train.shape[1:], hidden_layer_neurons, l1s, l2s, learning_rate)

    mod.fit(
        X_train,
        y_train,
        validation_data=(X_val, y_val),
        batch_size=batch_size,
        epochs=500,
        callbacks=[EarlyStopping(patience=10, restore_best_weights=True)],
        verbose=1,
    )

    y_preds = mod.predict(X_oos, verbose=0)

    df_preds = pd.DataFrame(
        y_preds,
        columns=['Prediction']
    )

    testing_data.append(pd.concat((df_mod_oos.reset_index(drop=True), df_preds), axis=1))


    y_oos_list.append(y_oos)
    y_pred_list.append(y_preds)

df_test = pd.concat(testing_data, ignore_index=True)

y_oos_concat = np.concatenate(y_oos_list)
y_pred_concat = np.concatenate(y_pred_list)

print(f"OOS RMSE: {root_mean_squared_error(y_oos_concat, y_pred_concat)}")
# Out:
# Epoch 1/500
# 2/2 [==============================] - 1s 323ms/step - loss: 188.6583 - mean_absolute_error: 6.8804 - val_loss: 88.0716 - val_mean_absolute_error: 3.8649
# Epoch 2/500
# 2/2 [==============================] - 0s 48ms/step - loss: 96.1160 - mean_absolute_error: 4.4842 - val_loss: 79.2096 - val_mean_absolute_error: 4.1049
# Epoch 3/500
# 2/2 [==============================] - 0s 48ms/step - loss: 84.1819 - mean_absolute_error: 4.4942 - val_loss: 82.0754 - val_mean_absolute_error: 4.4240
# Epoch 4/500
# 2/2 [==============================] - 0s 48ms/step - loss: 86.9790 - mean_absolute_error: 4.5565 - val_loss: 70.7970 - val_mean_absolute_error: 3.9411
# Epoch 5/500
# 2/2 [==============================] - 0s 49ms/step - loss: 75.5590 - mean_absolute_error: 4.2558 - val_loss: 64.4644 - val_mean_absolute_error: 4.1063
# Epoch 6/500
# 2/2 [==============================] - 0s 50ms/step - loss: 69.1196 - mean_absolute_error: 4.4908 - val_loss: 60.0323 - val_mean_absolute_error: 4.1822
# Epoch 7/500
# 2/2 [==============================] - 0s 50ms/step - loss: 64.6464 - mean_absolute_error: 4.5648 - val_loss: 55.2545 - val_mean_absolute_error: 3.8893
# Epoch 8/500
# 2/2 [==============================] - 0s 50ms/step - loss: 60.2863 - mean_absolute_error: 4.3373 - val_loss: 53.8164 - val_mean_absolute_error: 3.8507
# Epoch 9/500
# 2/2 [==============================] - 0s 50ms/step - loss: 58.7701 - mean_absolute_error: 4.2732 - val_loss: 50.4948 - val_mean_absolute_error: 3.8430
# Epoch 10/500
# 2/2 [==============================] - 0s 50ms/step - loss: 55.1374 - mean_absolute_error: 4.2379 - val_loss: 49.3899 - val_mean_absolute_error: 4.0332
# Epoch 11/500
# 2/2 [==============================] - 0s 50ms/step - loss: 53.5089 - mean_absolute_error: 4.3946 - val_loss: 47.2882 - val_mean_absolute_error: 3.9833
# Epoch 12/500
# 2/2 [==============================] - 0s 49ms/step - loss: 51.7739 - mean_absolute_error: 4.4093 - val_loss: 46.2201 - val_mean_absolute_error: 3.9023
# Epoch 13/500
# 2/2 [==============================] - 0s 51ms/step - loss: 51.5626 - mean_absolute_error: 4.2560 - val_loss: 44.2923 - val_mean_absolute_error: 3.8619
# Epoch 14/500
# 2/2 [==============================] - 0s 49ms/step - loss: 49.2794 - mean_absolute_error: 4.2211 - val_loss: 46.0225 - val_mean_absolute_error: 4.2608
# Epoch 15/500
# 2/2 [==============================] - 0s 48ms/step - loss: 50.5910 - mean_absolute_error: 4.7074 - val_loss: 44.4576 - val_mean_absolute_error: 4.2335
# Epoch 16/500
# 2/2 [==============================] - 0s 50ms/step - loss: 48.3251 - mean_absolute_error: 4.6042 - val_loss: 44.2250 - val_mean_absolute_error: 3.9881
# Epoch 17/500
# 2/2 [==============================] - 0s 49ms/step - loss: 49.2246 - mean_absolute_error: 4.2626 - val_loss: 44.0865 - val_mean_absolute_error: 3.9847
# Epoch 18/500
# 2/2 [==============================] - 0s 61ms/step - loss: 48.6545 - mean_absolute_error: 4.2577 - val_loss: 42.2793 - val_mean_absolute_error: 4.1004
# Epoch 19/500
# 2/2 [==============================] - 0s 50ms/step - loss: 46.5504 - mean_absolute_error: 4.5364 - val_loss: 40.8225 - val_mean_absolute_error: 4.0196
# Epoch 20/500
# 2/2 [==============================] - 0s 49ms/step - loss: 44.9135 - mean_absolute_error: 4.4235 - val_loss: 41.0075 - val_mean_absolute_error: 3.8825
# Epoch 21/500
# 2/2 [==============================] - 0s 48ms/step - loss: 45.6727 - mean_absolute_error: 4.2017 - val_loss: 41.1046 - val_mean_absolute_error: 3.9358
# Epoch 22/500
# 2/2 [==============================] - 0s 50ms/step - loss: 45.4390 - mean_absolute_error: 4.2089 - val_loss: 39.4548 - val_mean_absolute_error: 3.9419
# Epoch 23/500
# 2/2 [==============================] - 0s 48ms/step - loss: 43.1654 - mean_absolute_error: 4.2651 - val_loss: 40.0744 - val_mean_absolute_error: 4.0620
# Epoch 24/500
# 2/2 [==============================] - 0s 51ms/step - loss: 43.3580 - mean_absolute_error: 4.3711 - val_loss: 38.5121 - val_mean_absolute_error: 3.8674
# Epoch 25/500
# 2/2 [==============================] - 0s 49ms/step - loss: 43.0253 - mean_absolute_error: 4.2056 - val_loss: 38.7020 - val_mean_absolute_error: 3.8733
# Epoch 26/500
# 2/2 [==============================] - 0s 51ms/step - loss: 43.6406 - mean_absolute_error: 4.2140 - val_loss: 37.2057 - val_mean_absolute_error: 3.8749
# Epoch 27/500
# 2/2 [==============================] - 0s 50ms/step - loss: 42.1145 - mean_absolute_error: 4.2440 - val_loss: 37.1242 - val_mean_absolute_error: 3.9518
# Epoch 28/500
# 2/2 [==============================] - 0s 49ms/step - loss: 41.7267 - mean_absolute_error: 4.3292 - val_loss: 37.4916 - val_mean_absolute_error: 4.0133
# Epoch 29/500
# 2/2 [==============================] - 0s 48ms/step - loss: 41.6904 - mean_absolute_error: 4.3999 - val_loss: 37.1484 - val_mean_absolute_error: 3.9198
# Epoch 30/500
# 2/2 [==============================] - 0s 50ms/step - loss: 41.3023 - mean_absolute_error: 4.2883 - val_loss: 37.0629 - val_mean_absolute_error: 3.8298
# Epoch 31/500
# 2/2 [==============================] - 0s 51ms/step - loss: 41.8462 - mean_absolute_error: 4.1992 - val_loss: 36.3666 - val_mean_absolute_error: 3.8227
# Epoch 32/500
# 2/2 [==============================] - 0s 50ms/step - loss: 41.3656 - mean_absolute_error: 4.2093 - val_loss: 36.4567 - val_mean_absolute_error: 3.9802
# Epoch 33/500
# 2/2 [==============================] - 0s 49ms/step - loss: 41.3982 - mean_absolute_error: 4.4266 - val_loss: 38.0460 - val_mean_absolute_error: 4.2082
# Epoch 34/500
# 2/2 [==============================] - 0s 49ms/step - loss: 42.8208 - mean_absolute_error: 4.6387 - val_loss: 35.8198 - val_mean_absolute_error: 3.9245
# Epoch 35/500
# 2/2 [==============================] - 0s 48ms/step - loss: 40.7679 - mean_absolute_error: 4.3535 - val_loss: 36.7359 - val_mean_absolute_error: 3.8309
# Epoch 36/500
# 2/2 [==============================] - 0s 49ms/step - loss: 42.0665 - mean_absolute_error: 4.2098 - val_loss: 36.6440 - val_mean_absolute_error: 3.8397
# Epoch 37/500
# 2/2 [==============================] - 0s 51ms/step - loss: 41.7683 - mean_absolute_error: 4.2065 - val_loss: 35.8159 - val_mean_absolute_error: 3.9081
# Epoch 38/500
# 2/2 [==============================] - 0s 49ms/step - loss: 40.5654 - mean_absolute_error: 4.3297 - val_loss: 36.6572 - val_mean_absolute_error: 3.9919
# Epoch 39/500
# 2/2 [==============================] - 0s 50ms/step - loss: 40.9592 - mean_absolute_error: 4.3859 - val_loss: 35.6401 - val_mean_absolute_error: 3.8413
# Epoch 40/500
# 2/2 [==============================] - 0s 51ms/step - loss: 40.4095 - mean_absolute_error: 4.2247 - val_loss: 35.6368 - val_mean_absolute_error: 3.8241
# Epoch 41/500
# 2/2 [==============================] - 0s 49ms/step - loss: 40.6003 - mean_absolute_error: 4.2060 - val_loss: 35.2478 - val_mean_absolute_error: 3.8642
# Epoch 42/500
# 2/2 [==============================] - 0s 49ms/step - loss: 40.2926 - mean_absolute_error: 4.2878 - val_loss: 35.7896 - val_mean_absolute_error: 3.9822
# Epoch 43/500
# 2/2 [==============================] - 0s 48ms/step - loss: 40.6480 - mean_absolute_error: 4.4158 - val_loss: 35.3200 - val_mean_absolute_error: 3.9265
# Epoch 44/500
# 2/2 [==============================] - 0s 49ms/step - loss: 40.0412 - mean_absolute_error: 4.3525 - val_loss: 35.5708 - val_mean_absolute_error: 3.8563
# Epoch 45/500
# 2/2 [==============================] - 0s 49ms/step - loss: 40.2148 - mean_absolute_error: 4.2628 - val_loss: 35.4496 - val_mean_absolute_error: 3.8641
# Epoch 46/500
# 2/2 [==============================] - 0s 49ms/step - loss: 39.9155 - mean_absolute_error: 4.2705 - val_loss: 35.3124 - val_mean_absolute_error: 3.8887
# Epoch 47/500
# 2/2 [==============================] - 0s 48ms/step - loss: 39.6585 - mean_absolute_error: 4.2889 - val_loss: 35.6083 - val_mean_absolute_error: 3.8745
# Epoch 48/500
# 2/2 [==============================] - 0s 48ms/step - loss: 39.9687 - mean_absolute_error: 4.2654 - val_loss: 35.4166 - val_mean_absolute_error: 3.8715
# Epoch 49/500
# 2/2 [==============================] - 0s 48ms/step - loss: 39.7687 - mean_absolute_error: 4.2604 - val_loss: 35.3407 - val_mean_absolute_error: 3.8669
# Epoch 50/500
# 2/2 [==============================] - 0s 49ms/step - loss: 39.7267 - mean_absolute_error: 4.2573 - val_loss: 35.3112 - val_mean_absolute_error: 3.8596
# Epoch 51/500
# 2/2 [==============================] - 0s 50ms/step - loss: 39.7557 - mean_absolute_error: 4.2496 - val_loss: 35.1271 - val_mean_absolute_error: 3.8644
# Epoch 52/500
# 2/2 [==============================] - 0s 48ms/step - loss: 39.6286 - mean_absolute_error: 4.2525 - val_loss: 35.1571 - val_mean_absolute_error: 3.8415
# Epoch 53/500
# 2/2 [==============================] - 0s 51ms/step - loss: 39.8425 - mean_absolute_error: 4.2246 - val_loss: 35.0770 - val_mean_absolute_error: 3.8493
# Epoch 54/500
# 2/2 [==============================] - 0s 49ms/step - loss: 39.7860 - mean_absolute_error: 4.2342 - val_loss: 35.0870 - val_mean_absolute_error: 3.8994
# Epoch 55/500
# 2/2 [==============================] - 0s 48ms/step - loss: 39.6854 - mean_absolute_error: 4.2856 - val_loss: 35.5251 - val_mean_absolute_error: 3.9903
# Epoch 56/500
# 2/2 [==============================] - 0s 49ms/step - loss: 39.9605 - mean_absolute_error: 4.3834 - val_loss: 35.8939 - val_mean_absolute_error: 4.0352
# Epoch 57/500
# 2/2 [==============================] - 0s 48ms/step - loss: 40.1810 - mean_absolute_error: 4.4102 - val_loss: 35.2283 - val_mean_absolute_error: 3.9209
# Epoch 58/500
# 2/2 [==============================] - 0s 48ms/step - loss: 39.7429 - mean_absolute_error: 4.2929 - val_loss: 35.2839 - val_mean_absolute_error: 3.9320
# Epoch 59/500
# 2/2 [==============================] - 0s 48ms/step - loss: 39.6626 - mean_absolute_error: 4.3035 - val_loss: 36.0746 - val_mean_absolute_error: 4.0181
# Epoch 60/500
# 2/2 [==============================] - 0s 48ms/step - loss: 40.2383 - mean_absolute_error: 4.3853 - val_loss: 35.4890 - val_mean_absolute_error: 3.9732
# Epoch 61/500
# 2/2 [==============================] - 0s 49ms/step - loss: 39.8205 - mean_absolute_error: 4.3527 - val_loss: 35.3501 - val_mean_absolute_error: 3.9737
# Epoch 62/500
# 2/2 [==============================] - 0s 48ms/step - loss: 39.6705 - mean_absolute_error: 4.3678 - val_loss: 35.3225 - val_mean_absolute_error: 3.9079
# Epoch 63/500
# 2/2 [==============================] - 0s 50ms/step - loss: 39.7949 - mean_absolute_error: 4.3016 - val_loss: 35.0392 - val_mean_absolute_error: 3.8479
# Epoch 64/500
# 2/2 [==============================] - 0s 49ms/step - loss: 39.6923 - mean_absolute_error: 4.2388 - val_loss: 35.3513 - val_mean_absolute_error: 3.9203
# Epoch 65/500
# 2/2 [==============================] - 0s 50ms/step - loss: 39.8016 - mean_absolute_error: 4.3429 - val_loss: 35.7575 - val_mean_absolute_error: 3.9374
# Epoch 66/500
# 2/2 [==============================] - 0s 49ms/step - loss: 40.0219 - mean_absolute_error: 4.3524 - val_loss: 35.5904 - val_mean_absolute_error: 3.8245
# Epoch 67/500
# 2/2 [==============================] - 0s 48ms/step - loss: 40.3086 - mean_absolute_error: 4.2136 - val_loss: 36.4761 - val_mean_absolute_error: 3.8450
# Epoch 68/500
# 2/2 [==============================] - 0s 59ms/step - loss: 41.3389 - mean_absolute_error: 4.2018 - val_loss: 35.2774 - val_mean_absolute_error: 3.8647
# Epoch 69/500
# 2/2 [==============================] - 0s 48ms/step - loss: 39.9014 - mean_absolute_error: 4.2859 - val_loss: 36.8640 - val_mean_absolute_error: 4.0738
# Epoch 70/500
# 2/2 [==============================] - 0s 50ms/step - loss: 40.8951 - mean_absolute_error: 4.4745 - val_loss: 35.3571 - val_mean_absolute_error: 3.8997
# Epoch 71/500
# 2/2 [==============================] - 0s 49ms/step - loss: 39.7516 - mean_absolute_error: 4.2964 - val_loss: 35.3536 - val_mean_absolute_error: 3.8407
# Epoch 72/500
# 2/2 [==============================] - 0s 50ms/step - loss: 40.0400 - mean_absolute_error: 4.2172 - val_loss: 35.3289 - val_mean_absolute_error: 3.8778
# Epoch 73/500
# 2/2 [==============================] - 0s 60ms/step - loss: 39.7974 - mean_absolute_error: 4.2611 - val_loss: 35.9802 - val_mean_absolute_error: 4.0134
# Epoch 1/500
# 2/2 [==============================] - 1s 510ms/step - loss: 181.6137 - mean_absolute_error: 6.6985 - val_loss: 95.3425 - val_mean_absolute_error: 4.5494
# Epoch 2/500
# 2/2 [==============================] - 0s 47ms/step - loss: 95.8844 - mean_absolute_error: 4.5505 - val_loss: 81.6463 - val_mean_absolute_error: 4.4070
# Epoch 3/500
# 2/2 [==============================] - 0s 47ms/step - loss: 81.0451 - mean_absolute_error: 4.2913 - val_loss: 85.8132 - val_mean_absolute_error: 4.7837
# Epoch 4/500
# 2/2 [==============================] - 0s 52ms/step - loss: 84.2255 - mean_absolute_error: 4.4705 - val_loss: 74.5014 - val_mean_absolute_error: 4.3664
# Epoch 5/500
# 2/2 [==============================] - 0s 53ms/step - loss: 74.2097 - mean_absolute_error: 4.2567 - val_loss: 66.2216 - val_mean_absolute_error: 4.3111
# Epoch 6/500
# 2/2 [==============================] - 0s 52ms/step - loss: 67.7999 - mean_absolute_error: 4.4611 - val_loss: 60.5391 - val_mean_absolute_error: 4.1843
# Epoch 7/500
# 2/2 [==============================] - 0s 49ms/step - loss: 61.3395 - mean_absolute_error: 4.2205 - val_loss: 59.3542 - val_mean_absolute_error: 4.2250
# Epoch 8/500
# 2/2 [==============================] - 0s 47ms/step - loss: 59.3993 - mean_absolute_error: 4.1850 - val_loss: 56.6274 - val_mean_absolute_error: 4.2663
# Epoch 9/500
# 2/2 [==============================] - 0s 51ms/step - loss: 56.6256 - mean_absolute_error: 4.2428 - val_loss: 53.3772 - val_mean_absolute_error: 4.2595
# Epoch 10/500
# 2/2 [==============================] - 0s 50ms/step - loss: 53.5447 - mean_absolute_error: 4.2241 - val_loss: 50.8185 - val_mean_absolute_error: 4.2097
# Epoch 11/500
# 2/2 [==============================] - 0s 51ms/step - loss: 51.3266 - mean_absolute_error: 4.1617 - val_loss: 48.3432 - val_mean_absolute_error: 4.1544
# Epoch 12/500
# 2/2 [==============================] - 0s 51ms/step - loss: 49.2481 - mean_absolute_error: 4.1765 - val_loss: 46.5780 - val_mean_absolute_error: 4.2235
# Epoch 13/500
# 2/2 [==============================] - 0s 50ms/step - loss: 47.9533 - mean_absolute_error: 4.3157 - val_loss: 44.9169 - val_mean_absolute_error: 4.1784
# Epoch 14/500
# 2/2 [==============================] - 0s 49ms/step - loss: 46.0441 - mean_absolute_error: 4.2272 - val_loss: 44.9340 - val_mean_absolute_error: 4.1968
# Epoch 15/500
# 2/2 [==============================] - 0s 51ms/step - loss: 45.5388 - mean_absolute_error: 4.1440 - val_loss: 43.5182 - val_mean_absolute_error: 4.2612
# Epoch 16/500
# 2/2 [==============================] - 0s 51ms/step - loss: 44.7804 - mean_absolute_error: 4.3769 - val_loss: 42.4697 - val_mean_absolute_error: 4.1556
# Epoch 17/500
# 2/2 [==============================] - 0s 55ms/step - loss: 43.5484 - mean_absolute_error: 4.1516 - val_loss: 41.8778 - val_mean_absolute_error: 4.1440
# Epoch 18/500
# 2/2 [==============================] - 0s 52ms/step - loss: 43.1910 - mean_absolute_error: 4.1960 - val_loss: 40.1507 - val_mean_absolute_error: 4.1684
# Epoch 19/500
# 2/2 [==============================] - 0s 50ms/step - loss: 41.8593 - mean_absolute_error: 4.2518 - val_loss: 39.7698 - val_mean_absolute_error: 4.1640
# Epoch 20/500
# 2/2 [==============================] - 0s 51ms/step - loss: 41.3410 - mean_absolute_error: 4.2526 - val_loss: 39.6575 - val_mean_absolute_error: 4.1656
# Epoch 21/500
# 2/2 [==============================] - 0s 49ms/step - loss: 41.1681 - mean_absolute_error: 4.2335 - val_loss: 39.0956 - val_mean_absolute_error: 4.1417
# Epoch 22/500
# 2/2 [==============================] - 0s 52ms/step - loss: 40.5392 - mean_absolute_error: 4.1923 - val_loss: 38.8556 - val_mean_absolute_error: 4.2519
# Epoch 23/500
# 2/2 [==============================] - 0s 51ms/step - loss: 40.8849 - mean_absolute_error: 4.3940 - val_loss: 38.4194 - val_mean_absolute_error: 4.1704
# Epoch 24/500
# 2/2 [==============================] - 0s 49ms/step - loss: 40.0198 - mean_absolute_error: 4.2735 - val_loss: 40.0789 - val_mean_absolute_error: 4.1888
# Epoch 25/500
# 2/2 [==============================] - 0s 51ms/step - loss: 41.1410 - mean_absolute_error: 4.1645 - val_loss: 38.3680 - val_mean_absolute_error: 4.1531
# Epoch 26/500
# 2/2 [==============================] - 0s 51ms/step - loss: 39.7802 - mean_absolute_error: 4.2152 - val_loss: 37.9836 - val_mean_absolute_error: 4.1483
# Epoch 27/500
# 2/2 [==============================] - 0s 51ms/step - loss: 39.4586 - mean_absolute_error: 4.2104 - val_loss: 37.8587 - val_mean_absolute_error: 4.1941
# Epoch 28/500
# 2/2 [==============================] - 0s 50ms/step - loss: 39.4896 - mean_absolute_error: 4.3092 - val_loss: 37.6648 - val_mean_absolute_error: 4.1726
# Epoch 29/500
# 2/2 [==============================] - 0s 49ms/step - loss: 39.2448 - mean_absolute_error: 4.2600 - val_loss: 38.1864 - val_mean_absolute_error: 4.2469
# Epoch 30/500
# 2/2 [==============================] - 0s 50ms/step - loss: 39.7844 - mean_absolute_error: 4.3748 - val_loss: 37.4787 - val_mean_absolute_error: 4.1895
# Epoch 31/500
# 2/2 [==============================] - 0s 51ms/step - loss: 39.0326 - mean_absolute_error: 4.2824 - val_loss: 37.2179 - val_mean_absolute_error: 4.1375
# Epoch 32/500
# 2/2 [==============================] - 0s 49ms/step - loss: 38.9735 - mean_absolute_error: 4.2282 - val_loss: 37.3600 - val_mean_absolute_error: 4.1310
# Epoch 33/500
# 2/2 [==============================] - 0s 50ms/step - loss: 38.9070 - mean_absolute_error: 4.1925 - val_loss: 38.1110 - val_mean_absolute_error: 4.3464
# Epoch 34/500
# 2/2 [==============================] - 0s 48ms/step - loss: 40.0493 - mean_absolute_error: 4.5076 - val_loss: 38.7308 - val_mean_absolute_error: 4.1713
# Epoch 35/500
# 2/2 [==============================] - 0s 49ms/step - loss: 39.9507 - mean_absolute_error: 4.1627 - val_loss: 37.6322 - val_mean_absolute_error: 4.2434
# Epoch 36/500
# 2/2 [==============================] - 0s 50ms/step - loss: 39.6792 - mean_absolute_error: 4.4090 - val_loss: 37.0586 - val_mean_absolute_error: 4.1937
# Epoch 37/500
# 2/2 [==============================] - 0s 48ms/step - loss: 38.7409 - mean_absolute_error: 4.2871 - val_loss: 40.2586 - val_mean_absolute_error: 4.2569
# Epoch 38/500
# 2/2 [==============================] - 0s 48ms/step - loss: 40.9045 - mean_absolute_error: 4.1811 - val_loss: 37.2876 - val_mean_absolute_error: 4.1489
# Epoch 39/500
# 2/2 [==============================] - 0s 48ms/step - loss: 38.6921 - mean_absolute_error: 4.2259 - val_loss: 37.4695 - val_mean_absolute_error: 4.2088
# Epoch 40/500
# 2/2 [==============================] - 0s 49ms/step - loss: 39.1429 - mean_absolute_error: 4.3269 - val_loss: 37.2104 - val_mean_absolute_error: 4.1395
# Epoch 41/500
# 2/2 [==============================] - 0s 48ms/step - loss: 38.6190 - mean_absolute_error: 4.1954 - val_loss: 37.3182 - val_mean_absolute_error: 4.1436
# Epoch 42/500
# 2/2 [==============================] - 0s 51ms/step - loss: 38.5914 - mean_absolute_error: 4.1931 - val_loss: 36.9223 - val_mean_absolute_error: 4.1919
# Epoch 43/500
# 2/2 [==============================] - 0s 54ms/step - loss: 38.4392 - mean_absolute_error: 4.3001 - val_loss: 36.9143 - val_mean_absolute_error: 4.2005
# Epoch 44/500
# 2/2 [==============================] - 0s 50ms/step - loss: 38.2326 - mean_absolute_error: 4.2849 - val_loss: 38.1026 - val_mean_absolute_error: 4.1688
# Epoch 45/500
# 2/2 [==============================] - 0s 48ms/step - loss: 39.0483 - mean_absolute_error: 4.1626 - val_loss: 37.4045 - val_mean_absolute_error: 4.1518
# Epoch 46/500
# 2/2 [==============================] - 0s 53ms/step - loss: 38.5292 - mean_absolute_error: 4.1955 - val_loss: 36.8060 - val_mean_absolute_error: 4.1955
# Epoch 47/500
# 2/2 [==============================] - 0s 48ms/step - loss: 38.2448 - mean_absolute_error: 4.2891 - val_loss: 37.1635 - val_mean_absolute_error: 4.1384
# Epoch 48/500
# 2/2 [==============================] - 0s 51ms/step - loss: 38.4650 - mean_absolute_error: 4.1885 - val_loss: 36.9485 - val_mean_absolute_error: 4.1348
# Epoch 49/500
# 2/2 [==============================] - 0s 51ms/step - loss: 38.2731 - mean_absolute_error: 4.1983 - val_loss: 36.6734 - val_mean_absolute_error: 4.1523
# Epoch 50/500
# 2/2 [==============================] - 0s 49ms/step - loss: 38.0587 - mean_absolute_error: 4.2320 - val_loss: 36.7880 - val_mean_absolute_error: 4.1338
# Epoch 51/500
# 2/2 [==============================] - 0s 50ms/step - loss: 38.0571 - mean_absolute_error: 4.1991 - val_loss: 36.5174 - val_mean_absolute_error: 4.1493
# Epoch 52/500
# 2/2 [==============================] - 0s 47ms/step - loss: 37.9206 - mean_absolute_error: 4.2390 - val_loss: 36.6066 - val_mean_absolute_error: 4.1465
# Epoch 53/500
# 2/2 [==============================] - 0s 49ms/step - loss: 37.8959 - mean_absolute_error: 4.2198 - val_loss: 36.9761 - val_mean_absolute_error: 4.1336
# Epoch 54/500
# 2/2 [==============================] - 0s 50ms/step - loss: 38.1171 - mean_absolute_error: 4.1784 - val_loss: 36.4521 - val_mean_absolute_error: 4.1405
# Epoch 55/500
# 2/2 [==============================] - 0s 50ms/step - loss: 37.9078 - mean_absolute_error: 4.2351 - val_loss: 36.4217 - val_mean_absolute_error: 4.1689
# Epoch 56/500
# 2/2 [==============================] - 0s 48ms/step - loss: 38.0125 - mean_absolute_error: 4.2767 - val_loss: 36.4868 - val_mean_absolute_error: 4.1369
# Epoch 57/500
# 2/2 [==============================] - 0s 50ms/step - loss: 37.9532 - mean_absolute_error: 4.2215 - val_loss: 36.4874 - val_mean_absolute_error: 4.1573
# Epoch 58/500
# 2/2 [==============================] - 0s 48ms/step - loss: 37.9034 - mean_absolute_error: 4.2545 - val_loss: 36.5916 - val_mean_absolute_error: 4.2051
# Epoch 59/500
# 2/2 [==============================] - 0s 49ms/step - loss: 38.1461 - mean_absolute_error: 4.3242 - val_loss: 36.5900 - val_mean_absolute_error: 4.1448
# Epoch 60/500
# 2/2 [==============================] - 0s 49ms/step - loss: 38.0937 - mean_absolute_error: 4.2284 - val_loss: 36.5007 - val_mean_absolute_error: 4.1307
# Epoch 61/500
# 2/2 [==============================] - 0s 50ms/step - loss: 37.8234 - mean_absolute_error: 4.1986 - val_loss: 36.3618 - val_mean_absolute_error: 4.1920
# Epoch 62/500
# 2/2 [==============================] - 0s 48ms/step - loss: 37.9760 - mean_absolute_error: 4.3184 - val_loss: 36.9338 - val_mean_absolute_error: 4.2163
# Epoch 63/500
# 2/2 [==============================] - 0s 49ms/step - loss: 38.3909 - mean_absolute_error: 4.3355 - val_loss: 36.7022 - val_mean_absolute_error: 4.1508
# Epoch 64/500
# 2/2 [==============================] - 0s 51ms/step - loss: 37.7754 - mean_absolute_error: 4.1994 - val_loss: 37.7346 - val_mean_absolute_error: 4.1675
# Epoch 65/500
# 2/2 [==============================] - 0s 49ms/step - loss: 38.5940 - mean_absolute_error: 4.1520 - val_loss: 37.4345 - val_mean_absolute_error: 4.1482
# Epoch 66/500
# 2/2 [==============================] - 0s 47ms/step - loss: 38.3495 - mean_absolute_error: 4.1649 - val_loss: 36.8287 - val_mean_absolute_error: 4.1871
# Epoch 67/500
# 2/2 [==============================] - 0s 49ms/step - loss: 38.3943 - mean_absolute_error: 4.3145 - val_loss: 36.9076 - val_mean_absolute_error: 4.2009
# Epoch 68/500
# 2/2 [==============================] - 0s 48ms/step - loss: 38.5643 - mean_absolute_error: 4.3217 - val_loss: 36.6529 - val_mean_absolute_error: 4.1379
# Epoch 69/500
# 2/2 [==============================] - 0s 49ms/step - loss: 38.0365 - mean_absolute_error: 4.2172 - val_loss: 36.8247 - val_mean_absolute_error: 4.1338
# Epoch 70/500
# 2/2 [==============================] - 0s 48ms/step - loss: 38.0851 - mean_absolute_error: 4.1985 - val_loss: 36.6300 - val_mean_absolute_error: 4.1437
# Epoch 71/500
# 2/2 [==============================] - 0s 59ms/step - loss: 37.8993 - mean_absolute_error: 4.2145 - val_loss: 36.6928 - val_mean_absolute_error: 4.1554
# Epoch 1/500
# 2/2 [==============================] - 1s 322ms/step - loss: 189.5957 - mean_absolute_error: 6.9210 - val_loss: 98.2687 - val_mean_absolute_error: 4.6790
# Epoch 2/500
# 2/2 [==============================] - 0s 47ms/step - loss: 101.0814 - mean_absolute_error: 4.8730 - val_loss: 85.7425 - val_mean_absolute_error: 4.5974
# Epoch 3/500
# 2/2 [==============================] - 0s 48ms/step - loss: 85.2698 - mean_absolute_error: 4.5363 - val_loss: 93.1494 - val_mean_absolute_error: 5.2342
# Epoch 4/500
# 2/2 [==============================] - 0s 52ms/step - loss: 92.7720 - mean_absolute_error: 4.9328 - val_loss: 84.0320 - val_mean_absolute_error: 4.9058
# Epoch 5/500
# 2/2 [==============================] - 0s 49ms/step - loss: 84.0278 - mean_absolute_error: 4.7150 - val_loss: 71.7105 - val_mean_absolute_error: 4.3797
# Epoch 6/500
# 2/2 [==============================] - 0s 50ms/step - loss: 73.6758 - mean_absolute_error: 4.5871 - val_loss: 68.9052 - val_mean_absolute_error: 4.5585
# Epoch 7/500
# 2/2 [==============================] - 0s 49ms/step - loss: 69.5834 - mean_absolute_error: 4.7292 - val_loss: 65.5053 - val_mean_absolute_error: 4.4803
# Epoch 8/500
# 2/2 [==============================] - 0s 49ms/step - loss: 65.6291 - mean_absolute_error: 4.4426 - val_loss: 63.4558 - val_mean_absolute_error: 4.4971
# Epoch 9/500
# 2/2 [==============================] - 0s 50ms/step - loss: 63.0459 - mean_absolute_error: 4.4201 - val_loss: 59.7513 - val_mean_absolute_error: 4.4548
# Epoch 10/500
# 2/2 [==============================] - 0s 48ms/step - loss: 59.2475 - mean_absolute_error: 4.5098 - val_loss: 57.9028 - val_mean_absolute_error: 4.5061
# Epoch 11/500
# 2/2 [==============================] - 0s 50ms/step - loss: 57.7684 - mean_absolute_error: 4.6406 - val_loss: 54.7929 - val_mean_absolute_error: 4.4056
# Epoch 12/500
# 2/2 [==============================] - 0s 50ms/step - loss: 55.1850 - mean_absolute_error: 4.4587 - val_loss: 53.7301 - val_mean_absolute_error: 4.4403
# Epoch 13/500
# 2/2 [==============================] - 0s 49ms/step - loss: 54.3589 - mean_absolute_error: 4.4133 - val_loss: 50.8107 - val_mean_absolute_error: 4.3805
# Epoch 14/500
# 2/2 [==============================] - 0s 52ms/step - loss: 51.4295 - mean_absolute_error: 4.4323 - val_loss: 50.6443 - val_mean_absolute_error: 4.4624
# Epoch 15/500
# 2/2 [==============================] - 0s 51ms/step - loss: 50.9715 - mean_absolute_error: 4.6064 - val_loss: 49.5680 - val_mean_absolute_error: 4.4571
# Epoch 16/500
# 2/2 [==============================] - 0s 51ms/step - loss: 49.5180 - mean_absolute_error: 4.5595 - val_loss: 48.2789 - val_mean_absolute_error: 4.4106
# Epoch 17/500
# 2/2 [==============================] - 0s 51ms/step - loss: 48.6066 - mean_absolute_error: 4.4161 - val_loss: 47.3795 - val_mean_absolute_error: 4.3777
# Epoch 18/500
# 2/2 [==============================] - 0s 49ms/step - loss: 47.8403 - mean_absolute_error: 4.4777 - val_loss: 46.5723 - val_mean_absolute_error: 4.4426
# Epoch 19/500
# 2/2 [==============================] - 0s 50ms/step - loss: 46.9706 - mean_absolute_error: 4.5819 - val_loss: 45.0715 - val_mean_absolute_error: 4.3666
# Epoch 20/500
# 2/2 [==============================] - 0s 49ms/step - loss: 45.6881 - mean_absolute_error: 4.4643 - val_loss: 44.9125 - val_mean_absolute_error: 4.3698
# Epoch 21/500
# 2/2 [==============================] - 0s 49ms/step - loss: 45.5009 - mean_absolute_error: 4.4754 - val_loss: 44.3393 - val_mean_absolute_error: 4.4112
# Epoch 22/500
# 2/2 [==============================] - 0s 50ms/step - loss: 44.8694 - mean_absolute_error: 4.5380 - val_loss: 43.8701 - val_mean_absolute_error: 4.3738
# Epoch 23/500
# 2/2 [==============================] - 0s 50ms/step - loss: 44.6437 - mean_absolute_error: 4.4275 - val_loss: 43.4131 - val_mean_absolute_error: 4.3726
# Epoch 24/500
# 2/2 [==============================] - 0s 51ms/step - loss: 44.2043 - mean_absolute_error: 4.4876 - val_loss: 43.2431 - val_mean_absolute_error: 4.3911
# Epoch 25/500
# 2/2 [==============================] - 0s 50ms/step - loss: 43.8697 - mean_absolute_error: 4.5067 - val_loss: 42.7379 - val_mean_absolute_error: 4.3721
# Epoch 26/500
# 2/2 [==============================] - 0s 48ms/step - loss: 43.2531 - mean_absolute_error: 4.4578 - val_loss: 44.0207 - val_mean_absolute_error: 4.5466
# Epoch 27/500
# 2/2 [==============================] - 0s 47ms/step - loss: 44.2162 - mean_absolute_error: 4.6706 - val_loss: 43.0126 - val_mean_absolute_error: 4.4079
# Epoch 28/500
# 2/2 [==============================] - 0s 50ms/step - loss: 43.3132 - mean_absolute_error: 4.4832 - val_loss: 42.6507 - val_mean_absolute_error: 4.3991
# Epoch 29/500
# 2/2 [==============================] - 0s 49ms/step - loss: 43.1862 - mean_absolute_error: 4.4344 - val_loss: 42.5461 - val_mean_absolute_error: 4.4702
# Epoch 30/500
# 2/2 [==============================] - 0s 52ms/step - loss: 43.2663 - mean_absolute_error: 4.5982 - val_loss: 41.9696 - val_mean_absolute_error: 4.4198
# Epoch 31/500
# 2/2 [==============================] - 0s 48ms/step - loss: 42.7482 - mean_absolute_error: 4.5261 - val_loss: 42.0845 - val_mean_absolute_error: 4.3797
# Epoch 32/500
# 2/2 [==============================] - 0s 50ms/step - loss: 43.0492 - mean_absolute_error: 4.4342 - val_loss: 41.5166 - val_mean_absolute_error: 4.3711
# Epoch 33/500
# 2/2 [==============================] - 0s 50ms/step - loss: 42.4917 - mean_absolute_error: 4.4559 - val_loss: 41.6113 - val_mean_absolute_error: 4.4818
# Epoch 34/500
# 2/2 [==============================] - 0s 52ms/step - loss: 42.6116 - mean_absolute_error: 4.6341 - val_loss: 41.2815 - val_mean_absolute_error: 4.4246
# Epoch 35/500
# 2/2 [==============================] - 0s 50ms/step - loss: 42.4837 - mean_absolute_error: 4.5436 - val_loss: 41.1712 - val_mean_absolute_error: 4.3984
# Epoch 36/500
# 2/2 [==============================] - 0s 50ms/step - loss: 42.2237 - mean_absolute_error: 4.5215 - val_loss: 40.9551 - val_mean_absolute_error: 4.4017
# Epoch 37/500
# 2/2 [==============================] - 0s 48ms/step - loss: 41.9522 - mean_absolute_error: 4.5110 - val_loss: 41.0898 - val_mean_absolute_error: 4.4167
# Epoch 38/500
# 2/2 [==============================] - 0s 49ms/step - loss: 42.0874 - mean_absolute_error: 4.5535 - val_loss: 41.1741 - val_mean_absolute_error: 4.3847
# Epoch 39/500
# 2/2 [==============================] - 0s 48ms/step - loss: 42.1093 - mean_absolute_error: 4.4665 - val_loss: 41.2834 - val_mean_absolute_error: 4.3776
# Epoch 40/500
# 2/2 [==============================] - 0s 48ms/step - loss: 42.1854 - mean_absolute_error: 4.4524 - val_loss: 40.9842 - val_mean_absolute_error: 4.4170
# Epoch 41/500
# 2/2 [==============================] - 0s 48ms/step - loss: 41.6805 - mean_absolute_error: 4.5308 - val_loss: 41.3488 - val_mean_absolute_error: 4.3790
# Epoch 42/500
# 2/2 [==============================] - 0s 49ms/step - loss: 41.9706 - mean_absolute_error: 4.4520 - val_loss: 41.2171 - val_mean_absolute_error: 4.3778
# Epoch 43/500
# 2/2 [==============================] - 0s 48ms/step - loss: 41.7790 - mean_absolute_error: 4.4449 - val_loss: 41.4274 - val_mean_absolute_error: 4.4915
# Epoch 44/500
# 2/2 [==============================] - 0s 48ms/step - loss: 42.0594 - mean_absolute_error: 4.6274 - val_loss: 41.3332 - val_mean_absolute_error: 4.4245
# Epoch 45/500
# 2/2 [==============================] - 0s 49ms/step - loss: 41.9203 - mean_absolute_error: 4.5311 - val_loss: 41.9785 - val_mean_absolute_error: 4.3925
# Epoch 46/500
# 2/2 [==============================] - 0s 50ms/step - loss: 42.7222 - mean_absolute_error: 4.4110 - val_loss: 40.7539 - val_mean_absolute_error: 4.3760
# Epoch 47/500
# 2/2 [==============================] - 0s 49ms/step - loss: 41.6393 - mean_absolute_error: 4.4744 - val_loss: 40.9210 - val_mean_absolute_error: 4.3822
# Epoch 48/500
# 2/2 [==============================] - 0s 47ms/step - loss: 41.7486 - mean_absolute_error: 4.4896 - val_loss: 40.8210 - val_mean_absolute_error: 4.3730
# Epoch 49/500
# 2/2 [==============================] - 0s 51ms/step - loss: 41.6656 - mean_absolute_error: 4.4555 - val_loss: 40.6314 - val_mean_absolute_error: 4.3835
# Epoch 50/500
# 2/2 [==============================] - 0s 48ms/step - loss: 41.3752 - mean_absolute_error: 4.4973 - val_loss: 40.6914 - val_mean_absolute_error: 4.3901
# Epoch 51/500
# 2/2 [==============================] - 0s 49ms/step - loss: 41.4603 - mean_absolute_error: 4.5133 - val_loss: 40.7149 - val_mean_absolute_error: 4.3674
# Epoch 52/500
# 2/2 [==============================] - 0s 54ms/step - loss: 41.5868 - mean_absolute_error: 4.4460 - val_loss: 40.5608 - val_mean_absolute_error: 4.3647
# Epoch 53/500
# 2/2 [==============================] - 0s 48ms/step - loss: 41.5091 - mean_absolute_error: 4.4589 - val_loss: 40.7601 - val_mean_absolute_error: 4.4419
# Epoch 54/500
# 2/2 [==============================] - 0s 50ms/step - loss: 41.8136 - mean_absolute_error: 4.5938 - val_loss: 40.4285 - val_mean_absolute_error: 4.3657
# Epoch 55/500
# 2/2 [==============================] - 0s 49ms/step - loss: 41.5308 - mean_absolute_error: 4.4637 - val_loss: 41.7766 - val_mean_absolute_error: 4.3901
# Epoch 56/500
# 2/2 [==============================] - 0s 50ms/step - loss: 42.9433 - mean_absolute_error: 4.4180 - val_loss: 40.3223 - val_mean_absolute_error: 4.3736
# Epoch 57/500
# 2/2 [==============================] - 0s 48ms/step - loss: 41.4873 - mean_absolute_error: 4.5039 - val_loss: 42.5679 - val_mean_absolute_error: 4.6345
# Epoch 58/500
# 2/2 [==============================] - 0s 48ms/step - loss: 43.6202 - mean_absolute_error: 4.8162 - val_loss: 40.7041 - val_mean_absolute_error: 4.3814
# Epoch 59/500
# 2/2 [==============================] - 0s 48ms/step - loss: 41.8023 - mean_absolute_error: 4.5029 - val_loss: 42.2949 - val_mean_absolute_error: 4.3875
# Epoch 60/500
# 2/2 [==============================] - 0s 48ms/step - loss: 42.8996 - mean_absolute_error: 4.4068 - val_loss: 41.2842 - val_mean_absolute_error: 4.4653
# Epoch 61/500
# 2/2 [==============================] - 0s 49ms/step - loss: 42.1329 - mean_absolute_error: 4.6151 - val_loss: 41.0384 - val_mean_absolute_error: 4.4759
# Epoch 62/500
# 2/2 [==============================] - 0s 49ms/step - loss: 41.9083 - mean_absolute_error: 4.6077 - val_loss: 41.3832 - val_mean_absolute_error: 4.3739
# Epoch 63/500
# 2/2 [==============================] - 0s 48ms/step - loss: 42.4125 - mean_absolute_error: 4.4310 - val_loss: 40.7539 - val_mean_absolute_error: 4.3685
# Epoch 64/500
# 2/2 [==============================] - 0s 48ms/step - loss: 41.7748 - mean_absolute_error: 4.4428 - val_loss: 40.4179 - val_mean_absolute_error: 4.4058
# Epoch 65/500
# 2/2 [==============================] - 0s 48ms/step - loss: 41.5815 - mean_absolute_error: 4.5483 - val_loss: 40.8651 - val_mean_absolute_error: 4.4438
# Epoch 66/500
# 2/2 [==============================] - 0s 60ms/step - loss: 41.9163 - mean_absolute_error: 4.5844 - val_loss: 40.6677 - val_mean_absolute_error: 4.3839
# OOS RMSE: 5.604530867792031

# %%
df_test['Prediction'].describe()
# Out:
# count    2016.000000
# mean        6.640348
# std         1.540173
# min         3.908088
# 25%         5.371675
# 50%         6.492318
# 75%         7.814518
# max        11.387899
# Name: Prediction, dtype: float64

# %%
(df_test['Fantasy Points'] - df_test['Prediction']).describe()
# Out:
# count    2016.000000
# mean        0.027806
# std         5.605852
# min       -13.061255
# 25%        -3.711277
# 50%        -1.009756
# 75%         3.088506
# max        28.904758
# dtype: float64

# %%
(df_test['Fantasy Points'] - df_test['Prediction']).abs().describe()
# Out:
# count    2016.000000
# mean        4.318317
# std         3.573408
# min         0.001316
# 25%         1.719387
# 50%         3.450190
# 75%         6.031510
# max        28.904758
# dtype: float64

# %%
from sklearn.metrics import root_mean_squared_error

root_mean_squared_error(df_test['Fantasy Points'], df_test['Prediction'])
# Out:
# 5.604530867792031

# %%
from sklearn.metrics import mean_absolute_error

mean_absolute_error(df_test['Fantasy Points'], df_test['Prediction'])
# Out:
# 4.31831661446227

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6, 6), dpi=100)

ax = sns.regplot(
    data=df_test,
    x='Prediction',
    y='Fantasy Points',
    scatter_kws={'alpha': 0.10, 'color': sns.color_palette()[1]},
    line_kws={'color': sns.color_palette()[0]},
)

plt.title('Actual Fantasy Points vs. Predicted Fantasy Points')
plt.xlabel('Predicted Fantasy Points Scored')
plt.ylabel('Actual Fantasy Points Scored')

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6, 6), dpi=100)

ax = sns.regplot(
    data=df_test.assign(f=(df_test['Fantasy Points'] - df_test['Prediction'])),
    x='Prediction',
    y='f',
    scatter_kws={'alpha': 0.10, 'color': sns.color_palette()[0]},
    line_kws={'color': sns.color_palette()[3]},
)

plt.title('Residual Plot')
plt.xlabel('Predicted Fantasy Points Scored')
plt.ylabel('Actual Minus Predicted')

plt.show()

# %%
import shap

explainer = shap.DeepExplainer(mod, X_train.to_numpy())

shap_values = explainer(X_train.to_numpy())

shap_values.feature_names = X_train.columns

shap_values.shape
# Out:
# c:\Users\mhugh\anaconda3\envs\clean2\lib\site-packages\shap\explainers\_deep\deep_tf.py:99: UserWarning: Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
#   warnings.warn("Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.")
# c:\Users\mhugh\anaconda3\envs\clean2\lib\site-packages\keras\backend.py:451: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# (1138, 4, 1)

# %%
shap.plots.beeswarm(shap_values[:, :, 0], max_display=None)

# %% [markdown]
# ### Save Predictions

# %%
df_test.to_parquet('../../../data/out_of_sample_predictions/dst.parquet')

print('Done')
# Out:
# Done
