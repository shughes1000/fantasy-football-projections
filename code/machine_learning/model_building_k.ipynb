# %%
import pandas as pd

pd.set_option('display.max_columns', 100)

df_mod = pd.read_parquet('../../data/model_data/model_data_single_output.parquet')

df_mod = df_mod.loc[df_mod['Position'] == 'K', :].reset_index(drop=True)

df_mod
# Out:
#       Season  Week             Name Position Team  Fantasy Points  Rank  \
# 0       2020     1  harrison butker        K   KC            10.0   NaN
# 1       2020     1    justin tucker        K  BAL             9.0   NaN
# 2       2020     1         wil lutz        K   NO            10.0   NaN
# 3       2020     1    greg zuerlein        K  DAL             4.0   NaN
# 4       2020     1     robbie gould        K   SF            10.0   NaN
# ...      ...   ...              ...      ...  ...             ...   ...
# 1941    2023    17      matt prater        K  ARI             9.0   NaN
# 1942    2023    17     mason crosby        K  NYG             5.0   NaN
# 1943    2023    17    greg zuerlein        K  NYJ             9.0   NaN
# 1944    2023    17        joey slye        K  WAS             5.0   NaN
# 1945    2023    17      chad ryland        K   NE             2.0   NaN
#
#       Position Rank  Adjusted Passing Yards Projection  \
# 0                 1                                NaN
# 1                 2                                NaN
# 2                 3                                NaN
# 3                 4                                NaN
# 4                 5                                NaN
# ...             ...                                ...
# 1941             27                                NaN
# 1942             28                                NaN
# 1943             30                                NaN
# 1944             31                                NaN
# 1945             32                                NaN
#
#       Adjusted Passing Touchdowns Projection  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 1941                                     NaN
# 1942                                     NaN
# 1943                                     NaN
# 1944                                     NaN
# 1945                                     NaN
#
#       Adjusted Interceptions Projection  Adjusted Rushing Yards Projection  \
# 0                                   NaN                                NaN
# 1                                   NaN                                NaN
# 2                                   NaN                                NaN
# 3                                   NaN                                NaN
# 4                                   NaN                                NaN
# ...                                 ...                                ...
# 1941                                NaN                                NaN
# 1942                                NaN                                NaN
# 1943                                NaN                                NaN
# 1944                                NaN                                NaN
# 1945                                NaN                                NaN
#
#       Adjusted Receiving Yards Projection  Adjusted Receptions Projection  \
# 0                                     NaN                             NaN
# 1                                     NaN                             NaN
# 2                                     NaN                             NaN
# 3                                     NaN                             NaN
# 4                                     NaN                             NaN
# ...                                   ...                             ...
# 1941                                  NaN                             NaN
# 1942                                  NaN                             NaN
# 1943                                  NaN                             NaN
# 1944                                  NaN                             NaN
# 1945                                  NaN                             NaN
#
#       Anytime Touchdown Probability  Location  Team Projected Score  \
# 0                               NaN       1.0                 31.50
# 1                               NaN       1.0                 27.25
# 2                               NaN       1.0                 26.25
# 3                               NaN      -1.0                 25.50
# 4                               NaN       1.0                 26.75
# ...                             ...       ...                   ...
# 1941                            NaN      -1.0                 17.75
# 1942                            NaN       1.0                 18.75
# 1943                            NaN      -1.0                 13.25
# 1944                            NaN       1.0                 17.25
# 1945                            NaN      -1.0                 12.75
#
#       Opponent Projected Score
# 0                        22.00
# 1                        20.25
# 2                        22.25
# 3                        26.50
# 4                        20.25
# ...                        ...
# 1941                     30.25
# 1942                     24.75
# 1943                     20.25
# 1944                     31.25
# 1945                     27.25
#
# [1946 rows x 18 columns]

# %%
X = df_mod[[
    'Position Rank',
    'Location',
    'Team Projected Score',
    'Opponent Projected Score',
]].copy()

X
# Out:
#       Position Rank  Location  Team Projected Score  Opponent Projected Score
# 0                 1       1.0                 31.50                     22.00
# 1                 2       1.0                 27.25                     20.25
# 2                 3       1.0                 26.25                     22.25
# 3                 4      -1.0                 25.50                     26.50
# 4                 5       1.0                 26.75                     20.25
# ...             ...       ...                   ...                       ...
# 1941             27      -1.0                 17.75                     30.25
# 1942             28       1.0                 18.75                     24.75
# 1943             30      -1.0                 13.25                     20.25
# 1944             31       1.0                 17.25                     31.25
# 1945             32      -1.0                 12.75                     27.25
#
# [1946 rows x 4 columns]

# %%
y = df_mod['Fantasy Points'].copy()

y
# Out:
# 0       10.0
# 1        9.0
# 2       10.0
# 3        4.0
# 4       10.0
#         ...
# 1941     9.0
# 1942     5.0
# 1943     9.0
# 1944     5.0
# 1945     2.0
# Name: Fantasy Points, Length: 1946, dtype: float64

# %%
groups = df_mod['Season'].astype(str) + ' Week ' + df_mod['Week'].astype(str)

groups
# Out:
# 0        2020 Week 1
# 1        2020 Week 1
# 2        2020 Week 1
# 3        2020 Week 1
# 4        2020 Week 1
#             ...
# 1941    2023 Week 17
# 1942    2023 Week 17
# 1943    2023 Week 17
# 1944    2023 Week 17
# 1945    2023 Week 17
# Length: 1946, dtype: object

# %%
df_folds = pd.read_parquet('../../data/model_data/folds.parquet')

df_folds
# Out:
#     Fold ID   Season Week
# 0         0   2022 Week 3
# 1         0   2021 Week 7
# 2         0   2021 Week 1
# 3         0  2023 Week 16
# 4         0  2021 Week 11
# ..      ...           ...
# 62        2  2020 Week 15
# 63        2  2023 Week 14
# 64        2   2021 Week 5
# 65        2   2022 Week 6
# 66        2  2022 Week 12
#
# [67 rows x 2 columns]

# %%
from sklearn.model_selection import GroupShuffleSplit
from sklearn.preprocessing import StandardScaler
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

pd.options.mode.chained_assignment = None

# splitter = GroupKFold(n_splits=3)

cv_data = []
for fold in df_folds['Fold ID'].unique():
    oos_season_week = df_folds.loc[df_folds['Fold ID'] == fold, 'Season Week']
    is_indexes = df_mod.loc[~groups.isin(oos_season_week), :].index
    oos_indexes = df_mod.loc[groups.isin(oos_season_week), :].index
    # split
    X_is = X.iloc[is_indexes]
    X_oos = X.iloc[oos_indexes]

    y_is = y.iloc[is_indexes]
    y_oos = y.iloc[oos_indexes]

    groups_is = groups.iloc[is_indexes]
    df_mod_oos = df_mod.iloc[oos_indexes]

    gss = GroupShuffleSplit(n_splits=1, test_size=0.15, random_state=22)
    for train_indexes, val_indexes in gss.split(X=X_is, y=y_is, groups=groups_is):
        X_train = X_is.iloc[train_indexes]
        X_val = X_is.iloc[val_indexes]

        y_train = y_is.iloc[train_indexes]
        y_val = y_is.iloc[val_indexes]

    # impute
    # scaler = StandardScaler()
    # imputer = IterativeImputer(initial_strategy='median', max_iter=100)

    # X_train_fill_na = imputer.fit_transform(scaler.fit_transform(X_train))
    # X_train[X_train.columns] = scaler.inverse_transform(X_train_fill_na).copy()
    # X_train['Prop Bets Projection'] = (
    #     X_train['Adjusted Receiving Yards Projection']*0.1 + 
    #     X_train['Adjusted Receptions Projection']*0.5 + 
    #     X_train['Anytime Touchdown Probability']*6
    # )

    # X_val_fill_na = imputer.transform(scaler.transform(X_val))
    # X_val[X_val.columns] = scaler.inverse_transform(X_val_fill_na).copy()
    # X_val['Prop Bets Projection'] = (
    #     X_val['Adjusted Receiving Yards Projection']*0.1 + 
    #     X_val['Adjusted Receptions Projection']*0.5 + 
    #     X_val['Anytime Touchdown Probability']*6
    # )

    # X_oos_fill_na = imputer.transform(scaler.transform(X_oos))
    # X_oos[X_oos.columns] = scaler.inverse_transform(X_oos_fill_na).copy()
    # X_oos['Prop Bets Projection'] = (
    #     X_oos['Adjusted Receiving Yards Projection']*0.1 + 
    #     X_oos['Adjusted Receptions Projection']*0.5 + 
    #     X_oos['Anytime Touchdown Probability']*6
    # )

    # X_train.drop(columns=['Adjusted Passing Yards Projection', 'Adjusted Passing Touchdowns Projection', 'Adjusted Interceptions Projection', 'Adjusted Rushing Yards Projection', 'Anytime Touchdown Probability'], inplace=True)
    # X_val.drop(columns=['Adjusted Passing Yards Projection', 'Adjusted Passing Touchdowns Projection', 'Adjusted Interceptions Projection', 'Adjusted Rushing Yards Projection', 'Anytime Touchdown Probability'], inplace=True)
    # X_oos.drop(columns=['Adjusted Passing Yards Projection', 'Adjusted Passing Touchdowns Projection', 'Adjusted Interceptions Projection', 'Adjusted Rushing Yards Projection', 'Anytime Touchdown Probability'], inplace=True)

    cv_data.append((X_train, X_val, X_oos, y_train, y_val, y_oos, df_mod_oos))

for X_train, X_val, X_oos, y_train, y_val, y_oos, df_mod_oos in cv_data:
    print(X_train.shape, X_val.shape, X_oos.shape, y_train.shape, y_val.shape, y_oos.shape, df_mod_oos.shape)
# Out:
# (1068, 4) (210, 4) (668, 4) (1068,) (210,) (668,) (668, 18)
# (1112, 4) (206, 4) (628, 4) (1112,) (206,) (628,) (628, 18)
# (1098, 4) (198, 4) (650, 4) (1098,) (198,) (650,) (650, 18)

# %%
monotonic_contraints_dict = {
    'Position Rank': -1,
    'Location': 1,
    # 'Team Projected Score': 1,
}

monotone_contraints = [monotonic_contraints_dict.get(c, 0) for c in X_train.columns]

monotone_contraints
# Out:
# [-1, 1, 0, 0]

# %%
from sklearn.metrics import mean_squared_error
from lightgbm import LGBMRegressor
import optuna
import numpy as np

def objective(trial, cv_data=cv_data):
    # model tuning
    # params = {
    #     'random_state': 22,
    #     'objective': 'binary:logistic',
    #     'eval_metric': 'logloss',
    #     'n_estimators': 1_000,
    #     'eta': trial.suggest_float('eta', 0.005, 0.100),
    #     'max_depth': trial.suggest_int('max_depth', 4, 16),
    #     'lambda': trial.suggest_float('lambda', 1e-8, 5.0),
    #     'alpha': trial.suggest_float('alpha', 1e-8, 5.0),
    #     'min_child_weight': trial.suggest_float('min_child_weight', 1e-8, 5.0),
    #     # 'subsample': trial.suggest_float('subsample', 0.5, 1.0),
    #     'colsample_bytree': trial.suggest_float('colsample_bytree', 0.01, 0.30),
    # }
    params = {
        'random_state': 22,
        'metric': 'mean_squared_error',
        'verbosity': -1,
        'n_estimators': 500,
        'early_stopping_round': 25,
        'monotone_constraints': monotone_contraints,
        'lambda_l1': trial.suggest_float('lambda_l1', 1e-8, 10.0),
        'lambda_l2': trial.suggest_float('lambda_l2', 1e-8, 10.0),
        'max_depth': trial.suggest_int('max_depth', 1, 32),
        'num_leaves': trial.suggest_int('num_leaves', 2, 2**8),
        'feature_fraction': trial.suggest_float('feature_fraction', 1e-8, 1.0),
        'min_child_samples': trial.suggest_int('min_child_samples', 1, 100),
    }
    mod = LGBMRegressor(**params)

    # cross validation
    y_actuals = []
    y_preds = []
    for X_train, X_val, X_test, y_train, y_val, y_test, df_mod_oos in cv_data:
        y_actuals.append(y_test)

        mod.fit(
            X_train, 
            y_train, 
            eval_set=(X_val, y_val),
        )

        y_preds.append(mod.predict(X_test))

    return mean_squared_error(np.hstack(y_actuals), np.hstack(y_preds), squared=False)

study = optuna.create_study(direction='minimize', sampler=optuna.samplers.TPESampler(seed=22, n_startup_trials=50, multivariate=True))
study.optimize(objective, n_trials=500, show_progress_bar=True)

study.best_params
# Out:
# c:\Users\mhugh\anaconda3\envs\clean\lib\site-packages\optuna\samplers\_tpe\sampler.py:295: ExperimentalWarning: ``multivariate`` option is an experimental feature. The interface can change in the future.
#   warnings.warn(
# [I 2024-10-16 21:19:06,181] A new study created in memory with name: no-name-0ff2e953-e546-4a72-bfd3-6275690b8c49
#   0%|          | 0/500 [00:00<?, ?it/s]
# [I 2024-10-16 21:19:06,355] Trial 0 finished with value: 4.589858480894051 and parameters: {'lambda_l1': 2.084605381503821, 'lambda_l2': 4.816810622816848, 'max_depth': 14, 'num_leaves': 221, 'feature_fraction': 0.17116156190005774, 'min_child_samples': 34}. Best is trial 0 with value: 4.589858480894051.
# [I 2024-10-16 21:19:06,417] Trial 1 finished with value: 4.575067231312219 and parameters: {'lambda_l1': 2.7053283402729833, 'lambda_l2': 6.910413507585547, 'max_depth': 8, 'num_leaves': 209, 'feature_fraction': 0.010526884210839693, 'min_child_samples': 57}. Best is trial 1 with value: 4.575067231312219.
# [I 2024-10-16 21:19:06,472] Trial 2 finished with value: 4.556913605689468 and parameters: {'lambda_l1': 8.137261876014703, 'lambda_l2': 7.451002963137353, 'max_depth': 7, 'num_leaves': 3, 'feature_fraction': 0.7720438737240976, 'min_child_samples': 96}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:06,547] Trial 3 finished with value: 4.570740473505834 and parameters: {'lambda_l1': 7.0193788439237315, 'lambda_l2': 2.975782675674722, 'max_depth': 25, 'num_leaves': 177, 'feature_fraction': 0.38718348650918744, 'min_child_samples': 62}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:06,612] Trial 4 finished with value: 4.56087453742819 and parameters: {'lambda_l1': 4.275552404167853, 'lambda_l2': 5.842896435726052, 'max_depth': 23, 'num_leaves': 30, 'feature_fraction': 0.9232699266117512, 'min_child_samples': 99}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:06,668] Trial 5 finished with value: 4.56215309670877 and parameters: {'lambda_l1': 6.7741077381062915, 'lambda_l2': 7.95164775662488, 'max_depth': 1, 'num_leaves': 47, 'feature_fraction': 0.8749277465284395, 'min_child_samples': 75}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:06,726] Trial 6 finished with value: 4.591029911270341 and parameters: {'lambda_l1': 5.080901637200814, 'lambda_l2': 1.2833390269943445, 'max_depth': 16, 'num_leaves': 133, 'feature_fraction': 0.31126467031173777, 'min_child_samples': 5}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:06,761] Trial 7 finished with value: 4.5639485760153 and parameters: {'lambda_l1': 4.376806606444189, 'lambda_l2': 0.9588461082215654, 'max_depth': 2, 'num_leaves': 176, 'feature_fraction': 0.8491907467156716, 'min_child_samples': 13}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:06,798] Trial 8 finished with value: 4.572993439710707 and parameters: {'lambda_l1': 1.2906400808277216, 'lambda_l2': 4.730600026025964, 'max_depth': 7, 'num_leaves': 201, 'feature_fraction': 0.607413867067853, 'min_child_samples': 45}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:06,866] Trial 9 finished with value: 4.5740107693947945 and parameters: {'lambda_l1': 9.820291085978743, 'lambda_l2': 7.089554140971765, 'max_depth': 7, 'num_leaves': 44, 'feature_fraction': 0.5387654777120323, 'min_child_samples': 32}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:06,956] Trial 10 finished with value: 4.560729416282307 and parameters: {'lambda_l1': 9.115369974738407, 'lambda_l2': 0.8625568068298629, 'max_depth': 11, 'num_leaves': 57, 'feature_fraction': 0.7366662321509689, 'min_child_samples': 83}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:06,992] Trial 11 finished with value: 4.566470887888926 and parameters: {'lambda_l1': 7.445644632079445, 'lambda_l2': 1.7753703875851008, 'max_depth': 28, 'num_leaves': 3, 'feature_fraction': 0.3576431761648761, 'min_child_samples': 96}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:07,070] Trial 12 finished with value: 4.579869869673008 and parameters: {'lambda_l1': 9.417763861384264, 'lambda_l2': 0.23049013654080094, 'max_depth': 22, 'num_leaves': 43, 'feature_fraction': 0.5681323746241385, 'min_child_samples': 25}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:07,127] Trial 13 finished with value: 4.57619248627821 and parameters: {'lambda_l1': 1.5785591501063627, 'lambda_l2': 5.035628220122295, 'max_depth': 19, 'num_leaves': 121, 'feature_fraction': 0.5081672454060291, 'min_child_samples': 33}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:07,256] Trial 14 finished with value: 4.57249536862801 and parameters: {'lambda_l1': 8.864983553736035, 'lambda_l2': 2.5183551154305976, 'max_depth': 28, 'num_leaves': 163, 'feature_fraction': 0.6972231829797998, 'min_child_samples': 4}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:07,346] Trial 15 finished with value: 4.57093780421904 and parameters: {'lambda_l1': 6.573113029388262, 'lambda_l2': 9.993224216396282, 'max_depth': 17, 'num_leaves': 239, 'feature_fraction': 0.44080287410267743, 'min_child_samples': 21}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:07,404] Trial 16 finished with value: 4.569077338302611 and parameters: {'lambda_l1': 8.038535684069508, 'lambda_l2': 8.07672059410554, 'max_depth': 2, 'num_leaves': 203, 'feature_fraction': 0.450041684177444, 'min_child_samples': 86}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:07,547] Trial 17 finished with value: 4.581701482373016 and parameters: {'lambda_l1': 3.624168648699743, 'lambda_l2': 2.0242762718220377, 'max_depth': 28, 'num_leaves': 155, 'feature_fraction': 0.831852739197039, 'min_child_samples': 3}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:07,601] Trial 18 finished with value: 4.567329322329749 and parameters: {'lambda_l1': 7.042966208974291, 'lambda_l2': 7.62995911879823, 'max_depth': 13, 'num_leaves': 51, 'feature_fraction': 0.1689230888648846, 'min_child_samples': 89}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:07,662] Trial 19 finished with value: 4.572125622615595 and parameters: {'lambda_l1': 7.3094208835154015, 'lambda_l2': 8.8719403726663, 'max_depth': 9, 'num_leaves': 171, 'feature_fraction': 0.43498705260110365, 'min_child_samples': 52}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:07,769] Trial 20 finished with value: 4.586679028819251 and parameters: {'lambda_l1': 5.653980359239076, 'lambda_l2': 0.3451501808493058, 'max_depth': 28, 'num_leaves': 91, 'feature_fraction': 0.5389013475164267, 'min_child_samples': 1}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:07,821] Trial 21 finished with value: 4.5720983110871805 and parameters: {'lambda_l1': 0.489554667023236, 'lambda_l2': 9.333017947224663, 'max_depth': 7, 'num_leaves': 186, 'feature_fraction': 0.3980551630378403, 'min_child_samples': 74}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:07,883] Trial 22 finished with value: 4.581309159976384 and parameters: {'lambda_l1': 6.511376677483669, 'lambda_l2': 9.250353214624223, 'max_depth': 20, 'num_leaves': 11, 'feature_fraction': 0.11557638950587484, 'min_child_samples': 76}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:07,936] Trial 23 finished with value: 4.56443919256835 and parameters: {'lambda_l1': 4.517788248973011, 'lambda_l2': 6.046750447343872, 'max_depth': 28, 'num_leaves': 129, 'feature_fraction': 0.8169499167755174, 'min_child_samples': 65}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:08,006] Trial 24 finished with value: 4.591379755330694 and parameters: {'lambda_l1': 4.585916254770666, 'lambda_l2': 2.289650598801194, 'max_depth': 27, 'num_leaves': 132, 'feature_fraction': 0.026716911481217794, 'min_child_samples': 16}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:08,061] Trial 25 finished with value: 4.5655138186607225 and parameters: {'lambda_l1': 9.086816463002746, 'lambda_l2': 0.35256871082678004, 'max_depth': 16, 'num_leaves': 22, 'feature_fraction': 0.539854889190807, 'min_child_samples': 70}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:08,132] Trial 26 finished with value: 4.573923815402954 and parameters: {'lambda_l1': 0.5196410509014395, 'lambda_l2': 9.38557284441749, 'max_depth': 14, 'num_leaves': 249, 'feature_fraction': 0.37649331016315807, 'min_child_samples': 58}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:08,197] Trial 27 finished with value: 4.573360807115657 and parameters: {'lambda_l1': 2.77050808473577, 'lambda_l2': 1.7891537117257124, 'max_depth': 17, 'num_leaves': 256, 'feature_fraction': 0.5083273485258836, 'min_child_samples': 35}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:08,263] Trial 28 finished with value: 4.571935901871228 and parameters: {'lambda_l1': 1.8787035855576422, 'lambda_l2': 0.43517482596686374, 'max_depth': 18, 'num_leaves': 125, 'feature_fraction': 0.8592805504851173, 'min_child_samples': 41}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:08,311] Trial 29 finished with value: 4.587215984187534 and parameters: {'lambda_l1': 2.612231957998111, 'lambda_l2': 9.981270281205395, 'max_depth': 26, 'num_leaves': 17, 'feature_fraction': 0.3158046220351414, 'min_child_samples': 9}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:08,362] Trial 30 finished with value: 4.564963971237098 and parameters: {'lambda_l1': 7.455166416828882, 'lambda_l2': 2.530993227038728, 'max_depth': 12, 'num_leaves': 169, 'feature_fraction': 0.8346373618214232, 'min_child_samples': 73}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:08,399] Trial 31 finished with value: 4.5724647526916335 and parameters: {'lambda_l1': 4.0587436647437585, 'lambda_l2': 7.76438701377263, 'max_depth': 13, 'num_leaves': 171, 'feature_fraction': 0.18199141974675861, 'min_child_samples': 85}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:08,453] Trial 32 finished with value: 4.568365561114959 and parameters: {'lambda_l1': 8.336036101202682, 'lambda_l2': 4.643317602988053, 'max_depth': 8, 'num_leaves': 3, 'feature_fraction': 0.5405971573815558, 'min_child_samples': 51}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:08,520] Trial 33 finished with value: 4.5627194996253655 and parameters: {'lambda_l1': 0.4671699376957205, 'lambda_l2': 5.692352683937471, 'max_depth': 32, 'num_leaves': 207, 'feature_fraction': 0.5902617703671256, 'min_child_samples': 79}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:08,579] Trial 34 finished with value: 4.592337863048012 and parameters: {'lambda_l1': 7.7739315446946184, 'lambda_l2': 4.481509122576739, 'max_depth': 13, 'num_leaves': 162, 'feature_fraction': 0.09863312332364564, 'min_child_samples': 20}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:08,665] Trial 35 finished with value: 4.589241591018645 and parameters: {'lambda_l1': 0.8555555632055482, 'lambda_l2': 9.97684321181545, 'max_depth': 26, 'num_leaves': 117, 'feature_fraction': 0.1805574241161361, 'min_child_samples': 1}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:08,721] Trial 36 finished with value: 4.574400992779656 and parameters: {'lambda_l1': 6.813144850607171, 'lambda_l2': 4.427815824343865, 'max_depth': 31, 'num_leaves': 138, 'feature_fraction': 0.1339572513490412, 'min_child_samples': 64}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:08,777] Trial 37 finished with value: 4.570608935658478 and parameters: {'lambda_l1': 0.3413318706315758, 'lambda_l2': 5.090980726528967, 'max_depth': 27, 'num_leaves': 113, 'feature_fraction': 0.4691051702324455, 'min_child_samples': 92}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:08,844] Trial 38 finished with value: 4.5710263929480455 and parameters: {'lambda_l1': 7.236413490056097, 'lambda_l2': 5.591303698901367, 'max_depth': 3, 'num_leaves': 191, 'feature_fraction': 0.341136056824571, 'min_child_samples': 86}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:08,916] Trial 39 finished with value: 4.561066530715849 and parameters: {'lambda_l1': 6.155817368618826, 'lambda_l2': 4.395847102362112, 'max_depth': 20, 'num_leaves': 35, 'feature_fraction': 0.3856478817819415, 'min_child_samples': 94}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:08,961] Trial 40 finished with value: 4.56937635075656 and parameters: {'lambda_l1': 5.399968572820769, 'lambda_l2': 5.391522843987809, 'max_depth': 8, 'num_leaves': 157, 'feature_fraction': 0.19258927237072163, 'min_child_samples': 96}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:09,031] Trial 41 finished with value: 4.567501096403884 and parameters: {'lambda_l1': 2.702709615849796, 'lambda_l2': 5.796218029870317, 'max_depth': 25, 'num_leaves': 179, 'feature_fraction': 0.7658140957790239, 'min_child_samples': 59}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:09,107] Trial 42 finished with value: 4.568994747195418 and parameters: {'lambda_l1': 1.1995862883625372, 'lambda_l2': 6.698297084546612, 'max_depth': 31, 'num_leaves': 44, 'feature_fraction': 0.8193161329747478, 'min_child_samples': 43}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:09,171] Trial 43 finished with value: 4.573829318768677 and parameters: {'lambda_l1': 5.253924034309357, 'lambda_l2': 3.4318709225280926, 'max_depth': 19, 'num_leaves': 119, 'feature_fraction': 0.44123712890846883, 'min_child_samples': 47}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:09,218] Trial 44 finished with value: 4.573472559128546 and parameters: {'lambda_l1': 7.283309303827439, 'lambda_l2': 7.488947183275922, 'max_depth': 12, 'num_leaves': 29, 'feature_fraction': 0.440996944133391, 'min_child_samples': 24}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:09,275] Trial 45 finished with value: 4.5699139261355155 and parameters: {'lambda_l1': 5.937753990987566, 'lambda_l2': 9.27477560665493, 'max_depth': 4, 'num_leaves': 21, 'feature_fraction': 0.08474433830128524, 'min_child_samples': 39}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:09,312] Trial 46 finished with value: 4.5773801748784955 and parameters: {'lambda_l1': 0.7290652454728227, 'lambda_l2': 0.8353642645311443, 'max_depth': 21, 'num_leaves': 151, 'feature_fraction': 0.3716501369015927, 'min_child_samples': 64}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:09,400] Trial 47 finished with value: 4.586373214442316 and parameters: {'lambda_l1': 0.9503729415542443, 'lambda_l2': 5.984877369569943, 'max_depth': 32, 'num_leaves': 222, 'feature_fraction': 0.8846092517107087, 'min_child_samples': 25}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:09,470] Trial 48 finished with value: 4.566932961555135 and parameters: {'lambda_l1': 9.98309291492172, 'lambda_l2': 4.09130013452504, 'max_depth': 5, 'num_leaves': 23, 'feature_fraction': 0.5087459183109926, 'min_child_samples': 57}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:09,536] Trial 49 finished with value: 4.5673298238553555 and parameters: {'lambda_l1': 0.3489931223249833, 'lambda_l2': 5.985095723120339, 'max_depth': 3, 'num_leaves': 47, 'feature_fraction': 0.28627452007117343, 'min_child_samples': 60}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:09,630] Trial 50 finished with value: 4.559207734291769 and parameters: {'lambda_l1': 4.74910915990546, 'lambda_l2': 6.11769312170833, 'max_depth': 22, 'num_leaves': 4, 'feature_fraction': 0.9762547504432392, 'min_child_samples': 89}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:09,744] Trial 51 finished with value: 4.55775643404759 and parameters: {'lambda_l1': 4.498719695725419, 'lambda_l2': 5.427171522891368, 'max_depth': 23, 'num_leaves': 12, 'feature_fraction': 0.9994546131196755, 'min_child_samples': 95}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:09,817] Trial 52 finished with value: 4.5651129884204975 and parameters: {'lambda_l1': 4.103512277522063, 'lambda_l2': 6.63716459425203, 'max_depth': 26, 'num_leaves': 27, 'feature_fraction': 0.9380672256943785, 'min_child_samples': 86}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:09,920] Trial 53 finished with value: 4.562235959322792 and parameters: {'lambda_l1': 4.4858049353759535, 'lambda_l2': 3.7986475790547036, 'max_depth': 25, 'num_leaves': 36, 'feature_fraction': 0.9453298017930817, 'min_child_samples': 96}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:10,026] Trial 54 finished with value: 4.558982121045769 and parameters: {'lambda_l1': 4.427022101641329, 'lambda_l2': 5.238899788838893, 'max_depth': 21, 'num_leaves': 9, 'feature_fraction': 0.9702477097138181, 'min_child_samples': 70}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:10,093] Trial 55 finished with value: 4.562120623124841 and parameters: {'lambda_l1': 8.684108560575655, 'lambda_l2': 6.337553338912771, 'max_depth': 6, 'num_leaves': 13, 'feature_fraction': 0.8934512419886792, 'min_child_samples': 96}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:10,187] Trial 56 finished with value: 4.560147120124439 and parameters: {'lambda_l1': 6.029694032117462, 'lambda_l2': 4.93918035098068, 'max_depth': 18, 'num_leaves': 34, 'feature_fraction': 0.8901994015350063, 'min_child_samples': 81}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:10,270] Trial 57 finished with value: 4.560695799994218 and parameters: {'lambda_l1': 4.210790295917108, 'lambda_l2': 6.033500839909752, 'max_depth': 19, 'num_leaves': 11, 'feature_fraction': 0.7431531648542817, 'min_child_samples': 95}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:10,387] Trial 58 finished with value: 4.559900307561232 and parameters: {'lambda_l1': 5.169641620214854, 'lambda_l2': 4.73497594941608, 'max_depth': 17, 'num_leaves': 35, 'feature_fraction': 0.7277914714752312, 'min_child_samples': 86}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:10,477] Trial 59 finished with value: 4.561968927407988 and parameters: {'lambda_l1': 5.3035143652032, 'lambda_l2': 7.059588373280125, 'max_depth': 16, 'num_leaves': 7, 'feature_fraction': 0.9344116144814457, 'min_child_samples': 78}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:10,579] Trial 60 finished with value: 4.5620029181590525 and parameters: {'lambda_l1': 5.209552885172788, 'lambda_l2': 4.447576702482851, 'max_depth': 19, 'num_leaves': 26, 'feature_fraction': 0.8722609259692551, 'min_child_samples': 74}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:10,685] Trial 61 finished with value: 4.5645939757228895 and parameters: {'lambda_l1': 4.830736130289125, 'lambda_l2': 6.868831904803856, 'max_depth': 22, 'num_leaves': 55, 'feature_fraction': 0.704865805914037, 'min_child_samples': 96}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:10,784] Trial 62 finished with value: 4.558804869539673 and parameters: {'lambda_l1': 3.7810750172101826, 'lambda_l2': 5.699314441057266, 'max_depth': 17, 'num_leaves': 52, 'feature_fraction': 0.8691133226486571, 'min_child_samples': 92}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:10,861] Trial 63 finished with value: 4.557245487436033 and parameters: {'lambda_l1': 9.058939978514825, 'lambda_l2': 8.47033374866386, 'max_depth': 2, 'num_leaves': 23, 'feature_fraction': 0.6822081652934386, 'min_child_samples': 98}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:10,947] Trial 64 finished with value: 4.557767024196707 and parameters: {'lambda_l1': 8.268507092723448, 'lambda_l2': 8.663989414472477, 'max_depth': 9, 'num_leaves': 40, 'feature_fraction': 0.6258917958091549, 'min_child_samples': 93}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:11,017] Trial 65 finished with value: 4.559967470452373 and parameters: {'lambda_l1': 7.9691390913706535, 'lambda_l2': 8.963783271118148, 'max_depth': 3, 'num_leaves': 24, 'feature_fraction': 0.7418553035410683, 'min_child_samples': 97}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:11,093] Trial 66 finished with value: 4.561503556622768 and parameters: {'lambda_l1': 9.118542133990283, 'lambda_l2': 7.1057185540586865, 'max_depth': 4, 'num_leaves': 2, 'feature_fraction': 0.5481778298670965, 'min_child_samples': 88}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:11,170] Trial 67 finished with value: 4.5628106602513725 and parameters: {'lambda_l1': 7.740550368584088, 'lambda_l2': 9.77558509361605, 'max_depth': 13, 'num_leaves': 34, 'feature_fraction': 0.48082963695548164, 'min_child_samples': 91}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:11,293] Trial 68 finished with value: 4.564379290191427 and parameters: {'lambda_l1': 6.8247532216957225, 'lambda_l2': 7.99545868215434, 'max_depth': 7, 'num_leaves': 79, 'feature_fraction': 0.6588568167422486, 'min_child_samples': 99}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:11,406] Trial 69 finished with value: 4.566492333388042 and parameters: {'lambda_l1': 5.912499147178374, 'lambda_l2': 5.466368328641602, 'max_depth': 29, 'num_leaves': 17, 'feature_fraction': 0.9911683652641367, 'min_child_samples': 62}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:11,525] Trial 70 finished with value: 4.56373411581644 and parameters: {'lambda_l1': 2.765670348929228, 'lambda_l2': 4.266141577251116, 'max_depth': 13, 'num_leaves': 53, 'feature_fraction': 0.9927656955544645, 'min_child_samples': 77}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:11,591] Trial 71 finished with value: 4.56290131649152 and parameters: {'lambda_l1': 9.150956625419017, 'lambda_l2': 9.518331031618345, 'max_depth': 1, 'num_leaves': 10, 'feature_fraction': 0.6770857465962581, 'min_child_samples': 73}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:11,693] Trial 72 finished with value: 4.557578309038501 and parameters: {'lambda_l1': 9.88656499779552, 'lambda_l2': 8.783396182769561, 'max_depth': 10, 'num_leaves': 20, 'feature_fraction': 0.8260965612231296, 'min_child_samples': 93}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:11,791] Trial 73 finished with value: 4.562262150067088 and parameters: {'lambda_l1': 9.391946765270694, 'lambda_l2': 8.495613123139883, 'max_depth': 12, 'num_leaves': 8, 'feature_fraction': 0.9438221025874349, 'min_child_samples': 81}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:11,882] Trial 74 finished with value: 4.5653510383512295 and parameters: {'lambda_l1': 8.99383425149794, 'lambda_l2': 7.363060612128426, 'max_depth': 4, 'num_leaves': 89, 'feature_fraction': 0.6354244530281227, 'min_child_samples': 90}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:11,992] Trial 75 finished with value: 4.5594454551963866 and parameters: {'lambda_l1': 8.23099251727349, 'lambda_l2': 8.172976735665378, 'max_depth': 16, 'num_leaves': 63, 'feature_fraction': 0.7063702409697696, 'min_child_samples': 91}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:12,076] Trial 76 finished with value: 4.560587042588618 and parameters: {'lambda_l1': 2.8957015753312003, 'lambda_l2': 4.763230510351621, 'max_depth': 26, 'num_leaves': 21, 'feature_fraction': 0.9360077001263696, 'min_child_samples': 77}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:12,165] Trial 77 finished with value: 4.564404397588605 and parameters: {'lambda_l1': 6.447062641935588, 'lambda_l2': 8.398248189535446, 'max_depth': 11, 'num_leaves': 19, 'feature_fraction': 0.6493113006439579, 'min_child_samples': 99}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:12,285] Trial 78 finished with value: 4.563043603186158 and parameters: {'lambda_l1': 8.679049577894068, 'lambda_l2': 8.482815535538144, 'max_depth': 11, 'num_leaves': 62, 'feature_fraction': 0.87947950015935, 'min_child_samples': 98}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:12,375] Trial 79 finished with value: 4.564328067096243 and parameters: {'lambda_l1': 9.496354096324154, 'lambda_l2': 7.4414587164327015, 'max_depth': 8, 'num_leaves': 38, 'feature_fraction': 0.7606092041709225, 'min_child_samples': 97}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:12,479] Trial 80 finished with value: 4.560927757018407 and parameters: {'lambda_l1': 5.477831289222465, 'lambda_l2': 5.692933445919886, 'max_depth': 26, 'num_leaves': 19, 'feature_fraction': 0.9169188724834887, 'min_child_samples': 96}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:12,581] Trial 81 finished with value: 4.561770662092644 and parameters: {'lambda_l1': 9.822751584095448, 'lambda_l2': 9.95731232211544, 'max_depth': 4, 'num_leaves': 29, 'feature_fraction': 0.48138491670988653, 'min_child_samples': 96}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:12,712] Trial 82 finished with value: 4.564691139452763 and parameters: {'lambda_l1': 9.92000983288727, 'lambda_l2': 9.501672086624184, 'max_depth': 4, 'num_leaves': 42, 'feature_fraction': 0.85926482766337, 'min_child_samples': 98}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:12,791] Trial 83 finished with value: 4.55839361826677 and parameters: {'lambda_l1': 9.144155091803084, 'lambda_l2': 8.533235201272408, 'max_depth': 20, 'num_leaves': 91, 'feature_fraction': 0.7848792770181369, 'min_child_samples': 94}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:12,917] Trial 84 finished with value: 4.561992794133513 and parameters: {'lambda_l1': 7.647964241735444, 'lambda_l2': 9.509886098375965, 'max_depth': 28, 'num_leaves': 69, 'feature_fraction': 0.9664449047256303, 'min_child_samples': 91}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:13,007] Trial 85 finished with value: 4.558554373846667 and parameters: {'lambda_l1': 5.010196294100251, 'lambda_l2': 3.7987838375745104, 'max_depth': 18, 'num_leaves': 3, 'feature_fraction': 0.9518559511812236, 'min_child_samples': 99}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:13,083] Trial 86 finished with value: 4.564951296471641 and parameters: {'lambda_l1': 8.156991378540864, 'lambda_l2': 6.70865182509683, 'max_depth': 18, 'num_leaves': 118, 'feature_fraction': 0.7467845803778105, 'min_child_samples': 98}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:13,210] Trial 87 finished with value: 4.557949440065967 and parameters: {'lambda_l1': 4.244657555939595, 'lambda_l2': 1.93334663232086, 'max_depth': 20, 'num_leaves': 32, 'feature_fraction': 0.8063698765380467, 'min_child_samples': 93}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:13,294] Trial 88 finished with value: 4.560619008043976 and parameters: {'lambda_l1': 9.929953538005481, 'lambda_l2': 9.3695028540386, 'max_depth': 19, 'num_leaves': 107, 'feature_fraction': 0.7758365204661615, 'min_child_samples': 81}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:13,396] Trial 89 finished with value: 4.565520483769112 and parameters: {'lambda_l1': 4.800044480870449, 'lambda_l2': 2.0581983923155818, 'max_depth': 23, 'num_leaves': 66, 'feature_fraction': 0.7747341767528251, 'min_child_samples': 92}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:13,479] Trial 90 finished with value: 4.567943294695374 and parameters: {'lambda_l1': 3.965475627345854, 'lambda_l2': 2.143067170842299, 'max_depth': 14, 'num_leaves': 8, 'feature_fraction': 0.8224942759186341, 'min_child_samples': 100}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:13,552] Trial 91 finished with value: 4.563099381568389 and parameters: {'lambda_l1': 3.355146624792824, 'lambda_l2': 0.5475059860379379, 'max_depth': 22, 'num_leaves': 64, 'feature_fraction': 0.8732028515397409, 'min_child_samples': 76}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:13,671] Trial 92 finished with value: 4.5648461541725425 and parameters: {'lambda_l1': 2.590184088546839, 'lambda_l2': 5.386841143787317, 'max_depth': 12, 'num_leaves': 76, 'feature_fraction': 0.8502808079831922, 'min_child_samples': 96}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:13,770] Trial 93 finished with value: 4.561231054347238 and parameters: {'lambda_l1': 3.37253916050306, 'lambda_l2': 5.499130320646055, 'max_depth': 20, 'num_leaves': 113, 'feature_fraction': 0.9075034414291933, 'min_child_samples': 81}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:13,876] Trial 94 finished with value: 4.564527121525963 and parameters: {'lambda_l1': 5.740766302826405, 'lambda_l2': 2.888491255063586, 'max_depth': 12, 'num_leaves': 17, 'feature_fraction': 0.9348127937101653, 'min_child_samples': 86}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:13,950] Trial 95 finished with value: 4.559602721031163 and parameters: {'lambda_l1': 9.866024971032358, 'lambda_l2': 6.02186324939968, 'max_depth': 12, 'num_leaves': 5, 'feature_fraction': 0.7091503810157722, 'min_child_samples': 92}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:14,076] Trial 96 finished with value: 4.559364226443552 and parameters: {'lambda_l1': 9.806874538086163, 'lambda_l2': 9.213088727254206, 'max_depth': 16, 'num_leaves': 34, 'feature_fraction': 0.8261588337993464, 'min_child_samples': 91}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:14,190] Trial 97 finished with value: 4.567404069259894 and parameters: {'lambda_l1': 5.239976720067274, 'lambda_l2': 1.8861425597180814, 'max_depth': 23, 'num_leaves': 9, 'feature_fraction': 0.8879755412558404, 'min_child_samples': 90}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:14,280] Trial 98 finished with value: 4.565399279290018 and parameters: {'lambda_l1': 2.709590464945577, 'lambda_l2': 3.4154554465125315, 'max_depth': 18, 'num_leaves': 30, 'feature_fraction': 0.599416046916579, 'min_child_samples': 98}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:14,384] Trial 99 finished with value: 4.5634409461134435 and parameters: {'lambda_l1': 2.35324108454191, 'lambda_l2': 3.9903251929832853, 'max_depth': 19, 'num_leaves': 6, 'feature_fraction': 0.9301707871043822, 'min_child_samples': 97}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:14,516] Trial 100 finished with value: 4.55963596131523 and parameters: {'lambda_l1': 9.546253132214463, 'lambda_l2': 7.571217866768739, 'max_depth': 29, 'num_leaves': 101, 'feature_fraction': 0.7342491336805409, 'min_child_samples': 87}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:14,620] Trial 101 finished with value: 4.561514033392056 and parameters: {'lambda_l1': 5.457946539469543, 'lambda_l2': 5.136835428024055, 'max_depth': 16, 'num_leaves': 25, 'feature_fraction': 0.9549697798639069, 'min_child_samples': 98}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:14,754] Trial 102 finished with value: 4.565158547472714 and parameters: {'lambda_l1': 4.896346244446344, 'lambda_l2': 6.746460481698296, 'max_depth': 21, 'num_leaves': 80, 'feature_fraction': 0.9460725982662864, 'min_child_samples': 88}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:14,892] Trial 103 finished with value: 4.567965722886417 and parameters: {'lambda_l1': 1.8385293091625874, 'lambda_l2': 6.278922486576991, 'max_depth': 8, 'num_leaves': 89, 'feature_fraction': 0.80596786934233, 'min_child_samples': 43}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:15,035] Trial 104 finished with value: 4.571869400622709 and parameters: {'lambda_l1': 3.6991645055503266, 'lambda_l2': 6.320912407583984, 'max_depth': 23, 'num_leaves': 40, 'feature_fraction': 0.9955516211532766, 'min_child_samples': 52}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:15,107] Trial 105 finished with value: 4.563121266043701 and parameters: {'lambda_l1': 6.353418361800323, 'lambda_l2': 6.255292330811896, 'max_depth': 5, 'num_leaves': 6, 'feature_fraction': 0.7860892391420742, 'min_child_samples': 96}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:15,218] Trial 106 finished with value: 4.558994395236152 and parameters: {'lambda_l1': 7.5026842976843025, 'lambda_l2': 5.096458758655222, 'max_depth': 23, 'num_leaves': 30, 'feature_fraction': 0.9865240575321349, 'min_child_samples': 93}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:15,338] Trial 107 finished with value: 4.559753682759479 and parameters: {'lambda_l1': 8.381339061893593, 'lambda_l2': 2.4632988635277946, 'max_depth': 25, 'num_leaves': 17, 'feature_fraction': 0.8376498995587338, 'min_child_samples': 82}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:15,447] Trial 108 finished with value: 4.563614243743452 and parameters: {'lambda_l1': 7.784686550125869, 'lambda_l2': 5.389010135422106, 'max_depth': 19, 'num_leaves': 3, 'feature_fraction': 0.9579024798583834, 'min_child_samples': 33}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:15,542] Trial 109 finished with value: 4.558540540063079 and parameters: {'lambda_l1': 4.089276201231615, 'lambda_l2': 2.4144625790683887, 'max_depth': 19, 'num_leaves': 3, 'feature_fraction': 0.8729181361688945, 'min_child_samples': 57}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:15,638] Trial 110 finished with value: 4.566986209655963 and parameters: {'lambda_l1': 2.061131083503297, 'lambda_l2': 2.763365490690197, 'max_depth': 29, 'num_leaves': 76, 'feature_fraction': 0.6861539581697538, 'min_child_samples': 90}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:15,781] Trial 111 finished with value: 4.562973930999464 and parameters: {'lambda_l1': 8.120991495698494, 'lambda_l2': 6.137356748911086, 'max_depth': 23, 'num_leaves': 35, 'feature_fraction': 0.9933743317147414, 'min_child_samples': 93}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:15,911] Trial 112 finished with value: 4.567543040630424 and parameters: {'lambda_l1': 3.7844108540282613, 'lambda_l2': 4.930250100894683, 'max_depth': 21, 'num_leaves': 15, 'feature_fraction': 0.7792255655897834, 'min_child_samples': 48}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:15,995] Trial 113 finished with value: 4.5624716091309585 and parameters: {'lambda_l1': 5.62686515005718, 'lambda_l2': 1.2866678542355028, 'max_depth': 13, 'num_leaves': 7, 'feature_fraction': 0.946630407454111, 'min_child_samples': 61}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:16,075] Trial 114 finished with value: 4.563329885989095 and parameters: {'lambda_l1': 6.897508671325342, 'lambda_l2': 3.286579204178238, 'max_depth': 24, 'num_leaves': 103, 'feature_fraction': 0.887466795910967, 'min_child_samples': 71}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:16,184] Trial 115 finished with value: 4.570022205566077 and parameters: {'lambda_l1': 5.896528203015462, 'lambda_l2': 1.8001832670560494, 'max_depth': 20, 'num_leaves': 19, 'feature_fraction': 0.8192535843853983, 'min_child_samples': 52}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:16,304] Trial 116 finished with value: 4.565390455404201 and parameters: {'lambda_l1': 7.368327248818705, 'lambda_l2': 6.679769944449187, 'max_depth': 8, 'num_leaves': 63, 'feature_fraction': 0.776334285310724, 'min_child_samples': 72}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:16,375] Trial 117 finished with value: 4.564497393690469 and parameters: {'lambda_l1': 3.6113209490607128, 'lambda_l2': 4.225589156374224, 'max_depth': 17, 'num_leaves': 2, 'feature_fraction': 0.9075436673489938, 'min_child_samples': 64}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:16,471] Trial 118 finished with value: 4.591536251557276 and parameters: {'lambda_l1': 2.401790493893144, 'lambda_l2': 6.43805508083169, 'max_depth': 24, 'num_leaves': 228, 'feature_fraction': 0.09272574804824979, 'min_child_samples': 16}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:16,595] Trial 119 finished with value: 4.566576758987157 and parameters: {'lambda_l1': 2.945960170086879, 'lambda_l2': 1.2686846755203574, 'max_depth': 21, 'num_leaves': 9, 'feature_fraction': 0.74571639326001, 'min_child_samples': 64}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:16,701] Trial 120 finished with value: 4.579880706736563 and parameters: {'lambda_l1': 7.674943942517641, 'lambda_l2': 8.09978040248432, 'max_depth': 31, 'num_leaves': 234, 'feature_fraction': 0.05697129815536395, 'min_child_samples': 69}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:16,822] Trial 121 finished with value: 4.569410139663034 and parameters: {'lambda_l1': 8.034943145732953, 'lambda_l2': 8.929146178889386, 'max_depth': 11, 'num_leaves': 3, 'feature_fraction': 0.6155231234014822, 'min_child_samples': 92}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:16,937] Trial 122 finished with value: 4.564609624387468 and parameters: {'lambda_l1': 4.030833851035357, 'lambda_l2': 9.109328492982154, 'max_depth': 18, 'num_leaves': 15, 'feature_fraction': 0.8587610090122164, 'min_child_samples': 86}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:17,038] Trial 123 finished with value: 4.563249821415391 and parameters: {'lambda_l1': 5.456480995457392, 'lambda_l2': 5.219903078615643, 'max_depth': 19, 'num_leaves': 10, 'feature_fraction': 0.9496668593575375, 'min_child_samples': 80}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:17,139] Trial 124 finished with value: 4.561798147985751 and parameters: {'lambda_l1': 4.405501231052165, 'lambda_l2': 5.002542007187702, 'max_depth': 24, 'num_leaves': 6, 'feature_fraction': 0.9527306871634281, 'min_child_samples': 83}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:17,230] Trial 125 finished with value: 4.5601206755945105 and parameters: {'lambda_l1': 4.555673199335832, 'lambda_l2': 3.918832589179285, 'max_depth': 21, 'num_leaves': 73, 'feature_fraction': 0.935218105947089, 'min_child_samples': 100}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:17,325] Trial 126 finished with value: 4.563073576028952 and parameters: {'lambda_l1': 3.9888260930272597, 'lambda_l2': 6.42412443905302, 'max_depth': 20, 'num_leaves': 9, 'feature_fraction': 0.946177890420384, 'min_child_samples': 91}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:17,398] Trial 127 finished with value: 4.570212645996224 and parameters: {'lambda_l1': 0.5144382358681261, 'lambda_l2': 1.009762291528069, 'max_depth': 29, 'num_leaves': 22, 'feature_fraction': 0.055747593793744, 'min_child_samples': 96}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:17,490] Trial 128 finished with value: 4.568668851576805 and parameters: {'lambda_l1': 6.569925889231408, 'lambda_l2': 5.570375865601946, 'max_depth': 7, 'num_leaves': 17, 'feature_fraction': 0.34313930042864815, 'min_child_samples': 83}. Best is trial 2 with value: 4.556913605689468.
# [I 2024-10-16 21:19:17,639] Trial 129 finished with value: 4.556880024849827 and parameters: {'lambda_l1': 7.3587414336040595, 'lambda_l2': 4.515309189448878, 'max_depth': 22, 'num_leaves': 25, 'feature_fraction': 0.8860316472446975, 'min_child_samples': 98}. Best is trial 129 with value: 4.556880024849827.
# [I 2024-10-16 21:19:17,740] Trial 130 finished with value: 4.560136890374527 and parameters: {'lambda_l1': 6.924266911196292, 'lambda_l2': 7.38948235862351, 'max_depth': 1, 'num_leaves': 23, 'feature_fraction': 0.639372857075686, 'min_child_samples': 93}. Best is trial 129 with value: 4.556880024849827.
# [I 2024-10-16 21:19:17,851] Trial 131 finished with value: 4.563679434914872 and parameters: {'lambda_l1': 8.333549251992046, 'lambda_l2': 9.689837889821153, 'max_depth': 26, 'num_leaves': 36, 'feature_fraction': 0.5718157758154431, 'min_child_samples': 87}. Best is trial 129 with value: 4.556880024849827.
# [I 2024-10-16 21:19:17,965] Trial 132 finished with value: 4.575035501978413 and parameters: {'lambda_l1': 3.647085016065148, 'lambda_l2': 2.5209595676720875, 'max_depth': 11, 'num_leaves': 45, 'feature_fraction': 0.9764576989261258, 'min_child_samples': 41}. Best is trial 129 with value: 4.556880024849827.
# [I 2024-10-16 21:19:18,059] Trial 133 finished with value: 4.579120083386029 and parameters: {'lambda_l1': 9.91992217823692, 'lambda_l2': 8.755548134786862, 'max_depth': 8, 'num_leaves': 118, 'feature_fraction': 0.22877380784931473, 'min_child_samples': 67}. Best is trial 129 with value: 4.556880024849827.
# [I 2024-10-16 21:19:18,169] Trial 134 finished with value: 4.563266640512764 and parameters: {'lambda_l1': 7.332699351209315, 'lambda_l2': 3.5948231065240313, 'max_depth': 22, 'num_leaves': 32, 'feature_fraction': 0.8277757906813741, 'min_child_samples': 98}. Best is trial 129 with value: 4.556880024849827.
# [I 2024-10-16 21:19:18,294] Trial 135 finished with value: 4.56413118478215 and parameters: {'lambda_l1': 7.25091344070628, 'lambda_l2': 5.079025048644462, 'max_depth': 24, 'num_leaves': 69, 'feature_fraction': 0.9426931847437076, 'min_child_samples': 84}. Best is trial 129 with value: 4.556880024849827.
# [I 2024-10-16 21:19:18,375] Trial 136 finished with value: 4.5592649051046505 and parameters: {'lambda_l1': 5.235150293227679, 'lambda_l2': 7.011331094816217, 'max_depth': 30, 'num_leaves': 3, 'feature_fraction': 0.996786578091349, 'min_child_samples': 92}. Best is trial 129 with value: 4.556880024849827.
# [I 2024-10-16 21:19:18,465] Trial 137 finished with value: 4.560376476232987 and parameters: {'lambda_l1': 7.8323868709362285, 'lambda_l2': 6.621072009158763, 'max_depth': 26, 'num_leaves': 7, 'feature_fraction': 0.8084991285026297, 'min_child_samples': 88}. Best is trial 129 with value: 4.556880024849827.
# [I 2024-10-16 21:19:18,585] Trial 138 finished with value: 4.577205463400418 and parameters: {'lambda_l1': 3.226511294385638, 'lambda_l2': 2.6524678526420873, 'max_depth': 14, 'num_leaves': 23, 'feature_fraction': 0.5499350374098371, 'min_child_samples': 42}. Best is trial 129 with value: 4.556880024849827.
# [I 2024-10-16 21:19:18,696] Trial 139 finished with value: 4.562528619089945 and parameters: {'lambda_l1': 7.124505391419348, 'lambda_l2': 9.868687751749533, 'max_depth': 20, 'num_leaves': 114, 'feature_fraction': 0.9114681720118185, 'min_child_samples': 96}. Best is trial 129 with value: 4.556880024849827.
# [I 2024-10-16 21:19:18,811] Trial 140 finished with value: 4.559542458845668 and parameters: {'lambda_l1': 9.810464330211486, 'lambda_l2': 7.032898581590938, 'max_depth': 3, 'num_leaves': 20, 'feature_fraction': 0.7810185246597482, 'min_child_samples': 87}. Best is trial 129 with value: 4.556880024849827.
# [I 2024-10-16 21:19:18,928] Trial 141 finished with value: 4.565475513407572 and parameters: {'lambda_l1': 4.702511052911086, 'lambda_l2': 8.143219975733057, 'max_depth': 28, 'num_leaves': 44, 'feature_fraction': 0.7810967239478703, 'min_child_samples': 96}. Best is trial 129 with value: 4.556880024849827.
# [I 2024-10-16 21:19:19,049] Trial 142 finished with value: 4.5582159041359525 and parameters: {'lambda_l1': 9.836301895743869, 'lambda_l2': 7.478693684916657, 'max_depth': 21, 'num_leaves': 78, 'feature_fraction': 0.7541367440655744, 'min_child_samples': 94}. Best is trial 129 with value: 4.556880024849827.
# [I 2024-10-16 21:19:19,167] Trial 143 finished with value: 4.567355942485985 and parameters: {'lambda_l1': 1.783607206608134, 'lambda_l2': 2.9325729590802787, 'max_depth': 28, 'num_leaves': 67, 'feature_fraction': 0.8213924713996417, 'min_child_samples': 38}. Best is trial 129 with value: 4.556880024849827.
# [I 2024-10-16 21:19:19,263] Trial 144 finished with value: 4.558614509093109 and parameters: {'lambda_l1': 9.201112257062846, 'lambda_l2': 7.946055520492279, 'max_depth': 18, 'num_leaves': 115, 'feature_fraction': 0.636312437797577, 'min_child_samples': 94}. Best is trial 129 with value: 4.556880024849827.
# [I 2024-10-16 21:19:19,344] Trial 145 finished with value: 4.5585317523633275 and parameters: {'lambda_l1': 8.901035628650162, 'lambda_l2': 7.299480098100008, 'max_depth': 18, 'num_leaves': 116, 'feature_fraction': 0.6652548029274303, 'min_child_samples': 96}. Best is trial 129 with value: 4.556880024849827.
# [I 2024-10-16 21:19:19,452] Trial 146 finished with value: 4.56404932444545 and parameters: {'lambda_l1': 9.717247309524593, 'lambda_l2': 8.152193936917241, 'max_depth': 17, 'num_leaves': 88, 'feature_fraction': 0.5548719676468399, 'min_child_samples': 100}. Best is trial 129 with value: 4.556880024849827.
# [I 2024-10-16 21:19:19,566] Trial 147 finished with value: 4.560556355556846 and parameters: {'lambda_l1': 8.453971190595231, 'lambda_l2': 8.0562342573049, 'max_depth': 23, 'num_leaves': 116, 'feature_fraction': 0.7360430900657037, 'min_child_samples': 86}. Best is trial 129 with value: 4.556880024849827.
# [I 2024-10-16 21:19:19,666] Trial 148 finished with value: 4.558576120494931 and parameters: {'lambda_l1': 8.636290552940045, 'lambda_l2': 8.076068246116376, 'max_depth': 19, 'num_leaves': 108, 'feature_fraction': 0.7769481297939416, 'min_child_samples': 92}. Best is trial 129 with value: 4.556880024849827.
# [I 2024-10-16 21:19:19,760] Trial 149 finished with value: 4.56223949413136 and parameters: {'lambda_l1': 8.710464840202683, 'lambda_l2': 8.026941476917697, 'max_depth': 17, 'num_leaves': 132, 'feature_fraction': 0.7788007347507735, 'min_child_samples': 84}. Best is trial 129 with value: 4.556880024849827.
# [I 2024-10-16 21:19:19,848] Trial 150 finished with value: 4.558349416406708 and parameters: {'lambda_l1': 9.77337186822501, 'lambda_l2': 7.978359360441846, 'max_depth': 16, 'num_leaves': 147, 'feature_fraction': 0.6321816228053041, 'min_child_samples': 94}. Best is trial 129 with value: 4.556880024849827.
# [I 2024-10-16 21:19:19,955] Trial 151 finished with value: 4.558449456467636 and parameters: {'lambda_l1': 8.446408296836545, 'lambda_l2': 8.749384507542274, 'max_depth': 24, 'num_leaves': 182, 'feature_fraction': 0.6622330920785381, 'min_child_samples': 88}. Best is trial 129 with value: 4.556880024849827.
# [I 2024-10-16 21:19:20,050] Trial 152 finished with value: 4.560280429079453 and parameters: {'lambda_l1': 8.70266573567626, 'lambda_l2': 8.187537880497953, 'max_depth': 26, 'num_leaves': 207, 'feature_fraction': 0.744735489411514, 'min_child_samples': 82}. Best is trial 129 with value: 4.556880024849827.
# [I 2024-10-16 21:19:20,139] Trial 153 finished with value: 4.564373655574924 and parameters: {'lambda_l1': 8.890482368057183, 'lambda_l2': 8.086268990431801, 'max_depth': 18, 'num_leaves': 61, 'feature_fraction': 0.849691585350073, 'min_child_samples': 97}. Best is trial 129 with value: 4.556880024849827.
# [I 2024-10-16 21:19:20,258] Trial 154 finished with value: 4.559818926569304 and parameters: {'lambda_l1': 9.238608156077474, 'lambda_l2': 8.132349165289211, 'max_depth': 12, 'num_leaves': 145, 'feature_fraction': 0.5212953636099206, 'min_child_samples': 93}. Best is trial 129 with value: 4.556880024849827.
# ...
# [I 2024-10-16 21:19:49,860] Trial 449 finished with value: 4.561676842511922 and parameters: {'lambda_l1': 3.740929852319618, 'lambda_l2': 8.942686529517095, 'max_depth': 5, 'num_leaves': 210, 'feature_fraction': 0.6916954042041804, 'min_child_samples': 92}. Best is trial 428 with value: 4.555683622399063.
# [I 2024-10-16 21:19:49,954] Trial 450 finished with value: 4.563662045838731 and parameters: {'lambda_l1': 7.7911702522302555, 'lambda_l2': 5.03196451176637, 'max_depth': 24, 'num_leaves': 17, 'feature_fraction': 0.8111297796518497, 'min_child_samples': 99}. Best is trial 428 with value: 4.555683622399063.
# [I 2024-10-16 21:19:50,034] Trial 451 finished with value: 4.563459098015211 and parameters: {'lambda_l1': 8.598559177296405, 'lambda_l2': 4.87341434311544, 'max_depth': 20, 'num_leaves': 7, 'feature_fraction': 0.8282846277194663, 'min_child_samples': 83}. Best is trial 428 with value: 4.555683622399063.
# [I 2024-10-16 21:19:50,125] Trial 452 finished with value: 4.5592487823650325 and parameters: {'lambda_l1': 6.7089731366164935, 'lambda_l2': 8.151692586347218, 'max_depth': 7, 'num_leaves': 247, 'feature_fraction': 0.7589967099135522, 'min_child_samples': 94}. Best is trial 428 with value: 4.555683622399063.
# [I 2024-10-16 21:19:50,261] Trial 453 finished with value: 4.56820170656968 and parameters: {'lambda_l1': 4.88387041630793, 'lambda_l2': 8.77682014142188, 'max_depth': 14, 'num_leaves': 222, 'feature_fraction': 0.6062439711122802, 'min_child_samples': 97}. Best is trial 428 with value: 4.555683622399063.
# [I 2024-10-16 21:19:50,351] Trial 454 finished with value: 4.563899883032675 and parameters: {'lambda_l1': 5.965048799286146, 'lambda_l2': 9.37237317599592, 'max_depth': 4, 'num_leaves': 219, 'feature_fraction': 0.563239450569284, 'min_child_samples': 72}. Best is trial 428 with value: 4.555683622399063.
# [I 2024-10-16 21:19:50,453] Trial 455 finished with value: 4.555706976407826 and parameters: {'lambda_l1': 5.905427893609357, 'lambda_l2': 9.308662541623754, 'max_depth': 2, 'num_leaves': 254, 'feature_fraction': 0.7025248797961369, 'min_child_samples': 89}. Best is trial 428 with value: 4.555683622399063.
# [I 2024-10-16 21:19:50,534] Trial 456 finished with value: 4.5568560103983975 and parameters: {'lambda_l1': 3.3719332655186895, 'lambda_l2': 9.940805924406181, 'max_depth': 2, 'num_leaves': 227, 'feature_fraction': 0.6797304372666566, 'min_child_samples': 99}. Best is trial 428 with value: 4.555683622399063.
# [I 2024-10-16 21:19:50,629] Trial 457 finished with value: 4.56456206949597 and parameters: {'lambda_l1': 2.916727303713979, 'lambda_l2': 9.757370789842673, 'max_depth': 5, 'num_leaves': 220, 'feature_fraction': 0.7859644818258605, 'min_child_samples': 86}. Best is trial 428 with value: 4.555683622399063.
# [I 2024-10-16 21:19:50,711] Trial 458 finished with value: 4.559153586476101 and parameters: {'lambda_l1': 2.892389487754944, 'lambda_l2': 8.4164756578411, 'max_depth': 1, 'num_leaves': 246, 'feature_fraction': 0.6936103861356113, 'min_child_samples': 89}. Best is trial 428 with value: 4.555683622399063.
# [I 2024-10-16 21:19:50,811] Trial 459 finished with value: 4.564415830488108 and parameters: {'lambda_l1': 4.638393451767913, 'lambda_l2': 9.85011795152406, 'max_depth': 3, 'num_leaves': 222, 'feature_fraction': 0.5355731091146377, 'min_child_samples': 93}. Best is trial 428 with value: 4.555683622399063.
# [I 2024-10-16 21:19:50,940] Trial 460 finished with value: 4.5655013154482385 and parameters: {'lambda_l1': 4.579615744535764, 'lambda_l2': 8.812693005465146, 'max_depth': 4, 'num_leaves': 247, 'feature_fraction': 0.7391128287281944, 'min_child_samples': 57}. Best is trial 428 with value: 4.555683622399063.
# [I 2024-10-16 21:19:51,069] Trial 461 finished with value: 4.571533220975712 and parameters: {'lambda_l1': 5.07685577935259, 'lambda_l2': 9.498802047739034, 'max_depth': 1, 'num_leaves': 246, 'feature_fraction': 0.9596366027683665, 'min_child_samples': 40}. Best is trial 428 with value: 4.555683622399063.
# [I 2024-10-16 21:19:51,183] Trial 462 finished with value: 4.56450243291331 and parameters: {'lambda_l1': 5.586588164130815, 'lambda_l2': 9.621331262727702, 'max_depth': 7, 'num_leaves': 238, 'feature_fraction': 0.6409579095794183, 'min_child_samples': 97}. Best is trial 428 with value: 4.555683622399063.
# [I 2024-10-16 21:19:51,311] Trial 463 finished with value: 4.571546692562135 and parameters: {'lambda_l1': 3.220705825825494, 'lambda_l2': 5.912378872152598, 'max_depth': 32, 'num_leaves': 186, 'feature_fraction': 0.04129759010345402, 'min_child_samples': 80}. Best is trial 428 with value: 4.555683622399063.
# [I 2024-10-16 21:19:51,421] Trial 464 finished with value: 4.556723725789819 and parameters: {'lambda_l1': 5.676660320799348, 'lambda_l2': 8.716198320393758, 'max_depth': 2, 'num_leaves': 229, 'feature_fraction': 0.8067408326010344, 'min_child_samples': 75}. Best is trial 428 with value: 4.555683622399063.
# [I 2024-10-16 21:19:51,514] Trial 465 finished with value: 4.5600112859989075 and parameters: {'lambda_l1': 4.8135397790124195, 'lambda_l2': 9.604274448986912, 'max_depth': 1, 'num_leaves': 213, 'feature_fraction': 0.801864785948268, 'min_child_samples': 82}. Best is trial 428 with value: 4.555683622399063.
# [I 2024-10-16 21:19:51,626] Trial 466 finished with value: 4.556270105580053 and parameters: {'lambda_l1': 5.374952974380182, 'lambda_l2': 7.603792844414968, 'max_depth': 6, 'num_leaves': 255, 'feature_fraction': 0.996117262157029, 'min_child_samples': 98}. Best is trial 428 with value: 4.555683622399063.
# [I 2024-10-16 21:19:51,736] Trial 467 finished with value: 4.56534191915018 and parameters: {'lambda_l1': 4.624080890922421, 'lambda_l2': 9.636029330313054, 'max_depth': 9, 'num_leaves': 229, 'feature_fraction': 0.7946375288334447, 'min_child_samples': 75}. Best is trial 428 with value: 4.555683622399063.
# [I 2024-10-16 21:19:51,831] Trial 468 finished with value: 4.55758612027102 and parameters: {'lambda_l1': 4.134408649503355, 'lambda_l2': 8.726362837214946, 'max_depth': 4, 'num_leaves': 232, 'feature_fraction': 0.9711772793921055, 'min_child_samples': 95}. Best is trial 428 with value: 4.555683622399063.
# [I 2024-10-16 21:19:51,920] Trial 469 finished with value: 4.563377102346143 and parameters: {'lambda_l1': 3.974040074351736, 'lambda_l2': 6.502793815910039, 'max_depth': 5, 'num_leaves': 249, 'feature_fraction': 0.9085716431531152, 'min_child_samples': 73}. Best is trial 428 with value: 4.555683622399063.
# [I 2024-10-16 21:19:52,017] Trial 470 finished with value: 4.558485807295248 and parameters: {'lambda_l1': 2.9243446722401836, 'lambda_l2': 6.27685603282909, 'max_depth': 3, 'num_leaves': 215, 'feature_fraction': 0.9939437491273176, 'min_child_samples': 91}. Best is trial 428 with value: 4.555683622399063.
# [I 2024-10-16 21:19:52,108] Trial 471 finished with value: 4.560125497863542 and parameters: {'lambda_l1': 4.924060232256773, 'lambda_l2': 7.956325408909814, 'max_depth': 3, 'num_leaves': 185, 'feature_fraction': 0.9417658236875615, 'min_child_samples': 85}. Best is trial 428 with value: 4.555683622399063.
# [I 2024-10-16 21:19:52,207] Trial 472 finished with value: 4.5652020738363595 and parameters: {'lambda_l1': 2.131926242439122, 'lambda_l2': 9.974917832606069, 'max_depth': 7, 'num_leaves': 251, 'feature_fraction': 0.6741618321284335, 'min_child_samples': 98}. Best is trial 428 with value: 4.555683622399063.
# [I 2024-10-16 21:19:52,319] Trial 473 finished with value: 4.563898678660633 and parameters: {'lambda_l1': 4.106528503173104, 'lambda_l2': 9.85263100222879, 'max_depth': 8, 'num_leaves': 243, 'feature_fraction': 0.8627966068139518, 'min_child_samples': 97}. Best is trial 428 with value: 4.555683622399063.
# [I 2024-10-16 21:19:52,406] Trial 474 finished with value: 4.5561902700521415 and parameters: {'lambda_l1': 4.907939974049743, 'lambda_l2': 7.8866872232954455, 'max_depth': 2, 'num_leaves': 248, 'feature_fraction': 0.6736402005425521, 'min_child_samples': 99}. Best is trial 428 with value: 4.555683622399063.
# [I 2024-10-16 21:19:52,516] Trial 475 finished with value: 4.561948496342053 and parameters: {'lambda_l1': 3.4641685899563655, 'lambda_l2': 8.377247370797791, 'max_depth': 5, 'num_leaves': 232, 'feature_fraction': 0.9939173757459683, 'min_child_samples': 91}. Best is trial 428 with value: 4.555683622399063.
# [I 2024-10-16 21:19:52,644] Trial 476 finished with value: 4.562578379397611 and parameters: {'lambda_l1': 6.713834935033798, 'lambda_l2': 8.505524547726145, 'max_depth': 1, 'num_leaves': 234, 'feature_fraction': 0.9329948642788686, 'min_child_samples': 73}. Best is trial 428 with value: 4.555683622399063.
# [I 2024-10-16 21:19:52,728] Trial 477 finished with value: 4.557390774950672 and parameters: {'lambda_l1': 4.5623536708036285, 'lambda_l2': 6.407551585118201, 'max_depth': 2, 'num_leaves': 245, 'feature_fraction': 0.7714432725625189, 'min_child_samples': 92}. Best is trial 428 with value: 4.555683622399063.
# [I 2024-10-16 21:19:52,821] Trial 478 finished with value: 4.5640600572900185 and parameters: {'lambda_l1': 4.5129566219537836, 'lambda_l2': 8.009092586482158, 'max_depth': 5, 'num_leaves': 241, 'feature_fraction': 0.9643213765522846, 'min_child_samples': 98}. Best is trial 428 with value: 4.555683622399063.
# [I 2024-10-16 21:19:52,924] Trial 479 finished with value: 4.569861406201849 and parameters: {'lambda_l1': 5.30641540110721, 'lambda_l2': 7.5112867618336505, 'max_depth': 7, 'num_leaves': 218, 'feature_fraction': 0.5746927689598311, 'min_child_samples': 100}. Best is trial 428 with value: 4.555683622399063.
# [I 2024-10-16 21:19:53,030] Trial 480 finished with value: 4.559004154403275 and parameters: {'lambda_l1': 3.8008694077281957, 'lambda_l2': 6.098483410581082, 'max_depth': 2, 'num_leaves': 238, 'feature_fraction': 0.6281621446949404, 'min_child_samples': 85}. Best is trial 428 with value: 4.555683622399063.
# [I 2024-10-16 21:19:53,131] Trial 481 finished with value: 4.561048461665813 and parameters: {'lambda_l1': 4.4493841307703175, 'lambda_l2': 6.372788485074347, 'max_depth': 5, 'num_leaves': 255, 'feature_fraction': 0.8869078520526286, 'min_child_samples': 93}. Best is trial 428 with value: 4.555683622399063.
# [I 2024-10-16 21:19:53,242] Trial 482 finished with value: 4.556277486349229 and parameters: {'lambda_l1': 6.6259813700375165, 'lambda_l2': 7.942245332619761, 'max_depth': 3, 'num_leaves': 238, 'feature_fraction': 0.9316077501898855, 'min_child_samples': 99}. Best is trial 428 with value: 4.555683622399063.
# [I 2024-10-16 21:19:53,361] Trial 483 finished with value: 4.558834505264405 and parameters: {'lambda_l1': 5.368109417378691, 'lambda_l2': 6.085163737372115, 'max_depth': 2, 'num_leaves': 201, 'feature_fraction': 0.7391333974353036, 'min_child_samples': 96}. Best is trial 428 with value: 4.555683622399063.
# [I 2024-10-16 21:19:53,438] Trial 484 finished with value: 4.561222605169745 and parameters: {'lambda_l1': 5.09389313034799, 'lambda_l2': 7.991452206301814, 'max_depth': 1, 'num_leaves': 226, 'feature_fraction': 0.6878485885575615, 'min_child_samples': 95}. Best is trial 428 with value: 4.555683622399063.
# [I 2024-10-16 21:19:53,541] Trial 485 finished with value: 4.5618647314091865 and parameters: {'lambda_l1': 5.972231364279789, 'lambda_l2': 9.125472191283546, 'max_depth': 4, 'num_leaves': 214, 'feature_fraction': 0.9213992075974787, 'min_child_samples': 94}. Best is trial 428 with value: 4.555683622399063.
# [I 2024-10-16 21:19:53,638] Trial 486 finished with value: 4.557669685389274 and parameters: {'lambda_l1': 5.825042113302496, 'lambda_l2': 6.069537498097406, 'max_depth': 3, 'num_leaves': 234, 'feature_fraction': 0.8594838930308705, 'min_child_samples': 97}. Best is trial 428 with value: 4.555683622399063.
# [I 2024-10-16 21:19:53,724] Trial 487 finished with value: 4.562803129547135 and parameters: {'lambda_l1': 8.341314680895124, 'lambda_l2': 8.823705971293501, 'max_depth': 1, 'num_leaves': 232, 'feature_fraction': 0.5497926581725333, 'min_child_samples': 95}. Best is trial 428 with value: 4.555683622399063.
# [I 2024-10-16 21:19:53,821] Trial 488 finished with value: 4.562587211714284 and parameters: {'lambda_l1': 5.644804880554169, 'lambda_l2': 8.177734467548575, 'max_depth': 2, 'num_leaves': 247, 'feature_fraction': 0.9163520185265116, 'min_child_samples': 78}. Best is trial 428 with value: 4.555683622399063.
# [I 2024-10-16 21:19:53,927] Trial 489 finished with value: 4.558116724411452 and parameters: {'lambda_l1': 3.484993318499586, 'lambda_l2': 9.046229582601976, 'max_depth': 2, 'num_leaves': 178, 'feature_fraction': 0.690027512686685, 'min_child_samples': 56}. Best is trial 428 with value: 4.555683622399063.
# [I 2024-10-16 21:19:54,029] Trial 490 finished with value: 4.5632113422586515 and parameters: {'lambda_l1': 4.324760436859084, 'lambda_l2': 8.278899841983346, 'max_depth': 4, 'num_leaves': 252, 'feature_fraction': 0.5305239514179403, 'min_child_samples': 86}. Best is trial 428 with value: 4.555683622399063.
# [I 2024-10-16 21:19:54,128] Trial 491 finished with value: 4.562564609768125 and parameters: {'lambda_l1': 0.5116244245552064, 'lambda_l2': 0.0015171648399201487, 'max_depth': 22, 'num_leaves': 236, 'feature_fraction': 0.5397712792749909, 'min_child_samples': 81}. Best is trial 428 with value: 4.555683622399063.
# [I 2024-10-16 21:19:54,224] Trial 492 finished with value: 4.561022181261027 and parameters: {'lambda_l1': 9.933329672312365, 'lambda_l2': 9.481262424749934, 'max_depth': 15, 'num_leaves': 5, 'feature_fraction': 0.9764893165263286, 'min_child_samples': 100}. Best is trial 428 with value: 4.555683622399063.
# [I 2024-10-16 21:19:54,315] Trial 493 finished with value: 4.560691389785597 and parameters: {'lambda_l1': 8.608458566264456, 'lambda_l2': 6.9779861245784796, 'max_depth': 1, 'num_leaves': 225, 'feature_fraction': 0.9022886421519267, 'min_child_samples': 83}. Best is trial 428 with value: 4.555683622399063.
# [I 2024-10-16 21:19:54,417] Trial 494 finished with value: 4.56420607389322 and parameters: {'lambda_l1': 9.927185567299237, 'lambda_l2': 9.932993039755283, 'max_depth': 10, 'num_leaves': 102, 'feature_fraction': 0.870452332118752, 'min_child_samples': 97}. Best is trial 428 with value: 4.555683622399063.
# [I 2024-10-16 21:19:54,489] Trial 495 finished with value: 4.5641847536005065 and parameters: {'lambda_l1': 4.89496450725977, 'lambda_l2': 6.964576424091033, 'max_depth': 1, 'num_leaves': 192, 'feature_fraction': 0.6748343083881795, 'min_child_samples': 64}. Best is trial 428 with value: 4.555683622399063.
# [I 2024-10-16 21:19:54,588] Trial 496 finished with value: 4.568675020339116 and parameters: {'lambda_l1': 6.249429371123132, 'lambda_l2': 9.583040076323195, 'max_depth': 2, 'num_leaves': 248, 'feature_fraction': 0.6235726163961607, 'min_child_samples': 86}. Best is trial 428 with value: 4.555683622399063.
# [I 2024-10-16 21:19:54,683] Trial 497 finished with value: 4.578493951912943 and parameters: {'lambda_l1': 5.3688355183153345, 'lambda_l2': 8.22882787610375, 'max_depth': 1, 'num_leaves': 230, 'feature_fraction': 0.641604105996481, 'min_child_samples': 26}. Best is trial 428 with value: 4.555683622399063.
# [I 2024-10-16 21:19:54,787] Trial 498 finished with value: 4.562913985075345 and parameters: {'lambda_l1': 6.4911462305011165, 'lambda_l2': 5.641293709138559, 'max_depth': 1, 'num_leaves': 253, 'feature_fraction': 0.5740630818387957, 'min_child_samples': 98}. Best is trial 428 with value: 4.555683622399063.
# [I 2024-10-16 21:19:54,891] Trial 499 finished with value: 4.5592555822461405 and parameters: {'lambda_l1': 5.030425177834993, 'lambda_l2': 9.257819781440933, 'max_depth': 1, 'num_leaves': 243, 'feature_fraction': 0.9039801885411638, 'min_child_samples': 87}. Best is trial 428 with value: 4.555683622399063.
# {'lambda_l1': 4.968378636074441,
#  'lambda_l2': 8.911217418062131,
#  'max_depth': 2,
#  'num_leaves': 228,
#  'feature_fraction': 0.7179768666360982,
#  'min_child_samples': 70}

# %%
params = (
    {
        'random_state': 22,
        'metric': 'mean_squared_error',
        'verbosity': -1,
        'n_estimators': 500,
        'early_stopping_round': 25,
        'monotone_constraints': monotone_contraints,
    } |
    study.best_params
)

testing_data = []
mod = LGBMRegressor(**params)
for X_train, X_val, X_test, y_train, y_val, y_test, df_mod_oos in cv_data:
    mod.fit(
        X_train, 
        y_train, 
        eval_set=(X_val, y_val),
    )
    
    testing_data.append(df_mod_oos.assign(Prediction=mod.predict(X_test)))

df_test = pd.concat(testing_data, ignore_index=True)

df_test
# Out:
#       Season  Week             Name Position Team  Fantasy Points  Rank  \
# 0       2020     5    justin tucker        K  BAL             9.0   NaN
# 1       2020     5  harrison butker        K   KC             6.0   NaN
# 2       2020     5         wil lutz        K   NO            15.0   NaN
# 3       2020     5    greg zuerlein        K  DAL            14.0   NaN
# 4       2020     5     robbie gould        K   SF             5.0   NaN
# ...      ...   ...              ...      ...  ...             ...   ...
# 1941    2023    17      matt prater        K  ARI             9.0   NaN
# 1942    2023    17     mason crosby        K  NYG             5.0   NaN
# 1943    2023    17    greg zuerlein        K  NYJ             9.0   NaN
# 1944    2023    17        joey slye        K  WAS             5.0   NaN
# 1945    2023    17      chad ryland        K   NE             2.0   NaN
#
#       Position Rank  Adjusted Passing Yards Projection  \
# 0                 1                                NaN
# 1                 2                                NaN
# 2                 3                                NaN
# 3                 4                                NaN
# 4                 5                                NaN
# ...             ...                                ...
# 1941             27                                NaN
# 1942             28                                NaN
# 1943             30                                NaN
# 1944             31                                NaN
# 1945             32                                NaN
#
#       Adjusted Passing Touchdowns Projection  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 1941                                     NaN
# 1942                                     NaN
# 1943                                     NaN
# 1944                                     NaN
# 1945                                     NaN
#
#       Adjusted Interceptions Projection  Adjusted Rushing Yards Projection  \
# 0                                   NaN                                NaN
# 1                                   NaN                                NaN
# 2                                   NaN                                NaN
# 3                                   NaN                                NaN
# 4                                   NaN                                NaN
# ...                                 ...                                ...
# 1941                                NaN                                NaN
# 1942                                NaN                                NaN
# 1943                                NaN                                NaN
# 1944                                NaN                                NaN
# 1945                                NaN                                NaN
#
#       Adjusted Receiving Yards Projection  Adjusted Receptions Projection  \
# 0                                     NaN                             NaN
# 1                                     NaN                             NaN
# 2                                     NaN                             NaN
# 3                                     NaN                             NaN
# 4                                     NaN                             NaN
# ...                                   ...                             ...
# 1941                                  NaN                             NaN
# 1942                                  NaN                             NaN
# 1943                                  NaN                             NaN
# 1944                                  NaN                             NaN
# 1945                                  NaN                             NaN
#
#       Anytime Touchdown Probability  Location  Team Projected Score  \
# 0                               NaN       1.0                 30.50
# 1                               NaN       1.0                 32.50
# 2                               NaN       1.0                 28.25
# 3                               NaN       1.0                 29.75
# 4                               NaN       1.0                 29.50
# ...                             ...       ...                   ...
# 1941                            NaN      -1.0                 17.75
# 1942                            NaN       1.0                 18.75
# 1943                            NaN      -1.0                 13.25
# 1944                            NaN       1.0                 17.25
# 1945                            NaN      -1.0                 12.75
#
#       Opponent Projected Score  Prediction
# 0                        18.50    8.640649
# 1                        22.00    8.309685
# 2                        21.25    8.390053
# 3                        22.25    8.016286
# 4                        21.00    8.016286
# ...                        ...         ...
# 1941                     30.25    6.672158
# 1942                     24.75    6.935289
# 1943                     20.25    7.167508
# 1944                     31.25    6.628041
# 1945                     27.25    6.326406
#
# [1946 rows x 19 columns]

# %%
df_test['Prediction'].describe()
# Out:
# count    1946.000000
# mean        7.691180
# std         0.562601
# min         6.030940
# 25%         7.385069
# 50%         7.762945
# 75%         8.091415
# max         9.173791
# Name: Prediction, dtype: float64

# %%
(df_test['Fantasy Points'] - df_test['Prediction']).describe()
# Out:
# count    1946.000000
# mean       -0.035989
# std         4.556712
# min       -11.393917
# 25%        -3.274037
# 50%        -0.449952
# 75%         2.984999
# max        17.148553
# dtype: float64

# %%
(df_test['Fantasy Points'] - df_test['Prediction']).abs().describe()
# Out:
# count    1946.000000
# mean        3.651757
# std         2.724470
# min         0.005481
# 25%         1.541503
# 50%         3.137110
# 75%         5.285466
# max        17.148553
# dtype: float64

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(df_test['Fantasy Points'], df_test['Prediction'], squared=False)
# Out:
# 4.555683622399063

# %%
from sklearn.metrics import mean_absolute_error

mean_absolute_error(df_test['Fantasy Points'], df_test['Prediction'])
# Out:
# 3.651756949958077

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6, 6), dpi=100)

ax = sns.regplot(
    data=df_test,
    x='Prediction',
    y='Fantasy Points',
    scatter_kws={'alpha': 0.10, 'color': sns.color_palette()[1]},
    line_kws={'color': sns.color_palette()[0]},
)

plt.title('Actual Fantasy Points vs. Predicted Fantasy Points')
plt.xlabel('Predicted Fantasy Points Scored')
plt.ylabel('Actual Fantasy Points Scored')

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6, 6), dpi=100)

ax = sns.regplot(
    data=df_test.assign(f=(df_test['Fantasy Points'] - df_test['Prediction'])),
    x='Prediction',
    y='f',
    scatter_kws={'alpha': 0.10, 'color': sns.color_palette()[0]},
    line_kws={'color': sns.color_palette()[3]},
)

plt.title('Residual Plot')
plt.xlabel('Predicted Fantasy Points Scored')
plt.ylabel('Actual Minus Predicted')

plt.show()

# %%
import shap

explainer = shap.Explainer(mod, feature_names=X_train.columns, seed=22)

shap_values = explainer(pd.concat([i[0] for i in cv_data], ignore_index=True))

shap_values.shape
# Out:
# (3278, 4)

# %%
shap.plots.beeswarm(shap_values, max_display=None)
