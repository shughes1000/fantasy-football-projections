# %%
import pandas as pd

pd.set_option('display.max_columns', 100)

df_mod = pd.read_parquet('../../data/model_data/model_data_single_output.parquet')

df_mod = df_mod.loc[df_mod['Position'] == 'K', :].reset_index(drop=True)

df_mod
# Out:
#       Season  Week             Name Position Team  Fantasy Points  Rank  \
# 0       2020     1  harrison butker        K   KC            10.0   NaN
# 1       2020     1    justin tucker        K  BAL             9.0   NaN
# 2       2020     1         wil lutz        K   NO            10.0   NaN
# 3       2020     1    greg zuerlein        K  DAL             4.0   NaN
# 4       2020     1     robbie gould        K   SF            10.0   NaN
# ...      ...   ...              ...      ...  ...             ...   ...
# 1941    2023    17      matt prater        K  ARI             9.0   NaN
# 1942    2023    17     mason crosby        K  NYG             5.0   NaN
# 1943    2023    17    greg zuerlein        K  NYJ             9.0   NaN
# 1944    2023    17        joey slye        K  WAS             5.0   NaN
# 1945    2023    17      chad ryland        K   NE             2.0   NaN
#
#       Position Rank  Adjusted Passing Yards Projection  \
# 0                 1                                NaN
# 1                 2                                NaN
# 2                 3                                NaN
# 3                 4                                NaN
# 4                 5                                NaN
# ...             ...                                ...
# 1941             27                                NaN
# 1942             28                                NaN
# 1943             30                                NaN
# 1944             31                                NaN
# 1945             32                                NaN
#
#       Adjusted Passing Touchdowns Projection  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 1941                                     NaN
# 1942                                     NaN
# 1943                                     NaN
# 1944                                     NaN
# 1945                                     NaN
#
#       Adjusted Interceptions Projection  Adjusted Rushing Yards Projection  \
# 0                                   NaN                                NaN
# 1                                   NaN                                NaN
# 2                                   NaN                                NaN
# 3                                   NaN                                NaN
# 4                                   NaN                                NaN
# ...                                 ...                                ...
# 1941                                NaN                                NaN
# 1942                                NaN                                NaN
# 1943                                NaN                                NaN
# 1944                                NaN                                NaN
# 1945                                NaN                                NaN
#
#       Adjusted Receiving Yards Projection  Adjusted Receptions Projection  \
# 0                                     NaN                             NaN
# 1                                     NaN                             NaN
# 2                                     NaN                             NaN
# 3                                     NaN                             NaN
# 4                                     NaN                             NaN
# ...                                   ...                             ...
# 1941                                  NaN                             NaN
# 1942                                  NaN                             NaN
# 1943                                  NaN                             NaN
# 1944                                  NaN                             NaN
# 1945                                  NaN                             NaN
#
#       Anytime Touchdown Probability  Location  Team Projected Score  \
# 0                               NaN       1.0                 31.50
# 1                               NaN       1.0                 27.25
# 2                               NaN       1.0                 26.25
# 3                               NaN      -1.0                 25.50
# 4                               NaN       1.0                 26.75
# ...                             ...       ...                   ...
# 1941                            NaN      -1.0                 17.75
# 1942                            NaN       1.0                 18.75
# 1943                            NaN      -1.0                 13.25
# 1944                            NaN       1.0                 17.25
# 1945                            NaN      -1.0                 12.75
#
#       Opponent Projected Score
# 0                        22.00
# 1                        20.25
# 2                        22.25
# 3                        26.50
# 4                        20.25
# ...                        ...
# 1941                     30.25
# 1942                     24.75
# 1943                     20.25
# 1944                     31.25
# 1945                     27.25
#
# [1946 rows x 18 columns]

# %%
X = df_mod[[
    'Position Rank',
    'Location',
    'Team Projected Score',
    'Opponent Projected Score',
]].copy()

X
# Out:
#       Position Rank  Location  Team Projected Score  Opponent Projected Score
# 0                 1       1.0                 31.50                     22.00
# 1                 2       1.0                 27.25                     20.25
# 2                 3       1.0                 26.25                     22.25
# 3                 4      -1.0                 25.50                     26.50
# 4                 5       1.0                 26.75                     20.25
# ...             ...       ...                   ...                       ...
# 1941             27      -1.0                 17.75                     30.25
# 1942             28       1.0                 18.75                     24.75
# 1943             30      -1.0                 13.25                     20.25
# 1944             31       1.0                 17.25                     31.25
# 1945             32      -1.0                 12.75                     27.25
#
# [1946 rows x 4 columns]

# %%
y = df_mod['Fantasy Points'].copy()

y
# Out:
# 0       10.0
# 1        9.0
# 2       10.0
# 3        4.0
# 4       10.0
#         ...
# 1941     9.0
# 1942     5.0
# 1943     9.0
# 1944     5.0
# 1945     2.0
# Name: Fantasy Points, Length: 1946, dtype: float64

# %%
groups = df_mod['Season'].astype(str) + ' Week ' + df_mod['Week'].astype(str)

groups
# Out:
# 0        2020 Week 1
# 1        2020 Week 1
# 2        2020 Week 1
# 3        2020 Week 1
# 4        2020 Week 1
#             ...
# 1941    2023 Week 17
# 1942    2023 Week 17
# 1943    2023 Week 17
# 1944    2023 Week 17
# 1945    2023 Week 17
# Length: 1946, dtype: object

# %%
df_folds = pd.read_parquet('../../data/model_data/folds.parquet')

df_folds
# Out:
#     Fold ID   Season Week
# 0         0   2022 Week 3
# 1         0   2021 Week 7
# 2         0   2021 Week 1
# 3         0  2023 Week 16
# 4         0  2021 Week 11
# ..      ...           ...
# 62        2  2020 Week 15
# 63        2  2023 Week 14
# 64        2   2021 Week 5
# 65        2   2022 Week 6
# 66        2  2022 Week 12
#
# [67 rows x 2 columns]

# %%
from sklearn.model_selection import GroupShuffleSplit
from sklearn.preprocessing import StandardScaler
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

pd.options.mode.chained_assignment = None

# splitter = GroupKFold(n_splits=3)

cv_data = []
for fold in df_folds['Fold ID'].unique():
    oos_season_week = df_folds.loc[df_folds['Fold ID'] == fold, 'Season Week']
    is_indexes = df_mod.loc[~groups.isin(oos_season_week), :].index
    oos_indexes = df_mod.loc[groups.isin(oos_season_week), :].index
    # split
    X_is = X.iloc[is_indexes]
    X_oos = X.iloc[oos_indexes]

    y_is = y.iloc[is_indexes]
    y_oos = y.iloc[oos_indexes]

    groups_is = groups.iloc[is_indexes]
    df_mod_oos = df_mod.iloc[oos_indexes]

    gss = GroupShuffleSplit(n_splits=1, test_size=0.15, random_state=22)
    for train_indexes, val_indexes in gss.split(X=X_is, y=y_is, groups=groups_is):
            X_train = X.iloc[train_indexes]
            X_val = X.iloc[val_indexes]

            y_train = y.iloc[train_indexes]
            y_val = y.iloc[val_indexes]

    # impute
    # scaler = StandardScaler()
    # imputer = IterativeImputer(initial_strategy='median', max_iter=100)

    # X_train_fill_na = imputer.fit_transform(scaler.fit_transform(X_train))
    # X_train[X_train.columns] = scaler.inverse_transform(X_train_fill_na).copy()
    # X_train['Prop Bets Projection'] = (
    #     X_train['Adjusted Receiving Yards Projection']*0.1 + 
    #     X_train['Adjusted Receptions Projection']*0.5 + 
    #     X_train['Anytime Touchdown Probability']*6
    # )

    # X_val_fill_na = imputer.transform(scaler.transform(X_val))
    # X_val[X_val.columns] = scaler.inverse_transform(X_val_fill_na).copy()
    # X_val['Prop Bets Projection'] = (
    #     X_val['Adjusted Receiving Yards Projection']*0.1 + 
    #     X_val['Adjusted Receptions Projection']*0.5 + 
    #     X_val['Anytime Touchdown Probability']*6
    # )

    # X_oos_fill_na = imputer.transform(scaler.transform(X_oos))
    # X_oos[X_oos.columns] = scaler.inverse_transform(X_oos_fill_na).copy()
    # X_oos['Prop Bets Projection'] = (
    #     X_oos['Adjusted Receiving Yards Projection']*0.1 + 
    #     X_oos['Adjusted Receptions Projection']*0.5 + 
    #     X_oos['Anytime Touchdown Probability']*6
    # )

    # X_train.drop(columns=['Adjusted Passing Yards Projection', 'Adjusted Passing Touchdowns Projection', 'Adjusted Interceptions Projection', 'Adjusted Rushing Yards Projection', 'Anytime Touchdown Probability'], inplace=True)
    # X_val.drop(columns=['Adjusted Passing Yards Projection', 'Adjusted Passing Touchdowns Projection', 'Adjusted Interceptions Projection', 'Adjusted Rushing Yards Projection', 'Anytime Touchdown Probability'], inplace=True)
    # X_oos.drop(columns=['Adjusted Passing Yards Projection', 'Adjusted Passing Touchdowns Projection', 'Adjusted Interceptions Projection', 'Adjusted Rushing Yards Projection', 'Anytime Touchdown Probability'], inplace=True)

    cv_data.append((X_train, X_val, X_oos, y_train, y_val, y_oos, df_mod_oos))

for X_train, X_val, X_oos, y_train, y_val, y_oos, df_mod_oos in cv_data:
    print(X_train.shape, X_val.shape, X_oos.shape, y_train.shape, y_val.shape, y_oos.shape, df_mod_oos.shape)
# Out:
# (1068, 4) (210, 4) (668, 4) (1068,) (210,) (668,) (668, 18)
# (1112, 4) (206, 4) (628, 4) (1112,) (206,) (628,) (628, 18)
# (1098, 4) (198, 4) (650, 4) (1098,) (198,) (650,) (650, 18)

# %%
monotonic_contraints_dict = {
    'Position Rank': -1,
    'Location': 1,
    # 'Team Projected Score': 1,
}

monotone_contraints = [monotonic_contraints_dict.get(c, 0) for c in X_train.columns]

monotone_contraints
# Out:
# [-1, 1, 0, 0]

# %%
from sklearn.metrics import mean_squared_error
from lightgbm import LGBMRegressor
import optuna
import numpy as np

def objective(trial, cv_data=cv_data):
    # model tuning
    # params = {
    #     'random_state': 22,
    #     'objective': 'binary:logistic',
    #     'eval_metric': 'logloss',
    #     'n_estimators': 1_000,
    #     'eta': trial.suggest_float('eta', 0.005, 0.100),
    #     'max_depth': trial.suggest_int('max_depth', 4, 16),
    #     'lambda': trial.suggest_float('lambda', 1e-8, 5.0),
    #     'alpha': trial.suggest_float('alpha', 1e-8, 5.0),
    #     'min_child_weight': trial.suggest_float('min_child_weight', 1e-8, 5.0),
    #     # 'subsample': trial.suggest_float('subsample', 0.5, 1.0),
    #     'colsample_bytree': trial.suggest_float('colsample_bytree', 0.01, 0.30),
    # }
    params = {
        'random_state': 22,
        'metric': 'mean_squared_error',
        'verbosity': -1,
        'n_estimators': 500,
        'early_stopping_round': 25,
        'monotone_constraints': monotone_contraints,
        'lambda_l1': trial.suggest_float('lambda_l1', 1e-8, 10.0),
        'lambda_l2': trial.suggest_float('lambda_l2', 1e-8, 10.0),
        'max_depth': trial.suggest_int('max_depth', 1, 32),
        'num_leaves': trial.suggest_int('num_leaves', 2, 2**8),
        'feature_fraction': trial.suggest_float('feature_fraction', 1e-8, 1.0),
        'min_child_samples': trial.suggest_int('min_child_samples', 1, 100),
    }
    mod = LGBMRegressor(**params)

    # cross validation
    y_actuals = []
    y_preds = []
    for X_train, X_val, X_test, y_train, y_val, y_test, df_mod_oos in cv_data:
        y_actuals.append(y_test)

        mod.fit(
            X_train, 
            y_train, 
            eval_set=(X_val, y_val),
        )

        y_preds.append(mod.predict(X_test))

    return mean_squared_error(np.hstack(y_actuals), np.hstack(y_preds), squared=False)

study = optuna.create_study(direction='minimize', sampler=optuna.samplers.TPESampler(seed=22, n_startup_trials=50, multivariate=True))
study.optimize(objective, n_trials=500, show_progress_bar=True)

study.best_params
# Out:
# c:\Users\mhugh\anaconda3\envs\clean\lib\site-packages\optuna\samplers\_tpe\sampler.py:295: ExperimentalWarning: ``multivariate`` option is an experimental feature. The interface can change in the future.
#   warnings.warn(
# [I 2024-10-13 20:20:10,212] A new study created in memory with name: no-name-27b7078e-5c82-4e05-90d1-9816694022a8
#   0%|          | 0/500 [00:00<?, ?it/s]
# [I 2024-10-13 20:20:10,478] Trial 0 finished with value: 4.547907887356258 and parameters: {'lambda_l1': 2.084605381503821, 'lambda_l2': 4.816810622816848, 'max_depth': 14, 'num_leaves': 221, 'feature_fraction': 0.17116156190005774, 'min_child_samples': 34}. Best is trial 0 with value: 4.547907887356258.
# [I 2024-10-13 20:20:10,541] Trial 1 finished with value: 4.554538335595075 and parameters: {'lambda_l1': 2.7053283402729833, 'lambda_l2': 6.910413507585547, 'max_depth': 8, 'num_leaves': 209, 'feature_fraction': 0.010526884210839693, 'min_child_samples': 57}. Best is trial 0 with value: 4.547907887356258.
# [I 2024-10-13 20:20:10,598] Trial 2 finished with value: 4.54050006464724 and parameters: {'lambda_l1': 8.137261876014703, 'lambda_l2': 7.451002963137353, 'max_depth': 7, 'num_leaves': 3, 'feature_fraction': 0.7720438737240976, 'min_child_samples': 96}. Best is trial 2 with value: 4.54050006464724.
# [I 2024-10-13 20:20:10,686] Trial 3 finished with value: 4.529108698903705 and parameters: {'lambda_l1': 7.0193788439237315, 'lambda_l2': 2.975782675674722, 'max_depth': 25, 'num_leaves': 177, 'feature_fraction': 0.38718348650918744, 'min_child_samples': 62}. Best is trial 3 with value: 4.529108698903705.
# [I 2024-10-13 20:20:10,759] Trial 4 finished with value: 4.524627407800144 and parameters: {'lambda_l1': 4.275552404167853, 'lambda_l2': 5.842896435726052, 'max_depth': 23, 'num_leaves': 30, 'feature_fraction': 0.9232699266117512, 'min_child_samples': 99}. Best is trial 4 with value: 4.524627407800144.
# [I 2024-10-13 20:20:10,825] Trial 5 finished with value: 4.5475639078144106 and parameters: {'lambda_l1': 6.7741077381062915, 'lambda_l2': 7.95164775662488, 'max_depth': 1, 'num_leaves': 47, 'feature_fraction': 0.8749277465284395, 'min_child_samples': 75}. Best is trial 4 with value: 4.524627407800144.
# [I 2024-10-13 20:20:10,901] Trial 6 finished with value: 4.554604873122431 and parameters: {'lambda_l1': 5.080901637200814, 'lambda_l2': 1.2833390269943445, 'max_depth': 16, 'num_leaves': 133, 'feature_fraction': 0.31126467031173777, 'min_child_samples': 5}. Best is trial 4 with value: 4.524627407800144.
# [I 2024-10-13 20:20:10,958] Trial 7 finished with value: 4.547497241440243 and parameters: {'lambda_l1': 4.376806606444189, 'lambda_l2': 0.9588461082215654, 'max_depth': 2, 'num_leaves': 176, 'feature_fraction': 0.8491907467156716, 'min_child_samples': 13}. Best is trial 4 with value: 4.524627407800144.
# [I 2024-10-13 20:20:11,043] Trial 8 finished with value: 4.4886848456064845 and parameters: {'lambda_l1': 1.2906400808277216, 'lambda_l2': 4.730600026025964, 'max_depth': 7, 'num_leaves': 201, 'feature_fraction': 0.607413867067853, 'min_child_samples': 45}. Best is trial 8 with value: 4.4886848456064845.
# [I 2024-10-13 20:20:11,146] Trial 9 finished with value: 4.485810125016543 and parameters: {'lambda_l1': 9.820291085978743, 'lambda_l2': 7.089554140971765, 'max_depth': 7, 'num_leaves': 44, 'feature_fraction': 0.5387654777120323, 'min_child_samples': 32}. Best is trial 9 with value: 4.485810125016543.
# [I 2024-10-13 20:20:11,231] Trial 10 finished with value: 4.538160482131373 and parameters: {'lambda_l1': 9.115369974738407, 'lambda_l2': 0.8625568068298629, 'max_depth': 11, 'num_leaves': 57, 'feature_fraction': 0.7366662321509689, 'min_child_samples': 83}. Best is trial 9 with value: 4.485810125016543.
# [I 2024-10-13 20:20:11,291] Trial 11 finished with value: 4.545805981442847 and parameters: {'lambda_l1': 7.445644632079445, 'lambda_l2': 1.7753703875851008, 'max_depth': 28, 'num_leaves': 3, 'feature_fraction': 0.3576431761648761, 'min_child_samples': 96}. Best is trial 9 with value: 4.485810125016543.
# [I 2024-10-13 20:20:11,392] Trial 12 finished with value: 4.48788091874986 and parameters: {'lambda_l1': 9.417763861384264, 'lambda_l2': 0.23049013654080094, 'max_depth': 22, 'num_leaves': 43, 'feature_fraction': 0.5681323746241385, 'min_child_samples': 25}. Best is trial 9 with value: 4.485810125016543.
# [I 2024-10-13 20:20:11,487] Trial 13 finished with value: 4.501124491582086 and parameters: {'lambda_l1': 1.5785591501063627, 'lambda_l2': 5.035628220122295, 'max_depth': 19, 'num_leaves': 121, 'feature_fraction': 0.5081672454060291, 'min_child_samples': 33}. Best is trial 9 with value: 4.485810125016543.
# [I 2024-10-13 20:20:11,618] Trial 14 finished with value: 4.468656058230613 and parameters: {'lambda_l1': 8.864983553736035, 'lambda_l2': 2.5183551154305976, 'max_depth': 28, 'num_leaves': 163, 'feature_fraction': 0.6972231829797998, 'min_child_samples': 4}. Best is trial 14 with value: 4.468656058230613.
# [I 2024-10-13 20:20:11,734] Trial 15 finished with value: 4.489151361311139 and parameters: {'lambda_l1': 6.573113029388262, 'lambda_l2': 9.993224216396282, 'max_depth': 17, 'num_leaves': 239, 'feature_fraction': 0.44080287410267743, 'min_child_samples': 21}. Best is trial 14 with value: 4.468656058230613.
# [I 2024-10-13 20:20:11,780] Trial 16 finished with value: 4.53998312243874 and parameters: {'lambda_l1': 8.038535684069508, 'lambda_l2': 8.07672059410554, 'max_depth': 2, 'num_leaves': 203, 'feature_fraction': 0.450041684177444, 'min_child_samples': 86}. Best is trial 14 with value: 4.468656058230613.
# [I 2024-10-13 20:20:11,951] Trial 17 finished with value: 4.472113807703434 and parameters: {'lambda_l1': 3.624168648699743, 'lambda_l2': 2.0242762718220377, 'max_depth': 28, 'num_leaves': 155, 'feature_fraction': 0.831852739197039, 'min_child_samples': 3}. Best is trial 14 with value: 4.468656058230613.
# [I 2024-10-13 20:20:11,998] Trial 18 finished with value: 4.552917002073387 and parameters: {'lambda_l1': 7.042966208974291, 'lambda_l2': 7.62995911879823, 'max_depth': 13, 'num_leaves': 51, 'feature_fraction': 0.1689230888648846, 'min_child_samples': 89}. Best is trial 14 with value: 4.468656058230613.
# [I 2024-10-13 20:20:12,064] Trial 19 finished with value: 4.523602883172195 and parameters: {'lambda_l1': 7.3094208835154015, 'lambda_l2': 8.8719403726663, 'max_depth': 9, 'num_leaves': 171, 'feature_fraction': 0.43498705260110365, 'min_child_samples': 52}. Best is trial 14 with value: 4.468656058230613.
# [I 2024-10-13 20:20:12,175] Trial 20 finished with value: 4.458296069152674 and parameters: {'lambda_l1': 5.653980359239076, 'lambda_l2': 0.3451501808493058, 'max_depth': 28, 'num_leaves': 91, 'feature_fraction': 0.5389013475164267, 'min_child_samples': 1}. Best is trial 20 with value: 4.458296069152674.
# [I 2024-10-13 20:20:12,232] Trial 21 finished with value: 4.547220724667683 and parameters: {'lambda_l1': 0.489554667023236, 'lambda_l2': 9.333017947224663, 'max_depth': 7, 'num_leaves': 186, 'feature_fraction': 0.3980551630378403, 'min_child_samples': 74}. Best is trial 20 with value: 4.458296069152674.
# [I 2024-10-13 20:20:12,279] Trial 22 finished with value: 4.5538454485746 and parameters: {'lambda_l1': 6.511376677483669, 'lambda_l2': 9.250353214624223, 'max_depth': 20, 'num_leaves': 11, 'feature_fraction': 0.11557638950587484, 'min_child_samples': 76}. Best is trial 20 with value: 4.458296069152674.
# [I 2024-10-13 20:20:12,345] Trial 23 finished with value: 4.5302372124716195 and parameters: {'lambda_l1': 4.517788248973011, 'lambda_l2': 6.046750447343872, 'max_depth': 28, 'num_leaves': 129, 'feature_fraction': 0.8169499167755174, 'min_child_samples': 65}. Best is trial 20 with value: 4.458296069152674.
# [I 2024-10-13 20:20:12,387] Trial 24 finished with value: 4.5572428409380406 and parameters: {'lambda_l1': 4.585916254770666, 'lambda_l2': 2.289650598801194, 'max_depth': 27, 'num_leaves': 132, 'feature_fraction': 0.026716911481217794, 'min_child_samples': 16}. Best is trial 20 with value: 4.458296069152674.
# [I 2024-10-13 20:20:12,441] Trial 25 finished with value: 4.544044687461851 and parameters: {'lambda_l1': 9.086816463002746, 'lambda_l2': 0.35256871082678004, 'max_depth': 16, 'num_leaves': 22, 'feature_fraction': 0.539854889190807, 'min_child_samples': 70}. Best is trial 20 with value: 4.458296069152674.
# [I 2024-10-13 20:20:12,501] Trial 26 finished with value: 4.519159494832479 and parameters: {'lambda_l1': 0.5196410509014395, 'lambda_l2': 9.38557284441749, 'max_depth': 14, 'num_leaves': 249, 'feature_fraction': 0.37649331016315807, 'min_child_samples': 58}. Best is trial 20 with value: 4.458296069152674.
# [I 2024-10-13 20:20:12,578] Trial 27 finished with value: 4.492949620005478 and parameters: {'lambda_l1': 2.77050808473577, 'lambda_l2': 1.7891537117257124, 'max_depth': 17, 'num_leaves': 256, 'feature_fraction': 0.5083273485258836, 'min_child_samples': 35}. Best is trial 20 with value: 4.458296069152674.
# [I 2024-10-13 20:20:12,637] Trial 28 finished with value: 4.494086043798046 and parameters: {'lambda_l1': 1.8787035855576422, 'lambda_l2': 0.43517482596686374, 'max_depth': 18, 'num_leaves': 125, 'feature_fraction': 0.8592805504851173, 'min_child_samples': 41}. Best is trial 20 with value: 4.458296069152674.
# [I 2024-10-13 20:20:12,687] Trial 29 finished with value: 4.546100829070206 and parameters: {'lambda_l1': 2.612231957998111, 'lambda_l2': 9.981270281205395, 'max_depth': 26, 'num_leaves': 17, 'feature_fraction': 0.3158046220351414, 'min_child_samples': 9}. Best is trial 20 with value: 4.458296069152674.
# [I 2024-10-13 20:20:12,739] Trial 30 finished with value: 4.545525923518381 and parameters: {'lambda_l1': 7.455166416828882, 'lambda_l2': 2.530993227038728, 'max_depth': 12, 'num_leaves': 169, 'feature_fraction': 0.8346373618214232, 'min_child_samples': 73}. Best is trial 20 with value: 4.458296069152674.
# [I 2024-10-13 20:20:12,790] Trial 31 finished with value: 4.553055040579105 and parameters: {'lambda_l1': 4.0587436647437585, 'lambda_l2': 7.76438701377263, 'max_depth': 13, 'num_leaves': 171, 'feature_fraction': 0.18199141974675861, 'min_child_samples': 85}. Best is trial 20 with value: 4.458296069152674.
# [I 2024-10-13 20:20:12,852] Trial 32 finished with value: 4.535633909506232 and parameters: {'lambda_l1': 8.336036101202682, 'lambda_l2': 4.643317602988053, 'max_depth': 8, 'num_leaves': 3, 'feature_fraction': 0.5405971573815558, 'min_child_samples': 51}. Best is trial 20 with value: 4.458296069152674.
# [I 2024-10-13 20:20:12,931] Trial 33 finished with value: 4.547713590372382 and parameters: {'lambda_l1': 0.4671699376957205, 'lambda_l2': 5.692352683937471, 'max_depth': 32, 'num_leaves': 207, 'feature_fraction': 0.5902617703671256, 'min_child_samples': 79}. Best is trial 20 with value: 4.458296069152674.
# [I 2024-10-13 20:20:13,008] Trial 34 finished with value: 4.543359160827909 and parameters: {'lambda_l1': 7.7739315446946184, 'lambda_l2': 4.481509122576739, 'max_depth': 13, 'num_leaves': 162, 'feature_fraction': 0.09863312332364564, 'min_child_samples': 20}. Best is trial 20 with value: 4.458296069152674.
# [I 2024-10-13 20:20:13,091] Trial 35 finished with value: 4.554613071198557 and parameters: {'lambda_l1': 0.8555555632055482, 'lambda_l2': 9.97684321181545, 'max_depth': 26, 'num_leaves': 117, 'feature_fraction': 0.1805574241161361, 'min_child_samples': 1}. Best is trial 20 with value: 4.458296069152674.
# [I 2024-10-13 20:20:13,162] Trial 36 finished with value: 4.55367508186766 and parameters: {'lambda_l1': 6.813144850607171, 'lambda_l2': 4.427815824343865, 'max_depth': 31, 'num_leaves': 138, 'feature_fraction': 0.1339572513490412, 'min_child_samples': 64}. Best is trial 20 with value: 4.458296069152674.
# [I 2024-10-13 20:20:13,298] Trial 37 finished with value: 4.537158155628734 and parameters: {'lambda_l1': 0.3413318706315758, 'lambda_l2': 5.090980726528967, 'max_depth': 27, 'num_leaves': 113, 'feature_fraction': 0.4691051702324455, 'min_child_samples': 92}. Best is trial 20 with value: 4.458296069152674.
# [I 2024-10-13 20:20:13,357] Trial 38 finished with value: 4.5461440866489164 and parameters: {'lambda_l1': 7.236413490056097, 'lambda_l2': 5.591303698901367, 'max_depth': 3, 'num_leaves': 191, 'feature_fraction': 0.341136056824571, 'min_child_samples': 86}. Best is trial 20 with value: 4.458296069152674.
# [I 2024-10-13 20:20:13,442] Trial 39 finished with value: 4.525196179010587 and parameters: {'lambda_l1': 6.155817368618826, 'lambda_l2': 4.395847102362112, 'max_depth': 20, 'num_leaves': 35, 'feature_fraction': 0.3856478817819415, 'min_child_samples': 94}. Best is trial 20 with value: 4.458296069152674.
# [I 2024-10-13 20:20:13,520] Trial 40 finished with value: 4.55049137223626 and parameters: {'lambda_l1': 5.399968572820769, 'lambda_l2': 5.391522843987809, 'max_depth': 8, 'num_leaves': 157, 'feature_fraction': 0.19258927237072163, 'min_child_samples': 96}. Best is trial 20 with value: 4.458296069152674.
# [I 2024-10-13 20:20:13,597] Trial 41 finished with value: 4.531249024065028 and parameters: {'lambda_l1': 2.702709615849796, 'lambda_l2': 5.796218029870317, 'max_depth': 25, 'num_leaves': 179, 'feature_fraction': 0.7658140957790239, 'min_child_samples': 59}. Best is trial 20 with value: 4.458296069152674.
# [I 2024-10-13 20:20:13,668] Trial 42 finished with value: 4.506202023581944 and parameters: {'lambda_l1': 1.1995862883625372, 'lambda_l2': 6.698297084546612, 'max_depth': 31, 'num_leaves': 44, 'feature_fraction': 0.8193161329747478, 'min_child_samples': 43}. Best is trial 20 with value: 4.458296069152674.
# [I 2024-10-13 20:20:13,771] Trial 43 finished with value: 4.521831575890986 and parameters: {'lambda_l1': 5.253924034309357, 'lambda_l2': 3.4318709225280926, 'max_depth': 19, 'num_leaves': 119, 'feature_fraction': 0.44123712890846883, 'min_child_samples': 47}. Best is trial 20 with value: 4.458296069152674.
# [I 2024-10-13 20:20:13,878] Trial 44 finished with value: 4.490810729655341 and parameters: {'lambda_l1': 7.283309303827439, 'lambda_l2': 7.488947183275922, 'max_depth': 12, 'num_leaves': 29, 'feature_fraction': 0.440996944133391, 'min_child_samples': 24}. Best is trial 20 with value: 4.458296069152674.
# [I 2024-10-13 20:20:13,940] Trial 45 finished with value: 4.542172434633692 and parameters: {'lambda_l1': 5.937753990987566, 'lambda_l2': 9.27477560665493, 'max_depth': 4, 'num_leaves': 21, 'feature_fraction': 0.08474433830128524, 'min_child_samples': 39}. Best is trial 20 with value: 4.458296069152674.
# [I 2024-10-13 20:20:14,009] Trial 46 finished with value: 4.55289555175614 and parameters: {'lambda_l1': 0.7290652454728227, 'lambda_l2': 0.8353642645311443, 'max_depth': 21, 'num_leaves': 151, 'feature_fraction': 0.3716501369015927, 'min_child_samples': 64}. Best is trial 20 with value: 4.458296069152674.
# [I 2024-10-13 20:20:14,143] Trial 47 finished with value: 4.4362815162423335 and parameters: {'lambda_l1': 0.9503729415542443, 'lambda_l2': 5.984877369569943, 'max_depth': 32, 'num_leaves': 222, 'feature_fraction': 0.8846092517107087, 'min_child_samples': 25}. Best is trial 47 with value: 4.4362815162423335.
# [I 2024-10-13 20:20:14,200] Trial 48 finished with value: 4.531431333926504 and parameters: {'lambda_l1': 9.98309291492172, 'lambda_l2': 4.09130013452504, 'max_depth': 5, 'num_leaves': 23, 'feature_fraction': 0.5087459183109926, 'min_child_samples': 57}. Best is trial 47 with value: 4.4362815162423335.
# [I 2024-10-13 20:20:14,254] Trial 49 finished with value: 4.548662656357011 and parameters: {'lambda_l1': 0.3489931223249833, 'lambda_l2': 5.985095723120339, 'max_depth': 3, 'num_leaves': 47, 'feature_fraction': 0.28627452007117343, 'min_child_samples': 60}. Best is trial 47 with value: 4.4362815162423335.
# [I 2024-10-13 20:20:14,404] Trial 50 finished with value: 4.493328357285775 and parameters: {'lambda_l1': 2.4974545259302294, 'lambda_l2': 6.647164857796365, 'max_depth': 31, 'num_leaves': 188, 'feature_fraction': 0.8090975753691572, 'min_child_samples': 25}. Best is trial 47 with value: 4.4362815162423335.
# [I 2024-10-13 20:20:14,563] Trial 51 finished with value: 4.506812495667535 and parameters: {'lambda_l1': 6.731968372572888, 'lambda_l2': 0.4133668940002859, 'max_depth': 28, 'num_leaves': 95, 'feature_fraction': 0.5938053862486719, 'min_child_samples': 10}. Best is trial 47 with value: 4.4362815162423335.
# [I 2024-10-13 20:20:14,712] Trial 52 finished with value: 4.509776932198053 and parameters: {'lambda_l1': 8.919839667984071, 'lambda_l2': 2.8736827957366686, 'max_depth': 23, 'num_leaves': 152, 'feature_fraction': 0.6795457083473687, 'min_child_samples': 8}. Best is trial 47 with value: 4.4362815162423335.
# [I 2024-10-13 20:20:14,850] Trial 53 finished with value: 4.477330741731997 and parameters: {'lambda_l1': 3.9708501157914906, 'lambda_l2': 2.3087236345679893, 'max_depth': 30, 'num_leaves': 137, 'feature_fraction': 0.7659402571451114, 'min_child_samples': 7}. Best is trial 47 with value: 4.4362815162423335.
# [I 2024-10-13 20:20:14,983] Trial 54 finished with value: 4.499311080924485 and parameters: {'lambda_l1': 4.667638210726935, 'lambda_l2': 2.061043136311287, 'max_depth': 29, 'num_leaves': 165, 'feature_fraction': 0.751700499771602, 'min_child_samples': 19}. Best is trial 47 with value: 4.4362815162423335.
# [I 2024-10-13 20:20:15,161] Trial 55 finished with value: 4.462475907721857 and parameters: {'lambda_l1': 4.178792698007611, 'lambda_l2': 1.5023177686483145, 'max_depth': 29, 'num_leaves': 139, 'feature_fraction': 0.7062248652382098, 'min_child_samples': 4}. Best is trial 47 with value: 4.4362815162423335.
# [I 2024-10-13 20:20:15,329] Trial 56 finished with value: 4.443406016765938 and parameters: {'lambda_l1': 2.687765816071222, 'lambda_l2': 2.8898886444294027, 'max_depth': 28, 'num_leaves': 153, 'feature_fraction': 0.8360880395724206, 'min_child_samples': 8}. Best is trial 47 with value: 4.4362815162423335.
# [I 2024-10-13 20:20:15,529] Trial 57 finished with value: 4.369066385927498 and parameters: {'lambda_l1': 1.678472548963141, 'lambda_l2': 5.22160402872777, 'max_depth': 31, 'num_leaves': 228, 'feature_fraction': 0.8750721884720922, 'min_child_samples': 10}. Best is trial 57 with value: 4.369066385927498.
# [I 2024-10-13 20:20:15,668] Trial 58 finished with value: 4.493463102201962 and parameters: {'lambda_l1': 0.8695156598528799, 'lambda_l2': 5.269830912335706, 'max_depth': 29, 'num_leaves': 239, 'feature_fraction': 0.7519528577572981, 'min_child_samples': 27}. Best is trial 57 with value: 4.369066385927498.
# [I 2024-10-13 20:20:15,863] Trial 59 finished with value: 4.46020808210301 and parameters: {'lambda_l1': 1.6013719787155607, 'lambda_l2': 4.641987296205016, 'max_depth': 31, 'num_leaves': 183, 'feature_fraction': 0.6937116327664583, 'min_child_samples': 4}. Best is trial 57 with value: 4.369066385927498.
# [I 2024-10-13 20:20:15,997] Trial 60 finished with value: 4.462739256963782 and parameters: {'lambda_l1': 4.589272770155169, 'lambda_l2': 1.2154101874309078, 'max_depth': 27, 'num_leaves': 99, 'feature_fraction': 0.580292449093813, 'min_child_samples': 2}. Best is trial 57 with value: 4.369066385927498.
# [I 2024-10-13 20:20:16,150] Trial 61 finished with value: 4.489650620134455 and parameters: {'lambda_l1': 4.528382035058049, 'lambda_l2': 0.5931071439787232, 'max_depth': 22, 'num_leaves': 105, 'feature_fraction': 0.4257845902405192, 'min_child_samples': 4}. Best is trial 57 with value: 4.369066385927498.
# [I 2024-10-13 20:20:16,404] Trial 62 finished with value: 4.360820416302378 and parameters: {'lambda_l1': 2.7124815840228713, 'lambda_l2': 4.64148492436552, 'max_depth': 31, 'num_leaves': 212, 'feature_fraction': 0.918640412024514, 'min_child_samples': 3}. Best is trial 62 with value: 4.360820416302378.
# [I 2024-10-13 20:20:16,577] Trial 63 finished with value: 4.496576532652622 and parameters: {'lambda_l1': 1.4027013337362175, 'lambda_l2': 4.495200216259834, 'max_depth': 26, 'num_leaves': 165, 'feature_fraction': 0.8318386975728403, 'min_child_samples': 8}. Best is trial 62 with value: 4.360820416302378.
# [I 2024-10-13 20:20:16,793] Trial 64 finished with value: 4.435144751007192 and parameters: {'lambda_l1': 2.676602850143214, 'lambda_l2': 4.570135385907386, 'max_depth': 29, 'num_leaves': 253, 'feature_fraction': 0.8627972411907291, 'min_child_samples': 3}. Best is trial 62 with value: 4.360820416302378.
# [I 2024-10-13 20:20:16,997] Trial 65 finished with value: 4.389242295845671 and parameters: {'lambda_l1': 4.118239109608965, 'lambda_l2': 4.309654757057419, 'max_depth': 27, 'num_leaves': 230, 'feature_fraction': 0.9268729964554885, 'min_child_samples': 8}. Best is trial 62 with value: 4.360820416302378.
# [I 2024-10-13 20:20:17,139] Trial 66 finished with value: 4.498988628382236 and parameters: {'lambda_l1': 1.4099365052800978, 'lambda_l2': 4.586575484893992, 'max_depth': 31, 'num_leaves': 248, 'feature_fraction': 0.8336040739198528, 'min_child_samples': 24}. Best is trial 62 with value: 4.360820416302378.
# [I 2024-10-13 20:20:17,336] Trial 67 finished with value: 4.391339436653761 and parameters: {'lambda_l1': 2.5627373588719498, 'lambda_l2': 5.853883907560086, 'max_depth': 31, 'num_leaves': 251, 'feature_fraction': 0.9049227971613205, 'min_child_samples': 8}. Best is trial 62 with value: 4.360820416302378.
# [I 2024-10-13 20:20:17,504] Trial 68 finished with value: 4.428676428960922 and parameters: {'lambda_l1': 2.5992479394866432, 'lambda_l2': 5.8971030185754545, 'max_depth': 32, 'num_leaves': 241, 'feature_fraction': 0.9303839450566925, 'min_child_samples': 19}. Best is trial 62 with value: 4.360820416302378.
# [I 2024-10-13 20:20:17,821] Trial 69 finished with value: 4.35735024249496 and parameters: {'lambda_l1': 3.04713225096621, 'lambda_l2': 4.583595231572134, 'max_depth': 32, 'num_leaves': 193, 'feature_fraction': 0.9842738987045375, 'min_child_samples': 3}. Best is trial 69 with value: 4.35735024249496.
# [I 2024-10-13 20:20:18,039] Trial 70 finished with value: 4.378694367167001 and parameters: {'lambda_l1': 3.470083872566973, 'lambda_l2': 5.494197915882859, 'max_depth': 24, 'num_leaves': 238, 'feature_fraction': 0.9720319364320541, 'min_child_samples': 7}. Best is trial 69 with value: 4.35735024249496.
# [I 2024-10-13 20:20:18,348] Trial 71 finished with value: 4.390613311440315 and parameters: {'lambda_l1': 4.1033465544181835, 'lambda_l2': 3.4538841080146145, 'max_depth': 30, 'num_leaves': 233, 'feature_fraction': 0.8924578936921275, 'min_child_samples': 2}. Best is trial 69 with value: 4.35735024249496.
# [I 2024-10-13 20:20:18,582] Trial 72 finished with value: 4.366960965194392 and parameters: {'lambda_l1': 2.5063627627166642, 'lambda_l2': 5.557299722200563, 'max_depth': 24, 'num_leaves': 251, 'feature_fraction': 0.9968486088468985, 'min_child_samples': 9}. Best is trial 69 with value: 4.35735024249496.
# [I 2024-10-13 20:20:18,812] Trial 73 finished with value: 4.3938824824965845 and parameters: {'lambda_l1': 3.540534591210622, 'lambda_l2': 5.778900694444127, 'max_depth': 25, 'num_leaves': 183, 'feature_fraction': 0.977751267198355, 'min_child_samples': 10}. Best is trial 69 with value: 4.35735024249496.
# [I 2024-10-13 20:20:19,091] Trial 74 finished with value: 4.34659148052927 and parameters: {'lambda_l1': 5.297544760070409, 'lambda_l2': 4.841835170343791, 'max_depth': 22, 'num_leaves': 248, 'feature_fraction': 0.9878754107710784, 'min_child_samples': 6}. Best is trial 74 with value: 4.34659148052927.
# [I 2024-10-13 20:20:19,395] Trial 75 finished with value: 4.427240907378399 and parameters: {'lambda_l1': 4.383312446451017, 'lambda_l2': 4.013883195194955, 'max_depth': 26, 'num_leaves': 197, 'feature_fraction': 0.8522474855069571, 'min_child_samples': 1}. Best is trial 74 with value: 4.34659148052927.
# [I 2024-10-13 20:20:19,578] Trial 76 finished with value: 4.460490730864294 and parameters: {'lambda_l1': 4.197055363424833, 'lambda_l2': 3.699703044150103, 'max_depth': 20, 'num_leaves': 245, 'feature_fraction': 0.8814514701648317, 'min_child_samples': 13}. Best is trial 74 with value: 4.34659148052927.
# [I 2024-10-13 20:20:19,911] Trial 77 finished with value: 4.382551628935821 and parameters: {'lambda_l1': 7.058468680450135, 'lambda_l2': 4.985652196842858, 'max_depth': 22, 'num_leaves': 237, 'feature_fraction': 0.944374456347568, 'min_child_samples': 1}. Best is trial 74 with value: 4.34659148052927.
# [I 2024-10-13 20:20:20,103] Trial 78 finished with value: 4.42281197482655 and parameters: {'lambda_l1': 3.6763666248227, 'lambda_l2': 5.626002276249491, 'max_depth': 20, 'num_leaves': 245, 'feature_fraction': 0.9469238573478586, 'min_child_samples': 19}. Best is trial 74 with value: 4.34659148052927.
# [I 2024-10-13 20:20:20,275] Trial 79 finished with value: 4.465796600959355 and parameters: {'lambda_l1': 7.027171453168264, 'lambda_l2': 4.402124375484276, 'max_depth': 24, 'num_leaves': 206, 'feature_fraction': 0.9018328632415672, 'min_child_samples': 17}. Best is trial 74 with value: 4.34659148052927.
# [I 2024-10-13 20:20:20,620] Trial 80 finished with value: 4.397311444066636 and parameters: {'lambda_l1': 1.707340155616504, 'lambda_l2': 5.827343275223379, 'max_depth': 16, 'num_leaves': 221, 'feature_fraction': 0.9822802726539716, 'min_child_samples': 4}. Best is trial 74 with value: 4.34659148052927.
# [I 2024-10-13 20:20:20,832] Trial 81 finished with value: 4.4493086236809445 and parameters: {'lambda_l1': 6.57086023093886, 'lambda_l2': 6.2504405278834785, 'max_depth': 20, 'num_leaves': 247, 'feature_fraction': 0.9660027172750857, 'min_child_samples': 13}. Best is trial 74 with value: 4.34659148052927.
# [I 2024-10-13 20:20:21,133] Trial 82 finished with value: 4.427750896797827 and parameters: {'lambda_l1': 6.573192298117609, 'lambda_l2': 3.7422548940186413, 'max_depth': 27, 'num_leaves': 250, 'feature_fraction': 0.9078932611034087, 'min_child_samples': 2}. Best is trial 74 with value: 4.34659148052927.
# [I 2024-10-13 20:20:21,427] Trial 83 finished with value: 4.40321946769056 and parameters: {'lambda_l1': 5.365565989422679, 'lambda_l2': 6.090533696113754, 'max_depth': 20, 'num_leaves': 193, 'feature_fraction': 0.9105352410943162, 'min_child_samples': 3}. Best is trial 74 with value: 4.34659148052927.
# [I 2024-10-13 20:20:21,741] Trial 84 finished with value: 4.3332601981520815 and parameters: {'lambda_l1': 4.112350089723168, 'lambda_l2': 4.919715327925603, 'max_depth': 20, 'num_leaves': 242, 'feature_fraction': 0.9572840924248599, 'min_child_samples': 4}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:21,976] Trial 85 finished with value: 4.3805605023912735 and parameters: {'lambda_l1': 2.273330817501188, 'lambda_l2': 7.486881683070376, 'max_depth': 26, 'num_leaves': 245, 'feature_fraction': 0.9520767670814964, 'min_child_samples': 8}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:22,146] Trial 86 finished with value: 4.446927658574991 and parameters: {'lambda_l1': 4.787177567483562, 'lambda_l2': 5.445663526870032, 'max_depth': 24, 'num_leaves': 248, 'feature_fraction': 0.9524267987254763, 'min_child_samples': 10}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:22,304] Trial 87 finished with value: 4.40016009956808 and parameters: {'lambda_l1': 3.2830580886195744, 'lambda_l2': 8.721735166225738, 'max_depth': 22, 'num_leaves': 231, 'feature_fraction': 0.9164799651553878, 'min_child_samples': 8}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:22,454] Trial 88 finished with value: 4.408160331917977 and parameters: {'lambda_l1': 2.30074837412331, 'lambda_l2': 6.313298495438947, 'max_depth': 22, 'num_leaves': 239, 'feature_fraction': 0.9716233396771351, 'min_child_samples': 12}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:22,618] Trial 89 finished with value: 4.47209730472756 and parameters: {'lambda_l1': 0.06646328258805312, 'lambda_l2': 8.7218283439884, 'max_depth': 28, 'num_leaves': 214, 'feature_fraction': 0.8147327567137395, 'min_child_samples': 6}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:22,850] Trial 90 finished with value: 4.370738145172669 and parameters: {'lambda_l1': 1.5677421542183079, 'lambda_l2': 5.843642882217572, 'max_depth': 31, 'num_leaves': 182, 'feature_fraction': 0.9957412609961899, 'min_child_samples': 6}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:23,076] Trial 91 finished with value: 4.345574715940067 and parameters: {'lambda_l1': 1.1686599906473183, 'lambda_l2': 3.70821529202604, 'max_depth': 30, 'num_leaves': 203, 'feature_fraction': 0.9476552480467769, 'min_child_samples': 6}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:23,515] Trial 92 finished with value: 4.343638853464917 and parameters: {'lambda_l1': 0.10152564249336726, 'lambda_l2': 2.955588425783463, 'max_depth': 31, 'num_leaves': 231, 'feature_fraction': 0.9085492497705283, 'min_child_samples': 1}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:23,798] Trial 93 finished with value: 4.3779585979345566 and parameters: {'lambda_l1': 0.3901952751422097, 'lambda_l2': 3.781945171316598, 'max_depth': 27, 'num_leaves': 226, 'feature_fraction': 0.9298106548376266, 'min_child_samples': 3}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:24,027] Trial 94 finished with value: 4.426190355671221 and parameters: {'lambda_l1': 0.23295387198487805, 'lambda_l2': 4.02242309611428, 'max_depth': 29, 'num_leaves': 180, 'feature_fraction': 0.8621212353436453, 'min_child_samples': 4}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:24,226] Trial 95 finished with value: 4.396769136140389 and parameters: {'lambda_l1': 0.08266141250250447, 'lambda_l2': 2.210868660023798, 'max_depth': 30, 'num_leaves': 192, 'feature_fraction': 0.9259761466236187, 'min_child_samples': 9}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:24,601] Trial 96 finished with value: 4.351654722971349 and parameters: {'lambda_l1': 1.3097300363439495, 'lambda_l2': 5.374052643610953, 'max_depth': 31, 'num_leaves': 190, 'feature_fraction': 0.9318745603577313, 'min_child_samples': 1}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:24,955] Trial 97 finished with value: 4.404592730171307 and parameters: {'lambda_l1': 2.9099415087351037, 'lambda_l2': 5.480394510370621, 'max_depth': 32, 'num_leaves': 165, 'feature_fraction': 0.9711337324075362, 'min_child_samples': 1}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:25,127] Trial 98 finished with value: 4.434494936728267 and parameters: {'lambda_l1': 0.25877379868320816, 'lambda_l2': 7.931053066551087, 'max_depth': 29, 'num_leaves': 118, 'feature_fraction': 0.9779801072479721, 'min_child_samples': 17}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:25,359] Trial 99 finished with value: 4.376222639061313 and parameters: {'lambda_l1': 0.24089208285792885, 'lambda_l2': 5.094239734375218, 'max_depth': 32, 'num_leaves': 177, 'feature_fraction': 0.8931540583101532, 'min_child_samples': 10}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:25,524] Trial 100 finished with value: 4.413623856443408 and parameters: {'lambda_l1': 3.1466795549174518, 'lambda_l2': 3.994832678495979, 'max_depth': 32, 'num_leaves': 182, 'feature_fraction': 0.9632601765447958, 'min_child_samples': 14}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:25,737] Trial 101 finished with value: 4.4313731092606785 and parameters: {'lambda_l1': 0.005275985001805594, 'lambda_l2': 4.364615534428699, 'max_depth': 29, 'num_leaves': 194, 'feature_fraction': 0.9947071762461852, 'min_child_samples': 25}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:25,974] Trial 102 finished with value: 4.410046715024999 and parameters: {'lambda_l1': 1.717814522128913, 'lambda_l2': 0.5679676121451571, 'max_depth': 32, 'num_leaves': 238, 'feature_fraction': 0.9581618932963071, 'min_child_samples': 5}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:26,311] Trial 103 finished with value: 4.334405212152336 and parameters: {'lambda_l1': 1.3144636521219595, 'lambda_l2': 5.750470131488161, 'max_depth': 26, 'num_leaves': 200, 'feature_fraction': 0.9791851313587585, 'min_child_samples': 2}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:26,468] Trial 104 finished with value: 4.457498388861487 and parameters: {'lambda_l1': 1.8328695024238666, 'lambda_l2': 5.287965300393705, 'max_depth': 24, 'num_leaves': 161, 'feature_fraction': 0.8460909934020391, 'min_child_samples': 7}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:26,819] Trial 105 finished with value: 4.3687462471167 and parameters: {'lambda_l1': 0.9738358463566489, 'lambda_l2': 6.291817908016327, 'max_depth': 30, 'num_leaves': 213, 'feature_fraction': 0.9509185981131321, 'min_child_samples': 2}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:26,959] Trial 106 finished with value: 4.494290819188283 and parameters: {'lambda_l1': 3.359144672048558, 'lambda_l2': 5.938316080041771, 'max_depth': 32, 'num_leaves': 227, 'feature_fraction': 0.5324897363929899, 'min_child_samples': 5}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:27,128] Trial 107 finished with value: 4.3915160169410985 and parameters: {'lambda_l1': 0.4246609352782884, 'lambda_l2': 4.647304798854974, 'max_depth': 27, 'num_leaves': 251, 'feature_fraction': 0.9928397613114444, 'min_child_samples': 10}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:27,446] Trial 108 finished with value: 4.420688189187093 and parameters: {'lambda_l1': 1.8103072948095353, 'lambda_l2': 3.583979093223034, 'max_depth': 24, 'num_leaves': 182, 'feature_fraction': 0.9709905442651248, 'min_child_samples': 3}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:27,593] Trial 109 finished with value: 4.510545033751252 and parameters: {'lambda_l1': 8.96974791109002, 'lambda_l2': 0.3229556652562975, 'max_depth': 32, 'num_leaves': 231, 'feature_fraction': 0.540857914193961, 'min_child_samples': 45}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:27,866] Trial 110 finished with value: 4.46806391377131 and parameters: {'lambda_l1': 1.361887562216324, 'lambda_l2': 3.0188096548211543, 'max_depth': 31, 'num_leaves': 225, 'feature_fraction': 0.7691571105434459, 'min_child_samples': 3}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:28,099] Trial 111 finished with value: 4.4010907334526435 and parameters: {'lambda_l1': 2.5993846635722053, 'lambda_l2': 6.0881870551816935, 'max_depth': 30, 'num_leaves': 176, 'feature_fraction': 0.9397969486762469, 'min_child_samples': 11}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:28,301] Trial 112 finished with value: 4.46470704540141 and parameters: {'lambda_l1': 1.4047367533362043, 'lambda_l2': 5.773506655426882, 'max_depth': 25, 'num_leaves': 191, 'feature_fraction': 0.9218852198007628, 'min_child_samples': 14}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:28,564] Trial 113 finished with value: 4.456687224810067 and parameters: {'lambda_l1': 1.1714318597394824, 'lambda_l2': 7.238255206792145, 'max_depth': 32, 'num_leaves': 156, 'feature_fraction': 0.8745858364880689, 'min_child_samples': 3}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:28,824] Trial 114 finished with value: 4.3376601582566865 and parameters: {'lambda_l1': 1.3313023061237488, 'lambda_l2': 4.5936138540240385, 'max_depth': 31, 'num_leaves': 171, 'feature_fraction': 0.9935581295479622, 'min_child_samples': 7}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:28,957] Trial 115 finished with value: 4.539114939015245 and parameters: {'lambda_l1': 2.922057638860835, 'lambda_l2': 1.7629870212473011, 'max_depth': 3, 'num_leaves': 2, 'feature_fraction': 0.9295376038530582, 'min_child_samples': 26}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:29,359] Trial 116 finished with value: 4.436575644533325 and parameters: {'lambda_l1': 1.0179189404879825, 'lambda_l2': 6.265378208987421, 'max_depth': 29, 'num_leaves': 188, 'feature_fraction': 0.9838434994072951, 'min_child_samples': 1}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:29,577] Trial 117 finished with value: 4.397149314547394 and parameters: {'lambda_l1': 1.0571674185004747, 'lambda_l2': 3.12045737733924, 'max_depth': 32, 'num_leaves': 210, 'feature_fraction': 0.9466155034483689, 'min_child_samples': 12}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:29,709] Trial 118 finished with value: 4.5581148335606265 and parameters: {'lambda_l1': 2.401790493893144, 'lambda_l2': 6.43805508083169, 'max_depth': 24, 'num_leaves': 228, 'feature_fraction': 0.09272574804824979, 'min_child_samples': 16}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:29,857] Trial 119 finished with value: 4.537736966890107 and parameters: {'lambda_l1': 3.1925621816160765, 'lambda_l2': 8.809000953387232, 'max_depth': 14, 'num_leaves': 81, 'feature_fraction': 0.42854997365830916, 'min_child_samples': 94}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:29,984] Trial 120 finished with value: 4.55003523443348 and parameters: {'lambda_l1': 7.674943942517641, 'lambda_l2': 8.09978040248432, 'max_depth': 31, 'num_leaves': 234, 'feature_fraction': 0.05697129815536395, 'min_child_samples': 69}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:30,122] Trial 121 finished with value: 4.548052844383333 and parameters: {'lambda_l1': 1.2341389656946604, 'lambda_l2': 9.24027420183901, 'max_depth': 3, 'num_leaves': 173, 'feature_fraction': 0.6839357936629947, 'min_child_samples': 95}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:30,320] Trial 122 finished with value: 4.388178425968797 and parameters: {'lambda_l1': 5.40685933528138, 'lambda_l2': 4.43557996873404, 'max_depth': 9, 'num_leaves': 235, 'feature_fraction': 0.9406718304288959, 'min_child_samples': 9}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:30,776] Trial 123 finished with value: 4.40918555229311 and parameters: {'lambda_l1': 3.077225688002057, 'lambda_l2': 5.5555581798752875, 'max_depth': 30, 'num_leaves': 224, 'feature_fraction': 0.9548274002712032, 'min_child_samples': 1}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:30,905] Trial 124 finished with value: 4.547692066646723 and parameters: {'lambda_l1': 2.565778485839971, 'lambda_l2': 3.7241245577153026, 'max_depth': 22, 'num_leaves': 88, 'feature_fraction': 0.7591073493228854, 'min_child_samples': 69}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:31,154] Trial 125 finished with value: 4.362360020030105 and parameters: {'lambda_l1': 1.9584382818739787, 'lambda_l2': 4.120471741822481, 'max_depth': 30, 'num_leaves': 72, 'feature_fraction': 0.9214086176913613, 'min_child_samples': 6}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:31,346] Trial 126 finished with value: 4.423072773364653 and parameters: {'lambda_l1': 3.7483224462241296, 'lambda_l2': 5.122284476092199, 'max_depth': 32, 'num_leaves': 67, 'feature_fraction': 0.9855439776624375, 'min_child_samples': 12}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:31,574] Trial 127 finished with value: 4.4866618797216 and parameters: {'lambda_l1': 2.098083735742674, 'lambda_l2': 3.595642219106284, 'max_depth': 32, 'num_leaves': 106, 'feature_fraction': 0.77519506453542, 'min_child_samples': 5}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:31,747] Trial 128 finished with value: 4.450041435196471 and parameters: {'lambda_l1': 1.4505002139376535, 'lambda_l2': 4.933369053351525, 'max_depth': 29, 'num_leaves': 30, 'feature_fraction': 0.9920873026431334, 'min_child_samples': 26}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:32,012] Trial 129 finished with value: 4.448904311082768 and parameters: {'lambda_l1': 1.4528162541960141, 'lambda_l2': 2.065189858851817, 'max_depth': 20, 'num_leaves': 219, 'feature_fraction': 0.7012151012816753, 'min_child_samples': 2}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:32,109] Trial 130 finished with value: 4.546050786036949 and parameters: {'lambda_l1': 7.00371549065323, 'lambda_l2': 4.320641963343977, 'max_depth': 13, 'num_leaves': 205, 'feature_fraction': 0.5164144685705733, 'min_child_samples': 96}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:32,236] Trial 131 finished with value: 4.483398247355934 and parameters: {'lambda_l1': 1.4703409023681997, 'lambda_l2': 3.121376915041078, 'max_depth': 16, 'num_leaves': 90, 'feature_fraction': 0.7929927277541295, 'min_child_samples': 16}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:32,379] Trial 132 finished with value: 4.44524628477486 and parameters: {'lambda_l1': 1.582688927979816, 'lambda_l2': 4.122993770187187, 'max_depth': 31, 'num_leaves': 19, 'feature_fraction': 0.9147821216141991, 'min_child_samples': 2}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:32,659] Trial 133 finished with value: 4.414137628004402 and parameters: {'lambda_l1': 2.4567380148252798, 'lambda_l2': 4.95684353002335, 'max_depth': 32, 'num_leaves': 186, 'feature_fraction': 0.874122307338344, 'min_child_samples': 1}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:32,850] Trial 134 finished with value: 4.38568660163833 and parameters: {'lambda_l1': 0.4578018714272549, 'lambda_l2': 5.25598222906854, 'max_depth': 31, 'num_leaves': 143, 'feature_fraction': 0.9975055472681222, 'min_child_samples': 9}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:32,953] Trial 135 finished with value: 4.5426809164949065 and parameters: {'lambda_l1': 5.011333869177804, 'lambda_l2': 9.290664456695453, 'max_depth': 6, 'num_leaves': 221, 'feature_fraction': 0.05017538224413526, 'min_child_samples': 70}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:33,207] Trial 136 finished with value: 4.370684734120685 and parameters: {'lambda_l1': 0.4759961292546082, 'lambda_l2': 8.056689318575938, 'max_depth': 32, 'num_leaves': 222, 'feature_fraction': 0.941927070409594, 'min_child_samples': 4}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:33,342] Trial 137 finished with value: 4.450369225328456 and parameters: {'lambda_l1': 0.5235662746908606, 'lambda_l2': 8.642484341747814, 'max_depth': 32, 'num_leaves': 182, 'feature_fraction': 0.9299502842479309, 'min_child_samples': 24}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:33,571] Trial 138 finished with value: 4.35892742462522 and parameters: {'lambda_l1': 1.5124158694374612, 'lambda_l2': 7.181583045714, 'max_depth': 29, 'num_leaves': 230, 'feature_fraction': 0.9449992404315181, 'min_child_samples': 8}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:33,679] Trial 139 finished with value: 4.509536107283951 and parameters: {'lambda_l1': 1.663626614025978, 'lambda_l2': 4.740057007778523, 'max_depth': 18, 'num_leaves': 217, 'feature_fraction': 0.6249768213569931, 'min_child_samples': 31}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:33,831] Trial 140 finished with value: 4.430507141899243 and parameters: {'lambda_l1': 1.1203896239830187, 'lambda_l2': 2.6549141265102723, 'max_depth': 31, 'num_leaves': 100, 'feature_fraction': 0.9960063297388762, 'min_child_samples': 23}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:34,047] Trial 141 finished with value: 4.333819271478035 and parameters: {'lambda_l1': 0.606342954415731, 'lambda_l2': 6.6371169909626655, 'max_depth': 31, 'num_leaves': 230, 'feature_fraction': 0.9130196872725076, 'min_child_samples': 8}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:34,138] Trial 142 finished with value: 4.53620598892271 and parameters: {'lambda_l1': 6.5846971800548895, 'lambda_l2': 6.0995288800789496, 'max_depth': 20, 'num_leaves': 193, 'feature_fraction': 0.13117211610283414, 'min_child_samples': 46}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:34,281] Trial 143 finished with value: 4.462037045281073 and parameters: {'lambda_l1': 3.919631853083267, 'lambda_l2': 3.01085784450791, 'max_depth': 21, 'num_leaves': 236, 'feature_fraction': 0.9873090279682796, 'min_child_samples': 14}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:34,434] Trial 144 finished with value: 4.444107360817537 and parameters: {'lambda_l1': 1.2284896277234632, 'lambda_l2': 6.927054788217997, 'max_depth': 29, 'num_leaves': 255, 'feature_fraction': 0.7970738058414435, 'min_child_samples': 10}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:34,545] Trial 145 finished with value: 4.479696670828816 and parameters: {'lambda_l1': 0.9949999936758512, 'lambda_l2': 7.886946141867896, 'max_depth': 30, 'num_leaves': 249, 'feature_fraction': 0.9732880748809741, 'min_child_samples': 46}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:34,688] Trial 146 finished with value: 4.44292742031299 and parameters: {'lambda_l1': 0.5883427451127659, 'lambda_l2': 6.13282380246645, 'max_depth': 20, 'num_leaves': 251, 'feature_fraction': 0.9676295928939359, 'min_child_samples': 35}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:35,009] Trial 147 finished with value: 4.4561974819701 and parameters: {'lambda_l1': 0.4094570477465122, 'lambda_l2': 6.719242451890184, 'max_depth': 26, 'num_leaves': 240, 'feature_fraction': 0.7540223126397193, 'min_child_samples': 1}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:35,342] Trial 148 finished with value: 4.359116098862736 and parameters: {'lambda_l1': 3.476026761139335, 'lambda_l2': 4.262454117829794, 'max_depth': 16, 'num_leaves': 251, 'feature_fraction': 0.9751207558691616, 'min_child_samples': 3}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:35,630] Trial 149 finished with value: 4.4355919194270905 and parameters: {'lambda_l1': 2.6371664101917984, 'lambda_l2': 3.5317391449745967, 'max_depth': 26, 'num_leaves': 88, 'feature_fraction': 0.9831142789389866, 'min_child_samples': 4}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:36,086] Trial 150 finished with value: 4.347434732391574 and parameters: {'lambda_l1': 0.15877361344855578, 'lambda_l2': 0.27623283782957353, 'max_depth': 31, 'num_leaves': 216, 'feature_fraction': 0.630832910667235, 'min_child_samples': 1}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:36,342] Trial 151 finished with value: 4.4313311790701215 and parameters: {'lambda_l1': 1.5460040649244333, 'lambda_l2': 1.5265613230857058, 'max_depth': 32, 'num_leaves': 203, 'feature_fraction': 0.46484887665755603, 'min_child_samples': 1}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:36,534] Trial 152 finished with value: 4.471073139567899 and parameters: {'lambda_l1': 0.3224815014667677, 'lambda_l2': 0.49432943615670233, 'max_depth': 29, 'num_leaves': 197, 'feature_fraction': 0.6488177147102783, 'min_child_samples': 15}. Best is trial 84 with value: 4.3332601981520815.
# [I 2024-10-13 20:20:36,859] Trial 153 finished with value: 4.362299596335725 and parameters: {'lambda_l1': 0.0636320457571298, 'lambda_l2': 0.0877412043693204, 'max_depth': 31, 'num_leaves': 181, 'feature_fraction': 0.8471822809682266, 'min_child_samples': 2}. Best is trial 84 with value: 4.3332601981520815.
# ...
# [I 2024-10-13 20:21:35,051] Trial 449 finished with value: 4.499547472264888 and parameters: {'lambda_l1': 8.082460712839072, 'lambda_l2': 6.4399680699560085, 'max_depth': 7, 'num_leaves': 29, 'feature_fraction': 0.5632714411004652, 'min_child_samples': 15}. Best is trial 268 with value: 4.295782630358793.
# [I 2024-10-13 20:21:35,182] Trial 450 finished with value: 4.552937716892888 and parameters: {'lambda_l1': 7.427363369267384, 'lambda_l2': 2.4283518159662165, 'max_depth': 11, 'num_leaves': 107, 'feature_fraction': 0.20215005161968536, 'min_child_samples': 76}. Best is trial 268 with value: 4.295782630358793.
# [I 2024-10-13 20:21:35,351] Trial 451 finished with value: 4.407729523072068 and parameters: {'lambda_l1': 2.702154793576087, 'lambda_l2': 2.945231597370337, 'max_depth': 11, 'num_leaves': 141, 'feature_fraction': 0.9540365259984952, 'min_child_samples': 13}. Best is trial 268 with value: 4.295782630358793.
# [I 2024-10-13 20:21:35,590] Trial 452 finished with value: 4.42629267830002 and parameters: {'lambda_l1': 2.3246149478128735, 'lambda_l2': 5.694312379092814, 'max_depth': 25, 'num_leaves': 252, 'feature_fraction': 0.9382432463507817, 'min_child_samples': 14}. Best is trial 268 with value: 4.295782630358793.
# [I 2024-10-13 20:21:35,740] Trial 453 finished with value: 4.515615814237096 and parameters: {'lambda_l1': 4.165511878525691, 'lambda_l2': 2.3355350533863493, 'max_depth': 12, 'num_leaves': 33, 'feature_fraction': 0.43948585579063165, 'min_child_samples': 47}. Best is trial 268 with value: 4.295782630358793.
# [I 2024-10-13 20:21:36,073] Trial 454 finished with value: 4.373225943250389 and parameters: {'lambda_l1': 0.27054450634759486, 'lambda_l2': 7.666525936104781, 'max_depth': 26, 'num_leaves': 256, 'feature_fraction': 0.9442259573436435, 'min_child_samples': 4}. Best is trial 268 with value: 4.295782630358793.
# [I 2024-10-13 20:21:36,548] Trial 455 finished with value: 4.334855918965864 and parameters: {'lambda_l1': 0.6322412772148644, 'lambda_l2': 9.566904274575997, 'max_depth': 18, 'num_leaves': 238, 'feature_fraction': 0.9003193754348684, 'min_child_samples': 1}. Best is trial 268 with value: 4.295782630358793.
# [I 2024-10-13 20:21:36,720] Trial 456 finished with value: 4.497342815731124 and parameters: {'lambda_l1': 0.1431152397686168, 'lambda_l2': 9.434747280510063, 'max_depth': 15, 'num_leaves': 229, 'feature_fraction': 0.8622872206326125, 'min_child_samples': 32}. Best is trial 268 with value: 4.295782630358793.
# [I 2024-10-13 20:21:37,040] Trial 457 finished with value: 4.369076581507477 and parameters: {'lambda_l1': 0.921407831323258, 'lambda_l2': 9.704282237469025, 'max_depth': 19, 'num_leaves': 226, 'feature_fraction': 0.932300431233261, 'min_child_samples': 7}. Best is trial 268 with value: 4.295782630358793.
# [I 2024-10-13 20:21:37,432] Trial 458 finished with value: 4.385184211292681 and parameters: {'lambda_l1': 0.8795101735644311, 'lambda_l2': 9.901791370534042, 'max_depth': 21, 'num_leaves': 198, 'feature_fraction': 0.8194475216478114, 'min_child_samples': 1}. Best is trial 268 with value: 4.295782630358793.
# [I 2024-10-13 20:21:37,656] Trial 459 finished with value: 4.490371194800725 and parameters: {'lambda_l1': 2.2712135138271545, 'lambda_l2': 9.815699159475715, 'max_depth': 15, 'num_leaves': 228, 'feature_fraction': 0.7316679191424001, 'min_child_samples': 14}. Best is trial 268 with value: 4.295782630358793.
# [I 2024-10-13 20:21:37,842] Trial 460 finished with value: 4.488330378343852 and parameters: {'lambda_l1': 4.636944584664121, 'lambda_l2': 0.052104751104045555, 'max_depth': 14, 'num_leaves': 187, 'feature_fraction': 0.8775712376339331, 'min_child_samples': 59}. Best is trial 268 with value: 4.295782630358793.
# [I 2024-10-13 20:21:38,051] Trial 461 finished with value: 4.460442846028861 and parameters: {'lambda_l1': 4.891778870561987, 'lambda_l2': 4.9253566198148615, 'max_depth': 9, 'num_leaves': 150, 'feature_fraction': 0.8537441319898268, 'min_child_samples': 37}. Best is trial 268 with value: 4.295782630358793.
# [I 2024-10-13 20:21:38,392] Trial 462 finished with value: 4.380595676230361 and parameters: {'lambda_l1': 8.227994663676737, 'lambda_l2': 3.3390505415995166, 'max_depth': 26, 'num_leaves': 185, 'feature_fraction': 0.9744075732057577, 'min_child_samples': 2}. Best is trial 268 with value: 4.295782630358793.
# [I 2024-10-13 20:21:38,530] Trial 463 finished with value: 4.553504035294768 and parameters: {'lambda_l1': 3.220705825825494, 'lambda_l2': 5.912378872152598, 'max_depth': 32, 'num_leaves': 186, 'feature_fraction': 0.04129759010345402, 'min_child_samples': 80}. Best is trial 268 with value: 4.295782630358793.
# [I 2024-10-13 20:21:38,835] Trial 464 finished with value: 4.316246602819676 and parameters: {'lambda_l1': 2.492406691144696, 'lambda_l2': 4.924912674090019, 'max_depth': 13, 'num_leaves': 161, 'feature_fraction': 0.9956136373120343, 'min_child_samples': 2}. Best is trial 268 with value: 4.295782630358793.
# [I 2024-10-13 20:21:38,994] Trial 465 finished with value: 4.503782702308173 and parameters: {'lambda_l1': 3.7764287306406183, 'lambda_l2': 4.792436279655473, 'max_depth': 28, 'num_leaves': 209, 'feature_fraction': 0.6353856305324257, 'min_child_samples': 45}. Best is trial 268 with value: 4.295782630358793.
# [I 2024-10-13 20:21:39,118] Trial 466 finished with value: 4.545712095850303 and parameters: {'lambda_l1': 5.69215710754147, 'lambda_l2': 5.135371483935805, 'max_depth': 28, 'num_leaves': 169, 'feature_fraction': 0.750455479055664, 'min_child_samples': 76}. Best is trial 268 with value: 4.295782630358793.
# [I 2024-10-13 20:21:39,310] Trial 467 finished with value: 4.470788000058854 and parameters: {'lambda_l1': 1.9265419238293207, 'lambda_l2': 7.6946684358735595, 'max_depth': 20, 'num_leaves': 221, 'feature_fraction': 0.8098174161844339, 'min_child_samples': 6}. Best is trial 268 with value: 4.295782630358793.
# [I 2024-10-13 20:21:39,471] Trial 468 finished with value: 4.501525558103542 and parameters: {'lambda_l1': 3.873335394194741, 'lambda_l2': 5.180828371615524, 'max_depth': 10, 'num_leaves': 151, 'feature_fraction': 0.5208501594015804, 'min_child_samples': 32}. Best is trial 268 with value: 4.295782630358793.
# [I 2024-10-13 20:21:39,625] Trial 469 finished with value: 4.5347893956464915 and parameters: {'lambda_l1': 9.862354439935034, 'lambda_l2': 3.6091335138975835, 'max_depth': 2, 'num_leaves': 53, 'feature_fraction': 0.7580805650068398, 'min_child_samples': 80}. Best is trial 268 with value: 4.295782630358793.
# [I 2024-10-13 20:21:39,798] Trial 470 finished with value: 4.50730225697243 and parameters: {'lambda_l1': 2.89590470462194, 'lambda_l2': 1.9639734645016986, 'max_depth': 10, 'num_leaves': 110, 'feature_fraction': 0.5144377989455748, 'min_child_samples': 25}. Best is trial 268 with value: 4.295782630358793.
# [I 2024-10-13 20:21:39,938] Trial 471 finished with value: 4.4970676660509765 and parameters: {'lambda_l1': 2.570019962871608, 'lambda_l2': 4.7981154661234005, 'max_depth': 5, 'num_leaves': 20, 'feature_fraction': 0.8136570934435581, 'min_child_samples': 25}. Best is trial 268 with value: 4.295782630358793.
# [I 2024-10-13 20:21:40,066] Trial 472 finished with value: 4.546124915571489 and parameters: {'lambda_l1': 6.426217206056344, 'lambda_l2': 7.130301427347504, 'max_depth': 11, 'num_leaves': 108, 'feature_fraction': 0.36203756591458836, 'min_child_samples': 25}. Best is trial 268 with value: 4.295782630358793.
# [I 2024-10-13 20:21:40,388] Trial 473 finished with value: 4.32665972008977 and parameters: {'lambda_l1': 2.1898126845041963, 'lambda_l2': 7.131032096067653, 'max_depth': 12, 'num_leaves': 233, 'feature_fraction': 0.9663053846585354, 'min_child_samples': 1}. Best is trial 268 with value: 4.295782630358793.
# [I 2024-10-13 20:21:40,561] Trial 474 finished with value: 4.436985187029596 and parameters: {'lambda_l1': 0.33598589907938087, 'lambda_l2': 7.339775836250837, 'max_depth': 13, 'num_leaves': 212, 'feature_fraction': 0.8421075395207818, 'min_child_samples': 9}. Best is trial 268 with value: 4.295782630358793.
# [I 2024-10-13 20:21:40,755] Trial 475 finished with value: 4.387532812326165 and parameters: {'lambda_l1': 2.4220381990310056, 'lambda_l2': 5.016256105852133, 'max_depth': 8, 'num_leaves': 157, 'feature_fraction': 0.9188854522276528, 'min_child_samples': 1}. Best is trial 268 with value: 4.295782630358793.
# [I 2024-10-13 20:21:40,877] Trial 476 finished with value: 4.504251176712402 and parameters: {'lambda_l1': 2.612590122820542, 'lambda_l2': 8.26805582155483, 'max_depth': 3, 'num_leaves': 198, 'feature_fraction': 0.960075847938257, 'min_child_samples': 26}. Best is trial 268 with value: 4.295782630358793.
# [I 2024-10-13 20:21:41,025] Trial 477 finished with value: 4.530461549298225 and parameters: {'lambda_l1': 3.6179147118709034, 'lambda_l2': 0.5824926961949233, 'max_depth': 6, 'num_leaves': 128, 'feature_fraction': 0.4008544277365816, 'min_child_samples': 65}. Best is trial 268 with value: 4.295782630358793.
# [I 2024-10-13 20:21:41,232] Trial 478 finished with value: 4.491532158825129 and parameters: {'lambda_l1': 0.12197700676521483, 'lambda_l2': 9.777213471823313, 'max_depth': 8, 'num_leaves': 248, 'feature_fraction': 0.7471533054788579, 'min_child_samples': 11}. Best is trial 268 with value: 4.295782630358793.
# [I 2024-10-13 20:21:41,510] Trial 479 finished with value: 4.382216737160708 and parameters: {'lambda_l1': 1.9249783810001289, 'lambda_l2': 8.052322622638254, 'max_depth': 17, 'num_leaves': 256, 'feature_fraction': 0.9166945113466713, 'min_child_samples': 7}. Best is trial 268 with value: 4.295782630358793.
# [I 2024-10-13 20:21:41,667] Trial 480 finished with value: 4.4976028252909686 and parameters: {'lambda_l1': 4.1625702823736805, 'lambda_l2': 3.808195800081296, 'max_depth': 18, 'num_leaves': 86, 'feature_fraction': 0.7907180861950711, 'min_child_samples': 43}. Best is trial 268 with value: 4.295782630358793.
# [I 2024-10-13 20:21:41,926] Trial 481 finished with value: 4.451864129292396 and parameters: {'lambda_l1': 3.211346055706686, 'lambda_l2': 7.917190236399005, 'max_depth': 31, 'num_leaves': 252, 'feature_fraction': 0.9113826867089798, 'min_child_samples': 5}. Best is trial 268 with value: 4.295782630358793.
# [I 2024-10-13 20:21:42,138] Trial 482 finished with value: 4.3507583433854045 and parameters: {'lambda_l1': 3.2351910124578684, 'lambda_l2': 7.237831608914337, 'max_depth': 14, 'num_leaves': 194, 'feature_fraction': 0.8885057894002145, 'min_child_samples': 6}. Best is trial 268 with value: 4.295782630358793.
# [I 2024-10-13 20:21:42,275] Trial 483 finished with value: 4.5282754701091585 and parameters: {'lambda_l1': 6.239371291101959, 'lambda_l2': 2.09233261635394, 'max_depth': 2, 'num_leaves': 82, 'feature_fraction': 0.6857971646406473, 'min_child_samples': 44}. Best is trial 268 with value: 4.295782630358793.
# [I 2024-10-13 20:21:42,415] Trial 484 finished with value: 4.55200354019493 and parameters: {'lambda_l1': 5.387083581798235, 'lambda_l2': 3.094372092643683, 'max_depth': 29, 'num_leaves': 117, 'feature_fraction': 0.30915725812215034, 'min_child_samples': 2}. Best is trial 268 with value: 4.295782630358793.
# [I 2024-10-13 20:21:42,631] Trial 485 finished with value: 4.444920940613351 and parameters: {'lambda_l1': 6.9717063092381615, 'lambda_l2': 5.922394619629614, 'max_depth': 22, 'num_leaves': 93, 'feature_fraction': 0.7837174215823585, 'min_child_samples': 4}. Best is trial 268 with value: 4.295782630358793.
# [I 2024-10-13 20:21:42,764] Trial 486 finished with value: 4.548382919024751 and parameters: {'lambda_l1': 5.22049379733829, 'lambda_l2': 2.0302138503264, 'max_depth': 25, 'num_leaves': 18, 'feature_fraction': 0.06570177922938314, 'min_child_samples': 93}. Best is trial 268 with value: 4.295782630358793.
# [I 2024-10-13 20:21:42,987] Trial 487 finished with value: 4.3663929401914805 and parameters: {'lambda_l1': 3.139997481441205, 'lambda_l2': 7.479956078451607, 'max_depth': 9, 'num_leaves': 201, 'feature_fraction': 0.9093850706725045, 'min_child_samples': 1}. Best is trial 268 with value: 4.295782630358793.
# [I 2024-10-13 20:21:43,134] Trial 488 finished with value: 4.500771573523877 and parameters: {'lambda_l1': 5.027445338815453, 'lambda_l2': 3.059791705225667, 'max_depth': 22, 'num_leaves': 69, 'feature_fraction': 0.5967215087812463, 'min_child_samples': 61}. Best is trial 268 with value: 4.295782630358793.
# [I 2024-10-13 20:21:43,251] Trial 489 finished with value: 4.547050379434095 and parameters: {'lambda_l1': 9.424459827252797, 'lambda_l2': 7.499933508675298, 'max_depth': 4, 'num_leaves': 191, 'feature_fraction': 0.613347816582533, 'min_child_samples': 85}. Best is trial 268 with value: 4.295782630358793.
# [I 2024-10-13 20:21:43,347] Trial 490 finished with value: 4.5538908597743655 and parameters: {'lambda_l1': 7.404909580464093, 'lambda_l2': 8.639989482382788, 'max_depth': 29, 'num_leaves': 15, 'feature_fraction': 0.3462883928657534, 'min_child_samples': 37}. Best is trial 268 with value: 4.295782630358793.
# [I 2024-10-13 20:21:43,484] Trial 491 finished with value: 4.544157939073452 and parameters: {'lambda_l1': 0.5116244245552064, 'lambda_l2': 0.0015171648399201487, 'max_depth': 22, 'num_leaves': 236, 'feature_fraction': 0.5397712792749909, 'min_child_samples': 81}. Best is trial 268 with value: 4.295782630358793.
# [I 2024-10-13 20:21:43,600] Trial 492 finished with value: 4.549885535141676 and parameters: {'lambda_l1': 6.697120428702246, 'lambda_l2': 0.01380986155665731, 'max_depth': 19, 'num_leaves': 85, 'feature_fraction': 0.1086708416329133, 'min_child_samples': 54}. Best is trial 268 with value: 4.295782630358793.
# [I 2024-10-13 20:21:43,741] Trial 493 finished with value: 4.487080222112002 and parameters: {'lambda_l1': 7.127072116936054, 'lambda_l2': 4.101926768825024, 'max_depth': 12, 'num_leaves': 200, 'feature_fraction': 0.7686589160857299, 'min_child_samples': 13}. Best is trial 268 with value: 4.295782630358793.
# [I 2024-10-13 20:21:43,879] Trial 494 finished with value: 4.534299842086789 and parameters: {'lambda_l1': 3.9041027228024943, 'lambda_l2': 3.939687559495346, 'max_depth': 19, 'num_leaves': 89, 'feature_fraction': 0.50731465230136, 'min_child_samples': 77}. Best is trial 268 with value: 4.295782630358793.
# [I 2024-10-13 20:21:44,237] Trial 495 finished with value: 4.365688267417047 and parameters: {'lambda_l1': 2.5513861973103085, 'lambda_l2': 6.660663063661189, 'max_depth': 19, 'num_leaves': 222, 'feature_fraction': 0.9768138483248602, 'min_child_samples': 2}. Best is trial 268 with value: 4.295782630358793.
# [I 2024-10-13 20:21:44,401] Trial 496 finished with value: 4.54526620355293 and parameters: {'lambda_l1': 5.86311900541758, 'lambda_l2': 2.7405109274968322, 'max_depth': 11, 'num_leaves': 159, 'feature_fraction': 0.8067515677068909, 'min_child_samples': 84}. Best is trial 268 with value: 4.295782630358793.
# [I 2024-10-13 20:21:44,720] Trial 497 finished with value: 4.32568502613598 and parameters: {'lambda_l1': 0.6425755043807111, 'lambda_l2': 9.712352059014844, 'max_depth': 15, 'num_leaves': 232, 'feature_fraction': 0.9275554850766604, 'min_child_samples': 3}. Best is trial 268 with value: 4.295782630358793.
# [I 2024-10-13 20:21:44,913] Trial 498 finished with value: 4.42461555323756 and parameters: {'lambda_l1': 0.4367362477495191, 'lambda_l2': 8.772005218295519, 'max_depth': 13, 'num_leaves': 252, 'feature_fraction': 0.9364086377327145, 'min_child_samples': 20}. Best is trial 268 with value: 4.295782630358793.
# [I 2024-10-13 20:21:45,079] Trial 499 finished with value: 4.431035631202805 and parameters: {'lambda_l1': 5.646011551716638, 'lambda_l2': 9.506804932412743, 'max_depth': 10, 'num_leaves': 211, 'feature_fraction': 0.9128322865985545, 'min_child_samples': 22}. Best is trial 268 with value: 4.295782630358793.
# {'lambda_l1': 1.4310269647499527,
#  'lambda_l2': 4.657942794213137,
#  'max_depth': 27,
#  'num_leaves': 223,
#  'feature_fraction': 0.975320633437365,
#  'min_child_samples': 2}

# %%
params = (
    {
        'random_state': 22,
        'metric': 'mean_squared_error',
        'verbosity': -1,
        'n_estimators': 500,
        'early_stopping_round': 25,
        'monotone_constraints': monotone_contraints,
    } |
    study.best_params
)

testing_data = []
mod = LGBMRegressor(**params)
for X_train, X_val, X_test, y_train, y_val, y_test, df_mod_oos in cv_data:
    mod.fit(
        X_train, 
        y_train, 
        eval_set=(X_val, y_val),
    )
    
    testing_data.append(df_mod_oos.assign(Prediction=mod.predict(X_test)))

df_test = pd.concat(testing_data, ignore_index=True)

df_test
# Out:
#       Season  Week             Name Position Team  Fantasy Points  Rank  \
# 0       2020     5    justin tucker        K  BAL             9.0   NaN
# 1       2020     5  harrison butker        K   KC             6.0   NaN
# 2       2020     5         wil lutz        K   NO            15.0   NaN
# 3       2020     5    greg zuerlein        K  DAL            14.0   NaN
# 4       2020     5     robbie gould        K   SF             5.0   NaN
# ...      ...   ...              ...      ...  ...             ...   ...
# 1941    2023    17      matt prater        K  ARI             9.0   NaN
# 1942    2023    17     mason crosby        K  NYG             5.0   NaN
# 1943    2023    17    greg zuerlein        K  NYJ             9.0   NaN
# 1944    2023    17        joey slye        K  WAS             5.0   NaN
# 1945    2023    17      chad ryland        K   NE             2.0   NaN
#
#       Position Rank  Adjusted Passing Yards Projection  \
# 0                 1                                NaN
# 1                 2                                NaN
# 2                 3                                NaN
# 3                 4                                NaN
# 4                 5                                NaN
# ...             ...                                ...
# 1941             27                                NaN
# 1942             28                                NaN
# 1943             30                                NaN
# 1944             31                                NaN
# 1945             32                                NaN
#
#       Adjusted Passing Touchdowns Projection  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 1941                                     NaN
# 1942                                     NaN
# 1943                                     NaN
# 1944                                     NaN
# 1945                                     NaN
#
#       Adjusted Interceptions Projection  Adjusted Rushing Yards Projection  \
# 0                                   NaN                                NaN
# 1                                   NaN                                NaN
# 2                                   NaN                                NaN
# 3                                   NaN                                NaN
# 4                                   NaN                                NaN
# ...                                 ...                                ...
# 1941                                NaN                                NaN
# 1942                                NaN                                NaN
# 1943                                NaN                                NaN
# 1944                                NaN                                NaN
# 1945                                NaN                                NaN
#
#       Adjusted Receiving Yards Projection  Adjusted Receptions Projection  \
# 0                                     NaN                             NaN
# 1                                     NaN                             NaN
# 2                                     NaN                             NaN
# 3                                     NaN                             NaN
# 4                                     NaN                             NaN
# ...                                   ...                             ...
# 1941                                  NaN                             NaN
# 1942                                  NaN                             NaN
# 1943                                  NaN                             NaN
# 1944                                  NaN                             NaN
# 1945                                  NaN                             NaN
#
#       Anytime Touchdown Probability  Location  Team Projected Score  \
# 0                               NaN       1.0                 30.50
# 1                               NaN       1.0                 32.50
# 2                               NaN       1.0                 28.25
# 3                               NaN       1.0                 29.75
# 4                               NaN       1.0                 29.50
# ...                             ...       ...                   ...
# 1941                            NaN      -1.0                 17.75
# 1942                            NaN       1.0                 18.75
# 1943                            NaN      -1.0                 13.25
# 1944                            NaN       1.0                 17.25
# 1945                            NaN      -1.0                 12.75
#
#       Opponent Projected Score  Prediction
# 0                        18.50    8.038058
# 1                        22.00    7.361360
# 2                        21.25    9.209039
# 3                        22.25    8.777351
# 4                        21.00    8.307377
# ...                        ...         ...
# 1941                     30.25    7.195171
# 1942                     24.75    7.724417
# 1943                     20.25    5.899660
# 1944                     31.25    6.369704
# 1945                     27.25    6.340524
#
# [1946 rows x 19 columns]

# %%
df_test['Prediction'].describe()
# Out:
# count    1946.000000
# mean        7.534101
# std         0.952461
# min         4.685814
# 25%         6.869084
# 50%         7.537391
# 75%         8.243115
# max        10.055661
# Name: Prediction, dtype: float64

# %%
(df_test['Fantasy Points'] - df_test['Prediction']).describe()
# Out:
# count    1946.000000
# mean        0.121090
# std         4.295179
# min       -10.417323
# 25%        -2.890293
# 50%        -0.364826
# 75%         2.831687
# max        16.339972
# dtype: float64

# %%
(df_test['Fantasy Points'] - df_test['Prediction']).abs().describe()
# Out:
# count    1946.000000
# mean        3.425422
# std         2.593007
# min         0.003417
# 25%         1.405807
# 50%         2.879792
# 75%         4.953895
# max        16.339972
# dtype: float64

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(df_test['Fantasy Points'], df_test['Prediction'], squared=False)
# Out:
# 4.295782630358793

# %%
from sklearn.metrics import mean_absolute_error

mean_absolute_error(df_test['Fantasy Points'], df_test['Prediction'])
# Out:
# 3.4254220834089386

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6, 6), dpi=100)

ax = sns.regplot(
    data=df_test,
    x='Prediction',
    y='Fantasy Points',
    scatter_kws={'alpha': 0.10, 'color': sns.color_palette()[1]},
    line_kws={'color': sns.color_palette()[0]},
)

plt.title('Actual Fantasy Points vs. Predicted Fantasy Points')
plt.xlabel('Predicted Fantasy Points Scored')
plt.ylabel('Actual Fantasy Points Scored')

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6, 6), dpi=100)

ax = sns.regplot(
    data=df_test.assign(f=(df_test['Fantasy Points'] - df_test['Prediction'])),
    x='Prediction',
    y='f',
    scatter_kws={'alpha': 0.10, 'color': sns.color_palette()[0]},
    line_kws={'color': sns.color_palette()[3]},
)

plt.title('Residual Plot')
plt.xlabel('Predicted Fantasy Points Scored')
plt.ylabel('Actual Minus Predicted')

plt.show()

# %%
import shap

explainer = shap.Explainer(mod, feature_names=X_train.columns, seed=22)

shap_values = explainer(pd.concat([i[0] for i in cv_data], ignore_index=True))

shap_values.shape
# Out:
# (3278, 4)

# %%
shap.plots.beeswarm(shap_values, max_display=None)
